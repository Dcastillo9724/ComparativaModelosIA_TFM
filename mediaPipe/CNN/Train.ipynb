# %%
import joblib
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Cargar datos
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Pose', 'pose_data_images.csv')
ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual, 'datos', 'scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')

data = pd.read_csv(ruta_csv)

# Preparar datos
num_keypoints = 33 * 3
X = data.iloc[:, :num_keypoints].values
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

X_train, X_test, y_continuas_train, y_continuas_test, y_clase_train, y_clase_test = train_test_split(
    X, y_continuas, y_clase_encoded, test_size=0.2, random_state=42)

scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

X_train_cnn = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_cnn = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

# Función para crear el modelo con ajustes de hiperparámetros
def create_model(learning_rate=0.001):
    input_layer = Input(shape=(X_train_cnn.shape[1], X_train_cnn.shape[2]))
    x = Conv1D(64, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(input_layer)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Conv1D(64, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Conv1D(32, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Flatten()(x)
    
    salidas_continuas = Dense(6, activation='linear', name='salidas_continuas')(x)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)
    
    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])
    
    optimizer = Adam(learning_rate=learning_rate)
    
    model.compile(optimizer=optimizer,
                  loss={'salidas_continuas': 'mean_squared_error', 'salida_clase': 'sparse_categorical_crossentropy'},
                  metrics={'salidas_continuas': 'mae', 'salida_clase': 'accuracy'})
    
    return model

# Listas para almacenar métricas
all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

# Matrices para almacenar la historia del entrenamiento
n_epochs = 150  # Número de épocas
all_train_loss = np.full((5, n_epochs), np.nan)  
all_val_loss = np.full((5, n_epochs), np.nan)
all_train_accuracy = np.full((5, n_epochs), np.nan)
all_val_accuracy = np.full((5, n_epochs), np.nan)

# Optimización de hiperparámetros y validación cruzada
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

fold_index = 0
for train_index, val_index in kfold.split(X_train_cnn):
    fold_index += 1
    print(f"Entrenando fold {fold_index}...")

    X_train_fold, X_val_fold = X_train_cnn[train_index], X_train_cnn[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas_train[train_index], y_continuas_train[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_train[train_index], y_clase_train[val_index]

    model = create_model(learning_rate=0.0005)  # Ajustar la tasa de aprendizaje aquí
    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold_index}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    # Almacenar la historia del entrenamiento como matrices NumPy
    epochs_completed = len(history.history['loss'])
    all_train_loss[fold_index - 1, :epochs_completed] = history.history['loss']
    all_val_loss[fold_index - 1, :epochs_completed] = history.history['val_loss']
    all_train_accuracy[fold_index - 1, :epochs_completed] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold_index - 1, :epochs_completed] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de prueba
    scores = model.evaluate(X_test_cnn, {'salidas_continuas': y_continuas_test, 'salida_clase': y_clase_test})
    print(f"Fold {fold_index}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_test_cnn)[0]
    mae = mean_absolute_error(y_continuas_test, y_pred_continuas)
    mse = mean_squared_error(y_continuas_test, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_test)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_test_cnn)[1], axis=1)
    precision = precision_score(y_clase_test, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_test, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_test, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_test, y_pred_clase, labels=np.unique(y_clase_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 10903.3330 - salida_clase_accuracy: 0.3907 - salidas_continuas_mae: 92.8743 - val_loss: 9585.9951 - val_salida_clase_accuracy: 0.5651 - val_salidas_continuas_mae: 86.5041 - learning_rate: 5.0000e-04
# Epoch 2/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3616.8962 - salida_clase_accuracy: 0.6721 - salidas_continuas_mae: 50.7954 - val_loss: 2753.8931 - val_salida_clase_accuracy: 0.6760 - val_salidas_continuas_mae: 43.8564 - learning_rate: 5.0000e-04
# Epoch 3/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1380.7874 - salida_clase_accuracy: 0.7266 - salidas_continuas_mae: 31.0942 - val_loss: 1292.6903 - val_salida_clase_accuracy: 0.7456 - val_salidas_continuas_mae: 29.7975 - learning_rate: 5.0000e-04
# Epoch 4/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1093.4001 - salida_clase_accuracy: 0.7938 - salidas_continuas_mae: 26.6199 - val_loss: 1083.5820 - val_salida_clase_accuracy: 0.7825 - val_salidas_continuas_mae: 27.0864 - learning_rate: 5.0000e-04
# Epoch 5/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 986.0256 - salida_clase_accuracy: 0.8014 - salidas_continuas_mae: 24.8744 - val_loss: 1032.9329 - val_salida_clase_accuracy: 0.7885 - val_salidas_continuas_mae: 26.3037 - learning_rate: 5.0000e-04
# Epoch 6/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 906.7595 - salida_clase_accuracy: 0.7952 - salidas_continuas_mae: 23.7481 - val_loss: 972.4242 - val_salida_clase_accuracy: 0.8107 - val_salidas_continuas_mae: 25.3757 - learning_rate: 5.0000e-04
# Epoch 7/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 888.1772 - salida_clase_accuracy: 0.8167 - salidas_continuas_mae: 23.3353 - val_loss: 862.4842 - val_salida_clase_accuracy: 0.8343 - val_salidas_continuas_mae: 23.6730 - learning_rate: 5.0000e-04
# Epoch 8/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 843.0314 - salida_clase_accuracy: 0.8253 - salidas_continuas_mae: 22.5713 - val_loss: 864.6785 - val_salida_clase_accuracy: 0.8432 - val_salidas_continuas_mae: 23.6187 - learning_rate: 5.0000e-04
# Epoch 9/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 804.7345 - salida_clase_accuracy: 0.8299 - salidas_continuas_mae: 21.9766 - val_loss: 792.5893 - val_salida_clase_accuracy: 0.8136 - val_salidas_continuas_mae: 22.4137 - learning_rate: 5.0000e-04
# Epoch 10/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 790.8289 - salida_clase_accuracy: 0.8268 - salidas_continuas_mae: 21.7981 - val_loss: 751.7469 - val_salida_clase_accuracy: 0.8506 - val_salidas_continuas_mae: 21.6866 - learning_rate: 5.0000e-04
# Epoch 11/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 773.3994 - salida_clase_accuracy: 0.8329 - salidas_continuas_mae: 21.4727 - val_loss: 740.0227 - val_salida_clase_accuracy: 0.8595 - val_salidas_continuas_mae: 21.4478 - learning_rate: 5.0000e-04
# Epoch 12/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 718.4319 - salida_clase_accuracy: 0.8357 - salidas_continuas_mae: 20.6453 - val_loss: 704.6005 - val_salida_clase_accuracy: 0.8817 - val_salidas_continuas_mae: 20.7756 - learning_rate: 5.0000e-04
# Epoch 13/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 717.6850 - salida_clase_accuracy: 0.8354 - salidas_continuas_mae: 20.5090 - val_loss: 724.8820 - val_salida_clase_accuracy: 0.8757 - val_salidas_continuas_mae: 21.1977 - learning_rate: 5.0000e-04
# Epoch 14/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 683.7809 - salida_clase_accuracy: 0.8481 - salidas_continuas_mae: 19.9060 - val_loss: 694.9668 - val_salida_clase_accuracy: 0.8787 - val_salidas_continuas_mae: 20.6266 - learning_rate: 5.0000e-04
# Epoch 15/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 689.4937 - salida_clase_accuracy: 0.8586 - salidas_continuas_mae: 19.9521 - val_loss: 640.5992 - val_salida_clase_accuracy: 0.8772 - val_salidas_continuas_mae: 19.5635 - learning_rate: 5.0000e-04
# Epoch 16/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 645.4265 - salida_clase_accuracy: 0.8582 - salidas_continuas_mae: 19.3056 - val_loss: 645.4029 - val_salida_clase_accuracy: 0.8831 - val_salidas_continuas_mae: 19.6780 - learning_rate: 5.0000e-04
# Epoch 17/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 649.7058 - salida_clase_accuracy: 0.8540 - salidas_continuas_mae: 19.2688 - val_loss: 608.8957 - val_salida_clase_accuracy: 0.8772 - val_salidas_continuas_mae: 18.9302 - learning_rate: 5.0000e-04
# Epoch 18/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 628.4475 - salida_clase_accuracy: 0.8655 - salidas_continuas_mae: 18.9260 - val_loss: 617.3157 - val_salida_clase_accuracy: 0.8787 - val_salidas_continuas_mae: 19.0996 - learning_rate: 5.0000e-04
# Epoch 19/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 609.8331 - salida_clase_accuracy: 0.8636 - salidas_continuas_mae: 18.5228 - val_loss: 604.6691 - val_salida_clase_accuracy: 0.8817 - val_salidas_continuas_mae: 18.8270 - learning_rate: 5.0000e-04
# Epoch 20/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 610.2200 - salida_clase_accuracy: 0.8725 - salidas_continuas_mae: 18.5370 - val_loss: 593.5337 - val_salida_clase_accuracy: 0.8861 - val_salidas_continuas_mae: 18.5907 - learning_rate: 5.0000e-04
# Epoch 21/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 621.6349 - salida_clase_accuracy: 0.8734 - salidas_continuas_mae: 18.5794 - val_loss: 582.4518 - val_salida_clase_accuracy: 0.8580 - val_salidas_continuas_mae: 18.4364 - learning_rate: 5.0000e-04
# Epoch 22/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 586.2697 - salida_clase_accuracy: 0.8520 - salidas_continuas_mae: 18.1688 - val_loss: 592.2724 - val_salida_clase_accuracy: 0.8817 - val_salidas_continuas_mae: 18.6529 - learning_rate: 5.0000e-04
# Epoch 23/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 581.5861 - salida_clase_accuracy: 0.8530 - salidas_continuas_mae: 17.9751 - val_loss: 570.4584 - val_salida_clase_accuracy: 0.8935 - val_salidas_continuas_mae: 18.1982 - learning_rate: 5.0000e-04
# Epoch 24/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 557.3268 - salida_clase_accuracy: 0.8771 - salidas_continuas_mae: 17.6247 - val_loss: 597.2981 - val_salida_clase_accuracy: 0.8846 - val_salidas_continuas_mae: 18.7884 - learning_rate: 5.0000e-04
# Epoch 25/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 551.8868 - salida_clase_accuracy: 0.8716 - salidas_continuas_mae: 17.3914 - val_loss: 550.8606 - val_salida_clase_accuracy: 0.8831 - val_salidas_continuas_mae: 17.8298 - learning_rate: 5.0000e-04
# Epoch 26/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 545.5007 - salida_clase_accuracy: 0.8887 - salidas_continuas_mae: 17.3542 - val_loss: 536.6835 - val_salida_clase_accuracy: 0.8861 - val_salidas_continuas_mae: 17.4528 - learning_rate: 5.0000e-04
# Epoch 27/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 526.3624 - salida_clase_accuracy: 0.8848 - salidas_continuas_mae: 16.9483 - val_loss: 529.6689 - val_salida_clase_accuracy: 0.8950 - val_salidas_continuas_mae: 17.3536 - learning_rate: 5.0000e-04
# Epoch 28/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 549.4440 - salida_clase_accuracy: 0.8809 - salidas_continuas_mae: 17.3320 - val_loss: 505.7783 - val_salida_clase_accuracy: 0.8905 - val_salidas_continuas_mae: 16.8026 - learning_rate: 5.0000e-04
# Epoch 29/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 504.4881 - salida_clase_accuracy: 0.8868 - salidas_continuas_mae: 16.6329 - val_loss: 501.6693 - val_salida_clase_accuracy: 0.8950 - val_salidas_continuas_mae: 16.6624 - learning_rate: 5.0000e-04
# Epoch 30/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 507.6767 - salida_clase_accuracy: 0.8859 - salidas_continuas_mae: 16.6500 - val_loss: 516.0493 - val_salida_clase_accuracy: 0.8891 - val_salidas_continuas_mae: 17.0560 - learning_rate: 5.0000e-04
# Epoch 31/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 513.2247 - salida_clase_accuracy: 0.8816 - salidas_continuas_mae: 16.7142 - val_loss: 490.5385 - val_salida_clase_accuracy: 0.8950 - val_salidas_continuas_mae: 16.5259 - learning_rate: 5.0000e-04
# Epoch 32/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 511.0954 - salida_clase_accuracy: 0.8831 - salidas_continuas_mae: 16.7047 - val_loss: 491.7876 - val_salida_clase_accuracy: 0.8891 - val_salidas_continuas_mae: 16.4972 - learning_rate: 5.0000e-04
# Epoch 33/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 515.8622 - salida_clase_accuracy: 0.8648 - salidas_continuas_mae: 16.6845 - val_loss: 489.3369 - val_salida_clase_accuracy: 0.8772 - val_salidas_continuas_mae: 16.4085 - learning_rate: 5.0000e-04
# Epoch 34/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 492.4762 - salida_clase_accuracy: 0.8900 - salidas_continuas_mae: 16.2608 - val_loss: 475.9324 - val_salida_clase_accuracy: 0.8950 - val_salidas_continuas_mae: 16.2113 - learning_rate: 5.0000e-04
# Epoch 35/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 491.8470 - salida_clase_accuracy: 0.8774 - salidas_continuas_mae: 16.2079 - val_loss: 462.4395 - val_salida_clase_accuracy: 0.8935 - val_salidas_continuas_mae: 15.8341 - learning_rate: 5.0000e-04
# Epoch 36/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 494.3859 - salida_clase_accuracy: 0.8988 - salidas_continuas_mae: 16.1487 - val_loss: 472.0464 - val_salida_clase_accuracy: 0.8905 - val_salidas_continuas_mae: 16.1292 - learning_rate: 5.0000e-04
# Epoch 37/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 492.5509 - salida_clase_accuracy: 0.8867 - salidas_continuas_mae: 16.3046 - val_loss: 471.7434 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 16.1554 - learning_rate: 5.0000e-04
# Epoch 38/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 474.0935 - salida_clase_accuracy: 0.8889 - salidas_continuas_mae: 15.9402 - val_loss: 451.4277 - val_salida_clase_accuracy: 0.8979 - val_salidas_continuas_mae: 15.6210 - learning_rate: 5.0000e-04
# Epoch 39/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 464.6126 - salida_clase_accuracy: 0.8954 - salidas_continuas_mae: 15.6978 - val_loss: 444.4769 - val_salida_clase_accuracy: 0.9068 - val_salidas_continuas_mae: 15.4487 - learning_rate: 5.0000e-04
# Epoch 40/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 470.5021 - salida_clase_accuracy: 0.9072 - salidas_continuas_mae: 15.6314 - val_loss: 441.1094 - val_salida_clase_accuracy: 0.9009 - val_salidas_continuas_mae: 15.2955 - learning_rate: 5.0000e-04
# Epoch 41/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 474.5473 - salida_clase_accuracy: 0.8881 - salidas_continuas_mae: 15.9529 - val_loss: 447.6281 - val_salida_clase_accuracy: 0.8979 - val_salidas_continuas_mae: 15.5603 - learning_rate: 5.0000e-04
# Epoch 42/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 436.5481 - salida_clase_accuracy: 0.9036 - salidas_continuas_mae: 15.2771 - val_loss: 481.0424 - val_salida_clase_accuracy: 0.8891 - val_salidas_continuas_mae: 16.4765 - learning_rate: 5.0000e-04
# Epoch 43/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 453.7464 - salida_clase_accuracy: 0.8941 - salidas_continuas_mae: 15.5049 - val_loss: 441.5095 - val_salida_clase_accuracy: 0.9038 - val_salidas_continuas_mae: 15.4274 - learning_rate: 5.0000e-04
# Epoch 44/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 449.4384 - salida_clase_accuracy: 0.8895 - salidas_continuas_mae: 15.4966 - val_loss: 453.9433 - val_salida_clase_accuracy: 0.8905 - val_salidas_continuas_mae: 15.6877 - learning_rate: 5.0000e-04
# Epoch 45/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 446.4001 - salida_clase_accuracy: 0.8842 - salidas_continuas_mae: 15.3142 - val_loss: 417.2647 - val_salida_clase_accuracy: 0.9098 - val_salidas_continuas_mae: 14.7537 - learning_rate: 5.0000e-04
# Epoch 46/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 440.0725 - salida_clase_accuracy: 0.8981 - salidas_continuas_mae: 15.3055 - val_loss: 433.5622 - val_salida_clase_accuracy: 0.8905 - val_salidas_continuas_mae: 15.2659 - learning_rate: 5.0000e-04
# Epoch 47/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 459.2431 - salida_clase_accuracy: 0.9042 - salidas_continuas_mae: 15.5550 - val_loss: 423.0377 - val_salida_clase_accuracy: 0.9009 - val_salidas_continuas_mae: 14.9341 - learning_rate: 5.0000e-04
# Epoch 48/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 446.4024 - salida_clase_accuracy: 0.9035 - salidas_continuas_mae: 15.3221 - val_loss: 419.1437 - val_salida_clase_accuracy: 0.9009 - val_salidas_continuas_mae: 14.8403 - learning_rate: 5.0000e-04
# Epoch 49/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 411.7488 - salida_clase_accuracy: 0.9028 - salidas_continuas_mae: 14.8243 - val_loss: 421.7661 - val_salida_clase_accuracy: 0.8905 - val_salidas_continuas_mae: 14.9421 - learning_rate: 5.0000e-04
# Epoch 50/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 446.7095 - salida_clase_accuracy: 0.8870 - salidas_continuas_mae: 15.3335 - val_loss: 418.1512 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 14.8214 - learning_rate: 5.0000e-04
# Epoch 51/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 427.8217 - salida_clase_accuracy: 0.9045 - salidas_continuas_mae: 14.9610 - val_loss: 417.2163 - val_salida_clase_accuracy: 0.9186 - val_salidas_continuas_mae: 14.8169 - learning_rate: 2.5000e-04
# Epoch 52/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 427.8676 - salida_clase_accuracy: 0.9166 - salidas_continuas_mae: 15.0201 - val_loss: 412.4726 - val_salida_clase_accuracy: 0.9098 - val_salidas_continuas_mae: 14.7043 - learning_rate: 2.5000e-04
# Epoch 53/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 421.1803 - salida_clase_accuracy: 0.9104 - salidas_continuas_mae: 14.8163 - val_loss: 418.1202 - val_salida_clase_accuracy: 0.9098 - val_salidas_continuas_mae: 14.8228 - learning_rate: 2.5000e-04
# Epoch 54/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 417.9127 - salida_clase_accuracy: 0.9154 - salidas_continuas_mae: 14.7335 - val_loss: 427.2132 - val_salida_clase_accuracy: 0.9157 - val_salidas_continuas_mae: 15.1058 - learning_rate: 2.5000e-04
# Epoch 55/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 429.8148 - salida_clase_accuracy: 0.9070 - salidas_continuas_mae: 14.9727 - val_loss: 409.3896 - val_salida_clase_accuracy: 0.9068 - val_salidas_continuas_mae: 14.5832 - learning_rate: 2.5000e-04
# Epoch 56/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 428.1594 - salida_clase_accuracy: 0.9073 - salidas_continuas_mae: 15.0469 - val_loss: 407.3882 - val_salida_clase_accuracy: 0.9098 - val_salidas_continuas_mae: 14.5836 - learning_rate: 2.5000e-04
# Epoch 57/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 415.8530 - salida_clase_accuracy: 0.9112 - salidas_continuas_mae: 14.7587 - val_loss: 402.2344 - val_salida_clase_accuracy: 0.9112 - val_salidas_continuas_mae: 14.4089 - learning_rate: 2.5000e-04
# Epoch 58/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 419.1064 - salida_clase_accuracy: 0.8982 - salidas_continuas_mae: 14.8556 - val_loss: 417.1353 - val_salida_clase_accuracy: 0.9112 - val_salidas_continuas_mae: 14.8764 - learning_rate: 2.5000e-04
# Epoch 59/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 434.4259 - salida_clase_accuracy: 0.9133 - salidas_continuas_mae: 15.0064 - val_loss: 399.6238 - val_salida_clase_accuracy: 0.9157 - val_salidas_continuas_mae: 14.3256 - learning_rate: 2.5000e-04
# Epoch 60/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 413.2242 - salida_clase_accuracy: 0.9182 - salidas_continuas_mae: 14.5931 - val_loss: 403.6592 - val_salida_clase_accuracy: 0.9172 - val_salidas_continuas_mae: 14.4853 - learning_rate: 2.5000e-04
# Epoch 61/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 415.0324 - salida_clase_accuracy: 0.9133 - salidas_continuas_mae: 14.7700 - val_loss: 400.5546 - val_salida_clase_accuracy: 0.9172 - val_salidas_continuas_mae: 14.4038 - learning_rate: 2.5000e-04
# Epoch 62/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 403.2054 - salida_clase_accuracy: 0.9148 - salidas_continuas_mae: 14.6273 - val_loss: 405.6652 - val_salida_clase_accuracy: 0.9098 - val_salidas_continuas_mae: 14.5583 - learning_rate: 2.5000e-04
# Epoch 63/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 407.4146 - salida_clase_accuracy: 0.9174 - salidas_continuas_mae: 14.6550 - val_loss: 398.8314 - val_salida_clase_accuracy: 0.9068 - val_salidas_continuas_mae: 14.3193 - learning_rate: 2.5000e-04
# Epoch 64/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 423.5547 - salida_clase_accuracy: 0.9162 - salidas_continuas_mae: 14.8285 - val_loss: 395.9107 - val_salida_clase_accuracy: 0.9024 - val_salidas_continuas_mae: 14.2222 - learning_rate: 2.5000e-04
# Epoch 65/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 404.8246 - salida_clase_accuracy: 0.9190 - salidas_continuas_mae: 14.6175 - val_loss: 408.2088 - val_salida_clase_accuracy: 0.9053 - val_salidas_continuas_mae: 14.6110 - learning_rate: 2.5000e-04
# Epoch 66/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 406.6799 - salida_clase_accuracy: 0.9031 - salidas_continuas_mae: 14.7301 - val_loss: 405.7641 - val_salida_clase_accuracy: 0.9157 - val_salidas_continuas_mae: 14.5611 - learning_rate: 2.5000e-04
# Epoch 67/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 409.2168 - salida_clase_accuracy: 0.9013 - salidas_continuas_mae: 14.6974 - val_loss: 404.4877 - val_salida_clase_accuracy: 0.9038 - val_salidas_continuas_mae: 14.5386 - learning_rate: 2.5000e-04
# Epoch 68/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 408.1745 - salida_clase_accuracy: 0.9078 - salidas_continuas_mae: 14.6646 - val_loss: 406.7775 - val_salida_clase_accuracy: 0.9142 - val_salidas_continuas_mae: 14.5999 - learning_rate: 2.5000e-04
# Epoch 69/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 414.8752 - salida_clase_accuracy: 0.9171 - salidas_continuas_mae: 14.7608 - val_loss: 401.9044 - val_salida_clase_accuracy: 0.9172 - val_salidas_continuas_mae: 14.4563 - learning_rate: 2.5000e-04
# Epoch 70/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 408.4842 - salida_clase_accuracy: 0.9223 - salidas_continuas_mae: 14.7117 - val_loss: 395.7905 - val_salida_clase_accuracy: 0.9172 - val_salidas_continuas_mae: 14.2788 - learning_rate: 1.2500e-04
# Epoch 71/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 387.4000 - salida_clase_accuracy: 0.9258 - salidas_continuas_mae: 14.2057 - val_loss: 392.6333 - val_salida_clase_accuracy: 0.9142 - val_salidas_continuas_mae: 14.1780 - learning_rate: 1.2500e-04
# Epoch 72/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 397.2306 - salida_clase_accuracy: 0.9214 - salidas_continuas_mae: 14.4500 - val_loss: 400.3007 - val_salida_clase_accuracy: 0.9142 - val_salidas_continuas_mae: 14.3985 - learning_rate: 1.2500e-04
# Epoch 73/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 397.5900 - salida_clase_accuracy: 0.9246 - salidas_continuas_mae: 14.3668 - val_loss: 393.6173 - val_salida_clase_accuracy: 0.9201 - val_salidas_continuas_mae: 14.1963 - learning_rate: 1.2500e-04
# Epoch 74/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 399.9144 - salida_clase_accuracy: 0.9225 - salidas_continuas_mae: 14.4623 - val_loss: 399.9394 - val_salida_clase_accuracy: 0.9112 - val_salidas_continuas_mae: 14.4058 - learning_rate: 1.2500e-04
# Epoch 75/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 403.2417 - salida_clase_accuracy: 0.9264 - salidas_continuas_mae: 14.4499 - val_loss: 391.3050 - val_salida_clase_accuracy: 0.9112 - val_salidas_continuas_mae: 14.1251 - learning_rate: 1.2500e-04
# Epoch 76/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 388.7303 - salida_clase_accuracy: 0.9230 - salidas_continuas_mae: 14.2944 - val_loss: 397.7597 - val_salida_clase_accuracy: 0.9098 - val_salidas_continuas_mae: 14.3646 - learning_rate: 1.2500e-04
# Epoch 77/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 384.2015 - salida_clase_accuracy: 0.9204 - salidas_continuas_mae: 14.1811 - val_loss: 396.3349 - val_salida_clase_accuracy: 0.9201 - val_salidas_continuas_mae: 14.3006 - learning_rate: 1.2500e-04
# Epoch 78/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 399.4466 - salida_clase_accuracy: 0.9182 - salidas_continuas_mae: 14.4788 - val_loss: 391.8347 - val_salida_clase_accuracy: 0.9142 - val_salidas_continuas_mae: 14.1609 - learning_rate: 1.2500e-04
# Epoch 79/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 382.9856 - salida_clase_accuracy: 0.9158 - salidas_continuas_mae: 14.1173 - val_loss: 389.8583 - val_salida_clase_accuracy: 0.9201 - val_salidas_continuas_mae: 14.1147 - learning_rate: 1.2500e-04
# Epoch 80/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 415.5105 - salida_clase_accuracy: 0.9210 - salidas_continuas_mae: 14.6526 - val_loss: 391.8446 - val_salida_clase_accuracy: 0.9157 - val_salidas_continuas_mae: 14.1552 - learning_rate: 1.2500e-04
# Epoch 81/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 408.7772 - salida_clase_accuracy: 0.9189 - salidas_continuas_mae: 14.7078 - val_loss: 395.0733 - val_salida_clase_accuracy: 0.9246 - val_salidas_continuas_mae: 14.2856 - learning_rate: 1.2500e-04
# Epoch 82/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 397.1118 - salida_clase_accuracy: 0.9283 - salidas_continuas_mae: 14.3178 - val_loss: 394.9657 - val_salida_clase_accuracy: 0.9231 - val_salidas_continuas_mae: 14.2775 - learning_rate: 1.2500e-04
# Epoch 83/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 398.6513 - salida_clase_accuracy: 0.9264 - salidas_continuas_mae: 14.4944 - val_loss: 393.3192 - val_salida_clase_accuracy: 0.9186 - val_salidas_continuas_mae: 14.2154 - learning_rate: 1.2500e-04
# Epoch 84/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 388.8446 - salida_clase_accuracy: 0.9262 - salidas_continuas_mae: 14.2967 - val_loss: 396.1412 - val_salida_clase_accuracy: 0.9112 - val_salidas_continuas_mae: 14.3031 - learning_rate: 1.2500e-04
# Epoch 85/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 405.5153 - salida_clase_accuracy: 0.9218 - salidas_continuas_mae: 14.4997 - val_loss: 388.6861 - val_salida_clase_accuracy: 0.9201 - val_salidas_continuas_mae: 14.0774 - learning_rate: 6.2500e-05
# Epoch 86/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 416.9129 - salida_clase_accuracy: 0.9197 - salidas_continuas_mae: 14.7855 - val_loss: 389.9702 - val_salida_clase_accuracy: 0.9201 - val_salidas_continuas_mae: 14.1195 - learning_rate: 6.2500e-05
# Epoch 87/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 392.1535 - salida_clase_accuracy: 0.9313 - salidas_continuas_mae: 14.3178 - val_loss: 388.6545 - val_salida_clase_accuracy: 0.9231 - val_salidas_continuas_mae: 14.0839 - learning_rate: 6.2500e-05
# Epoch 88/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 391.8441 - salida_clase_accuracy: 0.9259 - salidas_continuas_mae: 14.3249 - val_loss: 389.2547 - val_salida_clase_accuracy: 0.9172 - val_salidas_continuas_mae: 14.0978 - learning_rate: 6.2500e-05
# Epoch 89/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 389.1438 - salida_clase_accuracy: 0.9213 - salidas_continuas_mae: 14.3492 - val_loss: 389.8652 - val_salida_clase_accuracy: 0.9172 - val_salidas_continuas_mae: 14.1117 - learning_rate: 6.2500e-05
# Epoch 90/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 396.6044 - salida_clase_accuracy: 0.9208 - salidas_continuas_mae: 14.3040 - val_loss: 389.2921 - val_salida_clase_accuracy: 0.9216 - val_salidas_continuas_mae: 14.0962 - learning_rate: 6.2500e-05
# Epoch 91/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 397.1740 - salida_clase_accuracy: 0.9322 - salidas_continuas_mae: 14.4154 - val_loss: 391.2724 - val_salida_clase_accuracy: 0.9231 - val_salidas_continuas_mae: 14.1596 - learning_rate: 6.2500e-05
# Epoch 92/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 391.1253 - salida_clase_accuracy: 0.9257 - salidas_continuas_mae: 14.3543 - val_loss: 391.8029 - val_salida_clase_accuracy: 0.9201 - val_salidas_continuas_mae: 14.1654 - learning_rate: 6.2500e-05
# Epoch 93/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 408.1696 - salida_clase_accuracy: 0.9285 - salidas_continuas_mae: 14.5010 - val_loss: 388.8543 - val_salida_clase_accuracy: 0.9201 - val_salidas_continuas_mae: 14.0797 - learning_rate: 3.1250e-05
# Epoch 94/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 384.0608 - salida_clase_accuracy: 0.9388 - salidas_continuas_mae: 14.1848 - val_loss: 389.5572 - val_salida_clase_accuracy: 0.9201 - val_salidas_continuas_mae: 14.1040 - learning_rate: 3.1250e-05
# Epoch 95/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 385.2667 - salida_clase_accuracy: 0.9396 - salidas_continuas_mae: 14.2180 - val_loss: 389.5447 - val_salida_clase_accuracy: 0.9186 - val_salidas_continuas_mae: 14.1078 - learning_rate: 3.1250e-05
# Epoch 96/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 401.4620 - salida_clase_accuracy: 0.9211 - salidas_continuas_mae: 14.4289 - val_loss: 389.8808 - val_salida_clase_accuracy: 0.9186 - val_salidas_continuas_mae: 14.1225 - learning_rate: 3.1250e-05
# Epoch 97/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 392.9430 - salida_clase_accuracy: 0.9241 - salidas_continuas_mae: 14.3990 - val_loss: 388.9882 - val_salida_clase_accuracy: 0.9157 - val_salidas_continuas_mae: 14.0872 - learning_rate: 3.1250e-05
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 366.3574 - salida_clase_accuracy: 0.9297 - salidas_continuas_mae: 13.6231
# Fold 1: Loss=374.2164611816406, MAE=13.588884353637695, Accuracy=0.9325443506240845
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Entrenando fold 2...
# Epoch 1/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 10754.7441 - salida_clase_accuracy: 0.3566 - salidas_continuas_mae: 92.1921 - val_loss: 9389.2578 - val_salida_clase_accuracy: 0.6474 - val_salidas_continuas_mae: 85.3010 - learning_rate: 5.0000e-04
# Epoch 2/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3561.4275 - salida_clase_accuracy: 0.6442 - salidas_continuas_mae: 50.4807 - val_loss: 2374.5210 - val_salida_clase_accuracy: 0.6578 - val_salidas_continuas_mae: 40.5095 - learning_rate: 5.0000e-04
# Epoch 3/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1319.0890 - salida_clase_accuracy: 0.7047 - salidas_continuas_mae: 30.2562 - val_loss: 1406.0350 - val_salida_clase_accuracy: 0.7585 - val_salidas_continuas_mae: 30.9463 - learning_rate: 5.0000e-04
# Epoch 4/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1064.3938 - salida_clase_accuracy: 0.7509 - salidas_continuas_mae: 26.2729 - val_loss: 1180.9708 - val_salida_clase_accuracy: 0.7911 - val_salidas_continuas_mae: 28.1373 - learning_rate: 5.0000e-04
# Epoch 5/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1020.7091 - salida_clase_accuracy: 0.7744 - salidas_continuas_mae: 25.4453 - val_loss: 1044.2164 - val_salida_clase_accuracy: 0.8504 - val_salidas_continuas_mae: 26.1982 - learning_rate: 5.0000e-04
# Epoch 6/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 918.1980 - salida_clase_accuracy: 0.7826 - salidas_continuas_mae: 24.1466 - val_loss: 1085.0985 - val_salida_clase_accuracy: 0.8504 - val_salidas_continuas_mae: 26.8540 - learning_rate: 5.0000e-04
# Epoch 7/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 904.5248 - salida_clase_accuracy: 0.8184 - salidas_continuas_mae: 23.7373 - val_loss: 984.6598 - val_salida_clase_accuracy: 0.8504 - val_salidas_continuas_mae: 25.3165 - learning_rate: 5.0000e-04
# Epoch 8/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 829.5059 - salida_clase_accuracy: 0.8366 - salidas_continuas_mae: 22.4932 - val_loss: 951.6954 - val_salida_clase_accuracy: 0.8607 - val_salidas_continuas_mae: 24.7827 - learning_rate: 5.0000e-04
# Epoch 9/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 797.9250 - salida_clase_accuracy: 0.8162 - salidas_continuas_mae: 21.9765 - val_loss: 916.0372 - val_salida_clase_accuracy: 0.8681 - val_salidas_continuas_mae: 24.1540 - learning_rate: 5.0000e-04
# Epoch 10/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 767.0791 - salida_clase_accuracy: 0.8462 - salidas_continuas_mae: 21.6054 - val_loss: 920.0212 - val_salida_clase_accuracy: 0.8770 - val_salidas_continuas_mae: 24.2075 - learning_rate: 5.0000e-04
# Epoch 11/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 742.5116 - salida_clase_accuracy: 0.8418 - salidas_continuas_mae: 21.0157 - val_loss: 806.0388 - val_salida_clase_accuracy: 0.8756 - val_salidas_continuas_mae: 22.1212 - learning_rate: 5.0000e-04
# Epoch 12/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 712.7342 - salida_clase_accuracy: 0.8436 - salidas_continuas_mae: 20.5881 - val_loss: 804.7518 - val_salida_clase_accuracy: 0.8874 - val_salidas_continuas_mae: 22.1677 - learning_rate: 5.0000e-04
# Epoch 13/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 720.8242 - salida_clase_accuracy: 0.8542 - salidas_continuas_mae: 20.5861 - val_loss: 741.1359 - val_salida_clase_accuracy: 0.8607 - val_salidas_continuas_mae: 20.9334 - learning_rate: 5.0000e-04
# Epoch 14/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 674.1002 - salida_clase_accuracy: 0.8484 - salidas_continuas_mae: 19.9566 - val_loss: 754.9718 - val_salida_clase_accuracy: 0.8770 - val_salidas_continuas_mae: 21.2340 - learning_rate: 5.0000e-04
# Epoch 15/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 684.2738 - salida_clase_accuracy: 0.8454 - salidas_continuas_mae: 19.8970 - val_loss: 711.4603 - val_salida_clase_accuracy: 0.8800 - val_salidas_continuas_mae: 20.3483 - learning_rate: 5.0000e-04
# Epoch 16/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 664.4556 - salida_clase_accuracy: 0.8578 - salidas_continuas_mae: 19.7714 - val_loss: 694.3802 - val_salida_clase_accuracy: 0.8904 - val_salidas_continuas_mae: 20.0181 - learning_rate: 5.0000e-04
# Epoch 17/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 646.2098 - salida_clase_accuracy: 0.8677 - salidas_continuas_mae: 19.4038 - val_loss: 702.3824 - val_salida_clase_accuracy: 0.8844 - val_salidas_continuas_mae: 20.2336 - learning_rate: 5.0000e-04
# Epoch 18/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 614.7402 - salida_clase_accuracy: 0.8565 - salidas_continuas_mae: 18.8234 - val_loss: 665.0381 - val_salida_clase_accuracy: 0.8785 - val_salidas_continuas_mae: 19.4484 - learning_rate: 5.0000e-04
# Epoch 19/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 634.0350 - salida_clase_accuracy: 0.8721 - salidas_continuas_mae: 19.1474 - val_loss: 651.4539 - val_salida_clase_accuracy: 0.8874 - val_salidas_continuas_mae: 19.1329 - learning_rate: 5.0000e-04
# Epoch 20/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 610.4473 - salida_clase_accuracy: 0.8794 - salidas_continuas_mae: 18.6043 - val_loss: 669.9943 - val_salida_clase_accuracy: 0.8785 - val_salidas_continuas_mae: 19.6719 - learning_rate: 5.0000e-04
# Epoch 21/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 601.8646 - salida_clase_accuracy: 0.8624 - salidas_continuas_mae: 18.4802 - val_loss: 644.9373 - val_salida_clase_accuracy: 0.8830 - val_salidas_continuas_mae: 19.1303 - learning_rate: 5.0000e-04
# Epoch 22/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 582.9109 - salida_clase_accuracy: 0.8708 - salidas_continuas_mae: 18.2981 - val_loss: 633.9825 - val_salida_clase_accuracy: 0.8830 - val_salidas_continuas_mae: 18.9163 - learning_rate: 5.0000e-04
# Epoch 23/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 566.2971 - salida_clase_accuracy: 0.8678 - salidas_continuas_mae: 17.7566 - val_loss: 615.1959 - val_salida_clase_accuracy: 0.8859 - val_salidas_continuas_mae: 18.5259 - learning_rate: 5.0000e-04
# Epoch 24/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 567.8828 - salida_clase_accuracy: 0.8750 - salidas_continuas_mae: 17.8327 - val_loss: 618.1503 - val_salida_clase_accuracy: 0.8904 - val_salidas_continuas_mae: 18.6336 - learning_rate: 5.0000e-04
# Epoch 25/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 555.0688 - salida_clase_accuracy: 0.8780 - salidas_continuas_mae: 17.5477 - val_loss: 603.4141 - val_salida_clase_accuracy: 0.8963 - val_salidas_continuas_mae: 18.2983 - learning_rate: 5.0000e-04
# Epoch 26/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 527.7535 - salida_clase_accuracy: 0.8874 - salidas_continuas_mae: 17.0606 - val_loss: 593.4278 - val_salida_clase_accuracy: 0.9081 - val_salidas_continuas_mae: 18.1360 - learning_rate: 5.0000e-04
# Epoch 27/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 543.9352 - salida_clase_accuracy: 0.8779 - salidas_continuas_mae: 17.2895 - val_loss: 601.0329 - val_salida_clase_accuracy: 0.8904 - val_salidas_continuas_mae: 18.3591 - learning_rate: 5.0000e-04
# Epoch 28/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 541.8259 - salida_clase_accuracy: 0.8747 - salidas_continuas_mae: 17.3103 - val_loss: 573.0063 - val_salida_clase_accuracy: 0.8830 - val_salidas_continuas_mae: 17.7422 - learning_rate: 5.0000e-04
# Epoch 29/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 534.6066 - salida_clase_accuracy: 0.8682 - salidas_continuas_mae: 17.1587 - val_loss: 578.4364 - val_salida_clase_accuracy: 0.8963 - val_salidas_continuas_mae: 17.9329 - learning_rate: 5.0000e-04
# Epoch 30/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 512.7213 - salida_clase_accuracy: 0.8834 - salidas_continuas_mae: 16.6297 - val_loss: 576.5165 - val_salida_clase_accuracy: 0.8919 - val_salidas_continuas_mae: 17.8577 - learning_rate: 5.0000e-04
# Epoch 31/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 512.2820 - salida_clase_accuracy: 0.8903 - salidas_continuas_mae: 16.7018 - val_loss: 539.8019 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 16.9728 - learning_rate: 5.0000e-04
# Epoch 32/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 487.1780 - salida_clase_accuracy: 0.8866 - salidas_continuas_mae: 16.3483 - val_loss: 541.0403 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 17.0006 - learning_rate: 5.0000e-04
# Epoch 33/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 500.0580 - salida_clase_accuracy: 0.8765 - salidas_continuas_mae: 16.5197 - val_loss: 549.5264 - val_salida_clase_accuracy: 0.8800 - val_salidas_continuas_mae: 17.4392 - learning_rate: 5.0000e-04
# Epoch 34/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 475.1313 - salida_clase_accuracy: 0.9000 - salidas_continuas_mae: 16.0837 - val_loss: 526.9162 - val_salida_clase_accuracy: 0.8978 - val_salidas_continuas_mae: 16.7949 - learning_rate: 5.0000e-04
# Epoch 35/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 486.0596 - salida_clase_accuracy: 0.8893 - salidas_continuas_mae: 16.0880 - val_loss: 522.1689 - val_salida_clase_accuracy: 0.8904 - val_salidas_continuas_mae: 16.7562 - learning_rate: 5.0000e-04
# Epoch 36/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 477.3238 - salida_clase_accuracy: 0.8949 - salidas_continuas_mae: 15.9470 - val_loss: 511.9291 - val_salida_clase_accuracy: 0.9052 - val_salidas_continuas_mae: 16.4836 - learning_rate: 5.0000e-04
# Epoch 37/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 468.6127 - salida_clase_accuracy: 0.8741 - salidas_continuas_mae: 16.0573 - val_loss: 506.6612 - val_salida_clase_accuracy: 0.8889 - val_salidas_continuas_mae: 16.3916 - learning_rate: 5.0000e-04
# Epoch 38/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 461.4083 - salida_clase_accuracy: 0.8906 - salidas_continuas_mae: 15.9210 - val_loss: 509.0319 - val_salida_clase_accuracy: 0.9037 - val_salidas_continuas_mae: 16.4658 - learning_rate: 5.0000e-04
# Epoch 39/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 454.3658 - salida_clase_accuracy: 0.8734 - salidas_continuas_mae: 15.6976 - val_loss: 513.3940 - val_salida_clase_accuracy: 0.8889 - val_salidas_continuas_mae: 16.7260 - learning_rate: 5.0000e-04
# Epoch 40/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 439.4117 - salida_clase_accuracy: 0.9036 - salidas_continuas_mae: 15.3318 - val_loss: 488.7671 - val_salida_clase_accuracy: 0.8800 - val_salidas_continuas_mae: 16.0200 - learning_rate: 5.0000e-04
# Epoch 41/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 460.6400 - salida_clase_accuracy: 0.8898 - salidas_continuas_mae: 15.6271 - val_loss: 489.0518 - val_salida_clase_accuracy: 0.9037 - val_salidas_continuas_mae: 16.0085 - learning_rate: 5.0000e-04
# Epoch 42/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 446.8680 - salida_clase_accuracy: 0.8855 - salidas_continuas_mae: 15.6099 - val_loss: 497.1349 - val_salida_clase_accuracy: 0.9052 - val_salidas_continuas_mae: 16.2703 - learning_rate: 5.0000e-04
# Epoch 43/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 443.1877 - salida_clase_accuracy: 0.8886 - salidas_continuas_mae: 15.4022 - val_loss: 494.6367 - val_salida_clase_accuracy: 0.8859 - val_salidas_continuas_mae: 16.2567 - learning_rate: 5.0000e-04
# Epoch 44/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 437.3309 - salida_clase_accuracy: 0.8911 - salidas_continuas_mae: 15.4174 - val_loss: 483.0155 - val_salida_clase_accuracy: 0.9037 - val_salidas_continuas_mae: 15.9622 - learning_rate: 5.0000e-04
# Epoch 45/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 441.4117 - salida_clase_accuracy: 0.9005 - salidas_continuas_mae: 15.3476 - val_loss: 478.0671 - val_salida_clase_accuracy: 0.9022 - val_salidas_continuas_mae: 15.9073 - learning_rate: 5.0000e-04
# Epoch 46/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 435.7675 - salida_clase_accuracy: 0.9099 - salidas_continuas_mae: 15.3203 - val_loss: 485.4807 - val_salida_clase_accuracy: 0.9052 - val_salidas_continuas_mae: 16.1808 - learning_rate: 5.0000e-04
# Epoch 47/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 433.6785 - salida_clase_accuracy: 0.9065 - salidas_continuas_mae: 15.2049 - val_loss: 470.4685 - val_salida_clase_accuracy: 0.9111 - val_salidas_continuas_mae: 15.7167 - learning_rate: 5.0000e-04
# Epoch 48/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 421.6404 - salida_clase_accuracy: 0.8835 - salidas_continuas_mae: 15.1332 - val_loss: 461.7817 - val_salida_clase_accuracy: 0.9156 - val_salidas_continuas_mae: 15.4334 - learning_rate: 5.0000e-04
# Epoch 49/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 421.1015 - salida_clase_accuracy: 0.9030 - salidas_continuas_mae: 14.9411 - val_loss: 446.2939 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 14.8976 - learning_rate: 5.0000e-04
# Epoch 50/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 422.9509 - salida_clase_accuracy: 0.8805 - salidas_continuas_mae: 15.0857 - val_loss: 455.8324 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 15.2826 - learning_rate: 5.0000e-04
# Epoch 51/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 431.6522 - salida_clase_accuracy: 0.9060 - salidas_continuas_mae: 15.2006 - val_loss: 440.8475 - val_salida_clase_accuracy: 0.9111 - val_salidas_continuas_mae: 14.6943 - learning_rate: 5.0000e-04
# Epoch 52/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 433.1418 - salida_clase_accuracy: 0.8933 - salidas_continuas_mae: 15.0532 - val_loss: 442.5414 - val_salida_clase_accuracy: 0.8978 - val_salidas_continuas_mae: 14.8176 - learning_rate: 5.0000e-04
# Epoch 53/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 417.4481 - salida_clase_accuracy: 0.8951 - salidas_continuas_mae: 14.6981 - val_loss: 446.2412 - val_salida_clase_accuracy: 0.9200 - val_salidas_continuas_mae: 15.0106 - learning_rate: 5.0000e-04
# Epoch 54/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 405.8296 - salida_clase_accuracy: 0.9020 - salidas_continuas_mae: 14.7710 - val_loss: 466.7273 - val_salida_clase_accuracy: 0.9096 - val_salidas_continuas_mae: 15.7773 - learning_rate: 5.0000e-04
# Epoch 55/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 411.3404 - salida_clase_accuracy: 0.9017 - salidas_continuas_mae: 14.8407 - val_loss: 446.3326 - val_salida_clase_accuracy: 0.8948 - val_salidas_continuas_mae: 15.0369 - learning_rate: 5.0000e-04
# Epoch 56/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 402.7996 - salida_clase_accuracy: 0.9006 - salidas_continuas_mae: 14.6284 - val_loss: 443.4128 - val_salida_clase_accuracy: 0.9141 - val_salidas_continuas_mae: 15.0355 - learning_rate: 5.0000e-04
# Epoch 57/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 396.7754 - salida_clase_accuracy: 0.9081 - salidas_continuas_mae: 14.5143 - val_loss: 437.0410 - val_salida_clase_accuracy: 0.9111 - val_salidas_continuas_mae: 14.7852 - learning_rate: 2.5000e-04
# Epoch 58/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 390.0008 - salida_clase_accuracy: 0.9173 - salidas_continuas_mae: 14.4304 - val_loss: 441.3811 - val_salida_clase_accuracy: 0.9185 - val_salidas_continuas_mae: 14.9817 - learning_rate: 2.5000e-04
# Epoch 59/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 406.4903 - salida_clase_accuracy: 0.9022 - salidas_continuas_mae: 14.6131 - val_loss: 446.8252 - val_salida_clase_accuracy: 0.9126 - val_salidas_continuas_mae: 15.1591 - learning_rate: 2.5000e-04
# Epoch 60/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 400.2204 - salida_clase_accuracy: 0.9173 - salidas_continuas_mae: 14.5674 - val_loss: 446.3087 - val_salida_clase_accuracy: 0.9170 - val_salidas_continuas_mae: 15.1315 - learning_rate: 2.5000e-04
# Epoch 61/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 408.5551 - salida_clase_accuracy: 0.9099 - salidas_continuas_mae: 14.6374 - val_loss: 429.7261 - val_salida_clase_accuracy: 0.9111 - val_salidas_continuas_mae: 14.5409 - learning_rate: 2.5000e-04
# Epoch 62/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 384.4921 - salida_clase_accuracy: 0.9191 - salidas_continuas_mae: 14.3255 - val_loss: 435.4548 - val_salida_clase_accuracy: 0.9126 - val_salidas_continuas_mae: 14.7427 - learning_rate: 2.5000e-04
# Epoch 63/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 404.3885 - salida_clase_accuracy: 0.9135 - salidas_continuas_mae: 14.6975 - val_loss: 430.3160 - val_salida_clase_accuracy: 0.9126 - val_salidas_continuas_mae: 14.5762 - learning_rate: 2.5000e-04
# Epoch 64/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 397.3568 - salida_clase_accuracy: 0.9030 - salidas_continuas_mae: 14.5827 - val_loss: 426.1222 - val_salida_clase_accuracy: 0.9170 - val_salidas_continuas_mae: 14.3373 - learning_rate: 2.5000e-04
# Epoch 65/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 401.8362 - salida_clase_accuracy: 0.9208 - salidas_continuas_mae: 14.6090 - val_loss: 442.0968 - val_salida_clase_accuracy: 0.9007 - val_salidas_continuas_mae: 15.0962 - learning_rate: 2.5000e-04
# Epoch 66/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 401.2778 - salida_clase_accuracy: 0.9043 - salidas_continuas_mae: 14.4700 - val_loss: 434.7365 - val_salida_clase_accuracy: 0.9156 - val_salidas_continuas_mae: 14.7999 - learning_rate: 2.5000e-04
# Epoch 67/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 399.7288 - salida_clase_accuracy: 0.9115 - salidas_continuas_mae: 14.5433 - val_loss: 434.3656 - val_salida_clase_accuracy: 0.9170 - val_salidas_continuas_mae: 14.8297 - learning_rate: 2.5000e-04
# Epoch 68/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 413.5128 - salida_clase_accuracy: 0.9130 - salidas_continuas_mae: 14.6866 - val_loss: 423.3072 - val_salida_clase_accuracy: 0.9289 - val_salidas_continuas_mae: 14.4105 - learning_rate: 2.5000e-04
# Epoch 69/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 399.5054 - salida_clase_accuracy: 0.9102 - salidas_continuas_mae: 14.5957 - val_loss: 429.4256 - val_salida_clase_accuracy: 0.9244 - val_salidas_continuas_mae: 14.6286 - learning_rate: 2.5000e-04
# Epoch 70/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 392.8987 - salida_clase_accuracy: 0.9158 - salidas_continuas_mae: 14.3213 - val_loss: 420.1718 - val_salida_clase_accuracy: 0.9067 - val_salidas_continuas_mae: 14.3557 - learning_rate: 2.5000e-04
# Epoch 71/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 380.7727 - salida_clase_accuracy: 0.9119 - salidas_continuas_mae: 14.2848 - val_loss: 426.4781 - val_salida_clase_accuracy: 0.9215 - val_salidas_continuas_mae: 14.5575 - learning_rate: 2.5000e-04
# Epoch 72/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 403.3481 - salida_clase_accuracy: 0.9222 - salidas_continuas_mae: 14.4959 - val_loss: 420.0970 - val_salida_clase_accuracy: 0.9185 - val_salidas_continuas_mae: 14.3664 - learning_rate: 2.5000e-04
# Epoch 73/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 387.5414 - salida_clase_accuracy: 0.9125 - salidas_continuas_mae: 14.3228 - val_loss: 424.1127 - val_salida_clase_accuracy: 0.9230 - val_salidas_continuas_mae: 14.4667 - learning_rate: 2.5000e-04
# Epoch 74/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 384.8245 - salida_clase_accuracy: 0.9282 - salidas_continuas_mae: 14.2386 - val_loss: 421.2422 - val_salida_clase_accuracy: 0.9215 - val_salidas_continuas_mae: 14.3593 - learning_rate: 2.5000e-04
# Epoch 75/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 382.9001 - salida_clase_accuracy: 0.9238 - salidas_continuas_mae: 14.1756 - val_loss: 419.9933 - val_salida_clase_accuracy: 0.9185 - val_salidas_continuas_mae: 14.3703 - learning_rate: 2.5000e-04
# Epoch 76/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 378.2926 - salida_clase_accuracy: 0.9167 - salidas_continuas_mae: 14.0592 - val_loss: 416.9134 - val_salida_clase_accuracy: 0.9259 - val_salidas_continuas_mae: 14.2895 - learning_rate: 2.5000e-04
# Epoch 77/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 396.4120 - salida_clase_accuracy: 0.9144 - salidas_continuas_mae: 14.4445 - val_loss: 425.0775 - val_salida_clase_accuracy: 0.9126 - val_salidas_continuas_mae: 14.5625 - learning_rate: 2.5000e-04
# Epoch 78/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 379.3982 - salida_clase_accuracy: 0.9201 - salidas_continuas_mae: 14.0835 - val_loss: 421.3554 - val_salida_clase_accuracy: 0.9141 - val_salidas_continuas_mae: 14.4844 - learning_rate: 2.5000e-04
# Epoch 79/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 392.1258 - salida_clase_accuracy: 0.9216 - salidas_continuas_mae: 14.3074 - val_loss: 419.2524 - val_salida_clase_accuracy: 0.9185 - val_salidas_continuas_mae: 14.4600 - learning_rate: 2.5000e-04
# Epoch 80/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 374.0490 - salida_clase_accuracy: 0.9167 - salidas_continuas_mae: 14.0053 - val_loss: 416.3221 - val_salida_clase_accuracy: 0.9141 - val_salidas_continuas_mae: 14.3585 - learning_rate: 2.5000e-04
# Epoch 81/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 375.1984 - salida_clase_accuracy: 0.9268 - salidas_continuas_mae: 13.9484 - val_loss: 412.5397 - val_salida_clase_accuracy: 0.9170 - val_salidas_continuas_mae: 14.0929 - learning_rate: 2.5000e-04
# Epoch 82/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 375.0392 - salida_clase_accuracy: 0.9222 - salidas_continuas_mae: 14.1272 - val_loss: 415.0934 - val_salida_clase_accuracy: 0.9081 - val_salidas_continuas_mae: 14.2713 - learning_rate: 2.5000e-04
# Epoch 83/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 369.2624 - salida_clase_accuracy: 0.9222 - salidas_continuas_mae: 13.9769 - val_loss: 416.0534 - val_salida_clase_accuracy: 0.9185 - val_salidas_continuas_mae: 14.3562 - learning_rate: 2.5000e-04
# Epoch 84/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 371.4830 - salida_clase_accuracy: 0.9229 - salidas_continuas_mae: 13.9445 - val_loss: 415.5870 - val_salida_clase_accuracy: 0.9200 - val_salidas_continuas_mae: 14.3306 - learning_rate: 2.5000e-04
# Epoch 85/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 367.8845 - salida_clase_accuracy: 0.9297 - salidas_continuas_mae: 13.8470 - val_loss: 410.9277 - val_salida_clase_accuracy: 0.9244 - val_salidas_continuas_mae: 14.0988 - learning_rate: 2.5000e-04
# Epoch 86/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 389.6601 - salida_clase_accuracy: 0.9177 - salidas_continuas_mae: 14.3138 - val_loss: 411.6698 - val_salida_clase_accuracy: 0.9185 - val_salidas_continuas_mae: 14.1422 - learning_rate: 2.5000e-04
# Epoch 87/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 403.8268 - salida_clase_accuracy: 0.9126 - salidas_continuas_mae: 14.5191 - val_loss: 417.3770 - val_salida_clase_accuracy: 0.9215 - val_salidas_continuas_mae: 14.3116 - learning_rate: 2.5000e-04
# Epoch 88/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 388.2317 - salida_clase_accuracy: 0.9255 - salidas_continuas_mae: 14.2873 - val_loss: 413.1407 - val_salida_clase_accuracy: 0.9156 - val_salidas_continuas_mae: 14.2565 - learning_rate: 2.5000e-04
# Epoch 89/150
# ...
# Epoch 22/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 588.1716 - salida_clase_accuracy: 0.8695 - salidas_continuas_mae: 18.2554 - val_loss: 625.4756 - val_salida_clase_accuracy: 0.8770 - val_salidas_continuas_mae: 19.1274 - learning_rate: 5.0000e-04
# Epoch 23/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 572.2087 - salida_clase_accuracy: 0.8634 - salidas_continuas_mae: 18.1355 - val_loss: 577.1566 - val_salida_clase_accuracy: 0.8726 - val_salidas_continuas_mae: 18.0098 - learning_rate: 5.0000e-04
# Epoch 24/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 581.4608 - salida_clase_accuracy: 0.8845 - salidas_continuas_mae: 17.9016 - val_loss: 572.9423 - val_salida_clase_accuracy: 0.8815 - val_salidas_continuas_mae: 17.9239 - learning_rate: 5.0000e-04
# Epoch 25/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 553.1071 - salida_clase_accuracy: 0.8744 - salidas_continuas_mae: 17.5661 - val_loss: 563.2565 - val_salida_clase_accuracy: 0.8874 - val_salidas_continuas_mae: 17.7228 - learning_rate: 5.0000e-04
# Epoch 26/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 559.1047 - salida_clase_accuracy: 0.8831 - salidas_continuas_mae: 17.6411 - val_loss: 577.2269 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 18.0811 - learning_rate: 5.0000e-04
# Epoch 27/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 545.5915 - salida_clase_accuracy: 0.8601 - salidas_continuas_mae: 17.4681 - val_loss: 529.3881 - val_salida_clase_accuracy: 0.8948 - val_salidas_continuas_mae: 16.9499 - learning_rate: 5.0000e-04
# Epoch 28/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 536.1946 - salida_clase_accuracy: 0.8657 - salidas_continuas_mae: 17.2280 - val_loss: 528.3239 - val_salida_clase_accuracy: 0.8919 - val_salidas_continuas_mae: 16.9562 - learning_rate: 5.0000e-04
# Epoch 29/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 543.2501 - salida_clase_accuracy: 0.8684 - salidas_continuas_mae: 17.2286 - val_loss: 534.9968 - val_salida_clase_accuracy: 0.8978 - val_salidas_continuas_mae: 17.1684 - learning_rate: 5.0000e-04
# Epoch 30/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 536.9262 - salida_clase_accuracy: 0.8823 - salidas_continuas_mae: 17.0829 - val_loss: 522.7429 - val_salida_clase_accuracy: 0.9022 - val_salidas_continuas_mae: 16.8178 - learning_rate: 5.0000e-04
# Epoch 31/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 532.2496 - salida_clase_accuracy: 0.8744 - salidas_continuas_mae: 17.1311 - val_loss: 495.2666 - val_salida_clase_accuracy: 0.8889 - val_salidas_continuas_mae: 16.1468 - learning_rate: 5.0000e-04
# Epoch 32/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 516.5427 - salida_clase_accuracy: 0.8772 - salidas_continuas_mae: 16.8104 - val_loss: 492.4446 - val_salida_clase_accuracy: 0.9037 - val_salidas_continuas_mae: 16.1035 - learning_rate: 5.0000e-04
# Epoch 33/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 503.7993 - salida_clase_accuracy: 0.8666 - salidas_continuas_mae: 16.6042 - val_loss: 512.4153 - val_salida_clase_accuracy: 0.8963 - val_salidas_continuas_mae: 16.6686 - learning_rate: 5.0000e-04
# Epoch 34/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 520.0461 - salida_clase_accuracy: 0.8951 - salidas_continuas_mae: 16.7168 - val_loss: 492.3467 - val_salida_clase_accuracy: 0.9126 - val_salidas_continuas_mae: 16.1785 - learning_rate: 5.0000e-04
# Epoch 35/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 497.5919 - salida_clase_accuracy: 0.8996 - salidas_continuas_mae: 16.4603 - val_loss: 496.4903 - val_salida_clase_accuracy: 0.9022 - val_salidas_continuas_mae: 16.3481 - learning_rate: 5.0000e-04
# Epoch 36/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 500.8249 - salida_clase_accuracy: 0.8948 - salidas_continuas_mae: 16.3963 - val_loss: 496.6669 - val_salida_clase_accuracy: 0.9052 - val_salidas_continuas_mae: 16.3630 - learning_rate: 5.0000e-04
# Epoch 37/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 484.1865 - salida_clase_accuracy: 0.9007 - salidas_continuas_mae: 16.1387 - val_loss: 467.8995 - val_salida_clase_accuracy: 0.9067 - val_salidas_continuas_mae: 15.5871 - learning_rate: 5.0000e-04
# Epoch 38/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 472.8745 - salida_clase_accuracy: 0.8986 - salidas_continuas_mae: 15.9534 - val_loss: 479.7554 - val_salida_clase_accuracy: 0.8978 - val_salidas_continuas_mae: 16.0022 - learning_rate: 5.0000e-04
# Epoch 39/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 473.3930 - salida_clase_accuracy: 0.8863 - salidas_continuas_mae: 15.9401 - val_loss: 467.3070 - val_salida_clase_accuracy: 0.8963 - val_salidas_continuas_mae: 15.6515 - learning_rate: 5.0000e-04
# Epoch 40/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 470.8733 - salida_clase_accuracy: 0.8791 - salidas_continuas_mae: 15.8802 - val_loss: 461.5847 - val_salida_clase_accuracy: 0.9007 - val_salidas_continuas_mae: 15.5168 - learning_rate: 5.0000e-04
# Epoch 41/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 463.4749 - salida_clase_accuracy: 0.8900 - salidas_continuas_mae: 15.8313 - val_loss: 454.9476 - val_salida_clase_accuracy: 0.8963 - val_salidas_continuas_mae: 15.2945 - learning_rate: 5.0000e-04
# Epoch 42/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 486.4747 - salida_clase_accuracy: 0.8876 - salidas_continuas_mae: 16.1737 - val_loss: 445.5276 - val_salida_clase_accuracy: 0.8933 - val_salidas_continuas_mae: 15.0665 - learning_rate: 5.0000e-04
# Epoch 43/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 467.4174 - salida_clase_accuracy: 0.8928 - salidas_continuas_mae: 15.9273 - val_loss: 469.8170 - val_salida_clase_accuracy: 0.8815 - val_salidas_continuas_mae: 15.8222 - learning_rate: 5.0000e-04
# Epoch 44/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 445.7687 - salida_clase_accuracy: 0.8847 - salidas_continuas_mae: 15.4865 - val_loss: 461.8325 - val_salida_clase_accuracy: 0.9067 - val_salidas_continuas_mae: 15.6763 - learning_rate: 5.0000e-04
# Epoch 45/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 443.1967 - salida_clase_accuracy: 0.9038 - salidas_continuas_mae: 15.4571 - val_loss: 437.9021 - val_salida_clase_accuracy: 0.8830 - val_salidas_continuas_mae: 14.9911 - learning_rate: 5.0000e-04
# Epoch 46/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 457.7663 - salida_clase_accuracy: 0.8839 - salidas_continuas_mae: 15.4646 - val_loss: 429.8246 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 14.7767 - learning_rate: 5.0000e-04
# Epoch 47/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 439.1566 - salida_clase_accuracy: 0.9003 - salidas_continuas_mae: 15.3461 - val_loss: 446.1380 - val_salida_clase_accuracy: 0.8859 - val_salidas_continuas_mae: 15.2972 - learning_rate: 5.0000e-04
# Epoch 48/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 432.8726 - salida_clase_accuracy: 0.8975 - salidas_continuas_mae: 15.2927 - val_loss: 430.7447 - val_salida_clase_accuracy: 0.9067 - val_salidas_continuas_mae: 14.8267 - learning_rate: 5.0000e-04
# Epoch 49/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 435.4923 - salida_clase_accuracy: 0.8942 - salidas_continuas_mae: 15.2593 - val_loss: 437.6113 - val_salida_clase_accuracy: 0.9067 - val_salidas_continuas_mae: 15.0651 - learning_rate: 5.0000e-04
# Epoch 50/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 436.8242 - salida_clase_accuracy: 0.8930 - salidas_continuas_mae: 15.1292 - val_loss: 452.0532 - val_salida_clase_accuracy: 0.9141 - val_salidas_continuas_mae: 15.5129 - learning_rate: 5.0000e-04
# Epoch 51/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 447.4177 - salida_clase_accuracy: 0.8911 - salidas_continuas_mae: 15.4116 - val_loss: 420.3913 - val_salida_clase_accuracy: 0.9126 - val_salidas_continuas_mae: 14.5593 - learning_rate: 5.0000e-04
# Epoch 52/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 431.1134 - salida_clase_accuracy: 0.8951 - salidas_continuas_mae: 15.1268 - val_loss: 421.0501 - val_salida_clase_accuracy: 0.8978 - val_salidas_continuas_mae: 14.6344 - learning_rate: 5.0000e-04
# Epoch 53/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 427.8774 - salida_clase_accuracy: 0.8806 - salidas_continuas_mae: 15.1275 - val_loss: 418.7919 - val_salida_clase_accuracy: 0.8948 - val_salidas_continuas_mae: 14.5181 - learning_rate: 5.0000e-04
# Epoch 54/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 438.8593 - salida_clase_accuracy: 0.9084 - salidas_continuas_mae: 15.1212 - val_loss: 410.4055 - val_salida_clase_accuracy: 0.9081 - val_salidas_continuas_mae: 14.2815 - learning_rate: 5.0000e-04
# Epoch 55/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 421.0994 - salida_clase_accuracy: 0.9001 - salidas_continuas_mae: 14.8795 - val_loss: 406.9518 - val_salida_clase_accuracy: 0.8963 - val_salidas_continuas_mae: 14.2481 - learning_rate: 5.0000e-04
# Epoch 56/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 425.1625 - salida_clase_accuracy: 0.9085 - salidas_continuas_mae: 15.0121 - val_loss: 412.8441 - val_salida_clase_accuracy: 0.9037 - val_salidas_continuas_mae: 14.3380 - learning_rate: 5.0000e-04
# Epoch 57/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 424.4209 - salida_clase_accuracy: 0.8871 - salidas_continuas_mae: 14.7636 - val_loss: 402.0251 - val_salida_clase_accuracy: 0.9052 - val_salidas_continuas_mae: 14.0116 - learning_rate: 5.0000e-04
# Epoch 58/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 407.3881 - salida_clase_accuracy: 0.9039 - salidas_continuas_mae: 14.6199 - val_loss: 419.8003 - val_salida_clase_accuracy: 0.9022 - val_salidas_continuas_mae: 14.6194 - learning_rate: 5.0000e-04
# Epoch 59/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 410.7085 - salida_clase_accuracy: 0.8926 - salidas_continuas_mae: 14.7142 - val_loss: 404.7944 - val_salida_clase_accuracy: 0.8889 - val_salidas_continuas_mae: 14.2406 - learning_rate: 5.0000e-04
# Epoch 60/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 412.1418 - salida_clase_accuracy: 0.9068 - salidas_continuas_mae: 14.7562 - val_loss: 393.6855 - val_salida_clase_accuracy: 0.8919 - val_salidas_continuas_mae: 13.8384 - learning_rate: 5.0000e-04
# Epoch 61/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 428.5141 - salida_clase_accuracy: 0.9011 - salidas_continuas_mae: 15.0384 - val_loss: 423.3211 - val_salida_clase_accuracy: 0.9081 - val_salidas_continuas_mae: 14.8709 - learning_rate: 5.0000e-04
# Epoch 62/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 411.6606 - salida_clase_accuracy: 0.9099 - salidas_continuas_mae: 14.7745 - val_loss: 404.5774 - val_salida_clase_accuracy: 0.8948 - val_salidas_continuas_mae: 14.2187 - learning_rate: 5.0000e-04
# Epoch 63/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 414.5275 - salida_clase_accuracy: 0.8964 - salidas_continuas_mae: 14.7386 - val_loss: 394.0441 - val_salida_clase_accuracy: 0.9052 - val_salidas_continuas_mae: 13.9809 - learning_rate: 5.0000e-04
# Epoch 64/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 406.5431 - salida_clase_accuracy: 0.9026 - salidas_continuas_mae: 14.6643 - val_loss: 405.5201 - val_salida_clase_accuracy: 0.9126 - val_salidas_continuas_mae: 14.3569 - learning_rate: 5.0000e-04
# Epoch 65/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 410.8805 - salida_clase_accuracy: 0.9132 - salidas_continuas_mae: 14.6714 - val_loss: 387.3060 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 13.7151 - learning_rate: 5.0000e-04
# Epoch 66/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 380.4230 - salida_clase_accuracy: 0.9064 - salidas_continuas_mae: 14.2798 - val_loss: 419.7159 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 14.8623 - learning_rate: 5.0000e-04
# Epoch 67/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 383.6080 - salida_clase_accuracy: 0.9029 - salidas_continuas_mae: 14.2670 - val_loss: 404.2585 - val_salida_clase_accuracy: 0.9037 - val_salidas_continuas_mae: 14.2701 - learning_rate: 5.0000e-04
# Epoch 68/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 410.9582 - salida_clase_accuracy: 0.9001 - salidas_continuas_mae: 14.7186 - val_loss: 387.8337 - val_salida_clase_accuracy: 0.9126 - val_salidas_continuas_mae: 13.8329 - learning_rate: 5.0000e-04
# Epoch 69/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 400.9780 - salida_clase_accuracy: 0.9061 - salidas_continuas_mae: 14.4680 - val_loss: 383.2314 - val_salida_clase_accuracy: 0.9200 - val_salidas_continuas_mae: 13.7349 - learning_rate: 5.0000e-04
# Epoch 70/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 395.2181 - salida_clase_accuracy: 0.9198 - salidas_continuas_mae: 14.3975 - val_loss: 386.4285 - val_salida_clase_accuracy: 0.9185 - val_salidas_continuas_mae: 13.7696 - learning_rate: 5.0000e-04
# Epoch 71/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 395.0373 - salida_clase_accuracy: 0.9063 - salidas_continuas_mae: 14.4373 - val_loss: 389.0706 - val_salida_clase_accuracy: 0.9111 - val_salidas_continuas_mae: 13.9591 - learning_rate: 5.0000e-04
# Epoch 72/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 393.7751 - salida_clase_accuracy: 0.9187 - salidas_continuas_mae: 14.3718 - val_loss: 368.0907 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 13.2583 - learning_rate: 5.0000e-04
# Epoch 73/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 396.8770 - salida_clase_accuracy: 0.9152 - salidas_continuas_mae: 14.4811 - val_loss: 380.1091 - val_salida_clase_accuracy: 0.9170 - val_salidas_continuas_mae: 13.6642 - learning_rate: 5.0000e-04
# Epoch 74/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 389.8462 - salida_clase_accuracy: 0.9176 - salidas_continuas_mae: 14.2818 - val_loss: 370.9146 - val_salida_clase_accuracy: 0.9141 - val_salidas_continuas_mae: 13.2597 - learning_rate: 5.0000e-04
# Epoch 75/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 394.9811 - salida_clase_accuracy: 0.9001 - salidas_continuas_mae: 14.3727 - val_loss: 369.4184 - val_salida_clase_accuracy: 0.9244 - val_salidas_continuas_mae: 13.3424 - learning_rate: 5.0000e-04
# Epoch 76/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 370.8281 - salida_clase_accuracy: 0.9131 - salidas_continuas_mae: 14.0526 - val_loss: 378.2691 - val_salida_clase_accuracy: 0.9170 - val_salidas_continuas_mae: 13.6239 - learning_rate: 5.0000e-04
# Epoch 77/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 389.7506 - salida_clase_accuracy: 0.9144 - salidas_continuas_mae: 14.2877 - val_loss: 372.5815 - val_salida_clase_accuracy: 0.9067 - val_salidas_continuas_mae: 13.4194 - learning_rate: 5.0000e-04
# Epoch 78/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 406.6371 - salida_clase_accuracy: 0.9202 - salidas_continuas_mae: 14.3834 - val_loss: 385.0403 - val_salida_clase_accuracy: 0.9170 - val_salidas_continuas_mae: 13.9558 - learning_rate: 2.5000e-04
# Epoch 79/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 395.4529 - salida_clase_accuracy: 0.9148 - salidas_continuas_mae: 14.4381 - val_loss: 375.8002 - val_salida_clase_accuracy: 0.9126 - val_salidas_continuas_mae: 13.5656 - learning_rate: 2.5000e-04
# Epoch 80/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 375.3165 - salida_clase_accuracy: 0.9179 - salidas_continuas_mae: 14.1641 - val_loss: 380.9279 - val_salida_clase_accuracy: 0.9170 - val_salidas_continuas_mae: 13.7468 - learning_rate: 2.5000e-04
# Epoch 81/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 385.0548 - salida_clase_accuracy: 0.9267 - salidas_continuas_mae: 14.2966 - val_loss: 380.9724 - val_salida_clase_accuracy: 0.9141 - val_salidas_continuas_mae: 13.7429 - learning_rate: 2.5000e-04
# Epoch 82/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 397.1990 - salida_clase_accuracy: 0.9178 - salidas_continuas_mae: 14.4596 - val_loss: 375.4968 - val_salida_clase_accuracy: 0.9126 - val_salidas_continuas_mae: 13.5966 - learning_rate: 2.5000e-04
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 355.8386 - salida_clase_accuracy: 0.9074 - salidas_continuas_mae: 13.2411
# Fold 5: Loss=359.03680419921875, MAE=13.124944686889648, Accuracy=0.9112426042556763
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 364.88128051757815
# MAE: 13.354687539739928
# MSE: 364.4389982635572
# RMSE: 19.0885078448456
# R^2: 0.8397702998078727
# Accuracy: 0.9287574052810669
# Precisión: 0.9297271442497175
# Recall: 0.928757396449704
# F1-Score: 0.928735209800976
