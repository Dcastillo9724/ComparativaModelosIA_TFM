# %%
import joblib
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Cargar datos
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Videos_Pose', 'pose_data.csv')
ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual, 'datos', 'scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')

data = pd.read_csv(ruta_csv)

# Preparar datos
num_keypoints = 33 * 3
X = data.iloc[:, :num_keypoints].values
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

X_train, X_test, y_continuas_train, y_continuas_test, y_clase_train, y_clase_test = train_test_split(
    X, y_continuas, y_clase_encoded, test_size=0.2, random_state=42)

scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

X_train_cnn = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_cnn = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

# Función para crear el modelo con ajustes de hiperparámetros
def create_model(learning_rate=0.001):
    input_layer = Input(shape=(X_train_cnn.shape[1], X_train_cnn.shape[2]))
    x = Conv1D(64, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(input_layer)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Conv1D(64, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Conv1D(32, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Flatten()(x)
    
    salidas_continuas = Dense(10, activation='linear', name='salidas_continuas')(x)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)
    
    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])
    
    optimizer = Adam(learning_rate=learning_rate)
    
    model.compile(optimizer=optimizer,
                  loss={'salidas_continuas': 'mean_squared_error', 'salida_clase': 'sparse_categorical_crossentropy'},
                  metrics={'salidas_continuas': 'mae', 'salida_clase': 'accuracy'})
    
    return model

# Listas para almacenar métricas
all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

# Matrices para almacenar la historia del entrenamiento
n_epochs = 50  # Número de épocas
all_train_loss = np.full((5, n_epochs), np.nan)  
all_val_loss = np.full((5, n_epochs), np.nan)
all_train_accuracy = np.full((5, n_epochs), np.nan)
all_val_accuracy = np.full((5, n_epochs), np.nan)

# Optimización de hiperparámetros y validación cruzada
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

fold_index = 0
for train_index, val_index in kfold.split(X_train_cnn):
    fold_index += 1
    print(f"Entrenando fold {fold_index}...")

    X_train_fold, X_val_fold = X_train_cnn[train_index], X_train_cnn[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas_train[train_index], y_continuas_train[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_train[train_index], y_clase_train[val_index]

    model = create_model(learning_rate=0.0005)  # Ajustar la tasa de aprendizaje aquí
    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold_index}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    # Almacenar la historia del entrenamiento como matrices NumPy
    epochs_completed = len(history.history['loss'])
    all_train_loss[fold_index - 1, :epochs_completed] = history.history['loss']
    all_val_loss[fold_index - 1, :epochs_completed] = history.history['val_loss']
    all_train_accuracy[fold_index - 1, :epochs_completed] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold_index - 1, :epochs_completed] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de prueba
    scores = model.evaluate(X_test_cnn, {'salidas_continuas': y_continuas_test, 'salida_clase': y_clase_test})
    print(f"Fold {fold_index}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_test_cnn)[0]
    mae = mean_absolute_error(y_continuas_test, y_pred_continuas)
    mse = mean_squared_error(y_continuas_test, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_test)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_test_cnn)[1], axis=1)
    precision = precision_score(y_clase_test, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_test, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_test, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_test, y_pred_clase, labels=np.unique(y_clase_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - loss: 2855.1028 - salida_clase_accuracy: 0.7662 - salidas_continuas_mae: 32.2756 - val_loss: 406.4236 - val_salida_clase_accuracy: 0.9675 - val_salidas_continuas_mae: 12.4395 - learning_rate: 5.0000e-04
# Epoch 2/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - loss: 347.4102 - salida_clase_accuracy: 0.9505 - salidas_continuas_mae: 11.2225 - val_loss: 262.8070 - val_salida_clase_accuracy: 0.9666 - val_salidas_continuas_mae: 9.6675 - learning_rate: 5.0000e-04
# Epoch 3/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - loss: 251.5920 - salida_clase_accuracy: 0.9626 - salidas_continuas_mae: 9.2393 - val_loss: 212.1435 - val_salida_clase_accuracy: 0.9844 - val_salidas_continuas_mae: 8.4043 - learning_rate: 5.0000e-04
# Epoch 4/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - loss: 209.6210 - salida_clase_accuracy: 0.9732 - salidas_continuas_mae: 8.2918 - val_loss: 166.7932 - val_salida_clase_accuracy: 0.9844 - val_salidas_continuas_mae: 7.2673 - learning_rate: 5.0000e-04
# Epoch 5/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 187.4702 - salida_clase_accuracy: 0.9746 - salidas_continuas_mae: 7.7889 - val_loss: 151.3996 - val_salida_clase_accuracy: 0.9922 - val_salidas_continuas_mae: 6.8732 - learning_rate: 5.0000e-04
# Epoch 6/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - loss: 167.3490 - salida_clase_accuracy: 0.9787 - salidas_continuas_mae: 7.3443 - val_loss: 144.6457 - val_salida_clase_accuracy: 0.9878 - val_salidas_continuas_mae: 6.8125 - learning_rate: 5.0000e-04
# Epoch 7/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - loss: 156.7916 - salida_clase_accuracy: 0.9804 - salidas_continuas_mae: 7.1082 - val_loss: 124.9362 - val_salida_clase_accuracy: 0.9924 - val_salidas_continuas_mae: 6.1619 - learning_rate: 5.0000e-04
# Epoch 8/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - loss: 152.3213 - salida_clase_accuracy: 0.9844 - salidas_continuas_mae: 7.0002 - val_loss: 118.9784 - val_salida_clase_accuracy: 0.9927 - val_salidas_continuas_mae: 6.0058 - learning_rate: 5.0000e-04
# Epoch 9/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - loss: 147.1965 - salida_clase_accuracy: 0.9858 - salidas_continuas_mae: 6.8724 - val_loss: 123.4806 - val_salida_clase_accuracy: 0.9960 - val_salidas_continuas_mae: 6.3269 - learning_rate: 5.0000e-04
# Epoch 10/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 138.7192 - salida_clase_accuracy: 0.9872 - salidas_continuas_mae: 6.6803 - val_loss: 112.0641 - val_salida_clase_accuracy: 0.9941 - val_salidas_continuas_mae: 5.8736 - learning_rate: 5.0000e-04
# Epoch 11/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 136.3262 - salida_clase_accuracy: 0.9868 - salidas_continuas_mae: 6.6312 - val_loss: 102.1195 - val_salida_clase_accuracy: 0.9930 - val_salidas_continuas_mae: 5.4972 - learning_rate: 5.0000e-04
# Epoch 12/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - loss: 132.7682 - salida_clase_accuracy: 0.9873 - salidas_continuas_mae: 6.5559 - val_loss: 99.6180 - val_salida_clase_accuracy: 0.9951 - val_salidas_continuas_mae: 5.4896 - learning_rate: 5.0000e-04
# Epoch 13/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - loss: 130.4326 - salida_clase_accuracy: 0.9873 - salidas_continuas_mae: 6.4947 - val_loss: 93.5576 - val_salida_clase_accuracy: 0.9943 - val_salidas_continuas_mae: 5.2029 - learning_rate: 5.0000e-04
# Epoch 14/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - loss: 129.8951 - salida_clase_accuracy: 0.9881 - salidas_continuas_mae: 6.4787 - val_loss: 96.8874 - val_salida_clase_accuracy: 0.9967 - val_salidas_continuas_mae: 5.3979 - learning_rate: 5.0000e-04
# Epoch 15/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 127.1677 - salida_clase_accuracy: 0.9907 - salidas_continuas_mae: 6.4043 - val_loss: 89.7694 - val_salida_clase_accuracy: 0.9936 - val_salidas_continuas_mae: 5.1336 - learning_rate: 5.0000e-04
# Epoch 16/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - loss: 124.1120 - salida_clase_accuracy: 0.9904 - salidas_continuas_mae: 6.3561 - val_loss: 96.4548 - val_salida_clase_accuracy: 0.9950 - val_salidas_continuas_mae: 5.3881 - learning_rate: 5.0000e-04
# Epoch 17/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - loss: 124.2230 - salida_clase_accuracy: 0.9918 - salidas_continuas_mae: 6.3371 - val_loss: 88.3410 - val_salida_clase_accuracy: 0.9970 - val_salidas_continuas_mae: 5.0755 - learning_rate: 5.0000e-04
# Epoch 18/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - loss: 122.0648 - salida_clase_accuracy: 0.9900 - salidas_continuas_mae: 6.2956 - val_loss: 83.3745 - val_salida_clase_accuracy: 0.9965 - val_salidas_continuas_mae: 4.8970 - learning_rate: 5.0000e-04
# Epoch 19/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 119.3515 - salida_clase_accuracy: 0.9893 - salidas_continuas_mae: 6.2531 - val_loss: 90.5103 - val_salida_clase_accuracy: 0.9976 - val_salidas_continuas_mae: 5.2711 - learning_rate: 5.0000e-04
# Epoch 20/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - loss: 119.4658 - salida_clase_accuracy: 0.9919 - salidas_continuas_mae: 6.2505 - val_loss: 87.8913 - val_salida_clase_accuracy: 0.9970 - val_salidas_continuas_mae: 5.1860 - learning_rate: 5.0000e-04
# Epoch 21/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - loss: 118.1332 - salida_clase_accuracy: 0.9922 - salidas_continuas_mae: 6.2008 - val_loss: 98.3993 - val_salida_clase_accuracy: 0.9960 - val_salidas_continuas_mae: 5.6501 - learning_rate: 5.0000e-04
# Epoch 22/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 116.9608 - salida_clase_accuracy: 0.9899 - salidas_continuas_mae: 6.1824 - val_loss: 85.5730 - val_salida_clase_accuracy: 0.9983 - val_salidas_continuas_mae: 5.1134 - learning_rate: 5.0000e-04
# Epoch 23/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - loss: 114.4394 - salida_clase_accuracy: 0.9936 - salidas_continuas_mae: 6.1250 - val_loss: 94.2782 - val_salida_clase_accuracy: 0.9964 - val_salidas_continuas_mae: 5.5710 - learning_rate: 5.0000e-04
# Epoch 24/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - loss: 115.0783 - salida_clase_accuracy: 0.9920 - salidas_continuas_mae: 6.1146 - val_loss: 84.3153 - val_salida_clase_accuracy: 0.9979 - val_salidas_continuas_mae: 5.0679 - learning_rate: 2.5000e-04
# Epoch 25/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 112.5109 - salida_clase_accuracy: 0.9942 - salidas_continuas_mae: 6.0465 - val_loss: 85.6838 - val_salida_clase_accuracy: 0.9979 - val_salidas_continuas_mae: 5.1727 - learning_rate: 2.5000e-04
# Epoch 26/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - loss: 111.8467 - salida_clase_accuracy: 0.9944 - salidas_continuas_mae: 6.0428 - val_loss: 84.3038 - val_salida_clase_accuracy: 0.9979 - val_salidas_continuas_mae: 5.0942 - learning_rate: 2.5000e-04
# Epoch 27/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - loss: 110.8403 - salida_clase_accuracy: 0.9946 - salidas_continuas_mae: 6.0053 - val_loss: 85.0609 - val_salida_clase_accuracy: 0.9981 - val_salidas_continuas_mae: 5.1391 - learning_rate: 2.5000e-04
# Epoch 28/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 111.4612 - salida_clase_accuracy: 0.9942 - salidas_continuas_mae: 6.0344 - val_loss: 82.9963 - val_salida_clase_accuracy: 0.9974 - val_salidas_continuas_mae: 5.0398 - learning_rate: 2.5000e-04
# Epoch 29/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - loss: 110.5076 - salida_clase_accuracy: 0.9934 - salidas_continuas_mae: 6.0174 - val_loss: 85.9598 - val_salida_clase_accuracy: 0.9984 - val_salidas_continuas_mae: 5.2192 - learning_rate: 2.5000e-04
# Epoch 30/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 112.1919 - salida_clase_accuracy: 0.9954 - salidas_continuas_mae: 6.0443 - val_loss: 80.7829 - val_salida_clase_accuracy: 0.9977 - val_salidas_continuas_mae: 4.9556 - learning_rate: 2.5000e-04
# Epoch 31/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 19s 26ms/step - loss: 108.8344 - salida_clase_accuracy: 0.9932 - salidas_continuas_mae: 5.9749 - val_loss: 82.5463 - val_salida_clase_accuracy: 0.9977 - val_salidas_continuas_mae: 5.0502 - learning_rate: 2.5000e-04
# Epoch 32/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - loss: 109.4761 - salida_clase_accuracy: 0.9955 - salidas_continuas_mae: 5.9739 - val_loss: 78.1840 - val_salida_clase_accuracy: 0.9986 - val_salidas_continuas_mae: 4.8373 - learning_rate: 2.5000e-04
# Epoch 33/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - loss: 110.5995 - salida_clase_accuracy: 0.9958 - salidas_continuas_mae: 5.9943 - val_loss: 80.2521 - val_salida_clase_accuracy: 0.9984 - val_salidas_continuas_mae: 4.9406 - learning_rate: 2.5000e-04
# Epoch 34/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 109.0742 - salida_clase_accuracy: 0.9949 - salidas_continuas_mae: 5.9769 - val_loss: 86.8502 - val_salida_clase_accuracy: 0.9976 - val_salidas_continuas_mae: 5.2845 - learning_rate: 2.5000e-04
# Epoch 35/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 108.7199 - salida_clase_accuracy: 0.9948 - salidas_continuas_mae: 5.9549 - val_loss: 81.8321 - val_salida_clase_accuracy: 0.9990 - val_salidas_continuas_mae: 5.0270 - learning_rate: 2.5000e-04
# Epoch 36/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 108.0976 - salida_clase_accuracy: 0.9954 - salidas_continuas_mae: 5.9511 - val_loss: 86.2842 - val_salida_clase_accuracy: 0.9986 - val_salidas_continuas_mae: 5.2570 - learning_rate: 2.5000e-04
# Epoch 37/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 106.0446 - salida_clase_accuracy: 0.9949 - salidas_continuas_mae: 5.8973 - val_loss: 80.2711 - val_salida_clase_accuracy: 0.9979 - val_salidas_continuas_mae: 4.9548 - learning_rate: 2.5000e-04
# Epoch 38/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 108.9376 - salida_clase_accuracy: 0.9960 - salidas_continuas_mae: 5.9504 - val_loss: 80.8869 - val_salida_clase_accuracy: 0.9986 - val_salidas_continuas_mae: 5.0341 - learning_rate: 1.2500e-04
# Epoch 39/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 104.1780 - salida_clase_accuracy: 0.9972 - salidas_continuas_mae: 5.8306 - val_loss: 85.3320 - val_salida_clase_accuracy: 0.9990 - val_salidas_continuas_mae: 5.2566 - learning_rate: 1.2500e-04
# Epoch 40/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - loss: 105.3441 - salida_clase_accuracy: 0.9965 - salidas_continuas_mae: 5.8589 - val_loss: 81.0510 - val_salida_clase_accuracy: 0.9990 - val_salidas_continuas_mae: 5.0556 - learning_rate: 1.2500e-04
# Epoch 41/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - loss: 106.8925 - salida_clase_accuracy: 0.9959 - salidas_continuas_mae: 5.9104 - val_loss: 80.2840 - val_salida_clase_accuracy: 0.9991 - val_salidas_continuas_mae: 5.0030 - learning_rate: 1.2500e-04
# Epoch 42/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 106.3656 - salida_clase_accuracy: 0.9966 - salidas_continuas_mae: 5.8793 - val_loss: 79.8952 - val_salida_clase_accuracy: 0.9988 - val_salidas_continuas_mae: 5.0046 - learning_rate: 1.2500e-04
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 76.5956 - salida_clase_accuracy: 0.9989 - salidas_continuas_mae: 4.7964
# Fold 1: Loss=76.890380859375, MAE=4.80341911315918, Accuracy=0.999165952205658
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Entrenando fold 2...
# Epoch 1/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - loss: 2829.5073 - salida_clase_accuracy: 0.7652 - salidas_continuas_mae: 32.1225 - val_loss: 433.9638 - val_salida_clase_accuracy: 0.9651 - val_salidas_continuas_mae: 13.2176 - learning_rate: 5.0000e-04
# Epoch 2/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 340.8744 - salida_clase_accuracy: 0.9476 - salidas_continuas_mae: 11.1290 - val_loss: 267.5696 - val_salida_clase_accuracy: 0.9772 - val_salidas_continuas_mae: 9.7059 - learning_rate: 5.0000e-04
# Epoch 3/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 255.8154 - salida_clase_accuracy: 0.9656 - salidas_continuas_mae: 9.3369 - val_loss: 207.4704 - val_salida_clase_accuracy: 0.9821 - val_salidas_continuas_mae: 8.3039 - learning_rate: 5.0000e-04
# Epoch 4/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 206.7068 - salida_clase_accuracy: 0.9708 - salidas_continuas_mae: 8.2362 - val_loss: 181.8519 - val_salida_clase_accuracy: 0.9878 - val_salidas_continuas_mae: 7.7352 - learning_rate: 5.0000e-04
# Epoch 5/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - loss: 185.9939 - salida_clase_accuracy: 0.9740 - salidas_continuas_mae: 7.7478 - val_loss: 147.1754 - val_salida_clase_accuracy: 0.9826 - val_salidas_continuas_mae: 6.7070 - learning_rate: 5.0000e-04
# Epoch 6/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - loss: 170.0101 - salida_clase_accuracy: 0.9764 - salidas_continuas_mae: 7.3645 - val_loss: 139.5547 - val_salida_clase_accuracy: 0.9915 - val_salidas_continuas_mae: 6.5980 - learning_rate: 5.0000e-04
# Epoch 7/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 157.3681 - salida_clase_accuracy: 0.9815 - salidas_continuas_mae: 7.0937 - val_loss: 127.7805 - val_salida_clase_accuracy: 0.9896 - val_salidas_continuas_mae: 6.2893 - learning_rate: 5.0000e-04
# Epoch 8/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 148.6856 - salida_clase_accuracy: 0.9824 - salidas_continuas_mae: 6.9063 - val_loss: 118.4030 - val_salida_clase_accuracy: 0.9904 - val_salidas_continuas_mae: 5.9729 - learning_rate: 5.0000e-04
# Epoch 9/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 142.5542 - salida_clase_accuracy: 0.9848 - salidas_continuas_mae: 6.7755 - val_loss: 131.3491 - val_salida_clase_accuracy: 0.9927 - val_salidas_continuas_mae: 6.4708 - learning_rate: 5.0000e-04
# Epoch 10/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 23ms/step - loss: 139.3423 - salida_clase_accuracy: 0.9854 - salidas_continuas_mae: 6.7108 - val_loss: 109.3815 - val_salida_clase_accuracy: 0.9944 - val_salidas_continuas_mae: 5.7113 - learning_rate: 5.0000e-04
# Epoch 11/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 134.1766 - salida_clase_accuracy: 0.9872 - salidas_continuas_mae: 6.5870 - val_loss: 111.9092 - val_salida_clase_accuracy: 0.9946 - val_salidas_continuas_mae: 5.9023 - learning_rate: 5.0000e-04
# Epoch 12/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 23ms/step - loss: 130.9974 - salida_clase_accuracy: 0.9881 - salidas_continuas_mae: 6.5414 - val_loss: 105.1880 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 5.6098 - learning_rate: 5.0000e-04
# Epoch 13/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - loss: 130.8344 - salida_clase_accuracy: 0.9891 - salidas_continuas_mae: 6.4894 - val_loss: 112.7037 - val_salida_clase_accuracy: 0.9927 - val_salidas_continuas_mae: 5.9892 - learning_rate: 5.0000e-04
# Epoch 14/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - loss: 129.3001 - salida_clase_accuracy: 0.9876 - salidas_continuas_mae: 6.4681 - val_loss: 101.0900 - val_salida_clase_accuracy: 0.9964 - val_salidas_continuas_mae: 5.5255 - learning_rate: 5.0000e-04
# Epoch 15/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 126.8618 - salida_clase_accuracy: 0.9896 - salidas_continuas_mae: 6.4132 - val_loss: 90.1065 - val_salida_clase_accuracy: 0.9944 - val_salidas_continuas_mae: 5.0254 - learning_rate: 5.0000e-04
# Epoch 16/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - loss: 124.2439 - salida_clase_accuracy: 0.9889 - salidas_continuas_mae: 6.3378 - val_loss: 93.1460 - val_salida_clase_accuracy: 0.9930 - val_salidas_continuas_mae: 5.2504 - learning_rate: 5.0000e-04
# Epoch 17/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 120.8143 - salida_clase_accuracy: 0.9902 - salidas_continuas_mae: 6.2696 - val_loss: 89.5093 - val_salida_clase_accuracy: 0.9960 - val_salidas_continuas_mae: 5.1002 - learning_rate: 5.0000e-04
# Epoch 18/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - loss: 121.0956 - salida_clase_accuracy: 0.9889 - salidas_continuas_mae: 6.2769 - val_loss: 99.2569 - val_salida_clase_accuracy: 0.9974 - val_salidas_continuas_mae: 5.5582 - learning_rate: 5.0000e-04
# Epoch 19/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - loss: 121.2351 - salida_clase_accuracy: 0.9904 - salidas_continuas_mae: 6.2883 - val_loss: 100.6090 - val_salida_clase_accuracy: 0.9965 - val_salidas_continuas_mae: 5.6443 - learning_rate: 5.0000e-04
# Epoch 20/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 24ms/step - loss: 116.0079 - salida_clase_accuracy: 0.9920 - salidas_continuas_mae: 6.1677 - val_loss: 99.5952 - val_salida_clase_accuracy: 0.9950 - val_salidas_continuas_mae: 5.5917 - learning_rate: 5.0000e-04
# Epoch 21/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 117.7849 - salida_clase_accuracy: 0.9923 - salidas_continuas_mae: 6.1913 - val_loss: 88.0319 - val_salida_clase_accuracy: 0.9969 - val_salidas_continuas_mae: 5.1239 - learning_rate: 5.0000e-04
# Epoch 22/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 116.0015 - salida_clase_accuracy: 0.9902 - salidas_continuas_mae: 6.1542 - val_loss: 86.4121 - val_salida_clase_accuracy: 0.9970 - val_salidas_continuas_mae: 5.0614 - learning_rate: 5.0000e-04
# Epoch 23/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 115.1250 - salida_clase_accuracy: 0.9924 - salidas_continuas_mae: 6.1289 - val_loss: 91.4209 - val_salida_clase_accuracy: 0.9983 - val_salidas_continuas_mae: 5.3139 - learning_rate: 5.0000e-04
# Epoch 24/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 114.1531 - salida_clase_accuracy: 0.9908 - salidas_continuas_mae: 6.1017 - val_loss: 100.0896 - val_salida_clase_accuracy: 0.9972 - val_salidas_continuas_mae: 5.7593 - learning_rate: 5.0000e-04
# Epoch 25/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 112.9863 - salida_clase_accuracy: 0.9917 - salidas_continuas_mae: 6.0729 - val_loss: 83.8158 - val_salida_clase_accuracy: 0.9983 - val_salidas_continuas_mae: 5.0002 - learning_rate: 5.0000e-04
# Epoch 26/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 113.0457 - salida_clase_accuracy: 0.9937 - salidas_continuas_mae: 6.0707 - val_loss: 97.9350 - val_salida_clase_accuracy: 0.9984 - val_salidas_continuas_mae: 5.6880 - learning_rate: 5.0000e-04
# Epoch 27/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 111.5194 - salida_clase_accuracy: 0.9924 - salidas_continuas_mae: 6.0203 - val_loss: 97.5622 - val_salida_clase_accuracy: 0.9983 - val_salidas_continuas_mae: 5.7368 - learning_rate: 5.0000e-04
# Epoch 28/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 111.3066 - salida_clase_accuracy: 0.9920 - salidas_continuas_mae: 6.0143 - val_loss: 99.1309 - val_salida_clase_accuracy: 0.9979 - val_salidas_continuas_mae: 5.7794 - learning_rate: 5.0000e-04
# Epoch 29/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 111.0105 - salida_clase_accuracy: 0.9930 - salidas_continuas_mae: 6.0270 - val_loss: 82.4448 - val_salida_clase_accuracy: 0.9950 - val_salidas_continuas_mae: 5.0039 - learning_rate: 5.0000e-04
# Epoch 30/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 111.4845 - salida_clase_accuracy: 0.9926 - salidas_continuas_mae: 6.0253 - val_loss: 81.9320 - val_salida_clase_accuracy: 0.9979 - val_salidas_continuas_mae: 4.9584 - learning_rate: 5.0000e-04
# Epoch 31/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 109.3386 - salida_clase_accuracy: 0.9941 - salidas_continuas_mae: 5.9766 - val_loss: 94.1389 - val_salida_clase_accuracy: 0.9974 - val_salidas_continuas_mae: 5.6127 - learning_rate: 5.0000e-04
# Epoch 32/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 110.2444 - salida_clase_accuracy: 0.9938 - salidas_continuas_mae: 5.9943 - val_loss: 103.1233 - val_salida_clase_accuracy: 0.9965 - val_salidas_continuas_mae: 5.9772 - learning_rate: 5.0000e-04
# Epoch 33/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 110.4819 - salida_clase_accuracy: 0.9921 - salidas_continuas_mae: 5.9857 - val_loss: 79.4112 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 4.8895 - learning_rate: 5.0000e-04
# Epoch 34/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - loss: 109.4409 - salida_clase_accuracy: 0.9934 - salidas_continuas_mae: 5.9577 - val_loss: 88.7912 - val_salida_clase_accuracy: 0.9986 - val_salidas_continuas_mae: 5.4127 - learning_rate: 5.0000e-04
# Epoch 35/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 25s 34ms/step - loss: 106.8176 - salida_clase_accuracy: 0.9931 - salidas_continuas_mae: 5.9177 - val_loss: 93.9771 - val_salida_clase_accuracy: 0.9976 - val_salidas_continuas_mae: 5.5640 - learning_rate: 5.0000e-04
# Epoch 36/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 108.6432 - salida_clase_accuracy: 0.9936 - salidas_continuas_mae: 5.9556 - val_loss: 81.8975 - val_salida_clase_accuracy: 0.9986 - val_salidas_continuas_mae: 4.9953 - learning_rate: 5.0000e-04
# Epoch 37/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 106.2847 - salida_clase_accuracy: 0.9935 - salidas_continuas_mae: 5.9205 - val_loss: 88.5561 - val_salida_clase_accuracy: 0.9983 - val_salidas_continuas_mae: 5.4115 - learning_rate: 5.0000e-04
# Epoch 38/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 25s 34ms/step - loss: 106.7270 - salida_clase_accuracy: 0.9933 - salidas_continuas_mae: 5.9157 - val_loss: 89.6198 - val_salida_clase_accuracy: 0.9974 - val_salidas_continuas_mae: 5.4261 - learning_rate: 5.0000e-04
# Epoch 39/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - loss: 105.1375 - salida_clase_accuracy: 0.9948 - salidas_continuas_mae: 5.8609 - val_loss: 89.2088 - val_salida_clase_accuracy: 0.9988 - val_salidas_continuas_mae: 5.4119 - learning_rate: 2.5000e-04
# Epoch 40/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 25s 34ms/step - loss: 106.1104 - salida_clase_accuracy: 0.9961 - salidas_continuas_mae: 5.8692 - val_loss: 85.4456 - val_salida_clase_accuracy: 0.9986 - val_salidas_continuas_mae: 5.2649 - learning_rate: 2.5000e-04
# Epoch 41/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 25s 34ms/step - loss: 105.9122 - salida_clase_accuracy: 0.9959 - salidas_continuas_mae: 5.8690 - val_loss: 87.9968 - val_salida_clase_accuracy: 0.9986 - val_salidas_continuas_mae: 5.3791 - learning_rate: 2.5000e-04
# Epoch 42/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 25s 35ms/step - loss: 104.0287 - salida_clase_accuracy: 0.9956 - salidas_continuas_mae: 5.8166 - val_loss: 84.2025 - val_salida_clase_accuracy: 0.9984 - val_salidas_continuas_mae: 5.1854 - learning_rate: 2.5000e-04
# Epoch 43/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 25s 34ms/step - loss: 103.1219 - salida_clase_accuracy: 0.9960 - salidas_continuas_mae: 5.8118 - val_loss: 88.8999 - val_salida_clase_accuracy: 0.9990 - val_salidas_continuas_mae: 5.4059 - learning_rate: 2.5000e-04
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 75.8823 - salida_clase_accuracy: 0.9975 - salidas_continuas_mae: 4.8002
# Fold 2: Loss=75.7641372680664, MAE=4.794183731079102, Accuracy=0.9973589181900024
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# Entrenando fold 3...
# Epoch 1/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 29s 34ms/step - loss: 2878.7336 - salida_clase_accuracy: 0.7479 - salidas_continuas_mae: 32.4044 - val_loss: 402.4066 - val_salida_clase_accuracy: 0.9494 - val_salidas_continuas_mae: 12.3383 - learning_rate: 5.0000e-04
# Epoch 2/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 344.1694 - salida_clase_accuracy: 0.9449 - salidas_continuas_mae: 11.2106 - val_loss: 266.7874 - val_salida_clase_accuracy: 0.9809 - val_salidas_continuas_mae: 9.6783 - learning_rate: 5.0000e-04
# Epoch 3/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 257.3680 - salida_clase_accuracy: 0.9604 - salidas_continuas_mae: 9.3641 - val_loss: 202.1647 - val_salida_clase_accuracy: 0.9854 - val_salidas_continuas_mae: 8.0649 - learning_rate: 5.0000e-04
# Epoch 4/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 212.3689 - salida_clase_accuracy: 0.9692 - salidas_continuas_mae: 8.3352 - val_loss: 173.2808 - val_salida_clase_accuracy: 0.9913 - val_salidas_continuas_mae: 7.4033 - learning_rate: 5.0000e-04
# Epoch 5/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 188.8161 - salida_clase_accuracy: 0.9764 - salidas_continuas_mae: 7.8189 - val_loss: 163.3107 - val_salida_clase_accuracy: 0.9934 - val_salidas_continuas_mae: 7.2572 - learning_rate: 5.0000e-04
# Epoch 6/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 172.4770 - salida_clase_accuracy: 0.9788 - salidas_continuas_mae: 7.4374 - val_loss: 145.3359 - val_salida_clase_accuracy: 0.9951 - val_salidas_continuas_mae: 6.7292 - learning_rate: 5.0000e-04
# Epoch 7/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 157.7713 - salida_clase_accuracy: 0.9840 - salidas_continuas_mae: 7.1425 - val_loss: 121.0223 - val_salida_clase_accuracy: 0.9943 - val_salidas_continuas_mae: 5.9214 - learning_rate: 5.0000e-04
# Epoch 8/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 150.6623 - salida_clase_accuracy: 0.9855 - salidas_continuas_mae: 6.9539 - val_loss: 124.3243 - val_salida_clase_accuracy: 0.9911 - val_salidas_continuas_mae: 6.1955 - learning_rate: 5.0000e-04
# Epoch 9/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 143.5518 - salida_clase_accuracy: 0.9843 - salidas_continuas_mae: 6.7881 - val_loss: 114.4009 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 5.8370 - learning_rate: 5.0000e-04
# Epoch 10/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 140.5430 - salida_clase_accuracy: 0.9853 - salidas_continuas_mae: 6.7423 - val_loss: 117.5586 - val_salida_clase_accuracy: 0.9934 - val_salidas_continuas_mae: 6.1649 - learning_rate: 5.0000e-04
# Epoch 11/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 135.5000 - salida_clase_accuracy: 0.9883 - salidas_continuas_mae: 6.6156 - val_loss: 107.6765 - val_salida_clase_accuracy: 0.9953 - val_salidas_continuas_mae: 5.7147 - learning_rate: 5.0000e-04
# Epoch 12/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 132.4804 - salida_clase_accuracy: 0.9873 - salidas_continuas_mae: 6.5728 - val_loss: 107.2400 - val_salida_clase_accuracy: 0.9951 - val_salidas_continuas_mae: 5.7378 - learning_rate: 5.0000e-04
# Epoch 13/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 131.4327 - salida_clase_accuracy: 0.9883 - salidas_continuas_mae: 6.5108 - val_loss: 94.9483 - val_salida_clase_accuracy: 0.9976 - val_salidas_continuas_mae: 5.2342 - learning_rate: 5.0000e-04
# Epoch 14/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 126.1893 - salida_clase_accuracy: 0.9891 - salidas_continuas_mae: 6.4190 - val_loss: 102.3418 - val_salida_clase_accuracy: 0.9981 - val_salidas_continuas_mae: 5.6263 - learning_rate: 5.0000e-04
# Epoch 15/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 126.9547 - salida_clase_accuracy: 0.9891 - salidas_continuas_mae: 6.4166 - val_loss: 90.3874 - val_salida_clase_accuracy: 0.9964 - val_salidas_continuas_mae: 5.0690 - learning_rate: 5.0000e-04
# Epoch 16/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 126.8268 - salida_clase_accuracy: 0.9893 - salidas_continuas_mae: 6.4074 - val_loss: 100.5767 - val_salida_clase_accuracy: 0.9957 - val_salidas_continuas_mae: 5.6502 - learning_rate: 5.0000e-04
# Epoch 17/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 122.4229 - salida_clase_accuracy: 0.9891 - salidas_continuas_mae: 6.3227 - val_loss: 100.3246 - val_salida_clase_accuracy: 0.9972 - val_salidas_continuas_mae: 5.6752 - learning_rate: 5.0000e-04
# Epoch 18/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - loss: 120.6882 - salida_clase_accuracy: 0.9899 - salidas_continuas_mae: 6.2707 - val_loss: 92.8275 - val_salida_clase_accuracy: 0.9979 - val_salidas_continuas_mae: 5.3662 - learning_rate: 5.0000e-04
# Epoch 19/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - loss: 119.6218 - salida_clase_accuracy: 0.9916 - salidas_continuas_mae: 6.2228 - val_loss: 93.0337 - val_salida_clase_accuracy: 0.9986 - val_salidas_continuas_mae: 5.3970 - learning_rate: 5.0000e-04
# Epoch 20/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 118.8574 - salida_clase_accuracy: 0.9904 - salidas_continuas_mae: 6.2299 - val_loss: 88.3606 - val_salida_clase_accuracy: 0.9974 - val_salidas_continuas_mae: 5.1550 - learning_rate: 5.0000e-04
# Epoch 21/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - loss: 116.9230 - salida_clase_accuracy: 0.9910 - salidas_continuas_mae: 6.1929 - val_loss: 87.4456 - val_salida_clase_accuracy: 0.9979 - val_salidas_continuas_mae: 5.1263 - learning_rate: 5.0000e-04
# Epoch 22/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 25s 35ms/step - loss: 117.6140 - salida_clase_accuracy: 0.9921 - salidas_continuas_mae: 6.1710 - val_loss: 85.5576 - val_salida_clase_accuracy: 0.9969 - val_salidas_continuas_mae: 5.0797 - learning_rate: 5.0000e-04
# Epoch 23/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 115.1572 - salida_clase_accuracy: 0.9918 - salidas_continuas_mae: 6.1384 - val_loss: 93.9674 - val_salida_clase_accuracy: 0.9979 - val_salidas_continuas_mae: 5.5204 - learning_rate: 5.0000e-04
# Epoch 24/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 115.0189 - salida_clase_accuracy: 0.9918 - salidas_continuas_mae: 6.1364 - val_loss: 92.9614 - val_salida_clase_accuracy: 0.9976 - val_salidas_continuas_mae: 5.4944 - learning_rate: 5.0000e-04
# Epoch 25/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 114.5547 - salida_clase_accuracy: 0.9914 - salidas_continuas_mae: 6.1301 - val_loss: 93.1099 - val_salida_clase_accuracy: 0.9990 - val_salidas_continuas_mae: 5.4384 - learning_rate: 5.0000e-04
# Epoch 26/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 113.2221 - salida_clase_accuracy: 0.9925 - salidas_continuas_mae: 6.0902 - val_loss: 80.2377 - val_salida_clase_accuracy: 0.9991 - val_salidas_continuas_mae: 4.8611 - learning_rate: 5.0000e-04
# Epoch 27/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 111.3519 - salida_clase_accuracy: 0.9935 - salidas_continuas_mae: 6.0543 - val_loss: 93.4230 - val_salida_clase_accuracy: 0.9979 - val_salidas_continuas_mae: 5.4902 - learning_rate: 5.0000e-04
# Epoch 28/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 111.2931 - salida_clase_accuracy: 0.9925 - salidas_continuas_mae: 6.0432 - val_loss: 86.0869 - val_salida_clase_accuracy: 0.9990 - val_salidas_continuas_mae: 5.1516 - learning_rate: 5.0000e-04
# Epoch 29/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 112.7768 - salida_clase_accuracy: 0.9935 - salidas_continuas_mae: 6.0745 - val_loss: 88.7185 - val_salida_clase_accuracy: 0.9988 - val_salidas_continuas_mae: 5.3477 - learning_rate: 5.0000e-04
# Epoch 30/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 110.9678 - salida_clase_accuracy: 0.9931 - salidas_continuas_mae: 6.0248 - val_loss: 85.8496 - val_salida_clase_accuracy: 0.9981 - val_salidas_continuas_mae: 5.2646 - learning_rate: 5.0000e-04
# Epoch 31/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 111.1106 - salida_clase_accuracy: 0.9929 - salidas_continuas_mae: 6.0351 - val_loss: 82.7838 - val_salida_clase_accuracy: 0.9991 - val_salidas_continuas_mae: 5.1166 - learning_rate: 5.0000e-04
# Epoch 32/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 107.2616 - salida_clase_accuracy: 0.9938 - salidas_continuas_mae: 5.9326 - val_loss: 85.6746 - val_salida_clase_accuracy: 0.9991 - val_salidas_continuas_mae: 5.2434 - learning_rate: 2.5000e-04
# Epoch 33/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 108.4173 - salida_clase_accuracy: 0.9943 - salidas_continuas_mae: 5.9425 - val_loss: 82.5527 - val_salida_clase_accuracy: 0.9988 - val_salidas_continuas_mae: 5.0869 - learning_rate: 2.5000e-04
# Epoch 34/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 110.3309 - salida_clase_accuracy: 0.9952 - salidas_continuas_mae: 5.9840 - val_loss: 83.3085 - val_salida_clase_accuracy: 0.9995 - val_salidas_continuas_mae: 5.1536 - learning_rate: 2.5000e-04
# Epoch 35/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 106.0557 - salida_clase_accuracy: 0.9948 - salidas_continuas_mae: 5.9031 - val_loss: 86.0673 - val_salida_clase_accuracy: 0.9991 - val_salidas_continuas_mae: 5.2541 - learning_rate: 2.5000e-04
# Epoch 36/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 106.1234 - salida_clase_accuracy: 0.9950 - salidas_continuas_mae: 5.8760 - val_loss: 82.6140 - val_salida_clase_accuracy: 0.9997 - val_salidas_continuas_mae: 5.1012 - learning_rate: 2.5000e-04
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 78.7850 - salida_clase_accuracy: 0.9987 - salidas_continuas_mae: 4.8458
# Fold 3: Loss=78.44712829589844, MAE=4.831810474395752, Accuracy=0.9987489581108093
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Entrenando fold 4...
# Epoch 1/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 26s 31ms/step - loss: 2886.8406 - salida_clase_accuracy: 0.7479 - salidas_continuas_mae: 32.4150 - val_loss: 388.4018 - val_salida_clase_accuracy: 0.9626 - val_salidas_continuas_mae: 12.0476 - learning_rate: 5.0000e-04
# Epoch 2/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 345.1490 - salida_clase_accuracy: 0.9507 - salidas_continuas_mae: 11.2294 - val_loss: 282.4079 - val_salida_clase_accuracy: 0.9758 - val_salidas_continuas_mae: 9.9564 - learning_rate: 5.0000e-04
# Epoch 3/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 255.6343 - salida_clase_accuracy: 0.9669 - salidas_continuas_mae: 9.3549 - val_loss: 209.9823 - val_salida_clase_accuracy: 0.9823 - val_salidas_continuas_mae: 8.2750 - learning_rate: 5.0000e-04
# Epoch 4/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 213.8136 - salida_clase_accuracy: 0.9701 - salidas_continuas_mae: 8.4062 - val_loss: 181.4385 - val_salida_clase_accuracy: 0.9868 - val_salidas_continuas_mae: 7.6852 - learning_rate: 5.0000e-04
# Epoch 5/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 190.2914 - salida_clase_accuracy: 0.9753 - salidas_continuas_mae: 7.8526 - val_loss: 163.7473 - val_salida_clase_accuracy: 0.9882 - val_salidas_continuas_mae: 7.2595 - learning_rate: 5.0000e-04
# Epoch 6/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 171.7137 - salida_clase_accuracy: 0.9774 - salidas_continuas_mae: 7.4421 - val_loss: 144.0889 - val_salida_clase_accuracy: 0.9873 - val_salidas_continuas_mae: 6.7197 - learning_rate: 5.0000e-04
# Epoch 7/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 162.5287 - salida_clase_accuracy: 0.9798 - salidas_continuas_mae: 7.2250 - val_loss: 130.6208 - val_salida_clase_accuracy: 0.9910 - val_salidas_continuas_mae: 6.3311 - learning_rate: 5.0000e-04
# Epoch 8/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 151.9225 - salida_clase_accuracy: 0.9811 - salidas_continuas_mae: 6.9853 - val_loss: 123.5365 - val_salida_clase_accuracy: 0.9941 - val_salidas_continuas_mae: 6.1631 - learning_rate: 5.0000e-04
# Epoch 9/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 144.2201 - salida_clase_accuracy: 0.9847 - salidas_continuas_mae: 6.8013 - val_loss: 111.7644 - val_salida_clase_accuracy: 0.9936 - val_salidas_continuas_mae: 5.7761 - learning_rate: 5.0000e-04
# Epoch 10/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - loss: 142.1153 - salida_clase_accuracy: 0.9849 - salidas_continuas_mae: 6.7675 - val_loss: 112.8439 - val_salida_clase_accuracy: 0.9951 - val_salidas_continuas_mae: 5.8458 - learning_rate: 5.0000e-04
# Epoch 11/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 136.7339 - salida_clase_accuracy: 0.9862 - salidas_continuas_mae: 6.6397 - val_loss: 99.4657 - val_salida_clase_accuracy: 0.9964 - val_salidas_continuas_mae: 5.3149 - learning_rate: 5.0000e-04
# Epoch 12/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - loss: 134.0137 - salida_clase_accuracy: 0.9862 - salidas_continuas_mae: 6.5842 - val_loss: 98.0384 - val_salida_clase_accuracy: 0.9937 - val_salidas_continuas_mae: 5.3272 - learning_rate: 5.0000e-04
# Epoch 13/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 132.1219 - salida_clase_accuracy: 0.9857 - salidas_continuas_mae: 6.5578 - val_loss: 99.5291 - val_salida_clase_accuracy: 0.9960 - val_salidas_continuas_mae: 5.4612 - learning_rate: 5.0000e-04
# Epoch 14/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 129.5944 - salida_clase_accuracy: 0.9855 - salidas_continuas_mae: 6.4941 - val_loss: 100.0341 - val_salida_clase_accuracy: 0.9969 - val_salidas_continuas_mae: 5.5440 - learning_rate: 5.0000e-04
# Epoch 15/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 126.7205 - salida_clase_accuracy: 0.9888 - salidas_continuas_mae: 6.4138 - val_loss: 93.1630 - val_salida_clase_accuracy: 0.9983 - val_salidas_continuas_mae: 5.2222 - learning_rate: 5.0000e-04
# Epoch 16/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 125.6354 - salida_clase_accuracy: 0.9910 - salidas_continuas_mae: 6.4215 - val_loss: 87.5415 - val_salida_clase_accuracy: 0.9970 - val_salidas_continuas_mae: 5.0319 - learning_rate: 5.0000e-04
# Epoch 17/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - loss: 126.2289 - salida_clase_accuracy: 0.9894 - salidas_continuas_mae: 6.4003 - val_loss: 94.3586 - val_salida_clase_accuracy: 0.9964 - val_salidas_continuas_mae: 5.3970 - learning_rate: 5.0000e-04
# Epoch 18/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 121.5465 - salida_clase_accuracy: 0.9901 - salidas_continuas_mae: 6.3020 - val_loss: 82.5759 - val_salida_clase_accuracy: 0.9977 - val_salidas_continuas_mae: 4.8115 - learning_rate: 5.0000e-04
# Epoch 19/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 122.4047 - salida_clase_accuracy: 0.9909 - salidas_continuas_mae: 6.2896 - val_loss: 86.6808 - val_salida_clase_accuracy: 0.9974 - val_salidas_continuas_mae: 5.0527 - learning_rate: 5.0000e-04
# Epoch 20/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 119.9046 - salida_clase_accuracy: 0.9893 - salidas_continuas_mae: 6.2479 - val_loss: 83.4597 - val_salida_clase_accuracy: 0.9972 - val_salidas_continuas_mae: 4.9185 - learning_rate: 5.0000e-04
# Epoch 21/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 118.8896 - salida_clase_accuracy: 0.9904 - salidas_continuas_mae: 6.2501 - val_loss: 97.6897 - val_salida_clase_accuracy: 0.9972 - val_salidas_continuas_mae: 5.6041 - learning_rate: 5.0000e-04
# Epoch 22/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 119.4393 - salida_clase_accuracy: 0.9892 - salidas_continuas_mae: 6.2465 - val_loss: 85.1054 - val_salida_clase_accuracy: 0.9970 - val_salidas_continuas_mae: 5.1106 - learning_rate: 5.0000e-04
# Epoch 23/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 114.8780 - salida_clase_accuracy: 0.9907 - salidas_continuas_mae: 6.1293 - val_loss: 83.9019 - val_salida_clase_accuracy: 0.9974 - val_salidas_continuas_mae: 5.0008 - learning_rate: 5.0000e-04
# Epoch 24/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 113.5237 - salida_clase_accuracy: 0.9931 - salidas_continuas_mae: 6.0927 - val_loss: 81.3081 - val_salida_clase_accuracy: 0.9981 - val_salidas_continuas_mae: 4.9130 - learning_rate: 2.5000e-04
# Epoch 25/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 114.5641 - salida_clase_accuracy: 0.9938 - salidas_continuas_mae: 6.1006 - val_loss: 89.1900 - val_salida_clase_accuracy: 0.9974 - val_salidas_continuas_mae: 5.3138 - learning_rate: 2.5000e-04
# Epoch 26/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 113.4252 - salida_clase_accuracy: 0.9943 - salidas_continuas_mae: 6.0472 - val_loss: 85.5305 - val_salida_clase_accuracy: 0.9984 - val_salidas_continuas_mae: 5.1275 - learning_rate: 2.5000e-04
# Epoch 27/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 113.2953 - salida_clase_accuracy: 0.9945 - salidas_continuas_mae: 6.0707 - val_loss: 87.6729 - val_salida_clase_accuracy: 0.9988 - val_salidas_continuas_mae: 5.2359 - learning_rate: 2.5000e-04
# Epoch 28/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 111.4582 - salida_clase_accuracy: 0.9937 - salidas_continuas_mae: 6.0434 - val_loss: 85.9902 - val_salida_clase_accuracy: 0.9984 - val_salidas_continuas_mae: 5.1842 - learning_rate: 2.5000e-04
# Epoch 29/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 111.7198 - salida_clase_accuracy: 0.9942 - salidas_continuas_mae: 6.0213 - val_loss: 82.9965 - val_salida_clase_accuracy: 0.9976 - val_salidas_continuas_mae: 5.0585 - learning_rate: 2.5000e-04
# Epoch 30/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 110.7497 - salida_clase_accuracy: 0.9942 - salidas_continuas_mae: 6.0032 - val_loss: 78.9831 - val_salida_clase_accuracy: 0.9984 - val_salidas_continuas_mae: 4.8368 - learning_rate: 1.2500e-04
# Epoch 31/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 109.7876 - salida_clase_accuracy: 0.9952 - salidas_continuas_mae: 5.9773 - val_loss: 83.9974 - val_salida_clase_accuracy: 0.9983 - val_salidas_continuas_mae: 5.1060 - learning_rate: 1.2500e-04
# Epoch 32/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - loss: 111.9120 - salida_clase_accuracy: 0.9964 - salidas_continuas_mae: 6.0044 - val_loss: 80.2885 - val_salida_clase_accuracy: 0.9988 - val_salidas_continuas_mae: 4.9289 - learning_rate: 1.2500e-04
# Epoch 33/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - loss: 110.0121 - salida_clase_accuracy: 0.9950 - salidas_continuas_mae: 5.9884 - val_loss: 83.0064 - val_salida_clase_accuracy: 0.9988 - val_salidas_continuas_mae: 5.0914 - learning_rate: 1.2500e-04
# Epoch 34/50
# 156/720 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 112.4290 - salida_clase_accuracy: 0.9974 - salidas_continuas_mae: 6.0003

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 82.00661087036133
# MAE: 4.992814470106881
# MSE: 81.76848625140559
# RMSE: 9.042562743429055
# R^2: 0.9801166762020008
# Accuracy: 0.9984709620475769
# Precisión: 0.9984758678289434
# Recall: 0.9984709480122325
# F1-Score: 0.9984711308003299
