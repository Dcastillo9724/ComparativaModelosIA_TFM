# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt

# %%
# Definir rutas
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_raiz = os.path.dirname(carpeta_mediapipe)
ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual,'datos','scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Pose', 'pose_data_images.csv')

# Cargar el dataset
data = pd.read_csv(ruta_csv)

# Preparar entradas (Keypoints)
num_keypoints = 33 * 3
X = data.iloc[:, :num_keypoints].values

# Las siguientes 11 columnas incluyen:
# 10 características continuas (ángulos, distancias) + 1 tipo de ejercicio (última columna)
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

# Codificar la etiqueta del tipo de ejercicio
encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_continuas_train, y_continuas_test, y_clase_train, y_clase_test = train_test_split(
    X, y_continuas, y_clase_encoded, test_size=0.2, random_state=42)

# Normalizar las entradas
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

# Listas para almacenar métricas
all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

n_epochs = 150  # Número de épocas
all_train_loss = np.full((5, n_epochs), np.nan)  
all_val_loss = np.full((5, n_epochs), np.nan)
all_train_accuracy = np.full((5, n_epochs), np.nan)
all_val_accuracy = np.full((5, n_epochs), np.nan)


# Validación cruzada
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
fold_index = 0

def create_model(learning_rate=0.001):
    input_layer = Input(shape=(X_train_scaled.shape[1],))
    x = Dense(128, activation='relu')(input_layer)
    x = Dense(64, activation='relu')(x)
    x = Dense(32, activation='relu')(x)
    salidas_continuas = Dense(6, activation='linear', name='salidas_continuas')(x)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)
    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer,
                  loss={'salidas_continuas': 'mean_squared_error', 'salida_clase': 'sparse_categorical_crossentropy'},
                  metrics={'salidas_continuas': 'mae', 'salida_clase': 'accuracy'})
    return model

for train_index, val_index in kfold.split(X_train_scaled):
    fold_index += 1
    print(f"Entrenando fold {fold_index}...")

    X_train_fold, X_val_fold = X_train_scaled[train_index], X_train_scaled[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas_train[train_index], y_continuas_train[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_train[train_index], y_clase_train[val_index]

    model = create_model(learning_rate=0.0005)  # Ajustar la tasa de aprendizaje aquí
    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold_index}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    epochs_completed = len(history.history['loss'])
    all_train_loss[fold_index - 1, :epochs_completed] = history.history['loss']
    all_val_loss[fold_index - 1, :epochs_completed] = history.history['val_loss']
    all_train_accuracy[fold_index - 1, :epochs_completed] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold_index - 1, :epochs_completed] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de prueba
    scores = model.evaluate(X_test_scaled, {'salidas_continuas': y_continuas_test, 'salida_clase': y_clase_test})
    print(f"Fold {fold_index}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_test_scaled)[0]
    mae = mean_absolute_error(y_continuas_test, y_pred_continuas)
    mse = mean_squared_error(y_continuas_test, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_test)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_test_scaled)[1], axis=1)
    precision = precision_score(y_clase_test, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_test, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_test, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_test, y_pred_clase, labels=np.unique(y_clase_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 12744.3164 - salida_clase_accuracy: 0.1532 - salidas_continuas_mae: 102.1195 - val_loss: 6844.9526 - val_salida_clase_accuracy: 0.2530 - val_salidas_continuas_mae: 71.3529 - learning_rate: 5.0000e-04
# Epoch 2/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4680.8550 - salida_clase_accuracy: 0.2084 - salidas_continuas_mae: 56.7141 - val_loss: 2123.4758 - val_salida_clase_accuracy: 0.2396 - val_salidas_continuas_mae: 36.9285 - learning_rate: 5.0000e-04
# Epoch 3/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2030.0668 - salida_clase_accuracy: 0.2300 - salidas_continuas_mae: 36.2497 - val_loss: 1740.8104 - val_salida_clase_accuracy: 0.2663 - val_salidas_continuas_mae: 33.2682 - learning_rate: 5.0000e-04
# Epoch 4/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1708.5948 - salida_clase_accuracy: 0.2691 - salidas_continuas_mae: 32.8165 - val_loss: 1551.4371 - val_salida_clase_accuracy: 0.3047 - val_salidas_continuas_mae: 31.4269 - learning_rate: 5.0000e-04
# Epoch 5/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1508.4973 - salida_clase_accuracy: 0.2932 - salidas_continuas_mae: 30.7581 - val_loss: 1414.7273 - val_salida_clase_accuracy: 0.3506 - val_salidas_continuas_mae: 29.8375 - learning_rate: 5.0000e-04
# Epoch 6/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1360.3777 - salida_clase_accuracy: 0.3307 - salidas_continuas_mae: 29.0020 - val_loss: 1324.3740 - val_salida_clase_accuracy: 0.3462 - val_salidas_continuas_mae: 28.6704 - learning_rate: 5.0000e-04
# Epoch 7/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1279.2843 - salida_clase_accuracy: 0.4200 - salidas_continuas_mae: 27.9505 - val_loss: 1227.1930 - val_salida_clase_accuracy: 0.3994 - val_salidas_continuas_mae: 27.5841 - learning_rate: 5.0000e-04
# Epoch 8/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1176.7964 - salida_clase_accuracy: 0.3961 - salidas_continuas_mae: 26.8154 - val_loss: 1157.4637 - val_salida_clase_accuracy: 0.3757 - val_salidas_continuas_mae: 26.6262 - learning_rate: 5.0000e-04
# Epoch 9/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1104.6550 - salida_clase_accuracy: 0.4160 - salidas_continuas_mae: 25.9227 - val_loss: 1099.1086 - val_salida_clase_accuracy: 0.4068 - val_salidas_continuas_mae: 25.7677 - learning_rate: 5.0000e-04
# Epoch 10/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1061.9059 - salida_clase_accuracy: 0.4070 - salidas_continuas_mae: 25.1493 - val_loss: 1033.4265 - val_salida_clase_accuracy: 0.4172 - val_salidas_continuas_mae: 24.8241 - learning_rate: 5.0000e-04
# Epoch 11/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 974.8170 - salida_clase_accuracy: 0.4476 - salidas_continuas_mae: 24.0437 - val_loss: 985.8082 - val_salida_clase_accuracy: 0.4320 - val_salidas_continuas_mae: 23.9992 - learning_rate: 5.0000e-04
# Epoch 12/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 913.3280 - salida_clase_accuracy: 0.4743 - salidas_continuas_mae: 23.2457 - val_loss: 927.2236 - val_salida_clase_accuracy: 0.4734 - val_salidas_continuas_mae: 23.2738 - learning_rate: 5.0000e-04
# Epoch 13/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 823.5889 - salida_clase_accuracy: 0.4806 - salidas_continuas_mae: 21.9053 - val_loss: 872.6728 - val_salida_clase_accuracy: 0.4719 - val_salidas_continuas_mae: 22.5713 - learning_rate: 5.0000e-04
# Epoch 14/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 809.0127 - salida_clase_accuracy: 0.4957 - salidas_continuas_mae: 21.5898 - val_loss: 825.1440 - val_salida_clase_accuracy: 0.4941 - val_salidas_continuas_mae: 21.7640 - learning_rate: 5.0000e-04
# Epoch 15/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 783.5737 - salida_clase_accuracy: 0.5385 - salidas_continuas_mae: 21.1305 - val_loss: 796.0276 - val_salida_clase_accuracy: 0.5000 - val_salidas_continuas_mae: 21.2122 - learning_rate: 5.0000e-04
# Epoch 16/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 725.3878 - salida_clase_accuracy: 0.5497 - salidas_continuas_mae: 20.3649 - val_loss: 758.3865 - val_salida_clase_accuracy: 0.5577 - val_salidas_continuas_mae: 20.7668 - learning_rate: 5.0000e-04
# Epoch 17/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 702.1569 - salida_clase_accuracy: 0.5569 - salidas_continuas_mae: 20.0570 - val_loss: 725.4153 - val_salida_clase_accuracy: 0.5355 - val_salidas_continuas_mae: 20.1627 - learning_rate: 5.0000e-04
# Epoch 18/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 684.8237 - salida_clase_accuracy: 0.5529 - salidas_continuas_mae: 19.6390 - val_loss: 705.0497 - val_salida_clase_accuracy: 0.5533 - val_salidas_continuas_mae: 19.5848 - learning_rate: 5.0000e-04
# Epoch 19/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 644.9023 - salida_clase_accuracy: 0.5646 - salidas_continuas_mae: 18.9543 - val_loss: 671.4553 - val_salida_clase_accuracy: 0.5473 - val_salidas_continuas_mae: 19.2649 - learning_rate: 5.0000e-04
# Epoch 20/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 589.6709 - salida_clase_accuracy: 0.6002 - salidas_continuas_mae: 18.0656 - val_loss: 655.4474 - val_salida_clase_accuracy: 0.5991 - val_salidas_continuas_mae: 18.8230 - learning_rate: 5.0000e-04
# Epoch 21/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 586.4842 - salida_clase_accuracy: 0.5930 - salidas_continuas_mae: 18.0582 - val_loss: 629.2650 - val_salida_clase_accuracy: 0.5607 - val_salidas_continuas_mae: 18.4977 - learning_rate: 5.0000e-04
# Epoch 22/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 563.7645 - salida_clase_accuracy: 0.5914 - salidas_continuas_mae: 17.6765 - val_loss: 623.0015 - val_salida_clase_accuracy: 0.5828 - val_salidas_continuas_mae: 18.2088 - learning_rate: 5.0000e-04
# Epoch 23/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 562.6602 - salida_clase_accuracy: 0.5991 - salidas_continuas_mae: 17.4080 - val_loss: 598.4554 - val_salida_clase_accuracy: 0.5917 - val_salidas_continuas_mae: 17.7825 - learning_rate: 5.0000e-04
# Epoch 24/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 523.5926 - salida_clase_accuracy: 0.6273 - salidas_continuas_mae: 16.8972 - val_loss: 586.9892 - val_salida_clase_accuracy: 0.6331 - val_salidas_continuas_mae: 17.5508 - learning_rate: 5.0000e-04
# Epoch 25/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 502.3997 - salida_clase_accuracy: 0.6369 - salidas_continuas_mae: 16.5346 - val_loss: 561.4542 - val_salida_clase_accuracy: 0.6391 - val_salidas_continuas_mae: 17.1906 - learning_rate: 5.0000e-04
# Epoch 26/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 496.0406 - salida_clase_accuracy: 0.6382 - salidas_continuas_mae: 16.2656 - val_loss: 552.6247 - val_salida_clase_accuracy: 0.6198 - val_salidas_continuas_mae: 17.0543 - learning_rate: 5.0000e-04
# Epoch 27/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 470.7715 - salida_clase_accuracy: 0.6383 - salidas_continuas_mae: 15.6611 - val_loss: 546.4589 - val_salida_clase_accuracy: 0.6183 - val_salidas_continuas_mae: 16.7908 - learning_rate: 5.0000e-04
# Epoch 28/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 465.4512 - salida_clase_accuracy: 0.6460 - salidas_continuas_mae: 15.6606 - val_loss: 532.0402 - val_salida_clase_accuracy: 0.6272 - val_salidas_continuas_mae: 16.6765 - learning_rate: 5.0000e-04
# Epoch 29/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 471.9119 - salida_clase_accuracy: 0.6340 - salidas_continuas_mae: 15.6901 - val_loss: 518.4212 - val_salida_clase_accuracy: 0.6257 - val_salidas_continuas_mae: 16.2664 - learning_rate: 5.0000e-04
# Epoch 30/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 444.5621 - salida_clase_accuracy: 0.6623 - salidas_continuas_mae: 15.2332 - val_loss: 513.8892 - val_salida_clase_accuracy: 0.6331 - val_salidas_continuas_mae: 16.2570 - learning_rate: 5.0000e-04
# Epoch 31/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 430.5616 - salida_clase_accuracy: 0.6490 - salidas_continuas_mae: 14.9828 - val_loss: 503.9899 - val_salida_clase_accuracy: 0.6538 - val_salidas_continuas_mae: 15.9063 - learning_rate: 5.0000e-04
# Epoch 32/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 424.8315 - salida_clase_accuracy: 0.6496 - salidas_continuas_mae: 14.8198 - val_loss: 497.2828 - val_salida_clase_accuracy: 0.6701 - val_salidas_continuas_mae: 15.7822 - learning_rate: 5.0000e-04
# Epoch 33/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 413.6621 - salida_clase_accuracy: 0.6556 - salidas_continuas_mae: 14.5679 - val_loss: 493.1741 - val_salida_clase_accuracy: 0.6021 - val_salidas_continuas_mae: 15.6845 - learning_rate: 5.0000e-04
# Epoch 34/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 403.4098 - salida_clase_accuracy: 0.6566 - salidas_continuas_mae: 14.4387 - val_loss: 490.2212 - val_salida_clase_accuracy: 0.6021 - val_salidas_continuas_mae: 15.5390 - learning_rate: 5.0000e-04
# Epoch 35/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 402.0805 - salida_clase_accuracy: 0.6608 - salidas_continuas_mae: 14.3207 - val_loss: 488.7116 - val_salida_clase_accuracy: 0.6302 - val_salidas_continuas_mae: 15.4826 - learning_rate: 5.0000e-04
# Epoch 36/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 403.6763 - salida_clase_accuracy: 0.6480 - salidas_continuas_mae: 14.3943 - val_loss: 481.6393 - val_salida_clase_accuracy: 0.6361 - val_salidas_continuas_mae: 15.4091 - learning_rate: 5.0000e-04
# Epoch 37/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 387.3566 - salida_clase_accuracy: 0.6568 - salidas_continuas_mae: 14.0921 - val_loss: 468.9629 - val_salida_clase_accuracy: 0.6553 - val_salidas_continuas_mae: 15.2278 - learning_rate: 5.0000e-04
# Epoch 38/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 390.5039 - salida_clase_accuracy: 0.6559 - salidas_continuas_mae: 14.1119 - val_loss: 462.3024 - val_salida_clase_accuracy: 0.6169 - val_salidas_continuas_mae: 15.1777 - learning_rate: 5.0000e-04
# Epoch 39/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 367.0403 - salida_clase_accuracy: 0.6591 - salidas_continuas_mae: 13.6525 - val_loss: 456.8354 - val_salida_clase_accuracy: 0.6598 - val_salidas_continuas_mae: 15.0613 - learning_rate: 5.0000e-04
# Epoch 40/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 367.8019 - salida_clase_accuracy: 0.6637 - salidas_continuas_mae: 13.7109 - val_loss: 445.4833 - val_salida_clase_accuracy: 0.6701 - val_salidas_continuas_mae: 14.7861 - learning_rate: 5.0000e-04
# Epoch 41/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 364.5155 - salida_clase_accuracy: 0.6618 - salidas_continuas_mae: 13.4641 - val_loss: 445.1699 - val_salida_clase_accuracy: 0.6376 - val_salidas_continuas_mae: 14.7506 - learning_rate: 5.0000e-04
# Epoch 42/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 364.3662 - salida_clase_accuracy: 0.6460 - salidas_continuas_mae: 13.5671 - val_loss: 442.2249 - val_salida_clase_accuracy: 0.6450 - val_salidas_continuas_mae: 14.6935 - learning_rate: 5.0000e-04
# Epoch 43/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 345.5362 - salida_clase_accuracy: 0.6619 - salidas_continuas_mae: 13.1854 - val_loss: 433.0256 - val_salida_clase_accuracy: 0.6405 - val_salidas_continuas_mae: 14.5223 - learning_rate: 5.0000e-04
# Epoch 44/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 359.5572 - salida_clase_accuracy: 0.6455 - salidas_continuas_mae: 13.4180 - val_loss: 434.6363 - val_salida_clase_accuracy: 0.6657 - val_salidas_continuas_mae: 14.4575 - learning_rate: 5.0000e-04
# Epoch 45/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 341.0955 - salida_clase_accuracy: 0.6420 - salidas_continuas_mae: 12.9925 - val_loss: 432.2363 - val_salida_clase_accuracy: 0.6642 - val_salidas_continuas_mae: 14.3901 - learning_rate: 5.0000e-04
# Epoch 46/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 339.3134 - salida_clase_accuracy: 0.6605 - salidas_continuas_mae: 13.0206 - val_loss: 424.2116 - val_salida_clase_accuracy: 0.6746 - val_salidas_continuas_mae: 14.3038 - learning_rate: 5.0000e-04
# Epoch 47/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 330.7950 - salida_clase_accuracy: 0.6382 - salidas_continuas_mae: 12.7292 - val_loss: 416.0120 - val_salida_clase_accuracy: 0.6479 - val_salidas_continuas_mae: 14.1975 - learning_rate: 5.0000e-04
# Epoch 48/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 335.7757 - salida_clase_accuracy: 0.6541 - salidas_continuas_mae: 12.8057 - val_loss: 415.3263 - val_salida_clase_accuracy: 0.6479 - val_salidas_continuas_mae: 14.2440 - learning_rate: 5.0000e-04
# Epoch 49/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 316.9948 - salida_clase_accuracy: 0.6553 - salidas_continuas_mae: 12.5507 - val_loss: 414.1586 - val_salida_clase_accuracy: 0.6435 - val_salidas_continuas_mae: 14.0896 - learning_rate: 5.0000e-04
# Epoch 50/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 325.9475 - salida_clase_accuracy: 0.6711 - salidas_continuas_mae: 12.6011 - val_loss: 412.3089 - val_salida_clase_accuracy: 0.6302 - val_salidas_continuas_mae: 14.0668 - learning_rate: 5.0000e-04
# Epoch 51/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 312.0294 - salida_clase_accuracy: 0.6543 - salidas_continuas_mae: 12.3827 - val_loss: 405.3897 - val_salida_clase_accuracy: 0.6612 - val_salidas_continuas_mae: 13.9353 - learning_rate: 5.0000e-04
# Epoch 52/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 316.6601 - salida_clase_accuracy: 0.6591 - salidas_continuas_mae: 12.4427 - val_loss: 400.5945 - val_salida_clase_accuracy: 0.6450 - val_salidas_continuas_mae: 13.9347 - learning_rate: 5.0000e-04
# Epoch 53/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 306.0932 - salida_clase_accuracy: 0.6595 - salidas_continuas_mae: 12.3310 - val_loss: 404.0872 - val_salida_clase_accuracy: 0.6198 - val_salidas_continuas_mae: 14.0176 - learning_rate: 5.0000e-04
# Epoch 54/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 299.4708 - salida_clase_accuracy: 0.6498 - salidas_continuas_mae: 12.2110 - val_loss: 395.6211 - val_salida_clase_accuracy: 0.6376 - val_salidas_continuas_mae: 13.7740 - learning_rate: 5.0000e-04
# Epoch 55/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 315.0666 - salida_clase_accuracy: 0.6512 - salidas_continuas_mae: 12.2492 - val_loss: 396.9259 - val_salida_clase_accuracy: 0.6302 - val_salidas_continuas_mae: 13.7520 - learning_rate: 5.0000e-04
# Epoch 56/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 296.2810 - salida_clase_accuracy: 0.6643 - salidas_continuas_mae: 12.1383 - val_loss: 386.7260 - val_salida_clase_accuracy: 0.6317 - val_salidas_continuas_mae: 13.6307 - learning_rate: 5.0000e-04
# Epoch 57/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 296.6925 - salida_clase_accuracy: 0.6559 - salidas_continuas_mae: 12.1357 - val_loss: 395.2491 - val_salida_clase_accuracy: 0.6154 - val_salidas_continuas_mae: 13.6988 - learning_rate: 5.0000e-04
# Epoch 58/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 286.0693 - salida_clase_accuracy: 0.6574 - salidas_continuas_mae: 11.8068 - val_loss: 386.5102 - val_salida_clase_accuracy: 0.6361 - val_salidas_continuas_mae: 13.5663 - learning_rate: 5.0000e-04
# Epoch 59/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 273.6127 - salida_clase_accuracy: 0.6587 - salidas_continuas_mae: 11.5802 - val_loss: 386.6925 - val_salida_clase_accuracy: 0.6568 - val_salidas_continuas_mae: 13.4197 - learning_rate: 5.0000e-04
# Epoch 60/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 283.1627 - salida_clase_accuracy: 0.6596 - salidas_continuas_mae: 11.8772 - val_loss: 379.2005 - val_salida_clase_accuracy: 0.6568 - val_salidas_continuas_mae: 13.2859 - learning_rate: 5.0000e-04
# Epoch 61/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 269.8271 - salida_clase_accuracy: 0.6629 - salidas_continuas_mae: 11.4502 - val_loss: 372.7111 - val_salida_clase_accuracy: 0.6612 - val_salidas_continuas_mae: 13.2399 - learning_rate: 5.0000e-04
# Epoch 62/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 274.9216 - salida_clase_accuracy: 0.6796 - salidas_continuas_mae: 11.5674 - val_loss: 370.0074 - val_salida_clase_accuracy: 0.6642 - val_salidas_continuas_mae: 13.1590 - learning_rate: 5.0000e-04
# Epoch 63/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 265.8629 - salida_clase_accuracy: 0.6673 - salidas_continuas_mae: 11.4215 - val_loss: 367.5353 - val_salida_clase_accuracy: 0.6568 - val_salidas_continuas_mae: 13.0871 - learning_rate: 5.0000e-04
# Epoch 64/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 270.5995 - salida_clase_accuracy: 0.6434 - salidas_continuas_mae: 11.5994 - val_loss: 370.8481 - val_salida_clase_accuracy: 0.6479 - val_salidas_continuas_mae: 13.1491 - learning_rate: 5.0000e-04
# Epoch 65/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 258.7999 - salida_clase_accuracy: 0.6632 - salidas_continuas_mae: 11.3479 - val_loss: 367.3541 - val_salida_clase_accuracy: 0.6317 - val_salidas_continuas_mae: 13.1335 - learning_rate: 5.0000e-04
# Epoch 66/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 263.9458 - salida_clase_accuracy: 0.6596 - salidas_continuas_mae: 11.2793 - val_loss: 374.2055 - val_salida_clase_accuracy: 0.6361 - val_salidas_continuas_mae: 13.2614 - learning_rate: 5.0000e-04
# Epoch 67/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 267.7469 - salida_clase_accuracy: 0.6636 - salidas_continuas_mae: 11.5128 - val_loss: 367.4825 - val_salida_clase_accuracy: 0.6524 - val_salidas_continuas_mae: 13.0640 - learning_rate: 5.0000e-04
# Epoch 68/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 257.0057 - salida_clase_accuracy: 0.6471 - salidas_continuas_mae: 11.2014 - val_loss: 361.5522 - val_salida_clase_accuracy: 0.6391 - val_salidas_continuas_mae: 12.9450 - learning_rate: 5.0000e-04
# Epoch 69/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 266.6782 - salida_clase_accuracy: 0.6512 - salidas_continuas_mae: 11.4604 - val_loss: 357.3096 - val_salida_clase_accuracy: 0.6583 - val_salidas_continuas_mae: 12.9934 - learning_rate: 5.0000e-04
# Epoch 70/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 245.2785 - salida_clase_accuracy: 0.6506 - salidas_continuas_mae: 11.0622 - val_loss: 360.5066 - val_salida_clase_accuracy: 0.6405 - val_salidas_continuas_mae: 12.9563 - learning_rate: 5.0000e-04
# Epoch 71/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 269.7088 - salida_clase_accuracy: 0.6565 - salidas_continuas_mae: 11.4540 - val_loss: 366.2242 - val_salida_clase_accuracy: 0.6391 - val_salidas_continuas_mae: 13.1251 - learning_rate: 5.0000e-04
# Epoch 72/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 244.5601 - salida_clase_accuracy: 0.6713 - salidas_continuas_mae: 10.9370 - val_loss: 354.2133 - val_salida_clase_accuracy: 0.6553 - val_salidas_continuas_mae: 12.7272 - learning_rate: 5.0000e-04
# Epoch 73/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 256.8845 - salida_clase_accuracy: 0.6549 - salidas_continuas_mae: 11.2062 - val_loss: 356.6413 - val_salida_clase_accuracy: 0.6568 - val_salidas_continuas_mae: 12.8077 - learning_rate: 5.0000e-04
# Epoch 74/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 250.0536 - salida_clase_accuracy: 0.6361 - salidas_continuas_mae: 11.0922 - val_loss: 358.2248 - val_salida_clase_accuracy: 0.6435 - val_salidas_continuas_mae: 12.9511 - learning_rate: 5.0000e-04
# Epoch 75/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 251.8885 - salida_clase_accuracy: 0.6759 - salidas_continuas_mae: 11.1078 - val_loss: 346.1315 - val_salida_clase_accuracy: 0.6627 - val_salidas_continuas_mae: 12.6130 - learning_rate: 5.0000e-04
# Epoch 76/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 236.1760 - salida_clase_accuracy: 0.6721 - salidas_continuas_mae: 10.7617 - val_loss: 352.5909 - val_salida_clase_accuracy: 0.6405 - val_salidas_continuas_mae: 12.7944 - learning_rate: 5.0000e-04
# Epoch 77/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 234.1081 - salida_clase_accuracy: 0.6573 - salidas_continuas_mae: 10.7963 - val_loss: 344.0474 - val_salida_clase_accuracy: 0.6435 - val_salidas_continuas_mae: 12.6114 - learning_rate: 5.0000e-04
# Epoch 78/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 232.9018 - salida_clase_accuracy: 0.6599 - salidas_continuas_mae: 10.7182 - val_loss: 344.5617 - val_salida_clase_accuracy: 0.6420 - val_salidas_continuas_mae: 12.6086 - learning_rate: 5.0000e-04
# Epoch 79/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 233.2589 - salida_clase_accuracy: 0.6776 - salidas_continuas_mae: 10.6295 - val_loss: 350.0505 - val_salida_clase_accuracy: 0.6583 - val_salidas_continuas_mae: 12.7787 - learning_rate: 5.0000e-04
# Epoch 80/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 233.2441 - salida_clase_accuracy: 0.6669 - salidas_continuas_mae: 10.6766 - val_loss: 350.0287 - val_salida_clase_accuracy: 0.6657 - val_salidas_continuas_mae: 12.6355 - learning_rate: 5.0000e-04
# Epoch 81/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 234.5923 - salida_clase_accuracy: 0.6684 - salidas_continuas_mae: 10.7537 - val_loss: 351.6942 - val_salida_clase_accuracy: 0.6657 - val_salidas_continuas_mae: 13.1602 - learning_rate: 5.0000e-04
# Epoch 82/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 238.5926 - salida_clase_accuracy: 0.6844 - salidas_continuas_mae: 10.8845 - val_loss: 340.6385 - val_salida_clase_accuracy: 0.6494 - val_salidas_continuas_mae: 12.5363 - learning_rate: 5.0000e-04
# Epoch 83/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 225.8612 - salida_clase_accuracy: 0.6813 - salidas_continuas_mae: 10.4339 - val_loss: 341.5656 - val_salida_clase_accuracy: 0.6820 - val_salidas_continuas_mae: 12.5319 - learning_rate: 5.0000e-04
# Epoch 84/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 226.2713 - salida_clase_accuracy: 0.6716 - salidas_continuas_mae: 10.5476 - val_loss: 337.9525 - val_salida_clase_accuracy: 0.6464 - val_salidas_continuas_mae: 12.4744 - learning_rate: 5.0000e-04
# Epoch 85/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 226.9459 - salida_clase_accuracy: 0.6878 - salidas_continuas_mae: 10.4992 - val_loss: 334.0811 - val_salida_clase_accuracy: 0.6509 - val_salidas_continuas_mae: 12.3651 - learning_rate: 5.0000e-04
# Epoch 86/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 208.6950 - salida_clase_accuracy: 0.6805 - salidas_continuas_mae: 10.1874 - val_loss: 333.2501 - val_salida_clase_accuracy: 0.6731 - val_salidas_continuas_mae: 12.3677 - learning_rate: 5.0000e-04
# Epoch 87/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 221.8532 - salida_clase_accuracy: 0.6805 - salidas_continuas_mae: 10.4611 - val_loss: 338.7221 - val_salida_clase_accuracy: 0.6494 - val_salidas_continuas_mae: 12.4607 - learning_rate: 5.0000e-04
# Epoch 88/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 214.0183 - salida_clase_accuracy: 0.6882 - salidas_continuas_mae: 10.2790 - val_loss: 335.4195 - val_salida_clase_accuracy: 0.6775 - val_salidas_continuas_mae: 12.4694 - learning_rate: 5.0000e-04
# Epoch 89/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 221.8155 - salida_clase_accuracy: 0.6853 - salidas_continuas_mae: 10.4739 - val_loss: 332.7849 - val_salida_clase_accuracy: 0.6820 - val_salidas_continuas_mae: 12.1786 - learning_rate: 5.0000e-04
# Epoch 90/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 211.2767 - salida_clase_accuracy: 0.6878 - salidas_continuas_mae: 10.1454 - val_loss: 327.6858 - val_salida_clase_accuracy: 0.6790 - val_salidas_continuas_mae: 12.2577 - learning_rate: 5.0000e-04
# Epoch 91/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 210.2304 - salida_clase_accuracy: 0.6823 - salidas_continuas_mae: 10.1934 - val_loss: 324.0183 - val_salida_clase_accuracy: 0.6790 - val_salidas_continuas_mae: 12.1352 - learning_rate: 5.0000e-04
# Epoch 92/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 204.4186 - salida_clase_accuracy: 0.6916 - salidas_continuas_mae: 10.0326 - val_loss: 333.3618 - val_salida_clase_accuracy: 0.6627 - val_salidas_continuas_mae: 12.4213 - learning_rate: 5.0000e-04
# Epoch 93/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 211.5647 - salida_clase_accuracy: 0.6809 - salidas_continuas_mae: 10.1221 - val_loss: 326.2713 - val_salida_clase_accuracy: 0.6746 - val_salidas_continuas_mae: 12.3183 - learning_rate: 5.0000e-04
# Epoch 94/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 201.2863 - salida_clase_accuracy: 0.6838 - salidas_continuas_mae: 9.9800 - val_loss: 324.9926 - val_salida_clase_accuracy: 0.6731 - val_salidas_continuas_mae: 12.1448 - learning_rate: 5.0000e-04
# Epoch 95/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 204.3507 - salida_clase_accuracy: 0.6945 - salidas_continuas_mae: 9.9788 - val_loss: 326.3039 - val_salida_clase_accuracy: 0.6746 - val_salidas_continuas_mae: 12.1960 - learning_rate: 5.0000e-04
# Epoch 96/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 206.4011 - salida_clase_accuracy: 0.6942 - salidas_continuas_mae: 10.1123 - val_loss: 322.9124 - val_salida_clase_accuracy: 0.6834 - val_salidas_continuas_mae: 12.1610 - learning_rate: 5.0000e-04
# Epoch 97/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 205.7149 - salida_clase_accuracy: 0.6947 - salidas_continuas_mae: 10.0399 - val_loss: 324.6800 - val_salida_clase_accuracy: 0.6893 - val_salidas_continuas_mae: 12.2204 - learning_rate: 5.0000e-04
# Epoch 98/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 191.8712 - salida_clase_accuracy: 0.6964 - salidas_continuas_mae: 9.8054 - val_loss: 325.3136 - val_salida_clase_accuracy: 0.6820 - val_salidas_continuas_mae: 12.2239 - learning_rate: 5.0000e-04
# Epoch 99/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 201.6278 - salida_clase_accuracy: 0.6931 - salidas_continuas_mae: 10.0017 - val_loss: 317.0419 - val_salida_clase_accuracy: 0.6893 - val_salidas_continuas_mae: 12.0371 - learning_rate: 5.0000e-04
# Epoch 100/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 196.4122 - salida_clase_accuracy: 0.7033 - salidas_continuas_mae: 9.8354 - val_loss: 324.7513 - val_salida_clase_accuracy: 0.6893 - val_salidas_continuas_mae: 12.1756 - learning_rate: 5.0000e-04
# Epoch 101/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 197.5035 - salida_clase_accuracy: 0.6900 - salidas_continuas_mae: 9.9317 - val_loss: 315.0933 - val_salida_clase_accuracy: 0.6805 - val_salidas_continuas_mae: 11.9722 - learning_rate: 5.0000e-04
# Epoch 102/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 191.0172 - salida_clase_accuracy: 0.7078 - salidas_continuas_mae: 9.6786 - val_loss: 321.2192 - val_salida_clase_accuracy: 0.6612 - val_salidas_continuas_mae: 12.1450 - learning_rate: 5.0000e-04
# Epoch 103/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 185.7539 - salida_clase_accuracy: 0.6878 - salidas_continuas_mae: 9.6064 - val_loss: 318.7578 - val_salida_clase_accuracy: 0.6820 - val_salidas_continuas_mae: 12.0413 - learning_rate: 5.0000e-04
# Epoch 104/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 190.2543 - salida_clase_accuracy: 0.7085 - salidas_continuas_mae: 9.7367 - val_loss: 320.9472 - val_salida_clase_accuracy: 0.6864 - val_salidas_continuas_mae: 11.9686 - learning_rate: 5.0000e-04
# Epoch 105/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 194.1178 - salida_clase_accuracy: 0.6973 - salidas_continuas_mae: 9.7912 - val_loss: 318.8170 - val_salida_clase_accuracy: 0.6820 - val_salidas_continuas_mae: 12.0398 - learning_rate: 5.0000e-04
# Epoch 106/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 191.1824 - salida_clase_accuracy: 0.7038 - salidas_continuas_mae: 9.7337 - val_loss: 318.1436 - val_salida_clase_accuracy: 0.6997 - val_salidas_continuas_mae: 11.9909 - learning_rate: 5.0000e-04
# Epoch 107/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 193.3530 - salida_clase_accuracy: 0.7006 - salidas_continuas_mae: 9.7218 - val_loss: 309.7336 - val_salida_clase_accuracy: 0.6953 - val_salidas_continuas_mae: 11.7489 - learning_rate: 2.5000e-04
# Epoch 108/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 185.3493 - salida_clase_accuracy: 0.6910 - salidas_continuas_mae: 9.4816 - val_loss: 309.8409 - val_salida_clase_accuracy: 0.6864 - val_salidas_continuas_mae: 11.8000 - learning_rate: 2.5000e-04
# Epoch 109/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 183.2669 - salida_clase_accuracy: 0.6927 - salidas_continuas_mae: 9.4306 - val_loss: 309.3835 - val_salida_clase_accuracy: 0.6938 - val_salidas_continuas_mae: 11.8238 - learning_rate: 2.5000e-04
# Epoch 110/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 176.7633 - salida_clase_accuracy: 0.7085 - salidas_continuas_mae: 9.2789 - val_loss: 309.4169 - val_salida_clase_accuracy: 0.6820 - val_salidas_continuas_mae: 11.8117 - learning_rate: 2.5000e-04
# Epoch 111/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 175.7649 - salida_clase_accuracy: 0.6998 - salidas_continuas_mae: 9.3372 - val_loss: 306.1428 - val_salida_clase_accuracy: 0.6953 - val_salidas_continuas_mae: 11.7598 - learning_rate: 2.5000e-04
# Epoch 112/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 177.6650 - salida_clase_accuracy: 0.7010 - salidas_continuas_mae: 9.3102 - val_loss: 308.4167 - val_salida_clase_accuracy: 0.6893 - val_salidas_continuas_mae: 11.7527 - learning_rate: 2.5000e-04
# Epoch 113/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 173.0313 - salida_clase_accuracy: 0.7021 - salidas_continuas_mae: 9.2355 - val_loss: 303.9817 - val_salida_clase_accuracy: 0.6997 - val_salidas_continuas_mae: 11.6880 - learning_rate: 2.5000e-04
# Epoch 114/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 175.1846 - salida_clase_accuracy: 0.7011 - salidas_continuas_mae: 9.2527 - val_loss: 308.5833 - val_salida_clase_accuracy: 0.6834 - val_salidas_continuas_mae: 11.7354 - learning_rate: 2.5000e-04
# Epoch 115/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 173.3377 - salida_clase_accuracy: 0.7025 - salidas_continuas_mae: 9.1609 - val_loss: 309.6530 - val_salida_clase_accuracy: 0.7027 - val_salidas_continuas_mae: 11.7518 - learning_rate: 2.5000e-04
# Epoch 116/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 178.2721 - salida_clase_accuracy: 0.7175 - salidas_continuas_mae: 9.3302 - val_loss: 307.8974 - val_salida_clase_accuracy: 0.6923 - val_salidas_continuas_mae: 11.7497 - learning_rate: 2.5000e-04
# Epoch 117/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 181.7119 - salida_clase_accuracy: 0.7051 - salidas_continuas_mae: 9.4254 - val_loss: 306.8014 - val_salida_clase_accuracy: 0.7071 - val_salidas_continuas_mae: 11.6805 - learning_rate: 2.5000e-04
# Epoch 118/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 177.3951 - salida_clase_accuracy: 0.7092 - salidas_continuas_mae: 9.3253 - val_loss: 309.8679 - val_salida_clase_accuracy: 0.6967 - val_salidas_continuas_mae: 11.7555 - learning_rate: 2.5000e-04
# Epoch 119/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 172.4053 - salida_clase_accuracy: 0.7042 - salidas_continuas_mae: 9.1970 - val_loss: 306.1379 - val_salida_clase_accuracy: 0.6997 - val_salidas_continuas_mae: 11.7157 - learning_rate: 1.2500e-04
# Epoch 120/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 175.0545 - salida_clase_accuracy: 0.7223 - salidas_continuas_mae: 9.2377 - val_loss: 303.5096 - val_salida_clase_accuracy: 0.6879 - val_salidas_continuas_mae: 11.6600 - learning_rate: 1.2500e-04
# Epoch 121/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 171.7297 - salida_clase_accuracy: 0.6998 - salidas_continuas_mae: 9.0778 - val_loss: 304.6818 - val_salida_clase_accuracy: 0.7056 - val_salidas_continuas_mae: 11.6097 - learning_rate: 1.2500e-04
# Epoch 122/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 172.8214 - salida_clase_accuracy: 0.7126 - salidas_continuas_mae: 9.1802 - val_loss: 305.2296 - val_salida_clase_accuracy: 0.6953 - val_salidas_continuas_mae: 11.6502 - learning_rate: 1.2500e-04
# Epoch 123/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 171.2777 - salida_clase_accuracy: 0.7081 - salidas_continuas_mae: 9.0983 - val_loss: 302.0743 - val_salida_clase_accuracy: 0.7041 - val_salidas_continuas_mae: 11.5748 - learning_rate: 1.2500e-04
# Epoch 124/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 167.7253 - salida_clase_accuracy: 0.7068 - salidas_continuas_mae: 9.1098 - val_loss: 303.4986 - val_salida_clase_accuracy: 0.6953 - val_salidas_continuas_mae: 11.6061 - learning_rate: 1.2500e-04
# Epoch 125/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 172.1091 - salida_clase_accuracy: 0.7158 - salidas_continuas_mae: 9.2040 - val_loss: 303.0213 - val_salida_clase_accuracy: 0.7101 - val_salidas_continuas_mae: 11.6030 - learning_rate: 1.2500e-04
# Epoch 126/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 169.4122 - salida_clase_accuracy: 0.7058 - salidas_continuas_mae: 9.1079 - val_loss: 301.7751 - val_salida_clase_accuracy: 0.7086 - val_salidas_continuas_mae: 11.5924 - learning_rate: 1.2500e-04
# Epoch 127/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 171.5303 - salida_clase_accuracy: 0.6975 - salidas_continuas_mae: 9.1189 - val_loss: 303.5618 - val_salida_clase_accuracy: 0.6908 - val_salidas_continuas_mae: 11.6036 - learning_rate: 1.2500e-04
# Epoch 128/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 168.2699 - salida_clase_accuracy: 0.7072 - salidas_continuas_mae: 9.0766 - val_loss: 300.5838 - val_salida_clase_accuracy: 0.6953 - val_salidas_continuas_mae: 11.6390 - learning_rate: 1.2500e-04
# Epoch 129/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 171.9895 - salida_clase_accuracy: 0.6982 - salidas_continuas_mae: 9.2246 - val_loss: 300.1302 - val_salida_clase_accuracy: 0.6953 - val_salidas_continuas_mae: 11.5735 - learning_rate: 1.2500e-04
# Epoch 130/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 174.7371 - salida_clase_accuracy: 0.7372 - salidas_continuas_mae: 9.2497 - val_loss: 305.1863 - val_salida_clase_accuracy: 0.6982 - val_salidas_continuas_mae: 11.6454 - learning_rate: 1.2500e-04
# Epoch 131/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 168.4795 - salida_clase_accuracy: 0.7007 - salidas_continuas_mae: 9.1085 - val_loss: 301.8683 - val_salida_clase_accuracy: 0.6967 - val_salidas_continuas_mae: 11.5926 - learning_rate: 1.2500e-04
# Epoch 132/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 169.0924 - salida_clase_accuracy: 0.7038 - salidas_continuas_mae: 9.0451 - val_loss: 300.6115 - val_salida_clase_accuracy: 0.6834 - val_salidas_continuas_mae: 11.6246 - learning_rate: 1.2500e-04
# Epoch 133/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 164.9328 - salida_clase_accuracy: 0.7167 - salidas_continuas_mae: 9.0336 - val_loss: 301.4290 - val_salida_clase_accuracy: 0.6879 - val_salidas_continuas_mae: 11.6216 - learning_rate: 1.2500e-04
# Epoch 134/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 168.1863 - salida_clase_accuracy: 0.7077 - salidas_continuas_mae: 9.1086 - val_loss: 300.1858 - val_salida_clase_accuracy: 0.6953 - val_salidas_continuas_mae: 11.5694 - learning_rate: 1.2500e-04
# Epoch 135/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 161.5511 - salida_clase_accuracy: 0.7076 - salidas_continuas_mae: 8.9128 - val_loss: 299.7265 - val_salida_clase_accuracy: 0.7012 - val_salidas_continuas_mae: 11.5457 - learning_rate: 6.2500e-05
# Epoch 136/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 172.9427 - salida_clase_accuracy: 0.6994 - salidas_continuas_mae: 9.1547 - val_loss: 299.2854 - val_salida_clase_accuracy: 0.7086 - val_salidas_continuas_mae: 11.5365 - learning_rate: 6.2500e-05
# Epoch 137/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 168.3143 - salida_clase_accuracy: 0.7139 - salidas_continuas_mae: 9.0376 - val_loss: 298.4875 - val_salida_clase_accuracy: 0.7041 - val_salidas_continuas_mae: 11.5323 - learning_rate: 6.2500e-05
# Epoch 138/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 163.2679 - salida_clase_accuracy: 0.7024 - salidas_continuas_mae: 8.8722 - val_loss: 298.6173 - val_salida_clase_accuracy: 0.6967 - val_salidas_continuas_mae: 11.5097 - learning_rate: 6.2500e-05
# Epoch 139/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 170.6943 - salida_clase_accuracy: 0.6986 - salidas_continuas_mae: 9.1220 - val_loss: 299.4131 - val_salida_clase_accuracy: 0.6997 - val_salidas_continuas_mae: 11.5471 - learning_rate: 6.2500e-05
# Epoch 140/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 167.1448 - salida_clase_accuracy: 0.7007 - salidas_continuas_mae: 9.0387 - val_loss: 298.3385 - val_salida_clase_accuracy: 0.7012 - val_salidas_continuas_mae: 11.5445 - learning_rate: 6.2500e-05
# Epoch 141/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 167.2108 - salida_clase_accuracy: 0.7187 - salidas_continuas_mae: 9.0101 - val_loss: 299.4587 - val_salida_clase_accuracy: 0.6997 - val_salidas_continuas_mae: 11.5333 - learning_rate: 6.2500e-05
# Epoch 142/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 160.8750 - salida_clase_accuracy: 0.7076 - salidas_continuas_mae: 8.9298 - val_loss: 299.0794 - val_salida_clase_accuracy: 0.6997 - val_salidas_continuas_mae: 11.5447 - learning_rate: 6.2500e-05
# Epoch 143/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 161.9446 - salida_clase_accuracy: 0.7155 - salidas_continuas_mae: 8.9381 - val_loss: 299.4898 - val_salida_clase_accuracy: 0.7041 - val_salidas_continuas_mae: 11.5640 - learning_rate: 6.2500e-05
# Epoch 144/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 162.4464 - salida_clase_accuracy: 0.6976 - salidas_continuas_mae: 8.8526 - val_loss: 298.8557 - val_salida_clase_accuracy: 0.7071 - val_salidas_continuas_mae: 11.5240 - learning_rate: 6.2500e-05
# Epoch 145/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 174.7624 - salida_clase_accuracy: 0.7146 - salidas_continuas_mae: 9.1434 - val_loss: 298.9988 - val_salida_clase_accuracy: 0.6997 - val_salidas_continuas_mae: 11.5372 - learning_rate: 6.2500e-05
# Epoch 146/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 166.2090 - salida_clase_accuracy: 0.7036 - salidas_continuas_mae: 8.9462 - val_loss: 298.7660 - val_salida_clase_accuracy: 0.7071 - val_salidas_continuas_mae: 11.5250 - learning_rate: 3.1250e-05
# Epoch 147/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 166.1453 - salida_clase_accuracy: 0.7145 - salidas_continuas_mae: 8.9843 - val_loss: 298.2308 - val_salida_clase_accuracy: 0.6997 - val_salidas_continuas_mae: 11.5145 - learning_rate: 3.1250e-05
# Epoch 148/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 161.4932 - salida_clase_accuracy: 0.7087 - salidas_continuas_mae: 8.8852 - val_loss: 298.8610 - val_salida_clase_accuracy: 0.6982 - val_salidas_continuas_mae: 11.5429 - learning_rate: 3.1250e-05
# Epoch 149/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 163.7820 - salida_clase_accuracy: 0.6983 - salidas_continuas_mae: 8.9343 - val_loss: 299.7099 - val_salida_clase_accuracy: 0.7086 - val_salidas_continuas_mae: 11.5012 - learning_rate: 3.1250e-05
# Epoch 150/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 166.8574 - salida_clase_accuracy: 0.7149 - salidas_continuas_mae: 8.9303 - val_loss: 298.4666 - val_salida_clase_accuracy: 0.7056 - val_salidas_continuas_mae: 11.5192 - learning_rate: 3.1250e-05
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 263.3094 - salida_clase_accuracy: 0.6902 - salidas_continuas_mae: 10.8728
# Fold 1: Loss=265.9170227050781, MAE=10.785870552062988, Accuracy=0.7112426161766052
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Entrenando fold 2...
# Epoch 1/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 12490.1260 - salida_clase_accuracy: 0.1968 - salidas_continuas_mae: 101.4198 - val_loss: 6450.0244 - val_salida_clase_accuracy: 0.2059 - val_salidas_continuas_mae: 69.8894 - learning_rate: 5.0000e-04
# Epoch 2/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4237.0684 - salida_clase_accuracy: 0.2362 - salidas_continuas_mae: 53.8842 - val_loss: 2396.7637 - val_salida_clase_accuracy: 0.2622 - val_salidas_continuas_mae: 37.3897 - learning_rate: 5.0000e-04
# Epoch 3/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2043.5381 - salida_clase_accuracy: 0.2434 - salidas_continuas_mae: 35.7794 - val_loss: 2004.4396 - val_salida_clase_accuracy: 0.2252 - val_salidas_continuas_mae: 34.0887 - learning_rate: 5.0000e-04
# Epoch 4/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1666.8925 - salida_clase_accuracy: 0.2091 - salidas_continuas_mae: 32.5257 - val_loss: 1742.2073 - val_salida_clase_accuracy: 0.2563 - val_salidas_continuas_mae: 32.1221 - learning_rate: 5.0000e-04
# Epoch 5/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1432.9419 - salida_clase_accuracy: 0.2745 - salidas_continuas_mae: 30.1843 - val_loss: 1561.8636 - val_salida_clase_accuracy: 0.2696 - val_salidas_continuas_mae: 30.8469 - learning_rate: 5.0000e-04
# Epoch 6/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1304.1313 - salida_clase_accuracy: 0.2935 - salidas_continuas_mae: 28.5835 - val_loss: 1429.5690 - val_salida_clase_accuracy: 0.3437 - val_salidas_continuas_mae: 29.3664 - learning_rate: 5.0000e-04
# Epoch 7/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1208.2101 - salida_clase_accuracy: 0.3367 - salidas_continuas_mae: 27.2520 - val_loss: 1334.3066 - val_salida_clase_accuracy: 0.3926 - val_salidas_continuas_mae: 28.0275 - learning_rate: 5.0000e-04
# Epoch 8/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1116.5054 - salida_clase_accuracy: 0.3991 - salidas_continuas_mae: 26.0820 - val_loss: 1245.5857 - val_salida_clase_accuracy: 0.4178 - val_salidas_continuas_mae: 27.2060 - learning_rate: 5.0000e-04
# Epoch 9/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1046.9980 - salida_clase_accuracy: 0.4252 - salidas_continuas_mae: 25.2133 - val_loss: 1190.5433 - val_salida_clase_accuracy: 0.4207 - val_salidas_continuas_mae: 26.0093 - learning_rate: 5.0000e-04
# Epoch 10/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 993.8715 - salida_clase_accuracy: 0.4108 - salidas_continuas_mae: 24.3784 - val_loss: 1117.0941 - val_salida_clase_accuracy: 0.4311 - val_salidas_continuas_mae: 25.1565 - learning_rate: 5.0000e-04
# Epoch 11/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 934.6056 - salida_clase_accuracy: 0.4364 - salidas_continuas_mae: 23.5438 - val_loss: 1046.2542 - val_salida_clase_accuracy: 0.4430 - val_salidas_continuas_mae: 24.2886 - learning_rate: 5.0000e-04
# Epoch 12/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 883.2110 - salida_clase_accuracy: 0.4468 - salidas_continuas_mae: 22.9359 - val_loss: 1001.0042 - val_salida_clase_accuracy: 0.4474 - val_salidas_continuas_mae: 23.5785 - learning_rate: 5.0000e-04
# Epoch 13/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 841.6490 - salida_clase_accuracy: 0.4465 - salidas_continuas_mae: 22.1682 - val_loss: 936.8612 - val_salida_clase_accuracy: 0.4904 - val_salidas_continuas_mae: 22.9765 - learning_rate: 5.0000e-04
# Epoch 14/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 790.3426 - salida_clase_accuracy: 0.4723 - salidas_continuas_mae: 21.4618 - val_loss: 906.1885 - val_salida_clase_accuracy: 0.5096 - val_salidas_continuas_mae: 22.3308 - learning_rate: 5.0000e-04
# Epoch 15/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 759.8935 - salida_clase_accuracy: 0.4922 - salidas_continuas_mae: 20.9014 - val_loss: 864.9122 - val_salida_clase_accuracy: 0.5156 - val_salidas_continuas_mae: 21.6726 - learning_rate: 5.0000e-04
# Epoch 16/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 698.1967 - salida_clase_accuracy: 0.4941 - salidas_continuas_mae: 19.9991 - val_loss: 831.4493 - val_salida_clase_accuracy: 0.5259 - val_salidas_continuas_mae: 21.0887 - learning_rate: 5.0000e-04
# Epoch 17/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 659.9030 - salida_clase_accuracy: 0.5137 - salidas_continuas_mae: 19.4315 - val_loss: 789.0851 - val_salida_clase_accuracy: 0.5052 - val_salidas_continuas_mae: 20.4220 - learning_rate: 5.0000e-04
# Epoch 18/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 627.6335 - salida_clase_accuracy: 0.5221 - salidas_continuas_mae: 18.8899 - val_loss: 781.2181 - val_salida_clase_accuracy: 0.5348 - val_salidas_continuas_mae: 19.9109 - learning_rate: 5.0000e-04
# Epoch 19/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 604.0893 - salida_clase_accuracy: 0.5126 - salidas_continuas_mae: 18.4522 - val_loss: 726.0502 - val_salida_clase_accuracy: 0.4993 - val_salidas_continuas_mae: 19.2955 - learning_rate: 5.0000e-04
# Epoch 20/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 595.3204 - salida_clase_accuracy: 0.5291 - salidas_continuas_mae: 18.1230 - val_loss: 703.1970 - val_salida_clase_accuracy: 0.5363 - val_salidas_continuas_mae: 18.9740 - learning_rate: 5.0000e-04
# Epoch 21/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 587.0752 - salida_clase_accuracy: 0.5174 - salidas_continuas_mae: 17.8758 - val_loss: 670.9999 - val_salida_clase_accuracy: 0.5319 - val_salidas_continuas_mae: 18.4646 - learning_rate: 5.0000e-04
# Epoch 22/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 568.7081 - salida_clase_accuracy: 0.5169 - salidas_continuas_mae: 17.5755 - val_loss: 656.4543 - val_salida_clase_accuracy: 0.5289 - val_salidas_continuas_mae: 18.1870 - learning_rate: 5.0000e-04
# Epoch 23/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 551.9197 - salida_clase_accuracy: 0.5042 - salidas_continuas_mae: 17.2014 - val_loss: 639.8422 - val_salida_clase_accuracy: 0.5111 - val_salidas_continuas_mae: 17.7567 - learning_rate: 5.0000e-04
# Epoch 24/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 519.4874 - salida_clase_accuracy: 0.5365 - salidas_continuas_mae: 16.6636 - val_loss: 616.7759 - val_salida_clase_accuracy: 0.5067 - val_salidas_continuas_mae: 17.5454 - learning_rate: 5.0000e-04
# Epoch 25/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 500.3539 - salida_clase_accuracy: 0.5328 - salidas_continuas_mae: 16.4446 - val_loss: 601.4004 - val_salida_clase_accuracy: 0.5126 - val_salidas_continuas_mae: 17.0879 - learning_rate: 5.0000e-04
# Epoch 26/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 474.4313 - salida_clase_accuracy: 0.5317 - salidas_continuas_mae: 15.8790 - val_loss: 599.7660 - val_salida_clase_accuracy: 0.5111 - val_salidas_continuas_mae: 17.0001 - learning_rate: 5.0000e-04
# Epoch 27/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 463.0756 - salida_clase_accuracy: 0.5209 - salidas_continuas_mae: 15.6453 - val_loss: 587.1425 - val_salida_clase_accuracy: 0.4993 - val_salidas_continuas_mae: 16.7359 - learning_rate: 5.0000e-04
# Epoch 28/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 453.2795 - salida_clase_accuracy: 0.5301 - salidas_continuas_mae: 15.4154 - val_loss: 565.5308 - val_salida_clase_accuracy: 0.5052 - val_salidas_continuas_mae: 16.5930 - learning_rate: 5.0000e-04
# Epoch 29/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 445.4013 - salida_clase_accuracy: 0.5346 - salidas_continuas_mae: 15.4053 - val_loss: 563.8543 - val_salida_clase_accuracy: 0.5407 - val_salidas_continuas_mae: 16.3881 - learning_rate: 5.0000e-04
# Epoch 30/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 440.0599 - salida_clase_accuracy: 0.5386 - salidas_continuas_mae: 15.1569 - val_loss: 545.0922 - val_salida_clase_accuracy: 0.5022 - val_salidas_continuas_mae: 16.0329 - learning_rate: 5.0000e-04
# Epoch 31/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 444.2115 - salida_clase_accuracy: 0.5461 - salidas_continuas_mae: 15.2314 - val_loss: 537.9788 - val_salida_clase_accuracy: 0.5304 - val_salidas_continuas_mae: 15.8968 - learning_rate: 5.0000e-04
# Epoch 32/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 420.1269 - salida_clase_accuracy: 0.5468 - salidas_continuas_mae: 14.7891 - val_loss: 531.1343 - val_salida_clase_accuracy: 0.5156 - val_salidas_continuas_mae: 16.0366 - learning_rate: 5.0000e-04
# Epoch 33/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 401.0394 - salida_clase_accuracy: 0.5082 - salidas_continuas_mae: 14.5129 - val_loss: 513.7994 - val_salida_clase_accuracy: 0.5289 - val_salidas_continuas_mae: 15.6106 - learning_rate: 5.0000e-04
# Epoch 34/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 405.8203 - salida_clase_accuracy: 0.5581 - salidas_continuas_mae: 14.5122 - val_loss: 508.2460 - val_salida_clase_accuracy: 0.5422 - val_salidas_continuas_mae: 15.5122 - learning_rate: 5.0000e-04
# Epoch 35/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 388.8840 - salida_clase_accuracy: 0.5651 - salidas_continuas_mae: 14.1879 - val_loss: 512.8273 - val_salida_clase_accuracy: 0.5333 - val_salidas_continuas_mae: 15.4130 - learning_rate: 5.0000e-04
# Epoch 36/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 371.0626 - salida_clase_accuracy: 0.5760 - salidas_continuas_mae: 13.9024 - val_loss: 494.3197 - val_salida_clase_accuracy: 0.5467 - val_salidas_continuas_mae: 15.2876 - learning_rate: 5.0000e-04
# Epoch 37/150
# ...
# Epoch 90/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 213.2030 - salida_clase_accuracy: 0.6358 - salidas_continuas_mae: 10.2277 - val_loss: 317.3676 - val_salida_clase_accuracy: 0.6696 - val_salidas_continuas_mae: 11.7237 - learning_rate: 5.0000e-04
# Epoch 91/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 198.7862 - salida_clase_accuracy: 0.6623 - salidas_continuas_mae: 9.9184 - val_loss: 314.9326 - val_salida_clase_accuracy: 0.6667 - val_salidas_continuas_mae: 11.6414 - learning_rate: 5.0000e-04
# Epoch 92/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 203.4731 - salida_clase_accuracy: 0.6626 - salidas_continuas_mae: 9.9642 - val_loss: 314.5873 - val_salida_clase_accuracy: 0.6800 - val_salidas_continuas_mae: 11.6756 - learning_rate: 5.0000e-04
# Epoch 93/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 211.8735 - salida_clase_accuracy: 0.6844 - salidas_continuas_mae: 10.1357 - val_loss: 312.3387 - val_salida_clase_accuracy: 0.6874 - val_salidas_continuas_mae: 11.5739 - learning_rate: 5.0000e-04
# Epoch 94/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 198.7366 - salida_clase_accuracy: 0.6838 - salidas_continuas_mae: 9.8096 - val_loss: 309.1925 - val_salida_clase_accuracy: 0.6756 - val_salidas_continuas_mae: 11.4742 - learning_rate: 5.0000e-04
# Epoch 95/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 210.6702 - salida_clase_accuracy: 0.6671 - salidas_continuas_mae: 10.0781 - val_loss: 310.0146 - val_salida_clase_accuracy: 0.6622 - val_salidas_continuas_mae: 11.5486 - learning_rate: 5.0000e-04
# Epoch 96/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 209.3644 - salida_clase_accuracy: 0.6717 - salidas_continuas_mae: 10.0691 - val_loss: 298.8959 - val_salida_clase_accuracy: 0.6904 - val_salidas_continuas_mae: 11.2784 - learning_rate: 5.0000e-04
# Epoch 97/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 200.8454 - salida_clase_accuracy: 0.6782 - salidas_continuas_mae: 9.8526 - val_loss: 302.3793 - val_salida_clase_accuracy: 0.6874 - val_salidas_continuas_mae: 11.3874 - learning_rate: 5.0000e-04
# Epoch 98/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 193.4346 - salida_clase_accuracy: 0.6648 - salidas_continuas_mae: 9.6631 - val_loss: 309.1418 - val_salida_clase_accuracy: 0.6519 - val_salidas_continuas_mae: 11.4454 - learning_rate: 5.0000e-04
# Epoch 99/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 195.7133 - salida_clase_accuracy: 0.6747 - salidas_continuas_mae: 9.8306 - val_loss: 304.0654 - val_salida_clase_accuracy: 0.6904 - val_salidas_continuas_mae: 11.3723 - learning_rate: 5.0000e-04
# Epoch 100/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 190.5254 - salida_clase_accuracy: 0.6848 - salidas_continuas_mae: 9.6362 - val_loss: 298.1989 - val_salida_clase_accuracy: 0.6874 - val_salidas_continuas_mae: 11.2451 - learning_rate: 5.0000e-04
# Epoch 101/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 192.7251 - salida_clase_accuracy: 0.6697 - salidas_continuas_mae: 9.6700 - val_loss: 303.2937 - val_salida_clase_accuracy: 0.6785 - val_salidas_continuas_mae: 11.3527 - learning_rate: 5.0000e-04
# Epoch 102/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 194.6237 - salida_clase_accuracy: 0.6694 - salidas_continuas_mae: 9.7319 - val_loss: 296.1476 - val_salida_clase_accuracy: 0.6622 - val_salidas_continuas_mae: 11.2746 - learning_rate: 5.0000e-04
# Epoch 103/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 185.8557 - salida_clase_accuracy: 0.6721 - salidas_continuas_mae: 9.4887 - val_loss: 299.2615 - val_salida_clase_accuracy: 0.6741 - val_salidas_continuas_mae: 11.2604 - learning_rate: 5.0000e-04
# Epoch 104/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 187.9572 - salida_clase_accuracy: 0.6880 - salidas_continuas_mae: 9.5371 - val_loss: 296.5776 - val_salida_clase_accuracy: 0.6785 - val_salidas_continuas_mae: 11.3327 - learning_rate: 5.0000e-04
# Epoch 105/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 191.7648 - salida_clase_accuracy: 0.6787 - salidas_continuas_mae: 9.6784 - val_loss: 298.0006 - val_salida_clase_accuracy: 0.7037 - val_salidas_continuas_mae: 11.2968 - learning_rate: 5.0000e-04
# Epoch 106/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 187.4040 - salida_clase_accuracy: 0.6881 - salidas_continuas_mae: 9.4964 - val_loss: 297.7971 - val_salida_clase_accuracy: 0.6830 - val_salidas_continuas_mae: 11.2770 - learning_rate: 5.0000e-04
# Epoch 107/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 185.8012 - salida_clase_accuracy: 0.6839 - salidas_continuas_mae: 9.6124 - val_loss: 294.3170 - val_salida_clase_accuracy: 0.6963 - val_salidas_continuas_mae: 11.2092 - learning_rate: 5.0000e-04
# Epoch 108/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 176.8273 - salida_clase_accuracy: 0.7043 - salidas_continuas_mae: 9.4097 - val_loss: 296.4107 - val_salida_clase_accuracy: 0.6830 - val_salidas_continuas_mae: 11.2164 - learning_rate: 5.0000e-04
# Epoch 109/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 193.5131 - salida_clase_accuracy: 0.6827 - salidas_continuas_mae: 9.7532 - val_loss: 290.6291 - val_salida_clase_accuracy: 0.7022 - val_salidas_continuas_mae: 11.1688 - learning_rate: 5.0000e-04
# Epoch 110/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 192.1926 - salida_clase_accuracy: 0.6951 - salidas_continuas_mae: 9.6124 - val_loss: 289.8682 - val_salida_clase_accuracy: 0.6948 - val_salidas_continuas_mae: 11.1362 - learning_rate: 5.0000e-04
# Epoch 111/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 180.2988 - salida_clase_accuracy: 0.6930 - salidas_continuas_mae: 9.4062 - val_loss: 300.3457 - val_salida_clase_accuracy: 0.7037 - val_salidas_continuas_mae: 11.1811 - learning_rate: 5.0000e-04
# Epoch 112/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 187.1661 - salida_clase_accuracy: 0.6847 - salidas_continuas_mae: 9.5451 - val_loss: 287.9164 - val_salida_clase_accuracy: 0.7022 - val_salidas_continuas_mae: 11.1017 - learning_rate: 5.0000e-04
# Epoch 113/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 178.6927 - salida_clase_accuracy: 0.6983 - salidas_continuas_mae: 9.2788 - val_loss: 287.5874 - val_salida_clase_accuracy: 0.6889 - val_salidas_continuas_mae: 11.1044 - learning_rate: 5.0000e-04
# Epoch 114/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 178.2821 - salida_clase_accuracy: 0.6886 - salidas_continuas_mae: 9.3102 - val_loss: 283.4159 - val_salida_clase_accuracy: 0.6933 - val_salidas_continuas_mae: 11.0841 - learning_rate: 5.0000e-04
# Epoch 115/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 174.3309 - salida_clase_accuracy: 0.7155 - salidas_continuas_mae: 9.2060 - val_loss: 288.9373 - val_salida_clase_accuracy: 0.6741 - val_salidas_continuas_mae: 11.1690 - learning_rate: 5.0000e-04
# Epoch 116/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 172.0211 - salida_clase_accuracy: 0.7211 - salidas_continuas_mae: 9.1768 - val_loss: 287.1134 - val_salida_clase_accuracy: 0.6993 - val_salidas_continuas_mae: 11.0509 - learning_rate: 5.0000e-04
# Epoch 117/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 174.7752 - salida_clase_accuracy: 0.6953 - salidas_continuas_mae: 9.2031 - val_loss: 285.1754 - val_salida_clase_accuracy: 0.7126 - val_salidas_continuas_mae: 10.9707 - learning_rate: 5.0000e-04
# Epoch 118/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 169.2459 - salida_clase_accuracy: 0.7006 - salidas_continuas_mae: 9.1092 - val_loss: 285.2395 - val_salida_clase_accuracy: 0.7096 - val_salidas_continuas_mae: 11.0407 - learning_rate: 5.0000e-04
# Epoch 119/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 168.0002 - salida_clase_accuracy: 0.7025 - salidas_continuas_mae: 9.0811 - val_loss: 277.7340 - val_salida_clase_accuracy: 0.6859 - val_salidas_continuas_mae: 10.8883 - learning_rate: 5.0000e-04
# Epoch 120/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 169.2174 - salida_clase_accuracy: 0.7093 - salidas_continuas_mae: 9.1142 - val_loss: 283.3993 - val_salida_clase_accuracy: 0.7304 - val_salidas_continuas_mae: 11.1053 - learning_rate: 5.0000e-04
# Epoch 121/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 163.0522 - salida_clase_accuracy: 0.6930 - salidas_continuas_mae: 9.0720 - val_loss: 279.7394 - val_salida_clase_accuracy: 0.7022 - val_salidas_continuas_mae: 10.9039 - learning_rate: 5.0000e-04
# Epoch 122/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 171.0973 - salida_clase_accuracy: 0.7211 - salidas_continuas_mae: 9.0597 - val_loss: 279.6378 - val_salida_clase_accuracy: 0.7096 - val_salidas_continuas_mae: 11.1411 - learning_rate: 5.0000e-04
# Epoch 123/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 165.4951 - salida_clase_accuracy: 0.6916 - salidas_continuas_mae: 9.0794 - val_loss: 283.9335 - val_salida_clase_accuracy: 0.7126 - val_salidas_continuas_mae: 10.9062 - learning_rate: 5.0000e-04
# Epoch 124/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 166.6395 - salida_clase_accuracy: 0.7255 - salidas_continuas_mae: 9.0031 - val_loss: 279.5220 - val_salida_clase_accuracy: 0.7067 - val_salidas_continuas_mae: 10.8132 - learning_rate: 5.0000e-04
# Epoch 125/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 165.1401 - salida_clase_accuracy: 0.7202 - salidas_continuas_mae: 8.9582 - val_loss: 273.9062 - val_salida_clase_accuracy: 0.7244 - val_salidas_continuas_mae: 10.6868 - learning_rate: 2.5000e-04
# Epoch 126/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 159.9328 - salida_clase_accuracy: 0.7175 - salidas_continuas_mae: 8.7377 - val_loss: 273.4633 - val_salida_clase_accuracy: 0.7304 - val_salidas_continuas_mae: 10.7134 - learning_rate: 2.5000e-04
# Epoch 127/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 162.7423 - salida_clase_accuracy: 0.7229 - salidas_continuas_mae: 8.8003 - val_loss: 275.9202 - val_salida_clase_accuracy: 0.7156 - val_salidas_continuas_mae: 10.7396 - learning_rate: 2.5000e-04
# Epoch 128/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 156.8225 - salida_clase_accuracy: 0.7290 - salidas_continuas_mae: 8.7163 - val_loss: 274.8469 - val_salida_clase_accuracy: 0.7289 - val_salidas_continuas_mae: 10.7392 - learning_rate: 2.5000e-04
# Epoch 129/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 160.1522 - salida_clase_accuracy: 0.7460 - salidas_continuas_mae: 8.7871 - val_loss: 272.7204 - val_salida_clase_accuracy: 0.7244 - val_salidas_continuas_mae: 10.7204 - learning_rate: 2.5000e-04
# Epoch 130/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 160.3139 - salida_clase_accuracy: 0.7177 - salidas_continuas_mae: 8.8101 - val_loss: 275.1067 - val_salida_clase_accuracy: 0.7081 - val_salidas_continuas_mae: 10.7532 - learning_rate: 2.5000e-04
# Epoch 131/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 155.9520 - salida_clase_accuracy: 0.7184 - salidas_continuas_mae: 8.6714 - val_loss: 272.1109 - val_salida_clase_accuracy: 0.7022 - val_salidas_continuas_mae: 10.6724 - learning_rate: 2.5000e-04
# Epoch 132/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 154.6772 - salida_clase_accuracy: 0.7252 - salidas_continuas_mae: 8.6343 - val_loss: 273.2877 - val_salida_clase_accuracy: 0.7170 - val_salidas_continuas_mae: 10.7570 - learning_rate: 2.5000e-04
# Epoch 133/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 162.9794 - salida_clase_accuracy: 0.7155 - salidas_continuas_mae: 8.8728 - val_loss: 270.7555 - val_salida_clase_accuracy: 0.7156 - val_salidas_continuas_mae: 10.6917 - learning_rate: 2.5000e-04
# Epoch 134/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 153.8593 - salida_clase_accuracy: 0.7245 - salidas_continuas_mae: 8.6426 - val_loss: 271.6403 - val_salida_clase_accuracy: 0.7244 - val_salidas_continuas_mae: 10.6530 - learning_rate: 2.5000e-04
# Epoch 135/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 156.1722 - salida_clase_accuracy: 0.7156 - salidas_continuas_mae: 8.6848 - val_loss: 269.5593 - val_salida_clase_accuracy: 0.7200 - val_salidas_continuas_mae: 10.6285 - learning_rate: 2.5000e-04
# Epoch 136/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 157.8284 - salida_clase_accuracy: 0.7347 - salidas_continuas_mae: 8.7017 - val_loss: 272.7113 - val_salida_clase_accuracy: 0.7244 - val_salidas_continuas_mae: 10.6561 - learning_rate: 2.5000e-04
# Epoch 137/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 152.5893 - salida_clase_accuracy: 0.7355 - salidas_continuas_mae: 8.6141 - val_loss: 271.7392 - val_salida_clase_accuracy: 0.7170 - val_salidas_continuas_mae: 10.6653 - learning_rate: 2.5000e-04
# Epoch 138/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 155.0909 - salida_clase_accuracy: 0.7187 - salidas_continuas_mae: 8.6694 - val_loss: 267.6248 - val_salida_clase_accuracy: 0.7393 - val_salidas_continuas_mae: 10.6122 - learning_rate: 2.5000e-04
# Epoch 139/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 148.3620 - salida_clase_accuracy: 0.7122 - salidas_continuas_mae: 8.5107 - val_loss: 271.0894 - val_salida_clase_accuracy: 0.7200 - val_salidas_continuas_mae: 10.6170 - learning_rate: 2.5000e-04
# Epoch 140/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 152.8492 - salida_clase_accuracy: 0.7273 - salidas_continuas_mae: 8.6426 - val_loss: 271.6693 - val_salida_clase_accuracy: 0.7126 - val_salidas_continuas_mae: 10.6951 - learning_rate: 2.5000e-04
# Epoch 141/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 152.7334 - salida_clase_accuracy: 0.7301 - salidas_continuas_mae: 8.5976 - val_loss: 270.3436 - val_salida_clase_accuracy: 0.7274 - val_salidas_continuas_mae: 10.6553 - learning_rate: 2.5000e-04
# Epoch 142/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 157.9410 - salida_clase_accuracy: 0.7478 - salidas_continuas_mae: 8.7260 - val_loss: 269.1808 - val_salida_clase_accuracy: 0.7185 - val_salidas_continuas_mae: 10.6354 - learning_rate: 2.5000e-04
# Epoch 143/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 146.2089 - salida_clase_accuracy: 0.7423 - salidas_continuas_mae: 8.4540 - val_loss: 267.7176 - val_salida_clase_accuracy: 0.7156 - val_salidas_continuas_mae: 10.6449 - learning_rate: 2.5000e-04
# Epoch 144/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 154.7590 - salida_clase_accuracy: 0.7346 - salidas_continuas_mae: 8.6064 - val_loss: 266.0476 - val_salida_clase_accuracy: 0.7244 - val_salidas_continuas_mae: 10.5591 - learning_rate: 1.2500e-04
# Epoch 145/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 150.5810 - salida_clase_accuracy: 0.7208 - salidas_continuas_mae: 8.5768 - val_loss: 267.3501 - val_salida_clase_accuracy: 0.7215 - val_salidas_continuas_mae: 10.5557 - learning_rate: 1.2500e-04
# Epoch 146/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 151.5069 - salida_clase_accuracy: 0.7220 - salidas_continuas_mae: 8.5283 - val_loss: 264.5561 - val_salida_clase_accuracy: 0.7215 - val_salidas_continuas_mae: 10.6300 - learning_rate: 1.2500e-04
# Epoch 147/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 154.6424 - salida_clase_accuracy: 0.7445 - salidas_continuas_mae: 8.6184 - val_loss: 266.9535 - val_salida_clase_accuracy: 0.7230 - val_salidas_continuas_mae: 10.5624 - learning_rate: 1.2500e-04
# Epoch 148/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 150.9477 - salida_clase_accuracy: 0.7282 - salidas_continuas_mae: 8.5268 - val_loss: 264.9147 - val_salida_clase_accuracy: 0.7259 - val_salidas_continuas_mae: 10.5683 - learning_rate: 1.2500e-04
# Epoch 149/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 148.5699 - salida_clase_accuracy: 0.7254 - salidas_continuas_mae: 8.4998 - val_loss: 268.2634 - val_salida_clase_accuracy: 0.7274 - val_salidas_continuas_mae: 10.5852 - learning_rate: 1.2500e-04
# Epoch 150/150
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 150.0085 - salida_clase_accuracy: 0.7355 - salidas_continuas_mae: 8.5069 - val_loss: 263.4875 - val_salida_clase_accuracy: 0.7274 - val_salidas_continuas_mae: 10.5623 - learning_rate: 1.2500e-04
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 250.5367 - salida_clase_accuracy: 0.7191 - salidas_continuas_mae: 10.4863
# Fold 5: Loss=245.8044891357422, MAE=10.341320037841797, Accuracy=0.7242603302001953
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 249.862646484375
# MAE: 10.479073519449752
# MSE: 249.02131023986118
# RMSE: 15.77786396889564
# R^2: 0.8905149831074661
# Accuracy: 0.7228402256965637
# Precisión: 0.7276200210707637
# Recall: 0.7228402366863905
# F1-Score: 0.7216531778884563
