# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt

# %%
# Definir rutas
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_raiz = os.path.dirname(carpeta_mediapipe)
ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual,'datos','scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Videos_Pose', 'pose_data.csv')

# Cargar el dataset
data = pd.read_csv(ruta_csv)

# Preparar entradas (Keypoints)
num_keypoints = 33 * 3
X = data.iloc[:, :num_keypoints].values

# Las siguientes 11 columnas incluyen:
# 10 características continuas (ángulos, distancias) + 1 tipo de ejercicio (última columna)
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

# Codificar la etiqueta del tipo de ejercicio
encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_continuas_train, y_continuas_test, y_clase_train, y_clase_test = train_test_split(
    X, y_continuas, y_clase_encoded, test_size=0.2, random_state=42)

# Normalizar las entradas
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

# Listas para almacenar métricas
all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

# Matrices para almacenar la historia del entrenamiento
n_epochs = 50  # Número de épocas
all_train_loss = np.zeros((5, n_epochs))  # 5 pliegues, n_epochs épocas
all_val_loss = np.zeros((5, n_epochs))
all_train_accuracy = np.zeros((5, n_epochs))
all_val_accuracy = np.zeros((5, n_epochs))

# Validación cruzada
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
fold_index = 0

def create_model(learning_rate=0.001):
    input_layer = Input(shape=(X_train_scaled.shape[1],))
    x = Dense(128, activation='relu')(input_layer)
    x = Dense(64, activation='relu')(x)
    x = Dense(32, activation='relu')(x)
    salidas_continuas = Dense(10, activation='linear', name='salidas_continuas')(x)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)
    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer,
                  loss={'salidas_continuas': 'mean_squared_error', 'salida_clase': 'sparse_categorical_crossentropy'},
                  metrics={'salidas_continuas': 'mae', 'salida_clase': 'accuracy'})
    return model

for train_index, val_index in kfold.split(X_train_scaled):
    fold_index += 1
    print(f"Entrenando fold {fold_index}...")

    X_train_fold, X_val_fold = X_train_scaled[train_index], X_train_scaled[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas_train[train_index], y_continuas_train[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_train[train_index], y_clase_train[val_index]

    model = create_model(learning_rate=0.0005)  # Ajustar la tasa de aprendizaje aquí
    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold_index}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    # Almacenar la historia del entrenamiento
    all_train_loss[fold_index - 1, :] = history.history['loss']
    all_val_loss[fold_index - 1, :] = history.history['val_loss']
    all_train_accuracy[fold_index - 1, :] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold_index - 1, :] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de prueba
    scores = model.evaluate(X_test_scaled, {'salidas_continuas': y_continuas_test, 'salida_clase': y_clase_test})
    print(f"Fold {fold_index}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_test_scaled)[0]
    mae = mean_absolute_error(y_continuas_test, y_pred_continuas)
    mse = mean_squared_error(y_continuas_test, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_test)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_test_scaled)[1], axis=1)
    precision = precision_score(y_clase_test, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_test, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_test, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_test, y_pred_clase, labels=np.unique(y_clase_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 3586.9043 - salida_clase_accuracy: 0.2776 - salidas_continuas_mae: 36.5369 - val_loss: 464.7220 - val_salida_clase_accuracy: 0.5011 - val_salidas_continuas_mae: 12.9859 - learning_rate: 5.0000e-04
# Epoch 2/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 414.4421 - salida_clase_accuracy: 0.5781 - salidas_continuas_mae: 12.1786 - val_loss: 275.1762 - val_salida_clase_accuracy: 0.6327 - val_salidas_continuas_mae: 9.8298 - learning_rate: 5.0000e-04
# Epoch 3/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 261.9757 - salida_clase_accuracy: 0.6598 - salidas_continuas_mae: 9.5027 - val_loss: 206.5954 - val_salida_clase_accuracy: 0.6843 - val_salidas_continuas_mae: 8.3858 - learning_rate: 5.0000e-04
# Epoch 4/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 192.9344 - salida_clase_accuracy: 0.7148 - salidas_continuas_mae: 7.9995 - val_loss: 161.3815 - val_salida_clase_accuracy: 0.7474 - val_salidas_continuas_mae: 7.2353 - learning_rate: 5.0000e-04
# Epoch 5/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 155.7597 - salida_clase_accuracy: 0.7710 - salidas_continuas_mae: 6.9796 - val_loss: 134.9950 - val_salida_clase_accuracy: 0.7753 - val_salidas_continuas_mae: 6.4959 - learning_rate: 5.0000e-04
# Epoch 6/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 130.0348 - salida_clase_accuracy: 0.7890 - salidas_continuas_mae: 6.3234 - val_loss: 117.6687 - val_salida_clase_accuracy: 0.8059 - val_salidas_continuas_mae: 6.0584 - learning_rate: 5.0000e-04
# Epoch 7/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 112.9395 - salida_clase_accuracy: 0.8042 - salidas_continuas_mae: 5.8795 - val_loss: 102.0682 - val_salida_clase_accuracy: 0.8155 - val_salidas_continuas_mae: 5.6112 - learning_rate: 5.0000e-04
# Epoch 8/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 98.6888 - salida_clase_accuracy: 0.8205 - salidas_continuas_mae: 5.4578 - val_loss: 89.3660 - val_salida_clase_accuracy: 0.8179 - val_salidas_continuas_mae: 5.2357 - learning_rate: 5.0000e-04
# Epoch 9/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 85.8540 - salida_clase_accuracy: 0.8388 - salidas_continuas_mae: 5.0899 - val_loss: 80.9794 - val_salida_clase_accuracy: 0.8433 - val_salidas_continuas_mae: 5.0225 - learning_rate: 5.0000e-04
# Epoch 10/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 77.8839 - salida_clase_accuracy: 0.8535 - salidas_continuas_mae: 4.8418 - val_loss: 73.9606 - val_salida_clase_accuracy: 0.8535 - val_salidas_continuas_mae: 4.7322 - learning_rate: 5.0000e-04
# Epoch 11/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 70.4458 - salida_clase_accuracy: 0.8635 - salidas_continuas_mae: 4.5961 - val_loss: 68.9481 - val_salida_clase_accuracy: 0.8542 - val_salidas_continuas_mae: 4.5567 - learning_rate: 5.0000e-04
# Epoch 12/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 64.9886 - salida_clase_accuracy: 0.8673 - salidas_continuas_mae: 4.4251 - val_loss: 64.2261 - val_salida_clase_accuracy: 0.8674 - val_salidas_continuas_mae: 4.3782 - learning_rate: 5.0000e-04
# Epoch 13/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 62.0083 - salida_clase_accuracy: 0.8777 - salidas_continuas_mae: 4.2944 - val_loss: 61.7770 - val_salida_clase_accuracy: 0.8723 - val_salidas_continuas_mae: 4.2911 - learning_rate: 5.0000e-04
# Epoch 14/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 56.5107 - salida_clase_accuracy: 0.8783 - salidas_continuas_mae: 4.1155 - val_loss: 59.1137 - val_salida_clase_accuracy: 0.8864 - val_salidas_continuas_mae: 4.1642 - learning_rate: 5.0000e-04
# Epoch 15/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 53.5862 - salida_clase_accuracy: 0.8782 - salidas_continuas_mae: 3.9971 - val_loss: 55.7496 - val_salida_clase_accuracy: 0.8794 - val_salidas_continuas_mae: 4.1141 - learning_rate: 5.0000e-04
# Epoch 16/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 51.0041 - salida_clase_accuracy: 0.8819 - salidas_continuas_mae: 3.9049 - val_loss: 54.5375 - val_salida_clase_accuracy: 0.8822 - val_salidas_continuas_mae: 4.0044 - learning_rate: 5.0000e-04
# Epoch 17/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 47.7972 - salida_clase_accuracy: 0.8834 - salidas_continuas_mae: 3.7692 - val_loss: 51.0368 - val_salida_clase_accuracy: 0.8796 - val_salidas_continuas_mae: 3.8405 - learning_rate: 5.0000e-04
# Epoch 18/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 48.2357 - salida_clase_accuracy: 0.8820 - salidas_continuas_mae: 3.7637 - val_loss: 49.4522 - val_salida_clase_accuracy: 0.8829 - val_salidas_continuas_mae: 3.8258 - learning_rate: 5.0000e-04
# Epoch 19/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 44.9625 - salida_clase_accuracy: 0.8840 - salidas_continuas_mae: 3.6478 - val_loss: 47.4217 - val_salida_clase_accuracy: 0.8844 - val_salidas_continuas_mae: 3.7142 - learning_rate: 5.0000e-04
# Epoch 20/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 42.8214 - salida_clase_accuracy: 0.8875 - salidas_continuas_mae: 3.5591 - val_loss: 45.6975 - val_salida_clase_accuracy: 0.8968 - val_salidas_continuas_mae: 3.6054 - learning_rate: 5.0000e-04
# Epoch 21/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 42.7330 - salida_clase_accuracy: 0.8944 - salidas_continuas_mae: 3.5389 - val_loss: 44.6037 - val_salida_clase_accuracy: 0.8947 - val_salidas_continuas_mae: 3.6012 - learning_rate: 5.0000e-04
# Epoch 22/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 40.0530 - salida_clase_accuracy: 0.8958 - salidas_continuas_mae: 3.4342 - val_loss: 43.0758 - val_salida_clase_accuracy: 0.8968 - val_salidas_continuas_mae: 3.5347 - learning_rate: 5.0000e-04
# Epoch 23/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 39.2681 - salida_clase_accuracy: 0.8965 - salidas_continuas_mae: 3.4021 - val_loss: 42.6791 - val_salida_clase_accuracy: 0.8950 - val_salidas_continuas_mae: 3.5041 - learning_rate: 5.0000e-04
# Epoch 24/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 37.8496 - salida_clase_accuracy: 0.8998 - salidas_continuas_mae: 3.3314 - val_loss: 42.3337 - val_salida_clase_accuracy: 0.8924 - val_salidas_continuas_mae: 3.5017 - learning_rate: 5.0000e-04
# Epoch 25/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 37.4393 - salida_clase_accuracy: 0.9012 - salidas_continuas_mae: 3.3033 - val_loss: 38.9988 - val_salida_clase_accuracy: 0.9070 - val_salidas_continuas_mae: 3.3164 - learning_rate: 5.0000e-04
# Epoch 26/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.7870 - salida_clase_accuracy: 0.9005 - salidas_continuas_mae: 3.2810 - val_loss: 39.1489 - val_salida_clase_accuracy: 0.9036 - val_salidas_continuas_mae: 3.3183 - learning_rate: 5.0000e-04
# Epoch 27/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 36.2889 - salida_clase_accuracy: 0.9070 - salidas_continuas_mae: 3.2448 - val_loss: 38.7825 - val_salida_clase_accuracy: 0.9110 - val_salidas_continuas_mae: 3.3079 - learning_rate: 5.0000e-04
# Epoch 28/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.7650 - salida_clase_accuracy: 0.9096 - salidas_continuas_mae: 3.1705 - val_loss: 38.1476 - val_salida_clase_accuracy: 0.9077 - val_salidas_continuas_mae: 3.2707 - learning_rate: 5.0000e-04
# Epoch 29/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.7023 - salida_clase_accuracy: 0.9085 - salidas_continuas_mae: 3.1677 - val_loss: 38.5714 - val_salida_clase_accuracy: 0.9129 - val_salidas_continuas_mae: 3.3069 - learning_rate: 5.0000e-04
# Epoch 30/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.2968 - salida_clase_accuracy: 0.9154 - salidas_continuas_mae: 3.1589 - val_loss: 37.0443 - val_salida_clase_accuracy: 0.9180 - val_salidas_continuas_mae: 3.2627 - learning_rate: 5.0000e-04
# Epoch 31/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.7111 - salida_clase_accuracy: 0.9147 - salidas_continuas_mae: 3.1002 - val_loss: 35.8970 - val_salida_clase_accuracy: 0.9251 - val_salidas_continuas_mae: 3.1516 - learning_rate: 5.0000e-04
# Epoch 32/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 32.5730 - salida_clase_accuracy: 0.9157 - salidas_continuas_mae: 3.0804 - val_loss: 35.6932 - val_salida_clase_accuracy: 0.9169 - val_salidas_continuas_mae: 3.1569 - learning_rate: 5.0000e-04
# Epoch 33/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31.1378 - salida_clase_accuracy: 0.9227 - salidas_continuas_mae: 2.9962 - val_loss: 35.1036 - val_salida_clase_accuracy: 0.9263 - val_salidas_continuas_mae: 3.1174 - learning_rate: 5.0000e-04
# Epoch 34/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31.9871 - salida_clase_accuracy: 0.9205 - salidas_continuas_mae: 3.0375 - val_loss: 36.3731 - val_salida_clase_accuracy: 0.9237 - val_salidas_continuas_mae: 3.2802 - learning_rate: 5.0000e-04
# Epoch 35/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31.0008 - salida_clase_accuracy: 0.9228 - salidas_continuas_mae: 2.9920 - val_loss: 33.8519 - val_salida_clase_accuracy: 0.9272 - val_salidas_continuas_mae: 3.0320 - learning_rate: 5.0000e-04
# Epoch 36/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 30.1202 - salida_clase_accuracy: 0.9237 - salidas_continuas_mae: 2.9540 - val_loss: 35.3585 - val_salida_clase_accuracy: 0.9194 - val_salidas_continuas_mae: 3.1918 - learning_rate: 5.0000e-04
# Epoch 37/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 30.7866 - salida_clase_accuracy: 0.9258 - salidas_continuas_mae: 2.9633 - val_loss: 32.6170 - val_salida_clase_accuracy: 0.9241 - val_salidas_continuas_mae: 2.9756 - learning_rate: 5.0000e-04
# Epoch 38/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 29.3734 - salida_clase_accuracy: 0.9286 - salidas_continuas_mae: 2.9042 - val_loss: 32.6628 - val_salida_clase_accuracy: 0.9291 - val_salidas_continuas_mae: 3.0087 - learning_rate: 5.0000e-04
# Epoch 39/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 28.5595 - salida_clase_accuracy: 0.9301 - salidas_continuas_mae: 2.8675 - val_loss: 32.5252 - val_salida_clase_accuracy: 0.9249 - val_salidas_continuas_mae: 3.0314 - learning_rate: 5.0000e-04
# Epoch 40/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 28.7299 - salida_clase_accuracy: 0.9260 - salidas_continuas_mae: 2.8615 - val_loss: 32.9233 - val_salida_clase_accuracy: 0.9341 - val_salidas_continuas_mae: 3.0270 - learning_rate: 5.0000e-04
# Epoch 41/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 28.7032 - salida_clase_accuracy: 0.9305 - salidas_continuas_mae: 2.8687 - val_loss: 31.4462 - val_salida_clase_accuracy: 0.9279 - val_salidas_continuas_mae: 2.9348 - learning_rate: 5.0000e-04
# Epoch 42/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.6836 - salida_clase_accuracy: 0.9312 - salidas_continuas_mae: 2.8101 - val_loss: 30.3783 - val_salida_clase_accuracy: 0.9262 - val_salidas_continuas_mae: 2.8381 - learning_rate: 5.0000e-04
# Epoch 43/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.1266 - salida_clase_accuracy: 0.9290 - salidas_continuas_mae: 2.7855 - val_loss: 30.4421 - val_salida_clase_accuracy: 0.9328 - val_salidas_continuas_mae: 2.8602 - learning_rate: 5.0000e-04
# Epoch 44/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.4536 - salida_clase_accuracy: 0.9353 - salidas_continuas_mae: 2.7993 - val_loss: 30.8842 - val_salida_clase_accuracy: 0.9242 - val_salidas_continuas_mae: 2.9022 - learning_rate: 5.0000e-04
# Epoch 45/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.6891 - salida_clase_accuracy: 0.9339 - salidas_continuas_mae: 2.7471 - val_loss: 30.7690 - val_salida_clase_accuracy: 0.9326 - val_salidas_continuas_mae: 2.9292 - learning_rate: 5.0000e-04
# Epoch 46/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.0626 - salida_clase_accuracy: 0.9383 - salidas_continuas_mae: 2.7486 - val_loss: 31.0005 - val_salida_clase_accuracy: 0.9383 - val_salidas_continuas_mae: 2.9868 - learning_rate: 5.0000e-04
# Epoch 47/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.0972 - salida_clase_accuracy: 0.9391 - salidas_continuas_mae: 2.7373 - val_loss: 29.2608 - val_salida_clase_accuracy: 0.9420 - val_salidas_continuas_mae: 2.8027 - learning_rate: 5.0000e-04
# Epoch 48/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.8103 - salida_clase_accuracy: 0.9365 - salidas_continuas_mae: 2.7565 - val_loss: 30.2928 - val_salida_clase_accuracy: 0.9430 - val_salidas_continuas_mae: 2.8694 - learning_rate: 5.0000e-04
# Epoch 49/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 25.5559 - salida_clase_accuracy: 0.9401 - salidas_continuas_mae: 2.6947 - val_loss: 31.7598 - val_salida_clase_accuracy: 0.9395 - val_salidas_continuas_mae: 2.9800 - learning_rate: 5.0000e-04
# Epoch 50/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 25.5096 - salida_clase_accuracy: 0.9418 - salidas_continuas_mae: 2.7042 - val_loss: 28.4637 - val_salida_clase_accuracy: 0.9423 - val_salidas_continuas_mae: 2.7467 - learning_rate: 5.0000e-04
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.4172 - salida_clase_accuracy: 0.9482 - salidas_continuas_mae: 2.6815
# Fold 1: Loss=27.070051193237305, MAE=2.69834566116333, Accuracy=0.9439811110496521
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Entrenando fold 2...
# Epoch 1/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 3882.8772 - salida_clase_accuracy: 0.1714 - salidas_continuas_mae: 38.6515 - val_loss: 520.1744 - val_salida_clase_accuracy: 0.4655 - val_salidas_continuas_mae: 13.9104 - learning_rate: 5.0000e-04
# Epoch 2/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 453.7702 - salida_clase_accuracy: 0.4936 - salidas_continuas_mae: 12.8670 - val_loss: 295.6915 - val_salida_clase_accuracy: 0.6127 - val_salidas_continuas_mae: 10.3482 - learning_rate: 5.0000e-04
# Epoch 3/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 265.7952 - salida_clase_accuracy: 0.6557 - salidas_continuas_mae: 9.6846 - val_loss: 219.4763 - val_salida_clase_accuracy: 0.7451 - val_salidas_continuas_mae: 8.6280 - learning_rate: 5.0000e-04
# Epoch 4/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 200.9955 - salida_clase_accuracy: 0.7467 - salidas_continuas_mae: 8.1668 - val_loss: 175.9465 - val_salida_clase_accuracy: 0.7687 - val_salidas_continuas_mae: 7.5839 - learning_rate: 5.0000e-04
# Epoch 5/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 162.5336 - salida_clase_accuracy: 0.7638 - salidas_continuas_mae: 7.2347 - val_loss: 150.4943 - val_salida_clase_accuracy: 0.7719 - val_salidas_continuas_mae: 6.9805 - learning_rate: 5.0000e-04
# Epoch 6/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 137.5312 - salida_clase_accuracy: 0.7867 - salidas_continuas_mae: 6.5363 - val_loss: 128.0740 - val_salida_clase_accuracy: 0.7856 - val_salidas_continuas_mae: 6.3016 - learning_rate: 5.0000e-04
# Epoch 7/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 117.8887 - salida_clase_accuracy: 0.7931 - salidas_continuas_mae: 5.9985 - val_loss: 113.6965 - val_salida_clase_accuracy: 0.7979 - val_salidas_continuas_mae: 5.9046 - learning_rate: 5.0000e-04
# Epoch 8/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 101.9311 - salida_clase_accuracy: 0.8086 - salidas_continuas_mae: 5.5632 - val_loss: 99.6978 - val_salida_clase_accuracy: 0.8252 - val_salidas_continuas_mae: 5.5193 - learning_rate: 5.0000e-04
# Epoch 9/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 92.9181 - salida_clase_accuracy: 0.8173 - salidas_continuas_mae: 5.3052 - val_loss: 89.0481 - val_salida_clase_accuracy: 0.8235 - val_salidas_continuas_mae: 5.1760 - learning_rate: 5.0000e-04
# Epoch 10/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 82.2130 - salida_clase_accuracy: 0.8317 - salidas_continuas_mae: 4.9764 - val_loss: 80.4540 - val_salida_clase_accuracy: 0.8367 - val_salidas_continuas_mae: 4.9094 - learning_rate: 5.0000e-04
# Epoch 11/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 74.4865 - salida_clase_accuracy: 0.8434 - salidas_continuas_mae: 4.7406 - val_loss: 76.0681 - val_salida_clase_accuracy: 0.8560 - val_salidas_continuas_mae: 4.7739 - learning_rate: 5.0000e-04
# Epoch 12/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 71.4913 - salida_clase_accuracy: 0.8492 - salidas_continuas_mae: 4.6344 - val_loss: 69.6225 - val_salida_clase_accuracy: 0.8605 - val_salidas_continuas_mae: 4.5159 - learning_rate: 5.0000e-04
# Epoch 13/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 64.5455 - salida_clase_accuracy: 0.8627 - salidas_continuas_mae: 4.3979 - val_loss: 65.4061 - val_salida_clase_accuracy: 0.8676 - val_salidas_continuas_mae: 4.4062 - learning_rate: 5.0000e-04
# Epoch 14/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 61.2829 - salida_clase_accuracy: 0.8668 - salidas_continuas_mae: 4.2643 - val_loss: 63.5702 - val_salida_clase_accuracy: 0.8606 - val_salidas_continuas_mae: 4.3854 - learning_rate: 5.0000e-04
# Epoch 15/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 57.5441 - salida_clase_accuracy: 0.8663 - salidas_continuas_mae: 4.1416 - val_loss: 60.7313 - val_salida_clase_accuracy: 0.8685 - val_salidas_continuas_mae: 4.2077 - learning_rate: 5.0000e-04
# Epoch 16/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 54.9858 - salida_clase_accuracy: 0.8776 - salidas_continuas_mae: 4.0390 - val_loss: 56.1843 - val_salida_clase_accuracy: 0.8754 - val_salidas_continuas_mae: 4.0444 - learning_rate: 5.0000e-04
# Epoch 17/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 52.4906 - salida_clase_accuracy: 0.8804 - salidas_continuas_mae: 3.9476 - val_loss: 53.2798 - val_salida_clase_accuracy: 0.8752 - val_salidas_continuas_mae: 3.9357 - learning_rate: 5.0000e-04
# Epoch 18/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 49.7422 - salida_clase_accuracy: 0.8789 - salidas_continuas_mae: 3.8268 - val_loss: 53.2938 - val_salida_clase_accuracy: 0.8751 - val_salidas_continuas_mae: 3.9571 - learning_rate: 5.0000e-04
# Epoch 19/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 47.6631 - salida_clase_accuracy: 0.8845 - salidas_continuas_mae: 3.7545 - val_loss: 51.7019 - val_salida_clase_accuracy: 0.8909 - val_salidas_continuas_mae: 3.8947 - learning_rate: 5.0000e-04
# Epoch 20/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 46.8145 - salida_clase_accuracy: 0.8879 - salidas_continuas_mae: 3.7165 - val_loss: 49.3394 - val_salida_clase_accuracy: 0.8902 - val_salidas_continuas_mae: 3.8088 - learning_rate: 5.0000e-04
# Epoch 21/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 45.3844 - salida_clase_accuracy: 0.8862 - salidas_continuas_mae: 3.6291 - val_loss: 50.3997 - val_salida_clase_accuracy: 0.8883 - val_salidas_continuas_mae: 3.8463 - learning_rate: 5.0000e-04
# Epoch 22/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 43.4191 - salida_clase_accuracy: 0.8824 - salidas_continuas_mae: 3.5583 - val_loss: 47.6459 - val_salida_clase_accuracy: 0.8853 - val_salidas_continuas_mae: 3.7106 - learning_rate: 5.0000e-04
# Epoch 23/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 41.9193 - salida_clase_accuracy: 0.8921 - salidas_continuas_mae: 3.4986 - val_loss: 45.6373 - val_salida_clase_accuracy: 0.8994 - val_salidas_continuas_mae: 3.6487 - learning_rate: 5.0000e-04
# Epoch 24/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 41.2046 - salida_clase_accuracy: 0.8907 - salidas_continuas_mae: 3.4376 - val_loss: 44.2151 - val_salida_clase_accuracy: 0.9013 - val_salidas_continuas_mae: 3.5621 - learning_rate: 5.0000e-04
# Epoch 25/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 39.8207 - salida_clase_accuracy: 0.8951 - salidas_continuas_mae: 3.3844 - val_loss: 43.1389 - val_salida_clase_accuracy: 0.8917 - val_salidas_continuas_mae: 3.5017 - learning_rate: 5.0000e-04
# Epoch 26/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 38.2896 - salida_clase_accuracy: 0.8946 - salidas_continuas_mae: 3.3352 - val_loss: 41.8856 - val_salida_clase_accuracy: 0.8954 - val_salidas_continuas_mae: 3.4352 - learning_rate: 5.0000e-04
# Epoch 27/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 38.1228 - salida_clase_accuracy: 0.8954 - salidas_continuas_mae: 3.3215 - val_loss: 40.6892 - val_salida_clase_accuracy: 0.9015 - val_salidas_continuas_mae: 3.3653 - learning_rate: 5.0000e-04
# Epoch 28/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 37.3651 - salida_clase_accuracy: 0.8988 - salidas_continuas_mae: 3.2856 - val_loss: 39.9676 - val_salida_clase_accuracy: 0.9072 - val_salidas_continuas_mae: 3.3409 - learning_rate: 5.0000e-04
# Epoch 29/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 35.9765 - salida_clase_accuracy: 0.8987 - salidas_continuas_mae: 3.2211 - val_loss: 39.5748 - val_salida_clase_accuracy: 0.9053 - val_salidas_continuas_mae: 3.3055 - learning_rate: 5.0000e-04
# Epoch 30/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 35.5489 - salida_clase_accuracy: 0.9020 - salidas_continuas_mae: 3.1939 - val_loss: 39.2314 - val_salida_clase_accuracy: 0.9010 - val_salidas_continuas_mae: 3.3026 - learning_rate: 5.0000e-04
# Epoch 31/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.9016 - salida_clase_accuracy: 0.9006 - salidas_continuas_mae: 3.1596 - val_loss: 39.0107 - val_salida_clase_accuracy: 0.9006 - val_salidas_continuas_mae: 3.3051 - learning_rate: 5.0000e-04
# Epoch 32/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.0126 - salida_clase_accuracy: 0.9008 - salidas_continuas_mae: 3.1238 - val_loss: 38.4681 - val_salida_clase_accuracy: 0.8944 - val_salidas_continuas_mae: 3.2565 - learning_rate: 5.0000e-04
# Epoch 33/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.1369 - salida_clase_accuracy: 0.9026 - salidas_continuas_mae: 3.0860 - val_loss: 37.6633 - val_salida_clase_accuracy: 0.9128 - val_salidas_continuas_mae: 3.2417 - learning_rate: 5.0000e-04
# Epoch 34/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.3528 - salida_clase_accuracy: 0.9039 - salidas_continuas_mae: 3.1008 - val_loss: 36.6434 - val_salida_clase_accuracy: 0.9152 - val_salidas_continuas_mae: 3.1761 - learning_rate: 5.0000e-04
# Epoch 35/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 31.7277 - salida_clase_accuracy: 0.9101 - salidas_continuas_mae: 2.9979 - val_loss: 36.6347 - val_salida_clase_accuracy: 0.9013 - val_salidas_continuas_mae: 3.1782 - learning_rate: 5.0000e-04
# Epoch 36/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 32.0574 - salida_clase_accuracy: 0.9085 - salidas_continuas_mae: 3.0109 - val_loss: 35.5628 - val_salida_clase_accuracy: 0.9119 - val_salidas_continuas_mae: 3.1401 - learning_rate: 5.0000e-04
# Epoch 37/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 31.1040 - salida_clase_accuracy: 0.9090 - salidas_continuas_mae: 2.9846 - val_loss: 35.1329 - val_salida_clase_accuracy: 0.9051 - val_salidas_continuas_mae: 3.1036 - learning_rate: 5.0000e-04
# Epoch 38/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 30.9127 - salida_clase_accuracy: 0.9088 - salidas_continuas_mae: 2.9768 - val_loss: 34.6330 - val_salida_clase_accuracy: 0.9116 - val_salidas_continuas_mae: 3.0936 - learning_rate: 5.0000e-04
# Epoch 39/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 31.0103 - salida_clase_accuracy: 0.9055 - salidas_continuas_mae: 2.9744 - val_loss: 35.9950 - val_salida_clase_accuracy: 0.9096 - val_salidas_continuas_mae: 3.1490 - learning_rate: 5.0000e-04
# Epoch 40/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 29.7721 - salida_clase_accuracy: 0.9123 - salidas_continuas_mae: 2.9082 - val_loss: 33.7808 - val_salida_clase_accuracy: 0.8999 - val_salidas_continuas_mae: 3.0470 - learning_rate: 5.0000e-04
# Epoch 41/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 30.0795 - salida_clase_accuracy: 0.9068 - salidas_continuas_mae: 2.9122 - val_loss: 34.3588 - val_salida_clase_accuracy: 0.9131 - val_salidas_continuas_mae: 3.0788 - learning_rate: 5.0000e-04
# Epoch 42/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 29.7525 - salida_clase_accuracy: 0.9119 - salidas_continuas_mae: 2.9015 - val_loss: 33.3846 - val_salida_clase_accuracy: 0.9166 - val_salidas_continuas_mae: 3.0361 - learning_rate: 5.0000e-04
# Epoch 43/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 28.7241 - salida_clase_accuracy: 0.9165 - salidas_continuas_mae: 2.8656 - val_loss: 32.8868 - val_salida_clase_accuracy: 0.9169 - val_salidas_continuas_mae: 3.0167 - learning_rate: 5.0000e-04
# Epoch 44/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 28.1234 - salida_clase_accuracy: 0.9167 - salidas_continuas_mae: 2.8294 - val_loss: 31.3835 - val_salida_clase_accuracy: 0.9176 - val_salidas_continuas_mae: 2.9261 - learning_rate: 5.0000e-04
# Epoch 45/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.9818 - salida_clase_accuracy: 0.9157 - salidas_continuas_mae: 2.8054 - val_loss: 31.9659 - val_salida_clase_accuracy: 0.9171 - val_salidas_continuas_mae: 2.9827 - learning_rate: 5.0000e-04
# Epoch 46/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.8856 - salida_clase_accuracy: 0.9200 - salidas_continuas_mae: 2.8078 - val_loss: 32.4747 - val_salida_clase_accuracy: 0.9197 - val_salidas_continuas_mae: 3.0028 - learning_rate: 5.0000e-04
# Epoch 47/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.9461 - salida_clase_accuracy: 0.9162 - salidas_continuas_mae: 2.8115 - val_loss: 31.3032 - val_salida_clase_accuracy: 0.9197 - val_salidas_continuas_mae: 2.9245 - learning_rate: 5.0000e-04
# Epoch 48/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.6634 - salida_clase_accuracy: 0.9198 - salidas_continuas_mae: 2.7385 - val_loss: 32.7846 - val_salida_clase_accuracy: 0.9222 - val_salidas_continuas_mae: 3.0371 - learning_rate: 5.0000e-04
# Epoch 49/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.8636 - salida_clase_accuracy: 0.9245 - salidas_continuas_mae: 2.7615 - val_loss: 30.7482 - val_salida_clase_accuracy: 0.9055 - val_salidas_continuas_mae: 2.9025 - learning_rate: 5.0000e-04
# Epoch 50/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.1175 - salida_clase_accuracy: 0.9224 - salidas_continuas_mae: 2.7209 - val_loss: 30.4394 - val_salida_clase_accuracy: 0.9168 - val_salidas_continuas_mae: 2.8994 - learning_rate: 5.0000e-04
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.5691 - salida_clase_accuracy: 0.9238 - salidas_continuas_mae: 2.7899
# Fold 2: Loss=28.346067428588867, MAE=2.815603017807007, Accuracy=0.9200722575187683
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Entrenando fold 3...
# Epoch 1/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 3707.1567 - salida_clase_accuracy: 0.2977 - salidas_continuas_mae: 37.4976 - val_loss: 469.3817 - val_salida_clase_accuracy: 0.5457 - val_salidas_continuas_mae: 13.1863 - learning_rate: 5.0000e-04
# Epoch 2/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 408.3592 - salida_clase_accuracy: 0.5477 - salidas_continuas_mae: 12.1334 - val_loss: 274.9735 - val_salida_clase_accuracy: 0.6917 - val_salidas_continuas_mae: 9.7224 - learning_rate: 5.0000e-04
# Epoch 3/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 254.2231 - salida_clase_accuracy: 0.6835 - salidas_continuas_mae: 9.3805 - val_loss: 200.2299 - val_salida_clase_accuracy: 0.7477 - val_salidas_continuas_mae: 8.0948 - learning_rate: 5.0000e-04
# Epoch 4/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 190.7665 - salida_clase_accuracy: 0.7413 - salidas_continuas_mae: 7.9142 - val_loss: 159.0635 - val_salida_clase_accuracy: 0.7675 - val_salidas_continuas_mae: 7.0351 - learning_rate: 5.0000e-04
# Epoch 5/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 151.0571 - salida_clase_accuracy: 0.7699 - salidas_continuas_mae: 6.9420 - val_loss: 134.9284 - val_salida_clase_accuracy: 0.8003 - val_salidas_continuas_mae: 6.4869 - learning_rate: 5.0000e-04
# Epoch 6/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 127.3314 - salida_clase_accuracy: 0.7906 - salidas_continuas_mae: 6.3190 - val_loss: 117.0074 - val_salida_clase_accuracy: 0.8090 - val_salidas_continuas_mae: 6.0288 - learning_rate: 5.0000e-04
# Epoch 7/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 110.8483 - salida_clase_accuracy: 0.8090 - salidas_continuas_mae: 5.8394 - val_loss: 99.9944 - val_salida_clase_accuracy: 0.8292 - val_salidas_continuas_mae: 5.4845 - learning_rate: 5.0000e-04
# Epoch 8/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 94.3424 - salida_clase_accuracy: 0.8276 - salidas_continuas_mae: 5.3618 - val_loss: 86.8156 - val_salida_clase_accuracy: 0.8384 - val_salidas_continuas_mae: 5.0562 - learning_rate: 5.0000e-04
# Epoch 9/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 85.5178 - salida_clase_accuracy: 0.8485 - salidas_continuas_mae: 5.0954 - val_loss: 78.1706 - val_salida_clase_accuracy: 0.8544 - val_salidas_continuas_mae: 4.8158 - learning_rate: 5.0000e-04
# Epoch 10/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 75.8733 - salida_clase_accuracy: 0.8602 - salidas_continuas_mae: 4.8095 - val_loss: 73.7032 - val_salida_clase_accuracy: 0.8796 - val_salidas_continuas_mae: 4.7210 - learning_rate: 5.0000e-04
# Epoch 11/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 68.4793 - salida_clase_accuracy: 0.8689 - salidas_continuas_mae: 4.5519 - val_loss: 68.2248 - val_salida_clase_accuracy: 0.8942 - val_salidas_continuas_mae: 4.5493 - learning_rate: 5.0000e-04
# Epoch 12/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 64.6220 - salida_clase_accuracy: 0.8775 - salidas_continuas_mae: 4.4348 - val_loss: 62.3638 - val_salida_clase_accuracy: 0.8966 - val_salidas_continuas_mae: 4.3146 - learning_rate: 5.0000e-04
# Epoch 13/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 61.3910 - salida_clase_accuracy: 0.8785 - salidas_continuas_mae: 4.3102 - val_loss: 57.9653 - val_salida_clase_accuracy: 0.8975 - val_salidas_continuas_mae: 4.1298 - learning_rate: 5.0000e-04
# Epoch 14/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 54.6055 - salida_clase_accuracy: 0.8855 - salidas_continuas_mae: 4.0755 - val_loss: 58.6960 - val_salida_clase_accuracy: 0.8982 - val_salidas_continuas_mae: 4.2851 - learning_rate: 5.0000e-04
# Epoch 15/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 53.1200 - salida_clase_accuracy: 0.8918 - salidas_continuas_mae: 3.9934 - val_loss: 52.5965 - val_salida_clase_accuracy: 0.9004 - val_salidas_continuas_mae: 3.9476 - learning_rate: 5.0000e-04
# Epoch 16/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 50.5965 - salida_clase_accuracy: 0.8892 - salidas_continuas_mae: 3.8858 - val_loss: 49.5923 - val_salida_clase_accuracy: 0.9002 - val_salidas_continuas_mae: 3.8147 - learning_rate: 5.0000e-04
# Epoch 17/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 49.5047 - salida_clase_accuracy: 0.8975 - salidas_continuas_mae: 3.8392 - val_loss: 49.2709 - val_salida_clase_accuracy: 0.9107 - val_salidas_continuas_mae: 3.8383 - learning_rate: 5.0000e-04
# Epoch 18/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 45.6699 - salida_clase_accuracy: 0.9035 - salidas_continuas_mae: 3.6980 - val_loss: 48.0739 - val_salida_clase_accuracy: 0.9150 - val_salidas_continuas_mae: 3.8364 - learning_rate: 5.0000e-04
# Epoch 19/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 45.1555 - salida_clase_accuracy: 0.9054 - salidas_continuas_mae: 3.6637 - val_loss: 45.0660 - val_salida_clase_accuracy: 0.9131 - val_salidas_continuas_mae: 3.6318 - learning_rate: 5.0000e-04
# Epoch 20/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 43.6649 - salida_clase_accuracy: 0.9062 - salidas_continuas_mae: 3.5785 - val_loss: 42.3507 - val_salida_clase_accuracy: 0.9164 - val_salidas_continuas_mae: 3.4911 - learning_rate: 5.0000e-04
# Epoch 21/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 42.0161 - salida_clase_accuracy: 0.9090 - salidas_continuas_mae: 3.5255 - val_loss: 42.2168 - val_salida_clase_accuracy: 0.9192 - val_salidas_continuas_mae: 3.4895 - learning_rate: 5.0000e-04
# Epoch 22/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 40.7247 - salida_clase_accuracy: 0.9119 - salidas_continuas_mae: 3.4502 - val_loss: 41.3012 - val_salida_clase_accuracy: 0.9201 - val_salidas_continuas_mae: 3.4797 - learning_rate: 5.0000e-04
# Epoch 23/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 40.1636 - salida_clase_accuracy: 0.9129 - salidas_continuas_mae: 3.4217 - val_loss: 39.1885 - val_salida_clase_accuracy: 0.9247 - val_salidas_continuas_mae: 3.3668 - learning_rate: 5.0000e-04
# Epoch 24/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 38.8408 - salida_clase_accuracy: 0.9149 - salidas_continuas_mae: 3.3578 - val_loss: 40.1863 - val_salida_clase_accuracy: 0.9140 - val_salidas_continuas_mae: 3.4662 - learning_rate: 5.0000e-04
# Epoch 25/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 37.6026 - salida_clase_accuracy: 0.9183 - salidas_continuas_mae: 3.3147 - val_loss: 39.0197 - val_salida_clase_accuracy: 0.9206 - val_salidas_continuas_mae: 3.3444 - learning_rate: 5.0000e-04
# Epoch 26/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 37.7440 - salida_clase_accuracy: 0.9184 - salidas_continuas_mae: 3.3174 - val_loss: 38.7002 - val_salida_clase_accuracy: 0.9310 - val_salidas_continuas_mae: 3.3707 - learning_rate: 5.0000e-04
# Epoch 27/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 35.2954 - salida_clase_accuracy: 0.9241 - salidas_continuas_mae: 3.2002 - val_loss: 38.4672 - val_salida_clase_accuracy: 0.9275 - val_salidas_continuas_mae: 3.3198 - learning_rate: 5.0000e-04
# Epoch 28/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.1287 - salida_clase_accuracy: 0.9273 - salidas_continuas_mae: 3.1517 - val_loss: 35.8943 - val_salida_clase_accuracy: 0.9237 - val_salidas_continuas_mae: 3.2364 - learning_rate: 5.0000e-04
# Epoch 29/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 34.1120 - salida_clase_accuracy: 0.9233 - salidas_continuas_mae: 3.1408 - val_loss: 36.3353 - val_salida_clase_accuracy: 0.9310 - val_salidas_continuas_mae: 3.2696 - learning_rate: 5.0000e-04
# Epoch 30/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.0486 - salida_clase_accuracy: 0.9255 - salidas_continuas_mae: 3.0872 - val_loss: 34.8401 - val_salida_clase_accuracy: 0.9371 - val_salidas_continuas_mae: 3.1211 - learning_rate: 5.0000e-04
# Epoch 31/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 32.9375 - salida_clase_accuracy: 0.9275 - salidas_continuas_mae: 3.0734 - val_loss: 33.5507 - val_salida_clase_accuracy: 0.9249 - val_salidas_continuas_mae: 3.1052 - learning_rate: 5.0000e-04
# Epoch 32/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 32.3833 - salida_clase_accuracy: 0.9241 - salidas_continuas_mae: 3.0437 - val_loss: 32.7172 - val_salida_clase_accuracy: 0.9348 - val_salidas_continuas_mae: 3.0698 - learning_rate: 5.0000e-04
# Epoch 33/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31.0939 - salida_clase_accuracy: 0.9293 - salidas_continuas_mae: 2.9877 - val_loss: 33.0597 - val_salida_clase_accuracy: 0.9317 - val_salidas_continuas_mae: 3.0954 - learning_rate: 5.0000e-04
# Epoch 34/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31.3102 - salida_clase_accuracy: 0.9314 - salidas_continuas_mae: 2.9842 - val_loss: 32.0789 - val_salida_clase_accuracy: 0.9331 - val_salidas_continuas_mae: 2.9969 - learning_rate: 5.0000e-04
# Epoch 35/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 29.9759 - salida_clase_accuracy: 0.9337 - salidas_continuas_mae: 2.9265 - val_loss: 32.0999 - val_salida_clase_accuracy: 0.9293 - val_salidas_continuas_mae: 3.0057 - learning_rate: 5.0000e-04
# Epoch 36/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 29.4510 - salida_clase_accuracy: 0.9329 - salidas_continuas_mae: 2.9164 - val_loss: 30.8305 - val_salida_clase_accuracy: 0.9088 - val_salidas_continuas_mae: 2.9181 - learning_rate: 5.0000e-04
# Epoch 37/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 29.1449 - salida_clase_accuracy: 0.9338 - salidas_continuas_mae: 2.8757 - val_loss: 31.0619 - val_salida_clase_accuracy: 0.9308 - val_salidas_continuas_mae: 2.9642 - learning_rate: 5.0000e-04
# Epoch 38/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 29.0784 - salida_clase_accuracy: 0.9351 - salidas_continuas_mae: 2.8710 - val_loss: 29.6265 - val_salida_clase_accuracy: 0.9432 - val_salidas_continuas_mae: 2.8683 - learning_rate: 5.0000e-04
# Epoch 39/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 28.2259 - salida_clase_accuracy: 0.9367 - salidas_continuas_mae: 2.8260 - val_loss: 30.5303 - val_salida_clase_accuracy: 0.9426 - val_salidas_continuas_mae: 2.9515 - learning_rate: 5.0000e-04
# Epoch 40/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 28.6869 - salida_clase_accuracy: 0.9348 - salidas_continuas_mae: 2.8430 - val_loss: 28.7023 - val_salida_clase_accuracy: 0.9437 - val_salidas_continuas_mae: 2.8195 - learning_rate: 5.0000e-04
# Epoch 41/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.3651 - salida_clase_accuracy: 0.9370 - salidas_continuas_mae: 2.7906 - val_loss: 29.6072 - val_salida_clase_accuracy: 0.9340 - val_salidas_continuas_mae: 2.8558 - learning_rate: 5.0000e-04
# Epoch 42/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.9292 - salida_clase_accuracy: 0.9360 - salidas_continuas_mae: 2.8011 - val_loss: 28.7051 - val_salida_clase_accuracy: 0.9414 - val_salidas_continuas_mae: 2.8286 - learning_rate: 5.0000e-04
# Epoch 43/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.0233 - salida_clase_accuracy: 0.9396 - salidas_continuas_mae: 2.7604 - val_loss: 28.3367 - val_salida_clase_accuracy: 0.9465 - val_salidas_continuas_mae: 2.8166 - learning_rate: 5.0000e-04
# Epoch 44/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.1934 - salida_clase_accuracy: 0.9391 - salidas_continuas_mae: 2.7236 - val_loss: 30.4241 - val_salida_clase_accuracy: 0.9460 - val_salidas_continuas_mae: 2.8910 - learning_rate: 5.0000e-04
# Epoch 45/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.5849 - salida_clase_accuracy: 0.9402 - salidas_continuas_mae: 2.7360 - val_loss: 28.1680 - val_salida_clase_accuracy: 0.9470 - val_salidas_continuas_mae: 2.7813 - learning_rate: 5.0000e-04
# Epoch 46/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 25.8449 - salida_clase_accuracy: 0.9389 - salidas_continuas_mae: 2.6892 - val_loss: 27.6894 - val_salida_clase_accuracy: 0.9437 - val_salidas_continuas_mae: 2.7843 - learning_rate: 5.0000e-04
# Epoch 47/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 25.7324 - salida_clase_accuracy: 0.9394 - salidas_continuas_mae: 2.6820 - val_loss: 28.1472 - val_salida_clase_accuracy: 0.9418 - val_salidas_continuas_mae: 2.7695 - learning_rate: 5.0000e-04
# Epoch 48/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 25.2489 - salida_clase_accuracy: 0.9453 - salidas_continuas_mae: 2.6618 - val_loss: 26.5201 - val_salida_clase_accuracy: 0.9460 - val_salidas_continuas_mae: 2.6718 - learning_rate: 5.0000e-04
# Epoch 49/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 24.8419 - salida_clase_accuracy: 0.9407 - salidas_continuas_mae: 2.6293 - val_loss: 24.9159 - val_salida_clase_accuracy: 0.9546 - val_salidas_continuas_mae: 2.5924 - learning_rate: 5.0000e-04
# Epoch 50/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 24.1251 - salida_clase_accuracy: 0.9445 - salidas_continuas_mae: 2.6046 - val_loss: 25.9236 - val_salida_clase_accuracy: 0.9482 - val_salidas_continuas_mae: 2.6490 - learning_rate: 5.0000e-04
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.0929 - salida_clase_accuracy: 0.9593 - salidas_continuas_mae: 2.5533
# Fold 3: Loss=24.66103744506836, MAE=2.5722007751464844, Accuracy=0.9549624919891357
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Entrenando fold 4...
# Epoch 1/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 3562.0586 - salida_clase_accuracy: 0.2743 - salidas_continuas_mae: 35.8656 - val_loss: 447.1530 - val_salida_clase_accuracy: 0.5535 - val_salidas_continuas_mae: 12.6484 - learning_rate: 5.0000e-04
# Epoch 2/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 382.1581 - salida_clase_accuracy: 0.6267 - salidas_continuas_mae: 11.6511 - val_loss: 277.3465 - val_salida_clase_accuracy: 0.6903 - val_salidas_continuas_mae: 9.6440 - learning_rate: 5.0000e-04
# Epoch 3/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 250.8158 - salida_clase_accuracy: 0.6819 - salidas_continuas_mae: 9.1492 - val_loss: 205.9051 - val_salida_clase_accuracy: 0.7004 - val_salidas_continuas_mae: 8.1035 - learning_rate: 5.0000e-04
# Epoch 4/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 187.4045 - salida_clase_accuracy: 0.7066 - salidas_continuas_mae: 7.7876 - val_loss: 164.9565 - val_salida_clase_accuracy: 0.7344 - val_salidas_continuas_mae: 7.2040 - learning_rate: 5.0000e-04
# Epoch 5/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 150.2662 - salida_clase_accuracy: 0.7227 - salidas_continuas_mae: 6.8580 - val_loss: 136.5715 - val_salida_clase_accuracy: 0.7596 - val_salidas_continuas_mae: 6.3549 - learning_rate: 5.0000e-04
# Epoch 6/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 127.7522 - salida_clase_accuracy: 0.7677 - salidas_continuas_mae: 6.2208 - val_loss: 115.6936 - val_salida_clase_accuracy: 0.7845 - val_salidas_continuas_mae: 5.8663 - learning_rate: 5.0000e-04
# Epoch 7/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 110.5149 - salida_clase_accuracy: 0.7932 - salidas_continuas_mae: 5.7484 - val_loss: 99.8399 - val_salida_clase_accuracy: 0.8054 - val_salidas_continuas_mae: 5.3890 - learning_rate: 5.0000e-04
# Epoch 8/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 96.2410 - salida_clase_accuracy: 0.7998 - salidas_continuas_mae: 5.3556 - val_loss: 87.1346 - val_salida_clase_accuracy: 0.8012 - val_salidas_continuas_mae: 5.0331 - learning_rate: 5.0000e-04
# Epoch 9/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 84.7999 - salida_clase_accuracy: 0.8135 - salidas_continuas_mae: 5.0175 - val_loss: 76.8961 - val_salida_clase_accuracy: 0.8149 - val_salidas_continuas_mae: 4.7075 - learning_rate: 5.0000e-04
# Epoch 10/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 73.6849 - salida_clase_accuracy: 0.8250 - salidas_continuas_mae: 4.6832 - val_loss: 68.7856 - val_salida_clase_accuracy: 0.8344 - val_salidas_continuas_mae: 4.4634 - learning_rate: 5.0000e-04
# Epoch 11/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 65.0872 - salida_clase_accuracy: 0.8364 - salidas_continuas_mae: 4.4135 - val_loss: 62.7457 - val_salida_clase_accuracy: 0.8542 - val_salidas_continuas_mae: 4.2941 - learning_rate: 5.0000e-04
# Epoch 12/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 60.9001 - salida_clase_accuracy: 0.8539 - salidas_continuas_mae: 4.2578 - val_loss: 57.5210 - val_salida_clase_accuracy: 0.8493 - val_salidas_continuas_mae: 4.0844 - learning_rate: 5.0000e-04
# Epoch 13/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 56.7568 - salida_clase_accuracy: 0.8650 - salidas_continuas_mae: 4.0954 - val_loss: 56.9170 - val_salida_clase_accuracy: 0.8705 - val_salidas_continuas_mae: 4.1002 - learning_rate: 5.0000e-04
# Epoch 14/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 53.9199 - salida_clase_accuracy: 0.8770 - salidas_continuas_mae: 3.9897 - val_loss: 51.4735 - val_salida_clase_accuracy: 0.8849 - val_salidas_continuas_mae: 3.8760 - learning_rate: 5.0000e-04
# Epoch 15/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 49.4745 - salida_clase_accuracy: 0.8853 - salidas_continuas_mae: 3.8263 - val_loss: 49.1920 - val_salida_clase_accuracy: 0.8886 - val_salidas_continuas_mae: 3.7743 - learning_rate: 5.0000e-04
# Epoch 16/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 46.8149 - salida_clase_accuracy: 0.8965 - salidas_continuas_mae: 3.7237 - val_loss: 47.0743 - val_salida_clase_accuracy: 0.8924 - val_salidas_continuas_mae: 3.6773 - learning_rate: 5.0000e-04
# Epoch 17/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 45.8394 - salida_clase_accuracy: 0.8910 - salidas_continuas_mae: 3.6772 - val_loss: 44.7555 - val_salida_clase_accuracy: 0.8962 - val_salidas_continuas_mae: 3.5840 - learning_rate: 5.0000e-04
# Epoch 18/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 44.1923 - salida_clase_accuracy: 0.8991 - salidas_continuas_mae: 3.6109 - val_loss: 45.3238 - val_salida_clase_accuracy: 0.8936 - val_salidas_continuas_mae: 3.6398 - learning_rate: 5.0000e-04
# Epoch 19/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 42.8854 - salida_clase_accuracy: 0.8980 - salidas_continuas_mae: 3.5414 - val_loss: 43.0118 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 3.5091 - learning_rate: 5.0000e-04
# Epoch 20/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 40.3026 - salida_clase_accuracy: 0.8996 - salidas_continuas_mae: 3.4293 - val_loss: 44.0102 - val_salida_clase_accuracy: 0.9034 - val_salidas_continuas_mae: 3.5969 - learning_rate: 5.0000e-04
# Epoch 21/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 40.1726 - salida_clase_accuracy: 0.9087 - salidas_continuas_mae: 3.4229 - val_loss: 40.8120 - val_salida_clase_accuracy: 0.8862 - val_salidas_continuas_mae: 3.4280 - learning_rate: 5.0000e-04
# Epoch 22/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 38.5944 - salida_clase_accuracy: 0.9095 - salidas_continuas_mae: 3.3697 - val_loss: 39.2275 - val_salida_clase_accuracy: 0.9030 - val_salidas_continuas_mae: 3.3603 - learning_rate: 5.0000e-04
# Epoch 23/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 37.6803 - salida_clase_accuracy: 0.9099 - salidas_continuas_mae: 3.3179 - val_loss: 38.4282 - val_salida_clase_accuracy: 0.9108 - val_salidas_continuas_mae: 3.3120 - learning_rate: 5.0000e-04
# Epoch 24/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.7247 - salida_clase_accuracy: 0.9126 - salidas_continuas_mae: 3.2563 - val_loss: 37.8665 - val_salida_clase_accuracy: 0.9101 - val_salidas_continuas_mae: 3.2793 - learning_rate: 5.0000e-04
# Epoch 25/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 35.9019 - salida_clase_accuracy: 0.9160 - salidas_continuas_mae: 3.2256 - val_loss: 37.6228 - val_salida_clase_accuracy: 0.9161 - val_salidas_continuas_mae: 3.2735 - learning_rate: 5.0000e-04
# Epoch 26/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 35.2469 - salida_clase_accuracy: 0.9189 - salidas_continuas_mae: 3.1999 - val_loss: 37.2343 - val_salida_clase_accuracy: 0.9178 - val_salidas_continuas_mae: 3.2879 - learning_rate: 5.0000e-04
# Epoch 27/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.8422 - salida_clase_accuracy: 0.9207 - salidas_continuas_mae: 3.1773 - val_loss: 36.1844 - val_salida_clase_accuracy: 0.9195 - val_salidas_continuas_mae: 3.2077 - learning_rate: 5.0000e-04
# Epoch 28/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.2351 - salida_clase_accuracy: 0.9196 - salidas_continuas_mae: 3.1352 - val_loss: 34.9219 - val_salida_clase_accuracy: 0.9126 - val_salidas_continuas_mae: 3.1231 - learning_rate: 5.0000e-04
# Epoch 29/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 32.4925 - salida_clase_accuracy: 0.9194 - salidas_continuas_mae: 3.0594 - val_loss: 35.1892 - val_salida_clase_accuracy: 0.9256 - val_salidas_continuas_mae: 3.1406 - learning_rate: 5.0000e-04
# Epoch 30/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 32.0550 - salida_clase_accuracy: 0.9277 - salidas_continuas_mae: 3.0599 - val_loss: 35.9849 - val_salida_clase_accuracy: 0.9287 - val_salidas_continuas_mae: 3.2017 - learning_rate: 5.0000e-04
# Epoch 31/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 32.1660 - salida_clase_accuracy: 0.9249 - salidas_continuas_mae: 3.0426 - val_loss: 33.1605 - val_salida_clase_accuracy: 0.9208 - val_salidas_continuas_mae: 3.0485 - learning_rate: 5.0000e-04
# Epoch 32/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31.3265 - salida_clase_accuracy: 0.9253 - salidas_continuas_mae: 2.9924 - val_loss: 34.5852 - val_salida_clase_accuracy: 0.9268 - val_salidas_continuas_mae: 3.1560 - learning_rate: 5.0000e-04
# Epoch 33/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 30.5836 - salida_clase_accuracy: 0.9277 - salidas_continuas_mae: 2.9618 - val_loss: 33.5249 - val_salida_clase_accuracy: 0.9310 - val_salidas_continuas_mae: 3.0488 - learning_rate: 5.0000e-04
# Epoch 34/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 30.9526 - salida_clase_accuracy: 0.9303 - salidas_continuas_mae: 2.9573 - val_loss: 34.2031 - val_salida_clase_accuracy: 0.9296 - val_salidas_continuas_mae: 3.0814 - learning_rate: 5.0000e-04
# Epoch 35/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 29.9501 - salida_clase_accuracy: 0.9301 - salidas_continuas_mae: 2.9182 - val_loss: 32.0237 - val_salida_clase_accuracy: 0.9322 - val_salidas_continuas_mae: 2.9861 - learning_rate: 5.0000e-04
# Epoch 36/50
# ...
# Epoch 41/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.1254 - salida_clase_accuracy: 0.9410 - salidas_continuas_mae: 2.7620 - val_loss: 28.8957 - val_salida_clase_accuracy: 0.9362 - val_salidas_continuas_mae: 2.8255 - learning_rate: 5.0000e-04
# Epoch 42/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.4776 - salida_clase_accuracy: 0.9411 - salidas_continuas_mae: 2.7728 - val_loss: 28.1891 - val_salida_clase_accuracy: 0.9407 - val_salidas_continuas_mae: 2.7537 - learning_rate: 5.0000e-04
# Epoch 43/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.0793 - salida_clase_accuracy: 0.9384 - salidas_continuas_mae: 2.7540 - val_loss: 28.1204 - val_salida_clase_accuracy: 0.9314 - val_salidas_continuas_mae: 2.7548 - learning_rate: 5.0000e-04
# Epoch 44/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.3904 - salida_clase_accuracy: 0.9381 - salidas_continuas_mae: 2.7578 - val_loss: 29.2487 - val_salida_clase_accuracy: 0.9383 - val_salidas_continuas_mae: 2.8663 - learning_rate: 5.0000e-04
# Epoch 45/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.2683 - salida_clase_accuracy: 0.9414 - salidas_continuas_mae: 2.7193 - val_loss: 27.8553 - val_salida_clase_accuracy: 0.9329 - val_salidas_continuas_mae: 2.7768 - learning_rate: 5.0000e-04
# Epoch 46/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.0890 - salida_clase_accuracy: 0.9424 - salidas_continuas_mae: 2.6937 - val_loss: 27.5012 - val_salida_clase_accuracy: 0.9430 - val_salidas_continuas_mae: 2.7595 - learning_rate: 5.0000e-04
# Epoch 47/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 25.1946 - salida_clase_accuracy: 0.9423 - salidas_continuas_mae: 2.6669 - val_loss: 26.8169 - val_salida_clase_accuracy: 0.9430 - val_salidas_continuas_mae: 2.6915 - learning_rate: 5.0000e-04
# Epoch 48/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 24.3697 - salida_clase_accuracy: 0.9486 - salidas_continuas_mae: 2.6232 - val_loss: 25.8170 - val_salida_clase_accuracy: 0.9447 - val_salidas_continuas_mae: 2.6275 - learning_rate: 5.0000e-04
# Epoch 49/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 25.1645 - salida_clase_accuracy: 0.9413 - salidas_continuas_mae: 2.6496 - val_loss: 26.6091 - val_salida_clase_accuracy: 0.9400 - val_salidas_continuas_mae: 2.7128 - learning_rate: 5.0000e-04
# Epoch 50/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 24.5572 - salida_clase_accuracy: 0.9434 - salidas_continuas_mae: 2.6222 - val_loss: 26.2290 - val_salida_clase_accuracy: 0.9390 - val_salidas_continuas_mae: 2.6701 - learning_rate: 5.0000e-04
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.3457 - salida_clase_accuracy: 0.9524 - salidas_continuas_mae: 2.6015
# Fold 4: Loss=25.812631607055664, MAE=2.609164237976074, Accuracy=0.9503753185272217
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Entrenando fold 5...
# Epoch 1/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 3374.8120 - salida_clase_accuracy: 0.3642 - salidas_continuas_mae: 34.8787 - val_loss: 471.7371 - val_salida_clase_accuracy: 0.6349 - val_salidas_continuas_mae: 13.0624 - learning_rate: 5.0000e-04
# Epoch 2/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 407.4062 - salida_clase_accuracy: 0.6593 - salidas_continuas_mae: 12.0698 - val_loss: 270.8446 - val_salida_clase_accuracy: 0.6700 - val_salidas_continuas_mae: 9.4796 - learning_rate: 5.0000e-04
# Epoch 3/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 244.9606 - salida_clase_accuracy: 0.6829 - salidas_continuas_mae: 9.0489 - val_loss: 190.7094 - val_salida_clase_accuracy: 0.7148 - val_salidas_continuas_mae: 7.7998 - learning_rate: 5.0000e-04
# Epoch 4/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 178.0580 - salida_clase_accuracy: 0.7424 - salidas_continuas_mae: 7.5331 - val_loss: 147.9397 - val_salida_clase_accuracy: 0.7920 - val_salidas_continuas_mae: 6.7606 - learning_rate: 5.0000e-04
# Epoch 5/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 145.7240 - salida_clase_accuracy: 0.7931 - salidas_continuas_mae: 6.6883 - val_loss: 126.0118 - val_salida_clase_accuracy: 0.8278 - val_salidas_continuas_mae: 6.1727 - learning_rate: 5.0000e-04
# Epoch 6/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 123.8214 - salida_clase_accuracy: 0.8189 - salidas_continuas_mae: 6.1246 - val_loss: 112.6171 - val_salida_clase_accuracy: 0.8029 - val_salidas_continuas_mae: 5.7668 - learning_rate: 5.0000e-04
# Epoch 7/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 106.6643 - salida_clase_accuracy: 0.8399 - salidas_continuas_mae: 5.6741 - val_loss: 96.7174 - val_salida_clase_accuracy: 0.8457 - val_salidas_continuas_mae: 5.4094 - learning_rate: 5.0000e-04
# Epoch 8/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 94.4092 - salida_clase_accuracy: 0.8520 - salidas_continuas_mae: 5.3437 - val_loss: 85.0912 - val_salida_clase_accuracy: 0.8264 - val_salidas_continuas_mae: 5.0447 - learning_rate: 5.0000e-04
# Epoch 9/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 83.1887 - salida_clase_accuracy: 0.8573 - salidas_continuas_mae: 5.0214 - val_loss: 79.4247 - val_salida_clase_accuracy: 0.8816 - val_salidas_continuas_mae: 4.9397 - learning_rate: 5.0000e-04
# Epoch 10/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 74.0544 - salida_clase_accuracy: 0.8718 - salidas_continuas_mae: 4.7329 - val_loss: 69.9183 - val_salida_clase_accuracy: 0.8749 - val_salidas_continuas_mae: 4.5448 - learning_rate: 5.0000e-04
# Epoch 11/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 69.3980 - salida_clase_accuracy: 0.8822 - salidas_continuas_mae: 4.5584 - val_loss: 67.4443 - val_salida_clase_accuracy: 0.8928 - val_salidas_continuas_mae: 4.5702 - learning_rate: 5.0000e-04
# Epoch 12/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 63.3881 - salida_clase_accuracy: 0.8883 - salidas_continuas_mae: 4.3730 - val_loss: 60.2558 - val_salida_clase_accuracy: 0.8827 - val_salidas_continuas_mae: 4.2153 - learning_rate: 5.0000e-04
# Epoch 13/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 59.0947 - salida_clase_accuracy: 0.8935 - salidas_continuas_mae: 4.2125 - val_loss: 55.4982 - val_salida_clase_accuracy: 0.9015 - val_salidas_continuas_mae: 4.0271 - learning_rate: 5.0000e-04
# Epoch 14/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 55.1421 - salida_clase_accuracy: 0.8965 - salidas_continuas_mae: 4.0848 - val_loss: 53.4267 - val_salida_clase_accuracy: 0.8961 - val_salidas_continuas_mae: 3.9518 - learning_rate: 5.0000e-04
# Epoch 15/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 53.8352 - salida_clase_accuracy: 0.9014 - salidas_continuas_mae: 4.0043 - val_loss: 51.3829 - val_salida_clase_accuracy: 0.8855 - val_salidas_continuas_mae: 3.8719 - learning_rate: 5.0000e-04
# Epoch 16/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 50.0411 - salida_clase_accuracy: 0.9089 - salidas_continuas_mae: 3.8503 - val_loss: 50.3867 - val_salida_clase_accuracy: 0.9065 - val_salidas_continuas_mae: 3.8400 - learning_rate: 5.0000e-04
# Epoch 17/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 47.4834 - salida_clase_accuracy: 0.9091 - salidas_continuas_mae: 3.7658 - val_loss: 47.7704 - val_salida_clase_accuracy: 0.9154 - val_salidas_continuas_mae: 3.7336 - learning_rate: 5.0000e-04
# Epoch 18/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 47.3613 - salida_clase_accuracy: 0.9117 - salidas_continuas_mae: 3.7350 - val_loss: 46.2302 - val_salida_clase_accuracy: 0.9148 - val_salidas_continuas_mae: 3.6436 - learning_rate: 5.0000e-04
# Epoch 19/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 45.6838 - salida_clase_accuracy: 0.9100 - salidas_continuas_mae: 3.6588 - val_loss: 44.4200 - val_salida_clase_accuracy: 0.9107 - val_salidas_continuas_mae: 3.5250 - learning_rate: 5.0000e-04
# Epoch 20/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 43.4449 - salida_clase_accuracy: 0.9163 - salidas_continuas_mae: 3.5694 - val_loss: 45.1712 - val_salida_clase_accuracy: 0.9227 - val_salidas_continuas_mae: 3.5923 - learning_rate: 5.0000e-04
# Epoch 21/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 42.5136 - salida_clase_accuracy: 0.9185 - salidas_continuas_mae: 3.5256 - val_loss: 41.9092 - val_salida_clase_accuracy: 0.9199 - val_salidas_continuas_mae: 3.4593 - learning_rate: 5.0000e-04
# Epoch 22/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 41.0731 - salida_clase_accuracy: 0.9189 - salidas_continuas_mae: 3.4641 - val_loss: 40.6947 - val_salida_clase_accuracy: 0.9214 - val_salidas_continuas_mae: 3.3708 - learning_rate: 5.0000e-04
# Epoch 23/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 39.9763 - salida_clase_accuracy: 0.9173 - salidas_continuas_mae: 3.4170 - val_loss: 40.5464 - val_salida_clase_accuracy: 0.9128 - val_salidas_continuas_mae: 3.3951 - learning_rate: 5.0000e-04
# Epoch 24/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 39.1921 - salida_clase_accuracy: 0.9213 - salidas_continuas_mae: 3.3763 - val_loss: 40.9636 - val_salida_clase_accuracy: 0.9228 - val_salidas_continuas_mae: 3.4077 - learning_rate: 5.0000e-04
# Epoch 25/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 38.0660 - salida_clase_accuracy: 0.9243 - salidas_continuas_mae: 3.3242 - val_loss: 37.8522 - val_salida_clase_accuracy: 0.9239 - val_salidas_continuas_mae: 3.2474 - learning_rate: 5.0000e-04
# Epoch 26/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.4527 - salida_clase_accuracy: 0.9280 - salidas_continuas_mae: 3.2485 - val_loss: 41.2293 - val_salida_clase_accuracy: 0.9291 - val_salidas_continuas_mae: 3.3958 - learning_rate: 5.0000e-04
# Epoch 27/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 37.1535 - salida_clase_accuracy: 0.9257 - salidas_continuas_mae: 3.2744 - val_loss: 36.8413 - val_salida_clase_accuracy: 0.9208 - val_salidas_continuas_mae: 3.1844 - learning_rate: 5.0000e-04
# Epoch 28/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 36.0883 - salida_clase_accuracy: 0.9293 - salidas_continuas_mae: 3.2164 - val_loss: 36.3719 - val_salida_clase_accuracy: 0.9154 - val_salidas_continuas_mae: 3.1314 - learning_rate: 5.0000e-04
# Epoch 29/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 35.3791 - salida_clase_accuracy: 0.9267 - salidas_continuas_mae: 3.1727 - val_loss: 36.7515 - val_salida_clase_accuracy: 0.9294 - val_salidas_continuas_mae: 3.2033 - learning_rate: 5.0000e-04
# Epoch 30/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.6000 - salida_clase_accuracy: 0.9282 - salidas_continuas_mae: 3.1675 - val_loss: 34.8633 - val_salida_clase_accuracy: 0.9310 - val_salidas_continuas_mae: 3.0780 - learning_rate: 5.0000e-04
# Epoch 31/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.2065 - salida_clase_accuracy: 0.9316 - salidas_continuas_mae: 3.1209 - val_loss: 35.1631 - val_salida_clase_accuracy: 0.9298 - val_salidas_continuas_mae: 3.1205 - learning_rate: 5.0000e-04
# Epoch 32/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 34.1900 - salida_clase_accuracy: 0.9304 - salidas_continuas_mae: 3.1335 - val_loss: 33.9140 - val_salida_clase_accuracy: 0.9336 - val_salidas_continuas_mae: 3.0527 - learning_rate: 5.0000e-04
# Epoch 33/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 32.7169 - salida_clase_accuracy: 0.9343 - salidas_continuas_mae: 3.0468 - val_loss: 34.9547 - val_salida_clase_accuracy: 0.9291 - val_salidas_continuas_mae: 3.1170 - learning_rate: 5.0000e-04
# Epoch 34/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 33.1185 - salida_clase_accuracy: 0.9337 - salidas_continuas_mae: 3.0677 - val_loss: 32.9218 - val_salida_clase_accuracy: 0.9326 - val_salidas_continuas_mae: 2.9954 - learning_rate: 5.0000e-04
# Epoch 35/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31.4070 - salida_clase_accuracy: 0.9305 - salidas_continuas_mae: 2.9972 - val_loss: 32.4279 - val_salida_clase_accuracy: 0.9319 - val_salidas_continuas_mae: 2.9478 - learning_rate: 5.0000e-04
# Epoch 36/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31.1766 - salida_clase_accuracy: 0.9300 - salidas_continuas_mae: 2.9991 - val_loss: 32.3977 - val_salida_clase_accuracy: 0.9256 - val_salidas_continuas_mae: 2.9677 - learning_rate: 5.0000e-04
# Epoch 37/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 31.0897 - salida_clase_accuracy: 0.9378 - salidas_continuas_mae: 2.9828 - val_loss: 33.6569 - val_salida_clase_accuracy: 0.9284 - val_salidas_continuas_mae: 3.0606 - learning_rate: 5.0000e-04
# Epoch 38/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 30.3437 - salida_clase_accuracy: 0.9358 - salidas_continuas_mae: 2.9432 - val_loss: 33.5429 - val_salida_clase_accuracy: 0.9338 - val_salidas_continuas_mae: 3.0266 - learning_rate: 5.0000e-04
# Epoch 39/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 30.3080 - salida_clase_accuracy: 0.9376 - salidas_continuas_mae: 2.9464 - val_loss: 33.2497 - val_salida_clase_accuracy: 0.9320 - val_salidas_continuas_mae: 2.9886 - learning_rate: 5.0000e-04
# Epoch 40/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 29.8572 - salida_clase_accuracy: 0.9372 - salidas_continuas_mae: 2.9020 - val_loss: 31.9582 - val_salida_clase_accuracy: 0.9362 - val_salidas_continuas_mae: 2.9433 - learning_rate: 5.0000e-04
# Epoch 41/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 28.9570 - salida_clase_accuracy: 0.9387 - salidas_continuas_mae: 2.8634 - val_loss: 31.8671 - val_salida_clase_accuracy: 0.9362 - val_salidas_continuas_mae: 3.0020 - learning_rate: 5.0000e-04
# Epoch 42/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 28.5132 - salida_clase_accuracy: 0.9399 - salidas_continuas_mae: 2.8583 - val_loss: 30.9305 - val_salida_clase_accuracy: 0.9420 - val_salidas_continuas_mae: 2.8841 - learning_rate: 5.0000e-04
# Epoch 43/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.7296 - salida_clase_accuracy: 0.9389 - salidas_continuas_mae: 2.8224 - val_loss: 30.6182 - val_salida_clase_accuracy: 0.9362 - val_salidas_continuas_mae: 2.8891 - learning_rate: 5.0000e-04
# Epoch 44/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.5425 - salida_clase_accuracy: 0.9408 - salidas_continuas_mae: 2.7972 - val_loss: 29.4376 - val_salida_clase_accuracy: 0.9433 - val_salidas_continuas_mae: 2.8148 - learning_rate: 5.0000e-04
# Epoch 45/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 27.3085 - salida_clase_accuracy: 0.9393 - salidas_continuas_mae: 2.7860 - val_loss: 28.5974 - val_salida_clase_accuracy: 0.9418 - val_salidas_continuas_mae: 2.7522 - learning_rate: 5.0000e-04
# Epoch 46/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.7468 - salida_clase_accuracy: 0.9426 - salidas_continuas_mae: 2.7649 - val_loss: 28.5581 - val_salida_clase_accuracy: 0.9383 - val_salidas_continuas_mae: 2.7728 - learning_rate: 5.0000e-04
# Epoch 47/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 26.0994 - salida_clase_accuracy: 0.9397 - salidas_continuas_mae: 2.7117 - val_loss: 29.9216 - val_salida_clase_accuracy: 0.9407 - val_salidas_continuas_mae: 2.9036 - learning_rate: 5.0000e-04
# Epoch 48/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 26.3196 - salida_clase_accuracy: 0.9402 - salidas_continuas_mae: 2.7358 - val_loss: 27.8427 - val_salida_clase_accuracy: 0.9322 - val_salidas_continuas_mae: 2.7111 - learning_rate: 5.0000e-04
# Epoch 49/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 25.5788 - salida_clase_accuracy: 0.9381 - salidas_continuas_mae: 2.6919 - val_loss: 27.8901 - val_salida_clase_accuracy: 0.9437 - val_salidas_continuas_mae: 2.7705 - learning_rate: 5.0000e-04
# Epoch 50/50
# 720/720 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 25.8313 - salida_clase_accuracy: 0.9424 - salidas_continuas_mae: 2.7015 - val_loss: 26.9660 - val_salida_clase_accuracy: 0.9463 - val_salidas_continuas_mae: 2.6925 - learning_rate: 5.0000e-04
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.0487 - salida_clase_accuracy: 0.9497 - salidas_continuas_mae: 2.6816
# Fold 5: Loss=26.559986114501953, MAE=2.6961889266967773, Accuracy=0.9481512308120728
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 26.48995475769043
# MAE: 2.6783003698823777
# MSE: 26.302967582692947
# RMSE: 5.1272915791729075
# R^2: 0.9936040099887997
# Accuracy: 0.9435084819793701
# Precisión: 0.9443234426514711
# Recall: 0.943508479288296
# F1-Score: 0.9433299651644649
