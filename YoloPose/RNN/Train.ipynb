# %%
import joblib
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
# Definir rutas
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_raiz = os.path.dirname(carpeta_mediapipe)

ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual, 'datos', 'scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Videos_Pose', 'pose_data.csv')

# Cargar el dataset
data = pd.read_csv(ruta_csv)

# Preparar entradas (Keypoints)
num_keypoints = 17 * 3
X = data.iloc[:, :num_keypoints].values

# Las siguientes 11 columnas incluyen:
# 10 características continuas (ángulos, distancias) + 1 tipo de ejercicio (última columna)
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

# Codificar la etiqueta del tipo de ejercicio
encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

# Normalizar las entradas
scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

# Reshape para LSTM
X_scaled = X_scaled[:, :, np.newaxis]  # Añadir una dimensión para el LSTM

# Definir función para crear el modelo
def create_model(input_shape, num_clases, learning_rate=0.001):
    input_layer = Input(shape=input_shape)

    # Capas LSTM con Dropout
    x = LSTM(128, dropout=0.2, recurrent_dropout=0.2)(input_layer)

    # Salidas continuas (10 características)
    salidas_continuas = Dense(10, activation='linear', name='salidas_continuas')(x)

    # Salida de tipo de ejercicio (multiclase)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)

    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer,
                  loss={
                      'salidas_continuas': 'mean_squared_error',
                      'salida_clase': 'sparse_categorical_crossentropy'
                  },
                  metrics={
                      'salidas_continuas': 'mae',
                      'salida_clase': 'accuracy'
                  })
    return model

# Inicializar KFold y métricas
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

# Matrices para almacenar la historia del entrenamiento
n_epochs = 50  # Número de épocas
all_train_loss = np.full((n_splits, n_epochs), np.nan)  
all_val_loss = np.full((n_splits, n_epochs), np.nan)
all_train_accuracy = np.full((n_splits, n_epochs), np.nan)
all_val_accuracy = np.full((n_splits, n_epochs), np.nan)

# Validación cruzada
for fold, (train_index, val_index) in enumerate(kf.split(X_scaled)):
    print(f"Entrenando fold {fold + 1}...")

    X_train_fold, X_val_fold = X_scaled[train_index], X_scaled[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas[train_index], y_continuas[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_encoded[train_index], y_clase_encoded[val_index]

    model = create_model(input_shape=(X_train_fold.shape[1], X_train_fold.shape[2]), num_clases=num_clases, learning_rate=0.0005)

    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold + 1}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    # Almacenar la historia del entrenamiento como matrices NumPy
    epochs_completed = len(history.history['loss'])
    all_train_loss[fold, :epochs_completed] = history.history['loss']
    all_val_loss[fold, :epochs_completed] = history.history['val_loss']
    all_train_accuracy[fold, :epochs_completed] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold, :epochs_completed] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de validación
    scores = model.evaluate(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold})
    print(f"Fold {fold + 1}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_val_fold)[0]
    mae = mean_absolute_error(y_continuas_val_fold, y_pred_continuas)
    mse = mean_squared_error(y_continuas_val_fold, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_val_fold)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_val_fold)[1], axis=1)
    precision = precision_score(y_clase_val_fold, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_val_fold, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_val_fold, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_val_fold, y_pred_clase, labels=np.unique(y_clase_val_fold))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión ')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 37s 33ms/step - loss: 31781.1660 - salida_clase_accuracy: 0.2147 - salidas_continuas_mae: 106.9130 - val_loss: 25277.6426 - val_salida_clase_accuracy: 0.2208 - val_salidas_continuas_mae: 84.1217 - learning_rate: 5.0000e-04
# Epoch 2/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 31s 31ms/step - loss: 23273.5391 - salida_clase_accuracy: 0.2251 - salidas_continuas_mae: 79.4183 - val_loss: 21041.6523 - val_salida_clase_accuracy: 0.2208 - val_salidas_continuas_mae: 72.8246 - learning_rate: 5.0000e-04
# Epoch 3/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 31s 32ms/step - loss: 19285.7656 - salida_clase_accuracy: 0.2205 - salidas_continuas_mae: 70.6340 - val_loss: 19018.5332 - val_salida_clase_accuracy: 0.2208 - val_salidas_continuas_mae: 70.2064 - learning_rate: 5.0000e-04
# Epoch 4/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━
50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 31s 31ms/step - loss: 12531.6191 - salida_clase_accuracy: 0.4375 - salidas_continuas_mae: 60.4414 - val_loss: 11287.6094 - val_salida_clase_accuracy: 0.4819 - val_salidas_continuas_mae: 56.7295 - learning_rate: 5.0000e-04
# Epoch 17/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - loss: 11851.8438 - salida_clase_accuracy: 0.4452 - salidas_continuas_mae: 58.7481 - val_loss: 10803.5859 - val_salida_clase_accuracy: 0.5045 - val_salidas_continuas_mae: 56.1734 - learning_rate: 5.0000e-04
# Epoch 18/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - loss: 11593.1318 - salida_clase_accuracy: 0.4546 - salidas_continuas_mae: 58.2849 - val_loss: 10833.0977 - val_salida_clase_accuracy: 0.5004 - val_salidas_continuas_mae: 55.5493 - learning_rate: 5.0000e-04
# Epoch 19/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 33s 34ms/step - loss: 11298.6621 - salida_clase_accuracy: 0.4673 - salidas_continuas_mae: 57.3921 - val_loss: 10574.1279 - val_salida_clase_accuracy: 0.5071 - val_salidas_continuas_mae: 55.0713 - learning_rate: 5.0000e-04
# Epoch 20/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - loss: 11367.8779 - salida_clase_accuracy: 0.4669 - salidas_continuas_mae: 57.4606 - val_loss: 10468.6006 - val_salida_clase_accuracy: 0.5299 - val_salidas_continuas_mae: 54.7162 - learning_rate: 5.0000e-04
# Epoch 21/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - loss: 10872.7041 - salida_clase_accuracy: 0.4628 - salidas_continuas_mae: 56.3625 - val_loss: 9527.8691 - val_salida_clase_accuracy: 0.5319 - val_salidas_continuas_mae: 52.8714 - learning_rate: 5.0000e-04
# Epoch 22/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 31s 32ms/step - loss: 10547.0547 - salida_clase_accuracy: 0.4740 - salidas_continuas_mae: 55.5946 - val_loss: 9122.5605 - val_salida_clase_accuracy: 0.5298 - val_salidas_continuas_mae: 51.7011 - learning_rate: 5.0000e-04
# Epoch 23/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - loss: 10437.4971 - salida_clase_accuracy: 0.4735 - salidas_continuas_mae: 55.0475 - val_loss: 9128.4072 - val_salida_clase_accuracy: 0.5432 - val_salidas_continuas_mae: 51.7627 - learning_rate: 5.0000e-04
# Epoch 24/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 32s 33ms/step - loss: 10157.7842 - salida_clase_accuracy: 0.4845 - salidas_continuas_mae: 54.1017 - val_loss: 8589.5234 - val_salida_clase_accuracy: 0.5411 - val_salidas_continuas_mae: 50.3574 - learning_rate: 5.0000e-04
# Epoch 25/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 30s 31ms/step - loss: 9824.8721 - salida_clase_accuracy: 0.4864 - salidas_continuas_mae: 53.4130 - val_loss: 8395.7715 - val_salida_clase_accuracy: 0.5585 - val_salidas_continuas_mae: 49.5262 - learning_rate: 5.0000e-04
# Epoch 26/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 28s 28ms/step - loss: 9891.4902 - salida_clase_accuracy: 0.4848 - salidas_continuas_mae: 53.2577 - val_loss: 8453.3564 - val_salida_clase_accuracy: 0.5352 - val_salidas_continuas_mae: 50.1580 - learning_rate: 5.0000e-04
# Epoch 27/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 27s
50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10554.0820 - salida_clase_accuracy: 0.4861 - salidas_continuas_mae: 55.5105 - val_loss: 8817.4248 - val_salida_clase_accuracy: 0.5430 - val_salidas_continuas_mae: 50.4066 - learning_rate: 5.0000e-04
# Epoch 24/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10624.6465 - salida_clase_accuracy: 0.4986 - salidas_continuas_mae: 55.2589 - val_loss: 9268.1143 - val_salida_clase_accuracy: 0.5525 - val_salidas_continuas_mae: 50.2276 - learning_rate: 5.0000e-04
# Epoch 25/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10131.2686 - salida_clase_accuracy: 0.4986 - salidas_continuas_mae: 54.2185 - val_loss: 8103.7456 - val_salida_clase_accuracy: 0.5531 - val_salidas_continuas_mae: 48.2938 - learning_rate: 5.0000e-04
# Epoch 26/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10124.3047 - salida_clase_accuracy: 0.5019 - salidas_continuas_mae: 53.8834 - val_loss: 8839.8926 - val_salida_clase_accuracy: 0.5494 - val_salidas_continuas_mae: 49.0056 - learning_rate: 5.0000e-04
# Epoch 27/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10035.9990 - salida_clase_accuracy: 0.4947 - salidas_continuas_mae: 53.6133 - val_loss: 9324.9863 - val_salida_clase_accuracy: 0.5509 - val_salidas_continuas_mae: 49.2418 - learning_rate: 5.0000e-04
# Epoch 28/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 9692.2285 - salida_clase_accuracy: 0.5032 - salidas_continuas_mae: 52.8214 - val_loss: 8228.2500 - val_salida_clase_accuracy: 0.5596 - val_salidas_continuas_mae: 48.1067 - learning_rate: 5.0000e-04
# Epoch 29/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 9548.6719 - salida_clase_accuracy: 0.5125 - salidas_continuas_mae: 52.2037 - val_loss: 8829.1055 - val_salida_clase_accuracy: 0.5580 - val_salidas_continuas_mae: 48.0509 - learning_rate: 5.0000e-04
# Epoch 30/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 9595.8359 - salida_clase_accuracy: 0.5109 - salidas_continuas_mae: 52.0076 - val_loss: 7406.1919 - val_salida_clase_accuracy: 0.5716 - val_salidas_continuas_mae: 46.1047 - learning_rate: 5.0000e-04
# Epoch 31/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 9180.1670 - salida_clase_accuracy: 0.5176 - salidas_continuas_mae: 51.2939 - val_loss: 7478.5669 - val_salida_clase_accuracy: 0.5652 - val_salidas_continuas_mae: 46.0394 - learning_rate: 5.0000e-04
# Epoch 32/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 9100.4775 - salida_clase_accuracy: 0.5130 - salidas_continuas_mae: 50.9698 - val_loss: 7475.5156 - val_salida_clase_accuracy: 0.5864 - val_salidas_continuas_mae: 45.9522 - learning_rate: 5.0000e-04
# Epoch 33/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 9293.4893 - salida_clase_accuracy: 0.5164 - salidas_continuas_mae: 51.1558 - val_loss: 7298.4380 - val_salida_clase_accuracy: 0.5875 - val_salidas_continuas_mae: 45.4841 - learning_rate: 5.0000e-04
# Epoch 34/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 9021.9971 - salida_clase_accuracy: 0.5237 - salidas_continuas_mae: 50.6242 - val_loss: 7114.7998 - val_salida_clase_accuracy: 0.6018 - val_salidas_continuas_mae: 45.0889 - learning_rate: 5.0000e-04
# Epoch 35/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 9038.2197 - salida_clase_accuracy: 0.5265 - salidas_continuas_mae: 50.4181 - val_loss: 6697.0425 - val_salida_clase_accuracy: 0.5870 - val_salidas_continuas_mae: 43.9498 - learning_rate: 5.0000e-04
# Epoch 36/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8869.7021 - salida_clase_accuracy: 0.5266 - salidas_continuas_mae: 50.1107 - val_loss: 7789.4072 - val_salida_clase_accuracy: 0.5827 - val_salidas_continuas_mae: 45.2247 - learning_rate: 5.0000e-04
# Epoch 37/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8887.4150 - salida_clase_accuracy: 0.5233 - salidas_continuas_mae: 50.2060 - val_loss: 6437.2026 - val_salida_clase_accuracy: 0.5795 - val_salidas_continuas_mae: 43.2396 - learning_rate: 5.0000e-04
# Epoch 38/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8723.9922 - salida_clase_accuracy: 0.5302 - salidas_continuas_mae: 49.6756 - val_loss: 7021.5972 - val_salida_clase_accuracy: 0.6086 - val_salidas_continuas_mae: 43.9227 - learning_rate: 5.0000e-04
# Epoch 39/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8672.9951 - salida_clase_accuracy: 0.5325 - salidas_continuas_mae: 49.3163 - val_loss: 6720.4092 - val_salida_clase_accuracy: 0.5884 - val_salidas_continuas_mae: 43.8818 - learning_rate: 5.0000e-04
# Epoch 40/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8563.7939 - salida_clase_accuracy: 0.5301 - salidas_continuas_mae: 49.1489 - val_loss: 6488.9019 - val_salida_clase_accuracy: 0.6099 - val_salidas_continuas_mae: 42.8371 - learning_rate: 5.0000e-04
# Epoch 41/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8474.9268 - salida_clase_accuracy: 0.5327 - salidas_continuas_mae: 48.6526 - val_loss: 6271.1465 - val_salida_clase_accuracy: 0.6066 - val_salidas_continuas_mae: 42.7378 - learning_rate: 5.0000e-04
# Epoch 42/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8557.5283 - salida_clase_accuracy: 0.5341 - salidas_continuas_mae: 48.8091 - val_loss: 6309.6978 - val_salida_clase_accuracy: 0.6082 - val_salidas_continuas_mae: 42.2786 - learning_rate: 5.0000e-04
# Epoch 43/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8167.4209 - salida_clase_accuracy: 0.5433 - salidas_continuas_mae: 48.0162 - val_loss: 6275.7671 - val_salida_clase_accuracy: 0.6326 - val_salidas_continuas_mae: 42.0995 - learning_rate: 5.0000e-04
# Epoch 44/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8298.4844 - salida_clase_accuracy: 0.5443 - salidas_continuas_mae: 48.0944 - val_loss: 6186.4790 - val_salida_clase_accuracy: 0.6227 - val_salidas_continuas_mae: 42.1877 - learning_rate: 5.0000e-04
# Epoch 45/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8125.4946 - salida_clase_accuracy: 0.5535 - salidas_continuas_mae: 47.7279 - val_loss: 6492.3271 - val_salida_clase_accuracy: 0.6089 - val_salidas_continuas_mae: 42.6003 - learning_rate: 5.0000e-04
# Epoch 46/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8233.3613 - salida_clase_accuracy: 0.5420 - salidas_continuas_mae: 47.9759 - val_loss: 6105.0649 - val_salida_clase_accuracy: 0.5924 - val_salidas_continuas_mae: 41.9116 - learning_rate: 5.0000e-04
# Epoch 47/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8432.4541 - salida_clase_accuracy: 0.5388 - salidas_continuas_mae: 48.3129 - val_loss: 6178.3291 - val_salida_clase_accuracy: 0.6174 - val_salidas_continuas_mae: 41.3807 - learning_rate: 5.0000e-04
# Epoch 48/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8307.7383 - salida_clase_accuracy: 0.5510 - salidas_continuas_mae: 47.8478 - val_loss: 5963.1738 - val_salida_clase_accuracy: 0.6378 - val_salidas_continuas_mae: 40.9315 - learning_rate: 5.0000e-04
# Epoch 49/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8286.3301 - salida_clase_accuracy: 0.5472 - salidas_continuas_mae: 47.7406 - val_loss: 6148.2832 - val_salida_clase_accuracy: 0.6313 - val_salidas_continuas_mae: 41.4737 - learning_rate: 5.0000e-04
# Epoch 50/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8012.4448 - salida_clase_accuracy: 0.5531 - salidas_continuas_mae: 46.9934 - val_loss: 6007.3418 - val_salida_clase_accuracy: 0.6353 - val_salidas_continuas_mae: 41.3061 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5414.4800 - salida_clase_accuracy: 0.7024 - salidas_continuas_mae: 41.2403
# Fold 2: Loss=5963.173828125, MAE=40.93154525756836, Accuracy=0.6378495693206787
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Entrenando fold 3...
# Epoch 1/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 31888.3691 - salida_clase_accuracy: 0.2021 - salidas_continuas_mae: 106.8124 - val_loss: 23880.7520 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 82.2582 - learning_rate: 5.0000e-04
# Epoch 2/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 23708.9570 - salida_clase_accuracy: 0.2189 - salidas_continuas_mae: 79.4761 - val_loss: 19833.7207 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 71.3960 - learning_rate: 5.0000e-04
# Epoch 3/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 20154.3750 - salida_clase_accuracy: 0.2194 - salidas_continuas_mae: 71.2405 - val_loss: 17947.9043 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 69.1735 - learning_rate: 5.0000e-04
# Epoch 4/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 18172.0840 - salida_clase_accuracy: 0.2165 - salidas_continuas_mae: 69.4736 - val_loss: 17734.2383 - val_salida_clase_accuracy: 0.2191 - val_salidas_continuas_mae: 70.4691 - learning_rate: 5.0000e-04
# Epoch 5/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 17488.4180 - salida_clase_accuracy: 0.2222 - salidas_continuas_mae: 69.6776 - val_loss: 16368.7100 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 69.3282 - learning_rate: 5.0000e-04
# Epoch 6/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 16880.2695 - salida_clase_accuracy: 0.2212 - salidas_continuas_mae: 70.0640 - val_loss: 16106.5039 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 69.6735 - learning_rate: 5.0000e-04
# Epoch 7/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 16754.3770 - salida_clase_accuracy: 0.2203 - salidas_continuas_mae: 70.4251 - val_loss: 15995.1777 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 70.0547 - learning_rate: 5.0000e-04
# Epoch 8/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 16486.5938 - salida_clase_accuracy: 0.2198 - salidas_continuas_mae: 70.5338 - val_loss: 15983.1768 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 70.0500 - learning_rate: 5.0000e-04
# Epoch 9/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 16458.4570 - salida_clase_accuracy: 0.2237 - salidas_continuas_mae: 70.2794 - val_loss: 15431.2959 - val_salida_clase_accuracy: 0.3311 - val_salidas_continuas_mae: 69.0214 - learning_rate: 5.0000e-04
# Epoch 10/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 16049.0820 - salida_clase_accuracy: 0.2593 - salidas_continuas_mae: 69.7115 - val_loss: 13994.7900 - val_salida_clase_accuracy: 0.2814 - val_salidas_continuas_mae: 66.2400 - learning_rate: 5.0000e-04
# Epoch 11/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 14635.1885 - salida_clase_accuracy: 0.2973 - salidas_continuas_mae: 67.0367 - val_loss: 13015.4111 - val_salida_clase_accuracy: 0.3968 - val_salidas_continuas_mae: 63.2086 - learning_rate: 5.0000e-04
# Epoch 12/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 13700.5459 - salida_clase_accuracy: 0.3631 - salidas_continuas_mae: 64.8563 - val_loss: 12210.4443 - val_salida_clase_accuracy: 0.4587 - val_salidas_continuas_mae: 61.0854 - learning_rate: 5.0000e-04
# Epoch 13/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 13420.5283 - salida_clase_accuracy: 0.3768 - salidas_continuas_mae: 63.4203 - val_loss: 11411.4092 - val_salida_clase_accuracy: 0.4609 - val_salidas_continuas_mae: 59.2647 - learning_rate: 5.0000e-04
# Epoch 14/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 12930.2969 - salida_clase_accuracy: 0.3825 - salidas_continuas_mae: 62.1111 - val_loss: 10767.0273 - val_salida_clase_accuracy: 0.4943 - val_salidas_continuas_mae: 57.0709 - learning_rate: 5.0000e-04
# Epoch 15/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 12419.4941 - salida_clase_accuracy: 0.4108 - salidas_continuas_mae: 60.6148 - val_loss: 10556.8145 - val_salida_clase_accuracy: 0.5208 - val_salidas_continuas_mae: 56.0726 - learning_rate: 5.0000e-04
# Epoch 16/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 12044.9258 - salida_clase_accuracy: 0.4282 - salidas_continuas_mae: 59.3171 - val_loss: 10242.6475 - val_salida_clase_accuracy: 0.5186 - val_salidas_continuas_mae: 54.7808 - learning_rate: 5.0000e-04
# Epoch 17/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 11948.7305 - salida_clase_accuracy: 0.4275 - salidas_continuas_mae: 58.9521 - val_loss: 10351.1631 - val_salida_clase_accuracy: 0.4958 - val_salidas_continuas_mae: 55.0742 - learning_rate: 5.0000e-04
# Epoch 18/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 11490.4121 - salida_clase_accuracy: 0.4470 - salidas_continuas_mae: 57.7367 - val_loss: 9820.3516 - val_salida_clase_accuracy: 0.5136 - val_salidas_continuas_mae: 53.4268 - learning_rate: 5.0000e-04
# Epoch 19/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 17s 18ms/step - loss: 11121.2412 - salida_clase_accuracy: 0.4482 - salidas_continuas_mae: 57.0123 - val_loss: 9651.8057 - val_salida_clase_accuracy: 0.5437 - val_salidas_continuas_mae: 53.0970 - learning_rate: 5.0000e-04
# Epoch 20/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 11154.3428 - salida_clase_accuracy: 0.4635 - salidas_continuas_mae: 56.9356 - val_loss: 9144.5908 - val_salida_clase_accuracy: 0.5556 - val_salidas_continuas_mae: 51.8830 - learning_rate: 5.0000e-04
# Epoch 21/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 10934.9092 - salida_clase_accuracy: 0.4685 - salidas_continuas_mae: 56.1925 - val_loss: 9276.1533 - val_salida_clase_accuracy: 0.5790 - val_salidas_continuas_mae: 51.8095 - learning_rate: 5.0000e-04
# Epoch 22/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - loss: 10612.8711 - salida_clase_accuracy: 0.4830 - salidas_continuas_mae: 55.4136 - val_loss: 8618.7939 - val_salida_clase_accuracy: 0.5841 - val_salidas_continuas_mae: 50.6437 - learning_rate: 5.0000e-04
# Epoch 23/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 10560.7510 - salida_clase_accuracy: 0.4924 - salidas_continuas_mae: 55.2968 - val_loss: 8281.9893 - val_salida_clase_accuracy: 0.5683 - val_salidas_continuas_mae: 49.2898 - learning_rate: 5.0000e-04
# Epoch 24/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 10279.6787 - salida_clase_accuracy: 0.4888 - salidas_continuas_mae: 54.6703 - val_loss: 8172.8677 - val_salida_clase_accuracy: 0.5952 - val_salidas_continuas_mae: 49.0180 - learning_rate: 5.0000e-04
# Epoch 25/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 10040.1377 - salida_clase_accuracy: 0.4952 - salidas_continuas_mae: 53.7603 - val_loss: 8528.0127 - val_salida_clase_accuracy: 0.5617 - val_salidas_continuas_mae: 48.9461 - learning_rate: 5.0000e-04
# Epoch 26/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 9811.6631 - salida_clase_accuracy: 0.5018 - salidas_continuas_mae: 53.1544 - val_loss: 7867.6333 - val_salida_clase_accuracy: 0.5974 - val_salidas_continuas_mae: 47.7243 - learning_rate: 5.0000e-04
# Epoch 27/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9659.8447 - salida_clase_accuracy: 0.5081 - salidas_continuas_mae: 52.5210 - val_loss: 7829.7085 - val_salida_clase_accuracy: 0.6067 - val_salidas_continuas_mae: 47.1290 - learning_rate: 5.0000e-04
# Epoch 28/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9719.4502 - salida_clase_accuracy: 0.5085 - salidas_continuas_mae: 52.5063 - val_loss: 7756.6821 - val_salida_clase_accuracy: 0.6122 - val_salidas_continuas_mae: 46.6995 - learning_rate: 5.0000e-04
# Epoch 29/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 9590.7246 - salida_clase_accuracy: 0.5128 - salidas_continuas_mae: 52.2864 - val_loss: 7248.0571 - val_salida_clase_accuracy: 0.6181 - val_salidas_continuas_mae: 46.2256 - learning_rate: 5.0000e-04
# Epoch 30/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9305.4502 - salida_clase_accuracy: 0.5272 - salidas_continuas_mae: 51.3850 - val_loss: 7177.2705 - val_salida_clase_accuracy: 0.6221 - val_salidas_continuas_mae: 45.7419 - learning_rate: 5.0000e-04
# Epoch 31/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 9388.1455 - salida_clase_accuracy: 0.5165 - salidas_continuas_mae: 51.5513 - val_loss: 7273.9663 - val_salida_clase_accuracy: 0.6053 - val_salidas_continuas_mae: 45.6085 - learning_rate: 5.0000e-04
# Epoch 32/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9050.5654 - salida_clase_accuracy: 0.5256 - salidas_continuas_mae: 50.8786 - val_loss: 7102.4165 - val_salida_clase_accuracy: 0.6290 - val_salidas_continuas_mae: 45.2856 - learning_rate: 5.0000e-04
# Epoch 33/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8988.2188 - salida_clase_accuracy: 0.5216 - salidas_continuas_mae: 50.6033 - val_loss: 6807.9028 - val_salida_clase_accuracy: 0.6359 - val_salidas_continuas_mae: 44.3856 - learning_rate: 5.0000e-04
# Epoch 34/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8980.1123 - salida_clase_accuracy: 0.5330 - salidas_continuas_mae: 50.2499 - val_loss: 6532.5742 - val_salida_clase_accuracy: 0.6491 - val_salidas_continuas_mae: 43.9144 - learning_rate: 5.0000e-04
# Epoch 35/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 8589.0176 - salida_clase_accuracy: 0.5374 - salidas_continuas_mae: 49.3282 - val_loss: 6368.2363 - val_salida_clase_accuracy: 0.6553 - val_salidas_continuas_mae: 43.0704 - learning_rate: 5.0000e-04
# Epoch 36/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 8732.3037 - salida_clase_accuracy: 0.5389 - salidas_continuas_mae: 49.5588 - val_loss: 6299.7866 - val_salida_clase_accuracy: 0.6649 - val_salidas_continuas_mae: 42.6883 - learning_rate: 5.0000e-04
# Epoch 37/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8457.4199 - salida_clase_accuracy: 0.5464 - salidas_continuas_mae: 48.8706 - val_loss: 6323.5747 - val_salida_clase_accuracy: 0.6424 - val_salidas_continuas_mae: 42.4906 - learning_rate: 5.0000e-04
# Epoch 38/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 8364.1436 - salida_clase_accuracy: 0.5463 - salidas_continuas_mae: 48.4777 - val_loss: 6138.2671 - val_salida_clase_accuracy: 0.6481 - val_salidas_continuas_mae: 41.8833 - learning_rate: 5.0000e-04
# Epoch 39/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 8359.9326 - salida_clase_accuracy: 0.5502 - salidas_continuas_mae: 48.2327 - val_loss: 6300.8433 - val_salida_clase_accuracy: 0.6307 - val_salidas_continuas_mae: 42.5038 - learning_rate: 5.0000e-04
# Epoch 40/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8372.2695 - salida_clase_accuracy: 0.5415 - salidas_continuas_mae: 48.4639 - val_loss: 6221.8501 - val_salida_clase_accuracy: 0.6545 - val_salidas_continuas_mae: 42.0206 - learning_rate: 5.0000e-04
# Epoch 41/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 8188.3013 - salida_clase_accuracy: 0.5524 - salidas_continuas_mae: 47.9027 - val_loss: 6035.6133 - val_salida_clase_accuracy: 0.6610 - val_salidas_continuas_mae: 41.4599 - learning_rate: 5.0000e-04
# Epoch 42/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - loss: 8073.5273 - salida_clase_accuracy: 0.5546 - salidas_continuas_mae: 47.4392 - val_loss: 5738.8350 - val_salida_clase_accuracy: 0.6795 - val_salidas_continuas_mae: 40.4692 - learning_rate: 5.0000e-04
# Epoch 43/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - loss: 8154.1494 - salida_clase_accuracy: 0.5590 - salidas_continuas_mae: 47.3412 - val_loss: 5894.0083 - val_salida_clase_accuracy: 0.6661 - val_salidas_continuas_mae: 40.6704 - learning_rate: 5.0000e-04
# Epoch 44/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 30s 31ms/step - loss: 8323.8779 - salida_clase_accuracy: 0.5552 - salidas_continuas_mae: 47.6923 - val_loss: 6112.6328 - val_salida_clase_accuracy: 0.6571 - val_salidas_continuas_mae: 41.7860 - learning_rate: 5.0000e-04
# Epoch 45/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - loss: 7915.4575 - salida_clase_accuracy: 0.5659 - salidas_continuas_mae: 46.7442 - val_loss: 5815.1279 - val_salida_clase_accuracy: 0.6488 - val_salidas_continuas_mae: 40.4165 - learning_rate: 5.0000e-04
# Epoch 46/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 7845.0625 - salida_clase_accuracy: 0.5574 - salidas_continuas_mae: 46.5363 - val_loss: 5641.9517 - val_salida_clase_accuracy: 0.6613 - val_salidas_continuas_mae: 39.7493 - learning_rate: 5.0000e-04
# Epoch 47/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 7907.3770 - salida_clase_accuracy: 0.5638 - salidas_continuas_mae: 46.5257 - val_loss: 5570.7861 - val_salida_clase_accuracy: 0.6764 - val_salidas_continuas_mae: 39.5491 - learning_rate: 5.0000e-04
# Epoch 48/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - loss: 7888.9873 - salida_clase_accuracy: 0.5690 - salidas_continuas_mae: 46.3943 - val_loss: 6255.8926 - val_salida_clase_accuracy: 0.6566 - val_salidas_continuas_mae: 41.5924 - learning_rate: 5.0000e-04
# Epoch 49/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 7681.0796 - salida_clase_accuracy: 0.5795 - salidas_continuas_mae: 45.7216 - val_loss: 5463.0059 - val_salida_clase_accuracy: 0.6753 - val_salidas_continuas_mae: 39.4092 - learning_rate: 5.0000e-04
# Epoch 50/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 7802.5127 - salida_clase_accuracy: 0.5766 - salidas_continuas_mae: 46.0276 - val_loss: 5930.0586 - val_salida_clase_accuracy: 0.6615 - val_salidas_continuas_mae: 40.4253 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4748.5815 - salida_clase_accuracy: 0.7487 - salidas_continuas_mae: 39.2096
# Fold 3: Loss=5463.005859375, MAE=39.409244537353516, Accuracy=0.6752649545669556
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Entrenando fold 4...
# Epoch 1/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 31867.5215 - salida_clase_accuracy: 0.2076 - salidas_continuas_mae: 106.6536 - val_loss: 24356.4219 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 82.6401 - learning_rate: 5.0000e-04
# Epoch 2/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 23257.7422 - salida_clase_accuracy: 0.2183 - salidas_continuas_mae: 79.4015 - val_loss: 20249.9316 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 71.5011 - learning_rate: 5.0000e-04
# Epoch 3/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 19645.9492 - salida_clase_accuracy: 0.2213 - salidas_continuas_mae: 70.9562 - val_loss: 18332.0078 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 69.1339 - learning_rate: 5.0000e-04
# Epoch 4/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 17939.2871 - salida_clase_accuracy: 0.2143 - salidas_continuas_mae: 69.4423 - val_loss: 17263.7910 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 69.0170 - learning_rate: 5.0000e-04
# Epoch 5/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 16951.0449 - salida_clase_accuracy: 0.2200 - salidas_continuas_mae: 69.2049 - val_loss: 16672.8223 - val_salida_clase_accuracy: 0.1688 - val_salidas_continuas_mae: 69.4144 - learning_rate: 5.0000e-04
# Epoch 6/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 16334.2764 - salida_clase_accuracy: 0.2164 - salidas_continuas_mae: 69.4990 - val_loss: 16396.1074 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 69.8507 - learning_rate: 5.0000e-04
# Epoch 7/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 16573.5605 - salida_clase_accuracy: 0.2194 - salidas_continuas_mae: 70.5140 - val_loss: 16306.3242 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 70.2568 - learning_rate: 5.0000e-04
# Epoch 8/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 16596.3242 - salida_clase_accuracy: 0.2158 - salidas_continuas_mae: 71.0074 - val_loss: 16257.0596 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 70.2694 - learning_rate: 5.0000e-04
# Epoch 9/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 16243.2197 - salida_clase_accuracy: 0.2251 - salidas_continuas_mae: 70.3500 - val_loss: 15775.4873 - val_salida_clase_accuracy: 0.2885 - val_salidas_continuas_mae: 69.0947 - learning_rate: 5.0000e-04
# Epoch 10/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 15972.2402 - salida_clase_accuracy: 0.2568 - salidas_continuas_mae: 69.5995 - val_loss: 14823.5840 - val_salida_clase_accuracy: 0.3204 - val_salidas_continuas_mae: 67.2433 - learning_rate: 5.0000e-04
# Epoch 11/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 15226.8018 - salida_clase_accuracy: 0.2881 - salidas_continuas_mae: 68.1804 - val_loss: 14004.0781 - val_salida_clase_accuracy: 0.3883 - val_salidas_continuas_mae: 65.0924 - learning_rate: 5.0000e-04
# Epoch 12/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 14772.0703 - salida_clase_accuracy: 0.3416 - salidas_continuas_mae: 66.9473 - val_loss: 13440.8467 - val_salida_clase_accuracy: 0.3831 - val_salidas_continuas_mae: 63.0589 - learning_rate: 5.0000e-04
# Epoch 13/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 13866.6328 - salida_clase_accuracy: 0.3462 - salidas_continuas_mae: 64.9657 - val_loss: 13043.7188 - val_salida_clase_accuracy: 0.4192 - val_salidas_continuas_mae: 62.3222 - learning_rate: 5.0000e-04
# Epoch 14/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 13548.9600 - salida_clase_accuracy: 0.3496 - salidas_continuas_mae: 64.0837 - val_loss: 12031.9199 - val_salida_clase_accuracy: 0.4598 - val_salidas_continuas_mae: 59.4324 - learning_rate: 5.0000e-04
# Epoch 15/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 12968.7383 - salida_clase_accuracy: 0.4060 - salidas_continuas_mae: 62.3817 - val_loss: 11728.4268 - val_salida_clase_accuracy: 0.5350 - val_salidas_continuas_mae: 57.8646 - learning_rate: 5.0000e-04
# Epoch 16/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 12437.3203 - salida_clase_accuracy: 0.4310 - salidas_continuas_mae: 60.9504 - val_loss: 10792.0381 - val_salida_clase_accuracy: 0.5377 - val_salidas_continuas_mae: 56.5815 - learning_rate: 5.0000e-04
# Epoch 17/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 12339.3320 - salida_clase_accuracy: 0.4528 - salidas_continuas_mae: 60.4282 - val_loss: 11261.5273 - val_salida_clase_accuracy: 0.5501 - val_salidas_continuas_mae: 55.9737 - learning_rate: 5.0000e-04
# Epoch 18/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 11605.5547 - salida_clase_accuracy: 0.4766 - salidas_continuas_mae: 58.9385 - val_loss: 9868.4893 - val_salida_clase_accuracy: 0.5589 - val_salidas_continuas_mae: 54.0779 - learning_rate: 5.0000e-04
# Epoch 19/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 11439.7207 - salida_clase_accuracy: 0.4861 - salidas_continuas_mae: 58.4100 - val_loss: 9998.0674 - val_salida_clase_accuracy: 0.5705 - val_salidas_continuas_mae: 53.6631 - learning_rate: 5.0000e-04
# Epoch 20/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 11158.3193 - salida_clase_accuracy: 0.4932 - salidas_continuas_mae: 57.5668 - val_loss: 9800.5293 - val_salida_clase_accuracy: 0.5655 - val_salidas_continuas_mae: 53.0950 - learning_rate: 5.0000e-04
# Epoch 21/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 10770.4561 - salida_clase_accuracy: 0.5029 - salidas_continuas_mae: 56.4722 - val_loss: 9406.2412 - val_salida_clase_accuracy: 0.5656 - val_salidas_continuas_mae: 51.8081 - learning_rate: 5.0000e-04
# Epoch 22/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10592.0576 - salida_clase_accuracy: 0.5011 - salidas_continuas_mae: 55.8673 - val_loss: 9381.6377 - val_salida_clase_accuracy: 0.5704 - val_salidas_continuas_mae: 51.5875 - learning_rate: 5.0000e-04
# Epoch 23/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10402.4590 - salida_clase_accuracy: 0.5000 - salidas_continuas_mae: 55.2132 - val_loss: 8962.9990 - val_salida_clase_accuracy: 0.5688 - val_salidas_continuas_mae: 50.6922 - learning_rate: 5.0000e-04
# Epoch 24/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 10040.7002 - salida_clase_accuracy: 0.5107 - salidas_continuas_mae: 54.3799 - val_loss: 8465.5967 - val_salida_clase_accuracy: 0.5613 - val_salidas_continuas_mae: 49.7879 - learning_rate: 5.0000e-04
# Epoch 25/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 10080.0479 - salida_clase_accuracy: 0.5149 - salidas_continuas_mae: 54.1973 - val_loss: 7984.3418 - val_salida_clase_accuracy: 0.5843 - val_salidas_continuas_mae: 48.5302 - learning_rate: 5.0000e-04
# Epoch 26/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 9868.4072 - salida_clase_accuracy: 0.5192 - salidas_continuas_mae: 53.6175 - val_loss: 8095.1724 - val_salida_clase_accuracy: 0.6079 - val_salidas_continuas_mae: 48.1621 - learning_rate: 5.0000e-04
# Epoch 27/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 9758.8867 - salida_clase_accuracy: 0.5262 - salidas_continuas_mae: 53.1131 - val_loss: 7720.2070 - val_salida_clase_accuracy: 0.6028 - val_salidas_continuas_mae: 47.3869 - learning_rate: 5.0000e-04
# Epoch 28/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 9555.7363 - salida_clase_accuracy: 0.5258 - salidas_continuas_mae: 52.7085 - val_loss: 8053.5488 - val_salida_clase_accuracy: 0.6029 - val_salidas_continuas_mae: 47.7527 - learning_rate: 5.0000e-04
# Epoch 29/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9317.7051 - salida_clase_accuracy: 0.5267 - salidas_continuas_mae: 51.9246 - val_loss: 7525.3198 - val_salida_clase_accuracy: 0.5711 - val_salidas_continuas_mae: 47.0072 - learning_rate: 5.0000e-04
# Epoch 30/50
# ...
# Epoch 43/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 8398.5225 - salida_clase_accuracy: 0.5585 - salidas_continuas_mae: 48.6191 - val_loss: 6235.9805 - val_salida_clase_accuracy: 0.6557 - val_salidas_continuas_mae: 42.3591 - learning_rate: 5.0000e-04
# Epoch 44/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8472.3066 - salida_clase_accuracy: 0.5593 - salidas_continuas_mae: 48.5767 - val_loss: 6267.7397 - val_salida_clase_accuracy: 0.6342 - val_salidas_continuas_mae: 42.5015 - learning_rate: 5.0000e-04
# Epoch 45/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 8306.7803 - salida_clase_accuracy: 0.5479 - salidas_continuas_mae: 48.2009 - val_loss: 6400.3247 - val_salida_clase_accuracy: 0.6355 - val_salidas_continuas_mae: 42.6312 - learning_rate: 5.0000e-04
# Epoch 46/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 8426.0342 - salida_clase_accuracy: 0.5504 - salidas_continuas_mae: 48.5891 - val_loss: 6345.5225 - val_salida_clase_accuracy: 0.6344 - val_salidas_continuas_mae: 42.1374 - learning_rate: 5.0000e-04
# Epoch 47/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 8132.6597 - salida_clase_accuracy: 0.5601 - salidas_continuas_mae: 47.8661 - val_loss: 6660.2144 - val_salida_clase_accuracy: 0.6401 - val_salidas_continuas_mae: 42.5872 - learning_rate: 5.0000e-04
# Epoch 48/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 8437.8779 - salida_clase_accuracy: 0.5562 - salidas_continuas_mae: 48.5047 - val_loss: 5873.3926 - val_salida_clase_accuracy: 0.6391 - val_salidas_continuas_mae: 41.0102 - learning_rate: 5.0000e-04
# Epoch 49/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 8007.9009 - salida_clase_accuracy: 0.5576 - salidas_continuas_mae: 47.6079 - val_loss: 6335.7310 - val_salida_clase_accuracy: 0.6354 - val_salidas_continuas_mae: 42.0414 - learning_rate: 5.0000e-04
# Epoch 50/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 8140.5322 - salida_clase_accuracy: 0.5597 - salidas_continuas_mae: 47.8491 - val_loss: 6492.2764 - val_salida_clase_accuracy: 0.6352 - val_salidas_continuas_mae: 42.4407 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5018.6606 - salida_clase_accuracy: 0.6355 - salidas_continuas_mae: 40.9306
# Fold 4: Loss=5873.392578125, MAE=41.01019287109375, Accuracy=0.6390804648399353
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Entrenando fold 5...
# Epoch 1/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 34s 33ms/step - loss: 31877.6621 - salida_clase_accuracy: 0.1976 - salidas_continuas_mae: 106.8608 - val_loss: 24700.1758 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 83.2271 - learning_rate: 5.0000e-04
# Epoch 2/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 26s 27ms/step - loss: 23134.8047 - salida_clase_accuracy: 0.2206 - salidas_continuas_mae: 79.2073 - val_loss: 20573.7754 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 72.1631 - learning_rate: 5.0000e-04
# Epoch 3/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 19699.9258 - salida_clase_accuracy: 0.2210 - salidas_continuas_mae: 70.9759 - val_loss: 18644.9004 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 69.8638 - learning_rate: 5.0000e-04
# Epoch 4/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 18081.9004 - salida_clase_accuracy: 0.2189 - salidas_continuas_mae: 69.3236 - val_loss: 17586.3809 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 69.6972 - learning_rate: 5.0000e-04
# Epoch 5/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 17534.8066 - salida_clase_accuracy: 0.2231 - salidas_continuas_mae: 69.8047 - val_loss: 17000.4141 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 70.0658 - learning_rate: 5.0000e-04
# Epoch 6/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 16558.2363 - salida_clase_accuracy: 0.2198 - salidas_continuas_mae: 69.7081 - val_loss: 16725.9824 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 70.5013 - learning_rate: 5.0000e-04
# Epoch 7/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 16566.8398 - salida_clase_accuracy: 0.2197 - salidas_continuas_mae: 70.3786 - val_loss: 16608.8379 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 70.7562 - learning_rate: 5.0000e-04
# Epoch 8/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 16356.8799 - salida_clase_accuracy: 0.2149 - salidas_continuas_mae: 70.1366 - val_loss: 16455.5469 - val_salida_clase_accuracy: 0.1524 - val_salidas_continuas_mae: 70.5298 - learning_rate: 5.0000e-04
# Epoch 9/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 15846.2949 - salida_clase_accuracy: 0.2432 - salidas_continuas_mae: 69.4118 - val_loss: 15115.1650 - val_salida_clase_accuracy: 0.3791 - val_salidas_continuas_mae: 67.6018 - learning_rate: 5.0000e-04
# Epoch 10/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 15123.8916 - salida_clase_accuracy: 0.3012 - salidas_continuas_mae: 67.7466 - val_loss: 14263.9873 - val_salida_clase_accuracy: 0.4091 - val_salidas_continuas_mae: 64.7436 - learning_rate: 5.0000e-04
# Epoch 11/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 14229.8848 - salida_clase_accuracy: 0.3295 - salidas_continuas_mae: 65.4795 - val_loss: 13375.8770 - val_salida_clase_accuracy: 0.4504 - val_salidas_continuas_mae: 62.6253 - learning_rate: 5.0000e-04
# Epoch 12/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 13665.6699 - salida_clase_accuracy: 0.3569 - salidas_continuas_mae: 63.8177 - val_loss: 12594.5107 - val_salida_clase_accuracy: 0.4870 - val_salidas_continuas_mae: 60.1594 - learning_rate: 5.0000e-04
# Epoch 13/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 12872.6562 - salida_clase_accuracy: 0.3940 - salidas_continuas_mae: 62.1107 - val_loss: 12168.8213 - val_salida_clase_accuracy: 0.4911 - val_salidas_continuas_mae: 58.7791 - learning_rate: 5.0000e-04
# Epoch 14/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 12522.1797 - salida_clase_accuracy: 0.4177 - salidas_continuas_mae: 61.1849 - val_loss: 12010.5557 - val_salida_clase_accuracy: 0.5170 - val_salidas_continuas_mae: 58.4294 - learning_rate: 5.0000e-04
# Epoch 15/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 12335.0801 - salida_clase_accuracy: 0.4544 - salidas_continuas_mae: 60.3794 - val_loss: 11323.6201 - val_salida_clase_accuracy: 0.5428 - val_salidas_continuas_mae: 56.3368 - learning_rate: 5.0000e-04
# Epoch 16/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 11798.5557 - salida_clase_accuracy: 0.4599 - salidas_continuas_mae: 59.3128 - val_loss: 10891.5586 - val_salida_clase_accuracy: 0.5097 - val_salidas_continuas_mae: 56.0327 - learning_rate: 5.0000e-04
# Epoch 17/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 11234.0889 - salida_clase_accuracy: 0.4785 - salidas_continuas_mae: 57.8751 - val_loss: 11519.5176 - val_salida_clase_accuracy: 0.5682 - val_salidas_continuas_mae: 55.9464 - learning_rate: 5.0000e-04
# Epoch 18/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 11199.9648 - salida_clase_accuracy: 0.4897 - salidas_continuas_mae: 57.6744 - val_loss: 10185.0078 - val_salida_clase_accuracy: 0.5865 - val_salidas_continuas_mae: 53.9809 - learning_rate: 5.0000e-04
# Epoch 19/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - loss: 10878.7959 - salida_clase_accuracy: 0.5059 - salidas_continuas_mae: 56.8764 - val_loss: 10687.5596 - val_salida_clase_accuracy: 0.5770 - val_salidas_continuas_mae: 53.7529 - learning_rate: 5.0000e-04
# Epoch 20/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 10878.1572 - salida_clase_accuracy: 0.5038 - salidas_continuas_mae: 56.5569 - val_loss: 10119.7158 - val_salida_clase_accuracy: 0.5782 - val_salidas_continuas_mae: 52.9306 - learning_rate: 5.0000e-04
# Epoch 21/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 10569.3740 - salida_clase_accuracy: 0.5019 - salidas_continuas_mae: 55.9558 - val_loss: 9456.7617 - val_salida_clase_accuracy: 0.5773 - val_salidas_continuas_mae: 51.5883 - learning_rate: 5.0000e-04
# Epoch 22/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 10340.8018 - salida_clase_accuracy: 0.5049 - salidas_continuas_mae: 55.0631 - val_loss: 9062.3408 - val_salida_clase_accuracy: 0.5479 - val_salidas_continuas_mae: 50.9541 - learning_rate: 5.0000e-04
# Epoch 23/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 24s 25ms/step - loss: 10066.9590 - salida_clase_accuracy: 0.5068 - salidas_continuas_mae: 54.4197 - val_loss: 9092.3604 - val_salida_clase_accuracy: 0.5770 - val_salidas_continuas_mae: 50.7073 - learning_rate: 5.0000e-04
# Epoch 24/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 28s 28ms/step - loss: 10118.0391 - salida_clase_accuracy: 0.4992 - salidas_continuas_mae: 54.3768 - val_loss: 8611.0049 - val_salida_clase_accuracy: 0.5885 - val_salidas_continuas_mae: 49.2804 - learning_rate: 5.0000e-04
# Epoch 25/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 9813.9014 - salida_clase_accuracy: 0.5133 - salidas_continuas_mae: 53.4391 - val_loss: 8756.0244 - val_salida_clase_accuracy: 0.5630 - val_salidas_continuas_mae: 49.7005 - learning_rate: 5.0000e-04
# Epoch 26/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 9662.0508 - salida_clase_accuracy: 0.5152 - salidas_continuas_mae: 52.9772 - val_loss: 8201.9248 - val_salida_clase_accuracy: 0.5857 - val_salidas_continuas_mae: 48.0507 - learning_rate: 5.0000e-04
# Epoch 27/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 9660.6484 - salida_clase_accuracy: 0.5128 - salidas_continuas_mae: 52.7826 - val_loss: 8502.0908 - val_salida_clase_accuracy: 0.5863 - val_salidas_continuas_mae: 48.3198 - learning_rate: 5.0000e-04
# Epoch 28/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 9508.2285 - salida_clase_accuracy: 0.5141 - salidas_continuas_mae: 52.4806 - val_loss: 8177.0630 - val_salida_clase_accuracy: 0.6132 - val_salidas_continuas_mae: 47.4961 - learning_rate: 5.0000e-04
# Epoch 29/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 24s 24ms/step - loss: 9329.5732 - salida_clase_accuracy: 0.5277 - salidas_continuas_mae: 51.6307 - val_loss: 7592.7510 - val_salida_clase_accuracy: 0.5991 - val_salidas_continuas_mae: 46.7492 - learning_rate: 5.0000e-04
# Epoch 30/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 9246.0039 - salida_clase_accuracy: 0.5238 - salidas_continuas_mae: 51.5394 - val_loss: 7659.0161 - val_salida_clase_accuracy: 0.6123 - val_salidas_continuas_mae: 46.4418 - learning_rate: 5.0000e-04
# Epoch 31/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 23s 23ms/step - loss: 9297.7686 - salida_clase_accuracy: 0.5295 - salidas_continuas_mae: 51.3466 - val_loss: 7861.0166 - val_salida_clase_accuracy: 0.5867 - val_salidas_continuas_mae: 46.7284 - learning_rate: 5.0000e-04
# Epoch 32/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 8829.0088 - salida_clase_accuracy: 0.5268 - salidas_continuas_mae: 50.3532 - val_loss: 7251.2925 - val_salida_clase_accuracy: 0.6204 - val_salidas_continuas_mae: 45.6910 - learning_rate: 5.0000e-04
# Epoch 33/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 8677.5791 - salida_clase_accuracy: 0.5318 - salidas_continuas_mae: 50.0285 - val_loss: 7230.6870 - val_salida_clase_accuracy: 0.5980 - val_salidas_continuas_mae: 45.5463 - learning_rate: 5.0000e-04
# Epoch 34/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 8834.0244 - salida_clase_accuracy: 0.5370 - salidas_continuas_mae: 50.0356 - val_loss: 9069.6367 - val_salida_clase_accuracy: 0.6038 - val_salidas_continuas_mae: 49.1747 - learning_rate: 5.0000e-04
# Epoch 35/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 8896.4541 - salida_clase_accuracy: 0.5398 - salidas_continuas_mae: 50.1206 - val_loss: 6870.0811 - val_salida_clase_accuracy: 0.6310 - val_salidas_continuas_mae: 44.2419 - learning_rate: 5.0000e-04
# Epoch 36/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - loss: 8700.9199 - salida_clase_accuracy: 0.5446 - salidas_continuas_mae: 49.5755 - val_loss: 6771.1602 - val_salida_clase_accuracy: 0.6342 - val_salidas_continuas_mae: 44.3653 - learning_rate: 5.0000e-04
# Epoch 37/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 25s 25ms/step - loss: 8711.2451 - salida_clase_accuracy: 0.5497 - salidas_continuas_mae: 49.7450 - val_loss: 6752.1582 - val_salida_clase_accuracy: 0.6573 - val_salidas_continuas_mae: 43.9611 - learning_rate: 5.0000e-04
# Epoch 38/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 8619.9912 - salida_clase_accuracy: 0.5543 - salidas_continuas_mae: 49.1717 - val_loss: 6992.2222 - val_salida_clase_accuracy: 0.6513 - val_salidas_continuas_mae: 44.0011 - learning_rate: 5.0000e-04
# Epoch 39/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 8416.4609 - salida_clase_accuracy: 0.5565 - salidas_continuas_mae: 48.8897 - val_loss: 6798.5527 - val_salida_clase_accuracy: 0.6527 - val_salidas_continuas_mae: 43.7144 - learning_rate: 5.0000e-04
# Epoch 40/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8221.1699 - salida_clase_accuracy: 0.5595 - salidas_continuas_mae: 48.4057 - val_loss: 6614.1035 - val_salida_clase_accuracy: 0.6535 - val_salidas_continuas_mae: 43.1688 - learning_rate: 5.0000e-04
# Epoch 41/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 8357.1035 - salida_clase_accuracy: 0.5571 - salidas_continuas_mae: 48.7926 - val_loss: 6497.5205 - val_salida_clase_accuracy: 0.6502 - val_salidas_continuas_mae: 43.1100 - learning_rate: 5.0000e-04
# Epoch 42/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8403.6562 - salida_clase_accuracy: 0.5559 - salidas_continuas_mae: 48.4537 - val_loss: 6359.9131 - val_salida_clase_accuracy: 0.6685 - val_salidas_continuas_mae: 42.3850 - learning_rate: 5.0000e-04
# Epoch 43/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8107.4844 - salida_clase_accuracy: 0.5646 - salidas_continuas_mae: 47.8437 - val_loss: 6867.6318 - val_salida_clase_accuracy: 0.6600 - val_salidas_continuas_mae: 43.5370 - learning_rate: 5.0000e-04
# Epoch 44/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8224.6982 - salida_clase_accuracy: 0.5617 - salidas_continuas_mae: 48.1875 - val_loss: 6685.9385 - val_salida_clase_accuracy: 0.6458 - val_salidas_continuas_mae: 43.5911 - learning_rate: 5.0000e-04
# Epoch 45/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 7954.8896 - salida_clase_accuracy: 0.5754 - salidas_continuas_mae: 47.3191 - val_loss: 6389.1836 - val_salida_clase_accuracy: 0.6715 - val_salidas_continuas_mae: 42.6254 - learning_rate: 5.0000e-04
# Epoch 46/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8120.6270 - salida_clase_accuracy: 0.5661 - salidas_continuas_mae: 47.6838 - val_loss: 6430.0591 - val_salida_clase_accuracy: 0.6591 - val_salidas_continuas_mae: 43.0035 - learning_rate: 5.0000e-04
# Epoch 47/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8006.1807 - salida_clase_accuracy: 0.5663 - salidas_continuas_mae: 47.2469 - val_loss: 6542.9741 - val_salida_clase_accuracy: 0.6658 - val_salidas_continuas_mae: 42.7963 - learning_rate: 5.0000e-04
# Epoch 48/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 7916.4204 - salida_clase_accuracy: 0.5799 - salidas_continuas_mae: 46.9151 - val_loss: 6382.8218 - val_salida_clase_accuracy: 0.6430 - val_salidas_continuas_mae: 42.7066 - learning_rate: 2.5000e-04
# Epoch 49/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8074.2412 - salida_clase_accuracy: 0.5767 - salidas_continuas_mae: 47.2470 - val_loss: 6228.3862 - val_salida_clase_accuracy: 0.6771 - val_salidas_continuas_mae: 41.9673 - learning_rate: 2.5000e-04
# Epoch 50/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8037.9556 - salida_clase_accuracy: 0.5785 - salidas_continuas_mae: 47.2548 - val_loss: 6085.6128 - val_salida_clase_accuracy: 0.6693 - val_salidas_continuas_mae: 41.1021 - learning_rate: 2.5000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 5359.9546 - salida_clase_accuracy: 0.7041 - salidas_continuas_mae: 40.6415
# Fold 5: Loss=6085.61279296875, MAE=41.10211181640625, Accuracy=0.6693486571311951
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 5955.77265625
# MAE: 41.10297733204411
# MSE: 5954.840694932865
# RMSE: 77.14248344697205
# R^2: 0.7220977242711655
# Accuracy: 0.6525937557220459
# Precisión: 0.655510505207803
# Recall: 0.6525937537764979
# F1-Score: 0.6376117293408846
