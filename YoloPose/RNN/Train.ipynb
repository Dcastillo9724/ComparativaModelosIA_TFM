# %%
import joblib
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
# Definir rutas
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_raiz = os.path.dirname(carpeta_mediapipe)

ruta_npy = os.path.join(ruta_actual, 'datos', 'classes_3.npy')
ruta_scaler = os.path.join(ruta_actual, 'datos', 'scaler_X_3.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model_3.h5')
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Videos_Pose', 'pose_data.csv')

# Cargar el dataset
data = pd.read_csv(ruta_csv)

# Preparar entradas (Keypoints)
num_keypoints = 17 * 3
X = data.iloc[:, :num_keypoints].values

# Las siguientes 11 columnas incluyen:
# 10 características continuas (ángulos, distancias) + 1 tipo de ejercicio (última columna)
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

# Codificar la etiqueta del tipo de ejercicio
encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

# Normalizar las entradas
scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform(X)

# Reshape para LSTM
X_scaled = X_scaled[:, :, np.newaxis]  # Añadir una dimensión para el LSTM

# Definir función para crear el modelo
def create_model(input_shape, num_clases, learning_rate=0.001):
    input_layer = Input(shape=input_shape)

    # Capas LSTM con Dropout
    x = LSTM(128, dropout=0.2, recurrent_dropout=0.2)(input_layer)

    # Salidas continuas (10 características)
    salidas_continuas = Dense(10, activation='linear', name='salidas_continuas')(x)

    # Salida de tipo de ejercicio (multiclase)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)

    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer,
                  loss={
                      'salidas_continuas': 'mean_squared_error',
                      'salida_clase': 'sparse_categorical_crossentropy'
                  },
                  metrics={
                      'salidas_continuas': 'mae',
                      'salida_clase': 'accuracy'
                  })
    return model

# Inicializar KFold y métricas
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

# Matrices para almacenar la historia del entrenamiento
n_epochs = 50  # Número de épocas
all_train_loss = np.full((n_splits, n_epochs), np.nan)  
all_val_loss = np.full((n_splits, n_epochs), np.nan)
all_train_accuracy = np.full((n_splits, n_epochs), np.nan)
all_val_accuracy = np.full((n_splits, n_epochs), np.nan)

# Validación cruzada
for fold, (train_index, val_index) in enumerate(kf.split(X_scaled)):
    print(f"Entrenando fold {fold + 1}...")

    X_train_fold, X_val_fold = X_scaled[train_index], X_scaled[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas[train_index], y_continuas[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_encoded[train_index], y_clase_encoded[val_index]

    model = create_model(input_shape=(X_train_fold.shape[1], X_train_fold.shape[2]), num_clases=num_clases, learning_rate=0.0005)

    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold + 1}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    # Almacenar la historia del entrenamiento como matrices NumPy
    epochs_completed = len(history.history['loss'])
    all_train_loss[fold, :epochs_completed] = history.history['loss']
    all_val_loss[fold, :epochs_completed] = history.history['val_loss']
    all_train_accuracy[fold, :epochs_completed] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold, :epochs_completed] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de validación
    scores = model.evaluate(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold})
    print(f"Fold {fold + 1}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_val_fold)[0]
    mae = mean_absolute_error(y_continuas_val_fold, y_pred_continuas)
    mse = mean_squared_error(y_continuas_val_fold, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_val_fold)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_val_fold)[1], axis=1)
    precision = precision_score(y_clase_val_fold, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_val_fold, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_val_fold, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_val_fold, y_pred_clase, labels=np.unique(y_clase_val_fold))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión ')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 23s 21ms/step - loss: 31791.3730 - salida_clase_accuracy: 0.2201 - salidas_continuas_mae: 106.7163 - val_loss: 25252.9180 - val_salida_clase_accuracy: 0.1769 - val_salidas_continuas_mae: 83.7970 - learning_rate: 5.0000e-04
# Epoch 2/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - loss: 23398.3066 - salida_clase_accuracy: 0.2189 - salidas_continuas_mae: 79.4192 - val_loss: 21045.5352 - val_salida_clase_accuracy: 0.2208 - val_salidas_continuas_mae: 72.6405 - learning_rate: 5.0000e-04
# Epoch 3/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 19230.6797 - salida_clase_accuracy: 0.2245 - salidas_continuas_mae: 70.2996 - val_loss: 19036.7188 - val_salida_clase_accuracy: 0.2208 - val_salidas_continuas_mae: 70.2141 - learning_rate: 5.0000e-04
# Epoch 4/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 24s 24ms/step
50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 28s 29ms/step - loss: 16071.2920 - salida_clase_accuracy: 0.2653 - salidas_continuas_mae: 69.9854 - val_loss: 15923.2617 - val_salida_clase_accuracy: 0.3205 - val_salidas_continuas_mae: 68.4897 - learning_rate: 5.0000e-04
# Epoch 13/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 28s 29ms/step - loss: 15829.8584 - salida_clase_accuracy: 0.2765 - salidas_continuas_mae: 69.1383 - val_loss: 14849.9111 - val_salida_clase_accuracy: 0.2858 - val_salidas_continuas_mae: 67.5607 - learning_rate: 5.0000e-04
# Epoch 14/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 28s 28ms/step - loss: 15230.2051 - salida_clase_accuracy: 0.2760 - salidas_continuas_mae: 67.6238 - val_loss: 14037.3408 - val_salida_clase_accuracy: 0.2858 - val_salidas_continuas_mae: 65.8342 - learning_rate: 5.0000e-04
# Epoch 15/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 27s 27ms/step - loss: 14700.8213 - salida_clase_accuracy: 0.2810 - salidas_continuas_mae: 66.9133 - val_loss: 14703.8506 - val_salida_clase_accuracy: 0.2772 - val_salidas_continuas_mae: 66.8513 - learning_rate: 5.0000e-04
# Epoch 16/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 27s 28ms/step - loss: 15241.0996 - salida_clase_accuracy: 0.2731 - salidas_continuas_mae: 67.6102 - val_loss: 13922.1680 - val_salida_clase_accuracy: 0.3162 - val_salidas_continuas_mae: 64.8809 - learning_rate: 5.0000e-04
# Epoch 17/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 24s 24ms/step - loss: 15093.3223 - salida_clase_accuracy: 0.3156 - salidas_continuas_mae: 67.1825 - val_loss: 13346.4609 - val_salida_clase_accuracy: 0.3701 - val_salidas_continuas_mae: 62.7562 - learning_rate: 5.0000e-04
# Epoch 18/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 14232.9805 - salida_clase_accuracy: 0.3322 - salidas_continuas_mae: 64.7916 - val_loss: 12996.2432 - val_salida_clase_accuracy: 0.3372 - val_salidas_continuas_mae: 62.0469 - learning_rate: 5.0000e-04
# Epoch 19/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 13811.6670 - salida_clase_accuracy: 0.2977 - salidas_continuas_mae: 64.3170 - val_loss: 12777.0928 - val_salida_clase_accuracy: 0.3261 - val_salidas_continuas_mae: 61.5661 - learning_rate: 5.0000e-04
# Epoch 20/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 13759.5078 - salida_clase_accuracy: 0.3094 - salidas_continuas_mae: 64.1660 - val_loss: 12510.4258 - val_salida_clase_accuracy: 0.3431 - val_salidas_continuas_mae: 60.8121 - learning_rate: 5.0000e-04
# Epoch 21/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 13533.5723 - salida_clase_accuracy: 0.3289 - salidas_continuas_mae: 63.4380 - val_loss: 12664.3271 - val_salida_clase_accuracy: 0.4090 - val_salidas_continuas_mae: 60.0757 - learning_rate: 5.0000e-04
# Epoch 22/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 13312.8262 - salida_clase_accuracy: 0.3448 - salidas_continuas_mae: 62.9169 - val_loss: 12596.4004 - val_salida_clase_accuracy: 0.3915 - val_salidas_continuas_mae: 59.7481 - learning_rate: 5.0000e-04
# Epoch 23/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 13108.6172 - salida_clase_accuracy: 0.3623 - salidas_continuas_mae: 62.3428 - val_loss: 11842.9834 - val_salida_clase_accuracy: 0.4277 - val_salidas_continuas_mae: 59.0587 - learning_rate: 5.0000e-04
# Epoch 24/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 13004.0967 - salida_clase_accuracy: 0.3825 - salidas_continuas_mae: 61.9430 - val_loss: 11585.7002 - val_salida_clase_accuracy: 0.4597 - val_salidas_continuas_mae: 57.2052 - learning_rate: 5.0000e-04
# Epoch 25/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 12538.9932 - salida_clase_accuracy: 0.3732 - salidas_continuas_mae: 60.9090 - val_loss: 11612.2930 - val_salida_clase_accuracy: 0.4657 - val_salidas_continuas_mae: 56.7245 - learning_rate: 5.0000e-04
# Epoch 26/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 12243.8242 - salida_clase_accuracy: 0.3949 - salidas_continuas_mae: 60.1501 - val_loss: 10541.0898 - val_salida_clase_accuracy: 0.4965 - val_salidas_continuas_mae: 55.6270 - learning_rate: 5.0000e-04
# Epoch 27/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 11845.4512 - salida_clase_accuracy: 0.4185 - salidas_continuas_mae: 59.2335 - val_loss: 11297.6201 - val_salida_clase_accuracy: 0.4961 - val_salidas_continuas_mae: 55.7251 - learning_rate: 5.0000e-04
# Epoch 28/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 11699.9414 - salida_clase_accuracy: 0.4555 - salidas_continuas_mae: 58.5158 - val_loss: 10029.6318 - val_salida_clase_accuracy: 0.5486 - val_salidas_continuas_mae: 53.8650 - learning_rate: 5.0000e-04
# Epoch 29/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 11476.6621 - salida_clase_accuracy: 0.4647 - salidas_continuas_mae: 58.0706 - val_loss: 10333.2637 - val_salida_clase_accuracy: 0.5534 - val_salidas_continuas_mae: 54.0813 - learning_rate: 5.0000e-04
# Epoch 30/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 11189.1816 - salida_clase_accuracy: 0.4810 - salidas_continuas_mae: 57.5312 - val_loss: 9950.9170 - val_salida_clase_accuracy: 0.5686 - val_salidas_continuas_mae: 52.9131 - learning_rate: 5.0000e-04
# Epoch 31/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 11219.4248 - salida_clase_accuracy: 0.4842 - salidas_continuas_mae: 57.1434 - val_loss: 9629.2021 - val_salida_clase_accuracy: 0.5566 - val_salidas_continuas_mae: 52.4693 - learning_rate: 5.0000e-04
# Epoch 32/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 10901.6982 - salida_clase_accuracy: 0.4889 - salidas_continuas_mae: 56.5686 - val_loss: 9658.3242 - val_salida_clase_accuracy: 0.5700 - val_salidas_continuas_mae: 52.4369 - learning_rate: 5.0000e-04
# Epoch 33/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 10848.3418 - salida_clase_accuracy: 0.4900 - salidas_continuas_mae: 56.2775 - val_loss: 10627.3809 - val_salida_clase_accuracy: 0.5621 - val_salidas_continuas_mae: 53.4931 - learning_rate: 5.0000e-04
# Epoch 34/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 10691.9766 - salida_clase_accuracy: 0.4936 - salidas_continuas_mae: 55.6210 - val_loss: 8960.8984 - val_salida_clase_accuracy: 0.5691 - val_salidas_continuas_mae: 50.8169 - learning_rate: 5.0000e-04
# Epoch 35/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 10441.1924 - salida_clase_accuracy: 0.5068 - salidas_continuas_mae: 54.9175 - val_loss: 8644.4795 - val_salida_clase_accuracy: 0.5703 - val_salidas_continuas_mae: 50.0297 - learning_rate: 5.0000e-04
# Epoch 36/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 10376.7744 - salida_clase_accuracy: 0.4954 - salidas_continuas_mae: 54.7930 - val_loss: 9209.8760 - val_salida_clase_accuracy: 0.5522 - val_salidas_continuas_mae: 50.6460 - learning_rate: 5.0000e-04
# Epoch 37/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 10196.4121 - salida_clase_accuracy: 0.4956 - salidas_continuas_mae: 54.2881 - val_loss: 9417.5234 - val_salida_clase_accuracy: 0.5661 - val_salidas_continuas_mae: 50.3666 - learning_rate: 5.0000e-04
# Epoch 38/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 10271.4463 - salida_clase_accuracy: 0.5005 - salidas_continuas_mae: 54.2905 - val_loss: 8203.5674 - val_salida_clase_accuracy: 0.5790 - val_salidas_continuas_mae: 48.6365 - learning_rate: 5.0000e-04
# Epoch 39/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 9959.3848 - salida_clase_accuracy: 0.5080 - salidas_continuas_mae: 53.5784 - val_loss: 8166.0522 - val_salida_clase_accuracy: 0.5704 - val_salidas_continuas_mae: 48.6721 - learning_rate: 5.0000e-04
# Epoch 40/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9979.3281 - salida_clase_accuracy: 0.5128 - salidas_continuas_mae: 53.3932 - val_loss: 8173.0103 - val_salida_clase_accuracy: 0.5717 - val_salidas_continuas_mae: 48.0372 - learning_rate: 5.0000e-04
# Epoch 41/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9667.3672 - salida_clase_accuracy: 0.5138 - salidas_continuas_mae: 52.5623 - val_loss: 8159.0664 - val_salida_clase_accuracy: 0.5716 - val_salidas_continuas_mae: 48.0200 - learning_rate: 5.0000e-04
# Epoch 42/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 9743.7588 - salida_clase_accuracy: 0.5157 - salidas_continuas_mae: 52.6361 - val_loss: 7706.7524 - val_salida_clase_accuracy: 0.6053 - val_salidas_continuas_mae: 47.3659 - learning_rate: 5.0000e-04
# Epoch 43/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 9654.8945 - salida_clase_accuracy: 0.5220 - salidas_continuas_mae: 52.2299 - val_loss: 7996.0977 - val_salida_clase_accuracy: 0.5820 - val_salidas_continuas_mae: 47.0797 - learning_rate: 5.0000e-04
# Epoch 44/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 9691.5020 - salida_clase_accuracy: 0.5180 - salidas_continuas_mae: 52.0860 - val_loss: 7448.2002 - val_salida_clase_accuracy: 0.5924 - val_salidas_continuas_mae: 46.0026 - learning_rate: 5.0000e-04
# Epoch 45/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 9476.7803 - salida_clase_accuracy: 0.5197 - salidas_continuas_mae: 51.5414 - val_loss: 7769.3428 - val_salida_clase_accuracy: 0.5824 - val_salidas_continuas_mae: 46.3873 - learning_rate: 5.0000e-04
# Epoch 46/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9371.3076 - salida_clase_accuracy: 0.5161 - salidas_continuas_mae: 51.2331 - val_loss: 7315.9746 - val_salida_clase_accuracy: 0.5948 - val_salidas_continuas_mae: 45.6944 - learning_rate: 5.0000e-04
# Epoch 47/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 9250.9951 - salida_clase_accuracy: 0.5251 - salidas_continuas_mae: 50.8213 - val_loss: 7600.7905 - val_salida_clase_accuracy: 0.5900 - val_salidas_continuas_mae: 45.6619 - learning_rate: 5.0000e-04
# Epoch 48/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9217.6104 - salida_clase_accuracy: 0.5148 - salidas_continuas_mae: 50.8125 - val_loss: 7095.7788 - val_salida_clase_accuracy: 0.5813 - val_salidas_continuas_mae: 44.9414 - learning_rate: 5.0000e-04
# Epoch 49/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9141.3770 - salida_clase_accuracy: 0.5199 - salidas_continuas_mae: 50.5288 - val_loss: 7175.7939 - val_salida_clase_accuracy: 0.6113 - val_salidas_continuas_mae: 44.7385 - learning_rate: 5.0000e-04
# Epoch 50/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 9025.8701 - salida_clase_accuracy: 0.5172 - salidas_continuas_mae: 50.1942 - val_loss: 7427.1938 - val_salida_clase_accuracy: 0.5773 - val_salidas_continuas_mae: 45.3980 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 6166.9590 - salida_clase_accuracy: 0.6010 - salidas_continuas_mae: 44.1492
# Fold 2: Loss=7095.77880859375, MAE=44.94138717651367, Accuracy=0.5812795162200928
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Entrenando fold 3...
# Epoch 1/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - loss: 32028.2949 - salida_clase_accuracy: 0.2147 - salidas_continuas_mae: 106.5605 - val_loss: 23971.6504 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 82.4830 - learning_rate: 5.0000e-04
# Epoch 2/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 23295.3418 - salida_clase_accuracy: 0.2241 - salidas_continuas_mae: 79.3649 - val_loss: 19889.7539 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 71.5185 - learning_rate: 5.0000e-04
# Epoch 3/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 19992.4883 - salida_clase_accuracy: 0.2213 - salidas_continuas_mae: 71.1332 - val_loss: 17980.5410 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 69.1779 - learning_rate: 5.0000e-04
# Epoch 4/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 18210.0508 - salida_clase_accuracy: 0.2184 - salidas_continuas_mae: 69.4532 - val_loss: 16925.2090 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 68.9808 - learning_rate: 5.0000e-04
# Epoch 5/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 17465.3848 - salida_clase_accuracy: 0.2214 - salidas_continuas_mae: 69.8074 - val_loss: 16338.0127 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 69.2917 - learning_rate: 5.0000e-04
# Epoch 6/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 16718.9121 - salida_clase_accuracy: 0.2226 - salidas_continuas_mae: 69.6836 - val_loss: 16066.8857 - val_salida_clase_accuracy: 0.2190 - val_salidas_continuas_mae: 69.7771 - learning_rate: 5.0000e-04
# Epoch 7/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 16693.9355 - salida_clase_accuracy: 0.2240 - salidas_continuas_mae: 70.7235 - val_loss: 16075.4453 - val_salida_clase_accuracy: 0.2230 - val_salidas_continuas_mae: 70.4263 - learning_rate: 5.0000e-04
# Epoch 8/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 16676.2246 - salida_clase_accuracy: 0.2103 - salidas_continuas_mae: 71.3346 - val_loss: 15818.4170 - val_salida_clase_accuracy: 0.2684 - val_salidas_continuas_mae: 70.1138 - learning_rate: 5.0000e-04
# Epoch 9/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 16193.7305 - salida_clase_accuracy: 0.2407 - salidas_continuas_mae: 70.0647 - val_loss: 15505.5361 - val_salida_clase_accuracy: 0.2878 - val_salidas_continuas_mae: 69.7068 - learning_rate: 5.0000e-04
# Epoch 10/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 16183.2822 - salida_clase_accuracy: 0.2532 - salidas_continuas_mae: 70.0239 - val_loss: 14754.9434 - val_salida_clase_accuracy: 0.3286 - val_salidas_continuas_mae: 67.5513 - learning_rate: 5.0000e-04
# Epoch 11/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 15602.3848 - salida_clase_accuracy: 0.2716 - salidas_continuas_mae: 68.5404 - val_loss: 14293.4326 - val_salida_clase_accuracy: 0.3033 - val_salidas_continuas_mae: 65.2906 - learning_rate: 5.0000e-04
# Epoch 12/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 15166.5068 - salida_clase_accuracy: 0.2870 - salidas_continuas_mae: 67.6494 - val_loss: 13383.8428 - val_salida_clase_accuracy: 0.3251 - val_salidas_continuas_mae: 63.5754 - learning_rate: 5.0000e-04
# Epoch 13/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 14388.5312 - salida_clase_accuracy: 0.3033 - salidas_continuas_mae: 65.7729 - val_loss: 12769.9238 - val_salida_clase_accuracy: 0.3816 - val_salidas_continuas_mae: 62.0828 - learning_rate: 5.0000e-04
# Epoch 14/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 14021.3037 - salida_clase_accuracy: 0.3276 - salidas_continuas_mae: 64.7360 - val_loss: 12067.6689 - val_salida_clase_accuracy: 0.4205 - val_salidas_continuas_mae: 60.7079 - learning_rate: 5.0000e-04
# Epoch 15/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 13536.9141 - salida_clase_accuracy: 0.3628 - salidas_continuas_mae: 63.5911 - val_loss: 12146.0742 - val_salida_clase_accuracy: 0.4174 - val_salidas_continuas_mae: 59.9363 - learning_rate: 5.0000e-04
# Epoch 16/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 13163.9004 - salida_clase_accuracy: 0.3842 - salidas_continuas_mae: 62.4843 - val_loss: 12191.0742 - val_salida_clase_accuracy: 0.4237 - val_salidas_continuas_mae: 59.3581 - learning_rate: 5.0000e-04
# Epoch 17/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - loss: 12881.1475 - salida_clase_accuracy: 0.4022 - salidas_continuas_mae: 61.8524 - val_loss: 11614.9814 - val_salida_clase_accuracy: 0.4536 - val_salidas_continuas_mae: 58.1786 - learning_rate: 5.0000e-04
# Epoch 18/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 12528.1211 - salida_clase_accuracy: 0.4268 - salidas_continuas_mae: 60.9431 - val_loss: 10896.9238 - val_salida_clase_accuracy: 0.5388 - val_salidas_continuas_mae: 56.3638 - learning_rate: 5.0000e-04
# Epoch 19/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 12114.0234 - salida_clase_accuracy: 0.4560 - salidas_continuas_mae: 59.8691 - val_loss: 10661.7305 - val_salida_clase_accuracy: 0.5215 - val_salidas_continuas_mae: 55.4477 - learning_rate: 5.0000e-04
# Epoch 20/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 11804.4395 - salida_clase_accuracy: 0.4517 - salidas_continuas_mae: 59.3113 - val_loss: 10438.9189 - val_salida_clase_accuracy: 0.5278 - val_salidas_continuas_mae: 55.1804 - learning_rate: 5.0000e-04
# Epoch 21/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 11771.8662 - salida_clase_accuracy: 0.4760 - salidas_continuas_mae: 58.9350 - val_loss: 9817.2773 - val_salida_clase_accuracy: 0.5615 - val_salidas_continuas_mae: 54.1816 - learning_rate: 5.0000e-04
# Epoch 22/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 11577.0957 - salida_clase_accuracy: 0.4882 - salidas_continuas_mae: 58.4898 - val_loss: 10236.5391 - val_salida_clase_accuracy: 0.5356 - val_salidas_continuas_mae: 53.7442 - learning_rate: 5.0000e-04
# Epoch 23/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 11110.8271 - salida_clase_accuracy: 0.4896 - salidas_continuas_mae: 57.2676 - val_loss: 9435.9863 - val_salida_clase_accuracy: 0.5467 - val_salidas_continuas_mae: 52.1835 - learning_rate: 5.0000e-04
# Epoch 24/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 10799.6172 - salida_clase_accuracy: 0.5090 - salidas_continuas_mae: 56.2297 - val_loss: 9884.7256 - val_salida_clase_accuracy: 0.5379 - val_salidas_continuas_mae: 52.5188 - learning_rate: 5.0000e-04
# Epoch 25/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 10791.9121 - salida_clase_accuracy: 0.5105 - salidas_continuas_mae: 56.0756 - val_loss: 8847.4785 - val_salida_clase_accuracy: 0.5929 - val_salidas_continuas_mae: 51.3802 - learning_rate: 5.0000e-04
# Epoch 26/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10413.7715 - salida_clase_accuracy: 0.5106 - salidas_continuas_mae: 55.1699 - val_loss: 9366.4160 - val_salida_clase_accuracy: 0.5869 - val_salidas_continuas_mae: 51.3772 - learning_rate: 5.0000e-04
# Epoch 27/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 10240.1719 - salida_clase_accuracy: 0.5193 - salidas_continuas_mae: 54.6488 - val_loss: 8212.8467 - val_salida_clase_accuracy: 0.6061 - val_salidas_continuas_mae: 49.5299 - learning_rate: 5.0000e-04
# Epoch 28/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10168.2998 - salida_clase_accuracy: 0.5129 - salidas_continuas_mae: 54.1509 - val_loss: 8296.1484 - val_salida_clase_accuracy: 0.5790 - val_salidas_continuas_mae: 49.0737 - learning_rate: 5.0000e-04
# Epoch 29/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - loss: 10053.4502 - salida_clase_accuracy: 0.5181 - salidas_continuas_mae: 53.9469 - val_loss: 8320.1631 - val_salida_clase_accuracy: 0.5677 - val_salidas_continuas_mae: 49.0609 - learning_rate: 5.0000e-04
# Epoch 30/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 25s 26ms/step - loss: 9645.2314 - salida_clase_accuracy: 0.5245 - salidas_continuas_mae: 52.9263 - val_loss: 7801.3188 - val_salida_clase_accuracy: 0.6062 - val_salidas_continuas_mae: 47.5720 - learning_rate: 5.0000e-04
# Epoch 31/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 25s 26ms/step - loss: 9756.4551 - salida_clase_accuracy: 0.5331 - salidas_continuas_mae: 52.6745 - val_loss: 8418.7520 - val_salida_clase_accuracy: 0.5850 - val_salidas_continuas_mae: 48.5367 - learning_rate: 5.0000e-04
# Epoch 32/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 24s 25ms/step - loss: 9452.3818 - salida_clase_accuracy: 0.5217 - salidas_continuas_mae: 52.4058 - val_loss: 7677.5796 - val_salida_clase_accuracy: 0.6238 - val_salidas_continuas_mae: 47.1733 - learning_rate: 5.0000e-04
# Epoch 33/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 27s 27ms/step - loss: 9383.6904 - salida_clase_accuracy: 0.5345 - salidas_continuas_mae: 51.8679 - val_loss: 8512.1533 - val_salida_clase_accuracy: 0.5903 - val_salidas_continuas_mae: 47.2886 - learning_rate: 5.0000e-04
# Epoch 34/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 27s 28ms/step - loss: 9408.5801 - salida_clase_accuracy: 0.5372 - salidas_continuas_mae: 51.4457 - val_loss: 7481.3564 - val_salida_clase_accuracy: 0.6046 - val_salidas_continuas_mae: 46.4216 - learning_rate: 5.0000e-04
# Epoch 35/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 27s 28ms/step - loss: 9205.0674 - salida_clase_accuracy: 0.5342 - salidas_continuas_mae: 51.0730 - val_loss: 7123.0601 - val_salida_clase_accuracy: 0.6241 - val_salidas_continuas_mae: 45.4505 - learning_rate: 5.0000e-04
# Epoch 36/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 26s 26ms/step - loss: 8960.7168 - salida_clase_accuracy: 0.5427 - salidas_continuas_mae: 50.5556 - val_loss: 7245.8281 - val_salida_clase_accuracy: 0.6073 - val_salidas_continuas_mae: 45.0872 - learning_rate: 5.0000e-04
# Epoch 37/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 25s 26ms/step - loss: 9089.7002 - salida_clase_accuracy: 0.5369 - salidas_continuas_mae: 50.3838 - val_loss: 6960.1758 - val_salida_clase_accuracy: 0.6387 - val_salidas_continuas_mae: 44.8223 - learning_rate: 5.0000e-04
# Epoch 38/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 26s 26ms/step - loss: 8800.0283 - salida_clase_accuracy: 0.5520 - salidas_continuas_mae: 49.6361 - val_loss: 7272.1807 - val_salida_clase_accuracy: 0.6205 - val_salidas_continuas_mae: 45.3918 - learning_rate: 5.0000e-04
# Epoch 39/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 26s 26ms/step - loss: 8986.3730 - salida_clase_accuracy: 0.5500 - salidas_continuas_mae: 49.8896 - val_loss: 6757.4194 - val_salida_clase_accuracy: 0.6144 - val_salidas_continuas_mae: 43.8533 - learning_rate: 5.0000e-04
# Epoch 40/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 24s 25ms/step - loss: 8831.3506 - salida_clase_accuracy: 0.5529 - salidas_continuas_mae: 49.4658 - val_loss: 6774.5835 - val_salida_clase_accuracy: 0.6285 - val_salidas_continuas_mae: 43.9739 - learning_rate: 5.0000e-04
# Epoch 41/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 26s 26ms/step - loss: 8602.7471 - salida_clase_accuracy: 0.5530 - salidas_continuas_mae: 49.1460 - val_loss: 6704.4956 - val_salida_clase_accuracy: 0.6216 - val_salidas_continuas_mae: 43.6244 - learning_rate: 5.0000e-04
# Epoch 42/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 25s 26ms/step - loss: 8617.8242 - salida_clase_accuracy: 0.5552 - salidas_continuas_mae: 49.0396 - val_loss: 6414.5366 - val_salida_clase_accuracy: 0.6311 - val_salidas_continuas_mae: 42.9433 - learning_rate: 5.0000e-04
# Epoch 43/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 8584.1338 - salida_clase_accuracy: 0.5534 - salidas_continuas_mae: 48.7543 - val_loss: 6482.3267 - val_salida_clase_accuracy: 0.6354 - val_salidas_continuas_mae: 42.5089 - learning_rate: 5.0000e-04
# Epoch 44/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8362.7900 - salida_clase_accuracy: 0.5571 - salidas_continuas_mae: 48.2298 - val_loss: 6303.7075 - val_salida_clase_accuracy: 0.6310 - val_salidas_continuas_mae: 42.5929 - learning_rate: 5.0000e-04
# Epoch 45/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8469.7656 - salida_clase_accuracy: 0.5575 - salidas_continuas_mae: 48.2947 - val_loss: 6616.7754 - val_salida_clase_accuracy: 0.6262 - val_salidas_continuas_mae: 42.9977 - learning_rate: 5.0000e-04
# Epoch 46/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8451.2422 - salida_clase_accuracy: 0.5676 - salidas_continuas_mae: 48.2717 - val_loss: 6918.2046 - val_salida_clase_accuracy: 0.6451 - val_salidas_continuas_mae: 43.1316 - learning_rate: 5.0000e-04
# Epoch 47/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8298.7725 - salida_clase_accuracy: 0.5647 - salidas_continuas_mae: 47.9426 - val_loss: 6558.8540 - val_salida_clase_accuracy: 0.6225 - val_salidas_continuas_mae: 43.3312 - learning_rate: 5.0000e-04
# Epoch 48/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8174.1753 - salida_clase_accuracy: 0.5668 - salidas_continuas_mae: 47.6412 - val_loss: 6194.7881 - val_salida_clase_accuracy: 0.6191 - val_salidas_continuas_mae: 41.9190 - learning_rate: 5.0000e-04
# Epoch 49/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8285.1006 - salida_clase_accuracy: 0.5571 - salidas_continuas_mae: 47.7774 - val_loss: 6461.5264 - val_salida_clase_accuracy: 0.6349 - val_salidas_continuas_mae: 42.5494 - learning_rate: 5.0000e-04
# Epoch 50/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 8211.2188 - salida_clase_accuracy: 0.5692 - salidas_continuas_mae: 47.4626 - val_loss: 6210.1787 - val_salida_clase_accuracy: 0.6459 - val_salidas_continuas_mae: 42.1350 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5417.5786 - salida_clase_accuracy: 0.6751 - salidas_continuas_mae: 41.7312
# Fold 3: Loss=6194.7880859375, MAE=41.91901397705078, Accuracy=0.6190780401229858
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Entrenando fold 4...
# Epoch 1/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - loss: 31752.8066 - salida_clase_accuracy: 0.2044 - salidas_continuas_mae: 106.5352 - val_loss: 24406.9785 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 82.7395 - learning_rate: 5.0000e-04
# Epoch 2/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 23548.8828 - salida_clase_accuracy: 0.2220 - salidas_continuas_mae: 79.6824 - val_loss: 20311.9473 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 71.6163 - learning_rate: 5.0000e-04
# Epoch 3/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 19988.6367 - salida_clase_accuracy: 0.2228 - salidas_continuas_mae: 71.2294 - val_loss: 18382.0273 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 69.2425 - learning_rate: 5.0000e-04
# Epoch 4/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 18673.5879 - salida_clase_accuracy: 0.2178 - salidas_continuas_mae: 70.2032 - val_loss: 17305.2070 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 68.9212 - learning_rate: 5.0000e-04
# Epoch 5/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 17347.0859 - salida_clase_accuracy: 0.2188 - salidas_continuas_mae: 69.7011 - val_loss: 16693.7266 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 69.3295 - learning_rate: 5.0000e-04
# Epoch 6/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 16819.4160 - salida_clase_accuracy: 0.2202 - salidas_continuas_mae: 70.0999 - val_loss: 16409.0996 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 69.7965 - learning_rate: 5.0000e-04
# Epoch 7/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 16676.9102 - salida_clase_accuracy: 0.2178 - salidas_continuas_mae: 70.5703 - val_loss: 16310.1650 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 70.2553 - learning_rate: 5.0000e-04
# Epoch 8/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 16284.7236 - salida_clase_accuracy: 0.2194 - salidas_continuas_mae: 70.4963 - val_loss: 16281.8389 - val_salida_clase_accuracy: 0.2307 - val_salidas_continuas_mae: 70.1932 - learning_rate: 5.0000e-04
# Epoch 9/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 16445.0605 - salida_clase_accuracy: 0.2275 - salidas_continuas_mae: 70.6315 - val_loss: 15560.6143 - val_salida_clase_accuracy: 0.2932 - val_salidas_continuas_mae: 68.5871 - learning_rate: 5.0000e-04
# Epoch 10/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 15746.8369 - salida_clase_accuracy: 0.2728 - salidas_continuas_mae: 69.3666 - val_loss: 14347.9785 - val_salida_clase_accuracy: 0.3662 - val_salidas_continuas_mae: 66.6773 - learning_rate: 5.0000e-04
# Epoch 11/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 14716.5859 - salida_clase_accuracy: 0.3380 - salidas_continuas_mae: 67.4912 - val_loss: 13220.6699 - val_salida_clase_accuracy: 0.3968 - val_salidas_continuas_mae: 63.0683 - learning_rate: 5.0000e-04
# Epoch 12/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 14059.0420 - salida_clase_accuracy: 0.3561 - salidas_continuas_mae: 65.0448 - val_loss: 12396.1240 - val_salida_clase_accuracy: 0.4785 - val_salidas_continuas_mae: 60.2168 - learning_rate: 5.0000e-04
# Epoch 13/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 13608.8242 - salida_clase_accuracy: 0.3813 - salidas_continuas_mae: 63.3654 - val_loss: 11884.2363 - val_salida_clase_accuracy: 0.4711 - val_salidas_continuas_mae: 58.6561 - learning_rate: 5.0000e-04
# Epoch 14/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 13046.3477 - salida_clase_accuracy: 0.4026 - salidas_continuas_mae: 61.7166 - val_loss: 11575.5605 - val_salida_clase_accuracy: 0.5013 - val_salidas_continuas_mae: 57.2736 - learning_rate: 5.0000e-04
# Epoch 15/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 12644.5430 - salida_clase_accuracy: 0.4293 - salidas_continuas_mae: 60.5096 - val_loss: 11119.9326 - val_salida_clase_accuracy: 0.4917 - val_salidas_continuas_mae: 56.3728 - learning_rate: 5.0000e-04
# Epoch 16/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 12304.1113 - salida_clase_accuracy: 0.4353 - salidas_continuas_mae: 59.6655 - val_loss: 10659.0205 - val_salida_clase_accuracy: 0.5409 - val_salidas_continuas_mae: 55.0330 - learning_rate: 5.0000e-04
# Epoch 17/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 12053.6885 - salida_clase_accuracy: 0.4483 - salidas_continuas_mae: 58.8403 - val_loss: 10157.9756 - val_salida_clase_accuracy: 0.4889 - val_salidas_continuas_mae: 54.1167 - learning_rate: 5.0000e-04
# Epoch 18/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 11931.4785 - salida_clase_accuracy: 0.4344 - salidas_continuas_mae: 58.8107 - val_loss: 10322.3662 - val_salida_clase_accuracy: 0.5562 - val_salidas_continuas_mae: 54.1004 - learning_rate: 5.0000e-04
# Epoch 19/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 11546.9961 - salida_clase_accuracy: 0.4561 - salidas_continuas_mae: 57.7705 - val_loss: 9851.4824 - val_salida_clase_accuracy: 0.5573 - val_salidas_continuas_mae: 53.2171 - learning_rate: 5.0000e-04
# Epoch 20/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 11219.3984 - salida_clase_accuracy: 0.4724 - salidas_continuas_mae: 56.9313 - val_loss: 9440.7920 - val_salida_clase_accuracy: 0.5584 - val_salidas_continuas_mae: 52.2827 - learning_rate: 5.0000e-04
# Epoch 21/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 11175.8262 - salida_clase_accuracy: 0.4770 - salidas_continuas_mae: 56.6860 - val_loss: 10705.1758 - val_salida_clase_accuracy: 0.5825 - val_salidas_continuas_mae: 52.6347 - learning_rate: 5.0000e-04
# Epoch 22/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10951.1787 - salida_clase_accuracy: 0.4797 - salidas_continuas_mae: 56.2326 - val_loss: 8903.3555 - val_salida_clase_accuracy: 0.5663 - val_salidas_continuas_mae: 50.4278 - learning_rate: 5.0000e-04
# Epoch 23/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10478.5195 - salida_clase_accuracy: 0.4858 - salidas_continuas_mae: 54.9019 - val_loss: 8749.5762 - val_salida_clase_accuracy: 0.5719 - val_salidas_continuas_mae: 50.2004 - learning_rate: 5.0000e-04
# Epoch 24/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10549.1543 - salida_clase_accuracy: 0.4877 - salidas_continuas_mae: 54.9733 - val_loss: 8839.6953 - val_salida_clase_accuracy: 0.5750 - val_salidas_continuas_mae: 49.8859 - learning_rate: 5.0000e-04
# Epoch 25/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 10088.8506 - salida_clase_accuracy: 0.4961 - salidas_continuas_mae: 53.8962 - val_loss: 8191.6064 - val_salida_clase_accuracy: 0.5685 - val_salidas_continuas_mae: 48.8446 - learning_rate: 5.0000e-04
# Epoch 26/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 10360.7178 - salida_clase_accuracy: 0.4957 - salidas_continuas_mae: 54.0833 - val_loss: 8145.1465 - val_salida_clase_accuracy: 0.5844 - val_salidas_continuas_mae: 48.2982 - learning_rate: 5.0000e-04
# Epoch 27/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 10122.7080 - salida_clase_accuracy: 0.4920 - salidas_continuas_mae: 53.8263 - val_loss: 7982.1157 - val_salida_clase_accuracy: 0.5702 - val_salidas_continuas_mae: 48.4081 - learning_rate: 5.0000e-04
# Epoch 28/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 9777.8105 - salida_clase_accuracy: 0.4990 - salidas_continuas_mae: 53.0556 - val_loss: 7912.4824 - val_salida_clase_accuracy: 0.5966 - val_salidas_continuas_mae: 47.6402 - learning_rate: 5.0000e-04
# Epoch 29/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 9794.6582 - salida_clase_accuracy: 0.4977 - salidas_continuas_mae: 52.8011 - val_loss: 8141.7427 - val_salida_clase_accuracy: 0.5920 - val_salidas_continuas_mae: 47.8877 - learning_rate: 5.0000e-04
# Epoch 30/50
# ...
# Epoch 43/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 8635.2197 - salida_clase_accuracy: 0.5402 - salidas_continuas_mae: 49.0036 - val_loss: 6339.1133 - val_salida_clase_accuracy: 0.6100 - val_salidas_continuas_mae: 42.5227 - learning_rate: 5.0000e-04
# Epoch 44/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 8542.7295 - salida_clase_accuracy: 0.5310 - salidas_continuas_mae: 48.9216 - val_loss: 6247.1450 - val_salida_clase_accuracy: 0.6222 - val_salidas_continuas_mae: 42.3250 - learning_rate: 5.0000e-04
# Epoch 45/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 8422.9697 - salida_clase_accuracy: 0.5387 - salidas_continuas_mae: 48.4867 - val_loss: 6296.1289 - val_salida_clase_accuracy: 0.6243 - val_salidas_continuas_mae: 42.2970 - learning_rate: 5.0000e-04
# Epoch 46/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 8412.8965 - salida_clase_accuracy: 0.5391 - salidas_continuas_mae: 48.2168 - val_loss: 6413.6890 - val_salida_clase_accuracy: 0.6354 - val_salidas_continuas_mae: 42.4490 - learning_rate: 5.0000e-04
# Epoch 47/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8238.4688 - salida_clase_accuracy: 0.5385 - salidas_continuas_mae: 48.0060 - val_loss: 6346.1768 - val_salida_clase_accuracy: 0.6107 - val_salidas_continuas_mae: 42.4188 - learning_rate: 5.0000e-04
# Epoch 48/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8369.7549 - salida_clase_accuracy: 0.5422 - salidas_continuas_mae: 48.1213 - val_loss: 6103.5356 - val_salida_clase_accuracy: 0.6476 - val_salidas_continuas_mae: 41.8980 - learning_rate: 5.0000e-04
# Epoch 49/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8332.5078 - salida_clase_accuracy: 0.5561 - salidas_continuas_mae: 48.1216 - val_loss: 6139.0410 - val_salida_clase_accuracy: 0.6207 - val_salidas_continuas_mae: 41.8324 - learning_rate: 5.0000e-04
# Epoch 50/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 8165.8418 - salida_clase_accuracy: 0.5540 - salidas_continuas_mae: 47.6949 - val_loss: 6569.3247 - val_salida_clase_accuracy: 0.6319 - val_salidas_continuas_mae: 42.7949 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5200.4932 - salida_clase_accuracy: 0.6700 - salidas_continuas_mae: 41.3896
# Fold 4: Loss=6103.53564453125, MAE=41.89804458618164, Accuracy=0.6476373076438904
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# Entrenando fold 5...
# Epoch 1/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 32322.0312 - salida_clase_accuracy: 0.1958 - salidas_continuas_mae: 107.8851 - val_loss: 24772.3613 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 83.5752 - learning_rate: 5.0000e-04
# Epoch 2/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 23286.0039 - salida_clase_accuracy: 0.2204 - salidas_continuas_mae: 79.7172 - val_loss: 20604.6855 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 72.2915 - learning_rate: 5.0000e-04
# Epoch 3/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 19ms/step - loss: 19831.9258 - salida_clase_accuracy: 0.2213 - salidas_continuas_mae: 71.1692 - val_loss: 18665.2051 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 69.9381 - learning_rate: 5.0000e-04
# Epoch 4/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 17736.2207 - salida_clase_accuracy: 0.2198 - salidas_continuas_mae: 69.0733 - val_loss: 17572.7832 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 69.6028 - learning_rate: 5.0000e-04
# Epoch 5/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 17122.0371 - salida_clase_accuracy: 0.2261 - salidas_continuas_mae: 69.1827 - val_loss: 16992.1328 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 70.0737 - learning_rate: 5.0000e-04
# Epoch 6/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 16776.7812 - salida_clase_accuracy: 0.2235 - salidas_continuas_mae: 69.7937 - val_loss: 16723.5273 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 70.5669 - learning_rate: 5.0000e-04
# Epoch 7/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 16570.1641 - salida_clase_accuracy: 0.2171 - salidas_continuas_mae: 70.3693 - val_loss: 16642.6582 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 70.8295 - learning_rate: 5.0000e-04
# Epoch 8/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 16375.6299 - salida_clase_accuracy: 0.2223 - salidas_continuas_mae: 70.5394 - val_loss: 16600.7031 - val_salida_clase_accuracy: 0.2291 - val_salidas_continuas_mae: 70.9447 - learning_rate: 5.0000e-04
# Epoch 9/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 16362.3535 - salida_clase_accuracy: 0.2236 - salidas_continuas_mae: 70.5328 - val_loss: 16311.0557 - val_salida_clase_accuracy: 0.2342 - val_salidas_continuas_mae: 70.0313 - learning_rate: 5.0000e-04
# Epoch 10/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 15951.3604 - salida_clase_accuracy: 0.2424 - salidas_continuas_mae: 69.5437 - val_loss: 14792.7764 - val_salida_clase_accuracy: 0.2751 - val_salidas_continuas_mae: 67.6003 - learning_rate: 5.0000e-04
# Epoch 11/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 14865.9932 - salida_clase_accuracy: 0.2811 - salidas_continuas_mae: 67.7420 - val_loss: 13532.7666 - val_salida_clase_accuracy: 0.3976 - val_salidas_continuas_mae: 64.3844 - learning_rate: 5.0000e-04
# Epoch 12/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 13757.0488 - salida_clase_accuracy: 0.3319 - salidas_continuas_mae: 64.9368 - val_loss: 12684.4688 - val_salida_clase_accuracy: 0.4432 - val_salidas_continuas_mae: 61.2087 - learning_rate: 5.0000e-04
# Epoch 13/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 12990.2598 - salida_clase_accuracy: 0.3710 - salidas_continuas_mae: 62.4566 - val_loss: 13666.8125 - val_salida_clase_accuracy: 0.4858 - val_salidas_continuas_mae: 59.9959 - learning_rate: 5.0000e-04
# Epoch 14/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 12740.3008 - salida_clase_accuracy: 0.3932 - salidas_continuas_mae: 61.1493 - val_loss: 12016.4023 - val_salida_clase_accuracy: 0.4941 - val_salidas_continuas_mae: 58.2845 - learning_rate: 5.0000e-04
# Epoch 15/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 12399.6680 - salida_clase_accuracy: 0.4220 - salidas_continuas_mae: 60.1861 - val_loss: 11163.6523 - val_salida_clase_accuracy: 0.4833 - val_salidas_continuas_mae: 56.8360 - learning_rate: 5.0000e-04
# Epoch 16/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 12129.4053 - salida_clase_accuracy: 0.4122 - salidas_continuas_mae: 59.5384 - val_loss: 11503.6230 - val_salida_clase_accuracy: 0.4826 - val_salidas_continuas_mae: 56.0854 - learning_rate: 5.0000e-04
# Epoch 17/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 11445.5713 - salida_clase_accuracy: 0.4260 - salidas_continuas_mae: 58.1305 - val_loss: 10561.5566 - val_salida_clase_accuracy: 0.5323 - val_salidas_continuas_mae: 54.7806 - learning_rate: 5.0000e-04
# Epoch 18/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 11280.2939 - salida_clase_accuracy: 0.4288 - salidas_continuas_mae: 57.6435 - val_loss: 9718.3301 - val_salida_clase_accuracy: 0.5243 - val_salidas_continuas_mae: 52.9244 - learning_rate: 5.0000e-04
# Epoch 19/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - loss: 10643.0918 - salida_clase_accuracy: 0.4407 - salidas_continuas_mae: 55.9517 - val_loss: 9334.3965 - val_salida_clase_accuracy: 0.4987 - val_salidas_continuas_mae: 52.2697 - learning_rate: 5.0000e-04
# Epoch 20/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 10647.6709 - salida_clase_accuracy: 0.4539 - salidas_continuas_mae: 55.8549 - val_loss: 9472.9092 - val_salida_clase_accuracy: 0.5378 - val_salidas_continuas_mae: 51.7858 - learning_rate: 5.0000e-04
# Epoch 21/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 10392.6865 - salida_clase_accuracy: 0.4542 - salidas_continuas_mae: 55.1158 - val_loss: 8759.4746 - val_salida_clase_accuracy: 0.5146 - val_salidas_continuas_mae: 50.6153 - learning_rate: 5.0000e-04
# Epoch 22/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 10052.7676 - salida_clase_accuracy: 0.4648 - salidas_continuas_mae: 54.1617 - val_loss: 9172.3311 - val_salida_clase_accuracy: 0.5088 - val_salidas_continuas_mae: 50.9545 - learning_rate: 5.0000e-04
# Epoch 23/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 9850.8262 - salida_clase_accuracy: 0.4737 - salidas_continuas_mae: 53.6251 - val_loss: 8003.4458 - val_salida_clase_accuracy: 0.5481 - val_salidas_continuas_mae: 48.4849 - learning_rate: 5.0000e-04
# Epoch 24/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 9661.5840 - salida_clase_accuracy: 0.4759 - salidas_continuas_mae: 52.9352 - val_loss: 9187.8184 - val_salida_clase_accuracy: 0.5455 - val_salidas_continuas_mae: 50.2244 - learning_rate: 5.0000e-04
# Epoch 25/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9508.9766 - salida_clase_accuracy: 0.4821 - salidas_continuas_mae: 52.7030 - val_loss: 7631.7910 - val_salida_clase_accuracy: 0.5510 - val_salidas_continuas_mae: 47.4859 - learning_rate: 5.0000e-04
# Epoch 26/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9369.7119 - salida_clase_accuracy: 0.4784 - salidas_continuas_mae: 52.2650 - val_loss: 8016.8921 - val_salida_clase_accuracy: 0.5655 - val_salidas_continuas_mae: 47.7340 - learning_rate: 5.0000e-04
# Epoch 27/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 9035.9678 - salida_clase_accuracy: 0.4893 - salidas_continuas_mae: 51.4889 - val_loss: 7887.0479 - val_salida_clase_accuracy: 0.5584 - val_salidas_continuas_mae: 47.4023 - learning_rate: 5.0000e-04
# Epoch 28/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 9334.6455 - salida_clase_accuracy: 0.4901 - salidas_continuas_mae: 51.6280 - val_loss: 7432.7725 - val_salida_clase_accuracy: 0.5704 - val_salidas_continuas_mae: 46.7603 - learning_rate: 5.0000e-04
# Epoch 29/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 9026.9160 - salida_clase_accuracy: 0.4957 - salidas_continuas_mae: 50.9671 - val_loss: 7678.5967 - val_salida_clase_accuracy: 0.5757 - val_salidas_continuas_mae: 46.7264 - learning_rate: 5.0000e-04
# Epoch 30/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 8924.3652 - salida_clase_accuracy: 0.5028 - salidas_continuas_mae: 50.6588 - val_loss: 7288.9600 - val_salida_clase_accuracy: 0.5943 - val_salidas_continuas_mae: 45.7975 - learning_rate: 5.0000e-04
# Epoch 31/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 8698.9541 - salida_clase_accuracy: 0.5014 - salidas_continuas_mae: 50.2150 - val_loss: 6942.4526 - val_salida_clase_accuracy: 0.6208 - val_salidas_continuas_mae: 45.0213 - learning_rate: 5.0000e-04
# Epoch 32/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 8559.9824 - salida_clase_accuracy: 0.5031 - salidas_continuas_mae: 49.9463 - val_loss: 6879.7876 - val_salida_clase_accuracy: 0.5904 - val_salidas_continuas_mae: 45.1129 - learning_rate: 5.0000e-04
# Epoch 33/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 8636.5811 - salida_clase_accuracy: 0.5144 - salidas_continuas_mae: 49.8409 - val_loss: 7187.1108 - val_salida_clase_accuracy: 0.6049 - val_salidas_continuas_mae: 45.0749 - learning_rate: 5.0000e-04
# Epoch 34/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - loss: 8606.5166 - salida_clase_accuracy: 0.5189 - salidas_continuas_mae: 49.5973 - val_loss: 6909.7588 - val_salida_clase_accuracy: 0.6043 - val_salidas_continuas_mae: 44.8434 - learning_rate: 5.0000e-04
# Epoch 35/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - loss: 8569.0186 - salida_clase_accuracy: 0.5161 - salidas_continuas_mae: 49.3119 - val_loss: 6513.7900 - val_salida_clase_accuracy: 0.6248 - val_salidas_continuas_mae: 43.5886 - learning_rate: 5.0000e-04
# Epoch 36/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 8342.9336 - salida_clase_accuracy: 0.5277 - salidas_continuas_mae: 48.9004 - val_loss: 6610.1406 - val_salida_clase_accuracy: 0.6335 - val_salidas_continuas_mae: 44.1360 - learning_rate: 5.0000e-04
# Epoch 37/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 8373.2734 - salida_clase_accuracy: 0.5311 - salidas_continuas_mae: 48.7916 - val_loss: 6497.3501 - val_salida_clase_accuracy: 0.6381 - val_salidas_continuas_mae: 43.2154 - learning_rate: 5.0000e-04
# Epoch 38/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 8087.2856 - salida_clase_accuracy: 0.5285 - salidas_continuas_mae: 48.1612 - val_loss: 6596.2314 - val_salida_clase_accuracy: 0.6367 - val_salidas_continuas_mae: 43.3161 - learning_rate: 5.0000e-04
# Epoch 39/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - loss: 8359.3691 - salida_clase_accuracy: 0.5308 - salidas_continuas_mae: 48.5842 - val_loss: 6387.9478 - val_salida_clase_accuracy: 0.6295 - val_salidas_continuas_mae: 43.2029 - learning_rate: 5.0000e-04
# Epoch 40/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 8795.3975 - salida_clase_accuracy: 0.5243 - salidas_continuas_mae: 49.3066 - val_loss: 6603.1440 - val_salida_clase_accuracy: 0.6470 - val_salidas_continuas_mae: 42.7116 - learning_rate: 5.0000e-04
# Epoch 41/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - loss: 8109.1387 - salida_clase_accuracy: 0.5411 - salidas_continuas_mae: 47.5976 - val_loss: 6996.5181 - val_salida_clase_accuracy: 0.6434 - val_salidas_continuas_mae: 43.5889 - learning_rate: 5.0000e-04
# Epoch 42/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - loss: 8009.2915 - salida_clase_accuracy: 0.5479 - salidas_continuas_mae: 47.4170 - val_loss: 6083.4551 - val_salida_clase_accuracy: 0.6507 - val_salidas_continuas_mae: 41.5511 - learning_rate: 5.0000e-04
# Epoch 43/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 8210.2490 - salida_clase_accuracy: 0.5515 - salidas_continuas_mae: 47.6164 - val_loss: 6234.6582 - val_salida_clase_accuracy: 0.6199 - val_salidas_continuas_mae: 42.1099 - learning_rate: 5.0000e-04
# Epoch 44/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - loss: 8095.9839 - salida_clase_accuracy: 0.5543 - salidas_continuas_mae: 47.3094 - val_loss: 6228.7651 - val_salida_clase_accuracy: 0.6494 - val_salidas_continuas_mae: 41.4382 - learning_rate: 5.0000e-04
# Epoch 45/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - loss: 8006.8242 - salida_clase_accuracy: 0.5515 - salidas_continuas_mae: 46.9874 - val_loss: 6345.9766 - val_salida_clase_accuracy: 0.6489 - val_salidas_continuas_mae: 42.0017 - learning_rate: 5.0000e-04
# Epoch 46/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 7901.5103 - salida_clase_accuracy: 0.5669 - salidas_continuas_mae: 46.5760 - val_loss: 5812.8906 - val_salida_clase_accuracy: 0.6439 - val_salidas_continuas_mae: 40.3679 - learning_rate: 5.0000e-04
# Epoch 47/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - loss: 7861.3770 - salida_clase_accuracy: 0.5700 - salidas_continuas_mae: 46.3573 - val_loss: 5784.9756 - val_salida_clase_accuracy: 0.6793 - val_salidas_continuas_mae: 40.2826 - learning_rate: 5.0000e-04
# Epoch 48/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - loss: 7995.2080 - salida_clase_accuracy: 0.5534 - salidas_continuas_mae: 46.9286 - val_loss: 5653.5396 - val_salida_clase_accuracy: 0.6693 - val_salidas_continuas_mae: 39.7019 - learning_rate: 5.0000e-04
# Epoch 49/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - loss: 7773.9546 - salida_clase_accuracy: 0.5664 - salidas_continuas_mae: 46.3712 - val_loss: 6102.2788 - val_salida_clase_accuracy: 0.6736 - val_salidas_continuas_mae: 40.2433 - learning_rate: 5.0000e-04
# Epoch 50/50
# 979/979 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 7446.2139 - salida_clase_accuracy: 0.5789 - salidas_continuas_mae: 45.2711 - val_loss: 5594.8906 - val_salida_clase_accuracy: 0.6433 - val_salidas_continuas_mae: 39.5202 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 4877.2251 - salida_clase_accuracy: 0.6727 - salidas_continuas_mae: 39.2887
# Fold 5: Loss=5594.890625, MAE=39.52023696899414, Accuracy=0.6432949900627136
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 6095.9931640625
# MAE: 41.61444782395237
# MSE: 6095.028192327997
# RMSE: 77.98755055671629
# R^2: 0.7150347230590091
# Accuracy: 0.6289437055587769
# Precisión: 0.6389284078289623
# Recall: 0.6289437091638774
# F1-Score: 0.6163388862953608
