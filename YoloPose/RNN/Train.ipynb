# %%
import joblib
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, BatchNormalization, Activation, Dropout, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Bidirectional, Attention, Concatenate

# Cargar datos
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Pose', 'pose_data_images_2.csv')
ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual, 'datos', 'scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')

data = pd.read_csv(ruta_csv)

# Preparar datos
num_keypoints = 17 * 3
X = data.iloc[:, :num_keypoints].values
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

X_train, X_test, y_continuas_train, y_continuas_test, y_clase_train, y_clase_test = train_test_split(
    X, y_continuas, y_clase_encoded, test_size=0.2, random_state=42)

scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

X_train_rnn = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_rnn = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

# Función para crear el modelo con ajustes adicionales
def create_model(learning_rate=0.001):
    input_layer = Input(shape=(X_train_rnn.shape[1], X_train_rnn.shape[2]))

    # Capas Bidireccionales LSTM
    x = Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=l2(0.001)))(input_layer)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.4)(x)
    
    x = Bidirectional(LSTM(64, return_sequences=True, kernel_regularizer=l2(0.001)))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.4)(x)
    
    # Aplicar mecanismo de atención
    attention = Attention()([x, x])
    x = Concatenate()([x, attention])
    
    x = Flatten()(x)
    
    salidas_continuas = Dense(6, activation='linear', name='salidas_continuas')(x)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)
    
    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])
    
    optimizer = Adam(learning_rate=learning_rate)
    
    model.compile(optimizer=optimizer,
                  loss={'salidas_continuas': 'mean_squared_error', 'salida_clase': 'sparse_categorical_crossentropy'},
                  metrics={'salidas_continuas': 'mae', 'salida_clase': 'accuracy'})
    
    return model
# Listas para almacenar métricas
all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

# Matrices para almacenar la historia del entrenamiento
n_epochs = 150  # Número de épocas
all_train_loss = np.full((5, n_epochs), np.nan)  
all_val_loss = np.full((5, n_epochs), np.nan)
all_train_accuracy = np.full((5, n_epochs), np.nan)
all_val_accuracy = np.full((5, n_epochs), np.nan)

# Ejecutar el entrenamiento con el modelo modificado
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

fold_index = 0
for train_index, val_index in kfold.split(X_train_rnn):
    fold_index += 1
    print(f"Entrenando fold {fold_index}...")

    X_train_fold, X_val_fold = X_train_rnn[train_index], X_train_rnn[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas_train[train_index], y_continuas_train[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_train[train_index], y_clase_train[val_index]

    model = create_model(learning_rate=0.001)  # Ajuste de tasa de aprendizaje
    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold_index}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    # Almacenar la historia del entrenamiento como matrices NumPy
    epochs_completed = len(history.history['loss'])
    all_train_loss[fold_index - 1, :epochs_completed] = history.history['loss']
    all_val_loss[fold_index - 1, :epochs_completed] = history.history['val_loss']
    all_train_accuracy[fold_index - 1, :epochs_completed] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold_index - 1, :epochs_completed] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de prueba
    scores = model.evaluate(X_test_rnn, {'salidas_continuas': y_continuas_test, 'salida_clase': y_clase_test})
    print(f"Fold {fold_index}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_test_rnn)[0]
    mae = mean_absolute_error(y_continuas_test, y_pred_continuas)
    mse = mean_squared_error(y_continuas_test, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_test)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_test_rnn)[1], axis=1)
    precision = precision_score(y_clase_test, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_test, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_test, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_test, y_pred_clase, labels=np.unique(y_clase_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión')
    plt.tight_layout()
    plt.show()

# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# Entrenando fold 1...
# Epoch 1/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 72ms/step - loss: 5106.5098 - salida_clase_accuracy: 0.3669 - salidas_continuas_mae: 56.4962 - val_loss: 7198.2739 - val_salida_clase_accuracy: 0.2730 - val_salidas_continuas_mae: 68.7697 - learning_rate: 0.0010
# Epoch 2/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1964.0983 - salida_clase_accuracy: 0.5211 - salidas_continuas_mae: 35.2774 - val_loss: 4378.6870 - val_salida_clase_accuracy: 0.2423 - val_salidas_continuas_mae: 54.2920 - learning_rate: 0.0010
# Epoch 3/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 1667.0836 - salida_clase_accuracy: 0.5595 - salidas_continuas_mae: 31.3415 - val_loss: 3776.8191 - val_salida_clase_accuracy: 0.2248 - val_salidas_continuas_mae: 50.0215 - learning_rate: 0.0010
# Epoch 4/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 1527.3235 - salida_clase_accuracy: 0.6060 - salidas_continuas_mae: 29.5070 - val_loss: 2896.4561 - val_salida_clase_accuracy: 0.4920 - val_salidas_continuas_mae: 43.7583 - learning_rate: 0.0010
# Epoch 5/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 1398.0601 - salida_clase_accuracy: 0.6331 - salidas_continuas_mae: 27.7290 - val_loss: 2121.2781 - val_salida_clase_accuracy: 0.4438 - val_salidas_continuas_mae: 36.6480 - learning_rate: 0.0010
# Epoch 6/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 1266.2329 - salida_clase_accuracy: 0.6495 - salidas_continuas_mae: 26.0255 - val_loss: 1424.8705 - val_salida_clase_accuracy: 0.6715 - val_salidas_continuas_mae: 28.4609 - learning_rate: 0.0010
# Epoch 7/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 1153.8943 - salida_clase_accuracy: 0.6906 - salidas_continuas_mae: 24.7479 - val_loss: 1387.1121 - val_salida_clase_accuracy: 0.7635 - val_salidas_continuas_mae: 27.8818 - learning_rate: 0.0010
# Epoch 8/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 1108.5471 - salida_clase_accuracy: 0.7327 - salidas_continuas_mae: 24.0653 - val_loss: 1241.5806 - val_salida_clase_accuracy: 0.7854 - val_salidas_continuas_mae: 26.3493 - learning_rate: 0.0010
# Epoch 9/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 1008.9881 - salida_clase_accuracy: 0.7231 - salidas_continuas_mae: 22.6662 - val_loss: 1066.5131 - val_salida_clase_accuracy: 0.7533 - val_salidas_continuas_mae: 23.2385 - learning_rate: 0.0010
# Epoch 10/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 943.5842 - salida_clase_accuracy: 0.7419 - salidas_continuas_mae: 21.6347 - val_loss: 1010.5689 - val_salida_clase_accuracy: 0.7737 - val_salidas_continuas_mae: 22.6563 - learning_rate: 0.0010
# Epoch 11/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 882.5526 - salida_clase_accuracy: 0.7710 - salidas_continuas_mae: 20.8609 - val_loss: 958.4070 - val_salida_clase_accuracy: 0.7591 - val_salidas_continuas_mae: 21.6207 - learning_rate: 0.0010
# Epoch 12/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 865.3297 - salida_clase_accuracy: 0.7592 - salidas_continuas_mae: 20.6416 - val_loss: 925.7037 - val_salida_clase_accuracy: 0.7693 - val_salidas_continuas_mae: 21.0492 - learning_rate: 0.0010
# Epoch 13/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 790.4497 - salida_clase_accuracy: 0.7700 - salidas_continuas_mae: 19.6752 - val_loss: 885.2012 - val_salida_clase_accuracy: 0.8044 - val_salidas_continuas_mae: 20.4991 - learning_rate: 0.0010
# Epoch 14/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 764.7691 - salida_clase_accuracy: 0.7710 - salidas_continuas_mae: 18.9535 - val_loss: 859.4727 - val_salida_clase_accuracy: 0.8248 - val_salidas_continuas_mae: 19.9145 - learning_rate: 0.0010
# Epoch 15/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 747.6595 - salida_clase_accuracy: 0.8084 - salidas_continuas_mae: 19.0735 - val_loss: 853.7790 - val_salida_clase_accuracy: 0.8277 - val_salidas_continuas_mae: 19.6297 - learning_rate: 0.0010
# Epoch 16/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 748.8050 - salida_clase_accuracy: 0.8036 - salidas_continuas_mae: 19.0047 - val_loss: 785.5866 - val_salida_clase_accuracy: 0.8219 - val_salidas_continuas_mae: 18.7928 - learning_rate: 0.0010
# Epoch 17/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 684.5566 - salida_clase_accuracy: 0.8278 - salidas_continuas_mae: 17.6951 - val_loss: 785.0093 - val_salida_clase_accuracy: 0.8409 - val_salidas_continuas_mae: 18.8314 - learning_rate: 0.0010
# Epoch 18/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 650.3256 - salida_clase_accuracy: 0.8220 - salidas_continuas_mae: 17.5098 - val_loss: 747.0251 - val_salida_clase_accuracy: 0.8307 - val_salidas_continuas_mae: 18.2684 - learning_rate: 0.0010
# Epoch 19/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 8s 89ms/step - loss: 653.4425 - salida_clase_accuracy: 0.8323 - salidas_continuas_mae: 17.6523 - val_loss: 816.4773 - val_salida_clase_accuracy: 0.8584 - val_salidas_continuas_mae: 19.6813 - learning_rate: 0.0010
# Epoch 20/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 625.5469 - salida_clase_accuracy: 0.8255 - salidas_continuas_mae: 17.2622 - val_loss: 801.3815 - val_salida_clase_accuracy: 0.8438 - val_salidas_continuas_mae: 19.1275 - learning_rate: 0.0010
# Epoch 21/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 642.3389 - salida_clase_accuracy: 0.8410 - salidas_continuas_mae: 17.4710 - val_loss: 702.9609 - val_salida_clase_accuracy: 0.8350 - val_salidas_continuas_mae: 17.5143 - learning_rate: 0.0010
# Epoch 22/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - loss: 612.0980 - salida_clase_accuracy: 0.8451 - salidas_continuas_mae: 16.8457 - val_loss: 701.2723 - val_salida_clase_accuracy: 0.8832 - val_salidas_continuas_mae: 17.1112 - learning_rate: 0.0010
# Epoch 23/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 596.7304 - salida_clase_accuracy: 0.8403 - salidas_continuas_mae: 16.7185 - val_loss: 763.9924 - val_salida_clase_accuracy: 0.8584 - val_salidas_continuas_mae: 18.1242 - learning_rate: 0.0010
# Epoch 24/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step
150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - loss: 270.5726 - salida_clase_accuracy: 0.9380 - salidas_continuas_mae: 11.4324 - val_loss: 494.9980 - val_salida_clase_accuracy: 0.9270 - val_salidas_continuas_mae: 12.4829 - learning_rate: 6.2500e-05
# Epoch 85/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 9s 108ms/step - loss: 276.2462 - salida_clase_accuracy: 0.9453 - salidas_continuas_mae: 11.5569 - val_loss: 497.4280 - val_salida_clase_accuracy: 0.9285 - val_salidas_continuas_mae: 12.5109 - learning_rate: 6.2500e-05
# Epoch 86/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 9s 109ms/step - loss: 280.7062 - salida_clase_accuracy: 0.9499 - salidas_continuas_mae: 11.3968 - val_loss: 492.9115 - val_salida_clase_accuracy: 0.9270 - val_salidas_continuas_mae: 12.4382 - learning_rate: 6.2500e-05
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 403.0643 - salida_clase_accuracy: 0.9225 - salidas_continuas_mae: 11.4418
# Fold 1: Loss=417.19378662109375, MAE=11.725088119506836, Accuracy=0.9334112405776978
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# Entrenando fold 2...
# Epoch 1/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 18s 95ms/step - loss: 5283.1714 - salida_clase_accuracy: 0.3770 - salidas_continuas_mae: 57.4526 - val_loss: 7111.2739 - val_salida_clase_accuracy: 0.4190 - val_salidas_continuas_mae: 67.6055 - learning_rate: 0.0010
# Epoch 2/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 2006.4918 - salida_clase_accuracy: 0.4912 - salidas_continuas_mae: 35.8759 - val_loss: 4893.7090 - val_salida_clase_accuracy: 0.3854 - val_salidas_continuas_mae: 56.4277 - learning_rate: 0.0010
# Epoch 3/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 1694.0242 - salida_clase_accuracy: 0.5525 - salidas_continuas_mae: 31.8471 - val_loss: 3324.0002 - val_salida_clase_accuracy: 0.4847 - val_salidas_continuas_mae: 47.4630 - learning_rate: 0.0010
# Epoch 4/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 1494.8699 - salida_clase_accuracy: 0.6142 - salidas_continuas_mae: 29.1241 - val_loss: 2120.6812 - val_salida_clase_accuracy: 0.5562 - val_salidas_continuas_mae: 37.4294 - learning_rate: 0.0010
# Epoch 5/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 1430.6277 - salida_clase_accuracy: 0.6699 - salidas_continuas_mae: 28.0770 - val_loss: 1718.1597 - val_salida_clase_accuracy: 0.6277 - val_salidas_continuas_mae: 32.5339 - learning_rate: 0.0010
# Epoch 6/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 1224.7991 - salida_clase_accuracy: 0.6625 - salidas_continuas_mae: 25.4703 - val_loss: 1312.4052 - val_salida_clase_accuracy: 0.6788 - val_salidas_continuas_mae: 26.3248 - learning_rate: 0.0010
# Epoch 7/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 1130.1743 - salida_clase_accuracy: 0.7040 - salidas_continuas_mae: 24.3057 - val_loss: 1255.0017 - val_salida_clase_accuracy: 0.6964 - val_salidas_continuas_mae: 24.7854 - learning_rate: 0.0010
# Epoch 8/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 1025.3551 - salida_clase_accuracy: 0.7263 - salidas_continuas_mae: 22.8692 - val_loss: 1131.1736 - val_salida_clase_accuracy: 0.7401 - val_salidas_continuas_mae: 23.3818 - learning_rate: 0.0010
# Epoch 9/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 1024.8517 - salida_clase_accuracy: 0.7359 - salidas_continuas_mae: 22.7194 - val_loss: 1008.5223 - val_salida_clase_accuracy: 0.7635 - val_salidas_continuas_mae: 22.0363 - learning_rate: 0.0010
# Epoch 10/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 925.5048 - salida_clase_accuracy: 0.7334 - salidas_continuas_mae: 21.4711 - val_loss: 906.4056 - val_salida_clase_accuracy: 0.7577 - val_salidas_continuas_mae: 20.9081 - learning_rate: 0.0010
# Epoch 11/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - loss: 880.4449 - salida_clase_accuracy: 0.7652 - salidas_continuas_mae: 20.6985 - val_loss: 822.7640 - val_salida_clase_accuracy: 0.7956 - val_salidas_continuas_mae: 19.1571 - learning_rate: 0.0010
# Epoch 12/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 821.9796 - salida_clase_accuracy: 0.7729 - salidas_continuas_mae: 20.0734 - val_loss: 923.9808 - val_salida_clase_accuracy: 0.7883 - val_salidas_continuas_mae: 20.8449 - learning_rate: 0.0010
# Epoch 13/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 758.1940 - salida_clase_accuracy: 0.7920 - salidas_continuas_mae: 18.9658 - val_loss: 840.6324 - val_salida_clase_accuracy: 0.7956 - val_salidas_continuas_mae: 19.5917 - learning_rate: 0.0010
# Epoch 14/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 753.6008 - salida_clase_accuracy: 0.8048 - salidas_continuas_mae: 19.0485 - val_loss: 795.2625 - val_salida_clase_accuracy: 0.7562 - val_salidas_continuas_mae: 19.0538 - learning_rate: 0.0010
# Epoch 15/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 717.5169 - salida_clase_accuracy: 0.8042 - salidas_continuas_mae: 18.5155 - val_loss: 707.1058 - val_salida_clase_accuracy: 0.7474 - val_salidas_continuas_mae: 17.5396 - learning_rate: 0.0010
# Epoch 16/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 706.0159 - salida_clase_accuracy: 0.8196 - salidas_continuas_mae: 18.1122 - val_loss: 700.9660 - val_salida_clase_accuracy: 0.8219 - val_salidas_continuas_mae: 17.5159 - learning_rate: 0.0010
# Epoch 17/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 696.6013 - salida_clase_accuracy: 0.8186 - salidas_continuas_mae: 18.0129 - val_loss: 777.4513 - val_salida_clase_accuracy: 0.8058 - val_salidas_continuas_mae: 18.3763 - learning_rate: 0.0010
# Epoch 18/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 697.0748 - salida_clase_accuracy: 0.8123 - salidas_continuas_mae: 18.2225 - val_loss: 698.5644 - val_salida_clase_accuracy: 0.8336 - val_salidas_continuas_mae: 17.3649 - learning_rate: 0.0010
# Epoch 19/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 666.9160 - salida_clase_accuracy: 0.8332 - salidas_continuas_mae: 17.6574 - val_loss: 661.1408 - val_salida_clase_accuracy: 0.8321 - val_salidas_continuas_mae: 16.5973 - learning_rate: 0.0010
# Epoch 20/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 622.3011 - salida_clase_accuracy: 0.8440 - salidas_continuas_mae: 17.1563 - val_loss: 641.9717 - val_salida_clase_accuracy: 0.8409 - val_salidas_continuas_mae: 16.6629 - learning_rate: 0.0010
# Epoch 21/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 608.2159 - salida_clase_accuracy: 0.8351 - salidas_continuas_mae: 16.9051 - val_loss: 635.9565 - val_salida_clase_accuracy: 0.8131 - val_salidas_continuas_mae: 16.3485 - learning_rate: 0.0010
# Epoch 22/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 627.9475 - salida_clase_accuracy: 0.8330 - salidas_continuas_mae: 17.2772 - val_loss: 702.7162 - val_salida_clase_accuracy: 0.8555 - val_salidas_continuas_mae: 17.2084 - learning_rate: 0.0010
# Epoch 23/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 577.0184 - salida_clase_accuracy: 0.8527 - salidas_continuas_mae: 16.5630 - val_loss: 611.5475 - val_salida_clase_accuracy: 0.8029 - val_salidas_continuas_mae: 16.0366 - learning_rate: 0.0010
# Epoch 24/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 587.7234 - salida_clase_accuracy: 0.8154 - salidas_continuas_mae: 16.7789 - val_loss: 624.2048 - val_salida_clase_accuracy: 0.8467 - val_salidas_continuas_mae: 15.8845 - learning_rate: 0.0010
# Epoch 25/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 599.8326 - salida_clase_accuracy: 0.8273 - salidas_continuas_mae: 16.6465 - val_loss: 564.7233 - val_salida_clase_accuracy: 0.8686 - val_salidas_continuas_mae: 14.9620 - learning_rate: 0.0010
# Epoch 26/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 563.6103 - salida_clase_accuracy: 0.8540 - salidas_continuas_mae: 16.1546 - val_loss: 585.4985 - val_salida_clase_accuracy: 0.8628 - val_salidas_continuas_mae: 15.4441 - learning_rate: 0.0010
# Epoch 27/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 550.1035 - salida_clase_accuracy: 0.8633 - salidas_continuas_mae: 16.0606 - val_loss: 618.8675 - val_salida_clase_accuracy: 0.8467 - val_salidas_continuas_mae: 15.8629 - learning_rate: 0.0010
# Epoch 28/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 517.2233 - salida_clase_accuracy: 0.8647 - salidas_continuas_mae: 15.5279 - val_loss: 561.9312 - val_salida_clase_accuracy: 0.8715 - val_salidas_continuas_mae: 14.7419 - learning_rate: 0.0010
# Epoch 29/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 523.3762 - salida_clase_accuracy: 0.8676 - salidas_continuas_mae: 15.8014 - val_loss: 558.6287 - val_salida_clase_accuracy: 0.7869 - val_salidas_continuas_mae: 14.7067 - learning_rate: 0.0010
# Epoch 30/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 532.8134 - salida_clase_accuracy: 0.8509 - salidas_continuas_mae: 15.7887 - val_loss: 531.4569 - val_salida_clase_accuracy: 0.8642 - val_salidas_continuas_mae: 14.1857 - learning_rate: 0.0010
# Epoch 31/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 503.1406 - salida_clase_accuracy: 0.8680 - salidas_continuas_mae: 15.5357 - val_loss: 562.6522 - val_salida_clase_accuracy: 0.8701 - val_salidas_continuas_mae: 14.8074 - learning_rate: 0.0010
# Epoch 32/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 521.3029 - salida_clase_accuracy: 0.8753 - salidas_continuas_mae: 15.4910 - val_loss: 557.5222 - val_salida_clase_accuracy: 0.8321 - val_salidas_continuas_mae: 14.6382 - learning_rate: 0.0010
# Epoch 33/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 513.4741 - salida_clase_accuracy: 0.8653 - salidas_continuas_mae: 15.4228 - val_loss: 542.8659 - val_salida_clase_accuracy: 0.8613 - val_salidas_continuas_mae: 14.2006 - learning_rate: 0.0010
# Epoch 34/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - loss: 472.3160 - salida_clase_accuracy: 0.8529 - salidas_continuas_mae: 15.0394 - val_loss: 521.4703 - val_salida_clase_accuracy: 0.8657 - val_salidas_continuas_mae: 13.8822 - learning_rate: 0.0010
# Epoch 35/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 484.8416 - salida_clase_accuracy: 0.8791 - salidas_continuas_mae: 14.8759 - val_loss: 537.1063 - val_salida_clase_accuracy: 0.8526 - val_salidas_continuas_mae: 14.1482 - learning_rate: 0.0010
# Epoch 36/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 496.3534 - salida_clase_accuracy: 0.8811 - salidas_continuas_mae: 15.1560 - val_loss: 527.0682 - val_salida_clase_accuracy: 0.8657 - val_salidas_continuas_mae: 13.8406 - learning_rate: 0.0010
# Epoch 37/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 450.7083 - salida_clase_accuracy: 0.8695 - salidas_continuas_mae: 14.7235 - val_loss: 535.0493 - val_salida_clase_accuracy: 0.8686 - val_salidas_continuas_mae: 14.2175 - learning_rate: 0.0010
# Epoch 38/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 449.4274 - salida_clase_accuracy: 0.8823 - salidas_continuas_mae: 14.6916 - val_loss: 537.6854 - val_salida_clase_accuracy: 0.8745 - val_salidas_continuas_mae: 13.9879 - learning_rate: 0.0010
# Epoch 39/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 448.9785 - salida_clase_accuracy: 0.8894 - salidas_continuas_mae: 14.4367 - val_loss: 514.7455 - val_salida_clase_accuracy: 0.8759 - val_salidas_continuas_mae: 13.7305 - learning_rate: 0.0010
# Epoch 40/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 431.3844 - salida_clase_accuracy: 0.8792 - salidas_continuas_mae: 14.2809 - val_loss: 521.5936 - val_salida_clase_accuracy: 0.8715 - val_salidas_continuas_mae: 13.7928 - learning_rate: 0.0010
# Epoch 41/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 427.8325 - salida_clase_accuracy: 0.8741 - salidas_continuas_mae: 14.3231 - val_loss: 563.2956 - val_salida_clase_accuracy: 0.8818 - val_salidas_continuas_mae: 14.9209 - learning_rate: 0.0010
# Epoch 42/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 432.9348 - salida_clase_accuracy: 0.8716 - salidas_continuas_mae: 14.2908 - val_loss: 518.2596 - val_salida_clase_accuracy: 0.8847 - val_salidas_continuas_mae: 13.6531 - learning_rate: 0.0010
# Epoch 43/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 451.4477 - salida_clase_accuracy: 0.9004 - salidas_continuas_mae: 14.6126 - val_loss: 515.7233 - val_salida_clase_accuracy: 0.8540 - val_salidas_continuas_mae: 13.4620 - learning_rate: 0.0010
# Epoch 44/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 437.4214 - salida_clase_accuracy: 0.8996 - salidas_continuas_mae: 14.3914 - val_loss: 535.1213 - val_salida_clase_accuracy: 0.8613 - val_salidas_continuas_mae: 13.8669 - learning_rate: 0.0010
# Epoch 45/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 407.9850 - salida_clase_accuracy: 0.8991 - salidas_continuas_mae: 13.7877 - val_loss: 491.4233 - val_salida_clase_accuracy: 0.8847 - val_salidas_continuas_mae: 12.7514 - learning_rate: 5.0000e-04
# Epoch 46/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 395.7555 - salida_clase_accuracy: 0.9211 - salidas_continuas_mae: 13.5371 - val_loss: 469.4217 - val_salida_clase_accuracy: 0.8920 - val_salidas_continuas_mae: 12.5657 - learning_rate: 5.0000e-04
# Epoch 47/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - loss: 377.3668 - salida_clase_accuracy: 0.9171 - salidas_continuas_mae: 13.3504 - val_loss: 487.0479 - val_salida_clase_accuracy: 0.8847 - val_salidas_continuas_mae: 12.7861 - learning_rate: 5.0000e-04
# Epoch 48/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 354.3417 - salida_clase_accuracy: 0.9219 - salidas_continuas_mae: 13.1199 - val_loss: 494.5970 - val_salida_clase_accuracy: 0.8847 - val_salidas_continuas_mae: 13.0524 - learning_rate: 5.0000e-04
# Epoch 49/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 373.3610 - salida_clase_accuracy: 0.9083 - salidas_continuas_mae: 13.3597 - val_loss: 492.1516 - val_salida_clase_accuracy: 0.8861 - val_salidas_continuas_mae: 12.8607 - learning_rate: 5.0000e-04
# Epoch 50/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 372.8721 - salida_clase_accuracy: 0.9286 - salidas_continuas_mae: 13.1047 - val_loss: 486.1493 - val_salida_clase_accuracy: 0.8876 - val_salidas_continuas_mae: 12.6678 - learning_rate: 5.0000e-04
# Epoch 51/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 392.8342 - salida_clase_accuracy: 0.9079 - salidas_continuas_mae: 13.4416 - val_loss: 484.5536 - val_salida_clase_accuracy: 0.9022 - val_salidas_continuas_mae: 12.6880 - learning_rate: 5.0000e-04
# Epoch 52/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 346.8217 - salida_clase_accuracy: 0.9229 - salidas_continuas_mae: 12.8022 - val_loss: 477.8828 - val_salida_clase_accuracy: 0.9007 - val_salidas_continuas_mae: 12.5133 - learning_rate: 2.5000e-04
# Epoch 53/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 343.4637 - salida_clase_accuracy: 0.9427 - salidas_continuas_mae: 12.6574 - val_loss: 479.6617 - val_salida_clase_accuracy: 0.9051 - val_salidas_continuas_mae: 12.3107 - learning_rate: 2.5000e-04
# Epoch 54/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 353.0196 - salida_clase_accuracy: 0.9304 - salidas_continuas_mae: 12.8646 - val_loss: 472.9073 - val_salida_clase_accuracy: 0.9066 - val_salidas_continuas_mae: 12.3642 - learning_rate: 2.5000e-04
# Epoch 55/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 352.2893 - salida_clase_accuracy: 0.9372 - salidas_continuas_mae: 12.9200 - val_loss: 465.0815 - val_salida_clase_accuracy: 0.9051 - val_salidas_continuas_mae: 12.1358 - learning_rate: 2.5000e-04
# Epoch 56/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 336.3148 - salida_clase_accuracy: 0.9217 - salidas_continuas_mae: 12.5161 - val_loss: 474.9998 - val_salida_clase_accuracy: 0.8949 - val_salidas_continuas_mae: 12.1946 - learning_rate: 2.5000e-04
# Epoch 57/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 343.4162 - salida_clase_accuracy: 0.9212 - salidas_continuas_mae: 12.7788 - val_loss: 471.6197 - val_salida_clase_accuracy: 0.9036 - val_salidas_continuas_mae: 12.2484 - learning_rate: 2.5000e-04
# Epoch 58/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 347.9753 - salida_clase_accuracy: 0.9283 - salidas_continuas_mae: 12.8149 - val_loss: 471.0436 - val_salida_clase_accuracy: 0.9051 - val_salidas_continuas_mae: 12.1625 - learning_rate: 2.5000e-04
# Epoch 59/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 326.5619 - salida_clase_accuracy: 0.9391 - salidas_continuas_mae: 12.5353 - val_loss: 468.8171 - val_salida_clase_accuracy: 0.9124 - val_salidas_continuas_mae: 12.1175 - learning_rate: 2.5000e-04
# Epoch 60/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 326.7536 - salida_clase_accuracy: 0.9327 - salidas_continuas_mae: 12.5379 - val_loss: 466.5823 - val_salida_clase_accuracy: 0.9124 - val_salidas_continuas_mae: 12.2105 - learning_rate: 2.5000e-04
# Epoch 61/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 345.7159 - salida_clase_accuracy: 0.9426 - salidas_continuas_mae: 12.5900 - val_loss: 468.5184 - val_salida_clase_accuracy: 0.9036 - val_salidas_continuas_mae: 12.0375 - learning_rate: 1.2500e-04
# Epoch 62/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 318.4585 - salida_clase_accuracy: 0.9421 - salidas_continuas_mae: 12.1857 - val_loss: 466.3262 - val_salida_clase_accuracy: 0.9109 - val_salidas_continuas_mae: 11.9986 - learning_rate: 1.2500e-04
# Epoch 63/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 307.3183 - salida_clase_accuracy: 0.9365 - salidas_continuas_mae: 12.1367 - val_loss: 461.0593 - val_salida_clase_accuracy: 0.9022 - val_salidas_continuas_mae: 11.8719 - learning_rate: 1.2500e-04
# Epoch 64/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 318.2184 - salida_clase_accuracy: 0.9409 - salidas_continuas_mae: 12.3249 - val_loss: 461.9410 - val_salida_clase_accuracy: 0.9109 - val_salidas_continuas_mae: 11.9432 - learning_rate: 1.2500e-04
# Epoch 65/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 315.8629 - salida_clase_accuracy: 0.9400 - salidas_continuas_mae: 12.1980 - val_loss: 456.9905 - val_salida_clase_accuracy: 0.9095 - val_salidas_continuas_mae: 11.8907 - learning_rate: 1.2500e-04
# Epoch 66/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 319.2589 - salida_clase_accuracy: 0.9371 - salidas_continuas_mae: 12.2859 - val_loss: 462.7959 - val_salida_clase_accuracy: 0.9036 - val_salidas_continuas_mae: 11.9716 - learning_rate: 1.2500e-04
# Epoch 67/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 313.5698 - salida_clase_accuracy: 0.9340 - salidas_continuas_mae: 12.1974 - val_loss: 460.0235 - val_salida_clase_accuracy: 0.9080 - val_salidas_continuas_mae: 11.9562 - learning_rate: 1.2500e-04
# Epoch 68/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 308.9096 - salida_clase_accuracy: 0.9445 - salidas_continuas_mae: 12.0704 - val_loss: 462.4624 - val_salida_clase_accuracy: 0.9066 - val_salidas_continuas_mae: 11.9510 - learning_rate: 1.2500e-04
# Epoch 69/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 305.1303 - salida_clase_accuracy: 0.9397 - salidas_continuas_mae: 12.1230 - val_loss: 461.5435 - val_salida_clase_accuracy: 0.9066 - val_salidas_continuas_mae: 11.8883 - learning_rate: 1.2500e-04
# Epoch 70/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 316.4277 - salida_clase_accuracy: 0.9393 - salidas_continuas_mae: 12.1855 - val_loss: 465.0150 - val_salida_clase_accuracy: 0.9109 - val_salidas_continuas_mae: 12.0263 - learning_rate: 1.2500e-04
# Epoch 71/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 318.8694 - salida_clase_accuracy: 0.9518 - salidas_continuas_mae: 12.2601 - val_loss: 458.5853 - val_salida_clase_accuracy: 0.9124 - val_salidas_continuas_mae: 11.8404 - learning_rate: 6.2500e-05
# Epoch 72/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - loss: 298.1117 - salida_clase_accuracy: 0.9438 - salidas_continuas_mae: 11.9926 - val_loss: 459.6046 - val_salida_clase_accuracy: 0.9124 - val_salidas_continuas_mae: 11.8458 - learning_rate: 6.2500e-05
# Epoch 73/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 300.4793 - salida_clase_accuracy: 0.9366 - salidas_continuas_mae: 12.0266 - val_loss: 457.2733 - val_salida_clase_accuracy: 0.9109 - val_salidas_continuas_mae: 11.8208 - learning_rate: 6.2500e-05
# Epoch 74/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 304.2332 - salida_clase_accuracy: 0.9363 - salidas_continuas_mae: 12.0336 - val_loss: 457.2696 - val_salida_clase_accuracy: 0.9182 - val_salidas_continuas_mae: 11.8002 - learning_rate: 6.2500e-05
# Epoch 75/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 302.4424 - salida_clase_accuracy: 0.9464 - salidas_continuas_mae: 11.9882 - val_loss: 457.2489 - val_salida_clase_accuracy: 0.9139 - val_salidas_continuas_mae: 11.7975 - learning_rate: 6.2500e-05
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 436.1880 - salida_clase_accuracy: 0.9193 - salidas_continuas_mae: 12.1035
# Fold 2: Loss=459.0015563964844, MAE=12.354232788085938, Accuracy=0.9264018535614014
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# Entrenando fold 3...
# Epoch 1/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - loss: 5296.0679 - salida_clase_accuracy: 0.3872 - salidas_continuas_mae: 57.6189 - val_loss: 8436.5654 - val_salida_clase_accuracy: 0.1813 - val_salidas_continuas_mae: 74.7914 - learning_rate: 0.0010
# Epoch 2/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 1956.8748 - salida_clase_accuracy: 0.5217 - salidas_continuas_mae: 35.2949 - val_loss: 6157.5342 - val_salida_clase_accuracy: 0.2997 - val_salidas_continuas_mae: 63.1356 - learning_rate: 0.0010
# Epoch 3/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 1678.0559 - salida_clase_accuracy: 0.5943 - salidas_continuas_mae: 31.7302 - val_loss: 4698.1670 - val_salida_clase_accuracy: 0.2763 - val_salidas_continuas_mae: 55.1841 - learning_rate: 0.0010
# Epoch 4/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 1527.7441 - salida_clase_accuracy: 0.6226 - salidas_continuas_mae: 29.5638 - val_loss: 3031.3992 - val_salida_clase_accuracy: 0.4678 - val_salidas_continuas_mae: 44.6874 - learning_rate: 0.0010
# Epoch 5/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - loss: 1497.5522 - salida_clase_accuracy: 0.6478 - salidas_continuas_mae: 29.0624 - val_loss: 2006.5139 - val_salida_clase_accuracy: 0.5673 - val_salidas_continuas_mae: 36.1743 - learning_rate: 0.0010
# Epoch 6/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 1284.5337 - salida_clase_accuracy: 0.6910 - salidas_continuas_mae: 26.2594 - val_loss: 1446.1440 - val_salida_clase_accuracy: 0.6681 - val_salidas_continuas_mae: 29.2992 - learning_rate: 0.0010
# Epoch 7/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - loss: 1181.7170 - salida_clase_accuracy: 0.7047 - salidas_continuas_mae: 24.7381 - val_loss: 1408.4473 - val_salida_clase_accuracy: 0.5702 - val_salidas_continuas_mae: 27.9124 - learning_rate: 0.0010
# Epoch 8/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 1145.0219 - salida_clase_accuracy: 0.6942 - salidas_continuas_mae: 24.3533 - val_loss: 1103.7078 - val_salida_clase_accuracy: 0.7485 - val_salidas_continuas_mae: 23.4649 - learning_rate: 0.0010
# Epoch 9/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 1077.3152 - salida_clase_accuracy: 0.7424 - salidas_continuas_mae: 23.6328 - val_loss: 1062.5891 - val_salida_clase_accuracy: 0.7442 - val_salidas_continuas_mae: 22.3539 - learning_rate: 0.0010
# Epoch 10/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 971.1736 - salida_clase_accuracy: 0.7713 - salidas_continuas_mae: 22.0010 - val_loss: 979.6595 - val_salida_clase_accuracy: 0.8085 - val_salidas_continuas_mae: 21.3640 - learning_rate: 0.0010
# Epoch 11/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 937.6392 - salida_clase_accuracy: 0.7778 - salidas_continuas_mae: 21.7049 - val_loss: 958.4342 - val_salida_clase_accuracy: 0.8070 - val_salidas_continuas_mae: 21.0780 - learning_rate: 0.0010
# Epoch 12/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 879.4016 - salida_clase_accuracy: 0.7784 - salidas_continuas_mae: 21.0299 - val_loss: 918.5081 - val_salida_clase_accuracy: 0.7778 - val_salidas_continuas_mae: 20.6676 - learning_rate: 0.0010
# Epoch 13/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 862.9523 - salida_clase_accuracy: 0.7902 - salidas_continuas_mae: 20.5292 - val_loss: 835.6486 - val_salida_clase_accuracy: 0.8202 - val_salidas_continuas_mae: 19.1537 - learning_rate: 0.0010
# Epoch 14/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 820.0056 - salida_clase_accuracy: 0.8004 - salidas_continuas_mae: 20.0811 - val_loss: 888.1274 - val_salida_clase_accuracy: 0.7880 - val_salidas_continuas_mae: 20.6077 - learning_rate: 0.0010
# Epoch 15/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 861.1663 - salida_clase_accuracy: 0.7817 - salidas_continuas_mae: 20.4960 - val_loss: 796.1594 - val_salida_clase_accuracy: 0.7997 - val_salidas_continuas_mae: 18.7620 - learning_rate: 0.0010
# Epoch 16/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 727.7814 - salida_clase_accuracy: 0.8273 - salidas_continuas_mae: 18.8807 - val_loss: 788.8688 - val_salida_clase_accuracy: 0.8480 - val_salidas_continuas_mae: 19.0053 - learning_rate: 0.0010
# Epoch 17/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 775.7866 - salida_clase_accuracy: 0.8257 - salidas_continuas_mae: 19.4845 - val_loss: 806.3099 - val_salida_clase_accuracy: 0.8173 - val_salidas_continuas_mae: 19.4142 - learning_rate: 0.0010
# Epoch 18/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 741.4735 - salida_clase_accuracy: 0.8276 - salidas_continuas_mae: 18.8546 - val_loss: 770.4423 - val_salida_clase_accuracy: 0.8333 - val_salidas_continuas_mae: 18.1192 - learning_rate: 0.0010
# Epoch 19/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 722.7109 - salida_clase_accuracy: 0.8167 - salidas_continuas_mae: 18.2981 - val_loss: 793.4364 - val_salida_clase_accuracy: 0.7822 - val_salidas_continuas_mae: 19.3336 - learning_rate: 0.0010
# Epoch 20/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 684.0455 - salida_clase_accuracy: 0.8178 - salidas_continuas_mae: 18.1864 - val_loss: 694.3666 - val_salida_clase_accuracy: 0.8333 - val_salidas_continuas_mae: 17.1455 - learning_rate: 0.0010
# Epoch 21/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 704.7520 - salida_clase_accuracy: 0.8452 - salidas_continuas_mae: 18.1599 - val_loss: 671.5965 - val_salida_clase_accuracy: 0.8655 - val_salidas_continuas_mae: 16.5365 - learning_rate: 0.0010
# Epoch 22/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 645.7229 - salida_clase_accuracy: 0.8414 - salidas_continuas_mae: 17.5250 - val_loss: 715.8287 - val_salida_clase_accuracy: 0.8582 - val_salidas_continuas_mae: 17.2897 - learning_rate: 0.0010
# Epoch 23/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 648.6369 - salida_clase_accuracy: 0.8351 - salidas_continuas_mae: 17.4199 - val_loss: 655.8577 - val_salida_clase_accuracy: 0.8436 - val_salidas_continuas_mae: 16.8138 - learning_rate: 0.0010
# Epoch 24/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 616.7738 - salida_clase_accuracy: 0.8469 - salidas_continuas_mae: 17.0169 - val_loss: 699.7446 - val_salida_clase_accuracy: 0.8392 - val_salidas_continuas_mae: 17.8448 - learning_rate: 0.0010
# Epoch 25/150
# ...
# Epoch 41/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 436.1080 - salida_clase_accuracy: 0.8947 - salidas_continuas_mae: 14.3167 - val_loss: 538.6967 - val_salida_clase_accuracy: 0.8904 - val_salidas_continuas_mae: 14.5670 - learning_rate: 0.0010
# Epoch 42/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 451.2060 - salida_clase_accuracy: 0.8902 - salidas_continuas_mae: 14.2965 - val_loss: 554.6919 - val_salida_clase_accuracy: 0.8947 - val_salidas_continuas_mae: 14.4426 - learning_rate: 0.0010
# Epoch 43/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 442.8133 - salida_clase_accuracy: 0.8804 - salidas_continuas_mae: 14.3638 - val_loss: 547.8234 - val_salida_clase_accuracy: 0.8874 - val_salidas_continuas_mae: 14.5000 - learning_rate: 0.0010
# Epoch 44/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 426.2551 - salida_clase_accuracy: 0.8808 - salidas_continuas_mae: 14.0659 - val_loss: 555.6201 - val_salida_clase_accuracy: 0.8699 - val_salidas_continuas_mae: 14.1167 - learning_rate: 0.0010
# Epoch 45/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 411.9899 - salida_clase_accuracy: 0.8846 - salidas_continuas_mae: 13.9222 - val_loss: 527.6246 - val_salida_clase_accuracy: 0.8991 - val_salidas_continuas_mae: 14.2587 - learning_rate: 0.0010
# Epoch 46/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 393.1528 - salida_clase_accuracy: 0.8948 - salidas_continuas_mae: 13.5619 - val_loss: 472.5174 - val_salida_clase_accuracy: 0.9035 - val_salidas_continuas_mae: 12.8894 - learning_rate: 5.0000e-04
# Epoch 47/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 375.0916 - salida_clase_accuracy: 0.9183 - salidas_continuas_mae: 13.1168 - val_loss: 485.1936 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 13.0183 - learning_rate: 5.0000e-04
# Epoch 48/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 386.5035 - salida_clase_accuracy: 0.9257 - salidas_continuas_mae: 13.2385 - val_loss: 483.2916 - val_salida_clase_accuracy: 0.8991 - val_salidas_continuas_mae: 12.7965 - learning_rate: 5.0000e-04
# Epoch 49/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 378.1510 - salida_clase_accuracy: 0.9261 - salidas_continuas_mae: 13.0402 - val_loss: 483.0415 - val_salida_clase_accuracy: 0.9167 - val_salidas_continuas_mae: 12.8906 - learning_rate: 5.0000e-04
# Epoch 50/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 361.4317 - salida_clase_accuracy: 0.9326 - salidas_continuas_mae: 12.8632 - val_loss: 493.4266 - val_salida_clase_accuracy: 0.8889 - val_salidas_continuas_mae: 13.0434 - learning_rate: 5.0000e-04
# Epoch 51/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 375.1020 - salida_clase_accuracy: 0.9185 - salidas_continuas_mae: 13.1197 - val_loss: 478.5156 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 12.9097 - learning_rate: 5.0000e-04
# Epoch 52/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 351.7118 - salida_clase_accuracy: 0.9294 - salidas_continuas_mae: 12.7772 - val_loss: 457.8401 - val_salida_clase_accuracy: 0.9123 - val_salidas_continuas_mae: 12.6238 - learning_rate: 2.5000e-04
# Epoch 53/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 349.3134 - salida_clase_accuracy: 0.9284 - salidas_continuas_mae: 12.7895 - val_loss: 465.0045 - val_salida_clase_accuracy: 0.9035 - val_salidas_continuas_mae: 12.5909 - learning_rate: 2.5000e-04
# Epoch 54/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 343.0078 - salida_clase_accuracy: 0.9327 - salidas_continuas_mae: 12.6940 - val_loss: 461.8253 - val_salida_clase_accuracy: 0.8991 - val_salidas_continuas_mae: 12.5633 - learning_rate: 2.5000e-04
# Epoch 55/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 330.8641 - salida_clase_accuracy: 0.9296 - salidas_continuas_mae: 12.5486 - val_loss: 463.8264 - val_salida_clase_accuracy: 0.9137 - val_salidas_continuas_mae: 12.5835 - learning_rate: 2.5000e-04
# Epoch 56/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 344.1724 - salida_clase_accuracy: 0.9144 - salidas_continuas_mae: 12.6422 - val_loss: 461.5275 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 12.5526 - learning_rate: 2.5000e-04
# Epoch 57/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 330.8038 - salida_clase_accuracy: 0.9305 - salidas_continuas_mae: 12.4233 - val_loss: 452.8723 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 12.3177 - learning_rate: 2.5000e-04
# Epoch 58/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 318.5075 - salida_clase_accuracy: 0.9358 - salidas_continuas_mae: 12.2871 - val_loss: 453.0201 - val_salida_clase_accuracy: 0.9094 - val_salidas_continuas_mae: 12.3375 - learning_rate: 2.5000e-04
# Epoch 59/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 340.0487 - salida_clase_accuracy: 0.9351 - salidas_continuas_mae: 12.4602 - val_loss: 459.4330 - val_salida_clase_accuracy: 0.9108 - val_salidas_continuas_mae: 12.2983 - learning_rate: 2.5000e-04
# Epoch 60/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 326.0189 - salida_clase_accuracy: 0.9327 - salidas_continuas_mae: 12.2913 - val_loss: 458.1365 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 12.3477 - learning_rate: 2.5000e-04
# Epoch 61/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 316.7204 - salida_clase_accuracy: 0.9355 - salidas_continuas_mae: 12.2313 - val_loss: 451.3137 - val_salida_clase_accuracy: 0.9064 - val_salidas_continuas_mae: 12.3532 - learning_rate: 2.5000e-04
# Epoch 62/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 334.0806 - salida_clase_accuracy: 0.9303 - salidas_continuas_mae: 12.3741 - val_loss: 454.6007 - val_salida_clase_accuracy: 0.9240 - val_salidas_continuas_mae: 12.5392 - learning_rate: 2.5000e-04
# Epoch 63/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 342.5414 - salida_clase_accuracy: 0.9325 - salidas_continuas_mae: 12.4938 - val_loss: 454.7801 - val_salida_clase_accuracy: 0.9137 - val_salidas_continuas_mae: 12.2753 - learning_rate: 2.5000e-04
# Epoch 64/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 313.9603 - salida_clase_accuracy: 0.9341 - salidas_continuas_mae: 12.1897 - val_loss: 459.4635 - val_salida_clase_accuracy: 0.9137 - val_salidas_continuas_mae: 12.3450 - learning_rate: 2.5000e-04
# Epoch 65/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 329.3586 - salida_clase_accuracy: 0.9349 - salidas_continuas_mae: 12.3010 - val_loss: 452.9169 - val_salida_clase_accuracy: 0.9137 - val_salidas_continuas_mae: 12.1470 - learning_rate: 2.5000e-04
# Epoch 66/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 321.0016 - salida_clase_accuracy: 0.9420 - salidas_continuas_mae: 12.2361 - val_loss: 466.2326 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 12.3805 - learning_rate: 2.5000e-04
# Epoch 67/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 317.7336 - salida_clase_accuracy: 0.9411 - salidas_continuas_mae: 12.1259 - val_loss: 446.7917 - val_salida_clase_accuracy: 0.9167 - val_salidas_continuas_mae: 12.0926 - learning_rate: 1.2500e-04
# Epoch 68/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 317.7882 - salida_clase_accuracy: 0.9353 - salidas_continuas_mae: 12.1966 - val_loss: 451.8862 - val_salida_clase_accuracy: 0.9094 - val_salidas_continuas_mae: 12.1323 - learning_rate: 1.2500e-04
# Epoch 69/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 308.8506 - salida_clase_accuracy: 0.9397 - salidas_continuas_mae: 12.0247 - val_loss: 444.5663 - val_salida_clase_accuracy: 0.9167 - val_salidas_continuas_mae: 12.0768 - learning_rate: 1.2500e-04
# Epoch 70/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 306.8352 - salida_clase_accuracy: 0.9390 - salidas_continuas_mae: 11.9439 - val_loss: 442.0482 - val_salida_clase_accuracy: 0.9108 - val_salidas_continuas_mae: 11.9574 - learning_rate: 1.2500e-04
# Epoch 71/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 306.9388 - salida_clase_accuracy: 0.9424 - salidas_continuas_mae: 11.8634 - val_loss: 437.7758 - val_salida_clase_accuracy: 0.9123 - val_salidas_continuas_mae: 11.9363 - learning_rate: 1.2500e-04
# Epoch 72/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 313.1141 - salida_clase_accuracy: 0.9442 - salidas_continuas_mae: 12.0669 - val_loss: 456.8445 - val_salida_clase_accuracy: 0.9064 - val_salidas_continuas_mae: 12.1360 - learning_rate: 1.2500e-04
# Epoch 73/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 292.7331 - salida_clase_accuracy: 0.9358 - salidas_continuas_mae: 11.8262 - val_loss: 441.1823 - val_salida_clase_accuracy: 0.9137 - val_salidas_continuas_mae: 11.9995 - learning_rate: 1.2500e-04
# Epoch 74/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 311.7624 - salida_clase_accuracy: 0.9482 - salidas_continuas_mae: 11.9511 - val_loss: 441.0816 - val_salida_clase_accuracy: 0.9108 - val_salidas_continuas_mae: 12.0282 - learning_rate: 1.2500e-04
# Epoch 75/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 309.4187 - salida_clase_accuracy: 0.9373 - salidas_continuas_mae: 11.8441 - val_loss: 441.5916 - val_salida_clase_accuracy: 0.9196 - val_salidas_continuas_mae: 11.9495 - learning_rate: 1.2500e-04
# Epoch 76/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 297.6686 - salida_clase_accuracy: 0.9378 - salidas_continuas_mae: 11.8139 - val_loss: 446.0376 - val_salida_clase_accuracy: 0.9137 - val_salidas_continuas_mae: 12.0292 - learning_rate: 1.2500e-04
# Epoch 77/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 278.6234 - salida_clase_accuracy: 0.9503 - salidas_continuas_mae: 11.5339 - val_loss: 437.8153 - val_salida_clase_accuracy: 0.9196 - val_salidas_continuas_mae: 11.8914 - learning_rate: 6.2500e-05
# Epoch 78/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 297.8275 - salida_clase_accuracy: 0.9455 - salidas_continuas_mae: 11.8715 - val_loss: 438.2216 - val_salida_clase_accuracy: 0.9167 - val_salidas_continuas_mae: 11.8535 - learning_rate: 6.2500e-05
# Epoch 79/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 283.1421 - salida_clase_accuracy: 0.9448 - salidas_continuas_mae: 11.6223 - val_loss: 439.2539 - val_salida_clase_accuracy: 0.9137 - val_salidas_continuas_mae: 11.8836 - learning_rate: 6.2500e-05
# Epoch 80/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 285.1470 - salida_clase_accuracy: 0.9445 - salidas_continuas_mae: 11.6504 - val_loss: 439.0425 - val_salida_clase_accuracy: 0.9152 - val_salidas_continuas_mae: 11.8811 - learning_rate: 6.2500e-05
# Epoch 81/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 271.8143 - salida_clase_accuracy: 0.9434 - salidas_continuas_mae: 11.5367 - val_loss: 437.7513 - val_salida_clase_accuracy: 0.9196 - val_salidas_continuas_mae: 11.8815 - learning_rate: 6.2500e-05
# Epoch 82/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 305.9806 - salida_clase_accuracy: 0.9446 - salidas_continuas_mae: 11.8780 - val_loss: 438.9622 - val_salida_clase_accuracy: 0.9167 - val_salidas_continuas_mae: 11.8681 - learning_rate: 6.2500e-05
# Epoch 83/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 287.8270 - salida_clase_accuracy: 0.9441 - salidas_continuas_mae: 11.6241 - val_loss: 442.5320 - val_salida_clase_accuracy: 0.9137 - val_salidas_continuas_mae: 11.8894 - learning_rate: 6.2500e-05
# Epoch 84/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 295.8687 - salida_clase_accuracy: 0.9507 - salidas_continuas_mae: 11.8610 - val_loss: 441.2331 - val_salida_clase_accuracy: 0.9225 - val_salidas_continuas_mae: 11.8612 - learning_rate: 6.2500e-05
# Epoch 85/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 302.2534 - salida_clase_accuracy: 0.9438 - salidas_continuas_mae: 11.9185 - val_loss: 440.5930 - val_salida_clase_accuracy: 0.9123 - val_salidas_continuas_mae: 11.8720 - learning_rate: 6.2500e-05
# Epoch 86/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 290.6559 - salida_clase_accuracy: 0.9426 - salidas_continuas_mae: 11.6219 - val_loss: 436.5482 - val_salida_clase_accuracy: 0.9152 - val_salidas_continuas_mae: 11.8792 - learning_rate: 6.2500e-05
# Epoch 87/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 286.6242 - salida_clase_accuracy: 0.9519 - salidas_continuas_mae: 11.6389 - val_loss: 436.0405 - val_salida_clase_accuracy: 0.9225 - val_salidas_continuas_mae: 11.8553 - learning_rate: 6.2500e-05
# Epoch 88/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 294.9910 - salida_clase_accuracy: 0.9458 - salidas_continuas_mae: 11.8631 - val_loss: 437.2939 - val_salida_clase_accuracy: 0.9225 - val_salidas_continuas_mae: 11.8318 - learning_rate: 6.2500e-05
# Epoch 89/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 294.9021 - salida_clase_accuracy: 0.9528 - salidas_continuas_mae: 11.6309 - val_loss: 434.2598 - val_salida_clase_accuracy: 0.9152 - val_salidas_continuas_mae: 11.7759 - learning_rate: 6.2500e-05
# Epoch 90/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 290.2426 - salida_clase_accuracy: 0.9396 - salidas_continuas_mae: 11.5569 - val_loss: 435.8786 - val_salida_clase_accuracy: 0.9181 - val_salidas_continuas_mae: 11.8885 - learning_rate: 6.2500e-05
# Epoch 91/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 287.2491 - salida_clase_accuracy: 0.9393 - salidas_continuas_mae: 11.5757 - val_loss: 445.7410 - val_salida_clase_accuracy: 0.9196 - val_salidas_continuas_mae: 11.9143 - learning_rate: 6.2500e-05
# Epoch 92/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 282.9622 - salida_clase_accuracy: 0.9451 - salidas_continuas_mae: 11.5456 - val_loss: 442.0366 - val_salida_clase_accuracy: 0.9152 - val_salidas_continuas_mae: 11.8216 - learning_rate: 6.2500e-05
# Epoch 93/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 303.4189 - salida_clase_accuracy: 0.9410 - salidas_continuas_mae: 11.8049 - val_loss: 443.8929 - val_salida_clase_accuracy: 0.9137 - val_salidas_continuas_mae: 11.8887 - learning_rate: 6.2500e-05
# Epoch 94/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 270.9241 - salida_clase_accuracy: 0.9338 - salidas_continuas_mae: 11.5201 - val_loss: 436.8105 - val_salida_clase_accuracy: 0.9064 - val_salidas_continuas_mae: 11.8737 - learning_rate: 6.2500e-05
# Epoch 95/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 289.5815 - salida_clase_accuracy: 0.9471 - salidas_continuas_mae: 11.6865 - val_loss: 437.6096 - val_salida_clase_accuracy: 0.9108 - val_salidas_continuas_mae: 11.7997 - learning_rate: 3.1250e-05
# Epoch 96/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 268.4719 - salida_clase_accuracy: 0.9519 - salidas_continuas_mae: 11.3537 - val_loss: 436.8607 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 11.7839 - learning_rate: 3.1250e-05
# Epoch 97/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 274.6088 - salida_clase_accuracy: 0.9464 - salidas_continuas_mae: 11.3630 - val_loss: 436.1392 - val_salida_clase_accuracy: 0.9108 - val_salidas_continuas_mae: 11.7532 - learning_rate: 3.1250e-05
# Epoch 98/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 275.8534 - salida_clase_accuracy: 0.9389 - salidas_continuas_mae: 11.4215 - val_loss: 435.0692 - val_salida_clase_accuracy: 0.9152 - val_salidas_continuas_mae: 11.7634 - learning_rate: 3.1250e-05
# Epoch 99/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 297.3475 - salida_clase_accuracy: 0.9487 - salidas_continuas_mae: 11.7492 - val_loss: 439.0348 - val_salida_clase_accuracy: 0.9123 - val_salidas_continuas_mae: 11.7510 - learning_rate: 3.1250e-05
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 420.9395 - salida_clase_accuracy: 0.9151 - salidas_continuas_mae: 11.4990
# Fold 5: Loss=444.094482421875, MAE=11.810332298278809, Accuracy=0.922897219657898
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 439.6016540527344
# MAE: 11.914783294294148
# MSE: 437.83539492225947
# RMSE: 20.92201668659157
# R^2: 0.8806675225855839
# Accuracy: 0.925000011920929
# Precisión: 0.9263636530757852
# Recall: 0.925
# F1-Score: 0.9250336041382037
