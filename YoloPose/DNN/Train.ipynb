# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt

# %%
# Definir rutas
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_raiz = os.path.dirname(carpeta_mediapipe)
ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual,'datos','scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Videos_Pose', 'pose_data.csv')

# Cargar el dataset
data = pd.read_csv(ruta_csv)

# Preparar entradas (Keypoints)
num_keypoints = 17 * 3
X = data.iloc[:, :num_keypoints].values

# Las siguientes 11 columnas incluyen:
# 10 características continuas (ángulos, distancias) + 1 tipo de ejercicio (última columna)
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

# Codificar la etiqueta del tipo de ejercicio
encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_continuas_train, y_continuas_test, y_clase_train, y_clase_test = train_test_split(
    X, y_continuas, y_clase_encoded, test_size=0.2, random_state=42)

# Normalizar las entradas
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

# Listas para almacenar métricas
all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

# Matrices para almacenar la historia del entrenamiento
n_epochs = 50  # Número de épocas
all_train_loss = np.zeros((5, n_epochs))  # 5 pliegues, n_epochs épocas
all_val_loss = np.zeros((5, n_epochs))
all_train_accuracy = np.zeros((5, n_epochs))
all_val_accuracy = np.zeros((5, n_epochs))

# Validación cruzada
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
fold_index = 0

def create_model(learning_rate=0.001):
    input_layer = Input(shape=(X_train_scaled.shape[1],))
    x = Dense(128, activation='relu')(input_layer)
    x = Dense(64, activation='relu')(x)
    x = Dense(32, activation='relu')(x)
    salidas_continuas = Dense(10, activation='linear', name='salidas_continuas')(x)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)
    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer,
                  loss={'salidas_continuas': 'mean_squared_error', 'salida_clase': 'sparse_categorical_crossentropy'},
                  metrics={'salidas_continuas': 'mae', 'salida_clase': 'accuracy'})
    return model

for train_index, val_index in kfold.split(X_train_scaled):
    fold_index += 1
    print(f"Entrenando fold {fold_index}...")

    X_train_fold, X_val_fold = X_train_scaled[train_index], X_train_scaled[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas_train[train_index], y_continuas_train[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_train[train_index], y_clase_train[val_index]

    model = create_model(learning_rate=0.0005)  # Ajustar la tasa de aprendizaje aquí
    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold_index}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    # Almacenar la historia del entrenamiento
    all_train_loss[fold_index - 1, :] = history.history['loss']
    all_val_loss[fold_index - 1, :] = history.history['val_loss']
    all_train_accuracy[fold_index - 1, :] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold_index - 1, :] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de prueba
    scores = model.evaluate(X_test_scaled, {'salidas_continuas': y_continuas_test, 'salida_clase': y_clase_test})
    print(f"Fold {fold_index}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_test_scaled)[0]
    mae = mean_absolute_error(y_continuas_test, y_pred_continuas)
    mse = mean_squared_error(y_continuas_test, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_test)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_test_scaled)[1], axis=1)
    precision = precision_score(y_clase_test, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_test, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_test, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_test, y_pred_clase, labels=np.unique(y_clase_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 24600.3281 - salida_clase_accuracy: 0.2460 - salidas_continuas_mae: 95.7981 - val_loss: 6020.8325 - val_salida_clase_accuracy: 0.5070 - val_salidas_continuas_mae: 47.0710 - learning_rate: 5.0000e-04
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5062.6377 - salida_clase_accuracy: 0.5120 - salidas_continuas_mae: 42.8549 - val_loss: 3834.0950 - val_salida_clase_accuracy: 0.5976 - val_salidas_continuas_mae: 36.3913 - learning_rate: 5.0000e-04
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3674.4102 - salida_clase_accuracy: 0.6111 - salidas_continuas_mae: 35.6362 - val_loss: 3189.3240 - val_salida_clase_accuracy: 0.6136 - val_salidas_continuas_mae: 33.3659 - learning_rate: 5.0000e-04
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2966.8481 - salida_clase_accuracy: 0.6340 - salidas_continuas_mae: 32.4852 - val_loss: 2769.4390 - val_salida_clase_accuracy: 0.6376 - val_salidas_continuas_mae: 30.7896 - learning_rate: 5.0000e-04
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2501.2869 - salida_clase_accuracy: 0.6538 - salidas_continuas_mae: 29.6931 - val_loss: 2455.9219 - val_salida_clase_accuracy: 0.6705 - val_salidas_continuas_mae: 28.6828 - learning_rate: 5.0000e-04
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2274.3193 - salida_clase_accuracy: 0.6698 - salidas_continuas_mae: 27.7056 - val_loss: 2195.2285 - val_salida_clase_accuracy: 0.6987 - val_salidas_continuas_mae: 26.7133 - learning_rate: 5.0000e-04
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2092.3159 - salida_clase_accuracy: 0.7077 - salidas_continuas_mae: 26.1750 - val_loss: 1964.1945 - val_salida_clase_accuracy: 0.7242 - val_salidas_continuas_mae: 25.2383 - learning_rate: 5.0000e-04
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1780.0303 - salida_clase_accuracy: 0.7418 - salidas_continuas_mae: 24.3415 - val_loss: 1754.2505 - val_salida_clase_accuracy: 0.7681 - val_salidas_continuas_mae: 23.3526 - learning_rate: 5.0000e-04
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1564.1779 - salida_clase_accuracy: 0.7811 - salidas_continuas_mae: 22.6805 - val_loss: 1574.5635 - val_salida_clase_accuracy: 0.7972 - val_salidas_continuas_mae: 22.1516 - learning_rate: 5.0000e-04
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1417.5092 - salida_clase_accuracy: 0.7946 - salidas_continuas_mae: 21.4653 - val_loss: 1428.0721 - val_salida_clase_accuracy: 0.8013 - val_salidas_continuas_mae: 21.0708 - learning_rate: 5.0000e-04
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1277.1702 - salida_clase_accuracy: 0.7999 - salidas_continuas_mae: 20.4432 - val_loss: 1310.0428 - val_salida_clase_accuracy: 0.8004 - val_salidas_continuas_mae: 20.1626 - learning_rate: 5.0000e-04
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1153.5447 - salida_clase_accuracy: 0.7979 - salidas_continuas_mae: 19.6455 - val_loss: 1215.3989 - val_salida_clase_accuracy: 0.8023 - val_salidas_continuas_mae: 19.3379 - learning_rate: 5.0000e-04
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 995.3410 - salida_clase_accuracy: 0.8128 - salidas_continuas_mae: 18.5852 - val_loss: 1151.6869 - val_salida_clase_accuracy: 0.8084 - val_salidas_continuas_mae: 19.1233 - learning_rate: 5.0000e-04
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 982.4555 - salida_clase_accuracy: 0.8056 - salidas_continuas_mae: 18.3000 - val_loss: 1069.2815 - val_salida_clase_accuracy: 0.8065 - val_salidas_continuas_mae: 18.0682 - learning_rate: 5.0000e-04
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 902.3102 - salida_clase_accuracy: 0.8138 - salidas_continuas_mae: 17.5530 - val_loss: 1019.1241 - val_salida_clase_accuracy: 0.7821 - val_salidas_continuas_mae: 17.4975 - learning_rate: 5.0000e-04
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 867.6308 - salida_clase_accuracy: 0.8089 - salidas_continuas_mae: 17.0906 - val_loss: 967.4124 - val_salida_clase_accuracy: 0.8225 - val_salidas_continuas_mae: 16.8971 - learning_rate: 5.0000e-04
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 780.7162 - salida_clase_accuracy: 0.8146 - salidas_continuas_mae: 16.2817 - val_loss: 922.7383 - val_salida_clase_accuracy: 0.7985 - val_salidas_continuas_mae: 16.6768 - learning_rate: 5.0000e-04
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 815.6615 - salida_clase_accuracy: 0.8136 - salidas_continuas_mae: 16.1880 - val_loss: 891.4918 - val_salida_clase_accuracy: 0.8231 - val_salidas_continuas_mae: 16.1167 - learning_rate: 5.0000e-04
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 707.2698 - salida_clase_accuracy: 0.8226 - salidas_continuas_mae: 15.4452 - val_loss: 846.9387 - val_salida_clase_accuracy: 0.8077 - val_salidas_continuas_mae: 15.7130 - learning_rate: 5.0000e-04
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 684.3033 - salida_clase_accuracy: 0.8150 - salidas_continuas_mae: 15.0694 - val_loss: 821.8000 - val_salida_clase_accuracy: 0.8090 - val_salidas_continuas_mae: 15.5276 - learning_rate: 5.0000e-04
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 683.3427 - salida_clase_accuracy: 0.8168 - salidas_continuas_mae: 14.8444 - val_loss: 777.4020 - val_salida_clase_accuracy: 0.7869 - val_salidas_continuas_mae: 14.7969 - learning_rate: 5.0000e-04
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 623.4949 - salida_clase_accuracy: 0.8195 - salidas_continuas_mae: 14.1896 - val_loss: 758.2847 - val_salida_clase_accuracy: 0.8087 - val_salidas_continuas_mae: 14.7777 - learning_rate: 5.0000e-04
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 643.8281 - salida_clase_accuracy: 0.8096 - salidas_continuas_mae: 14.2677 - val_loss: 727.5692 - val_salida_clase_accuracy: 0.7985 - val_salidas_continuas_mae: 14.4502 - learning_rate: 5.0000e-04
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 567.2234 - salida_clase_accuracy: 0.8201 - salidas_continuas_mae: 13.5710 - val_loss: 707.3801 - val_salida_clase_accuracy: 0.8135 - val_salidas_continuas_mae: 14.3115 - learning_rate: 5.0000e-04
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 592.4688 - salida_clase_accuracy: 0.8112 - salidas_continuas_mae: 13.6652 - val_loss: 674.0059 - val_salida_clase_accuracy: 0.7933 - val_salidas_continuas_mae: 13.7796 - learning_rate: 5.0000e-04
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 570.2107 - salida_clase_accuracy: 0.8204 - salidas_continuas_mae: 13.2601 - val_loss: 654.4533 - val_salida_clase_accuracy: 0.8196 - val_salidas_continuas_mae: 13.4697 - learning_rate: 5.0000e-04
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 530.5921 - salida_clase_accuracy: 0.8219 - salidas_continuas_mae: 13.0186 - val_loss: 635.6826 - val_salida_clase_accuracy: 0.8007 - val_salidas_continuas_mae: 13.2136 - learning_rate: 5.0000e-04
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 537.1772 - salida_clase_accuracy: 0.8182 - salidas_continuas_mae: 12.8596 - val_loss: 624.3081 - val_salida_clase_accuracy: 0.8065 - val_salidas_continuas_mae: 13.2224 - learning_rate: 5.0000e-04
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 489.6660 - salida_clase_accuracy: 0.8300 - salidas_continuas_mae: 12.5367 - val_loss: 602.1553 - val_salida_clase_accuracy: 0.8170 - val_salidas_continuas_mae: 13.1145 - learning_rate: 5.0000e-04
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 495.8203 - salida_clase_accuracy: 0.8276 - salidas_continuas_mae: 12.4800 - val_loss: 579.8406 - val_salida_clase_accuracy: 0.8260 - val_salidas_continuas_mae: 12.6616 - learning_rate: 5.0000e-04
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 466.3626 - salida_clase_accuracy: 0.8282 - salidas_continuas_mae: 12.2232 - val_loss: 560.4935 - val_salida_clase_accuracy: 0.8343 - val_salidas_continuas_mae: 12.4605 - learning_rate: 5.0000e-04
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 431.5972 - salida_clase_accuracy: 0.8378 - salidas_continuas_mae: 11.8578 - val_loss: 552.6845 - val_salida_clase_accuracy: 0.7994 - val_salidas_continuas_mae: 12.4946 - learning_rate: 5.0000e-04
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 441.9316 - salida_clase_accuracy: 0.8306 - salidas_continuas_mae: 11.9128 - val_loss: 529.2560 - val_salida_clase_accuracy: 0.8295 - val_salidas_continuas_mae: 12.2654 - learning_rate: 5.0000e-04
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 417.8467 - salida_clase_accuracy: 0.8404 - salidas_continuas_mae: 11.7466 - val_loss: 520.4874 - val_salida_clase_accuracy: 0.8253 - val_salidas_continuas_mae: 12.1389 - learning_rate: 5.0000e-04
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 413.5440 - salida_clase_accuracy: 0.8423 - salidas_continuas_mae: 11.6251 - val_loss: 508.8347 - val_salida_clase_accuracy: 0.8426 - val_salidas_continuas_mae: 12.0080 - learning_rate: 5.0000e-04
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 400.8995 - salida_clase_accuracy: 0.8366 - salidas_continuas_mae: 11.4348 - val_loss: 496.4028 - val_salida_clase_accuracy: 0.8349 - val_salidas_continuas_mae: 11.9572 - learning_rate: 5.0000e-04
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 391.0072 - salida_clase_accuracy: 0.8466 - salidas_continuas_mae: 11.3219 - val_loss: 485.5393 - val_salida_clase_accuracy: 0.8295 - val_salidas_continuas_mae: 11.7482 - learning_rate: 5.0000e-04
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 399.3852 - salida_clase_accuracy: 0.8514 - salidas_continuas_mae: 11.2308 - val_loss: 475.6719 - val_salida_clase_accuracy: 0.8385 - val_salidas_continuas_mae: 11.6853 - learning_rate: 5.0000e-04
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 388.3151 - salida_clase_accuracy: 0.8546 - salidas_continuas_mae: 11.1497 - val_loss: 463.9575 - val_salida_clase_accuracy: 0.8599 - val_salidas_continuas_mae: 11.7026 - learning_rate: 5.0000e-04
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 383.2351 - salida_clase_accuracy: 0.8535 - salidas_continuas_mae: 11.1925 - val_loss: 453.6985 - val_salida_clase_accuracy: 0.8381 - val_salidas_continuas_mae: 11.4970 - learning_rate: 5.0000e-04
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 360.2084 - salida_clase_accuracy: 0.8565 - salidas_continuas_mae: 10.9769 - val_loss: 442.6493 - val_salida_clase_accuracy: 0.8519 - val_salidas_continuas_mae: 11.4597 - learning_rate: 5.0000e-04
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 396.2181 - salida_clase_accuracy: 0.8597 - salidas_continuas_mae: 11.0208 - val_loss: 432.9635 - val_salida_clase_accuracy: 0.8445 - val_salidas_continuas_mae: 11.2458 - learning_rate: 5.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 346.9061 - salida_clase_accuracy: 0.8580 - salidas_continuas_mae: 10.6820 - val_loss: 430.2346 - val_salida_clase_accuracy: 0.8644 - val_salidas_continuas_mae: 11.4045 - learning_rate: 5.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 344.6828 - salida_clase_accuracy: 0.8596 - salidas_continuas_mae: 10.6745 - val_loss: 416.8704 - val_salida_clase_accuracy: 0.8618 - val_salidas_continuas_mae: 11.0313 - learning_rate: 5.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 332.7863 - salida_clase_accuracy: 0.8578 - salidas_continuas_mae: 10.5179 - val_loss: 412.9389 - val_salida_clase_accuracy: 0.8701 - val_salidas_continuas_mae: 11.0703 - learning_rate: 5.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 332.7705 - salida_clase_accuracy: 0.8645 - salidas_continuas_mae: 10.4846 - val_loss: 408.4109 - val_salida_clase_accuracy: 0.8688 - val_salidas_continuas_mae: 11.0983 - learning_rate: 5.0000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 315.5914 - salida_clase_accuracy: 0.8665 - salidas_continuas_mae: 10.3585 - val_loss: 399.7348 - val_salida_clase_accuracy: 0.8586 - val_salidas_continuas_mae: 10.8328 - learning_rate: 5.0000e-04
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 327.3621 - salida_clase_accuracy: 0.8650 - salidas_continuas_mae: 10.5029 - val_loss: 389.0660 - val_salida_clase_accuracy: 0.8605 - val_salidas_continuas_mae: 10.7962 - learning_rate: 5.0000e-04
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 323.5550 - salida_clase_accuracy: 0.8663 - salidas_continuas_mae: 10.3606 - val_loss: 378.5163 - val_salida_clase_accuracy: 0.8650 - val_salidas_continuas_mae: 10.6130 - learning_rate: 5.0000e-04
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 319.8476 - salida_clase_accuracy: 0.8605 - salidas_continuas_mae: 10.3050 - val_loss: 371.2234 - val_salida_clase_accuracy: 0.8672 - val_salidas_continuas_mae: 10.3885 - learning_rate: 5.0000e-04
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 321.7805 - salida_clase_accuracy: 0.8598 - salidas_continuas_mae: 10.2395
# Fold 1: Loss=320.0027770996094, MAE=10.050615310668945, Accuracy=0.8643807768821716
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Entrenando fold 2...
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 23745.8965 - salida_clase_accuracy: 0.2060 - salidas_continuas_mae: 93.8779 - val_loss: 7290.8267 - val_salida_clase_accuracy: 0.3880 - val_salidas_continuas_mae: 56.9118 - learning_rate: 5.0000e-04
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5795.7212 - salida_clase_accuracy: 0.4052 - salidas_continuas_mae: 49.3165 - val_loss: 3808.1965 - val_salida_clase_accuracy: 0.5576 - val_salidas_continuas_mae: 37.2472 - learning_rate: 5.0000e-04
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3424.0229 - salida_clase_accuracy: 0.5299 - salidas_continuas_mae: 35.1758 - val_loss: 3096.7358 - val_salida_clase_accuracy: 0.5368 - val_salidas_continuas_mae: 32.9679 - learning_rate: 5.0000e-04
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3011.6299 - salida_clase_accuracy: 0.5438 - salidas_continuas_mae: 32.3611 - val_loss: 2678.5930 - val_salida_clase_accuracy: 0.5905 - val_salidas_continuas_mae: 30.7458 - learning_rate: 5.0000e-04
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2576.1755 - salida_clase_accuracy: 0.5791 - salidas_continuas_mae: 30.1140 - val_loss: 2349.6699 - val_salida_clase_accuracy: 0.5829 - val_salidas_continuas_mae: 28.6301 - learning_rate: 5.0000e-04
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2245.0244 - salida_clase_accuracy: 0.5889 - salidas_continuas_mae: 27.8565 - val_loss: 2074.2336 - val_salida_clase_accuracy: 0.6027 - val_salidas_continuas_mae: 26.6139 - learning_rate: 5.0000e-04
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1988.8649 - salida_clase_accuracy: 0.6087 - salidas_continuas_mae: 25.8894 - val_loss: 1866.3463 - val_salida_clase_accuracy: 0.6356 - val_salidas_continuas_mae: 24.8782 - learning_rate: 5.0000e-04
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1732.7524 - salida_clase_accuracy: 0.6502 - salidas_continuas_mae: 24.2077 - val_loss: 1664.7455 - val_salida_clase_accuracy: 0.6932 - val_salidas_continuas_mae: 23.3041 - learning_rate: 5.0000e-04
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1567.1796 - salida_clase_accuracy: 0.6806 - salidas_continuas_mae: 22.8730 - val_loss: 1492.0326 - val_salida_clase_accuracy: 0.7073 - val_salidas_continuas_mae: 22.0270 - learning_rate: 5.0000e-04
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1438.7303 - salida_clase_accuracy: 0.7230 - salidas_continuas_mae: 21.6783 - val_loss: 1351.9800 - val_salida_clase_accuracy: 0.7438 - val_salidas_continuas_mae: 20.9663 - learning_rate: 5.0000e-04
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1325.0667 - salida_clase_accuracy: 0.7414 - salidas_continuas_mae: 20.6389 - val_loss: 1235.1392 - val_salida_clase_accuracy: 0.7553 - val_salidas_continuas_mae: 20.1943 - learning_rate: 5.0000e-04
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1189.4774 - salida_clase_accuracy: 0.7642 - salidas_continuas_mae: 19.7969 - val_loss: 1137.6511 - val_salida_clase_accuracy: 0.7546 - val_salidas_continuas_mae: 19.6049 - learning_rate: 5.0000e-04
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1117.1722 - salida_clase_accuracy: 0.7679 - salidas_continuas_mae: 19.2346 - val_loss: 1055.6173 - val_salida_clase_accuracy: 0.7671 - val_salidas_continuas_mae: 18.6651 - learning_rate: 5.0000e-04
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1018.5737 - salida_clase_accuracy: 0.7868 - salidas_continuas_mae: 18.3627 - val_loss: 990.7272 - val_salida_clase_accuracy: 0.7652 - val_salidas_continuas_mae: 18.2809 - learning_rate: 5.0000e-04
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 987.8699 - salida_clase_accuracy: 0.7700 - salidas_continuas_mae: 17.8765 - val_loss: 922.4626 - val_salida_clase_accuracy: 0.7502 - val_salidas_continuas_mae: 17.4417 - learning_rate: 5.0000e-04
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 893.3373 - salida_clase_accuracy: 0.7551 - salidas_continuas_mae: 17.3307 - val_loss: 877.1543 - val_salida_clase_accuracy: 0.7569 - val_salidas_continuas_mae: 17.1118 - learning_rate: 5.0000e-04
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 851.6022 - salida_clase_accuracy: 0.7541 - salidas_continuas_mae: 16.8443 - val_loss: 834.6039 - val_salida_clase_accuracy: 0.7361 - val_salidas_continuas_mae: 16.8099 - learning_rate: 5.0000e-04
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 812.5710 - salida_clase_accuracy: 0.7519 - salidas_continuas_mae: 16.4165 - val_loss: 791.6802 - val_salida_clase_accuracy: 0.7281 - val_salidas_continuas_mae: 16.3783 - learning_rate: 5.0000e-04
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 801.2144 - salida_clase_accuracy: 0.7593 - salidas_continuas_mae: 16.2374 - val_loss: 766.3683 - val_salida_clase_accuracy: 0.7399 - val_salidas_continuas_mae: 16.0997 - learning_rate: 5.0000e-04
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 718.8370 - salida_clase_accuracy: 0.7476 - salidas_continuas_mae: 15.5688 - val_loss: 726.1172 - val_salida_clase_accuracy: 0.7319 - val_salidas_continuas_mae: 15.5370 - learning_rate: 5.0000e-04
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 708.3026 - salida_clase_accuracy: 0.7544 - salidas_continuas_mae: 15.2989 - val_loss: 695.2711 - val_salida_clase_accuracy: 0.7585 - val_salidas_continuas_mae: 15.2241 - learning_rate: 5.0000e-04
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 687.4597 - salida_clase_accuracy: 0.7658 - salidas_continuas_mae: 14.9895 - val_loss: 668.8775 - val_salida_clase_accuracy: 0.7726 - val_salidas_continuas_mae: 14.8830 - learning_rate: 5.0000e-04
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 639.2542 - salida_clase_accuracy: 0.7765 - salidas_continuas_mae: 14.3776 - val_loss: 638.3616 - val_salida_clase_accuracy: 0.7486 - val_salidas_continuas_mae: 14.5012 - learning_rate: 5.0000e-04
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 614.2459 - salida_clase_accuracy: 0.7742 - salidas_continuas_mae: 14.1553 - val_loss: 613.2007 - val_salida_clase_accuracy: 0.7706 - val_salidas_continuas_mae: 14.1874 - learning_rate: 5.0000e-04
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 603.6359 - salida_clase_accuracy: 0.7826 - salidas_continuas_mae: 13.9742 - val_loss: 585.8094 - val_salida_clase_accuracy: 0.7684 - val_salidas_continuas_mae: 13.7086 - learning_rate: 5.0000e-04
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 551.6707 - salida_clase_accuracy: 0.7946 - salidas_continuas_mae: 13.5456 - val_loss: 566.5092 - val_salida_clase_accuracy: 0.7761 - val_salidas_continuas_mae: 13.5508 - learning_rate: 5.0000e-04
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 522.4323 - salida_clase_accuracy: 0.7969 - salidas_continuas_mae: 13.2013 - val_loss: 548.8368 - val_salida_clase_accuracy: 0.8017 - val_salidas_continuas_mae: 13.3974 - learning_rate: 5.0000e-04
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 516.8187 - salida_clase_accuracy: 0.8002 - salidas_continuas_mae: 13.1285 - val_loss: 534.8377 - val_salida_clase_accuracy: 0.7908 - val_salidas_continuas_mae: 13.3060 - learning_rate: 5.0000e-04
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 502.3011 - salida_clase_accuracy: 0.8070 - salidas_continuas_mae: 12.9290 - val_loss: 509.4732 - val_salida_clase_accuracy: 0.8125 - val_salidas_continuas_mae: 12.8103 - learning_rate: 5.0000e-04
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 474.3731 - salida_clase_accuracy: 0.8194 - salidas_continuas_mae: 12.6045 - val_loss: 491.1509 - val_salida_clase_accuracy: 0.8061 - val_salidas_continuas_mae: 12.5852 - learning_rate: 5.0000e-04
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 439.5340 - salida_clase_accuracy: 0.8161 - salidas_continuas_mae: 12.3561 - val_loss: 477.0178 - val_salida_clase_accuracy: 0.7959 - val_salidas_continuas_mae: 12.4786 - learning_rate: 5.0000e-04
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 459.9997 - salida_clase_accuracy: 0.8227 - salidas_continuas_mae: 12.3228 - val_loss: 467.6599 - val_salida_clase_accuracy: 0.8330 - val_salidas_continuas_mae: 12.2727 - learning_rate: 5.0000e-04
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 408.4129 - salida_clase_accuracy: 0.8308 - salidas_continuas_mae: 11.8547 - val_loss: 452.4461 - val_salida_clase_accuracy: 0.8145 - val_salidas_continuas_mae: 12.0657 - learning_rate: 5.0000e-04
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 395.1053 - salida_clase_accuracy: 0.8337 - salidas_continuas_mae: 11.7654 - val_loss: 444.7787 - val_salida_clase_accuracy: 0.8257 - val_salidas_continuas_mae: 12.1104 - learning_rate: 5.0000e-04
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 396.0414 - salida_clase_accuracy: 0.8355 - salidas_continuas_mae: 11.6572 - val_loss: 435.8233 - val_salida_clase_accuracy: 0.8397 - val_salidas_continuas_mae: 11.9438 - learning_rate: 5.0000e-04
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 382.0068 - salida_clase_accuracy: 0.8358 - salidas_continuas_mae: 11.5683 - val_loss: 420.5344 - val_salida_clase_accuracy: 0.8391 - val_salidas_continuas_mae: 11.6767 - learning_rate: 5.0000e-04
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 358.1281 - salida_clase_accuracy: 0.8317 - salidas_continuas_mae: 11.2107 - val_loss: 417.4775 - val_salida_clase_accuracy: 0.8426 - val_salidas_continuas_mae: 11.7827 - learning_rate: 5.0000e-04
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 363.0686 - salida_clase_accuracy: 0.8429 - salidas_continuas_mae: 11.2639 - val_loss: 406.8456 - val_salida_clase_accuracy: 0.8349 - val_salidas_continuas_mae: 11.5325 - learning_rate: 5.0000e-04
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 357.4702 - salida_clase_accuracy: 0.8405 - salidas_continuas_mae: 11.1014 - val_loss: 394.8471 - val_salida_clase_accuracy: 0.8337 - val_salidas_continuas_mae: 11.2646 - learning_rate: 5.0000e-04
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 352.2978 - salida_clase_accuracy: 0.8460 - salidas_continuas_mae: 10.9778 - val_loss: 386.3545 - val_salida_clase_accuracy: 0.8433 - val_salidas_continuas_mae: 11.1428 - learning_rate: 5.0000e-04
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 331.9318 - salida_clase_accuracy: 0.8531 - salidas_continuas_mae: 10.7762 - val_loss: 385.7883 - val_salida_clase_accuracy: 0.8461 - val_salidas_continuas_mae: 11.2309 - learning_rate: 5.0000e-04
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 322.4297 - salida_clase_accuracy: 0.8440 - salidas_continuas_mae: 10.6389 - val_loss: 376.3306 - val_salida_clase_accuracy: 0.8202 - val_salidas_continuas_mae: 11.1309 - learning_rate: 5.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 312.1982 - salida_clase_accuracy: 0.8451 - salidas_continuas_mae: 10.5071 - val_loss: 366.7746 - val_salida_clase_accuracy: 0.8401 - val_salidas_continuas_mae: 10.9014 - learning_rate: 5.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 308.4809 - salida_clase_accuracy: 0.8475 - salidas_continuas_mae: 10.4711 - val_loss: 356.7653 - val_salida_clase_accuracy: 0.8445 - val_salidas_continuas_mae: 10.6898 - learning_rate: 5.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 326.1675 - salida_clase_accuracy: 0.8515 - salidas_continuas_mae: 10.5213 - val_loss: 352.9088 - val_salida_clase_accuracy: 0.8560 - val_salidas_continuas_mae: 10.6862 - learning_rate: 5.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 294.9718 - salida_clase_accuracy: 0.8554 - salidas_continuas_mae: 10.2919 - val_loss: 350.9226 - val_salida_clase_accuracy: 0.8429 - val_salidas_continuas_mae: 10.7250 - learning_rate: 5.0000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 283.7953 - salida_clase_accuracy: 0.8567 - salidas_continuas_mae: 10.0703 - val_loss: 357.9359 - val_salida_clase_accuracy: 0.8589 - val_salidas_continuas_mae: 10.9331 - learning_rate: 5.0000e-04
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 299.6985 - salida_clase_accuracy: 0.8535 - salidas_continuas_mae: 10.2767 - val_loss: 335.4577 - val_salida_clase_accuracy: 0.8532 - val_salidas_continuas_mae: 10.4137 - learning_rate: 5.0000e-04
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 285.0611 - salida_clase_accuracy: 0.8612 - salidas_continuas_mae: 10.0011 - val_loss: 330.4779 - val_salida_clase_accuracy: 0.8541 - val_salidas_continuas_mae: 10.3259 - learning_rate: 5.0000e-04
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 277.9632 - salida_clase_accuracy: 0.8585 - salidas_continuas_mae: 9.9631 - val_loss: 326.9996 - val_salida_clase_accuracy: 0.8621 - val_salidas_continuas_mae: 10.3147 - learning_rate: 5.0000e-04
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 299.0438 - salida_clase_accuracy: 0.8680 - salidas_continuas_mae: 10.2176
# Fold 2: Loss=293.6146240234375, MAE=10.04858684539795, Accuracy=0.8712896704673767
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Entrenando fold 3...
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 24676.2754 - salida_clase_accuracy: 0.1521 - salidas_continuas_mae: 97.1590 - val_loss: 8202.5508 - val_salida_clase_accuracy: 0.4162 - val_salidas_continuas_mae: 62.1117 - learning_rate: 5.0000e-04
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6649.5625 - salida_clase_accuracy: 0.4540 - salidas_continuas_mae: 54.8028 - val_loss: 4216.8018 - val_salida_clase_accuracy: 0.5518 - val_salidas_continuas_mae: 39.8997 - learning_rate: 5.0000e-04
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3874.0688 - salida_clase_accuracy: 0.5859 - salidas_continuas_mae: 37.9683 - val_loss: 3330.9302 - val_salida_clase_accuracy: 0.6324 - val_salidas_continuas_mae: 34.2650 - learning_rate: 5.0000e-04
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3236.8799 - salida_clase_accuracy: 0.6543 - salidas_continuas_mae: 33.7917 - val_loss: 2884.9966 - val_salida_clase_accuracy: 0.6116 - val_salidas_continuas_mae: 31.1817 - learning_rate: 5.0000e-04
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2666.0886 - salida_clase_accuracy: 0.6487 - salidas_continuas_mae: 31.0123 - val_loss: 2595.7993 - val_salida_clase_accuracy: 0.6923 - val_salidas_continuas_mae: 29.5268 - learning_rate: 5.0000e-04
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2414.0225 - salida_clase_accuracy: 0.6868 - salidas_continuas_mae: 29.2205 - val_loss: 2350.8940 - val_salida_clase_accuracy: 0.7099 - val_salidas_continuas_mae: 27.6957 - learning_rate: 5.0000e-04
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2134.0457 - salida_clase_accuracy: 0.6979 - salidas_continuas_mae: 27.2133 - val_loss: 2162.3564 - val_salida_clase_accuracy: 0.6977 - val_salidas_continuas_mae: 26.5612 - learning_rate: 5.0000e-04
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1925.7626 - salida_clase_accuracy: 0.6950 - salidas_continuas_mae: 26.0191 - val_loss: 1973.7341 - val_salida_clase_accuracy: 0.7070 - val_salidas_continuas_mae: 25.3622 - learning_rate: 5.0000e-04
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1871.9224 - salida_clase_accuracy: 0.6919 - salidas_continuas_mae: 25.1976 - val_loss: 1800.1324 - val_salida_clase_accuracy: 0.6951 - val_salidas_continuas_mae: 23.8509 - learning_rate: 5.0000e-04
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1668.8838 - salida_clase_accuracy: 0.7043 - salidas_continuas_mae: 23.8015 - val_loss: 1622.8127 - val_salida_clase_accuracy: 0.7364 - val_salidas_continuas_mae: 22.4672 - learning_rate: 5.0000e-04
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1487.3794 - salida_clase_accuracy: 0.7357 - salidas_continuas_mae: 22.0346 - val_loss: 1456.6030 - val_salida_clase_accuracy: 0.7527 - val_salidas_continuas_mae: 21.2674 - learning_rate: 5.0000e-04
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1256.8783 - salida_clase_accuracy: 0.7610 - salidas_continuas_mae: 20.6412 - val_loss: 1342.9484 - val_salida_clase_accuracy: 0.7774 - val_salidas_continuas_mae: 20.4626 - learning_rate: 5.0000e-04
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1186.3120 - salida_clase_accuracy: 0.7866 - salidas_continuas_mae: 19.8565 - val_loss: 1230.5542 - val_salida_clase_accuracy: 0.7898 - val_salidas_continuas_mae: 19.3726 - learning_rate: 5.0000e-04
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1118.5455 - salida_clase_accuracy: 0.7914 - salidas_continuas_mae: 19.2237 - val_loss: 1155.0658 - val_salida_clase_accuracy: 0.7949 - val_salidas_continuas_mae: 18.7964 - learning_rate: 5.0000e-04
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1028.7806 - salida_clase_accuracy: 0.8112 - salidas_continuas_mae: 18.4558 - val_loss: 1087.8480 - val_salida_clase_accuracy: 0.8247 - val_salidas_continuas_mae: 18.1672 - learning_rate: 5.0000e-04
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 955.8049 - salida_clase_accuracy: 0.8060 - salidas_continuas_mae: 17.9042 - val_loss: 1026.6810 - val_salida_clase_accuracy: 0.8161 - val_salidas_continuas_mae: 17.5901 - learning_rate: 5.0000e-04
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 890.7753 - salida_clase_accuracy: 0.8138 - salidas_continuas_mae: 17.3647 - val_loss: 984.1054 - val_salida_clase_accuracy: 0.8145 - val_salidas_continuas_mae: 17.2232 - learning_rate: 5.0000e-04
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 841.9663 - salida_clase_accuracy: 0.8106 - salidas_continuas_mae: 16.8239 - val_loss: 950.9995 - val_salida_clase_accuracy: 0.8148 - val_salidas_continuas_mae: 16.9617 - learning_rate: 5.0000e-04
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 802.7819 - salida_clase_accuracy: 0.8141 - salidas_continuas_mae: 16.3269 - val_loss: 907.4152 - val_salida_clase_accuracy: 0.7991 - val_salidas_continuas_mae: 16.4955 - learning_rate: 5.0000e-04
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 784.2336 - salida_clase_accuracy: 0.8120 - salidas_continuas_mae: 16.1512 - val_loss: 869.6956 - val_salida_clase_accuracy: 0.8359 - val_salidas_continuas_mae: 16.0931 - learning_rate: 5.0000e-04
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 762.2446 - salida_clase_accuracy: 0.8132 - salidas_continuas_mae: 15.7060 - val_loss: 840.1647 - val_salida_clase_accuracy: 0.8407 - val_salidas_continuas_mae: 15.7049 - learning_rate: 5.0000e-04
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 724.0320 - salida_clase_accuracy: 0.8189 - salidas_continuas_mae: 15.2686 - val_loss: 813.2358 - val_salida_clase_accuracy: 0.8337 - val_salidas_continuas_mae: 15.3974 - learning_rate: 5.0000e-04
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 676.3703 - salida_clase_accuracy: 0.8279 - salidas_continuas_mae: 15.0783 - val_loss: 776.6073 - val_salida_clase_accuracy: 0.8356 - val_salidas_continuas_mae: 14.9501 - learning_rate: 5.0000e-04
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 641.9752 - salida_clase_accuracy: 0.8239 - salidas_continuas_mae: 14.6065 - val_loss: 753.1246 - val_salida_clase_accuracy: 0.8496 - val_salidas_continuas_mae: 14.7196 - learning_rate: 5.0000e-04
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 619.1450 - salida_clase_accuracy: 0.8296 - salidas_continuas_mae: 14.3639 - val_loss: 727.8466 - val_salida_clase_accuracy: 0.8346 - val_salidas_continuas_mae: 14.4741 - learning_rate: 5.0000e-04
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 626.9094 - salida_clase_accuracy: 0.8286 - salidas_continuas_mae: 14.2129 - val_loss: 707.7126 - val_salida_clase_accuracy: 0.8445 - val_salidas_continuas_mae: 14.1097 - learning_rate: 5.0000e-04
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 559.1830 - salida_clase_accuracy: 0.8252 - salidas_continuas_mae: 13.6619 - val_loss: 682.4098 - val_salida_clase_accuracy: 0.8538 - val_salidas_continuas_mae: 14.0108 - learning_rate: 5.0000e-04
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 559.2519 - salida_clase_accuracy: 0.8328 - salidas_continuas_mae: 13.7272 - val_loss: 666.5718 - val_salida_clase_accuracy: 0.8436 - val_salidas_continuas_mae: 13.6210 - learning_rate: 5.0000e-04
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 551.7532 - salida_clase_accuracy: 0.8313 - salidas_continuas_mae: 13.4448 - val_loss: 643.5393 - val_salida_clase_accuracy: 0.8273 - val_salidas_continuas_mae: 13.5278 - learning_rate: 5.0000e-04
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 531.4065 - salida_clase_accuracy: 0.8267 - salidas_continuas_mae: 13.1960 - val_loss: 624.5409 - val_salida_clase_accuracy: 0.8541 - val_salidas_continuas_mae: 13.2927 - learning_rate: 5.0000e-04
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 506.7418 - salida_clase_accuracy: 0.8320 - salidas_continuas_mae: 12.9394 - val_loss: 617.6824 - val_salida_clase_accuracy: 0.8557 - val_salidas_continuas_mae: 13.2181 - learning_rate: 5.0000e-04
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 497.4029 - salida_clase_accuracy: 0.8439 - salidas_continuas_mae: 12.6561 - val_loss: 596.2338 - val_salida_clase_accuracy: 0.8394 - val_salidas_continuas_mae: 12.9490 - learning_rate: 5.0000e-04
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 493.4247 - salida_clase_accuracy: 0.8392 - salidas_continuas_mae: 12.6143 - val_loss: 586.3284 - val_salida_clase_accuracy: 0.8314 - val_salidas_continuas_mae: 13.0124 - learning_rate: 5.0000e-04
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 500.3213 - salida_clase_accuracy: 0.8393 - salidas_continuas_mae: 12.5594 - val_loss: 561.1041 - val_salida_clase_accuracy: 0.8426 - val_salidas_continuas_mae: 12.5517 - learning_rate: 5.0000e-04
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 440.0516 - salida_clase_accuracy: 0.8451 - salidas_continuas_mae: 12.1952 - val_loss: 554.6426 - val_salida_clase_accuracy: 0.8269 - val_salidas_continuas_mae: 12.5690 - learning_rate: 5.0000e-04
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 423.8682 - salida_clase_accuracy: 0.8483 - salidas_continuas_mae: 11.9562 - val_loss: 538.0728 - val_salida_clase_accuracy: 0.8695 - val_salidas_continuas_mae: 12.2842 - learning_rate: 5.0000e-04
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 408.2259 - salida_clase_accuracy: 0.8558 - salidas_continuas_mae: 11.8100 - val_loss: 521.6810 - val_salida_clase_accuracy: 0.8535 - val_salidas_continuas_mae: 12.2443 - learning_rate: 5.0000e-04
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 433.5646 - salida_clase_accuracy: 0.8560 - salidas_continuas_mae: 11.8348 - val_loss: 520.0947 - val_salida_clase_accuracy: 0.8768 - val_salidas_continuas_mae: 12.2536 - learning_rate: 5.0000e-04
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 407.5607 - salida_clase_accuracy: 0.8528 - salidas_continuas_mae: 11.7485 - val_loss: 502.1219 - val_salida_clase_accuracy: 0.8551 - val_salidas_continuas_mae: 12.0421 - learning_rate: 5.0000e-04
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 377.5330 - salida_clase_accuracy: 0.8574 - salidas_continuas_mae: 11.3721 - val_loss: 485.5074 - val_salida_clase_accuracy: 0.8682 - val_salidas_continuas_mae: 11.7106 - learning_rate: 5.0000e-04
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 389.4906 - salida_clase_accuracy: 0.8640 - salidas_continuas_mae: 11.3614 - val_loss: 476.8239 - val_salida_clase_accuracy: 0.8698 - val_salidas_continuas_mae: 11.7388 - learning_rate: 5.0000e-04
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 390.4034 - salida_clase_accuracy: 0.8730 - salidas_continuas_mae: 11.3382 - val_loss: 472.9545 - val_salida_clase_accuracy: 0.8788 - val_salidas_continuas_mae: 11.7134 - learning_rate: 5.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 373.7217 - salida_clase_accuracy: 0.8767 - salidas_continuas_mae: 11.2161 - val_loss: 458.3736 - val_salida_clase_accuracy: 0.8759 - val_salidas_continuas_mae: 11.5425 - learning_rate: 5.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 370.7264 - salida_clase_accuracy: 0.8804 - salidas_continuas_mae: 11.0427 - val_loss: 453.1195 - val_salida_clase_accuracy: 0.8868 - val_salidas_continuas_mae: 11.5221 - learning_rate: 5.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 351.0359 - salida_clase_accuracy: 0.8776 - salidas_continuas_mae: 10.9875 - val_loss: 441.8025 - val_salida_clase_accuracy: 0.8928 - val_salidas_continuas_mae: 11.4857 - learning_rate: 5.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 336.2053 - salida_clase_accuracy: 0.8784 - salidas_continuas_mae: 10.7349 - val_loss: 437.6105 - val_salida_clase_accuracy: 0.8794 - val_salidas_continuas_mae: 11.4973 - learning_rate: 5.0000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 336.9684 - salida_clase_accuracy: 0.8761 - salidas_continuas_mae: 10.6825 - val_loss: 425.7951 - val_salida_clase_accuracy: 0.8720 - val_salidas_continuas_mae: 11.1637 - learning_rate: 5.0000e-04
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 337.8470 - salida_clase_accuracy: 0.8796 - salidas_continuas_mae: 10.7614 - val_loss: 413.3599 - val_salida_clase_accuracy: 0.8938 - val_salidas_continuas_mae: 11.1248 - learning_rate: 5.0000e-04
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 342.8988 - salida_clase_accuracy: 0.8839 - salidas_continuas_mae: 10.7093 - val_loss: 407.6171 - val_salida_clase_accuracy: 0.8957 - val_salidas_continuas_mae: 10.9964 - learning_rate: 5.0000e-04
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 317.5094 - salida_clase_accuracy: 0.8900 - salidas_continuas_mae: 10.3509 - val_loss: 407.5941 - val_salida_clase_accuracy: 0.8823 - val_salidas_continuas_mae: 11.0330 - learning_rate: 5.0000e-04
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 363.4548 - salida_clase_accuracy: 0.8708 - salidas_continuas_mae: 10.9780
# Fold 3: Loss=347.86474609375, MAE=10.759899139404297, Accuracy=0.8735926151275635
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Entrenando fold 4...
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 23782.0723 - salida_clase_accuracy: 0.1188 - salidas_continuas_mae: 95.1889 - val_loss: 6628.0996 - val_salida_clase_accuracy: 0.4958 - val_salidas_continuas_mae: 53.6452 - learning_rate: 5.0000e-04
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5430.7622 - salida_clase_accuracy: 0.4302 - salidas_continuas_mae: 47.6846 - val_loss: 3843.8359 - val_salida_clase_accuracy: 0.5361 - val_salidas_continuas_mae: 37.8799 - learning_rate: 5.0000e-04
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 3680.9888 - salida_clase_accuracy: 0.5553 - salidas_continuas_mae: 36.2956 - val_loss: 3107.5547 - val_salida_clase_accuracy: 0.5857 - val_salidas_continuas_mae: 33.0590 - learning_rate: 5.0000e-04
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2936.3438 - salida_clase_accuracy: 0.6213 - salidas_continuas_mae: 32.3166 - val_loss: 2702.1501 - val_salida_clase_accuracy: 0.6631 - val_salidas_continuas_mae: 30.8891 - learning_rate: 5.0000e-04
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2463.0593 - salida_clase_accuracy: 0.6609 - salidas_continuas_mae: 29.7178 - val_loss: 2383.3555 - val_salida_clase_accuracy: 0.7172 - val_salidas_continuas_mae: 29.1299 - learning_rate: 5.0000e-04
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2264.3171 - salida_clase_accuracy: 0.7036 - salidas_continuas_mae: 27.8141 - val_loss: 2121.6765 - val_salida_clase_accuracy: 0.6900 - val_salidas_continuas_mae: 27.0960 - learning_rate: 5.0000e-04
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2077.1292 - salida_clase_accuracy: 0.7002 - salidas_continuas_mae: 26.5917 - val_loss: 1895.4296 - val_salida_clase_accuracy: 0.7226 - val_salidas_continuas_mae: 25.7461 - learning_rate: 5.0000e-04
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1845.0967 - salida_clase_accuracy: 0.7175 - salidas_continuas_mae: 25.0651 - val_loss: 1661.5587 - val_salida_clase_accuracy: 0.7399 - val_salidas_continuas_mae: 24.2740 - learning_rate: 5.0000e-04
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1637.1375 - salida_clase_accuracy: 0.7328 - salidas_continuas_mae: 23.7535 - val_loss: 1435.5903 - val_salida_clase_accuracy: 0.7396 - val_salidas_continuas_mae: 22.5429 - learning_rate: 5.0000e-04
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1374.3275 - salida_clase_accuracy: 0.7493 - salidas_continuas_mae: 22.0017 - val_loss: 1267.5089 - val_salida_clase_accuracy: 0.7690 - val_salidas_continuas_mae: 21.1139 - learning_rate: 5.0000e-04
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1242.1967 - salida_clase_accuracy: 0.7628 - salidas_continuas_mae: 20.7041 - val_loss: 1138.0356 - val_salida_clase_accuracy: 0.7745 - val_salidas_continuas_mae: 19.7691 - learning_rate: 5.0000e-04
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1095.4480 - salida_clase_accuracy: 0.7660 - salidas_continuas_mae: 19.3307 - val_loss: 1050.2363 - val_salida_clase_accuracy: 0.7694 - val_salidas_continuas_mae: 19.0809 - learning_rate: 5.0000e-04
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 1051.1813 - salida_clase_accuracy: 0.7673 - salidas_continuas_mae: 18.6906 - val_loss: 968.3409 - val_salida_clase_accuracy: 0.7671 - val_salidas_continuas_mae: 18.0828 - learning_rate: 5.0000e-04
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 901.4768 - salida_clase_accuracy: 0.7619 - salidas_continuas_mae: 17.5994 - val_loss: 911.8965 - val_salida_clase_accuracy: 0.7591 - val_salidas_continuas_mae: 17.6068 - learning_rate: 5.0000e-04
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 893.6772 - salida_clase_accuracy: 0.7620 - salidas_continuas_mae: 17.1846 - val_loss: 856.0874 - val_salida_clase_accuracy: 0.7495 - val_salidas_continuas_mae: 16.9460 - learning_rate: 5.0000e-04
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 867.6227 - salida_clase_accuracy: 0.7460 - salidas_continuas_mae: 16.9359 - val_loss: 812.4418 - val_salida_clase_accuracy: 0.7447 - val_salidas_continuas_mae: 16.5627 - learning_rate: 5.0000e-04
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 767.3311 - salida_clase_accuracy: 0.7462 - salidas_continuas_mae: 16.0725 - val_loss: 775.1567 - val_salida_clase_accuracy: 0.7534 - val_salidas_continuas_mae: 16.0569 - learning_rate: 5.0000e-04
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 727.8772 - salida_clase_accuracy: 0.7503 - salidas_continuas_mae: 15.6954 - val_loss: 735.8204 - val_salida_clase_accuracy: 0.7732 - val_salidas_continuas_mae: 15.6766 - learning_rate: 5.0000e-04
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 670.6365 - salida_clase_accuracy: 0.7553 - salidas_continuas_mae: 15.0913 - val_loss: 711.8777 - val_salida_clase_accuracy: 0.7623 - val_salidas_continuas_mae: 15.4112 - learning_rate: 5.0000e-04
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 687.0151 - salida_clase_accuracy: 0.7518 - salidas_continuas_mae: 15.2833 - val_loss: 683.9415 - val_salida_clase_accuracy: 0.7655 - val_salidas_continuas_mae: 15.1508 - learning_rate: 5.0000e-04
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 692.5673 - salida_clase_accuracy: 0.7594 - salidas_continuas_mae: 14.7614 - val_loss: 646.8214 - val_salida_clase_accuracy: 0.7588 - val_salidas_continuas_mae: 14.6027 - learning_rate: 5.0000e-04
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 614.3634 - salida_clase_accuracy: 0.7684 - salidas_continuas_mae: 14.3843 - val_loss: 619.0252 - val_salida_clase_accuracy: 0.7594 - val_salidas_continuas_mae: 14.1760 - learning_rate: 5.0000e-04
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 575.0787 - salida_clase_accuracy: 0.7711 - salidas_continuas_mae: 13.8883 - val_loss: 595.6968 - val_salida_clase_accuracy: 0.7610 - val_salidas_continuas_mae: 13.9189 - learning_rate: 5.0000e-04
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 549.8608 - salida_clase_accuracy: 0.7672 - salidas_continuas_mae: 13.6000 - val_loss: 572.7234 - val_salida_clase_accuracy: 0.7869 - val_salidas_continuas_mae: 13.5904 - learning_rate: 5.0000e-04
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 547.2078 - salida_clase_accuracy: 0.7777 - salidas_continuas_mae: 13.4738 - val_loss: 548.1125 - val_salida_clase_accuracy: 0.7706 - val_salidas_continuas_mae: 13.2624 - learning_rate: 5.0000e-04
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 489.5939 - salida_clase_accuracy: 0.7887 - salidas_continuas_mae: 12.8827 - val_loss: 538.9080 - val_salida_clase_accuracy: 0.7815 - val_salidas_continuas_mae: 13.2513 - learning_rate: 5.0000e-04
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 489.4927 - salida_clase_accuracy: 0.7836 - salidas_continuas_mae: 12.8036 - val_loss: 516.6522 - val_salida_clase_accuracy: 0.7997 - val_salidas_continuas_mae: 12.9285 - learning_rate: 5.0000e-04
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 462.3657 - salida_clase_accuracy: 0.7933 - salidas_continuas_mae: 12.3916 - val_loss: 499.0857 - val_salida_clase_accuracy: 0.8225 - val_salidas_continuas_mae: 12.7355 - learning_rate: 5.0000e-04
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 452.0658 - salida_clase_accuracy: 0.8081 - salidas_continuas_mae: 12.3216 - val_loss: 475.0102 - val_salida_clase_accuracy: 0.8260 - val_salidas_continuas_mae: 12.3121 - learning_rate: 5.0000e-04
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 418.1552 - salida_clase_accuracy: 0.8203 - salidas_continuas_mae: 11.9293 - val_loss: 461.5623 - val_salida_clase_accuracy: 0.8317 - val_salidas_continuas_mae: 12.1760 - learning_rate: 5.0000e-04
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 387.1484 - salida_clase_accuracy: 0.8159 - salidas_continuas_mae: 11.6616 - val_loss: 449.5496 - val_salida_clase_accuracy: 0.8285 - val_salidas_continuas_mae: 11.9932 - learning_rate: 5.0000e-04
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 412.0753 - salida_clase_accuracy: 0.8202 - salidas_continuas_mae: 11.5581 - val_loss: 438.8039 - val_salida_clase_accuracy: 0.8279 - val_salidas_continuas_mae: 11.8293 - learning_rate: 5.0000e-04
# Epoch 33/50
# ...
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 309.4041 - salida_clase_accuracy: 0.8589 - salidas_continuas_mae: 10.1997 - val_loss: 361.8322 - val_salida_clase_accuracy: 0.8730 - val_salidas_continuas_mae: 10.6712 - learning_rate: 5.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 291.4907 - salida_clase_accuracy: 0.8605 - salidas_continuas_mae: 10.1060 - val_loss: 364.2456 - val_salida_clase_accuracy: 0.8592 - val_salidas_continuas_mae: 10.8028 - learning_rate: 5.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 313.2490 - salida_clase_accuracy: 0.8609 - salidas_continuas_mae: 10.3683 - val_loss: 344.7983 - val_salida_clase_accuracy: 0.8765 - val_salidas_continuas_mae: 10.3931 - learning_rate: 5.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 303.4701 - salida_clase_accuracy: 0.8633 - salidas_continuas_mae: 10.1527 - val_loss: 345.4290 - val_salida_clase_accuracy: 0.8765 - val_salidas_continuas_mae: 10.6282 - learning_rate: 5.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 291.6857 - salida_clase_accuracy: 0.8674 - salidas_continuas_mae: 10.0301 - val_loss: 334.4364 - val_salida_clase_accuracy: 0.8788 - val_salidas_continuas_mae: 10.3914 - learning_rate: 5.0000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 273.1444 - salida_clase_accuracy: 0.8628 - salidas_continuas_mae: 9.9310 - val_loss: 331.5974 - val_salida_clase_accuracy: 0.8698 - val_salidas_continuas_mae: 10.3761 - learning_rate: 5.0000e-04
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 274.1143 - salida_clase_accuracy: 0.8706 - salidas_continuas_mae: 9.7527 - val_loss: 320.9559 - val_salida_clase_accuracy: 0.8752 - val_salidas_continuas_mae: 10.0729 - learning_rate: 5.0000e-04
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 259.5414 - salida_clase_accuracy: 0.8735 - salidas_continuas_mae: 9.6391 - val_loss: 330.6359 - val_salida_clase_accuracy: 0.8653 - val_salidas_continuas_mae: 10.3177 - learning_rate: 5.0000e-04
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 258.9585 - salida_clase_accuracy: 0.8620 - salidas_continuas_mae: 9.7323 - val_loss: 322.2425 - val_salida_clase_accuracy: 0.8724 - val_salidas_continuas_mae: 10.2148 - learning_rate: 5.0000e-04
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 298.8380 - salida_clase_accuracy: 0.8854 - salidas_continuas_mae: 10.0358
# Fold 4: Loss=294.67950439453125, MAE=9.841789245605469, Accuracy=0.8843398094177246
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Entrenando fold 5...
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 23347.2148 - salida_clase_accuracy: 0.2859 - salidas_continuas_mae: 94.2484 - val_loss: 6955.9663 - val_salida_clase_accuracy: 0.5371 - val_salidas_continuas_mae: 55.3836 - learning_rate: 5.0000e-04
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 5758.4590 - salida_clase_accuracy: 0.5532 - salidas_continuas_mae: 49.0896 - val_loss: 3688.0430 - val_salida_clase_accuracy: 0.5304 - val_salidas_continuas_mae: 37.2931 - learning_rate: 5.0000e-04
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3608.3757 - salida_clase_accuracy: 0.5530 - salidas_continuas_mae: 36.1080 - val_loss: 2947.0168 - val_salida_clase_accuracy: 0.6004 - val_salidas_continuas_mae: 32.4417 - learning_rate: 5.0000e-04
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2982.2915 - salida_clase_accuracy: 0.5889 - salidas_continuas_mae: 32.2038 - val_loss: 2552.0999 - val_salida_clase_accuracy: 0.5992 - val_salidas_continuas_mae: 30.4416 - learning_rate: 5.0000e-04
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2629.9973 - salida_clase_accuracy: 0.5827 - salidas_continuas_mae: 30.2282 - val_loss: 2264.5000 - val_salida_clase_accuracy: 0.6078 - val_salidas_continuas_mae: 28.3631 - learning_rate: 5.0000e-04
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2273.0488 - salida_clase_accuracy: 0.5951 - salidas_continuas_mae: 28.2135 - val_loss: 2035.3357 - val_salida_clase_accuracy: 0.6267 - val_salidas_continuas_mae: 26.8816 - learning_rate: 5.0000e-04
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 2069.3350 - salida_clase_accuracy: 0.6354 - salidas_continuas_mae: 26.7418 - val_loss: 1823.9136 - val_salida_clase_accuracy: 0.6839 - val_salidas_continuas_mae: 25.4213 - learning_rate: 5.0000e-04
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1791.5951 - salida_clase_accuracy: 0.6929 - salidas_continuas_mae: 25.2899 - val_loss: 1632.3922 - val_salida_clase_accuracy: 0.7354 - val_salidas_continuas_mae: 24.1796 - learning_rate: 5.0000e-04
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1758.1670 - salida_clase_accuracy: 0.7326 - salidas_continuas_mae: 24.4459 - val_loss: 1450.9427 - val_salida_clase_accuracy: 0.7562 - val_salidas_continuas_mae: 22.9771 - learning_rate: 5.0000e-04
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1473.4392 - salida_clase_accuracy: 0.7318 - salidas_continuas_mae: 22.7008 - val_loss: 1263.3197 - val_salida_clase_accuracy: 0.7294 - val_salidas_continuas_mae: 21.4253 - learning_rate: 5.0000e-04
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1373.2183 - salida_clase_accuracy: 0.7563 - salidas_continuas_mae: 21.4375 - val_loss: 1131.0546 - val_salida_clase_accuracy: 0.7652 - val_salidas_continuas_mae: 20.3887 - learning_rate: 5.0000e-04
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1221.0133 - salida_clase_accuracy: 0.7652 - salidas_continuas_mae: 20.2705 - val_loss: 1009.3631 - val_salida_clase_accuracy: 0.7844 - val_salidas_continuas_mae: 19.2000 - learning_rate: 5.0000e-04
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1088.9432 - salida_clase_accuracy: 0.7797 - salidas_continuas_mae: 19.3379 - val_loss: 930.0611 - val_salida_clase_accuracy: 0.7706 - val_salidas_continuas_mae: 18.6122 - learning_rate: 5.0000e-04
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 997.0386 - salida_clase_accuracy: 0.7839 - salidas_continuas_mae: 18.4672 - val_loss: 872.7580 - val_salida_clase_accuracy: 0.7706 - val_salidas_continuas_mae: 18.0222 - learning_rate: 5.0000e-04
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 931.5060 - salida_clase_accuracy: 0.7800 - salidas_continuas_mae: 17.7676 - val_loss: 807.0029 - val_salida_clase_accuracy: 0.7863 - val_salidas_continuas_mae: 17.1729 - learning_rate: 5.0000e-04
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 961.6058 - salida_clase_accuracy: 0.7811 - salidas_continuas_mae: 17.5671 - val_loss: 756.2119 - val_salida_clase_accuracy: 0.7905 - val_salidas_continuas_mae: 16.7251 - learning_rate: 5.0000e-04
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 837.5165 - salida_clase_accuracy: 0.7849 - salidas_continuas_mae: 16.7844 - val_loss: 721.0636 - val_salida_clase_accuracy: 0.7767 - val_salidas_continuas_mae: 16.1846 - learning_rate: 5.0000e-04
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 789.6385 - salida_clase_accuracy: 0.7837 - salidas_continuas_mae: 16.2983 - val_loss: 676.3466 - val_salida_clase_accuracy: 0.7793 - val_salidas_continuas_mae: 15.6987 - learning_rate: 5.0000e-04
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 746.7145 - salida_clase_accuracy: 0.7940 - salidas_continuas_mae: 15.7576 - val_loss: 651.5774 - val_salida_clase_accuracy: 0.8036 - val_salidas_continuas_mae: 15.4362 - learning_rate: 5.0000e-04
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 719.0517 - salida_clase_accuracy: 0.7877 - salidas_continuas_mae: 15.4440 - val_loss: 630.2413 - val_salida_clase_accuracy: 0.7895 - val_salidas_continuas_mae: 15.3765 - learning_rate: 5.0000e-04
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 676.2545 - salida_clase_accuracy: 0.7968 - salidas_continuas_mae: 15.0876 - val_loss: 596.7086 - val_salida_clase_accuracy: 0.8010 - val_salidas_continuas_mae: 14.7913 - learning_rate: 5.0000e-04
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 664.3224 - salida_clase_accuracy: 0.7982 - salidas_continuas_mae: 14.6295 - val_loss: 572.6849 - val_salida_clase_accuracy: 0.8081 - val_salidas_continuas_mae: 14.5277 - learning_rate: 5.0000e-04
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 585.8489 - salida_clase_accuracy: 0.8059 - salidas_continuas_mae: 14.1069 - val_loss: 545.2662 - val_salida_clase_accuracy: 0.8186 - val_salidas_continuas_mae: 14.0481 - learning_rate: 5.0000e-04
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 614.1987 - salida_clase_accuracy: 0.8053 - salidas_continuas_mae: 14.0487 - val_loss: 524.9941 - val_salida_clase_accuracy: 0.8228 - val_salidas_continuas_mae: 13.8027 - learning_rate: 5.0000e-04
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 563.8245 - salida_clase_accuracy: 0.8056 - salidas_continuas_mae: 13.7945 - val_loss: 514.4807 - val_salida_clase_accuracy: 0.8141 - val_salidas_continuas_mae: 13.6568 - learning_rate: 5.0000e-04
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 562.2104 - salida_clase_accuracy: 0.8107 - salidas_continuas_mae: 13.7177 - val_loss: 485.2018 - val_salida_clase_accuracy: 0.8039 - val_salidas_continuas_mae: 13.1732 - learning_rate: 5.0000e-04
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 513.8029 - salida_clase_accuracy: 0.8139 - salidas_continuas_mae: 13.2502 - val_loss: 482.3190 - val_salida_clase_accuracy: 0.8340 - val_salidas_continuas_mae: 13.3380 - learning_rate: 5.0000e-04
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 514.2269 - salida_clase_accuracy: 0.8199 - salidas_continuas_mae: 13.1800 - val_loss: 457.6067 - val_salida_clase_accuracy: 0.8218 - val_salidas_continuas_mae: 12.8577 - learning_rate: 5.0000e-04
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 509.2068 - salida_clase_accuracy: 0.8260 - salidas_continuas_mae: 12.9930 - val_loss: 444.0036 - val_salida_clase_accuracy: 0.8292 - val_salidas_continuas_mae: 12.6947 - learning_rate: 5.0000e-04
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 502.4937 - salida_clase_accuracy: 0.8326 - salidas_continuas_mae: 12.7807 - val_loss: 423.2083 - val_salida_clase_accuracy: 0.8196 - val_salidas_continuas_mae: 12.2981 - learning_rate: 5.0000e-04
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 476.3325 - salida_clase_accuracy: 0.8322 - salidas_continuas_mae: 12.5287 - val_loss: 418.3329 - val_salida_clase_accuracy: 0.8308 - val_salidas_continuas_mae: 12.3998 - learning_rate: 5.0000e-04
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 456.7790 - salida_clase_accuracy: 0.8427 - salidas_continuas_mae: 12.3846 - val_loss: 406.6163 - val_salida_clase_accuracy: 0.8490 - val_salidas_continuas_mae: 12.0634 - learning_rate: 5.0000e-04
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 447.8345 - salida_clase_accuracy: 0.8509 - salidas_continuas_mae: 12.1195 - val_loss: 396.0223 - val_salida_clase_accuracy: 0.8500 - val_salidas_continuas_mae: 11.9338 - learning_rate: 5.0000e-04
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 428.3164 - salida_clase_accuracy: 0.8494 - salidas_continuas_mae: 11.9266 - val_loss: 387.0787 - val_salida_clase_accuracy: 0.8557 - val_salidas_continuas_mae: 11.8164 - learning_rate: 5.0000e-04
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 405.3436 - salida_clase_accuracy: 0.8511 - salidas_continuas_mae: 11.8560 - val_loss: 379.9875 - val_salida_clase_accuracy: 0.8560 - val_salidas_continuas_mae: 11.7106 - learning_rate: 5.0000e-04
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 389.8965 - salida_clase_accuracy: 0.8614 - salidas_continuas_mae: 11.6012 - val_loss: 379.4480 - val_salida_clase_accuracy: 0.8711 - val_salidas_continuas_mae: 11.6947 - learning_rate: 5.0000e-04
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 403.1286 - salida_clase_accuracy: 0.8565 - salidas_continuas_mae: 11.4826 - val_loss: 358.5436 - val_salida_clase_accuracy: 0.8813 - val_salidas_continuas_mae: 11.3462 - learning_rate: 5.0000e-04
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 381.6369 - salida_clase_accuracy: 0.8697 - salidas_continuas_mae: 11.3049 - val_loss: 359.8553 - val_salida_clase_accuracy: 0.8589 - val_salidas_continuas_mae: 11.3707 - learning_rate: 5.0000e-04
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 382.4520 - salida_clase_accuracy: 0.8714 - salidas_continuas_mae: 11.1753 - val_loss: 343.0067 - val_salida_clase_accuracy: 0.8701 - val_salidas_continuas_mae: 11.0502 - learning_rate: 5.0000e-04
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 372.5684 - salida_clase_accuracy: 0.8689 - salidas_continuas_mae: 11.0452 - val_loss: 337.6990 - val_salida_clase_accuracy: 0.8644 - val_salidas_continuas_mae: 10.9612 - learning_rate: 5.0000e-04
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 354.4244 - salida_clase_accuracy: 0.8646 - salidas_continuas_mae: 10.8568 - val_loss: 335.6396 - val_salida_clase_accuracy: 0.8724 - val_salidas_continuas_mae: 10.8695 - learning_rate: 5.0000e-04
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 336.2409 - salida_clase_accuracy: 0.8731 - salidas_continuas_mae: 10.6801 - val_loss: 329.7099 - val_salida_clase_accuracy: 0.8772 - val_salidas_continuas_mae: 10.8701 - learning_rate: 5.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 334.3152 - salida_clase_accuracy: 0.8756 - salidas_continuas_mae: 10.6728 - val_loss: 326.6433 - val_salida_clase_accuracy: 0.8762 - val_salidas_continuas_mae: 10.8670 - learning_rate: 5.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 324.2178 - salida_clase_accuracy: 0.8769 - salidas_continuas_mae: 10.5387 - val_loss: 313.9494 - val_salida_clase_accuracy: 0.8807 - val_salidas_continuas_mae: 10.5737 - learning_rate: 5.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 338.6446 - salida_clase_accuracy: 0.8809 - salidas_continuas_mae: 10.5236 - val_loss: 314.6852 - val_salida_clase_accuracy: 0.8736 - val_salidas_continuas_mae: 10.6285 - learning_rate: 5.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 325.1587 - salida_clase_accuracy: 0.8754 - salidas_continuas_mae: 10.4852 - val_loss: 301.4090 - val_salida_clase_accuracy: 0.8794 - val_salidas_continuas_mae: 10.2609 - learning_rate: 5.0000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 310.6562 - salida_clase_accuracy: 0.8811 - salidas_continuas_mae: 10.2144 - val_loss: 297.2141 - val_salida_clase_accuracy: 0.8756 - val_salidas_continuas_mae: 10.2386 - learning_rate: 5.0000e-04
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 320.4237 - salida_clase_accuracy: 0.8806 - salidas_continuas_mae: 10.2468 - val_loss: 297.3297 - val_salida_clase_accuracy: 0.8810 - val_salidas_continuas_mae: 10.2951 - learning_rate: 5.0000e-04
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 294.8484 - salida_clase_accuracy: 0.8837 - salidas_continuas_mae: 10.0354 - val_loss: 289.6782 - val_salida_clase_accuracy: 0.8832 - val_salidas_continuas_mae: 10.1233 - learning_rate: 5.0000e-04
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 303.1152 - salida_clase_accuracy: 0.8851 - salidas_continuas_mae: 10.0370 - val_loss: 280.4784 - val_salida_clase_accuracy: 0.8778 - val_salidas_continuas_mae: 9.8902 - learning_rate: 5.0000e-04
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 310.4001 - salida_clase_accuracy: 0.8745 - salidas_continuas_mae: 10.1453
# Fold 5: Loss=303.1008605957031, MAE=9.9247407913208, Accuracy=0.8792220950126648
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 311.8525024414063
# MAE: 10.125126651415812
# MSE: 311.44466218544954
# RMSE: 17.638626695684373
# R^2: 0.9835980105404186
# Accuracy: 0.8745649933815003
# Precisión: 0.8776141836920093
# Recall: 0.8745649948822928
# F1-Score: 0.8731688835470525
