# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt

# %%
# Definir rutas
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_raiz = os.path.dirname(carpeta_mediapipe)
ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual,'datos','scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Pose', 'pose_data_images_2.csv')

# Cargar el dataset
data = pd.read_csv(ruta_csv)

# Preparar entradas (Keypoints)
num_keypoints = 17 * 3
X = data.iloc[:, :num_keypoints].values

# Las siguientes 11 columnas incluyen:
# 10 características continuas (ángulos, distancias) + 1 tipo de ejercicio (última columna)
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

# Codificar la etiqueta del tipo de ejercicio
encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_continuas_train, y_continuas_test, y_clase_train, y_clase_test = train_test_split(
    X, y_continuas, y_clase_encoded, test_size=0.2, random_state=42)

# Normalizar las entradas
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

# Listas para almacenar métricas
all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

n_epochs = 150  # Número de épocas
all_train_loss = np.full((5, n_epochs), np.nan)  
all_val_loss = np.full((5, n_epochs), np.nan)
all_train_accuracy = np.full((5, n_epochs), np.nan)
all_val_accuracy = np.full((5, n_epochs), np.nan)


# Validación cruzada
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
fold_index = 0

def create_model(learning_rate=0.001):
    input_layer = Input(shape=(X_train_scaled.shape[1],))
    x = Dense(128, activation='relu')(input_layer)
    x = Dense(64, activation='relu')(x)
    x = Dense(32, activation='relu')(x)
    salidas_continuas = Dense(6, activation='linear', name='salidas_continuas')(x)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)
    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer,
                  loss={'salidas_continuas': 'mean_squared_error', 'salida_clase': 'sparse_categorical_crossentropy'},
                  metrics={'salidas_continuas': 'mae', 'salida_clase': 'accuracy'})
    return model

for train_index, val_index in kfold.split(X_train_scaled):
    fold_index += 1
    print(f"Entrenando fold {fold_index}...")

    X_train_fold, X_val_fold = X_train_scaled[train_index], X_train_scaled[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas_train[train_index], y_continuas_train[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_train[train_index], y_clase_train[val_index]

    model = create_model(learning_rate=0.0005)  # Ajustar la tasa de aprendizaje aquí
    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold_index}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    epochs_completed = len(history.history['loss'])
    all_train_loss[fold_index - 1, :epochs_completed] = history.history['loss']
    all_val_loss[fold_index - 1, :epochs_completed] = history.history['val_loss']
    all_train_accuracy[fold_index - 1, :epochs_completed] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold_index - 1, :epochs_completed] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de prueba
    scores = model.evaluate(X_test_scaled, {'salidas_continuas': y_continuas_test, 'salida_clase': y_clase_test})
    print(f"Fold {fold_index}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_test_scaled)[0]
    mae = mean_absolute_error(y_continuas_test, y_pred_continuas)
    mse = mean_squared_error(y_continuas_test, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_test)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_test_scaled)[1], axis=1)
    precision = precision_score(y_clase_test, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_test, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_test, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_test, y_pred_clase, labels=np.unique(y_clase_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 12507.0742 - salida_clase_accuracy: 0.1734 - salidas_continuas_mae: 93.9183 - val_loss: 9187.7412 - val_salida_clase_accuracy: 0.1474 - val_salidas_continuas_mae: 78.7053 - learning_rate: 5.0000e-04
# Epoch 2/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6651.9829 - salida_clase_accuracy: 0.1661 - salidas_continuas_mae: 65.1735 - val_loss: 2787.9231 - val_salida_clase_accuracy: 0.1255 - val_salidas_continuas_mae: 43.8008 - learning_rate: 5.0000e-04
# Epoch 3/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2686.0291 - salida_clase_accuracy: 0.1311 - salidas_continuas_mae: 43.0741 - val_loss: 2530.6667 - val_salida_clase_accuracy: 0.1241 - val_salidas_continuas_mae: 41.4111 - learning_rate: 5.0000e-04
# Epoch 4/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2506.8792 - salida_clase_accuracy: 0.1244 - salidas_continuas_mae: 41.4368 - val_loss: 2408.9431 - val_salida_clase_accuracy: 0.1781 - val_salidas_continuas_mae: 40.6137 - learning_rate: 5.0000e-04
# Epoch 5/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2350.0994 - salida_clase_accuracy: 0.1934 - salidas_continuas_mae: 40.1723 - val_loss: 2298.1387 - val_salida_clase_accuracy: 0.1883 - val_salidas_continuas_mae: 39.1254 - learning_rate: 5.0000e-04
# Epoch 6/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2188.6067 - salida_clase_accuracy: 0.1890 - salidas_continuas_mae: 38.2337 - val_loss: 2144.9307 - val_salida_clase_accuracy: 0.2088 - val_salidas_continuas_mae: 37.4599 - learning_rate: 5.0000e-04
# Epoch 7/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2002.0173 - salida_clase_accuracy: 0.2212 - salidas_continuas_mae: 36.1184 - val_loss: 1961.1317 - val_salida_clase_accuracy: 0.2934 - val_salidas_continuas_mae: 35.3969 - learning_rate: 5.0000e-04
# Epoch 8/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1852.8214 - salida_clase_accuracy: 0.3103 - salidas_continuas_mae: 34.0229 - val_loss: 1802.1093 - val_salida_clase_accuracy: 0.3518 - val_salidas_continuas_mae: 33.0132 - learning_rate: 5.0000e-04
# Epoch 9/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1665.7992 - salida_clase_accuracy: 0.3805 - salidas_continuas_mae: 31.5897 - val_loss: 1679.8223 - val_salida_clase_accuracy: 0.3956 - val_salidas_continuas_mae: 31.2159 - learning_rate: 5.0000e-04
# Epoch 10/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1583.0983 - salida_clase_accuracy: 0.4368 - salidas_continuas_mae: 30.0824 - val_loss: 1577.7047 - val_salida_clase_accuracy: 0.4102 - val_salidas_continuas_mae: 30.1511 - learning_rate: 5.0000e-04
# Epoch 11/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1428.6676 - salida_clase_accuracy: 0.4595 - salidas_continuas_mae: 28.4283 - val_loss: 1510.3629 - val_salida_clase_accuracy: 0.4555 - val_salidas_continuas_mae: 28.7078 - learning_rate: 5.0000e-04
# Epoch 12/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1391.8693 - salida_clase_accuracy: 0.4870 - salidas_continuas_mae: 27.8678 - val_loss: 1420.0535 - val_salida_clase_accuracy: 0.4715 - val_salidas_continuas_mae: 27.9106 - learning_rate: 5.0000e-04
# Epoch 13/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1275.8575 - salida_clase_accuracy: 0.4988 - salidas_continuas_mae: 26.2458 - val_loss: 1364.2281 - val_salida_clase_accuracy: 0.4905 - val_salidas_continuas_mae: 27.2362 - learning_rate: 5.0000e-04
# Epoch 14/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1300.5283 - salida_clase_accuracy: 0.5097 - salidas_continuas_mae: 26.6013 - val_loss: 1318.1184 - val_salida_clase_accuracy: 0.4788 - val_salidas_continuas_mae: 26.4392 - learning_rate: 5.0000e-04
# Epoch 15/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1202.3970 - salida_clase_accuracy: 0.5101 - salidas_continuas_mae: 25.2354 - val_loss: 1274.6479 - val_salida_clase_accuracy: 0.5022 - val_salidas_continuas_mae: 25.8864 - learning_rate: 5.0000e-04
# Epoch 16/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1187.0916 - salida_clase_accuracy: 0.5270 - salidas_continuas_mae: 25.1572 - val_loss: 1236.7213 - val_salida_clase_accuracy: 0.4920 - val_salidas_continuas_mae: 25.3133 - learning_rate: 5.0000e-04
# Epoch 17/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1136.1205 - salida_clase_accuracy: 0.5261 - salidas_continuas_mae: 24.3547 - val_loss: 1199.8785 - val_salida_clase_accuracy: 0.5241 - val_salidas_continuas_mae: 24.8504 - learning_rate: 5.0000e-04
# Epoch 18/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1086.3258 - salida_clase_accuracy: 0.5543 - salidas_continuas_mae: 23.6476 - val_loss: 1167.4065 - val_salida_clase_accuracy: 0.5664 - val_salidas_continuas_mae: 24.2223 - learning_rate: 5.0000e-04
# Epoch 19/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1070.4077 - salida_clase_accuracy: 0.5801 - salidas_continuas_mae: 23.3483 - val_loss: 1137.5243 - val_salida_clase_accuracy: 0.5474 - val_salidas_continuas_mae: 23.8755 - learning_rate: 5.0000e-04
# Epoch 20/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1043.9476 - salida_clase_accuracy: 0.5642 - salidas_continuas_mae: 22.9936 - val_loss: 1112.4908 - val_salida_clase_accuracy: 0.5518 - val_salidas_continuas_mae: 23.5448 - learning_rate: 5.0000e-04
# Epoch 21/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1025.6799 - salida_clase_accuracy: 0.5576 - salidas_continuas_mae: 22.6838 - val_loss: 1083.0598 - val_salida_clase_accuracy: 0.5445 - val_salidas_continuas_mae: 23.3362 - learning_rate: 5.0000e-04
# Epoch 22/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1006.7858 - salida_clase_accuracy: 0.5651 - salidas_continuas_mae: 22.5721 - val_loss: 1068.3641 - val_salida_clase_accuracy: 0.5358 - val_salidas_continuas_mae: 22.8146 - learning_rate: 5.0000e-04
# Epoch 23/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 977.3344 - salida_clase_accuracy: 0.5696 - salidas_continuas_mae: 21.6927 - val_loss: 1046.6913 - val_salida_clase_accuracy: 0.5562 - val_salidas_continuas_mae: 22.5369 - learning_rate: 5.0000e-04
# Epoch 24/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 960.7831 - salida_clase_accuracy: 0.5675 - salidas_continuas_mae: 21.7350 - val_loss: 1030.4474 - val_salida_clase_accuracy: 0.5372 - val_salidas_continuas_mae: 22.2887 - learning_rate: 5.0000e-04
# Epoch 25/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 953.7766 - salida_clase_accuracy: 0.5614 - salidas_continuas_mae: 21.3748 - val_loss: 1005.4431 - val_salida_clase_accuracy: 0.5606 - val_salidas_continuas_mae: 22.0495 - learning_rate: 5.0000e-04
# Epoch 26/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 861.7330 - salida_clase_accuracy: 0.5757 - salidas_continuas_mae: 20.5594 - val_loss: 993.9152 - val_salida_clase_accuracy: 0.5489 - val_salidas_continuas_mae: 21.7067 - learning_rate: 5.0000e-04
# Epoch 27/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 882.5263 - salida_clase_accuracy: 0.5568 - salidas_continuas_mae: 20.8124 - val_loss: 978.6879 - val_salida_clase_accuracy: 0.5591 - val_salidas_continuas_mae: 21.4757 - learning_rate: 5.0000e-04
# Epoch 28/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 891.8375 - salida_clase_accuracy: 0.5746 - salidas_continuas_mae: 20.8229 - val_loss: 963.6421 - val_salida_clase_accuracy: 0.5723 - val_salidas_continuas_mae: 21.3955 - learning_rate: 5.0000e-04
# Epoch 29/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 854.8929 - salida_clase_accuracy: 0.5814 - salidas_continuas_mae: 20.1457 - val_loss: 949.9108 - val_salida_clase_accuracy: 0.5591 - val_salidas_continuas_mae: 21.1790 - learning_rate: 5.0000e-04
# Epoch 30/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 852.4079 - salida_clase_accuracy: 0.5787 - salidas_continuas_mae: 20.2229 - val_loss: 940.0704 - val_salida_clase_accuracy: 0.5606 - val_salidas_continuas_mae: 21.0033 - learning_rate: 5.0000e-04
# Epoch 31/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 839.4108 - salida_clase_accuracy: 0.5608 - salidas_continuas_mae: 20.1326 - val_loss: 934.6434 - val_salida_clase_accuracy: 0.5664 - val_salidas_continuas_mae: 20.8146 - learning_rate: 5.0000e-04
# Epoch 32/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 829.8008 - salida_clase_accuracy: 0.5837 - salidas_continuas_mae: 19.6717 - val_loss: 921.4664 - val_salida_clase_accuracy: 0.5679 - val_salidas_continuas_mae: 20.7755 - learning_rate: 5.0000e-04
# Epoch 33/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 844.5264 - salida_clase_accuracy: 0.5968 - salidas_continuas_mae: 19.8310 - val_loss: 907.9828 - val_salida_clase_accuracy: 0.5620 - val_salidas_continuas_mae: 20.7068 - learning_rate: 5.0000e-04
# Epoch 34/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 807.3412 - salida_clase_accuracy: 0.5868 - salidas_continuas_mae: 19.5744 - val_loss: 904.7407 - val_salida_clase_accuracy: 0.5635 - val_salidas_continuas_mae: 20.3473 - learning_rate: 5.0000e-04
# Epoch 35/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 796.7593 - salida_clase_accuracy: 0.5796 - salidas_continuas_mae: 19.2047 - val_loss: 887.2977 - val_salida_clase_accuracy: 0.5839 - val_salidas_continuas_mae: 20.3180 - learning_rate: 5.0000e-04
# Epoch 36/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 765.4443 - salida_clase_accuracy: 0.5961 - salidas_continuas_mae: 19.0409 - val_loss: 882.4286 - val_salida_clase_accuracy: 0.5679 - val_salidas_continuas_mae: 20.1975 - learning_rate: 5.0000e-04
# Epoch 37/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 791.3915 - salida_clase_accuracy: 0.6061 - salidas_continuas_mae: 19.1698 - val_loss: 885.1039 - val_salida_clase_accuracy: 0.5328 - val_salidas_continuas_mae: 19.9020 - learning_rate: 5.0000e-04
# Epoch 38/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 734.7289 - salida_clase_accuracy: 0.5761 - salidas_continuas_mae: 18.5948 - val_loss: 866.9381 - val_salida_clase_accuracy: 0.5781 - val_salidas_continuas_mae: 19.8903 - learning_rate: 5.0000e-04
# Epoch 39/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 731.2037 - salida_clase_accuracy: 0.5985 - salidas_continuas_mae: 18.4919 - val_loss: 858.3622 - val_salida_clase_accuracy: 0.5737 - val_salidas_continuas_mae: 19.6845 - learning_rate: 5.0000e-04
# Epoch 40/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 750.7868 - salida_clase_accuracy: 0.5912 - salidas_continuas_mae: 18.5226 - val_loss: 851.6035 - val_salida_clase_accuracy: 0.5839 - val_salidas_continuas_mae: 19.4309 - learning_rate: 5.0000e-04
# Epoch 41/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 743.8842 - salida_clase_accuracy: 0.6113 - salidas_continuas_mae: 18.4717 - val_loss: 842.8572 - val_salida_clase_accuracy: 0.5781 - val_salidas_continuas_mae: 19.5213 - learning_rate: 5.0000e-04
# Epoch 42/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 727.4424 - salida_clase_accuracy: 0.6082 - salidas_continuas_mae: 18.3898 - val_loss: 845.4197 - val_salida_clase_accuracy: 0.5518 - val_salidas_continuas_mae: 19.3436 - learning_rate: 5.0000e-04
# Epoch 43/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 707.5912 - salida_clase_accuracy: 0.6113 - salidas_continuas_mae: 17.9457 - val_loss: 828.1904 - val_salida_clase_accuracy: 0.5679 - val_salidas_continuas_mae: 19.3295 - learning_rate: 5.0000e-04
# Epoch 44/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 699.1029 - salida_clase_accuracy: 0.5997 - salidas_continuas_mae: 17.8972 - val_loss: 830.5378 - val_salida_clase_accuracy: 0.5927 - val_salidas_continuas_mae: 19.3172 - learning_rate: 5.0000e-04
# Epoch 45/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 677.3343 - salida_clase_accuracy: 0.6091 - salidas_continuas_mae: 17.7292 - val_loss: 809.9001 - val_salida_clase_accuracy: 0.6029 - val_salidas_continuas_mae: 19.1476 - learning_rate: 5.0000e-04
# Epoch 46/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 693.0821 - salida_clase_accuracy: 0.6294 - salidas_continuas_mae: 17.6519 - val_loss: 803.5983 - val_salida_clase_accuracy: 0.6161 - val_salidas_continuas_mae: 19.0219 - learning_rate: 5.0000e-04
# Epoch 47/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 677.4179 - salida_clase_accuracy: 0.6204 - salidas_continuas_mae: 17.5904 - val_loss: 797.8267 - val_salida_clase_accuracy: 0.6131 - val_salidas_continuas_mae: 18.9448 - learning_rate: 5.0000e-04
# Epoch 48/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 673.6216 - salida_clase_accuracy: 0.6178 - salidas_continuas_mae: 17.5898 - val_loss: 798.4600 - val_salida_clase_accuracy: 0.5810 - val_salidas_continuas_mae: 18.8837 - learning_rate: 5.0000e-04
# Epoch 49/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 660.5557 - salida_clase_accuracy: 0.5853 - salidas_continuas_mae: 17.3548 - val_loss: 796.2983 - val_salida_clase_accuracy: 0.6102 - val_salidas_continuas_mae: 18.9002 - learning_rate: 5.0000e-04
# Epoch 50/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 638.5004 - salida_clase_accuracy: 0.6343 - salidas_continuas_mae: 17.1426 - val_loss: 786.2147 - val_salida_clase_accuracy: 0.6234 - val_salidas_continuas_mae: 18.6551 - learning_rate: 5.0000e-04
# Epoch 51/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 660.2833 - salida_clase_accuracy: 0.6439 - salidas_continuas_mae: 17.2286 - val_loss: 779.2819 - val_salida_clase_accuracy: 0.6117 - val_salidas_continuas_mae: 18.6183 - learning_rate: 5.0000e-04
# Epoch 52/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 616.6389 - salida_clase_accuracy: 0.6418 - salidas_continuas_mae: 16.7115 - val_loss: 770.9857 - val_salida_clase_accuracy: 0.6277 - val_salidas_continuas_mae: 18.4110 - learning_rate: 5.0000e-04
# Epoch 53/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 614.0750 - salida_clase_accuracy: 0.6276 - salidas_continuas_mae: 16.6796 - val_loss: 775.5654 - val_salida_clase_accuracy: 0.6263 - val_salidas_continuas_mae: 18.4536 - learning_rate: 5.0000e-04
# Epoch 54/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 584.1466 - salida_clase_accuracy: 0.6502 - salidas_continuas_mae: 16.3669 - val_loss: 763.6341 - val_salida_clase_accuracy: 0.6307 - val_salidas_continuas_mae: 18.3759 - learning_rate: 5.0000e-04
# Epoch 55/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 636.1502 - salida_clase_accuracy: 0.6207 - salidas_continuas_mae: 17.0971 - val_loss: 760.9499 - val_salida_clase_accuracy: 0.6277 - val_salidas_continuas_mae: 18.2517 - learning_rate: 5.0000e-04
# Epoch 56/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 604.0553 - salida_clase_accuracy: 0.6422 - salidas_continuas_mae: 16.6046 - val_loss: 750.1070 - val_salida_clase_accuracy: 0.6409 - val_salidas_continuas_mae: 18.2986 - learning_rate: 5.0000e-04
# Epoch 57/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 592.7997 - salida_clase_accuracy: 0.6242 - salidas_continuas_mae: 16.2869 - val_loss: 752.5582 - val_salida_clase_accuracy: 0.6365 - val_salidas_continuas_mae: 18.1497 - learning_rate: 5.0000e-04
# Epoch 58/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 592.2838 - salida_clase_accuracy: 0.6340 - salidas_continuas_mae: 16.5319 - val_loss: 747.4600 - val_salida_clase_accuracy: 0.6263 - val_salidas_continuas_mae: 18.1982 - learning_rate: 5.0000e-04
# Epoch 59/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 605.3774 - salida_clase_accuracy: 0.6249 - salidas_continuas_mae: 16.6176 - val_loss: 742.5070 - val_salida_clase_accuracy: 0.6102 - val_salidas_continuas_mae: 18.0753 - learning_rate: 5.0000e-04
# Epoch 60/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 599.1070 - salida_clase_accuracy: 0.6475 - salidas_continuas_mae: 16.2279 - val_loss: 742.3541 - val_salida_clase_accuracy: 0.6350 - val_salidas_continuas_mae: 17.9400 - learning_rate: 5.0000e-04
# Epoch 61/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 577.7386 - salida_clase_accuracy: 0.6196 - salidas_continuas_mae: 16.0208 - val_loss: 738.0200 - val_salida_clase_accuracy: 0.6292 - val_salidas_continuas_mae: 17.8530 - learning_rate: 5.0000e-04
# Epoch 62/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 577.7855 - salida_clase_accuracy: 0.6319 - salidas_continuas_mae: 16.1077 - val_loss: 718.4417 - val_salida_clase_accuracy: 0.6277 - val_salidas_continuas_mae: 17.6132 - learning_rate: 5.0000e-04
# Epoch 63/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 554.9213 - salida_clase_accuracy: 0.6413 - salidas_continuas_mae: 15.8484 - val_loss: 713.2627 - val_salida_clase_accuracy: 0.6394 - val_salidas_continuas_mae: 17.5517 - learning_rate: 5.0000e-04
# Epoch 64/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 527.3478 - salida_clase_accuracy: 0.6700 - salidas_continuas_mae: 15.4636 - val_loss: 712.3160 - val_salida_clase_accuracy: 0.6292 - val_salidas_continuas_mae: 17.6445 - learning_rate: 5.0000e-04
# Epoch 65/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 520.2371 - salida_clase_accuracy: 0.6456 - salidas_continuas_mae: 15.4584 - val_loss: 708.6476 - val_salida_clase_accuracy: 0.6467 - val_salidas_continuas_mae: 17.5147 - learning_rate: 5.0000e-04
# Epoch 66/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 545.9929 - salida_clase_accuracy: 0.6482 - salidas_continuas_mae: 15.5255 - val_loss: 704.5150 - val_salida_clase_accuracy: 0.6307 - val_salidas_continuas_mae: 17.4248 - learning_rate: 5.0000e-04
# Epoch 67/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 538.1341 - salida_clase_accuracy: 0.6358 - salidas_continuas_mae: 15.4955 - val_loss: 706.5830 - val_salida_clase_accuracy: 0.6307 - val_salidas_continuas_mae: 17.2982 - learning_rate: 5.0000e-04
# Epoch 68/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 537.4877 - salida_clase_accuracy: 0.6475 - salidas_continuas_mae: 15.4388 - val_loss: 693.6829 - val_salida_clase_accuracy: 0.6482 - val_salidas_continuas_mae: 17.2175 - learning_rate: 5.0000e-04
# Epoch 69/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 557.4966 - salida_clase_accuracy: 0.6471 - salidas_continuas_mae: 15.5543 - val_loss: 694.4923 - val_salida_clase_accuracy: 0.6365 - val_salidas_continuas_mae: 17.0775 - learning_rate: 5.0000e-04
# Epoch 70/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 521.6967 - salida_clase_accuracy: 0.6466 - salidas_continuas_mae: 15.0899 - val_loss: 692.4987 - val_salida_clase_accuracy: 0.6438 - val_salidas_continuas_mae: 17.1879 - learning_rate: 5.0000e-04
# Epoch 71/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 483.2819 - salida_clase_accuracy: 0.6527 - salidas_continuas_mae: 14.6982 - val_loss: 690.4598 - val_salida_clase_accuracy: 0.6540 - val_salidas_continuas_mae: 17.0329 - learning_rate: 5.0000e-04
# Epoch 72/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 512.4970 - salida_clase_accuracy: 0.6466 - salidas_continuas_mae: 15.1587 - val_loss: 696.7754 - val_salida_clase_accuracy: 0.6365 - val_salidas_continuas_mae: 17.1476 - learning_rate: 5.0000e-04
# Epoch 73/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 496.3563 - salida_clase_accuracy: 0.6549 - salidas_continuas_mae: 14.9459 - val_loss: 685.1876 - val_salida_clase_accuracy: 0.6321 - val_salidas_continuas_mae: 17.0699 - learning_rate: 5.0000e-04
# Epoch 74/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 514.3210 - salida_clase_accuracy: 0.6332 - salidas_continuas_mae: 15.0643 - val_loss: 674.7687 - val_salida_clase_accuracy: 0.6423 - val_salidas_continuas_mae: 16.7916 - learning_rate: 5.0000e-04
# Epoch 75/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 506.5619 - salida_clase_accuracy: 0.6586 - salidas_continuas_mae: 14.8937 - val_loss: 671.3777 - val_salida_clase_accuracy: 0.6453 - val_salidas_continuas_mae: 16.8307 - learning_rate: 5.0000e-04
# Epoch 76/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 488.7091 - salida_clase_accuracy: 0.6522 - salidas_continuas_mae: 14.4746 - val_loss: 673.5259 - val_salida_clase_accuracy: 0.6365 - val_salidas_continuas_mae: 16.7349 - learning_rate: 5.0000e-04
# Epoch 77/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 484.9431 - salida_clase_accuracy: 0.6764 - salidas_continuas_mae: 14.4661 - val_loss: 664.6240 - val_salida_clase_accuracy: 0.6467 - val_salidas_continuas_mae: 16.7866 - learning_rate: 5.0000e-04
# Epoch 78/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 484.1383 - salida_clase_accuracy: 0.6536 - salidas_continuas_mae: 14.6450 - val_loss: 673.4477 - val_salida_clase_accuracy: 0.6423 - val_salidas_continuas_mae: 16.8139 - learning_rate: 5.0000e-04
# Epoch 79/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 464.5386 - salida_clase_accuracy: 0.6659 - salidas_continuas_mae: 14.3339 - val_loss: 657.1992 - val_salida_clase_accuracy: 0.6307 - val_salidas_continuas_mae: 16.5660 - learning_rate: 5.0000e-04
# Epoch 80/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 492.3943 - salida_clase_accuracy: 0.6624 - salidas_continuas_mae: 14.5978 - val_loss: 669.0908 - val_salida_clase_accuracy: 0.6555 - val_salidas_continuas_mae: 16.7615 - learning_rate: 5.0000e-04
# Epoch 81/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 488.3684 - salida_clase_accuracy: 0.6668 - salidas_continuas_mae: 14.4361 - val_loss: 648.1086 - val_salida_clase_accuracy: 0.6511 - val_salidas_continuas_mae: 16.3398 - learning_rate: 5.0000e-04
# Epoch 82/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 462.3351 - salida_clase_accuracy: 0.6325 - salidas_continuas_mae: 14.2906 - val_loss: 658.6998 - val_salida_clase_accuracy: 0.6277 - val_salidas_continuas_mae: 16.4792 - learning_rate: 5.0000e-04
# Epoch 83/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 457.4621 - salida_clase_accuracy: 0.6641 - salidas_continuas_mae: 14.0209 - val_loss: 647.4449 - val_salida_clase_accuracy: 0.6409 - val_salidas_continuas_mae: 16.2920 - learning_rate: 5.0000e-04
# Epoch 84/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 426.4580 - salida_clase_accuracy: 0.6686 - salidas_continuas_mae: 13.8222 - val_loss: 647.6698 - val_salida_clase_accuracy: 0.6365 - val_salidas_continuas_mae: 16.3548 - learning_rate: 5.0000e-04
# Epoch 85/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 449.2096 - salida_clase_accuracy: 0.6798 - salidas_continuas_mae: 14.0922 - val_loss: 644.0284 - val_salida_clase_accuracy: 0.6467 - val_salidas_continuas_mae: 16.1255 - learning_rate: 5.0000e-04
# Epoch 86/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 440.3125 - salida_clase_accuracy: 0.6398 - salidas_continuas_mae: 14.0058 - val_loss: 639.6150 - val_salida_clase_accuracy: 0.6453 - val_salidas_continuas_mae: 16.2549 - learning_rate: 5.0000e-04
# Epoch 87/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 466.7696 - salida_clase_accuracy: 0.6566 - salidas_continuas_mae: 14.2971 - val_loss: 638.3369 - val_salida_clase_accuracy: 0.6584 - val_salidas_continuas_mae: 16.2203 - learning_rate: 5.0000e-04
# Epoch 88/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 441.1904 - salida_clase_accuracy: 0.6525 - salidas_continuas_mae: 13.9863 - val_loss: 636.1314 - val_salida_clase_accuracy: 0.6496 - val_salidas_continuas_mae: 16.0496 - learning_rate: 5.0000e-04
# Epoch 89/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 436.1063 - salida_clase_accuracy: 0.6614 - salidas_continuas_mae: 13.5949 - val_loss: 631.6507 - val_salida_clase_accuracy: 0.6380 - val_salidas_continuas_mae: 16.1355 - learning_rate: 5.0000e-04
# Epoch 90/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 451.0302 - salida_clase_accuracy: 0.6647 - salidas_continuas_mae: 13.9855 - val_loss: 638.5847 - val_salida_clase_accuracy: 0.6569 - val_salidas_continuas_mae: 15.9827 - learning_rate: 5.0000e-04
# Epoch 91/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 425.3701 - salida_clase_accuracy: 0.6648 - salidas_continuas_mae: 13.4904 - val_loss: 632.8295 - val_salida_clase_accuracy: 0.6496 - val_salidas_continuas_mae: 16.0351 - learning_rate: 5.0000e-04
# Epoch 92/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 429.6313 - salida_clase_accuracy: 0.6843 - salidas_continuas_mae: 13.6287 - val_loss: 620.1218 - val_salida_clase_accuracy: 0.6438 - val_salidas_continuas_mae: 15.8824 - learning_rate: 5.0000e-04
# Epoch 93/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 430.8471 - salida_clase_accuracy: 0.6555 - salidas_continuas_mae: 13.5126 - val_loss: 625.3801 - val_salida_clase_accuracy: 0.6555 - val_salidas_continuas_mae: 15.8953 - learning_rate: 5.0000e-04
# Epoch 94/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 448.9419 - salida_clase_accuracy: 0.6556 - salidas_continuas_mae: 13.8659 - val_loss: 621.0342 - val_salida_clase_accuracy: 0.6555 - val_salidas_continuas_mae: 15.8748 - learning_rate: 5.0000e-04
# Epoch 95/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 422.4935 - salida_clase_accuracy: 0.6544 - salidas_continuas_mae: 13.4616 - val_loss: 617.8578 - val_salida_clase_accuracy: 0.6599 - val_salidas_continuas_mae: 15.8085 - learning_rate: 5.0000e-04
# Epoch 96/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 389.6285 - salida_clase_accuracy: 0.6405 - salidas_continuas_mae: 13.0379 - val_loss: 617.7960 - val_salida_clase_accuracy: 0.6555 - val_salidas_continuas_mae: 15.8173 - learning_rate: 5.0000e-04
# Epoch 97/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 384.4057 - salida_clase_accuracy: 0.6525 - salidas_continuas_mae: 12.8522 - val_loss: 614.0973 - val_salida_clase_accuracy: 0.6496 - val_salidas_continuas_mae: 15.8374 - learning_rate: 5.0000e-04
# Epoch 98/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 381.9015 - salida_clase_accuracy: 0.6433 - salidas_continuas_mae: 12.9106 - val_loss: 617.9015 - val_salida_clase_accuracy: 0.6628 - val_salidas_continuas_mae: 15.8367 - learning_rate: 5.0000e-04
# Epoch 99/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 409.2248 - salida_clase_accuracy: 0.6698 - salidas_continuas_mae: 13.3227 - val_loss: 620.5955 - val_salida_clase_accuracy: 0.6599 - val_salidas_continuas_mae: 15.6822 - learning_rate: 5.0000e-04
# Epoch 100/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 405.1133 - salida_clase_accuracy: 0.6661 - salidas_continuas_mae: 13.0203 - val_loss: 613.5712 - val_salida_clase_accuracy: 0.6526 - val_salidas_continuas_mae: 15.5133 - learning_rate: 5.0000e-04
# Epoch 101/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 396.4932 - salida_clase_accuracy: 0.6550 - salidas_continuas_mae: 12.9920 - val_loss: 613.9092 - val_salida_clase_accuracy: 0.6599 - val_salidas_continuas_mae: 15.5177 - learning_rate: 5.0000e-04
# Epoch 102/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 396.0514 - salida_clase_accuracy: 0.6667 - salidas_continuas_mae: 12.9672 - val_loss: 622.1775 - val_salida_clase_accuracy: 0.6686 - val_salidas_continuas_mae: 15.4567 - learning_rate: 5.0000e-04
# Epoch 103/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 402.4344 - salida_clase_accuracy: 0.6291 - salidas_continuas_mae: 12.9180 - val_loss: 605.6218 - val_salida_clase_accuracy: 0.6380 - val_salidas_continuas_mae: 15.6206 - learning_rate: 5.0000e-04
# Epoch 104/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 398.7872 - salida_clase_accuracy: 0.6662 - salidas_continuas_mae: 13.1164 - val_loss: 606.5572 - val_salida_clase_accuracy: 0.6467 - val_salidas_continuas_mae: 15.4159 - learning_rate: 5.0000e-04
# Epoch 105/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 387.8105 - salida_clase_accuracy: 0.6540 - salidas_continuas_mae: 12.8364 - val_loss: 602.7312 - val_salida_clase_accuracy: 0.6555 - val_salidas_continuas_mae: 15.3608 - learning_rate: 5.0000e-04
# Epoch 106/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 389.3409 - salida_clase_accuracy: 0.6433 - salidas_continuas_mae: 12.8797 - val_loss: 594.6359 - val_salida_clase_accuracy: 0.6642 - val_salidas_continuas_mae: 15.3713 - learning_rate: 5.0000e-04
# Epoch 107/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 386.8013 - salida_clase_accuracy: 0.6667 - salidas_continuas_mae: 12.9177 - val_loss: 595.2217 - val_salida_clase_accuracy: 0.6672 - val_salidas_continuas_mae: 15.4068 - learning_rate: 5.0000e-04
# Epoch 108/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 381.4753 - salida_clase_accuracy: 0.6467 - salidas_continuas_mae: 12.6495 - val_loss: 590.4471 - val_salida_clase_accuracy: 0.6555 - val_salidas_continuas_mae: 15.1829 - learning_rate: 5.0000e-04
# Epoch 109/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 391.9265 - salida_clase_accuracy: 0.6625 - salidas_continuas_mae: 12.7937 - val_loss: 599.6052 - val_salida_clase_accuracy: 0.6438 - val_salidas_continuas_mae: 15.2184 - learning_rate: 5.0000e-04
# Epoch 110/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 369.6229 - salida_clase_accuracy: 0.6522 - salidas_continuas_mae: 12.4896 - val_loss: 590.3150 - val_salida_clase_accuracy: 0.6599 - val_salidas_continuas_mae: 15.1259 - learning_rate: 5.0000e-04
# Epoch 111/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 373.9168 - salida_clase_accuracy: 0.6638 - salidas_continuas_mae: 12.6449 - val_loss: 595.2582 - val_salida_clase_accuracy: 0.6584 - val_salidas_continuas_mae: 15.3571 - learning_rate: 5.0000e-04
# Epoch 112/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 377.3782 - salida_clase_accuracy: 0.6844 - salidas_continuas_mae: 12.4966 - val_loss: 588.6744 - val_salida_clase_accuracy: 0.6599 - val_salidas_continuas_mae: 15.1421 - learning_rate: 5.0000e-04
# Epoch 113/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 373.8071 - salida_clase_accuracy: 0.6496 - salidas_continuas_mae: 12.7379 - val_loss: 598.0063 - val_salida_clase_accuracy: 0.6628 - val_salidas_continuas_mae: 15.2641 - learning_rate: 5.0000e-04
# Epoch 114/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 341.7968 - salida_clase_accuracy: 0.6702 - salidas_continuas_mae: 12.2853 - val_loss: 590.8249 - val_salida_clase_accuracy: 0.6599 - val_salidas_continuas_mae: 15.2176 - learning_rate: 5.0000e-04
# Epoch 115/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 369.1731 - salida_clase_accuracy: 0.6577 - salidas_continuas_mae: 12.4971 - val_loss: 585.5096 - val_salida_clase_accuracy: 0.6642 - val_salidas_continuas_mae: 15.0911 - learning_rate: 5.0000e-04
# Epoch 116/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 343.6899 - salida_clase_accuracy: 0.6433 - salidas_continuas_mae: 12.1011 - val_loss: 584.5024 - val_salida_clase_accuracy: 0.6555 - val_salidas_continuas_mae: 14.9971 - learning_rate: 5.0000e-04
# Epoch 117/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 354.5707 - salida_clase_accuracy: 0.6700 - salidas_continuas_mae: 12.3522 - val_loss: 585.9468 - val_salida_clase_accuracy: 0.6569 - val_salidas_continuas_mae: 14.9946 - learning_rate: 5.0000e-04
# Epoch 118/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 377.9918 - salida_clase_accuracy: 0.6706 - salidas_continuas_mae: 12.5991 - val_loss: 582.5036 - val_salida_clase_accuracy: 0.6613 - val_salidas_continuas_mae: 15.0333 - learning_rate: 5.0000e-04
# Epoch 119/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 350.9164 - salida_clase_accuracy: 0.6789 - salidas_continuas_mae: 12.2187 - val_loss: 580.1663 - val_salida_clase_accuracy: 0.6453 - val_salidas_continuas_mae: 15.1445 - learning_rate: 5.0000e-04
# Epoch 120/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 328.0560 - salida_clase_accuracy: 0.6659 - salidas_continuas_mae: 11.8515 - val_loss: 587.0164 - val_salida_clase_accuracy: 0.6321 - val_salidas_continuas_mae: 14.9516 - learning_rate: 5.0000e-04
# Epoch 121/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 326.2426 - salida_clase_accuracy: 0.6830 - salidas_continuas_mae: 11.8320 - val_loss: 583.4193 - val_salida_clase_accuracy: 0.6657 - val_salidas_continuas_mae: 15.1216 - learning_rate: 5.0000e-04
# Epoch 122/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 348.3307 - salida_clase_accuracy: 0.6662 - salidas_continuas_mae: 12.1820 - val_loss: 570.4930 - val_salida_clase_accuracy: 0.6599 - val_salidas_continuas_mae: 14.9120 - learning_rate: 5.0000e-04
# Epoch 123/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 358.1318 - salida_clase_accuracy: 0.6573 - salidas_continuas_mae: 12.3012 - val_loss: 583.5958 - val_salida_clase_accuracy: 0.6672 - val_salidas_continuas_mae: 15.1344 - learning_rate: 5.0000e-04
# Epoch 124/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 331.8897 - salida_clase_accuracy: 0.6654 - salidas_continuas_mae: 11.9769 - val_loss: 575.2293 - val_salida_clase_accuracy: 0.6569 - val_salidas_continuas_mae: 15.0093 - learning_rate: 5.0000e-04
# Epoch 125/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 330.4588 - salida_clase_accuracy: 0.6565 - salidas_continuas_mae: 11.8082 - val_loss: 571.6385 - val_salida_clase_accuracy: 0.6584 - val_salidas_continuas_mae: 14.8660 - learning_rate: 5.0000e-04
# Epoch 126/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 343.2617 - salida_clase_accuracy: 0.6486 - salidas_continuas_mae: 12.0204 - val_loss: 572.5271 - val_salida_clase_accuracy: 0.6642 - val_salidas_continuas_mae: 14.7097 - learning_rate: 5.0000e-04
# Epoch 127/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 332.4771 - salida_clase_accuracy: 0.6584 - salidas_continuas_mae: 11.7942 - val_loss: 565.5941 - val_salida_clase_accuracy: 0.6526 - val_salidas_continuas_mae: 14.8210 - learning_rate: 5.0000e-04
# Epoch 128/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 347.1601 - salida_clase_accuracy: 0.6684 - salidas_continuas_mae: 12.1087 - val_loss: 564.4916 - val_salida_clase_accuracy: 0.6526 - val_salidas_continuas_mae: 14.6768 - learning_rate: 5.0000e-04
# Epoch 129/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 325.8994 - salida_clase_accuracy: 0.6663 - salidas_continuas_mae: 11.7645 - val_loss: 568.0195 - val_salida_clase_accuracy: 0.6686 - val_salidas_continuas_mae: 14.8050 - learning_rate: 5.0000e-04
# Epoch 130/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 333.3509 - salida_clase_accuracy: 0.6674 - salidas_continuas_mae: 11.9473 - val_loss: 569.0033 - val_salida_clase_accuracy: 0.6496 - val_salidas_continuas_mae: 14.8204 - learning_rate: 5.0000e-04
# Epoch 131/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 337.4493 - salida_clase_accuracy: 0.6697 - salidas_continuas_mae: 11.8001 - val_loss: 571.7469 - val_salida_clase_accuracy: 0.6613 - val_salidas_continuas_mae: 14.7676 - learning_rate: 5.0000e-04
# Epoch 132/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 304.2341 - salida_clase_accuracy: 0.6493 - salidas_continuas_mae: 11.4759 - val_loss: 573.8284 - val_salida_clase_accuracy: 0.6555 - val_salidas_continuas_mae: 14.9085 - learning_rate: 5.0000e-04
# Epoch 133/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 330.5118 - salida_clase_accuracy: 0.6667 - salidas_continuas_mae: 11.7005 - val_loss: 571.4815 - val_salida_clase_accuracy: 0.6496 - val_salidas_continuas_mae: 14.7231 - learning_rate: 5.0000e-04
# Epoch 134/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 311.7423 - salida_clase_accuracy: 0.6708 - salidas_continuas_mae: 11.3767 - val_loss: 561.9388 - val_salida_clase_accuracy: 0.6613 - val_salidas_continuas_mae: 14.5656 - learning_rate: 2.5000e-04
# Epoch 135/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 313.2515 - salida_clase_accuracy: 0.6878 - salidas_continuas_mae: 11.3924 - val_loss: 557.0511 - val_salida_clase_accuracy: 0.6540 - val_salidas_continuas_mae: 14.5344 - learning_rate: 2.5000e-04
# Epoch 136/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 302.9999 - salida_clase_accuracy: 0.6791 - salidas_continuas_mae: 11.3615 - val_loss: 557.1928 - val_salida_clase_accuracy: 0.6555 - val_salidas_continuas_mae: 14.4831 - learning_rate: 2.5000e-04
# Epoch 137/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 294.8320 - salida_clase_accuracy: 0.6711 - salidas_continuas_mae: 11.2037 - val_loss: 559.7402 - val_salida_clase_accuracy: 0.6599 - val_salidas_continuas_mae: 14.5653 - learning_rate: 2.5000e-04
# Epoch 138/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 318.7887 - salida_clase_accuracy: 0.6614 - salidas_continuas_mae: 11.4742 - val_loss: 553.8981 - val_salida_clase_accuracy: 0.6555 - val_salidas_continuas_mae: 14.4347 - learning_rate: 2.5000e-04
# Epoch 139/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 310.1932 - salida_clase_accuracy: 0.6523 - salidas_continuas_mae: 11.4421 - val_loss: 561.3699 - val_salida_clase_accuracy: 0.6540 - val_salidas_continuas_mae: 14.5175 - learning_rate: 2.5000e-04
# Epoch 140/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 290.7669 - salida_clase_accuracy: 0.6669 - salidas_continuas_mae: 11.1451 - val_loss: 556.8571 - val_salida_clase_accuracy: 0.6715 - val_salidas_continuas_mae: 14.5402 - learning_rate: 2.5000e-04
# Epoch 141/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 311.4294 - salida_clase_accuracy: 0.6572 - salidas_continuas_mae: 11.4583 - val_loss: 558.6632 - val_salida_clase_accuracy: 0.6569 - val_salidas_continuas_mae: 14.6083 - learning_rate: 2.5000e-04
# Epoch 142/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 298.3415 - salida_clase_accuracy: 0.6548 - salidas_continuas_mae: 11.2550 - val_loss: 556.3489 - val_salida_clase_accuracy: 0.6569 - val_salidas_continuas_mae: 14.5494 - learning_rate: 2.5000e-04
# Epoch 143/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 305.7205 - salida_clase_accuracy: 0.6703 - salidas_continuas_mae: 11.4663 - val_loss: 558.3601 - val_salida_clase_accuracy: 0.6613 - val_salidas_continuas_mae: 14.5627 - learning_rate: 2.5000e-04
# Epoch 144/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 316.4530 - salida_clase_accuracy: 0.6627 - salidas_continuas_mae: 11.4007 - val_loss: 557.3828 - val_salida_clase_accuracy: 0.6599 - val_salidas_continuas_mae: 14.4578 - learning_rate: 1.2500e-04
# Epoch 145/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 318.4310 - salida_clase_accuracy: 0.6702 - salidas_continuas_mae: 11.4216 - val_loss: 558.1664 - val_salida_clase_accuracy: 0.6686 - val_salidas_continuas_mae: 14.4917 - learning_rate: 1.2500e-04
# Epoch 146/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 305.4962 - salida_clase_accuracy: 0.6521 - salidas_continuas_mae: 11.4083 - val_loss: 553.9387 - val_salida_clase_accuracy: 0.6672 - val_salidas_continuas_mae: 14.4234 - learning_rate: 1.2500e-04
# Epoch 147/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 281.3835 - salida_clase_accuracy: 0.6639 - salidas_continuas_mae: 10.8200 - val_loss: 555.8412 - val_salida_clase_accuracy: 0.6657 - val_salidas_continuas_mae: 14.4471 - learning_rate: 1.2500e-04
# Epoch 148/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 298.7981 - salida_clase_accuracy: 0.6570 - salidas_continuas_mae: 11.0969 - val_loss: 558.0160 - val_salida_clase_accuracy: 0.6628 - val_salidas_continuas_mae: 14.4445 - learning_rate: 1.2500e-04
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 471.0238 - salida_clase_accuracy: 0.6566 - salidas_continuas_mae: 13.2455
# Fold 1: Loss=485.2188720703125, MAE=13.550692558288574, Accuracy=0.6518691778182983
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Entrenando fold 2...
# Epoch 1/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 12698.1318 - salida_clase_accuracy: 0.1885 - salidas_continuas_mae: 95.0899 - val_loss: 9359.2490 - val_salida_clase_accuracy: 0.1416 - val_salidas_continuas_mae: 78.4177 - learning_rate: 5.0000e-04
# Epoch 2/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6362.5195 - salida_clase_accuracy: 0.1764 - salidas_continuas_mae: 63.1694 - val_loss: 2810.5566 - val_salida_clase_accuracy: 0.1372 - val_salidas_continuas_mae: 44.1702 - learning_rate: 5.0000e-04
# Epoch 3/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2667.6895 - salida_clase_accuracy: 0.2028 - salidas_continuas_mae: 42.6328 - val_loss: 2488.3455 - val_salida_clase_accuracy: 0.1810 - val_salidas_continuas_mae: 41.5263 - learning_rate: 5.0000e-04
# Epoch 4/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2463.6687 - salida_clase_accuracy: 0.1889 - salidas_continuas_mae: 41.1168 - val_loss: 2345.9106 - val_salida_clase_accuracy: 0.1825 - val_salidas_continuas_mae: 39.6197 - learning_rate: 5.0000e-04
# Epoch 5/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2310.8645 - salida_clase_accuracy: 0.2190 - salidas_continuas_mae: 39.4085 - val_loss: 2225.8462 - val_salida_clase_accuracy: 0.2161 - val_salidas_continuas_mae: 38.6110 - learning_rate: 5.0000e-04
# Epoch 6/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2171.5188 - salida_clase_accuracy: 0.2644 - salidas_continuas_mae: 37.8145 - val_loss: 2104.8821 - val_salida_clase_accuracy: 0.2467 - val_salidas_continuas_mae: 36.8928 - learning_rate: 5.0000e-04
# Epoch 7/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2032.5197 - salida_clase_accuracy: 0.2643 - salidas_continuas_mae: 36.2550 - val_loss: 2008.1899 - val_salida_clase_accuracy: 0.2540 - val_salidas_continuas_mae: 35.5505 - learning_rate: 5.0000e-04
# Epoch 8/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1928.4333 - salida_clase_accuracy: 0.3056 - salidas_continuas_mae: 35.0016 - val_loss: 1881.3835 - val_salida_clase_accuracy: 0.3387 - val_salidas_continuas_mae: 34.4509 - learning_rate: 5.0000e-04
# Epoch 9/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1886.3948 - salida_clase_accuracy: 0.2942 - salidas_continuas_mae: 34.3330 - val_loss: 1786.0453 - val_salida_clase_accuracy: 0.2949 - val_salidas_continuas_mae: 33.0298 - learning_rate: 5.0000e-04
# Epoch 10/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1743.1930 - salida_clase_accuracy: 0.3052 - salidas_continuas_mae: 32.6662 - val_loss: 1673.3721 - val_salida_clase_accuracy: 0.3255 - val_salidas_continuas_mae: 31.8776 - learning_rate: 5.0000e-04
# Epoch 11/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1643.2467 - salida_clase_accuracy: 0.3151 - salidas_continuas_mae: 31.4832 - val_loss: 1559.1970 - val_salida_clase_accuracy: 0.3650 - val_salidas_continuas_mae: 29.8644 - learning_rate: 5.0000e-04
# Epoch 12/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1529.3463 - salida_clase_accuracy: 0.3453 - salidas_continuas_mae: 29.8070 - val_loss: 1455.2661 - val_salida_clase_accuracy: 0.4219 - val_salidas_continuas_mae: 28.6817 - learning_rate: 5.0000e-04
# Epoch 13/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1448.1859 - salida_clase_accuracy: 0.4166 - salidas_continuas_mae: 28.6976 - val_loss: 1379.1830 - val_salida_clase_accuracy: 0.4584 - val_salidas_continuas_mae: 27.4463 - learning_rate: 5.0000e-04
# Epoch 14/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1332.1758 - salida_clase_accuracy: 0.4857 - salidas_continuas_mae: 26.9318 - val_loss: 1326.7068 - val_salida_clase_accuracy: 0.5139 - val_salidas_continuas_mae: 26.8797 - learning_rate: 5.0000e-04
# Epoch 15/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1304.0710 - salida_clase_accuracy: 0.5015 - salidas_continuas_mae: 26.5915 - val_loss: 1263.0245 - val_salida_clase_accuracy: 0.5270 - val_salidas_continuas_mae: 25.9507 - learning_rate: 5.0000e-04
# Epoch 16/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1255.2455 - salida_clase_accuracy: 0.5131 - salidas_continuas_mae: 25.8966 - val_loss: 1216.6456 - val_salida_clase_accuracy: 0.5416 - val_salidas_continuas_mae: 25.3265 - learning_rate: 5.0000e-04
# Epoch 17/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1217.9236 - salida_clase_accuracy: 0.5248 - salidas_continuas_mae: 25.5462 - val_loss: 1178.0402 - val_salida_clase_accuracy: 0.5445 - val_salidas_continuas_mae: 24.4896 - learning_rate: 5.0000e-04
# Epoch 18/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1128.7582 - salida_clase_accuracy: 0.5021 - salidas_continuas_mae: 24.1242 - val_loss: 1141.2411 - val_salida_clase_accuracy: 0.5095 - val_salidas_continuas_mae: 24.2705 - learning_rate: 5.0000e-04
# Epoch 19/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1118.2449 - salida_clase_accuracy: 0.5145 - salidas_continuas_mae: 24.1495 - val_loss: 1117.7690 - val_salida_clase_accuracy: 0.5139 - val_salidas_continuas_mae: 23.8566 - learning_rate: 5.0000e-04
# Epoch 20/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1069.4655 - salida_clase_accuracy: 0.5407 - salidas_continuas_mae: 23.4797 - val_loss: 1091.9006 - val_salida_clase_accuracy: 0.5197 - val_salidas_continuas_mae: 23.3968 - learning_rate: 5.0000e-04
# Epoch 21/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1051.6318 - salida_clase_accuracy: 0.5115 - salidas_continuas_mae: 23.2643 - val_loss: 1069.6665 - val_salida_clase_accuracy: 0.5489 - val_salidas_continuas_mae: 22.9437 - learning_rate: 5.0000e-04
# Epoch 22/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1031.3507 - salida_clase_accuracy: 0.5374 - salidas_continuas_mae: 22.7815 - val_loss: 1056.7874 - val_salida_clase_accuracy: 0.5285 - val_salidas_continuas_mae: 22.6950 - learning_rate: 5.0000e-04
# Epoch 23/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1016.3831 - salida_clase_accuracy: 0.5283 - salidas_continuas_mae: 22.3603 - val_loss: 1030.1050 - val_salida_clase_accuracy: 0.5212 - val_salidas_continuas_mae: 22.2656 - learning_rate: 5.0000e-04
# Epoch 24/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 977.4792 - salida_clase_accuracy: 0.5383 - salidas_continuas_mae: 21.8465 - val_loss: 1017.9835 - val_salida_clase_accuracy: 0.5518 - val_salidas_continuas_mae: 22.2005 - learning_rate: 5.0000e-04
# Epoch 25/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 976.1734 - salida_clase_accuracy: 0.5319 - salidas_continuas_mae: 22.0608 - val_loss: 996.8295 - val_salida_clase_accuracy: 0.5416 - val_salidas_continuas_mae: 21.7790 - learning_rate: 5.0000e-04
# Epoch 26/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 941.1256 - salida_clase_accuracy: 0.5506 - salidas_continuas_mae: 21.4757 - val_loss: 979.6259 - val_salida_clase_accuracy: 0.5431 - val_salidas_continuas_mae: 21.4340 - learning_rate: 5.0000e-04
# Epoch 27/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 899.2829 - salida_clase_accuracy: 0.5382 - salidas_continuas_mae: 20.7793 - val_loss: 971.2307 - val_salida_clase_accuracy: 0.5255 - val_salidas_continuas_mae: 21.3244 - learning_rate: 5.0000e-04
# Epoch 28/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 895.6113 - salida_clase_accuracy: 0.5487 - salidas_continuas_mae: 20.8052 - val_loss: 955.4233 - val_salida_clase_accuracy: 0.5328 - val_salidas_continuas_mae: 21.1839 - learning_rate: 5.0000e-04
# Epoch 29/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 875.3508 - salida_clase_accuracy: 0.5478 - salidas_continuas_mae: 20.5888 - val_loss: 942.7028 - val_salida_clase_accuracy: 0.5299 - val_salidas_continuas_mae: 20.9223 - learning_rate: 5.0000e-04
# Epoch 30/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 854.3611 - salida_clase_accuracy: 0.5415 - salidas_continuas_mae: 20.3682 - val_loss: 932.4700 - val_salida_clase_accuracy: 0.5343 - val_salidas_continuas_mae: 20.8443 - learning_rate: 5.0000e-04
# Epoch 31/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 823.6430 - salida_clase_accuracy: 0.5491 - salidas_continuas_mae: 19.9749 - val_loss: 923.8269 - val_salida_clase_accuracy: 0.5606 - val_salidas_continuas_mae: 20.8701 - learning_rate: 5.0000e-04
# Epoch 32/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 810.7376 - salida_clase_accuracy: 0.5437 - salidas_continuas_mae: 19.8171 - val_loss: 903.3311 - val_salida_clase_accuracy: 0.5577 - val_salidas_continuas_mae: 20.4346 - learning_rate: 5.0000e-04
# Epoch 33/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 876.0807 - salida_clase_accuracy: 0.5595 - salidas_continuas_mae: 20.3532 - val_loss: 898.3285 - val_salida_clase_accuracy: 0.5679 - val_salidas_continuas_mae: 20.3936 - learning_rate: 5.0000e-04
# Epoch 34/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 851.1768 - salida_clase_accuracy: 0.5650 - salidas_continuas_mae: 19.9265 - val_loss: 889.5330 - val_salida_clase_accuracy: 0.5825 - val_salidas_continuas_mae: 20.1864 - learning_rate: 5.0000e-04
# Epoch 35/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 819.7982 - salida_clase_accuracy: 0.5745 - salidas_continuas_mae: 19.6059 - val_loss: 878.0185 - val_salida_clase_accuracy: 0.5693 - val_salidas_continuas_mae: 20.0493 - learning_rate: 5.0000e-04
# Epoch 36/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 836.4951 - salida_clase_accuracy: 0.5674 - salidas_continuas_mae: 19.8740 - val_loss: 876.4594 - val_salida_clase_accuracy: 0.5693 - val_salidas_continuas_mae: 20.0155 - learning_rate: 5.0000e-04
# Epoch 37/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 818.0008 - salida_clase_accuracy: 0.5546 - salidas_continuas_mae: 19.6150 - val_loss: 861.0339 - val_salida_clase_accuracy: 0.5942 - val_salidas_continuas_mae: 19.7348 - learning_rate: 5.0000e-04
# Epoch 38/150
# ...
# Epoch 89/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 460.4328 - salida_clase_accuracy: 0.6829 - salidas_continuas_mae: 14.0304 - val_loss: 639.6343 - val_salida_clase_accuracy: 0.6711 - val_salidas_continuas_mae: 16.0227 - learning_rate: 5.0000e-04
# Epoch 90/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 451.8985 - salida_clase_accuracy: 0.6812 - salidas_continuas_mae: 13.7454 - val_loss: 648.4592 - val_salida_clase_accuracy: 0.6579 - val_salidas_continuas_mae: 16.1181 - learning_rate: 5.0000e-04
# Epoch 91/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 447.4607 - salida_clase_accuracy: 0.6772 - salidas_continuas_mae: 13.6711 - val_loss: 660.9440 - val_salida_clase_accuracy: 0.6564 - val_salidas_continuas_mae: 16.1627 - learning_rate: 5.0000e-04
# Epoch 92/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 448.4666 - salida_clase_accuracy: 0.6665 - salidas_continuas_mae: 13.7886 - val_loss: 662.6705 - val_salida_clase_accuracy: 0.6711 - val_salidas_continuas_mae: 16.1131 - learning_rate: 5.0000e-04
# Epoch 93/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 438.6231 - salida_clase_accuracy: 0.6901 - salidas_continuas_mae: 13.6479 - val_loss: 647.2018 - val_salida_clase_accuracy: 0.6667 - val_salidas_continuas_mae: 16.0662 - learning_rate: 5.0000e-04
# Epoch 94/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 441.1711 - salida_clase_accuracy: 0.6845 - salidas_continuas_mae: 13.6081 - val_loss: 638.9018 - val_salida_clase_accuracy: 0.6535 - val_salidas_continuas_mae: 15.9590 - learning_rate: 5.0000e-04
# Epoch 95/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 424.2700 - salida_clase_accuracy: 0.6899 - salidas_continuas_mae: 13.3561 - val_loss: 639.1765 - val_salida_clase_accuracy: 0.6579 - val_salidas_continuas_mae: 15.9929 - learning_rate: 5.0000e-04
# Epoch 96/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 418.6004 - salida_clase_accuracy: 0.6906 - salidas_continuas_mae: 13.1856 - val_loss: 632.7262 - val_salida_clase_accuracy: 0.6696 - val_salidas_continuas_mae: 15.9207 - learning_rate: 5.0000e-04
# Epoch 97/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 451.7162 - salida_clase_accuracy: 0.6714 - salidas_continuas_mae: 13.7207 - val_loss: 644.4006 - val_salida_clase_accuracy: 0.6564 - val_salidas_continuas_mae: 15.8892 - learning_rate: 5.0000e-04
# Epoch 98/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 431.3954 - salida_clase_accuracy: 0.6932 - salidas_continuas_mae: 13.3072 - val_loss: 642.2195 - val_salida_clase_accuracy: 0.6564 - val_salidas_continuas_mae: 16.0596 - learning_rate: 5.0000e-04
# Epoch 99/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 428.0069 - salida_clase_accuracy: 0.6789 - salidas_continuas_mae: 13.4337 - val_loss: 632.2858 - val_salida_clase_accuracy: 0.6594 - val_salidas_continuas_mae: 15.7157 - learning_rate: 5.0000e-04
# Epoch 100/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 410.2980 - salida_clase_accuracy: 0.6901 - salidas_continuas_mae: 13.0813 - val_loss: 634.2809 - val_salida_clase_accuracy: 0.6696 - val_salidas_continuas_mae: 15.7135 - learning_rate: 5.0000e-04
# Epoch 101/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 451.9011 - salida_clase_accuracy: 0.6953 - salidas_continuas_mae: 13.5934 - val_loss: 624.8981 - val_salida_clase_accuracy: 0.6608 - val_salidas_continuas_mae: 15.6662 - learning_rate: 5.0000e-04
# Epoch 102/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 428.0192 - salida_clase_accuracy: 0.6741 - salidas_continuas_mae: 13.1705 - val_loss: 624.7166 - val_salida_clase_accuracy: 0.6637 - val_salidas_continuas_mae: 15.7252 - learning_rate: 5.0000e-04
# Epoch 103/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 444.0889 - salida_clase_accuracy: 0.6721 - salidas_continuas_mae: 13.5975 - val_loss: 630.4988 - val_salida_clase_accuracy: 0.6637 - val_salidas_continuas_mae: 15.5463 - learning_rate: 5.0000e-04
# Epoch 104/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 415.3908 - salida_clase_accuracy: 0.6882 - salidas_continuas_mae: 13.2559 - val_loss: 607.6351 - val_salida_clase_accuracy: 0.6696 - val_salidas_continuas_mae: 15.5886 - learning_rate: 5.0000e-04
# Epoch 105/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 421.2615 - salida_clase_accuracy: 0.6801 - salidas_continuas_mae: 13.2079 - val_loss: 613.6867 - val_salida_clase_accuracy: 0.6520 - val_salidas_continuas_mae: 15.5278 - learning_rate: 5.0000e-04
# Epoch 106/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 429.2711 - salida_clase_accuracy: 0.6702 - salidas_continuas_mae: 13.3348 - val_loss: 615.5482 - val_salida_clase_accuracy: 0.6681 - val_salidas_continuas_mae: 15.5294 - learning_rate: 5.0000e-04
# Epoch 107/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 403.7478 - salida_clase_accuracy: 0.6877 - salidas_continuas_mae: 13.0922 - val_loss: 614.1961 - val_salida_clase_accuracy: 0.6594 - val_salidas_continuas_mae: 15.4977 - learning_rate: 5.0000e-04
# Epoch 108/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 396.1864 - salida_clase_accuracy: 0.6784 - salidas_continuas_mae: 12.6780 - val_loss: 613.2346 - val_salida_clase_accuracy: 0.6550 - val_salidas_continuas_mae: 15.4626 - learning_rate: 5.0000e-04
# Epoch 109/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 413.9875 - salida_clase_accuracy: 0.6937 - salidas_continuas_mae: 13.1172 - val_loss: 604.8904 - val_salida_clase_accuracy: 0.6506 - val_salidas_continuas_mae: 15.3837 - learning_rate: 5.0000e-04
# Epoch 110/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 370.4734 - salida_clase_accuracy: 0.6927 - salidas_continuas_mae: 12.5905 - val_loss: 602.3951 - val_salida_clase_accuracy: 0.6594 - val_salidas_continuas_mae: 15.3124 - learning_rate: 5.0000e-04
# Epoch 111/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 400.7390 - salida_clase_accuracy: 0.6696 - salidas_continuas_mae: 12.8864 - val_loss: 600.5778 - val_salida_clase_accuracy: 0.6462 - val_salidas_continuas_mae: 15.5418 - learning_rate: 5.0000e-04
# Epoch 112/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 386.5986 - salida_clase_accuracy: 0.6889 - salidas_continuas_mae: 12.6611 - val_loss: 618.9471 - val_salida_clase_accuracy: 0.6725 - val_salidas_continuas_mae: 15.2255 - learning_rate: 5.0000e-04
# Epoch 113/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 395.6563 - salida_clase_accuracy: 0.6551 - salidas_continuas_mae: 12.8617 - val_loss: 603.6767 - val_salida_clase_accuracy: 0.6740 - val_salidas_continuas_mae: 15.2539 - learning_rate: 5.0000e-04
# Epoch 114/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 373.7015 - salida_clase_accuracy: 0.6962 - salidas_continuas_mae: 12.5227 - val_loss: 606.5325 - val_salida_clase_accuracy: 0.6550 - val_salidas_continuas_mae: 15.4539 - learning_rate: 5.0000e-04
# Epoch 115/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 374.1413 - salida_clase_accuracy: 0.6926 - salidas_continuas_mae: 12.5783 - val_loss: 590.7376 - val_salida_clase_accuracy: 0.6579 - val_salidas_continuas_mae: 15.1918 - learning_rate: 5.0000e-04
# Epoch 116/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 385.8127 - salida_clase_accuracy: 0.6898 - salidas_continuas_mae: 12.7347 - val_loss: 595.4124 - val_salida_clase_accuracy: 0.6798 - val_salidas_continuas_mae: 15.3946 - learning_rate: 5.0000e-04
# Epoch 117/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 372.3690 - salida_clase_accuracy: 0.6872 - salidas_continuas_mae: 12.4722 - val_loss: 610.9876 - val_salida_clase_accuracy: 0.6769 - val_salidas_continuas_mae: 15.2302 - learning_rate: 5.0000e-04
# Epoch 118/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 381.6775 - salida_clase_accuracy: 0.7030 - salidas_continuas_mae: 12.7239 - val_loss: 587.5956 - val_salida_clase_accuracy: 0.6608 - val_salidas_continuas_mae: 15.1517 - learning_rate: 5.0000e-04
# Epoch 119/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 363.7432 - salida_clase_accuracy: 0.7010 - salidas_continuas_mae: 12.3723 - val_loss: 594.2844 - val_salida_clase_accuracy: 0.6740 - val_salidas_continuas_mae: 15.2438 - learning_rate: 5.0000e-04
# Epoch 120/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 372.1513 - salida_clase_accuracy: 0.6782 - salidas_continuas_mae: 12.4474 - val_loss: 600.3534 - val_salida_clase_accuracy: 0.6608 - val_salidas_continuas_mae: 15.3095 - learning_rate: 5.0000e-04
# Epoch 121/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 367.2915 - salida_clase_accuracy: 0.6951 - salidas_continuas_mae: 12.4228 - val_loss: 595.8071 - val_salida_clase_accuracy: 0.6550 - val_salidas_continuas_mae: 15.0579 - learning_rate: 5.0000e-04
# Epoch 122/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 348.0652 - salida_clase_accuracy: 0.6859 - salidas_continuas_mae: 12.1103 - val_loss: 595.7092 - val_salida_clase_accuracy: 0.6667 - val_salidas_continuas_mae: 15.1378 - learning_rate: 5.0000e-04
# Epoch 123/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 386.5643 - salida_clase_accuracy: 0.7006 - salidas_continuas_mae: 12.7653 - val_loss: 587.7534 - val_salida_clase_accuracy: 0.6769 - val_salidas_continuas_mae: 14.9058 - learning_rate: 5.0000e-04
# Epoch 124/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 363.0534 - salida_clase_accuracy: 0.7026 - salidas_continuas_mae: 12.1375 - val_loss: 580.7095 - val_salida_clase_accuracy: 0.6754 - val_salidas_continuas_mae: 14.8196 - learning_rate: 2.5000e-04
# Epoch 125/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 363.0399 - salida_clase_accuracy: 0.7166 - salidas_continuas_mae: 12.0966 - val_loss: 582.5218 - val_salida_clase_accuracy: 0.6711 - val_salidas_continuas_mae: 14.9423 - learning_rate: 2.5000e-04
# Epoch 126/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 359.3022 - salida_clase_accuracy: 0.6862 - salidas_continuas_mae: 12.2562 - val_loss: 585.8475 - val_salida_clase_accuracy: 0.6813 - val_salidas_continuas_mae: 14.9525 - learning_rate: 2.5000e-04
# Epoch 127/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 359.4040 - salida_clase_accuracy: 0.7034 - salidas_continuas_mae: 12.1862 - val_loss: 586.8067 - val_salida_clase_accuracy: 0.6681 - val_salidas_continuas_mae: 14.9349 - learning_rate: 2.5000e-04
# Epoch 128/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 349.5690 - salida_clase_accuracy: 0.6903 - salidas_continuas_mae: 11.9330 - val_loss: 578.8398 - val_salida_clase_accuracy: 0.6901 - val_salidas_continuas_mae: 14.8770 - learning_rate: 2.5000e-04
# Epoch 129/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 356.6772 - salida_clase_accuracy: 0.6913 - salidas_continuas_mae: 12.0958 - val_loss: 581.3768 - val_salida_clase_accuracy: 0.6754 - val_salidas_continuas_mae: 14.7373 - learning_rate: 2.5000e-04
# Epoch 130/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 390.6426 - salida_clase_accuracy: 0.6933 - salidas_continuas_mae: 12.3787 - val_loss: 575.3031 - val_salida_clase_accuracy: 0.6798 - val_salidas_continuas_mae: 14.6926 - learning_rate: 2.5000e-04
# Epoch 131/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 344.1442 - salida_clase_accuracy: 0.6930 - salidas_continuas_mae: 11.8481 - val_loss: 573.4535 - val_salida_clase_accuracy: 0.6769 - val_salidas_continuas_mae: 14.8136 - learning_rate: 2.5000e-04
# Epoch 132/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 347.6111 - salida_clase_accuracy: 0.7065 - salidas_continuas_mae: 11.9561 - val_loss: 571.1632 - val_salida_clase_accuracy: 0.6886 - val_salidas_continuas_mae: 14.7166 - learning_rate: 2.5000e-04
# Epoch 133/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 360.7029 - salida_clase_accuracy: 0.6780 - salidas_continuas_mae: 12.1585 - val_loss: 575.3854 - val_salida_clase_accuracy: 0.6711 - val_salidas_continuas_mae: 14.8212 - learning_rate: 2.5000e-04
# Epoch 134/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 364.9165 - salida_clase_accuracy: 0.7094 - salidas_continuas_mae: 12.2765 - val_loss: 572.7131 - val_salida_clase_accuracy: 0.6813 - val_salidas_continuas_mae: 14.7691 - learning_rate: 2.5000e-04
# Epoch 135/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 345.8171 - salida_clase_accuracy: 0.7039 - salidas_continuas_mae: 11.9129 - val_loss: 581.9060 - val_salida_clase_accuracy: 0.6754 - val_salidas_continuas_mae: 14.7525 - learning_rate: 2.5000e-04
# Epoch 136/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 349.2149 - salida_clase_accuracy: 0.6998 - salidas_continuas_mae: 11.8518 - val_loss: 574.8143 - val_salida_clase_accuracy: 0.6769 - val_salidas_continuas_mae: 14.7436 - learning_rate: 2.5000e-04
# Epoch 137/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 341.3642 - salida_clase_accuracy: 0.7016 - salidas_continuas_mae: 11.9246 - val_loss: 578.8324 - val_salida_clase_accuracy: 0.6769 - val_salidas_continuas_mae: 14.7243 - learning_rate: 2.5000e-04
# Epoch 138/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 338.3188 - salida_clase_accuracy: 0.6816 - salidas_continuas_mae: 11.7798 - val_loss: 567.4608 - val_salida_clase_accuracy: 0.6842 - val_salidas_continuas_mae: 14.6866 - learning_rate: 1.2500e-04
# Epoch 139/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 334.2509 - salida_clase_accuracy: 0.6800 - salidas_continuas_mae: 11.5435 - val_loss: 563.1613 - val_salida_clase_accuracy: 0.6798 - val_salidas_continuas_mae: 14.6959 - learning_rate: 1.2500e-04
# Epoch 140/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 345.8051 - salida_clase_accuracy: 0.6970 - salidas_continuas_mae: 11.8714 - val_loss: 573.3821 - val_salida_clase_accuracy: 0.6813 - val_salidas_continuas_mae: 14.6450 - learning_rate: 1.2500e-04
# Epoch 141/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 321.6493 - salida_clase_accuracy: 0.7033 - salidas_continuas_mae: 11.5184 - val_loss: 571.2777 - val_salida_clase_accuracy: 0.6842 - val_salidas_continuas_mae: 14.6357 - learning_rate: 1.2500e-04
# Epoch 142/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 355.8472 - salida_clase_accuracy: 0.7081 - salidas_continuas_mae: 12.0248 - val_loss: 568.5787 - val_salida_clase_accuracy: 0.6930 - val_salidas_continuas_mae: 14.6154 - learning_rate: 1.2500e-04
# Epoch 143/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 332.7938 - salida_clase_accuracy: 0.6978 - salidas_continuas_mae: 11.7116 - val_loss: 566.7623 - val_salida_clase_accuracy: 0.6857 - val_salidas_continuas_mae: 14.7257 - learning_rate: 1.2500e-04
# Epoch 144/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 327.7610 - salida_clase_accuracy: 0.6939 - salidas_continuas_mae: 11.5404 - val_loss: 568.8408 - val_salida_clase_accuracy: 0.6696 - val_salidas_continuas_mae: 14.6802 - learning_rate: 1.2500e-04
# Epoch 145/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 333.9741 - salida_clase_accuracy: 0.7025 - salidas_continuas_mae: 11.7247 - val_loss: 569.8290 - val_salida_clase_accuracy: 0.6886 - val_salidas_continuas_mae: 14.6177 - learning_rate: 6.2500e-05
# Epoch 146/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 324.5725 - salida_clase_accuracy: 0.7043 - salidas_continuas_mae: 11.5485 - val_loss: 571.8578 - val_salida_clase_accuracy: 0.6827 - val_salidas_continuas_mae: 14.6348 - learning_rate: 6.2500e-05
# Epoch 147/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 341.1866 - salida_clase_accuracy: 0.6916 - salidas_continuas_mae: 11.6545 - val_loss: 569.1985 - val_salida_clase_accuracy: 0.6886 - val_salidas_continuas_mae: 14.5940 - learning_rate: 6.2500e-05
# Epoch 148/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 329.5121 - salida_clase_accuracy: 0.6902 - salidas_continuas_mae: 11.6386 - val_loss: 567.4789 - val_salida_clase_accuracy: 0.6915 - val_salidas_continuas_mae: 14.6203 - learning_rate: 6.2500e-05
# Epoch 149/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 335.8311 - salida_clase_accuracy: 0.7053 - salidas_continuas_mae: 11.7027 - val_loss: 567.4042 - val_salida_clase_accuracy: 0.6871 - val_salidas_continuas_mae: 14.6298 - learning_rate: 6.2500e-05
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 491.4311 - salida_clase_accuracy: 0.6971 - salidas_continuas_mae: 13.6968
# Fold 5: Loss=515.5096435546875, MAE=14.100393295288086, Accuracy=0.7009345889091492
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 510.4870239257813
# MAE: 13.872990692491225
# MSE: 509.58228132020406
# RMSE: 22.571092145557575
# R^2: 0.8611128365096498
# Accuracy: 0.6880841135978699
# Precisión: 0.6879221073502445
# Recall: 0.6880841121495328
# F1-Score: 0.683027049001103
