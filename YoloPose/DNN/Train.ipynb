# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import joblib
import matplotlib.pyplot as plt

# %%
# Definir rutas
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_raiz = os.path.dirname(carpeta_mediapipe)
ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual,'datos','scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Videos_Pose', 'pose_data.csv')

# Cargar el dataset
data = pd.read_csv(ruta_csv)

# Preparar entradas (Keypoints)
num_keypoints = 17 * 3
X = data.iloc[:, :num_keypoints].values

# Las siguientes 11 columnas incluyen:
# 10 características continuas (ángulos, distancias) + 1 tipo de ejercicio (última columna)
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

# Codificar la etiqueta del tipo de ejercicio
encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_continuas_train, y_continuas_test, y_clase_train, y_clase_test = train_test_split(
    X, y_continuas, y_clase_encoded, test_size=0.2, random_state=42)

# Normalizar las entradas
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

# Listas para almacenar métricas
all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

# Matrices para almacenar la historia del entrenamiento
n_epochs = 50  # Número de épocas
all_train_loss = np.zeros((5, n_epochs))  # 5 pliegues, n_epochs épocas
all_val_loss = np.zeros((5, n_epochs))
all_train_accuracy = np.zeros((5, n_epochs))
all_val_accuracy = np.zeros((5, n_epochs))

# Validación cruzada
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
fold_index = 0

def create_model(learning_rate=0.001):
    input_layer = Input(shape=(X_train_scaled.shape[1],))
    x = Dense(128, activation='relu')(input_layer)
    x = Dense(64, activation='relu')(x)
    x = Dense(32, activation='relu')(x)
    salidas_continuas = Dense(10, activation='linear', name='salidas_continuas')(x)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)
    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer,
                  loss={'salidas_continuas': 'mean_squared_error', 'salida_clase': 'sparse_categorical_crossentropy'},
                  metrics={'salidas_continuas': 'mae', 'salida_clase': 'accuracy'})
    return model

for train_index, val_index in kfold.split(X_train_scaled):
    fold_index += 1
    print(f"Entrenando fold {fold_index}...")

    X_train_fold, X_val_fold = X_train_scaled[train_index], X_train_scaled[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas_train[train_index], y_continuas_train[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_train[train_index], y_clase_train[val_index]

    model = create_model(learning_rate=0.0005)  # Ajustar la tasa de aprendizaje aquí
    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold_index}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    # Almacenar la historia del entrenamiento
    all_train_loss[fold_index - 1, :] = history.history['loss']
    all_val_loss[fold_index - 1, :] = history.history['val_loss']
    all_train_accuracy[fold_index - 1, :] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold_index - 1, :] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de prueba
    scores = model.evaluate(X_test_scaled, {'salidas_continuas': y_continuas_test, 'salida_clase': y_clase_test})
    print(f"Fold {fold_index}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_test_scaled)[0]
    mae = mean_absolute_error(y_continuas_test, y_pred_continuas)
    mse = mean_squared_error(y_continuas_test, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_test)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_test_scaled)[1], axis=1)
    precision = precision_score(y_clase_test, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_test, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_test, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_test, y_pred_clase, labels=np.unique(y_clase_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 21601.6621 - salida_clase_accuracy: 0.2831 - salidas_continuas_mae: 87.2628 - val_loss: 7444.4360 - val_salida_clase_accuracy: 0.4457 - val_salidas_continuas_mae: 48.5316 - learning_rate: 5.0000e-04
# Epoch 2/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 6775.8501 - salida_clase_accuracy: 0.4652 - salidas_continuas_mae: 45.7477 - val_loss: 5438.8818 - val_salida_clase_accuracy: 0.5068 - val_salidas_continuas_mae: 39.0513 - learning_rate: 5.0000e-04
# Epoch 3/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5142.3281 - salida_clase_accuracy: 0.4976 - salidas_continuas_mae: 38.3316 - val_loss: 4876.5757 - val_salida_clase_accuracy: 0.4846 - val_salidas_continuas_mae: 35.9205 - learning_rate: 5.0000e-04
# Epoch 4/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4647.7505 - salida_clase_accuracy: 0.4794 - salidas_continuas_mae: 35.7488 - val_loss: 4438.4653 - val_salida_clase_accuracy: 0.4943 - val_salidas_continuas_mae: 34.5893 - learning_rate: 5.0000e-04
# Epoch 5/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4244.2705 - salida_clase_accuracy: 0.5155 - salidas_continuas_mae: 34.1252 - val_loss: 3714.1797 - val_salida_clase_accuracy: 0.5310 - val_salidas_continuas_mae: 32.2937 - learning_rate: 5.0000e-04
# Epoch 6/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3470.2004 - salida_clase_accuracy: 0.5789 - salidas_continuas_mae: 31.4062 - val_loss: 2950.0237 - val_salida_clase_accuracy: 0.6037 - val_salidas_continuas_mae: 29.3114 - learning_rate: 5.0000e-04
# Epoch 7/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2585.8110 - salida_clase_accuracy: 0.6039 - salidas_continuas_mae: 28.3134 - val_loss: 2199.0542 - val_salida_clase_accuracy: 0.5421 - val_salidas_continuas_mae: 26.5963 - learning_rate: 5.0000e-04
# Epoch 8/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1902.1466 - salida_clase_accuracy: 0.6013 - salidas_continuas_mae: 25.5634 - val_loss: 1521.7596 - val_salida_clase_accuracy: 0.6434 - val_salidas_continuas_mae: 23.4635 - learning_rate: 5.0000e-04
# Epoch 9/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1319.9587 - salida_clase_accuracy: 0.6606 - salidas_continuas_mae: 22.4111 - val_loss: 1052.6238 - val_salida_clase_accuracy: 0.6552 - val_salidas_continuas_mae: 20.7084 - learning_rate: 5.0000e-04
# Epoch 10/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 947.8224 - salida_clase_accuracy: 0.6756 - salidas_continuas_mae: 20.1230 - val_loss: 811.4073 - val_salida_clase_accuracy: 0.7017 - val_salidas_continuas_mae: 18.7533 - learning_rate: 5.0000e-04
# Epoch 11/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 758.2260 - salida_clase_accuracy: 0.6917 - salidas_continuas_mae: 18.2226 - val_loss: 699.7800 - val_salida_clase_accuracy: 0.6970 - val_salidas_continuas_mae: 17.4968 - learning_rate: 5.0000e-04
# Epoch 12/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 678.0341 - salida_clase_accuracy: 0.6984 - salidas_continuas_mae: 17.2416 - val_loss: 643.7697 - val_salida_clase_accuracy: 0.7052 - val_salidas_continuas_mae: 16.9444 - learning_rate: 5.0000e-04
# Epoch 13/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 608.0774 - salida_clase_accuracy: 0.7096 - salidas_continuas_mae: 16.2917 - val_loss: 578.6268 - val_salida_clase_accuracy: 0.7077 - val_salidas_continuas_mae: 15.5964 - learning_rate: 5.0000e-04
# Epoch 14/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 550.2251 - salida_clase_accuracy: 0.7087 - salidas_continuas_mae: 15.3607 - val_loss: 538.9350 - val_salida_clase_accuracy: 0.7085 - val_salidas_continuas_mae: 14.9629 - learning_rate: 5.0000e-04
# Epoch 15/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 514.3537 - salida_clase_accuracy: 0.7216 - salidas_continuas_mae: 14.7031 - val_loss: 513.6716 - val_salida_clase_accuracy: 0.7342 - val_salidas_continuas_mae: 14.6083 - learning_rate: 5.0000e-04
# Epoch 16/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 484.2338 - salida_clase_accuracy: 0.7235 - salidas_continuas_mae: 14.2180 - val_loss: 484.4327 - val_salida_clase_accuracy: 0.7338 - val_salidas_continuas_mae: 13.9338 - learning_rate: 5.0000e-04
# Epoch 17/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 451.4210 - salida_clase_accuracy: 0.7286 - salidas_continuas_mae: 13.6556 - val_loss: 466.6525 - val_salida_clase_accuracy: 0.6982 - val_salidas_continuas_mae: 13.6822 - learning_rate: 5.0000e-04
# Epoch 18/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 444.1246 - salida_clase_accuracy: 0.7295 - salidas_continuas_mae: 13.4392 - val_loss: 443.4197 - val_salida_clase_accuracy: 0.7219 - val_salidas_continuas_mae: 13.1617 - learning_rate: 5.0000e-04
# Epoch 19/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 421.5056 - salida_clase_accuracy: 0.7350 - salidas_continuas_mae: 13.0800 - val_loss: 432.3350 - val_salida_clase_accuracy: 0.7223 - val_salidas_continuas_mae: 12.9591 - learning_rate: 5.0000e-04
# Epoch 20/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 407.5923 - salida_clase_accuracy: 0.7314 - salidas_continuas_mae: 12.7748 - val_loss: 417.1084 - val_salida_clase_accuracy: 0.7494 - val_salidas_continuas_mae: 12.7860 - learning_rate: 5.0000e-04
# Epoch 21/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 387.5444 - salida_clase_accuracy: 0.7338 - salidas_continuas_mae: 12.3864 - val_loss: 401.2784 - val_salida_clase_accuracy: 0.7373 - val_salidas_continuas_mae: 12.3840 - learning_rate: 5.0000e-04
# Epoch 22/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 384.0155 - salida_clase_accuracy: 0.7301 - salidas_continuas_mae: 12.2575 - val_loss: 391.4643 - val_salida_clase_accuracy: 0.7400 - val_salidas_continuas_mae: 12.2708 - learning_rate: 5.0000e-04
# Epoch 23/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 372.4470 - salida_clase_accuracy: 0.7305 - salidas_continuas_mae: 12.0053 - val_loss: 376.0956 - val_salida_clase_accuracy: 0.7100 - val_salidas_continuas_mae: 11.8756 - learning_rate: 5.0000e-04
# Epoch 24/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 352.7946 - salida_clase_accuracy: 0.7401 - salidas_continuas_mae: 11.6370 - val_loss: 374.1821 - val_salida_clase_accuracy: 0.7140 - val_salidas_continuas_mae: 11.9548 - learning_rate: 5.0000e-04
# Epoch 25/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 347.8190 - salida_clase_accuracy: 0.7261 - salidas_continuas_mae: 11.6213 - val_loss: 358.4751 - val_salida_clase_accuracy: 0.7492 - val_salidas_continuas_mae: 11.5255 - learning_rate: 5.0000e-04
# Epoch 26/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 332.8481 - salida_clase_accuracy: 0.7287 - salidas_continuas_mae: 11.2587 - val_loss: 349.6737 - val_salida_clase_accuracy: 0.7473 - val_salidas_continuas_mae: 11.2370 - learning_rate: 5.0000e-04
# Epoch 27/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 320.9661 - salida_clase_accuracy: 0.7419 - salidas_continuas_mae: 11.0315 - val_loss: 345.5638 - val_salida_clase_accuracy: 0.7459 - val_salidas_continuas_mae: 11.3250 - learning_rate: 5.0000e-04
# Epoch 28/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 318.5100 - salida_clase_accuracy: 0.7353 - salidas_continuas_mae: 10.9480 - val_loss: 334.6586 - val_salida_clase_accuracy: 0.7373 - val_salidas_continuas_mae: 11.0873 - learning_rate: 5.0000e-04
# Epoch 29/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 306.8896 - salida_clase_accuracy: 0.7356 - salidas_continuas_mae: 10.7632 - val_loss: 322.6556 - val_salida_clase_accuracy: 0.7457 - val_salidas_continuas_mae: 10.6800 - learning_rate: 5.0000e-04
# Epoch 30/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 298.0627 - salida_clase_accuracy: 0.7397 - salidas_continuas_mae: 10.5308 - val_loss: 320.2648 - val_salida_clase_accuracy: 0.7427 - val_salidas_continuas_mae: 10.6799 - learning_rate: 5.0000e-04
# Epoch 31/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 296.7018 - salida_clase_accuracy: 0.7443 - salidas_continuas_mae: 10.4927 - val_loss: 313.1505 - val_salida_clase_accuracy: 0.7585 - val_salidas_continuas_mae: 10.5996 - learning_rate: 5.0000e-04
# Epoch 32/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 292.6485 - salida_clase_accuracy: 0.7383 - salidas_continuas_mae: 10.4346 - val_loss: 303.3217 - val_salida_clase_accuracy: 0.7569 - val_salidas_continuas_mae: 10.3538 - learning_rate: 5.0000e-04
# Epoch 33/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 281.6456 - salida_clase_accuracy: 0.7414 - salidas_continuas_mae: 10.1796 - val_loss: 300.5962 - val_salida_clase_accuracy: 0.7579 - val_salidas_continuas_mae: 10.2135 - learning_rate: 5.0000e-04
# Epoch 34/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 277.3408 - salida_clase_accuracy: 0.7445 - salidas_continuas_mae: 10.0762 - val_loss: 296.3098 - val_salida_clase_accuracy: 0.7536 - val_salidas_continuas_mae: 10.1823 - learning_rate: 5.0000e-04
# Epoch 35/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 271.3692 - salida_clase_accuracy: 0.7581 - salidas_continuas_mae: 9.9446 - val_loss: 292.8206 - val_salida_clase_accuracy: 0.7633 - val_salidas_continuas_mae: 10.1014 - learning_rate: 5.0000e-04
# Epoch 36/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 265.8591 - salida_clase_accuracy: 0.7566 - salidas_continuas_mae: 9.8172 - val_loss: 291.5206 - val_salida_clase_accuracy: 0.7261 - val_salidas_continuas_mae: 10.1408 - learning_rate: 5.0000e-04
# Epoch 37/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 263.1060 - salida_clase_accuracy: 0.7550 - salidas_continuas_mae: 9.7814 - val_loss: 284.1258 - val_salida_clase_accuracy: 0.7580 - val_salidas_continuas_mae: 9.9592 - learning_rate: 5.0000e-04
# Epoch 38/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 259.7827 - salida_clase_accuracy: 0.7508 - salidas_continuas_mae: 9.7084 - val_loss: 276.1001 - val_salida_clase_accuracy: 0.7580 - val_salidas_continuas_mae: 9.6718 - learning_rate: 5.0000e-04
# Epoch 39/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 250.2251 - salida_clase_accuracy: 0.7587 - salidas_continuas_mae: 9.4917 - val_loss: 274.5139 - val_salida_clase_accuracy: 0.7703 - val_salidas_continuas_mae: 9.6769 - learning_rate: 5.0000e-04
# Epoch 40/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 253.3521 - salida_clase_accuracy: 0.7570 - salidas_continuas_mae: 9.5126 - val_loss: 270.6822 - val_salida_clase_accuracy: 0.7684 - val_salidas_continuas_mae: 9.5561 - learning_rate: 5.0000e-04
# Epoch 41/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 249.5060 - salida_clase_accuracy: 0.7599 - salidas_continuas_mae: 9.3909 - val_loss: 277.7945 - val_salida_clase_accuracy: 0.7346 - val_salidas_continuas_mae: 9.7894 - learning_rate: 5.0000e-04
# Epoch 42/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 256.6697 - salida_clase_accuracy: 0.7611 - salidas_continuas_mae: 9.6298 - val_loss: 260.7055 - val_salida_clase_accuracy: 0.7807 - val_salidas_continuas_mae: 9.3371 - learning_rate: 5.0000e-04
# Epoch 43/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 238.6269 - salida_clase_accuracy: 0.7650 - salidas_continuas_mae: 9.1862 - val_loss: 257.2095 - val_salida_clase_accuracy: 0.7698 - val_salidas_continuas_mae: 9.2821 - learning_rate: 5.0000e-04
# Epoch 44/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 235.7005 - salida_clase_accuracy: 0.7713 - salidas_continuas_mae: 9.0755 - val_loss: 262.0384 - val_salida_clase_accuracy: 0.7590 - val_salidas_continuas_mae: 9.4435 - learning_rate: 5.0000e-04
# Epoch 45/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 240.6998 - salida_clase_accuracy: 0.7634 - salidas_continuas_mae: 9.1872 - val_loss: 256.1647 - val_salida_clase_accuracy: 0.7551 - val_salidas_continuas_mae: 9.2996 - learning_rate: 5.0000e-04
# Epoch 46/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 230.9559 - salida_clase_accuracy: 0.7647 - salidas_continuas_mae: 8.9907 - val_loss: 255.9684 - val_salida_clase_accuracy: 0.7700 - val_salidas_continuas_mae: 9.3503 - learning_rate: 5.0000e-04
# Epoch 47/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 230.5688 - salida_clase_accuracy: 0.7747 - salidas_continuas_mae: 8.9801 - val_loss: 249.9474 - val_salida_clase_accuracy: 0.7813 - val_salidas_continuas_mae: 9.1051 - learning_rate: 5.0000e-04
# Epoch 48/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 228.2703 - salida_clase_accuracy: 0.7788 - salidas_continuas_mae: 8.9099 - val_loss: 247.4865 - val_salida_clase_accuracy: 0.7868 - val_salidas_continuas_mae: 9.0541 - learning_rate: 5.0000e-04
# Epoch 49/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 217.9510 - salida_clase_accuracy: 0.7798 - salidas_continuas_mae: 8.7384 - val_loss: 246.4101 - val_salida_clase_accuracy: 0.7930 - val_salidas_continuas_mae: 9.0989 - learning_rate: 5.0000e-04
# Epoch 50/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 216.9521 - salida_clase_accuracy: 0.7779 - salidas_continuas_mae: 8.6684 - val_loss: 245.8726 - val_salida_clase_accuracy: 0.7837 - val_salidas_continuas_mae: 9.0205 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 240.4024 - salida_clase_accuracy: 0.7790 - salidas_continuas_mae: 9.0439
# Fold 1: Loss=237.35711669921875, MAE=9.018142700195312, Accuracy=0.7816370725631714
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Entrenando fold 2...
# Epoch 1/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 21305.4805 - salida_clase_accuracy: 0.1417 - salidas_continuas_mae: 85.0252 - val_loss: 7285.7974 - val_salida_clase_accuracy: 0.2254 - val_salidas_continuas_mae: 47.1105 - learning_rate: 5.0000e-04
# Epoch 2/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 6426.8013 - salida_clase_accuracy: 0.3213 - salidas_continuas_mae: 44.5456 - val_loss: 5643.9458 - val_salida_clase_accuracy: 0.5243 - val_salidas_continuas_mae: 39.6843 - learning_rate: 5.0000e-04
# Epoch 3/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5214.6997 - salida_clase_accuracy: 0.5046 - salidas_continuas_mae: 38.6612 - val_loss: 4939.4224 - val_salida_clase_accuracy: 0.5210 - val_salidas_continuas_mae: 35.8526 - learning_rate: 5.0000e-04
# Epoch 4/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4431.4683 - salida_clase_accuracy: 0.5211 - salidas_continuas_mae: 34.6791 - val_loss: 4005.7922 - val_salida_clase_accuracy: 0.5604 - val_salidas_continuas_mae: 33.5529 - learning_rate: 5.0000e-04
# Epoch 5/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3500.3667 - salida_clase_accuracy: 0.5760 - salidas_continuas_mae: 32.2784 - val_loss: 2839.7964 - val_salida_clase_accuracy: 0.6388 - val_salidas_continuas_mae: 29.8402 - learning_rate: 5.0000e-04
# Epoch 6/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2454.5371 - salida_clase_accuracy: 0.6421 - salidas_continuas_mae: 28.6481 - val_loss: 2054.3713 - val_salida_clase_accuracy: 0.6535 - val_salidas_continuas_mae: 26.8738 - learning_rate: 5.0000e-04
# Epoch 7/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1766.9631 - salida_clase_accuracy: 0.6719 - salidas_continuas_mae: 25.7973 - val_loss: 1471.6343 - val_salida_clase_accuracy: 0.6784 - val_salidas_continuas_mae: 24.3590 - learning_rate: 5.0000e-04
# Epoch 8/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1298.9424 - salida_clase_accuracy: 0.6888 - salidas_continuas_mae: 23.5929 - val_loss: 1107.9724 - val_salida_clase_accuracy: 0.6836 - val_salidas_continuas_mae: 22.1116 - learning_rate: 5.0000e-04
# Epoch 9/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1007.1657 - salida_clase_accuracy: 0.6983 - salidas_continuas_mae: 21.3802 - val_loss: 952.6110 - val_salida_clase_accuracy: 0.7267 - val_salidas_continuas_mae: 21.2167 - learning_rate: 5.0000e-04
# Epoch 10/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 872.4568 - salida_clase_accuracy: 0.7015 - salidas_continuas_mae: 20.1425 - val_loss: 807.8638 - val_salida_clase_accuracy: 0.7194 - val_salidas_continuas_mae: 19.2343 - learning_rate: 5.0000e-04
# Epoch 11/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 753.0302 - salida_clase_accuracy: 0.7041 - salidas_continuas_mae: 18.6085 - val_loss: 716.1456 - val_salida_clase_accuracy: 0.7192 - val_salidas_continuas_mae: 17.8162 - learning_rate: 5.0000e-04
# Epoch 12/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 680.0585 - salida_clase_accuracy: 0.6980 - salidas_continuas_mae: 17.4842 - val_loss: 653.2829 - val_salida_clase_accuracy: 0.7263 - val_salidas_continuas_mae: 17.1114 - learning_rate: 5.0000e-04
# Epoch 13/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 631.6201 - salida_clase_accuracy: 0.6986 - salidas_continuas_mae: 16.7461 - val_loss: 587.9754 - val_salida_clase_accuracy: 0.7063 - val_salidas_continuas_mae: 15.8115 - learning_rate: 5.0000e-04
# Epoch 14/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 568.5499 - salida_clase_accuracy: 0.6989 - salidas_continuas_mae: 15.6579 - val_loss: 543.7281 - val_salida_clase_accuracy: 0.7357 - val_salidas_continuas_mae: 15.2653 - learning_rate: 5.0000e-04
# Epoch 15/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 533.6951 - salida_clase_accuracy: 0.7138 - salidas_continuas_mae: 15.0222 - val_loss: 511.2315 - val_salida_clase_accuracy: 0.7028 - val_salidas_continuas_mae: 14.7335 - learning_rate: 5.0000e-04
# Epoch 16/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 501.8866 - salida_clase_accuracy: 0.7224 - salidas_continuas_mae: 14.4930 - val_loss: 478.6736 - val_salida_clase_accuracy: 0.7607 - val_salidas_continuas_mae: 14.0550 - learning_rate: 5.0000e-04
# Epoch 17/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 470.8442 - salida_clase_accuracy: 0.7455 - salidas_continuas_mae: 13.9510 - val_loss: 451.3939 - val_salida_clase_accuracy: 0.7229 - val_salidas_continuas_mae: 13.4700 - learning_rate: 5.0000e-04
# Epoch 18/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 446.8770 - salida_clase_accuracy: 0.7409 - salidas_continuas_mae: 13.4988 - val_loss: 431.6941 - val_salida_clase_accuracy: 0.7702 - val_salidas_continuas_mae: 13.1641 - learning_rate: 5.0000e-04
# Epoch 19/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 422.2708 - salida_clase_accuracy: 0.7537 - salidas_continuas_mae: 13.0278 - val_loss: 420.9596 - val_salida_clase_accuracy: 0.7481 - val_salidas_continuas_mae: 12.9257 - learning_rate: 5.0000e-04
# Epoch 20/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 404.8698 - salida_clase_accuracy: 0.7600 - salidas_continuas_mae: 12.6528 - val_loss: 400.7860 - val_salida_clase_accuracy: 0.7488 - val_salidas_continuas_mae: 12.5416 - learning_rate: 5.0000e-04
# Epoch 21/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 389.6476 - salida_clase_accuracy: 0.7491 - salidas_continuas_mae: 12.3926 - val_loss: 381.8794 - val_salida_clase_accuracy: 0.7741 - val_salidas_continuas_mae: 12.1595 - learning_rate: 5.0000e-04
# Epoch 22/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 381.7430 - salida_clase_accuracy: 0.7587 - salidas_continuas_mae: 12.1470 - val_loss: 391.6693 - val_salida_clase_accuracy: 0.7660 - val_salidas_continuas_mae: 12.6534 - learning_rate: 5.0000e-04
# Epoch 23/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 373.7580 - salida_clase_accuracy: 0.7683 - salidas_continuas_mae: 12.0448 - val_loss: 368.5865 - val_salida_clase_accuracy: 0.7513 - val_salidas_continuas_mae: 12.0242 - learning_rate: 5.0000e-04
# Epoch 24/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 353.3559 - salida_clase_accuracy: 0.7711 - salidas_continuas_mae: 11.5841 - val_loss: 347.1216 - val_salida_clase_accuracy: 0.7792 - val_salidas_continuas_mae: 11.3917 - learning_rate: 5.0000e-04
# Epoch 25/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 336.8173 - salida_clase_accuracy: 0.7617 - salidas_continuas_mae: 11.3108 - val_loss: 338.8229 - val_salida_clase_accuracy: 0.7767 - val_salidas_continuas_mae: 11.2842 - learning_rate: 5.0000e-04
# Epoch 26/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 329.6321 - salida_clase_accuracy: 0.7760 - salidas_continuas_mae: 11.0980 - val_loss: 332.9129 - val_salida_clase_accuracy: 0.7309 - val_salidas_continuas_mae: 11.1238 - learning_rate: 5.0000e-04
# Epoch 27/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 329.5203 - salida_clase_accuracy: 0.7742 - salidas_continuas_mae: 11.1217 - val_loss: 325.9226 - val_salida_clase_accuracy: 0.7480 - val_salidas_continuas_mae: 11.1238 - learning_rate: 5.0000e-04
# Epoch 28/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 312.6770 - salida_clase_accuracy: 0.7732 - salidas_continuas_mae: 10.8013 - val_loss: 317.8456 - val_salida_clase_accuracy: 0.7660 - val_salidas_continuas_mae: 10.8146 - learning_rate: 5.0000e-04
# Epoch 29/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 312.6547 - salida_clase_accuracy: 0.7755 - salidas_continuas_mae: 10.7896 - val_loss: 317.5489 - val_salida_clase_accuracy: 0.7708 - val_salidas_continuas_mae: 10.9519 - learning_rate: 5.0000e-04
# Epoch 30/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 306.4395 - salida_clase_accuracy: 0.7819 - salidas_continuas_mae: 10.6832 - val_loss: 307.3688 - val_salida_clase_accuracy: 0.7778 - val_salidas_continuas_mae: 10.6140 - learning_rate: 5.0000e-04
# Epoch 31/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 295.9969 - salida_clase_accuracy: 0.7853 - salidas_continuas_mae: 10.3790 - val_loss: 296.3022 - val_salida_clase_accuracy: 0.7864 - val_salidas_continuas_mae: 10.3415 - learning_rate: 5.0000e-04
# Epoch 32/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 286.2092 - salida_clase_accuracy: 0.7923 - salidas_continuas_mae: 10.2321 - val_loss: 296.7751 - val_salida_clase_accuracy: 0.7954 - val_salidas_continuas_mae: 10.4044 - learning_rate: 5.0000e-04
# Epoch 33/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 282.9038 - salida_clase_accuracy: 0.7860 - salidas_continuas_mae: 10.1760 - val_loss: 287.0131 - val_salida_clase_accuracy: 0.7998 - val_salidas_continuas_mae: 10.1227 - learning_rate: 5.0000e-04
# Epoch 34/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 277.4999 - salida_clase_accuracy: 0.7883 - salidas_continuas_mae: 10.0211 - val_loss: 283.6208 - val_salida_clase_accuracy: 0.7874 - val_salidas_continuas_mae: 10.1370 - learning_rate: 5.0000e-04
# Epoch 35/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 271.1265 - salida_clase_accuracy: 0.7937 - salidas_continuas_mae: 9.9094 - val_loss: 279.5501 - val_salida_clase_accuracy: 0.7797 - val_salidas_continuas_mae: 9.9475 - learning_rate: 5.0000e-04
# Epoch 36/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 263.8032 - salida_clase_accuracy: 0.7971 - salidas_continuas_mae: 9.7411 - val_loss: 273.3029 - val_salida_clase_accuracy: 0.8002 - val_salidas_continuas_mae: 9.7467 - learning_rate: 5.0000e-04
# Epoch 37/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 262.4636 - salida_clase_accuracy: 0.7968 - salidas_continuas_mae: 9.6932 - val_loss: 268.1580 - val_salida_clase_accuracy: 0.8147 - val_salidas_continuas_mae: 9.6932 - learning_rate: 5.0000e-04
# Epoch 38/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 256.5475 - salida_clase_accuracy: 0.7991 - salidas_continuas_mae: 9.5778 - val_loss: 269.3175 - val_salida_clase_accuracy: 0.7994 - val_salidas_continuas_mae: 9.7560 - learning_rate: 5.0000e-04
# Epoch 39/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 255.0524 - salida_clase_accuracy: 0.8106 - salidas_continuas_mae: 9.4919 - val_loss: 263.3397 - val_salida_clase_accuracy: 0.7986 - val_salidas_continuas_mae: 9.6700 - learning_rate: 5.0000e-04
# Epoch 40/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 249.9192 - salida_clase_accuracy: 0.8009 - salidas_continuas_mae: 9.4140 - val_loss: 258.4263 - val_salida_clase_accuracy: 0.8107 - val_salidas_continuas_mae: 9.4661 - learning_rate: 5.0000e-04
# Epoch 41/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 246.2905 - salida_clase_accuracy: 0.8065 - salidas_continuas_mae: 9.3087 - val_loss: 259.0860 - val_salida_clase_accuracy: 0.7898 - val_salidas_continuas_mae: 9.6827 - learning_rate: 5.0000e-04
# Epoch 42/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 249.3616 - salida_clase_accuracy: 0.7986 - salidas_continuas_mae: 9.4264 - val_loss: 256.0644 - val_salida_clase_accuracy: 0.8223 - val_salidas_continuas_mae: 9.4867 - learning_rate: 5.0000e-04
# Epoch 43/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 239.1457 - salida_clase_accuracy: 0.8087 - salidas_continuas_mae: 9.2001 - val_loss: 251.0201 - val_salida_clase_accuracy: 0.8070 - val_salidas_continuas_mae: 9.3734 - learning_rate: 5.0000e-04
# Epoch 44/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 238.7126 - salida_clase_accuracy: 0.7989 - salidas_continuas_mae: 9.1641 - val_loss: 248.1922 - val_salida_clase_accuracy: 0.8085 - val_salidas_continuas_mae: 9.3209 - learning_rate: 5.0000e-04
# Epoch 45/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 236.6817 - salida_clase_accuracy: 0.8076 - salidas_continuas_mae: 9.1242 - val_loss: 247.1336 - val_salida_clase_accuracy: 0.8184 - val_salidas_continuas_mae: 9.1736 - learning_rate: 5.0000e-04
# Epoch 46/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 229.6502 - salida_clase_accuracy: 0.8054 - salidas_continuas_mae: 8.9637 - val_loss: 240.3833 - val_salida_clase_accuracy: 0.8155 - val_salidas_continuas_mae: 8.9755 - learning_rate: 5.0000e-04
# Epoch 47/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 227.2328 - salida_clase_accuracy: 0.8108 - salidas_continuas_mae: 8.9061 - val_loss: 243.5876 - val_salida_clase_accuracy: 0.8177 - val_salidas_continuas_mae: 9.2368 - learning_rate: 5.0000e-04
# Epoch 48/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 226.0954 - salida_clase_accuracy: 0.8152 - salidas_continuas_mae: 8.9128 - val_loss: 235.6544 - val_salida_clase_accuracy: 0.8053 - val_salidas_continuas_mae: 8.9878 - learning_rate: 5.0000e-04
# Epoch 49/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 223.2526 - salida_clase_accuracy: 0.8118 - salidas_continuas_mae: 8.7836 - val_loss: 232.8183 - val_salida_clase_accuracy: 0.8099 - val_salidas_continuas_mae: 8.7965 - learning_rate: 5.0000e-04
# Epoch 50/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 216.9498 - salida_clase_accuracy: 0.8117 - salidas_continuas_mae: 8.6627 - val_loss: 234.0870 - val_salida_clase_accuracy: 0.8168 - val_salidas_continuas_mae: 8.9453 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 233.9118 - salida_clase_accuracy: 0.8101 - salidas_continuas_mae: 8.7649
# Fold 2: Loss=230.21890258789062, MAE=8.759140968322754, Accuracy=0.8131784200668335
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Entrenando fold 3...
# Epoch 1/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 22082.1934 - salida_clase_accuracy: 0.1808 - salidas_continuas_mae: 87.9961 - val_loss: 7268.1406 - val_salida_clase_accuracy: 0.3784 - val_salidas_continuas_mae: 48.9767 - learning_rate: 5.0000e-04
# Epoch 2/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 6478.4150 - salida_clase_accuracy: 0.4056 - salidas_continuas_mae: 44.6787 - val_loss: 5323.0068 - val_salida_clase_accuracy: 0.4543 - val_salidas_continuas_mae: 39.5999 - learning_rate: 5.0000e-04
# Epoch 3/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5283.8018 - salida_clase_accuracy: 0.4784 - salidas_continuas_mae: 38.6985 - val_loss: 4689.4766 - val_salida_clase_accuracy: 0.4963 - val_salidas_continuas_mae: 35.8303 - learning_rate: 5.0000e-04
# Epoch 4/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4485.1377 - salida_clase_accuracy: 0.4906 - salidas_continuas_mae: 35.1944 - val_loss: 3864.0156 - val_salida_clase_accuracy: 0.4296 - val_salidas_continuas_mae: 33.3810 - learning_rate: 5.0000e-04
# Epoch 5/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3603.1079 - salida_clase_accuracy: 0.4550 - salidas_continuas_mae: 32.3996 - val_loss: 2737.6812 - val_salida_clase_accuracy: 0.5211 - val_salidas_continuas_mae: 29.0265 - learning_rate: 5.0000e-04
# Epoch 6/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2569.0679 - salida_clase_accuracy: 0.5546 - salidas_continuas_mae: 27.8354 - val_loss: 2109.6570 - val_salida_clase_accuracy: 0.5845 - val_salidas_continuas_mae: 25.3602 - learning_rate: 5.0000e-04
# Epoch 7/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2038.8069 - salida_clase_accuracy: 0.6301 - salidas_continuas_mae: 24.8257 - val_loss: 1568.6427 - val_salida_clase_accuracy: 0.6665 - val_salidas_continuas_mae: 22.9895 - learning_rate: 5.0000e-04
# Epoch 8/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1424.8993 - salida_clase_accuracy: 0.6574 - salidas_continuas_mae: 22.3224 - val_loss: 1089.8235 - val_salida_clase_accuracy: 0.6617 - val_salidas_continuas_mae: 20.9821 - learning_rate: 5.0000e-04
# Epoch 9/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 963.6031 - salida_clase_accuracy: 0.6694 - salidas_continuas_mae: 19.9499 - val_loss: 807.1307 - val_salida_clase_accuracy: 0.6426 - val_salidas_continuas_mae: 18.7051 - learning_rate: 5.0000e-04
# Epoch 10/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 751.8737 - salida_clase_accuracy: 0.6622 - salidas_continuas_mae: 18.1144 - val_loss: 691.3212 - val_salida_clase_accuracy: 0.6783 - val_salidas_continuas_mae: 17.4706 - learning_rate: 5.0000e-04
# Epoch 11/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 643.0413 - salida_clase_accuracy: 0.6698 - salidas_continuas_mae: 16.7794 - val_loss: 619.9745 - val_salida_clase_accuracy: 0.6564 - val_salidas_continuas_mae: 16.2661 - learning_rate: 5.0000e-04
# Epoch 12/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 577.5131 - salida_clase_accuracy: 0.6844 - salidas_continuas_mae: 15.8106 - val_loss: 565.1724 - val_salida_clase_accuracy: 0.6877 - val_salidas_continuas_mae: 15.5033 - learning_rate: 5.0000e-04
# Epoch 13/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 526.3179 - salida_clase_accuracy: 0.6849 - salidas_continuas_mae: 15.0599 - val_loss: 538.5313 - val_salida_clase_accuracy: 0.6917 - val_salidas_continuas_mae: 15.1788 - learning_rate: 5.0000e-04
# Epoch 14/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 499.9290 - salida_clase_accuracy: 0.6860 - salidas_continuas_mae: 14.6175 - val_loss: 500.5262 - val_salida_clase_accuracy: 0.6944 - val_salidas_continuas_mae: 14.4905 - learning_rate: 5.0000e-04
# Epoch 15/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 471.8796 - salida_clase_accuracy: 0.6915 - salidas_continuas_mae: 14.0637 - val_loss: 475.8987 - val_salida_clase_accuracy: 0.7066 - val_salidas_continuas_mae: 14.0290 - learning_rate: 5.0000e-04
# Epoch 16/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 446.0371 - salida_clase_accuracy: 0.6957 - salidas_continuas_mae: 13.6053 - val_loss: 452.6717 - val_salida_clase_accuracy: 0.7138 - val_salidas_continuas_mae: 13.5761 - learning_rate: 5.0000e-04
# Epoch 17/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 428.7988 - salida_clase_accuracy: 0.7112 - salidas_continuas_mae: 13.2257 - val_loss: 436.5645 - val_salida_clase_accuracy: 0.7257 - val_salidas_continuas_mae: 13.2655 - learning_rate: 5.0000e-04
# Epoch 18/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 411.3430 - salida_clase_accuracy: 0.7149 - salidas_continuas_mae: 12.9418 - val_loss: 419.6769 - val_salida_clase_accuracy: 0.7246 - val_salidas_continuas_mae: 12.8712 - learning_rate: 5.0000e-04
# Epoch 19/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 392.2196 - salida_clase_accuracy: 0.7182 - salidas_continuas_mae: 12.4870 - val_loss: 413.5829 - val_salida_clase_accuracy: 0.7209 - val_salidas_continuas_mae: 12.8750 - learning_rate: 5.0000e-04
# Epoch 20/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 382.6478 - salida_clase_accuracy: 0.7311 - salidas_continuas_mae: 12.3473 - val_loss: 393.9200 - val_salida_clase_accuracy: 0.7548 - val_salidas_continuas_mae: 12.4429 - learning_rate: 5.0000e-04
# Epoch 21/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 369.3360 - salida_clase_accuracy: 0.7357 - salidas_continuas_mae: 12.0797 - val_loss: 385.0585 - val_salida_clase_accuracy: 0.7412 - val_salidas_continuas_mae: 12.3575 - learning_rate: 5.0000e-04
# Epoch 22/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 366.5587 - salida_clase_accuracy: 0.7377 - salidas_continuas_mae: 12.0105 - val_loss: 372.4822 - val_salida_clase_accuracy: 0.7684 - val_salidas_continuas_mae: 11.9311 - learning_rate: 5.0000e-04
# Epoch 23/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 343.7455 - salida_clase_accuracy: 0.7535 - salidas_continuas_mae: 11.5807 - val_loss: 354.9183 - val_salida_clase_accuracy: 0.7565 - val_salidas_continuas_mae: 11.5840 - learning_rate: 5.0000e-04
# Epoch 24/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 334.1844 - salida_clase_accuracy: 0.7575 - salidas_continuas_mae: 11.3350 - val_loss: 355.3773 - val_salida_clase_accuracy: 0.7637 - val_salidas_continuas_mae: 11.6447 - learning_rate: 5.0000e-04
# Epoch 25/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 329.6127 - salida_clase_accuracy: 0.7604 - salidas_continuas_mae: 11.2344 - val_loss: 342.4359 - val_salida_clase_accuracy: 0.7427 - val_salidas_continuas_mae: 11.2134 - learning_rate: 5.0000e-04
# Epoch 26/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 319.3289 - salida_clase_accuracy: 0.7559 - salidas_continuas_mae: 11.0242 - val_loss: 331.3857 - val_salida_clase_accuracy: 0.7299 - val_salidas_continuas_mae: 11.0931 - learning_rate: 5.0000e-04
# Epoch 27/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 308.5761 - salida_clase_accuracy: 0.7564 - salidas_continuas_mae: 10.7825 - val_loss: 327.1611 - val_salida_clase_accuracy: 0.7690 - val_salidas_continuas_mae: 11.0092 - learning_rate: 5.0000e-04
# Epoch 28/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 298.9622 - salida_clase_accuracy: 0.7565 - salidas_continuas_mae: 10.6268 - val_loss: 323.1861 - val_salida_clase_accuracy: 0.7680 - val_salidas_continuas_mae: 11.0018 - learning_rate: 5.0000e-04
# Epoch 29/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 297.0048 - salida_clase_accuracy: 0.7644 - salidas_continuas_mae: 10.5025 - val_loss: 312.6737 - val_salida_clase_accuracy: 0.7677 - val_salidas_continuas_mae: 10.7115 - learning_rate: 5.0000e-04
# Epoch 30/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 293.1036 - salida_clase_accuracy: 0.7650 - salidas_continuas_mae: 10.4612 - val_loss: 306.5004 - val_salida_clase_accuracy: 0.7744 - val_salidas_continuas_mae: 10.5915 - learning_rate: 5.0000e-04
# Epoch 31/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 284.3112 - salida_clase_accuracy: 0.7664 - salidas_continuas_mae: 10.1944 - val_loss: 309.0992 - val_salida_clase_accuracy: 0.7712 - val_salidas_continuas_mae: 10.6596 - learning_rate: 5.0000e-04
# Epoch 32/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 274.1769 - salida_clase_accuracy: 0.7677 - salidas_continuas_mae: 10.0549 - val_loss: 296.0343 - val_salida_clase_accuracy: 0.7779 - val_salidas_continuas_mae: 10.3690 - learning_rate: 5.0000e-04
# Epoch 33/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 272.2480 - salida_clase_accuracy: 0.7641 - salidas_continuas_mae: 9.9709 - val_loss: 292.5086 - val_salida_clase_accuracy: 0.7893 - val_salidas_continuas_mae: 10.2909 - learning_rate: 5.0000e-04
# Epoch 34/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 268.0276 - salida_clase_accuracy: 0.7667 - salidas_continuas_mae: 9.8915 - val_loss: 286.7661 - val_salida_clase_accuracy: 0.7540 - val_salidas_continuas_mae: 10.1352 - learning_rate: 5.0000e-04
# Epoch 35/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 257.8260 - salida_clase_accuracy: 0.7712 - salidas_continuas_mae: 9.6615 - val_loss: 278.6373 - val_salida_clase_accuracy: 0.7891 - val_salidas_continuas_mae: 9.9293 - learning_rate: 5.0000e-04
# Epoch 36/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 251.0174 - salida_clase_accuracy: 0.7788 - salidas_continuas_mae: 9.5068 - val_loss: 276.6434 - val_salida_clase_accuracy: 0.7650 - val_salidas_continuas_mae: 9.9125 - learning_rate: 5.0000e-04
# Epoch 37/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 243.8912 - salida_clase_accuracy: 0.7829 - salidas_continuas_mae: 9.4064 - val_loss: 273.3404 - val_salida_clase_accuracy: 0.7805 - val_salidas_continuas_mae: 9.8248 - learning_rate: 5.0000e-04
# Epoch 38/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 238.3222 - salida_clase_accuracy: 0.7768 - salidas_continuas_mae: 9.2649 - val_loss: 264.9062 - val_salida_clase_accuracy: 0.7545 - val_salidas_continuas_mae: 9.5696 - learning_rate: 5.0000e-04
# Epoch 39/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 234.3829 - salida_clase_accuracy: 0.7801 - salidas_continuas_mae: 9.1814 - val_loss: 262.4197 - val_salida_clase_accuracy: 0.7751 - val_salidas_continuas_mae: 9.5525 - learning_rate: 5.0000e-04
# Epoch 40/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 231.8361 - salida_clase_accuracy: 0.7767 - salidas_continuas_mae: 9.0631 - val_loss: 256.5025 - val_salida_clase_accuracy: 0.7701 - val_salidas_continuas_mae: 9.3369 - learning_rate: 5.0000e-04
# Epoch 41/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 238.3457 - salida_clase_accuracy: 0.7840 - salidas_continuas_mae: 9.0993 - val_loss: 253.2473 - val_salida_clase_accuracy: 0.7901 - val_salidas_continuas_mae: 9.2992 - learning_rate: 5.0000e-04
# Epoch 42/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 225.2833 - salida_clase_accuracy: 0.7866 - salidas_continuas_mae: 8.9118 - val_loss: 249.9377 - val_salida_clase_accuracy: 0.8027 - val_salidas_continuas_mae: 9.2151 - learning_rate: 5.0000e-04
# Epoch 43/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 227.5233 - salida_clase_accuracy: 0.7895 - salidas_continuas_mae: 8.9289 - val_loss: 245.2872 - val_salida_clase_accuracy: 0.7890 - val_salidas_continuas_mae: 9.1161 - learning_rate: 5.0000e-04
# Epoch 44/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 220.2166 - salida_clase_accuracy: 0.7865 - salidas_continuas_mae: 8.7903 - val_loss: 250.9088 - val_salida_clase_accuracy: 0.7926 - val_salidas_continuas_mae: 9.2008 - learning_rate: 5.0000e-04
# Epoch 45/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 216.0008 - salida_clase_accuracy: 0.7897 - salidas_continuas_mae: 8.6893 - val_loss: 248.6000 - val_salida_clase_accuracy: 0.7755 - val_salidas_continuas_mae: 9.3114 - learning_rate: 5.0000e-04
# Epoch 46/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 214.5956 - salida_clase_accuracy: 0.7928 - salidas_continuas_mae: 8.7024 - val_loss: 236.0469 - val_salida_clase_accuracy: 0.7613 - val_salidas_continuas_mae: 8.8288 - learning_rate: 5.0000e-04
# Epoch 47/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 216.8304 - salida_clase_accuracy: 0.7882 - salidas_continuas_mae: 8.6350 - val_loss: 234.9787 - val_salida_clase_accuracy: 0.8014 - val_salidas_continuas_mae: 8.7375 - learning_rate: 5.0000e-04
# Epoch 48/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 210.8556 - salida_clase_accuracy: 0.7888 - salidas_continuas_mae: 8.5304 - val_loss: 236.2199 - val_salida_clase_accuracy: 0.7904 - val_salidas_continuas_mae: 8.9280 - learning_rate: 5.0000e-04
# Epoch 49/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 208.2632 - salida_clase_accuracy: 0.7930 - salidas_continuas_mae: 8.4608 - val_loss: 230.5873 - val_salida_clase_accuracy: 0.8030 - val_salidas_continuas_mae: 8.7011 - learning_rate: 5.0000e-04
# Epoch 50/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 208.6877 - salida_clase_accuracy: 0.7967 - salidas_continuas_mae: 8.4363 - val_loss: 237.7602 - val_salida_clase_accuracy: 0.7958 - val_salidas_continuas_mae: 8.8796 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 223.9931 - salida_clase_accuracy: 0.8043 - salidas_continuas_mae: 8.6273
# Fold 3: Loss=222.5345458984375, MAE=8.60242748260498, Accuracy=0.8042395710945129
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Entrenando fold 4...
# Epoch 1/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 21796.8652 - salida_clase_accuracy: 0.2252 - salidas_continuas_mae: 88.0070 - val_loss: 7151.0708 - val_salida_clase_accuracy: 0.2645 - val_salidas_continuas_mae: 48.1321 - learning_rate: 5.0000e-04
# Epoch 2/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 6787.3462 - salida_clase_accuracy: 0.3276 - salidas_continuas_mae: 45.5492 - val_loss: 5367.3667 - val_salida_clase_accuracy: 0.4489 - val_salidas_continuas_mae: 40.1839 - learning_rate: 5.0000e-04
# Epoch 3/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5335.0195 - salida_clase_accuracy: 0.4286 - salidas_continuas_mae: 39.3782 - val_loss: 4824.3584 - val_salida_clase_accuracy: 0.4333 - val_salidas_continuas_mae: 37.4378 - learning_rate: 5.0000e-04
# Epoch 4/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4889.3721 - salida_clase_accuracy: 0.3956 - salidas_continuas_mae: 36.8243 - val_loss: 4255.4375 - val_salida_clase_accuracy: 0.4132 - val_salidas_continuas_mae: 34.6175 - learning_rate: 5.0000e-04
# Epoch 5/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4252.5044 - salida_clase_accuracy: 0.4632 - salidas_continuas_mae: 34.1564 - val_loss: 3468.7793 - val_salida_clase_accuracy: 0.5089 - val_salidas_continuas_mae: 31.5857 - learning_rate: 5.0000e-04
# Epoch 6/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3221.4697 - salida_clase_accuracy: 0.5012 - salidas_continuas_mae: 30.6998 - val_loss: 2685.9805 - val_salida_clase_accuracy: 0.5032 - val_salidas_continuas_mae: 29.2110 - learning_rate: 5.0000e-04
# Epoch 7/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2484.0852 - salida_clase_accuracy: 0.5043 - salidas_continuas_mae: 28.3835 - val_loss: 1895.8456 - val_salida_clase_accuracy: 0.5663 - val_salidas_continuas_mae: 26.2534 - learning_rate: 5.0000e-04
# Epoch 8/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1758.9261 - salida_clase_accuracy: 0.5739 - salidas_continuas_mae: 25.5738 - val_loss: 1341.1176 - val_salida_clase_accuracy: 0.5886 - val_salidas_continuas_mae: 23.1237 - learning_rate: 5.0000e-04
# Epoch 9/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1178.9915 - salida_clase_accuracy: 0.6064 - salidas_continuas_mae: 22.1737 - val_loss: 995.3450 - val_salida_clase_accuracy: 0.6095 - val_salidas_continuas_mae: 20.7960 - learning_rate: 5.0000e-04
# Epoch 10/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 917.7256 - salida_clase_accuracy: 0.6262 - salidas_continuas_mae: 20.1656 - val_loss: 815.2070 - val_salida_clase_accuracy: 0.6162 - val_salidas_continuas_mae: 19.0111 - learning_rate: 5.0000e-04
# Epoch 11/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 759.7222 - salida_clase_accuracy: 0.6436 - salidas_continuas_mae: 18.4902 - val_loss: 710.3543 - val_salida_clase_accuracy: 0.6323 - val_salidas_continuas_mae: 17.7134 - learning_rate: 5.0000e-04
# Epoch 12/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 665.6614 - salida_clase_accuracy: 0.6520 - salidas_continuas_mae: 17.1346 - val_loss: 639.6537 - val_salida_clase_accuracy: 0.6529 - val_salidas_continuas_mae: 16.5807 - learning_rate: 5.0000e-04
# Epoch 13/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 607.9550 - salida_clase_accuracy: 0.6556 - salidas_continuas_mae: 16.2374 - val_loss: 588.6871 - val_salida_clase_accuracy: 0.6646 - val_salidas_continuas_mae: 15.7605 - learning_rate: 5.0000e-04
# Epoch 14/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 561.8629 - salida_clase_accuracy: 0.6698 - salidas_continuas_mae: 15.4530 - val_loss: 553.8986 - val_salida_clase_accuracy: 0.6216 - val_salidas_continuas_mae: 15.1982 - learning_rate: 5.0000e-04
# Epoch 15/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 511.7560 - salida_clase_accuracy: 0.6769 - salidas_continuas_mae: 14.6103 - val_loss: 517.5220 - val_salida_clase_accuracy: 0.6871 - val_salidas_continuas_mae: 14.5511 - learning_rate: 5.0000e-04
# Epoch 16/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 487.8275 - salida_clase_accuracy: 0.6956 - salidas_continuas_mae: 14.1589 - val_loss: 491.6799 - val_salida_clase_accuracy: 0.6822 - val_salidas_continuas_mae: 14.1039 - learning_rate: 5.0000e-04
# Epoch 17/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 457.4891 - salida_clase_accuracy: 0.7104 - salidas_continuas_mae: 13.6389 - val_loss: 468.2618 - val_salida_clase_accuracy: 0.7213 - val_salidas_continuas_mae: 13.5827 - learning_rate: 5.0000e-04
# Epoch 18/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 442.4442 - salida_clase_accuracy: 0.7133 - salidas_continuas_mae: 13.3132 - val_loss: 450.6544 - val_salida_clase_accuracy: 0.7206 - val_salidas_continuas_mae: 13.3032 - learning_rate: 5.0000e-04
# Epoch 19/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 423.0189 - salida_clase_accuracy: 0.7206 - salidas_continuas_mae: 12.9497 - val_loss: 436.7244 - val_salida_clase_accuracy: 0.7197 - val_salidas_continuas_mae: 13.1476 - learning_rate: 5.0000e-04
# Epoch 20/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 406.9345 - salida_clase_accuracy: 0.7235 - salidas_continuas_mae: 12.6238 - val_loss: 418.3987 - val_salida_clase_accuracy: 0.7106 - val_salidas_continuas_mae: 12.7553 - learning_rate: 5.0000e-04
# Epoch 21/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 391.8721 - salida_clase_accuracy: 0.7252 - salidas_continuas_mae: 12.3028 - val_loss: 404.8276 - val_salida_clase_accuracy: 0.7302 - val_salidas_continuas_mae: 12.4383 - learning_rate: 5.0000e-04
# Epoch 22/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 379.0491 - salida_clase_accuracy: 0.7318 - salidas_continuas_mae: 12.0582 - val_loss: 391.8834 - val_salida_clase_accuracy: 0.7412 - val_salidas_continuas_mae: 12.1200 - learning_rate: 5.0000e-04
# Epoch 23/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 368.3064 - salida_clase_accuracy: 0.7365 - salidas_continuas_mae: 11.8348 - val_loss: 380.1162 - val_salida_clase_accuracy: 0.7403 - val_salidas_continuas_mae: 11.8729 - learning_rate: 5.0000e-04
# Epoch 24/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 355.2797 - salida_clase_accuracy: 0.7432 - salidas_continuas_mae: 11.5957 - val_loss: 365.7152 - val_salida_clase_accuracy: 0.7267 - val_salidas_continuas_mae: 11.5571 - learning_rate: 5.0000e-04
# Epoch 25/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 338.8149 - salida_clase_accuracy: 0.7424 - salidas_continuas_mae: 11.2268 - val_loss: 360.7953 - val_salida_clase_accuracy: 0.7449 - val_salidas_continuas_mae: 11.5133 - learning_rate: 5.0000e-04
# Epoch 26/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 336.6618 - salida_clase_accuracy: 0.7488 - salidas_continuas_mae: 11.1306 - val_loss: 350.2922 - val_salida_clase_accuracy: 0.7647 - val_salidas_continuas_mae: 11.2378 - learning_rate: 5.0000e-04
# Epoch 27/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 330.1992 - salida_clase_accuracy: 0.7477 - salidas_continuas_mae: 10.9814 - val_loss: 345.4742 - val_salida_clase_accuracy: 0.7128 - val_salidas_continuas_mae: 11.1168 - learning_rate: 5.0000e-04
# Epoch 28/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 321.9325 - salida_clase_accuracy: 0.7506 - salidas_continuas_mae: 10.8428 - val_loss: 336.1091 - val_salida_clase_accuracy: 0.7312 - val_salidas_continuas_mae: 10.8776 - learning_rate: 5.0000e-04
# Epoch 29/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 316.2786 - salida_clase_accuracy: 0.7562 - salidas_continuas_mae: 10.7500 - val_loss: 330.9207 - val_salida_clase_accuracy: 0.7326 - val_salidas_continuas_mae: 10.8929 - learning_rate: 5.0000e-04
# Epoch 30/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 307.8212 - salida_clase_accuracy: 0.7588 - salidas_continuas_mae: 10.5125 - val_loss: 327.5711 - val_salida_clase_accuracy: 0.7272 - val_salidas_continuas_mae: 10.7571 - learning_rate: 5.0000e-04
# Epoch 31/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 304.8520 - salida_clase_accuracy: 0.7551 - salidas_continuas_mae: 10.4884 - val_loss: 320.4378 - val_salida_clase_accuracy: 0.7751 - val_salidas_continuas_mae: 10.6065 - learning_rate: 5.0000e-04
# Epoch 32/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 297.0789 - salida_clase_accuracy: 0.7619 - salidas_continuas_mae: 10.3192 - val_loss: 321.4794 - val_salida_clase_accuracy: 0.7639 - val_salidas_continuas_mae: 10.6095 - learning_rate: 5.0000e-04
# Epoch 33/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 299.6948 - salida_clase_accuracy: 0.7601 - salidas_continuas_mae: 10.2598 - val_loss: 309.9776 - val_salida_clase_accuracy: 0.7516 - val_salidas_continuas_mae: 10.4194 - learning_rate: 5.0000e-04
# Epoch 34/50
# ...
# Epoch 41/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 246.3752 - salida_clase_accuracy: 0.7890 - salidas_continuas_mae: 9.2337 - val_loss: 270.7542 - val_salida_clase_accuracy: 0.7957 - val_salidas_continuas_mae: 9.5411 - learning_rate: 5.0000e-04
# Epoch 42/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 244.4160 - salida_clase_accuracy: 0.7880 - salidas_continuas_mae: 9.2175 - val_loss: 263.6736 - val_salida_clase_accuracy: 0.7869 - val_salidas_continuas_mae: 9.4359 - learning_rate: 5.0000e-04
# Epoch 43/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 240.2079 - salida_clase_accuracy: 0.7916 - salidas_continuas_mae: 9.1627 - val_loss: 264.1789 - val_salida_clase_accuracy: 0.7848 - val_salidas_continuas_mae: 9.4195 - learning_rate: 5.0000e-04
# Epoch 44/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 239.7544 - salida_clase_accuracy: 0.7923 - salidas_continuas_mae: 9.1060 - val_loss: 262.7879 - val_salida_clase_accuracy: 0.7688 - val_salidas_continuas_mae: 9.4528 - learning_rate: 5.0000e-04
# Epoch 45/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 233.2012 - salida_clase_accuracy: 0.7932 - salidas_continuas_mae: 8.9431 - val_loss: 259.4023 - val_salida_clase_accuracy: 0.7572 - val_salidas_continuas_mae: 9.2793 - learning_rate: 5.0000e-04
# Epoch 46/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 229.6666 - salida_clase_accuracy: 0.7895 - salidas_continuas_mae: 8.8632 - val_loss: 252.7501 - val_salida_clase_accuracy: 0.8052 - val_salidas_continuas_mae: 9.1905 - learning_rate: 5.0000e-04
# Epoch 47/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 221.9361 - salida_clase_accuracy: 0.7949 - salidas_continuas_mae: 8.7095 - val_loss: 247.7626 - val_salida_clase_accuracy: 0.7834 - val_salidas_continuas_mae: 9.0901 - learning_rate: 5.0000e-04
# Epoch 48/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 223.7148 - salida_clase_accuracy: 0.7931 - salidas_continuas_mae: 8.7271 - val_loss: 241.5719 - val_salida_clase_accuracy: 0.8035 - val_salidas_continuas_mae: 8.8484 - learning_rate: 5.0000e-04
# Epoch 49/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 218.0754 - salida_clase_accuracy: 0.7912 - salidas_continuas_mae: 8.6109 - val_loss: 239.1445 - val_salida_clase_accuracy: 0.7880 - val_salidas_continuas_mae: 8.7642 - learning_rate: 5.0000e-04
# Epoch 50/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 221.5800 - salida_clase_accuracy: 0.7979 - salidas_continuas_mae: 8.5978 - val_loss: 244.8995 - val_salida_clase_accuracy: 0.7775 - val_salidas_continuas_mae: 8.9665 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 235.4957 - salida_clase_accuracy: 0.7952 - salidas_continuas_mae: 8.7074
# Fold 4: Loss=230.4626922607422, MAE=8.65499210357666, Accuracy=0.7950453162193298
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Entrenando fold 5...
# Epoch 1/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 22136.5430 - salida_clase_accuracy: 0.2485 - salidas_continuas_mae: 87.6535 - val_loss: 7558.6309 - val_salida_clase_accuracy: 0.3610 - val_salidas_continuas_mae: 48.7858 - learning_rate: 5.0000e-04
# Epoch 2/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 6795.5967 - salida_clase_accuracy: 0.4159 - salidas_continuas_mae: 45.6527 - val_loss: 5275.8628 - val_salida_clase_accuracy: 0.4620 - val_salidas_continuas_mae: 38.6048 - learning_rate: 5.0000e-04
# Epoch 3/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 5245.3398 - salida_clase_accuracy: 0.4695 - salidas_continuas_mae: 38.0431 - val_loss: 4577.2568 - val_salida_clase_accuracy: 0.5054 - val_salidas_continuas_mae: 35.2368 - learning_rate: 5.0000e-04
# Epoch 4/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4614.6655 - salida_clase_accuracy: 0.5160 - salidas_continuas_mae: 35.1536 - val_loss: 3917.4863 - val_salida_clase_accuracy: 0.5461 - val_salidas_continuas_mae: 33.1167 - learning_rate: 5.0000e-04
# Epoch 5/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 3845.2029 - salida_clase_accuracy: 0.5561 - salidas_continuas_mae: 32.5998 - val_loss: 2920.4443 - val_salida_clase_accuracy: 0.5404 - val_salidas_continuas_mae: 29.9989 - learning_rate: 5.0000e-04
# Epoch 6/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 2761.8574 - salida_clase_accuracy: 0.5656 - salidas_continuas_mae: 29.4498 - val_loss: 2050.3633 - val_salida_clase_accuracy: 0.5995 - val_salidas_continuas_mae: 26.6971 - learning_rate: 5.0000e-04
# Epoch 7/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1930.9351 - salida_clase_accuracy: 0.5835 - salidas_continuas_mae: 26.2899 - val_loss: 1419.3372 - val_salida_clase_accuracy: 0.6394 - val_salidas_continuas_mae: 23.6243 - learning_rate: 5.0000e-04
# Epoch 8/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1306.3447 - salida_clase_accuracy: 0.6421 - salidas_continuas_mae: 23.1647 - val_loss: 1037.1744 - val_salida_clase_accuracy: 0.6509 - val_salidas_continuas_mae: 21.2035 - learning_rate: 5.0000e-04
# Epoch 9/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 970.2314 - salida_clase_accuracy: 0.6520 - salidas_continuas_mae: 20.7369 - val_loss: 840.9296 - val_salida_clase_accuracy: 0.6501 - val_salidas_continuas_mae: 19.2201 - learning_rate: 5.0000e-04
# Epoch 10/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 799.4505 - salida_clase_accuracy: 0.6592 - salidas_continuas_mae: 18.9714 - val_loss: 724.5748 - val_salida_clase_accuracy: 0.6718 - val_salidas_continuas_mae: 17.6822 - learning_rate: 5.0000e-04
# Epoch 11/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 687.6862 - salida_clase_accuracy: 0.6781 - salidas_continuas_mae: 17.4486 - val_loss: 651.4514 - val_salida_clase_accuracy: 0.7087 - val_salidas_continuas_mae: 16.6777 - learning_rate: 5.0000e-04
# Epoch 12/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 611.4276 - salida_clase_accuracy: 0.6995 - salidas_continuas_mae: 16.2891 - val_loss: 579.5377 - val_salida_clase_accuracy: 0.7034 - val_salidas_continuas_mae: 15.5855 - learning_rate: 5.0000e-04
# Epoch 13/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 567.2247 - salida_clase_accuracy: 0.7119 - salidas_continuas_mae: 15.5060 - val_loss: 544.3928 - val_salida_clase_accuracy: 0.6834 - val_salidas_continuas_mae: 15.0189 - learning_rate: 5.0000e-04
# Epoch 14/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 523.7555 - salida_clase_accuracy: 0.7187 - salidas_continuas_mae: 14.7871 - val_loss: 510.2128 - val_salida_clase_accuracy: 0.7045 - val_salidas_continuas_mae: 14.5245 - learning_rate: 5.0000e-04
# Epoch 15/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 489.4135 - salida_clase_accuracy: 0.7167 - salidas_continuas_mae: 14.2296 - val_loss: 485.1831 - val_salida_clase_accuracy: 0.7292 - val_salidas_continuas_mae: 14.0558 - learning_rate: 5.0000e-04
# Epoch 16/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 462.6536 - salida_clase_accuracy: 0.7386 - salidas_continuas_mae: 13.7451 - val_loss: 463.1057 - val_salida_clase_accuracy: 0.7126 - val_salidas_continuas_mae: 13.6340 - learning_rate: 5.0000e-04
# Epoch 17/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 440.1886 - salida_clase_accuracy: 0.7345 - salidas_continuas_mae: 13.3451 - val_loss: 436.1228 - val_salida_clase_accuracy: 0.7216 - val_salidas_continuas_mae: 13.0403 - learning_rate: 5.0000e-04
# Epoch 18/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 419.3431 - salida_clase_accuracy: 0.7391 - salidas_continuas_mae: 13.0000 - val_loss: 417.2239 - val_salida_clase_accuracy: 0.7168 - val_salidas_continuas_mae: 12.7429 - learning_rate: 5.0000e-04
# Epoch 19/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 411.0481 - salida_clase_accuracy: 0.7432 - salidas_continuas_mae: 12.6854 - val_loss: 407.8997 - val_salida_clase_accuracy: 0.7441 - val_salidas_continuas_mae: 12.5743 - learning_rate: 5.0000e-04
# Epoch 20/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 389.7317 - salida_clase_accuracy: 0.7511 - salidas_continuas_mae: 12.3534 - val_loss: 391.7417 - val_salida_clase_accuracy: 0.7599 - val_salidas_continuas_mae: 12.2178 - learning_rate: 5.0000e-04
# Epoch 21/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 383.2398 - salida_clase_accuracy: 0.7522 - salidas_continuas_mae: 12.1702 - val_loss: 377.6175 - val_salida_clase_accuracy: 0.7514 - val_salidas_continuas_mae: 11.9215 - learning_rate: 5.0000e-04
# Epoch 22/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 365.1193 - salida_clase_accuracy: 0.7574 - salidas_continuas_mae: 11.8046 - val_loss: 366.6000 - val_salida_clase_accuracy: 0.7615 - val_salidas_continuas_mae: 11.6866 - learning_rate: 5.0000e-04
# Epoch 23/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 350.1536 - salida_clase_accuracy: 0.7671 - salidas_continuas_mae: 11.5491 - val_loss: 360.7723 - val_salida_clase_accuracy: 0.7640 - val_salidas_continuas_mae: 11.5907 - learning_rate: 5.0000e-04
# Epoch 24/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 347.3965 - salida_clase_accuracy: 0.7689 - salidas_continuas_mae: 11.4197 - val_loss: 353.2963 - val_salida_clase_accuracy: 0.7779 - val_salidas_continuas_mae: 11.3288 - learning_rate: 5.0000e-04
# Epoch 25/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 329.8604 - salida_clase_accuracy: 0.7709 - salidas_continuas_mae: 11.1389 - val_loss: 337.6466 - val_salida_clase_accuracy: 0.7776 - val_salidas_continuas_mae: 11.0960 - learning_rate: 5.0000e-04
# Epoch 26/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 314.7599 - salida_clase_accuracy: 0.7791 - salidas_continuas_mae: 10.8751 - val_loss: 329.1789 - val_salida_clase_accuracy: 0.7832 - val_salidas_continuas_mae: 10.8610 - learning_rate: 5.0000e-04
# Epoch 27/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 312.7799 - salida_clase_accuracy: 0.7811 - salidas_continuas_mae: 10.7837 - val_loss: 328.8305 - val_salida_clase_accuracy: 0.7950 - val_salidas_continuas_mae: 10.9088 - learning_rate: 5.0000e-04
# Epoch 28/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 306.2987 - salida_clase_accuracy: 0.7851 - salidas_continuas_mae: 10.6476 - val_loss: 320.4836 - val_salida_clase_accuracy: 0.7361 - val_salidas_continuas_mae: 10.7954 - learning_rate: 5.0000e-04
# Epoch 29/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 299.0846 - salida_clase_accuracy: 0.7775 - salidas_continuas_mae: 10.5179 - val_loss: 314.5482 - val_salida_clase_accuracy: 0.7770 - val_salidas_continuas_mae: 10.7288 - learning_rate: 5.0000e-04
# Epoch 30/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 298.2825 - salida_clase_accuracy: 0.7873 - salidas_continuas_mae: 10.5465 - val_loss: 307.8708 - val_salida_clase_accuracy: 0.7854 - val_salidas_continuas_mae: 10.4409 - learning_rate: 5.0000e-04
# Epoch 31/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 281.7705 - salida_clase_accuracy: 0.7973 - salidas_continuas_mae: 10.1460 - val_loss: 295.5160 - val_salida_clase_accuracy: 0.7794 - val_salidas_continuas_mae: 10.1298 - learning_rate: 5.0000e-04
# Epoch 32/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 283.7679 - salida_clase_accuracy: 0.7832 - salidas_continuas_mae: 10.1575 - val_loss: 294.6227 - val_salida_clase_accuracy: 0.7937 - val_salidas_continuas_mae: 10.1383 - learning_rate: 5.0000e-04
# Epoch 33/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 271.9082 - salida_clase_accuracy: 0.7958 - salidas_continuas_mae: 9.9485 - val_loss: 291.4567 - val_salida_clase_accuracy: 0.7701 - val_salidas_continuas_mae: 10.1332 - learning_rate: 5.0000e-04
# Epoch 34/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 272.9620 - salida_clase_accuracy: 0.7872 - salidas_continuas_mae: 9.8929 - val_loss: 285.2883 - val_salida_clase_accuracy: 0.7789 - val_salidas_continuas_mae: 9.9212 - learning_rate: 5.0000e-04
# Epoch 35/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 265.2547 - salida_clase_accuracy: 0.7976 - salidas_continuas_mae: 9.7895 - val_loss: 281.7874 - val_salida_clase_accuracy: 0.7936 - val_salidas_continuas_mae: 9.9666 - learning_rate: 5.0000e-04
# Epoch 36/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 265.5994 - salida_clase_accuracy: 0.7903 - salidas_continuas_mae: 9.7361 - val_loss: 280.8279 - val_salida_clase_accuracy: 0.7505 - val_salidas_continuas_mae: 9.9210 - learning_rate: 5.0000e-04
# Epoch 37/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 258.0959 - salida_clase_accuracy: 0.7909 - salidas_continuas_mae: 9.6641 - val_loss: 277.6743 - val_salida_clase_accuracy: 0.7684 - val_salidas_continuas_mae: 9.8610 - learning_rate: 5.0000e-04
# Epoch 38/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 259.9866 - salida_clase_accuracy: 0.8027 - salidas_continuas_mae: 9.5808 - val_loss: 276.3704 - val_salida_clase_accuracy: 0.7770 - val_salidas_continuas_mae: 9.8648 - learning_rate: 5.0000e-04
# Epoch 39/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 248.8629 - salida_clase_accuracy: 0.7966 - salidas_continuas_mae: 9.4015 - val_loss: 269.5515 - val_salida_clase_accuracy: 0.8092 - val_salidas_continuas_mae: 9.6267 - learning_rate: 5.0000e-04
# Epoch 40/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 250.0453 - salida_clase_accuracy: 0.8097 - salidas_continuas_mae: 9.3953 - val_loss: 262.4859 - val_salida_clase_accuracy: 0.7944 - val_salidas_continuas_mae: 9.5288 - learning_rate: 5.0000e-04
# Epoch 41/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 240.6609 - salida_clase_accuracy: 0.8093 - salidas_continuas_mae: 9.2422 - val_loss: 263.5856 - val_salida_clase_accuracy: 0.7913 - val_salidas_continuas_mae: 9.5738 - learning_rate: 5.0000e-04
# Epoch 42/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 240.9505 - salida_clase_accuracy: 0.8046 - salidas_continuas_mae: 9.1877 - val_loss: 258.5329 - val_salida_clase_accuracy: 0.8040 - val_salidas_continuas_mae: 9.3937 - learning_rate: 5.0000e-04
# Epoch 43/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 230.9800 - salida_clase_accuracy: 0.8064 - salidas_continuas_mae: 9.0727 - val_loss: 252.1800 - val_salida_clase_accuracy: 0.8048 - val_salidas_continuas_mae: 9.1455 - learning_rate: 5.0000e-04
# Epoch 44/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 236.6409 - salida_clase_accuracy: 0.8056 - salidas_continuas_mae: 9.0891 - val_loss: 255.8716 - val_salida_clase_accuracy: 0.7966 - val_salidas_continuas_mae: 9.3131 - learning_rate: 5.0000e-04
# Epoch 45/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 230.3006 - salida_clase_accuracy: 0.8151 - salidas_continuas_mae: 8.9860 - val_loss: 247.7578 - val_salida_clase_accuracy: 0.7960 - val_salidas_continuas_mae: 9.1962 - learning_rate: 5.0000e-04
# Epoch 46/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 228.2129 - salida_clase_accuracy: 0.8069 - salidas_continuas_mae: 8.9106 - val_loss: 245.6758 - val_salida_clase_accuracy: 0.7989 - val_salidas_continuas_mae: 8.9724 - learning_rate: 5.0000e-04
# Epoch 47/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 227.4078 - salida_clase_accuracy: 0.8104 - salidas_continuas_mae: 8.8609 - val_loss: 248.7942 - val_salida_clase_accuracy: 0.7925 - val_salidas_continuas_mae: 9.0866 - learning_rate: 5.0000e-04
# Epoch 48/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 227.1710 - salida_clase_accuracy: 0.8121 - salidas_continuas_mae: 8.8248 - val_loss: 244.4282 - val_salida_clase_accuracy: 0.7992 - val_salidas_continuas_mae: 8.9391 - learning_rate: 5.0000e-04
# Epoch 49/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 227.9215 - salida_clase_accuracy: 0.8135 - salidas_continuas_mae: 8.8475 - val_loss: 237.0013 - val_salida_clase_accuracy: 0.8177 - val_salidas_continuas_mae: 8.7554 - learning_rate: 5.0000e-04
# Epoch 50/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 216.1813 - salida_clase_accuracy: 0.8167 - salidas_continuas_mae: 8.6271 - val_loss: 240.4398 - val_salida_clase_accuracy: 0.8059 - val_salidas_continuas_mae: 8.8832 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 231.0143 - salida_clase_accuracy: 0.8264 - salidas_continuas_mae: 8.7265
# Fold 5: Loss=228.9031219482422, MAE=8.711241722106934, Accuracy=0.8265866637229919
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 229.89527587890626
# MAE: 8.749189795130642
# MSE: 229.29825792601372
# RMSE: 15.141798836928078
# R^2: 0.9896030872063644
# Accuracy: 0.8041374087333679
# Precisión: 0.806471671079585
# Recall: 0.8041374026305709
# F1-Score: 0.800730524096154
