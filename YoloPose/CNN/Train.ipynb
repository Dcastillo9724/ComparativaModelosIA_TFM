# %%
import joblib
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Cargar datos
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Pose', 'pose_data_images_2.csv')
ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual, 'datos', 'scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')

data = pd.read_csv(ruta_csv)

# Preparar datos
num_keypoints = 17 * 3
X = data.iloc[:, :num_keypoints].values
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

X_train, X_test, y_continuas_train, y_continuas_test, y_clase_train, y_clase_test = train_test_split(
    X, y_continuas, y_clase_encoded, test_size=0.2, random_state=42)

scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

X_train_cnn = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_cnn = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

# Función para crear el modelo con ajustes de hiperparámetros
def create_model(learning_rate=0.001):
    input_layer = Input(shape=(X_train_cnn.shape[1], X_train_cnn.shape[2]))
    x = Conv1D(64, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(input_layer)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Conv1D(64, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Conv1D(32, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Flatten()(x)
    
    salidas_continuas = Dense(6, activation='linear', name='salidas_continuas')(x)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)
    
    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])
    
    optimizer = Adam(learning_rate=learning_rate)
    
    model.compile(optimizer=optimizer,
                  loss={'salidas_continuas': 'mean_squared_error', 'salida_clase': 'sparse_categorical_crossentropy'},
                  metrics={'salidas_continuas': 'mae', 'salida_clase': 'accuracy'})
    
    return model

# Listas para almacenar métricas
all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

# Matrices para almacenar la historia del entrenamiento
n_epochs = 150  # Número de épocas
all_train_loss = np.full((5, n_epochs), np.nan)  
all_val_loss = np.full((5, n_epochs), np.nan)
all_train_accuracy = np.full((5, n_epochs), np.nan)
all_val_accuracy = np.full((5, n_epochs), np.nan)

# Optimización de hiperparámetros y validación cruzada
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

fold_index = 0
for train_index, val_index in kfold.split(X_train_cnn):
    fold_index += 1
    print(f"Entrenando fold {fold_index}...")

    X_train_fold, X_val_fold = X_train_cnn[train_index], X_train_cnn[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas_train[train_index], y_continuas_train[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_train[train_index], y_clase_train[val_index]

    model = create_model(learning_rate=0.0005)  # Ajustar la tasa de aprendizaje aquí
    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold_index}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    # Almacenar la historia del entrenamiento como matrices NumPy
    epochs_completed = len(history.history['loss'])
    all_train_loss[fold_index - 1, :epochs_completed] = history.history['loss']
    all_val_loss[fold_index - 1, :epochs_completed] = history.history['val_loss']
    all_train_accuracy[fold_index - 1, :epochs_completed] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold_index - 1, :epochs_completed] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de prueba
    scores = model.evaluate(X_test_cnn, {'salidas_continuas': y_continuas_test, 'salida_clase': y_clase_test})
    print(f"Fold {fold_index}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_test_cnn)[0]
    mae = mean_absolute_error(y_continuas_test, y_pred_continuas)
    mse = mean_squared_error(y_continuas_test, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_test)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_test_cnn)[1], axis=1)
    precision = precision_score(y_clase_test, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_test, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_test, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_test, y_pred_clase, labels=np.unique(y_clase_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 11728.9365 - salida_clase_accuracy: 0.2574 - salidas_continuas_mae: 89.9450 - val_loss: 10825.9395 - val_salida_clase_accuracy: 0.5328 - val_salidas_continuas_mae: 85.9174 - learning_rate: 5.0000e-04
# Epoch 2/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 6825.9180 - salida_clase_accuracy: 0.5138 - salidas_continuas_mae: 66.6494 - val_loss: 5948.7881 - val_salida_clase_accuracy: 0.5533 - val_salidas_continuas_mae: 62.9094 - learning_rate: 5.0000e-04
# Epoch 3/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 3822.0957 - salida_clase_accuracy: 0.5818 - salidas_continuas_mae: 51.7245 - val_loss: 3479.0500 - val_salida_clase_accuracy: 0.6482 - val_salidas_continuas_mae: 49.0622 - learning_rate: 5.0000e-04
# Epoch 4/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2808.3274 - salida_clase_accuracy: 0.5917 - salidas_continuas_mae: 44.9576 - val_loss: 2822.1189 - val_salida_clase_accuracy: 0.6686 - val_salidas_continuas_mae: 44.1595 - learning_rate: 5.0000e-04
# Epoch 5/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 2497.7417 - salida_clase_accuracy: 0.5944 - salidas_continuas_mae: 42.1713 - val_loss: 2568.3645 - val_salida_clase_accuracy: 0.7255 - val_salidas_continuas_mae: 42.3014 - learning_rate: 5.0000e-04
# Epoch 6/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 2391.7302 - salida_clase_accuracy: 0.6432 - salidas_continuas_mae: 41.2762 - val_loss: 2419.3088 - val_salida_clase_accuracy: 0.7401 - val_salidas_continuas_mae: 41.0580 - learning_rate: 5.0000e-04
# Epoch 7/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2305.3806 - salida_clase_accuracy: 0.6758 - salidas_continuas_mae: 40.1658 - val_loss: 2255.1060 - val_salida_clase_accuracy: 0.7445 - val_salidas_continuas_mae: 39.5263 - learning_rate: 5.0000e-04
# Epoch 8/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2185.1929 - salida_clase_accuracy: 0.6584 - salidas_continuas_mae: 38.9045 - val_loss: 2153.1189 - val_salida_clase_accuracy: 0.7650 - val_salidas_continuas_mae: 38.4368 - learning_rate: 5.0000e-04
# Epoch 9/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 2162.0935 - salida_clase_accuracy: 0.6889 - salidas_continuas_mae: 38.3451 - val_loss: 2086.6616 - val_salida_clase_accuracy: 0.7810 - val_salidas_continuas_mae: 37.4420 - learning_rate: 5.0000e-04
# Epoch 10/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 2038.4993 - salida_clase_accuracy: 0.6892 - salidas_continuas_mae: 36.7888 - val_loss: 2005.5837 - val_salida_clase_accuracy: 0.7810 - val_salidas_continuas_mae: 36.4919 - learning_rate: 5.0000e-04
# Epoch 11/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1953.2100 - salida_clase_accuracy: 0.6871 - salidas_continuas_mae: 35.9594 - val_loss: 1989.9148 - val_salida_clase_accuracy: 0.7635 - val_salidas_continuas_mae: 36.3306 - learning_rate: 5.0000e-04
# Epoch 12/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1923.4285 - salida_clase_accuracy: 0.7265 - salidas_continuas_mae: 35.5045 - val_loss: 1927.1797 - val_salida_clase_accuracy: 0.8058 - val_salidas_continuas_mae: 35.5847 - learning_rate: 5.0000e-04
# Epoch 13/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1893.8782 - salida_clase_accuracy: 0.7315 - salidas_continuas_mae: 34.8567 - val_loss: 1876.7555 - val_salida_clase_accuracy: 0.8175 - val_salidas_continuas_mae: 34.8293 - learning_rate: 5.0000e-04
# Epoch 14/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1827.2697 - salida_clase_accuracy: 0.7344 - salidas_continuas_mae: 33.9236 - val_loss: 1812.9907 - val_salida_clase_accuracy: 0.8248 - val_salidas_continuas_mae: 33.8376 - learning_rate: 5.0000e-04
# Epoch 15/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1810.0975 - salida_clase_accuracy: 0.7529 - salidas_continuas_mae: 33.7254 - val_loss: 1781.9414 - val_salida_clase_accuracy: 0.8307 - val_salidas_continuas_mae: 33.5580 - learning_rate: 5.0000e-04
# Epoch 16/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1802.6488 - salida_clase_accuracy: 0.7589 - salidas_continuas_mae: 33.3858 - val_loss: 1754.8661 - val_salida_clase_accuracy: 0.8423 - val_salidas_continuas_mae: 33.2398 - learning_rate: 5.0000e-04
# Epoch 17/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1769.0167 - salida_clase_accuracy: 0.7631 - salidas_continuas_mae: 33.0340 - val_loss: 1723.7418 - val_salida_clase_accuracy: 0.8423 - val_salidas_continuas_mae: 32.7718 - learning_rate: 5.0000e-04
# Epoch 18/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1666.8876 - salida_clase_accuracy: 0.7500 - salidas_continuas_mae: 31.8570 - val_loss: 1674.4230 - val_salida_clase_accuracy: 0.8453 - val_salidas_continuas_mae: 32.0087 - learning_rate: 5.0000e-04
# Epoch 19/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1615.4294 - salida_clase_accuracy: 0.7826 - salidas_continuas_mae: 31.3263 - val_loss: 1650.2856 - val_salida_clase_accuracy: 0.8569 - val_salidas_continuas_mae: 31.5915 - learning_rate: 5.0000e-04
# Epoch 20/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1623.5938 - salida_clase_accuracy: 0.7861 - salidas_continuas_mae: 31.1905 - val_loss: 1609.6891 - val_salida_clase_accuracy: 0.8540 - val_salidas_continuas_mae: 30.9792 - learning_rate: 5.0000e-04
# Epoch 21/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1615.6570 - salida_clase_accuracy: 0.7720 - salidas_continuas_mae: 30.8120 - val_loss: 1597.7896 - val_salida_clase_accuracy: 0.8686 - val_salidas_continuas_mae: 31.1334 - learning_rate: 5.0000e-04
# Epoch 22/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1544.7706 - salida_clase_accuracy: 0.7735 - salidas_continuas_mae: 30.4381 - val_loss: 1547.3927 - val_salida_clase_accuracy: 0.8599 - val_salidas_continuas_mae: 30.3904 - learning_rate: 5.0000e-04
# Epoch 23/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1517.3019 - salida_clase_accuracy: 0.7683 - salidas_continuas_mae: 29.9062 - val_loss: 1523.9844 - val_salida_clase_accuracy: 0.8730 - val_salidas_continuas_mae: 29.9772 - learning_rate: 5.0000e-04
# Epoch 24/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1525.2922 - salida_clase_accuracy: 0.7832 - salidas_continuas_mae: 29.9142 - val_loss: 1497.1377 - val_salida_clase_accuracy: 0.8847 - val_salidas_continuas_mae: 29.8415 - learning_rate: 5.0000e-04
# Epoch 25/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1492.2117 - salida_clase_accuracy: 0.7889 - salidas_continuas_mae: 29.3813 - val_loss: 1459.1107 - val_salida_clase_accuracy: 0.8730 - val_salidas_continuas_mae: 29.0827 - learning_rate: 5.0000e-04
# Epoch 26/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1435.3632 - salida_clase_accuracy: 0.7983 - salidas_continuas_mae: 28.8475 - val_loss: 1439.8892 - val_salida_clase_accuracy: 0.8745 - val_salidas_continuas_mae: 28.9296 - learning_rate: 5.0000e-04
# Epoch 27/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1434.7417 - salida_clase_accuracy: 0.8106 - salidas_continuas_mae: 28.5664 - val_loss: 1400.5459 - val_salida_clase_accuracy: 0.8526 - val_salidas_continuas_mae: 28.3050 - learning_rate: 5.0000e-04
# Epoch 28/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1413.5291 - salida_clase_accuracy: 0.7946 - salidas_continuas_mae: 28.5079 - val_loss: 1394.0911 - val_salida_clase_accuracy: 0.8715 - val_salidas_continuas_mae: 28.4105 - learning_rate: 5.0000e-04
# Epoch 29/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1352.2947 - salida_clase_accuracy: 0.7963 - salidas_continuas_mae: 27.6964 - val_loss: 1353.5303 - val_salida_clase_accuracy: 0.8715 - val_salidas_continuas_mae: 27.6146 - learning_rate: 5.0000e-04
# Epoch 30/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1374.9194 - salida_clase_accuracy: 0.8040 - salidas_continuas_mae: 27.9100 - val_loss: 1343.9585 - val_salida_clase_accuracy: 0.8774 - val_salidas_continuas_mae: 27.7426 - learning_rate: 5.0000e-04
# Epoch 31/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1353.3502 - salida_clase_accuracy: 0.8172 - salidas_continuas_mae: 27.7448 - val_loss: 1315.5027 - val_salida_clase_accuracy: 0.8555 - val_salidas_continuas_mae: 27.2771 - learning_rate: 5.0000e-04
# Epoch 32/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1355.3876 - salida_clase_accuracy: 0.8030 - salidas_continuas_mae: 27.4466 - val_loss: 1284.1251 - val_salida_clase_accuracy: 0.8715 - val_salidas_continuas_mae: 26.3301 - learning_rate: 5.0000e-04
# Epoch 33/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1315.3450 - salida_clase_accuracy: 0.8205 - salidas_continuas_mae: 27.1168 - val_loss: 1272.4321 - val_salida_clase_accuracy: 0.8847 - val_salidas_continuas_mae: 26.4746 - learning_rate: 5.0000e-04
# Epoch 34/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1313.8152 - salida_clase_accuracy: 0.7921 - salidas_continuas_mae: 27.0682 - val_loss: 1248.3676 - val_salida_clase_accuracy: 0.8759 - val_salidas_continuas_mae: 25.9352 - learning_rate: 5.0000e-04
# Epoch 35/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1279.2020 - salida_clase_accuracy: 0.8162 - salidas_continuas_mae: 26.5860 - val_loss: 1247.4099 - val_salida_clase_accuracy: 0.8569 - val_salidas_continuas_mae: 26.1198 - learning_rate: 5.0000e-04
# Epoch 36/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1257.4919 - salida_clase_accuracy: 0.8174 - salidas_continuas_mae: 26.3556 - val_loss: 1214.5549 - val_salida_clase_accuracy: 0.8934 - val_salidas_continuas_mae: 25.6278 - learning_rate: 5.0000e-04
# Epoch 37/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1248.8522 - salida_clase_accuracy: 0.8075 - salidas_continuas_mae: 26.0087 - val_loss: 1212.9266 - val_salida_clase_accuracy: 0.8803 - val_salidas_continuas_mae: 25.8070 - learning_rate: 5.0000e-04
# Epoch 38/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1192.5757 - salida_clase_accuracy: 0.8123 - salidas_continuas_mae: 25.5413 - val_loss: 1179.1107 - val_salida_clase_accuracy: 0.8788 - val_salidas_continuas_mae: 24.9455 - learning_rate: 5.0000e-04
# Epoch 39/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1181.6167 - salida_clase_accuracy: 0.8353 - salidas_continuas_mae: 25.3909 - val_loss: 1180.1078 - val_salida_clase_accuracy: 0.8818 - val_salidas_continuas_mae: 25.2315 - learning_rate: 5.0000e-04
# Epoch 40/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1158.2228 - salida_clase_accuracy: 0.8405 - salidas_continuas_mae: 25.1688 - val_loss: 1156.4128 - val_salida_clase_accuracy: 0.8745 - val_salidas_continuas_mae: 24.6331 - learning_rate: 5.0000e-04
# Epoch 41/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1210.5557 - salida_clase_accuracy: 0.8282 - salidas_continuas_mae: 25.6316 - val_loss: 1157.2638 - val_salida_clase_accuracy: 0.8803 - val_salidas_continuas_mae: 24.9421 - learning_rate: 5.0000e-04
# Epoch 42/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1218.3536 - salida_clase_accuracy: 0.8252 - salidas_continuas_mae: 25.6091 - val_loss: 1138.6624 - val_salida_clase_accuracy: 0.8613 - val_salidas_continuas_mae: 24.4201 - learning_rate: 5.0000e-04
# Epoch 43/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1171.3656 - salida_clase_accuracy: 0.8258 - salidas_continuas_mae: 25.1002 - val_loss: 1128.4832 - val_salida_clase_accuracy: 0.8686 - val_salidas_continuas_mae: 24.3945 - learning_rate: 5.0000e-04
# Epoch 44/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1135.5608 - salida_clase_accuracy: 0.8233 - salidas_continuas_mae: 24.9200 - val_loss: 1104.6840 - val_salida_clase_accuracy: 0.8847 - val_salidas_continuas_mae: 23.8906 - learning_rate: 5.0000e-04
# Epoch 45/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1092.1974 - salida_clase_accuracy: 0.8345 - salidas_continuas_mae: 24.1965 - val_loss: 1101.4037 - val_salida_clase_accuracy: 0.8832 - val_salidas_continuas_mae: 23.7350 - learning_rate: 5.0000e-04
# Epoch 46/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1139.5188 - salida_clase_accuracy: 0.8331 - salidas_continuas_mae: 24.5874 - val_loss: 1090.3384 - val_salida_clase_accuracy: 0.8701 - val_salidas_continuas_mae: 23.6577 - learning_rate: 5.0000e-04
# Epoch 47/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1103.2051 - salida_clase_accuracy: 0.8262 - salidas_continuas_mae: 24.2558 - val_loss: 1079.0073 - val_salida_clase_accuracy: 0.8905 - val_salidas_continuas_mae: 23.4523 - learning_rate: 5.0000e-04
# Epoch 48/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1116.4508 - salida_clase_accuracy: 0.8222 - salidas_continuas_mae: 24.4509 - val_loss: 1063.6093 - val_salida_clase_accuracy: 0.8876 - val_salidas_continuas_mae: 23.2572 - learning_rate: 5.0000e-04
# Epoch 49/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1072.6244 - salida_clase_accuracy: 0.8390 - salidas_continuas_mae: 23.9222 - val_loss: 1062.3069 - val_salida_clase_accuracy: 0.8803 - val_salidas_continuas_mae: 23.2147 - learning_rate: 5.0000e-04
# Epoch 50/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1101.6404 - salida_clase_accuracy: 0.8371 - salidas_continuas_mae: 24.2886 - val_loss: 1051.4926 - val_salida_clase_accuracy: 0.8861 - val_salidas_continuas_mae: 23.0386 - learning_rate: 5.0000e-04
# Epoch 51/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1056.4816 - salida_clase_accuracy: 0.8453 - salidas_continuas_mae: 23.7420 - val_loss: 1043.6818 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 22.9784 - learning_rate: 5.0000e-04
# Epoch 52/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1084.6333 - salida_clase_accuracy: 0.8349 - salidas_continuas_mae: 24.1623 - val_loss: 1031.6752 - val_salida_clase_accuracy: 0.8818 - val_salidas_continuas_mae: 22.6534 - learning_rate: 5.0000e-04
# Epoch 53/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1061.5043 - salida_clase_accuracy: 0.8441 - salidas_continuas_mae: 23.5725 - val_loss: 1022.0741 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 22.3817 - learning_rate: 5.0000e-04
# Epoch 54/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1056.6379 - salida_clase_accuracy: 0.8313 - salidas_continuas_mae: 23.6551 - val_loss: 1020.1511 - val_salida_clase_accuracy: 0.8701 - val_salidas_continuas_mae: 22.6155 - learning_rate: 5.0000e-04
# Epoch 55/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1012.9851 - salida_clase_accuracy: 0.8366 - salidas_continuas_mae: 23.2986 - val_loss: 1029.9230 - val_salida_clase_accuracy: 0.8876 - val_salidas_continuas_mae: 22.9928 - learning_rate: 5.0000e-04
# Epoch 56/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 984.5346 - salida_clase_accuracy: 0.8352 - salidas_continuas_mae: 23.1017 - val_loss: 1006.6033 - val_salida_clase_accuracy: 0.8949 - val_salidas_continuas_mae: 22.3973 - learning_rate: 5.0000e-04
# Epoch 57/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1027.8480 - salida_clase_accuracy: 0.8436 - salidas_continuas_mae: 23.3022 - val_loss: 994.7557 - val_salida_clase_accuracy: 0.8934 - val_salidas_continuas_mae: 22.0915 - learning_rate: 5.0000e-04
# Epoch 58/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1017.4208 - salida_clase_accuracy: 0.8316 - salidas_continuas_mae: 23.1891 - val_loss: 994.8724 - val_salida_clase_accuracy: 0.9022 - val_salidas_continuas_mae: 22.1229 - learning_rate: 5.0000e-04
# Epoch 59/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1027.3546 - salida_clase_accuracy: 0.8402 - salidas_continuas_mae: 23.2717 - val_loss: 976.9403 - val_salida_clase_accuracy: 0.8701 - val_salidas_continuas_mae: 21.7282 - learning_rate: 5.0000e-04
# Epoch 60/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 997.2997 - salida_clase_accuracy: 0.8485 - salidas_continuas_mae: 23.0142 - val_loss: 981.3801 - val_salida_clase_accuracy: 0.8876 - val_salidas_continuas_mae: 21.8217 - learning_rate: 5.0000e-04
# Epoch 61/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1003.5663 - salida_clase_accuracy: 0.8468 - salidas_continuas_mae: 23.0408 - val_loss: 969.0258 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 21.6291 - learning_rate: 5.0000e-04
# Epoch 62/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 980.2327 - salida_clase_accuracy: 0.8454 - salidas_continuas_mae: 22.6902 - val_loss: 974.5345 - val_salida_clase_accuracy: 0.8949 - val_salidas_continuas_mae: 21.7540 - learning_rate: 5.0000e-04
# Epoch 63/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1024.1648 - salida_clase_accuracy: 0.8301 - salidas_continuas_mae: 22.9232 - val_loss: 968.0208 - val_salida_clase_accuracy: 0.8715 - val_salidas_continuas_mae: 21.7432 - learning_rate: 5.0000e-04
# Epoch 64/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 989.8298 - salida_clase_accuracy: 0.8308 - salidas_continuas_mae: 22.6947 - val_loss: 954.5521 - val_salida_clase_accuracy: 0.8905 - val_salidas_continuas_mae: 21.2952 - learning_rate: 5.0000e-04
# Epoch 65/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 979.5138 - salida_clase_accuracy: 0.8387 - salidas_continuas_mae: 22.7682 - val_loss: 959.2681 - val_salida_clase_accuracy: 0.9051 - val_salidas_continuas_mae: 21.6194 - learning_rate: 5.0000e-04
# Epoch 66/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 996.8739 - salida_clase_accuracy: 0.8491 - salidas_continuas_mae: 22.7092 - val_loss: 953.2107 - val_salida_clase_accuracy: 0.8920 - val_salidas_continuas_mae: 21.5899 - learning_rate: 5.0000e-04
# Epoch 67/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 978.4153 - salida_clase_accuracy: 0.8283 - salidas_continuas_mae: 22.6032 - val_loss: 948.2241 - val_salida_clase_accuracy: 0.8978 - val_salidas_continuas_mae: 21.5144 - learning_rate: 5.0000e-04
# Epoch 68/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 982.1426 - salida_clase_accuracy: 0.8483 - salidas_continuas_mae: 22.8713 - val_loss: 932.1245 - val_salida_clase_accuracy: 0.8949 - val_salidas_continuas_mae: 21.0646 - learning_rate: 5.0000e-04
# Epoch 69/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 951.7347 - salida_clase_accuracy: 0.8506 - salidas_continuas_mae: 22.1863 - val_loss: 932.0198 - val_salida_clase_accuracy: 0.8905 - val_salidas_continuas_mae: 21.0952 - learning_rate: 5.0000e-04
# Epoch 70/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 958.0419 - salida_clase_accuracy: 0.8559 - salidas_continuas_mae: 22.4650 - val_loss: 921.6547 - val_salida_clase_accuracy: 0.8978 - val_salidas_continuas_mae: 20.8156 - learning_rate: 5.0000e-04
# Epoch 71/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 933.6204 - salida_clase_accuracy: 0.8532 - salidas_continuas_mae: 22.2605 - val_loss: 925.6393 - val_salida_clase_accuracy: 0.8934 - val_salidas_continuas_mae: 20.9749 - learning_rate: 5.0000e-04
# Epoch 72/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 962.9609 - salida_clase_accuracy: 0.8550 - salidas_continuas_mae: 22.4839 - val_loss: 913.8929 - val_salida_clase_accuracy: 0.9168 - val_salidas_continuas_mae: 20.6793 - learning_rate: 5.0000e-04
# Epoch 73/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 938.3763 - salida_clase_accuracy: 0.8470 - salidas_continuas_mae: 22.2320 - val_loss: 920.9560 - val_salida_clase_accuracy: 0.8715 - val_salidas_continuas_mae: 21.0256 - learning_rate: 5.0000e-04
# Epoch 74/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 962.9142 - salida_clase_accuracy: 0.8434 - salidas_continuas_mae: 22.5337 - val_loss: 907.4187 - val_salida_clase_accuracy: 0.8788 - val_salidas_continuas_mae: 20.6561 - learning_rate: 5.0000e-04
# Epoch 75/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 936.0218 - salida_clase_accuracy: 0.8587 - salidas_continuas_mae: 22.1354 - val_loss: 908.8082 - val_salida_clase_accuracy: 0.8934 - val_salidas_continuas_mae: 20.6461 - learning_rate: 5.0000e-04
# Epoch 76/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 965.0609 - salida_clase_accuracy: 0.8500 - salidas_continuas_mae: 22.2792 - val_loss: 901.5734 - val_salida_clase_accuracy: 0.8861 - val_salidas_continuas_mae: 20.4588 - learning_rate: 5.0000e-04
# Epoch 77/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 933.1918 - salida_clase_accuracy: 0.8500 - salidas_continuas_mae: 22.0395 - val_loss: 901.2428 - val_salida_clase_accuracy: 0.9007 - val_salidas_continuas_mae: 20.6489 - learning_rate: 5.0000e-04
# Epoch 78/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 921.4058 - salida_clase_accuracy: 0.8490 - salidas_continuas_mae: 21.8965 - val_loss: 898.8284 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 20.5470 - learning_rate: 5.0000e-04
# Epoch 79/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 926.6500 - salida_clase_accuracy: 0.8560 - salidas_continuas_mae: 22.0705 - val_loss: 890.1467 - val_salida_clase_accuracy: 0.9051 - val_salidas_continuas_mae: 20.4380 - learning_rate: 5.0000e-04
# Epoch 80/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 928.1530 - salida_clase_accuracy: 0.8338 - salidas_continuas_mae: 22.0677 - val_loss: 893.8088 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 20.4290 - learning_rate: 5.0000e-04
# Epoch 81/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 930.2125 - salida_clase_accuracy: 0.8418 - salidas_continuas_mae: 22.0650 - val_loss: 898.0544 - val_salida_clase_accuracy: 0.8832 - val_salidas_continuas_mae: 20.4372 - learning_rate: 5.0000e-04
# Epoch 82/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 924.4259 - salida_clase_accuracy: 0.8568 - salidas_continuas_mae: 21.9963 - val_loss: 896.4084 - val_salida_clase_accuracy: 0.9022 - val_salidas_continuas_mae: 20.4579 - learning_rate: 5.0000e-04
# Epoch 83/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 943.4355 - salida_clase_accuracy: 0.8599 - salidas_continuas_mae: 22.0709 - val_loss: 883.4922 - val_salida_clase_accuracy: 0.8949 - val_salidas_continuas_mae: 20.2273 - learning_rate: 5.0000e-04
# Epoch 84/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 944.2556 - salida_clase_accuracy: 0.8506 - salidas_continuas_mae: 22.1033 - val_loss: 883.4906 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 20.3544 - learning_rate: 5.0000e-04
# Epoch 85/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 927.2468 - salida_clase_accuracy: 0.8415 - salidas_continuas_mae: 21.9213 - val_loss: 879.0607 - val_salida_clase_accuracy: 0.8759 - val_salidas_continuas_mae: 20.0576 - learning_rate: 5.0000e-04
# Epoch 86/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 946.7341 - salida_clase_accuracy: 0.8471 - salidas_continuas_mae: 22.1072 - val_loss: 879.6580 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 20.0789 - learning_rate: 5.0000e-04
# Epoch 87/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 889.6736 - salida_clase_accuracy: 0.8540 - salidas_continuas_mae: 21.5038 - val_loss: 871.2409 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 20.0305 - learning_rate: 5.0000e-04
# Epoch 88/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 887.0970 - salida_clase_accuracy: 0.8499 - salidas_continuas_mae: 21.4848 - val_loss: 870.5129 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 20.0273 - learning_rate: 5.0000e-04
# Epoch 89/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 889.7118 - salida_clase_accuracy: 0.8644 - salidas_continuas_mae: 21.4739 - val_loss: 859.7886 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 19.7555 - learning_rate: 5.0000e-04
# Epoch 90/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 911.5011 - salida_clase_accuracy: 0.8549 - salidas_continuas_mae: 21.7040 - val_loss: 868.5941 - val_salida_clase_accuracy: 0.9066 - val_salidas_continuas_mae: 20.0251 - learning_rate: 5.0000e-04
# Epoch 91/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 878.1640 - salida_clase_accuracy: 0.8515 - salidas_continuas_mae: 21.4287 - val_loss: 866.5964 - val_salida_clase_accuracy: 0.8861 - val_salidas_continuas_mae: 19.9831 - learning_rate: 5.0000e-04
# Epoch 92/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 906.6156 - salida_clase_accuracy: 0.8469 - salidas_continuas_mae: 21.5130 - val_loss: 853.6765 - val_salida_clase_accuracy: 0.9109 - val_salidas_continuas_mae: 19.5489 - learning_rate: 5.0000e-04
# Epoch 93/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 908.6219 - salida_clase_accuracy: 0.8647 - salidas_continuas_mae: 21.6212 - val_loss: 859.8584 - val_salida_clase_accuracy: 0.8978 - val_salidas_continuas_mae: 19.8030 - learning_rate: 5.0000e-04
# Epoch 94/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 873.1035 - salida_clase_accuracy: 0.8614 - salidas_continuas_mae: 21.3381 - val_loss: 868.6075 - val_salida_clase_accuracy: 0.8978 - val_salidas_continuas_mae: 20.0458 - learning_rate: 5.0000e-04
# Epoch 95/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 866.6832 - salida_clase_accuracy: 0.8722 - salidas_continuas_mae: 21.3645 - val_loss: 858.6364 - val_salida_clase_accuracy: 0.9051 - val_salidas_continuas_mae: 19.9740 - learning_rate: 5.0000e-04
# Epoch 96/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 907.6852 - salida_clase_accuracy: 0.8601 - salidas_continuas_mae: 21.6142 - val_loss: 849.0039 - val_salida_clase_accuracy: 0.8934 - val_salidas_continuas_mae: 19.5065 - learning_rate: 5.0000e-04
# Epoch 97/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 873.5574 - salida_clase_accuracy: 0.8623 - salidas_continuas_mae: 21.2381 - val_loss: 850.0477 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 19.6124 - learning_rate: 5.0000e-04
# Epoch 98/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 873.2700 - salida_clase_accuracy: 0.8488 - salidas_continuas_mae: 21.0013 - val_loss: 847.3472 - val_salida_clase_accuracy: 0.9095 - val_salidas_continuas_mae: 19.4637 - learning_rate: 5.0000e-04
# Epoch 99/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 894.2972 - salida_clase_accuracy: 0.8522 - salidas_continuas_mae: 21.4798 - val_loss: 850.7844 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 19.5838 - learning_rate: 5.0000e-04
# Epoch 100/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 886.1758 - salida_clase_accuracy: 0.8552 - salidas_continuas_mae: 21.2331 - val_loss: 830.6038 - val_salida_clase_accuracy: 0.9036 - val_salidas_continuas_mae: 19.1699 - learning_rate: 5.0000e-04
# Epoch 101/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 866.8215 - salida_clase_accuracy: 0.8570 - salidas_continuas_mae: 21.1241 - val_loss: 833.1058 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 19.4799 - learning_rate: 5.0000e-04
# Epoch 102/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 860.4656 - salida_clase_accuracy: 0.8567 - salidas_continuas_mae: 21.1750 - val_loss: 838.0251 - val_salida_clase_accuracy: 0.9080 - val_salidas_continuas_mae: 19.3858 - learning_rate: 5.0000e-04
# Epoch 103/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 894.5201 - salida_clase_accuracy: 0.8693 - salidas_continuas_mae: 21.3686 - val_loss: 832.8955 - val_salida_clase_accuracy: 0.8847 - val_salidas_continuas_mae: 19.3956 - learning_rate: 5.0000e-04
# Epoch 104/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 867.8536 - salida_clase_accuracy: 0.8570 - salidas_continuas_mae: 21.0774 - val_loss: 828.1643 - val_salida_clase_accuracy: 0.9007 - val_salidas_continuas_mae: 19.2667 - learning_rate: 5.0000e-04
# Epoch 105/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 904.7345 - salida_clase_accuracy: 0.8702 - salidas_continuas_mae: 21.6288 - val_loss: 831.1423 - val_salida_clase_accuracy: 0.9066 - val_salidas_continuas_mae: 19.3517 - learning_rate: 5.0000e-04
# Epoch 106/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 886.8807 - salida_clase_accuracy: 0.8664 - salidas_continuas_mae: 21.5692 - val_loss: 823.5960 - val_salida_clase_accuracy: 0.9022 - val_salidas_continuas_mae: 19.1326 - learning_rate: 5.0000e-04
# Epoch 107/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 883.7015 - salida_clase_accuracy: 0.8499 - salidas_continuas_mae: 21.1909 - val_loss: 821.3522 - val_salida_clase_accuracy: 0.9080 - val_salidas_continuas_mae: 19.0281 - learning_rate: 5.0000e-04
# Epoch 108/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 826.0906 - salida_clase_accuracy: 0.8665 - salidas_continuas_mae: 20.5980 - val_loss: 833.9552 - val_salida_clase_accuracy: 0.8861 - val_salidas_continuas_mae: 19.4641 - learning_rate: 5.0000e-04
# Epoch 109/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 867.9752 - salida_clase_accuracy: 0.8555 - salidas_continuas_mae: 21.2802 - val_loss: 833.7342 - val_salida_clase_accuracy: 0.8978 - val_salidas_continuas_mae: 19.4199 - learning_rate: 5.0000e-04
# Epoch 110/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 868.3834 - salida_clase_accuracy: 0.8786 - salidas_continuas_mae: 21.1684 - val_loss: 832.4224 - val_salida_clase_accuracy: 0.8978 - val_salidas_continuas_mae: 19.3671 - learning_rate: 5.0000e-04
# Epoch 111/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 881.5598 - salida_clase_accuracy: 0.8548 - salidas_continuas_mae: 21.3752 - val_loss: 819.3099 - val_salida_clase_accuracy: 0.8934 - val_salidas_continuas_mae: 19.1339 - learning_rate: 5.0000e-04
# Epoch 112/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 838.3320 - salida_clase_accuracy: 0.8515 - salidas_continuas_mae: 20.8916 - val_loss: 818.1763 - val_salida_clase_accuracy: 0.9022 - val_salidas_continuas_mae: 19.1919 - learning_rate: 5.0000e-04
# Epoch 113/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 831.7763 - salida_clase_accuracy: 0.8745 - salidas_continuas_mae: 20.7074 - val_loss: 810.0332 - val_salida_clase_accuracy: 0.9036 - val_salidas_continuas_mae: 18.8409 - learning_rate: 5.0000e-04
# Epoch 114/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 845.2665 - salida_clase_accuracy: 0.8492 - salidas_continuas_mae: 20.9466 - val_loss: 821.2718 - val_salida_clase_accuracy: 0.9036 - val_salidas_continuas_mae: 19.2581 - learning_rate: 5.0000e-04
# Epoch 115/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 874.2831 - salida_clase_accuracy: 0.8680 - salidas_continuas_mae: 21.1618 - val_loss: 814.6859 - val_salida_clase_accuracy: 0.9036 - val_salidas_continuas_mae: 19.0961 - learning_rate: 5.0000e-04
# Epoch 116/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 849.7207 - salida_clase_accuracy: 0.8732 - salidas_continuas_mae: 21.1522 - val_loss: 821.9399 - val_salida_clase_accuracy: 0.9051 - val_salidas_continuas_mae: 19.2368 - learning_rate: 5.0000e-04
# Epoch 117/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 894.6163 - salida_clase_accuracy: 0.8635 - salidas_continuas_mae: 21.3935 - val_loss: 810.1807 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 18.9999 - learning_rate: 5.0000e-04
# Epoch 118/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 819.1241 - salida_clase_accuracy: 0.8624 - salidas_continuas_mae: 20.7477 - val_loss: 805.5350 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 18.7792 - learning_rate: 5.0000e-04
# Epoch 119/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 874.5632 - salida_clase_accuracy: 0.8643 - salidas_continuas_mae: 21.0842 - val_loss: 804.4725 - val_salida_clase_accuracy: 0.8934 - val_salidas_continuas_mae: 18.7691 - learning_rate: 5.0000e-04
# Epoch 120/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 850.5437 - salida_clase_accuracy: 0.8591 - salidas_continuas_mae: 20.8273 - val_loss: 799.2958 - val_salida_clase_accuracy: 0.9066 - val_salidas_continuas_mae: 18.7209 - learning_rate: 5.0000e-04
# Epoch 121/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 866.1139 - salida_clase_accuracy: 0.8626 - salidas_continuas_mae: 21.2879 - val_loss: 804.3947 - val_salida_clase_accuracy: 0.9036 - val_salidas_continuas_mae: 18.8394 - learning_rate: 5.0000e-04
# Epoch 122/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 856.0794 - salida_clase_accuracy: 0.8760 - salidas_continuas_mae: 20.9664 - val_loss: 800.7438 - val_salida_clase_accuracy: 0.8993 - val_salidas_continuas_mae: 18.6362 - learning_rate: 5.0000e-04
# Epoch 123/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 858.7404 - salida_clase_accuracy: 0.8504 - salidas_continuas_mae: 21.0534 - val_loss: 811.6688 - val_salida_clase_accuracy: 0.9197 - val_salidas_continuas_mae: 19.1301 - learning_rate: 5.0000e-04
# Epoch 124/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 839.0839 - salida_clase_accuracy: 0.8596 - salidas_continuas_mae: 20.9312 - val_loss: 806.6224 - val_salida_clase_accuracy: 0.9080 - val_salidas_continuas_mae: 19.0363 - learning_rate: 5.0000e-04
# Epoch 125/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 837.8251 - salida_clase_accuracy: 0.8623 - salidas_continuas_mae: 20.8598 - val_loss: 801.2714 - val_salida_clase_accuracy: 0.9080 - val_salidas_continuas_mae: 18.8894 - learning_rate: 5.0000e-04
# Epoch 126/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 837.3030 - salida_clase_accuracy: 0.8698 - salidas_continuas_mae: 20.6836 - val_loss: 791.9873 - val_salida_clase_accuracy: 0.9109 - val_salidas_continuas_mae: 18.6027 - learning_rate: 2.5000e-04
# Epoch 127/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 795.5093 - salida_clase_accuracy: 0.8771 - salidas_continuas_mae: 20.1530 - val_loss: 793.6728 - val_salida_clase_accuracy: 0.9109 - val_salidas_continuas_mae: 18.6198 - learning_rate: 2.5000e-04
# Epoch 128/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 840.5695 - salida_clase_accuracy: 0.8792 - salidas_continuas_mae: 20.7643 - val_loss: 796.3312 - val_salida_clase_accuracy: 0.9153 - val_salidas_continuas_mae: 18.7328 - learning_rate: 2.5000e-04
# Epoch 129/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 818.5969 - salida_clase_accuracy: 0.8811 - salidas_continuas_mae: 20.6890 - val_loss: 799.4738 - val_salida_clase_accuracy: 0.9124 - val_salidas_continuas_mae: 18.8879 - learning_rate: 2.5000e-04
# Epoch 130/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 811.4255 - salida_clase_accuracy: 0.8863 - salidas_continuas_mae: 20.4062 - val_loss: 798.1678 - val_salida_clase_accuracy: 0.9124 - val_salidas_continuas_mae: 18.8855 - learning_rate: 2.5000e-04
# Epoch 131/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 839.7011 - salida_clase_accuracy: 0.8627 - salidas_continuas_mae: 20.6791 - val_loss: 793.1987 - val_salida_clase_accuracy: 0.9226 - val_salidas_continuas_mae: 18.7053 - learning_rate: 2.5000e-04
# Epoch 132/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 834.2463 - salida_clase_accuracy: 0.8815 - salidas_continuas_mae: 20.8233 - val_loss: 791.2150 - val_salida_clase_accuracy: 0.9226 - val_salidas_continuas_mae: 18.6202 - learning_rate: 1.2500e-04
# Epoch 133/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 819.3801 - salida_clase_accuracy: 0.8756 - salidas_continuas_mae: 20.4985 - val_loss: 787.0826 - val_salida_clase_accuracy: 0.9212 - val_salidas_continuas_mae: 18.5847 - learning_rate: 1.2500e-04
# Epoch 134/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 825.1674 - salida_clase_accuracy: 0.8712 - salidas_continuas_mae: 20.7103 - val_loss: 790.9092 - val_salida_clase_accuracy: 0.9182 - val_salidas_continuas_mae: 18.6573 - learning_rate: 1.2500e-04
# Epoch 135/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 840.9229 - salida_clase_accuracy: 0.8952 - salidas_continuas_mae: 20.7767 - val_loss: 787.9860 - val_salida_clase_accuracy: 0.9124 - val_salidas_continuas_mae: 18.5744 - learning_rate: 1.2500e-04
# Epoch 136/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 817.8969 - salida_clase_accuracy: 0.8754 - salidas_continuas_mae: 20.5521 - val_loss: 789.0972 - val_salida_clase_accuracy: 0.9139 - val_salidas_continuas_mae: 18.5829 - learning_rate: 1.2500e-04
# Epoch 137/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 810.8979 - salida_clase_accuracy: 0.8737 - salidas_continuas_mae: 20.2690 - val_loss: 788.8358 - val_salida_clase_accuracy: 0.9197 - val_salidas_continuas_mae: 18.5816 - learning_rate: 1.2500e-04
# Epoch 138/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 826.5884 - salida_clase_accuracy: 0.8838 - salidas_continuas_mae: 20.5535 - val_loss: 787.5419 - val_salida_clase_accuracy: 0.9197 - val_salidas_continuas_mae: 18.6080 - learning_rate: 1.2500e-04
# Epoch 139/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 795.9335 - salida_clase_accuracy: 0.9022 - salidas_continuas_mae: 20.3977 - val_loss: 785.1278 - val_salida_clase_accuracy: 0.9182 - val_salidas_continuas_mae: 18.5072 - learning_rate: 6.2500e-05
# Epoch 140/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 780.8727 - salida_clase_accuracy: 0.8728 - salidas_continuas_mae: 20.0224 - val_loss: 786.0534 - val_salida_clase_accuracy: 0.9109 - val_salidas_continuas_mae: 18.5382 - learning_rate: 6.2500e-05
# Epoch 141/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 803.8762 - salida_clase_accuracy: 0.8915 - salidas_continuas_mae: 20.3807 - val_loss: 785.5651 - val_salida_clase_accuracy: 0.9226 - val_salidas_continuas_mae: 18.5308 - learning_rate: 6.2500e-05
# Epoch 142/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 816.0227 - salida_clase_accuracy: 0.8863 - salidas_continuas_mae: 20.5210 - val_loss: 786.6825 - val_salida_clase_accuracy: 0.9182 - val_salidas_continuas_mae: 18.5418 - learning_rate: 6.2500e-05
# Epoch 143/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 808.3319 - salida_clase_accuracy: 0.8799 - salidas_continuas_mae: 20.2353 - val_loss: 786.8687 - val_salida_clase_accuracy: 0.9168 - val_salidas_continuas_mae: 18.5391 - learning_rate: 6.2500e-05
# Epoch 144/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 792.4772 - salida_clase_accuracy: 0.8714 - salidas_continuas_mae: 20.1029 - val_loss: 783.8614 - val_salida_clase_accuracy: 0.9241 - val_salidas_continuas_mae: 18.4838 - learning_rate: 6.2500e-05
# Epoch 145/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 789.9246 - salida_clase_accuracy: 0.8877 - salidas_continuas_mae: 20.1277 - val_loss: 784.8103 - val_salida_clase_accuracy: 0.9168 - val_salidas_continuas_mae: 18.5047 - learning_rate: 6.2500e-05
# Epoch 146/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 828.1327 - salida_clase_accuracy: 0.8813 - salidas_continuas_mae: 20.7139 - val_loss: 784.7600 - val_salida_clase_accuracy: 0.9212 - val_salidas_continuas_mae: 18.5186 - learning_rate: 6.2500e-05
# Epoch 147/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 834.0370 - salida_clase_accuracy: 0.8900 - salidas_continuas_mae: 20.6587 - val_loss: 785.2044 - val_salida_clase_accuracy: 0.9182 - val_salidas_continuas_mae: 18.5166 - learning_rate: 6.2500e-05
# Epoch 148/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 787.5425 - salida_clase_accuracy: 0.8949 - salidas_continuas_mae: 20.2033 - val_loss: 786.1473 - val_salida_clase_accuracy: 0.9197 - val_salidas_continuas_mae: 18.5683 - learning_rate: 6.2500e-05
# Epoch 149/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 832.1687 - salida_clase_accuracy: 0.8659 - salidas_continuas_mae: 20.4922 - val_loss: 784.1171 - val_salida_clase_accuracy: 0.9212 - val_salidas_continuas_mae: 18.4999 - learning_rate: 6.2500e-05
# Epoch 150/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 785.9734 - salida_clase_accuracy: 0.8763 - salidas_continuas_mae: 20.1514 - val_loss: 785.7233 - val_salida_clase_accuracy: 0.9168 - val_salidas_continuas_mae: 18.5598 - learning_rate: 3.1250e-05
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 682.2062 - salida_clase_accuracy: 0.9292 - salidas_continuas_mae: 17.2701
# Fold 1: Loss=681.8121337890625, MAE=17.42595672607422, Accuracy=0.9345794320106506
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Entrenando fold 2...
# Epoch 1/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - loss: 11490.5459 - salida_clase_accuracy: 0.2465 - salidas_continuas_mae: 89.1949 - val_loss: 10946.8760 - val_salida_clase_accuracy: 0.4526 - val_salidas_continuas_mae: 85.7056 - learning_rate: 5.0000e-04
# Epoch 2/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6831.8633 - salida_clase_accuracy: 0.5283 - salidas_continuas_mae: 66.9108 - val_loss: 6344.4971 - val_salida_clase_accuracy: 0.5460 - val_salidas_continuas_mae: 63.9677 - learning_rate: 5.0000e-04
# Epoch 3/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3859.9727 - salida_clase_accuracy: 0.5929 - salidas_continuas_mae: 51.9881 - val_loss: 3619.0300 - val_salida_clase_accuracy: 0.5927 - val_salidas_continuas_mae: 50.1222 - learning_rate: 5.0000e-04
# Epoch 4/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2796.3777 - salida_clase_accuracy: 0.6580 - salidas_continuas_mae: 45.0626 - val_loss: 2731.1504 - val_salida_clase_accuracy: 0.7124 - val_salidas_continuas_mae: 43.9215 - learning_rate: 5.0000e-04
# Epoch 5/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 2485.5398 - salida_clase_accuracy: 0.6598 - salidas_continuas_mae: 42.3384 - val_loss: 2493.5562 - val_salida_clase_accuracy: 0.7095 - val_salidas_continuas_mae: 41.8960 - learning_rate: 5.0000e-04
# Epoch 6/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2383.8379 - salida_clase_accuracy: 0.6789 - salidas_continuas_mae: 41.1761 - val_loss: 2347.0698 - val_salida_clase_accuracy: 0.7314 - val_salidas_continuas_mae: 40.5801 - learning_rate: 5.0000e-04
# Epoch 7/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2291.2024 - salida_clase_accuracy: 0.7090 - salidas_continuas_mae: 39.9383 - val_loss: 2227.4600 - val_salida_clase_accuracy: 0.7737 - val_salidas_continuas_mae: 39.4322 - learning_rate: 5.0000e-04
# Epoch 8/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2161.9048 - salida_clase_accuracy: 0.7184 - salidas_continuas_mae: 38.5429 - val_loss: 2142.7893 - val_salida_clase_accuracy: 0.7533 - val_salidas_continuas_mae: 38.4535 - learning_rate: 5.0000e-04
# Epoch 9/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 2124.8850 - salida_clase_accuracy: 0.7253 - salidas_continuas_mae: 37.9402 - val_loss: 2060.6367 - val_salida_clase_accuracy: 0.7796 - val_salidas_continuas_mae: 37.0363 - learning_rate: 5.0000e-04
# Epoch 10/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 2080.9292 - salida_clase_accuracy: 0.7408 - salidas_continuas_mae: 37.2693 - val_loss: 2013.5593 - val_salida_clase_accuracy: 0.7971 - val_salidas_continuas_mae: 36.7963 - learning_rate: 5.0000e-04
# Epoch 11/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2003.8676 - salida_clase_accuracy: 0.7463 - salidas_continuas_mae: 36.4395 - val_loss: 1935.0052 - val_salida_clase_accuracy: 0.8029 - val_salidas_continuas_mae: 35.5983 - learning_rate: 5.0000e-04
# Epoch 12/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1894.3646 - salida_clase_accuracy: 0.7344 - salidas_continuas_mae: 35.1386 - val_loss: 1895.5259 - val_salida_clase_accuracy: 0.8073 - val_salidas_continuas_mae: 34.7806 - learning_rate: 5.0000e-04
# Epoch 13/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1860.0327 - salida_clase_accuracy: 0.7450 - salidas_continuas_mae: 34.4857 - val_loss: 1844.0583 - val_salida_clase_accuracy: 0.8161 - val_salidas_continuas_mae: 34.3097 - learning_rate: 5.0000e-04
# Epoch 14/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1840.7938 - salida_clase_accuracy: 0.7664 - salidas_continuas_mae: 34.1998 - val_loss: 1797.4407 - val_salida_clase_accuracy: 0.7912 - val_salidas_continuas_mae: 33.6823 - learning_rate: 5.0000e-04
# Epoch 15/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1824.1429 - salida_clase_accuracy: 0.7650 - salidas_continuas_mae: 33.8111 - val_loss: 1785.0630 - val_salida_clase_accuracy: 0.8161 - val_salidas_continuas_mae: 33.6863 - learning_rate: 5.0000e-04
# Epoch 16/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1738.0726 - salida_clase_accuracy: 0.7742 - salidas_continuas_mae: 32.8344 - val_loss: 1731.1942 - val_salida_clase_accuracy: 0.8029 - val_salidas_continuas_mae: 32.8206 - learning_rate: 5.0000e-04
# Epoch 17/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1738.4384 - salida_clase_accuracy: 0.7664 - salidas_continuas_mae: 32.8297 - val_loss: 1686.8799 - val_salida_clase_accuracy: 0.8029 - val_salidas_continuas_mae: 31.7998 - learning_rate: 5.0000e-04
# Epoch 18/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1680.4362 - salida_clase_accuracy: 0.7812 - salidas_continuas_mae: 31.9985 - val_loss: 1656.6652 - val_salida_clase_accuracy: 0.8161 - val_salidas_continuas_mae: 31.5815 - learning_rate: 5.0000e-04
# Epoch 19/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1664.1036 - salida_clase_accuracy: 0.7722 - salidas_continuas_mae: 31.5981 - val_loss: 1641.2058 - val_salida_clase_accuracy: 0.8234 - val_salidas_continuas_mae: 31.7384 - learning_rate: 5.0000e-04
# Epoch 20/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1653.7250 - salida_clase_accuracy: 0.7794 - salidas_continuas_mae: 31.6145 - val_loss: 1612.4739 - val_salida_clase_accuracy: 0.8307 - val_salidas_continuas_mae: 31.1196 - learning_rate: 5.0000e-04
# Epoch 21/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1588.2570 - salida_clase_accuracy: 0.7744 - salidas_continuas_mae: 30.7148 - val_loss: 1554.7903 - val_salida_clase_accuracy: 0.8263 - val_salidas_continuas_mae: 30.1973 - learning_rate: 5.0000e-04
# Epoch 22/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1571.0288 - salida_clase_accuracy: 0.7993 - salidas_continuas_mae: 30.5473 - val_loss: 1549.4720 - val_salida_clase_accuracy: 0.8453 - val_salidas_continuas_mae: 30.5479 - learning_rate: 5.0000e-04
# Epoch 23/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1524.3689 - salida_clase_accuracy: 0.7955 - salidas_continuas_mae: 29.9472 - val_loss: 1509.1571 - val_salida_clase_accuracy: 0.8350 - val_salidas_continuas_mae: 29.8901 - learning_rate: 5.0000e-04
# Epoch 24/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1531.6803 - salida_clase_accuracy: 0.7793 - salidas_continuas_mae: 29.9326 - val_loss: 1473.9783 - val_salida_clase_accuracy: 0.8365 - val_salidas_continuas_mae: 29.3824 - learning_rate: 5.0000e-04
# Epoch 25/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1539.9714 - salida_clase_accuracy: 0.7897 - salidas_continuas_mae: 29.9454 - val_loss: 1444.2924 - val_salida_clase_accuracy: 0.8467 - val_salidas_continuas_mae: 28.9873 - learning_rate: 5.0000e-04
# Epoch 26/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1456.7473 - salida_clase_accuracy: 0.7978 - salidas_continuas_mae: 29.1297 - val_loss: 1423.3990 - val_salida_clase_accuracy: 0.8467 - val_salidas_continuas_mae: 28.7514 - learning_rate: 5.0000e-04
# Epoch 27/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1494.3389 - salida_clase_accuracy: 0.8122 - salidas_continuas_mae: 29.3510 - val_loss: 1393.1008 - val_salida_clase_accuracy: 0.8599 - val_salidas_continuas_mae: 28.3571 - learning_rate: 5.0000e-04
# Epoch 28/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1430.0524 - salida_clase_accuracy: 0.8088 - salidas_continuas_mae: 28.6566 - val_loss: 1356.3915 - val_salida_clase_accuracy: 0.8540 - val_salidas_continuas_mae: 27.6850 - learning_rate: 5.0000e-04
# Epoch 29/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1399.9979 - salida_clase_accuracy: 0.8257 - salidas_continuas_mae: 28.2668 - val_loss: 1341.6027 - val_salida_clase_accuracy: 0.8555 - val_salidas_continuas_mae: 27.5382 - learning_rate: 5.0000e-04
# Epoch 30/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1399.0134 - salida_clase_accuracy: 0.8039 - salidas_continuas_mae: 28.1615 - val_loss: 1314.7446 - val_salida_clase_accuracy: 0.8511 - val_salidas_continuas_mae: 27.1682 - learning_rate: 5.0000e-04
# Epoch 31/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1357.4268 - salida_clase_accuracy: 0.8290 - salidas_continuas_mae: 27.5861 - val_loss: 1296.0958 - val_salida_clase_accuracy: 0.8540 - val_salidas_continuas_mae: 26.9745 - learning_rate: 5.0000e-04
# Epoch 32/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 1324.7749 - salida_clase_accuracy: 0.8127 - salidas_continuas_mae: 27.2824 - val_loss: 1270.9381 - val_salida_clase_accuracy: 0.8438 - val_salidas_continuas_mae: 26.7062 - learning_rate: 5.0000e-04
# Epoch 33/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1295.3485 - salida_clase_accuracy: 0.8145 - salidas_continuas_mae: 27.0169 - val_loss: 1250.8502 - val_salida_clase_accuracy: 0.8453 - val_salidas_continuas_mae: 26.2861 - learning_rate: 5.0000e-04
# Epoch 34/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 1271.7620 - salida_clase_accuracy: 0.8063 - salidas_continuas_mae: 26.7669 - val_loss: 1211.3911 - val_salida_clase_accuracy: 0.8453 - val_salidas_continuas_mae: 25.4383 - learning_rate: 5.0000e-04
# Epoch 35/150
# ...
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 905.1398 - salida_clase_accuracy: 0.8620 - salidas_continuas_mae: 21.5105 - val_loss: 850.1018 - val_salida_clase_accuracy: 0.8991 - val_salidas_continuas_mae: 19.8611 - learning_rate: 5.0000e-04
# Epoch 91/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 898.7631 - salida_clase_accuracy: 0.8517 - salidas_continuas_mae: 21.4776 - val_loss: 851.5046 - val_salida_clase_accuracy: 0.8874 - val_salidas_continuas_mae: 19.8253 - learning_rate: 5.0000e-04
# Epoch 92/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 916.7439 - salida_clase_accuracy: 0.8549 - salidas_continuas_mae: 21.9391 - val_loss: 854.9842 - val_salida_clase_accuracy: 0.8947 - val_salidas_continuas_mae: 20.1001 - learning_rate: 5.0000e-04
# Epoch 93/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 881.2732 - salida_clase_accuracy: 0.8627 - salidas_continuas_mae: 21.2326 - val_loss: 834.5408 - val_salida_clase_accuracy: 0.9035 - val_salidas_continuas_mae: 19.4786 - learning_rate: 5.0000e-04
# Epoch 94/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 898.2985 - salida_clase_accuracy: 0.8590 - salidas_continuas_mae: 21.5406 - val_loss: 839.7654 - val_salida_clase_accuracy: 0.8933 - val_salidas_continuas_mae: 19.5780 - learning_rate: 5.0000e-04
# Epoch 95/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 905.0485 - salida_clase_accuracy: 0.8663 - salidas_continuas_mae: 21.5673 - val_loss: 834.5189 - val_salida_clase_accuracy: 0.8889 - val_salidas_continuas_mae: 19.5497 - learning_rate: 5.0000e-04
# Epoch 96/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 880.2765 - salida_clase_accuracy: 0.8645 - salidas_continuas_mae: 21.3701 - val_loss: 834.9061 - val_salida_clase_accuracy: 0.8830 - val_salidas_continuas_mae: 19.7313 - learning_rate: 5.0000e-04
# Epoch 97/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 849.9874 - salida_clase_accuracy: 0.8489 - salidas_continuas_mae: 20.9807 - val_loss: 831.3226 - val_salida_clase_accuracy: 0.9020 - val_salidas_continuas_mae: 19.5171 - learning_rate: 5.0000e-04
# Epoch 98/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 845.0266 - salida_clase_accuracy: 0.8771 - salidas_continuas_mae: 21.0070 - val_loss: 830.7064 - val_salida_clase_accuracy: 0.8962 - val_salidas_continuas_mae: 19.5089 - learning_rate: 5.0000e-04
# Epoch 99/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 906.4763 - salida_clase_accuracy: 0.8513 - salidas_continuas_mae: 21.5172 - val_loss: 822.6006 - val_salida_clase_accuracy: 0.8933 - val_salidas_continuas_mae: 19.3137 - learning_rate: 5.0000e-04
# Epoch 100/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 865.2324 - salida_clase_accuracy: 0.8642 - salidas_continuas_mae: 21.2304 - val_loss: 813.1369 - val_salida_clase_accuracy: 0.8845 - val_salidas_continuas_mae: 19.0782 - learning_rate: 5.0000e-04
# Epoch 101/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 847.2886 - salida_clase_accuracy: 0.8515 - salidas_continuas_mae: 20.9710 - val_loss: 822.0342 - val_salida_clase_accuracy: 0.8904 - val_salidas_continuas_mae: 19.3658 - learning_rate: 5.0000e-04
# Epoch 102/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 861.2458 - salida_clase_accuracy: 0.8678 - salidas_continuas_mae: 21.0838 - val_loss: 818.7822 - val_salida_clase_accuracy: 0.8918 - val_salidas_continuas_mae: 19.3464 - learning_rate: 5.0000e-04
# Epoch 103/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 853.0964 - salida_clase_accuracy: 0.8476 - salidas_continuas_mae: 20.9814 - val_loss: 825.5119 - val_salida_clase_accuracy: 0.8830 - val_salidas_continuas_mae: 19.3848 - learning_rate: 5.0000e-04
# Epoch 104/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 881.5414 - salida_clase_accuracy: 0.8546 - salidas_continuas_mae: 21.4356 - val_loss: 818.7064 - val_salida_clase_accuracy: 0.8918 - val_salidas_continuas_mae: 19.4070 - learning_rate: 5.0000e-04
# Epoch 105/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 857.4133 - salida_clase_accuracy: 0.8575 - salidas_continuas_mae: 21.2035 - val_loss: 816.6252 - val_salida_clase_accuracy: 0.8991 - val_salidas_continuas_mae: 19.3596 - learning_rate: 5.0000e-04
# Epoch 106/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 857.9917 - salida_clase_accuracy: 0.8482 - salidas_continuas_mae: 21.2031 - val_loss: 809.7643 - val_salida_clase_accuracy: 0.8933 - val_salidas_continuas_mae: 19.0964 - learning_rate: 2.5000e-04
# Epoch 107/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 854.4780 - salida_clase_accuracy: 0.8819 - salidas_continuas_mae: 20.9490 - val_loss: 815.9930 - val_salida_clase_accuracy: 0.9050 - val_salidas_continuas_mae: 19.4320 - learning_rate: 2.5000e-04
# Epoch 108/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 852.0094 - salida_clase_accuracy: 0.8808 - salidas_continuas_mae: 20.9731 - val_loss: 811.1685 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 19.2455 - learning_rate: 2.5000e-04
# Epoch 109/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 858.8369 - salida_clase_accuracy: 0.8706 - salidas_continuas_mae: 21.1668 - val_loss: 817.8006 - val_salida_clase_accuracy: 0.9108 - val_salidas_continuas_mae: 19.3710 - learning_rate: 2.5000e-04
# Epoch 110/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 904.9215 - salida_clase_accuracy: 0.8617 - salidas_continuas_mae: 21.7913 - val_loss: 810.5411 - val_salida_clase_accuracy: 0.9050 - val_salidas_continuas_mae: 19.1699 - learning_rate: 2.5000e-04
# Epoch 111/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 846.0040 - salida_clase_accuracy: 0.8728 - salidas_continuas_mae: 20.9292 - val_loss: 806.2227 - val_salida_clase_accuracy: 0.9006 - val_salidas_continuas_mae: 19.0923 - learning_rate: 2.5000e-04
# Epoch 112/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 834.3134 - salida_clase_accuracy: 0.8742 - salidas_continuas_mae: 20.9069 - val_loss: 809.9594 - val_salida_clase_accuracy: 0.8991 - val_salidas_continuas_mae: 19.2055 - learning_rate: 2.5000e-04
# Epoch 113/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 862.8252 - salida_clase_accuracy: 0.8811 - salidas_continuas_mae: 21.2428 - val_loss: 804.0043 - val_salida_clase_accuracy: 0.9006 - val_salidas_continuas_mae: 19.0639 - learning_rate: 2.5000e-04
# Epoch 114/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 842.5962 - salida_clase_accuracy: 0.8768 - salidas_continuas_mae: 20.8904 - val_loss: 808.2055 - val_salida_clase_accuracy: 0.9006 - val_salidas_continuas_mae: 19.1762 - learning_rate: 2.5000e-04
# Epoch 115/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 848.8203 - salida_clase_accuracy: 0.8780 - salidas_continuas_mae: 20.9125 - val_loss: 804.6735 - val_salida_clase_accuracy: 0.9050 - val_salidas_continuas_mae: 19.0326 - learning_rate: 2.5000e-04
# Epoch 116/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 854.3900 - salida_clase_accuracy: 0.8663 - salidas_continuas_mae: 20.9146 - val_loss: 805.8879 - val_salida_clase_accuracy: 0.9064 - val_salidas_continuas_mae: 19.0001 - learning_rate: 2.5000e-04
# Epoch 117/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 863.0808 - salida_clase_accuracy: 0.8761 - salidas_continuas_mae: 20.9760 - val_loss: 805.5737 - val_salida_clase_accuracy: 0.8977 - val_salidas_continuas_mae: 18.9243 - learning_rate: 2.5000e-04
# Epoch 118/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 869.3994 - salida_clase_accuracy: 0.8742 - salidas_continuas_mae: 21.2351 - val_loss: 803.1682 - val_salida_clase_accuracy: 0.8991 - val_salidas_continuas_mae: 18.9871 - learning_rate: 2.5000e-04
# Epoch 119/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 862.3973 - salida_clase_accuracy: 0.8749 - salidas_continuas_mae: 21.1932 - val_loss: 811.3237 - val_salida_clase_accuracy: 0.9064 - val_salidas_continuas_mae: 19.3437 - learning_rate: 2.5000e-04
# Epoch 120/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 836.6595 - salida_clase_accuracy: 0.8802 - salidas_continuas_mae: 20.7267 - val_loss: 802.2274 - val_salida_clase_accuracy: 0.9006 - val_salidas_continuas_mae: 19.0374 - learning_rate: 2.5000e-04
# Epoch 121/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 827.8610 - salida_clase_accuracy: 0.8712 - salidas_continuas_mae: 20.5884 - val_loss: 801.2504 - val_salida_clase_accuracy: 0.9064 - val_salidas_continuas_mae: 19.0134 - learning_rate: 2.5000e-04
# Epoch 122/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 831.2430 - salida_clase_accuracy: 0.8820 - salidas_continuas_mae: 20.5908 - val_loss: 804.1266 - val_salida_clase_accuracy: 0.8991 - val_salidas_continuas_mae: 19.1211 - learning_rate: 2.5000e-04
# Epoch 123/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 845.2762 - salida_clase_accuracy: 0.8606 - salidas_continuas_mae: 20.9018 - val_loss: 806.1971 - val_salida_clase_accuracy: 0.9050 - val_salidas_continuas_mae: 19.2059 - learning_rate: 2.5000e-04
# Epoch 124/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 851.0661 - salida_clase_accuracy: 0.8744 - salidas_continuas_mae: 20.8028 - val_loss: 798.1761 - val_salida_clase_accuracy: 0.9050 - val_salidas_continuas_mae: 19.0308 - learning_rate: 2.5000e-04
# Epoch 125/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 838.0726 - salida_clase_accuracy: 0.8748 - salidas_continuas_mae: 20.9183 - val_loss: 795.0831 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 18.9273 - learning_rate: 2.5000e-04
# Epoch 126/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 871.1924 - salida_clase_accuracy: 0.8769 - salidas_continuas_mae: 21.1876 - val_loss: 801.4797 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 19.1641 - learning_rate: 2.5000e-04
# Epoch 127/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 873.2448 - salida_clase_accuracy: 0.8759 - salidas_continuas_mae: 21.2683 - val_loss: 794.7153 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 19.0077 - learning_rate: 2.5000e-04
# Epoch 128/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 831.4412 - salida_clase_accuracy: 0.8804 - salidas_continuas_mae: 20.6558 - val_loss: 795.4211 - val_salida_clase_accuracy: 0.9006 - val_salidas_continuas_mae: 19.0766 - learning_rate: 2.5000e-04
# Epoch 129/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 825.4276 - salida_clase_accuracy: 0.8830 - salidas_continuas_mae: 20.6141 - val_loss: 788.5932 - val_salida_clase_accuracy: 0.9006 - val_salidas_continuas_mae: 18.8454 - learning_rate: 2.5000e-04
# Epoch 130/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 840.5963 - salida_clase_accuracy: 0.8706 - salidas_continuas_mae: 20.8962 - val_loss: 793.5715 - val_salida_clase_accuracy: 0.9094 - val_salidas_continuas_mae: 19.0017 - learning_rate: 2.5000e-04
# Epoch 131/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 835.0455 - salida_clase_accuracy: 0.8752 - salidas_continuas_mae: 20.6324 - val_loss: 793.0884 - val_salida_clase_accuracy: 0.9079 - val_salidas_continuas_mae: 18.8851 - learning_rate: 2.5000e-04
# Epoch 132/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 815.0797 - salida_clase_accuracy: 0.8719 - salidas_continuas_mae: 20.5333 - val_loss: 788.9381 - val_salida_clase_accuracy: 0.8977 - val_salidas_continuas_mae: 18.7762 - learning_rate: 2.5000e-04
# Epoch 133/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 808.7212 - salida_clase_accuracy: 0.8692 - salidas_continuas_mae: 20.4977 - val_loss: 786.8561 - val_salida_clase_accuracy: 0.9006 - val_salidas_continuas_mae: 18.7151 - learning_rate: 2.5000e-04
# Epoch 134/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 853.0953 - salida_clase_accuracy: 0.8747 - salidas_continuas_mae: 20.8924 - val_loss: 793.2090 - val_salida_clase_accuracy: 0.9006 - val_salidas_continuas_mae: 18.9255 - learning_rate: 2.5000e-04
# Epoch 135/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 829.9700 - salida_clase_accuracy: 0.8796 - salidas_continuas_mae: 20.5565 - val_loss: 791.2009 - val_salida_clase_accuracy: 0.8977 - val_salidas_continuas_mae: 18.8761 - learning_rate: 2.5000e-04
# Epoch 136/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 816.7787 - salida_clase_accuracy: 0.8830 - salidas_continuas_mae: 20.3980 - val_loss: 799.9803 - val_salida_clase_accuracy: 0.9050 - val_salidas_continuas_mae: 19.2139 - learning_rate: 2.5000e-04
# Epoch 137/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 846.3704 - salida_clase_accuracy: 0.8843 - salidas_continuas_mae: 20.7879 - val_loss: 797.4910 - val_salida_clase_accuracy: 0.8962 - val_salidas_continuas_mae: 19.1444 - learning_rate: 2.5000e-04
# Epoch 138/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 840.6072 - salida_clase_accuracy: 0.8609 - salidas_continuas_mae: 21.0240 - val_loss: 790.4418 - val_salida_clase_accuracy: 0.9006 - val_salidas_continuas_mae: 18.8978 - learning_rate: 2.5000e-04
# Epoch 139/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 886.1355 - salida_clase_accuracy: 0.8798 - salidas_continuas_mae: 21.2320 - val_loss: 789.6206 - val_salida_clase_accuracy: 0.9064 - val_salidas_continuas_mae: 18.8967 - learning_rate: 1.2500e-04
# Epoch 140/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 837.0975 - salida_clase_accuracy: 0.8896 - salidas_continuas_mae: 20.6618 - val_loss: 784.2301 - val_salida_clase_accuracy: 0.9020 - val_salidas_continuas_mae: 18.7692 - learning_rate: 1.2500e-04
# Epoch 141/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 841.7917 - salida_clase_accuracy: 0.8896 - salidas_continuas_mae: 20.7800 - val_loss: 785.3991 - val_salida_clase_accuracy: 0.9035 - val_salidas_continuas_mae: 18.7916 - learning_rate: 1.2500e-04
# Epoch 142/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 850.9015 - salida_clase_accuracy: 0.8825 - salidas_continuas_mae: 20.9431 - val_loss: 790.2528 - val_salida_clase_accuracy: 0.9035 - val_salidas_continuas_mae: 18.9271 - learning_rate: 1.2500e-04
# Epoch 143/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 835.5641 - salida_clase_accuracy: 0.8921 - salidas_continuas_mae: 20.8762 - val_loss: 783.9417 - val_salida_clase_accuracy: 0.9020 - val_salidas_continuas_mae: 18.7402 - learning_rate: 1.2500e-04
# Epoch 144/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 830.6865 - salida_clase_accuracy: 0.8826 - salidas_continuas_mae: 20.5757 - val_loss: 780.6386 - val_salida_clase_accuracy: 0.9035 - val_salidas_continuas_mae: 18.6377 - learning_rate: 1.2500e-04
# Epoch 145/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 826.0082 - salida_clase_accuracy: 0.8939 - salidas_continuas_mae: 20.5744 - val_loss: 782.4532 - val_salida_clase_accuracy: 0.9020 - val_salidas_continuas_mae: 18.7657 - learning_rate: 1.2500e-04
# Epoch 146/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 823.5165 - salida_clase_accuracy: 0.8926 - salidas_continuas_mae: 20.5467 - val_loss: 785.4656 - val_salida_clase_accuracy: 0.9064 - val_salidas_continuas_mae: 18.8877 - learning_rate: 1.2500e-04
# Epoch 147/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 789.7325 - salida_clase_accuracy: 0.8670 - salidas_continuas_mae: 20.2932 - val_loss: 783.9174 - val_salida_clase_accuracy: 0.9064 - val_salidas_continuas_mae: 18.8158 - learning_rate: 1.2500e-04
# Epoch 148/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 827.9676 - salida_clase_accuracy: 0.8771 - salidas_continuas_mae: 20.6768 - val_loss: 786.5903 - val_salida_clase_accuracy: 0.9108 - val_salidas_continuas_mae: 18.9334 - learning_rate: 1.2500e-04
# Epoch 149/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 814.3530 - salida_clase_accuracy: 0.8864 - salidas_continuas_mae: 20.4853 - val_loss: 782.4060 - val_salida_clase_accuracy: 0.9137 - val_salidas_continuas_mae: 18.7930 - learning_rate: 1.2500e-04
# Epoch 150/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 838.0450 - salida_clase_accuracy: 0.8816 - salidas_continuas_mae: 20.6877 - val_loss: 783.1758 - val_salida_clase_accuracy: 0.9064 - val_salidas_continuas_mae: 18.8043 - learning_rate: 6.2500e-05
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 703.2351 - salida_clase_accuracy: 0.9200 - salidas_continuas_mae: 17.5665
# Fold 5: Loss=704.4244384765625, MAE=17.662622451782227, Accuracy=0.922897219657898
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 706.4020874023438
# MAE: 17.720210977800168
# MSE: 705.9541247074274
# RMSE: 26.568232302335673
# R^2: 0.80759149301481
# Accuracy: 0.9224299192428589
# Precisión: 0.9244995068932796
# Recall: 0.9224299065420561
# F1-Score: 0.9223542609857329
