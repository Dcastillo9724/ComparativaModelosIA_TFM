# %%
import joblib
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Cargar datos
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Videos_Pose', 'pose_data.csv')
ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual, 'datos', 'scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')

data = pd.read_csv(ruta_csv)

# Preparar datos
num_keypoints = 17 * 3
X = data.iloc[:, :num_keypoints].values
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

X_train, X_test, y_continuas_train, y_continuas_test, y_clase_train, y_clase_test = train_test_split(
    X, y_continuas, y_clase_encoded, test_size=0.2, random_state=42)

scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

X_train_cnn = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_cnn = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

# Función para crear el modelo con ajustes de hiperparámetros
def create_model(learning_rate=0.001):
    input_layer = Input(shape=(X_train_cnn.shape[1], X_train_cnn.shape[2]))
    x = Conv1D(64, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(input_layer)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Conv1D(64, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Conv1D(32, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Flatten()(x)
    
    salidas_continuas = Dense(10, activation='linear', name='salidas_continuas')(x)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)
    
    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])
    
    optimizer = Adam(learning_rate=learning_rate)
    
    model.compile(optimizer=optimizer,
                  loss={'salidas_continuas': 'mean_squared_error', 'salida_clase': 'sparse_categorical_crossentropy'},
                  metrics={'salidas_continuas': 'mae', 'salida_clase': 'accuracy'})
    
    return model

# Listas para almacenar métricas
all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

# Matrices para almacenar la historia del entrenamiento
n_epochs = 50  # Número de épocas
all_train_loss = np.full((5, n_epochs), np.nan)  
all_val_loss = np.full((5, n_epochs), np.nan)
all_train_accuracy = np.full((5, n_epochs), np.nan)
all_val_accuracy = np.full((5, n_epochs), np.nan)

# Optimización de hiperparámetros y validación cruzada
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

fold_index = 0
for train_index, val_index in kfold.split(X_train_cnn):
    fold_index += 1
    print(f"Entrenando fold {fold_index}...")

    X_train_fold, X_val_fold = X_train_cnn[train_index], X_train_cnn[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas_train[train_index], y_continuas_train[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_train[train_index], y_clase_train[val_index]

    model = create_model(learning_rate=0.0005)  # Ajustar la tasa de aprendizaje aquí
    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold_index}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    # Almacenar la historia del entrenamiento como matrices NumPy
    epochs_completed = len(history.history['loss'])
    all_train_loss[fold_index - 1, :epochs_completed] = history.history['loss']
    all_val_loss[fold_index - 1, :epochs_completed] = history.history['val_loss']
    all_train_accuracy[fold_index - 1, :epochs_completed] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold_index - 1, :epochs_completed] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de prueba
    scores = model.evaluate(X_test_cnn, {'salidas_continuas': y_continuas_test, 'salida_clase': y_clase_test})
    print(f"Fold {fold_index}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_test_cnn)[0]
    mae = mean_absolute_error(y_continuas_test, y_pred_continuas)
    mse = mean_squared_error(y_continuas_test, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_test)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_test_cnn)[1], axis=1)
    precision = precision_score(y_clase_test, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_test, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_test, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_test, y_pred_clase, labels=np.unique(y_clase_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - loss: 24822.0742 - salida_clase_accuracy: 0.5946 - salidas_continuas_mae: 88.6227 - val_loss: 10165.8164 - val_salida_clase_accuracy: 0.8081 - val_salidas_continuas_mae: 57.8163 - learning_rate: 5.0000e-04
# Epoch 2/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 8989.0625 - salida_clase_accuracy: 0.7659 - salidas_continuas_mae: 53.4500 - val_loss: 6293.0713 - val_salida_clase_accuracy: 0.8575 - val_salidas_continuas_mae: 43.6080 - learning_rate: 5.0000e-04
# Epoch 3/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 6558.6450 - salida_clase_accuracy: 0.7981 - salidas_continuas_mae: 44.8058 - val_loss: 4487.0762 - val_salida_clase_accuracy: 0.9055 - val_salidas_continuas_mae: 36.8978 - learning_rate: 5.0000e-04
# Epoch 4/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 4692.3271 - salida_clase_accuracy: 0.8227 - salidas_continuas_mae: 39.1354 - val_loss: 3349.4966 - val_salida_clase_accuracy: 0.9176 - val_salidas_continuas_mae: 33.5144 - learning_rate: 5.0000e-04
# Epoch 5/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3590.9565 - salida_clase_accuracy: 0.8405 - salidas_continuas_mae: 35.7401 - val_loss: 2341.1860 - val_salida_clase_accuracy: 0.9227 - val_salidas_continuas_mae: 29.2182 - learning_rate: 5.0000e-04
# Epoch 6/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2879.0000 - salida_clase_accuracy: 0.8455 - salidas_continuas_mae: 33.2676 - val_loss: 1864.3933 - val_salida_clase_accuracy: 0.9247 - val_salidas_continuas_mae: 27.3762 - learning_rate: 5.0000e-04
# Epoch 7/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2492.6926 - salida_clase_accuracy: 0.8494 - salidas_continuas_mae: 31.6714 - val_loss: 1492.7416 - val_salida_clase_accuracy: 0.9309 - val_salidas_continuas_mae: 24.6489 - learning_rate: 5.0000e-04
# Epoch 8/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2156.6389 - salida_clase_accuracy: 0.8575 - salidas_continuas_mae: 30.1828 - val_loss: 1299.6584 - val_salida_clase_accuracy: 0.9272 - val_salidas_continuas_mae: 23.7530 - learning_rate: 5.0000e-04
# Epoch 9/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1933.2897 - salida_clase_accuracy: 0.8636 - salidas_continuas_mae: 29.2161 - val_loss: 1121.4048 - val_salida_clase_accuracy: 0.9526 - val_salidas_continuas_mae: 22.3420 - learning_rate: 5.0000e-04
# Epoch 10/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1763.8418 - salida_clase_accuracy: 0.8733 - salidas_continuas_mae: 28.2969 - val_loss: 1025.8090 - val_salida_clase_accuracy: 0.9341 - val_salidas_continuas_mae: 21.8281 - learning_rate: 5.0000e-04
# Epoch 11/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1709.6581 - salida_clase_accuracy: 0.8757 - salidas_continuas_mae: 27.7737 - val_loss: 940.4083 - val_salida_clase_accuracy: 0.9453 - val_salidas_continuas_mae: 20.6630 - learning_rate: 5.0000e-04
# Epoch 12/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1616.0533 - salida_clase_accuracy: 0.8796 - salidas_continuas_mae: 27.1984 - val_loss: 892.6085 - val_salida_clase_accuracy: 0.9630 - val_salidas_continuas_mae: 20.1036 - learning_rate: 5.0000e-04
# Epoch 13/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1565.9559 - salida_clase_accuracy: 0.8779 - salidas_continuas_mae: 26.9763 - val_loss: 825.4014 - val_salida_clase_accuracy: 0.9575 - val_salidas_continuas_mae: 19.6078 - learning_rate: 5.0000e-04
# Epoch 14/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1525.7148 - salida_clase_accuracy: 0.8849 - salidas_continuas_mae: 26.6777 - val_loss: 849.3984 - val_salida_clase_accuracy: 0.9571 - val_salidas_continuas_mae: 19.9589 - learning_rate: 5.0000e-04
# Epoch 15/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1463.1379 - salida_clase_accuracy: 0.8917 - salidas_continuas_mae: 26.0621 - val_loss: 756.3370 - val_salida_clase_accuracy: 0.9545 - val_salidas_continuas_mae: 18.7720 - learning_rate: 5.0000e-04
# Epoch 16/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1443.4171 - salida_clase_accuracy: 0.8930 - salidas_continuas_mae: 25.9234 - val_loss: 858.8238 - val_salida_clase_accuracy: 0.9536 - val_salidas_continuas_mae: 20.2505 - learning_rate: 5.0000e-04
# Epoch 17/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1411.4833 - salida_clase_accuracy: 0.8976 - salidas_continuas_mae: 25.6436 - val_loss: 719.0067 - val_salida_clase_accuracy: 0.9579 - val_salidas_continuas_mae: 18.2838 - learning_rate: 5.0000e-04
# Epoch 18/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1414.3267 - salida_clase_accuracy: 0.8970 - salidas_continuas_mae: 25.6236 - val_loss: 776.6733 - val_salida_clase_accuracy: 0.9649 - val_salidas_continuas_mae: 19.6415 - learning_rate: 5.0000e-04
# Epoch 19/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1382.7349 - salida_clase_accuracy: 0.8996 - salidas_continuas_mae: 25.3346 - val_loss: 754.9503 - val_salida_clase_accuracy: 0.9657 - val_salidas_continuas_mae: 19.0785 - learning_rate: 5.0000e-04
# Epoch 20/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1371.4684 - salida_clase_accuracy: 0.9016 - salidas_continuas_mae: 25.1414 - val_loss: 701.7831 - val_salida_clase_accuracy: 0.9673 - val_salidas_continuas_mae: 17.9631 - learning_rate: 5.0000e-04
# Epoch 21/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1323.7522 - salida_clase_accuracy: 0.9010 - salidas_continuas_mae: 24.9089 - val_loss: 686.2610 - val_salida_clase_accuracy: 0.9708 - val_salidas_continuas_mae: 18.0628 - learning_rate: 5.0000e-04
# Epoch 22/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1300.6832 - salida_clase_accuracy: 0.9063 - salidas_continuas_mae: 24.6345 - val_loss: 736.0978 - val_salida_clase_accuracy: 0.9603 - val_salidas_continuas_mae: 18.9425 - learning_rate: 5.0000e-04
# Epoch 23/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1311.2688 - salida_clase_accuracy: 0.9047 - salidas_continuas_mae: 24.7565 - val_loss: 650.3357 - val_salida_clase_accuracy: 0.9706 - val_salidas_continuas_mae: 16.9132 - learning_rate: 5.0000e-04
# Epoch 24/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1299.9803 - salida_clase_accuracy: 0.9078 - salidas_continuas_mae: 24.5351 - val_loss: 644.1799 - val_salida_clase_accuracy: 0.9729 - val_salidas_continuas_mae: 17.2913 - learning_rate: 5.0000e-04
# Epoch 25/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1277.0117 - salida_clase_accuracy: 0.9108 - salidas_continuas_mae: 24.4068 - val_loss: 664.4196 - val_salida_clase_accuracy: 0.9729 - val_salidas_continuas_mae: 17.5308 - learning_rate: 5.0000e-04
# Epoch 26/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1263.2532 - salida_clase_accuracy: 0.9084 - salidas_continuas_mae: 24.2679 - val_loss: 629.1457 - val_salida_clase_accuracy: 0.9642 - val_salidas_continuas_mae: 17.0132 - learning_rate: 5.0000e-04
# Epoch 27/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1277.7048 - salida_clase_accuracy: 0.9095 - salidas_continuas_mae: 24.2310 - val_loss: 637.4086 - val_salida_clase_accuracy: 0.9719 - val_salidas_continuas_mae: 16.9838 - learning_rate: 5.0000e-04
# Epoch 28/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1252.0350 - salida_clase_accuracy: 0.9172 - salidas_continuas_mae: 24.0962 - val_loss: 618.2700 - val_salida_clase_accuracy: 0.9662 - val_salidas_continuas_mae: 16.6871 - learning_rate: 5.0000e-04
# Epoch 29/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1267.3369 - salida_clase_accuracy: 0.9130 - salidas_continuas_mae: 24.1689 - val_loss: 649.8138 - val_salida_clase_accuracy: 0.9764 - val_salidas_continuas_mae: 17.4764 - learning_rate: 5.0000e-04
# Epoch 30/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1238.6632 - salida_clase_accuracy: 0.9138 - salidas_continuas_mae: 23.8802 - val_loss: 617.5902 - val_salida_clase_accuracy: 0.9729 - val_salidas_continuas_mae: 16.9214 - learning_rate: 5.0000e-04
# Epoch 31/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1208.6798 - salida_clase_accuracy: 0.9192 - salidas_continuas_mae: 23.7697 - val_loss: 597.9119 - val_salida_clase_accuracy: 0.9722 - val_salidas_continuas_mae: 16.6214 - learning_rate: 5.0000e-04
# Epoch 32/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1213.6578 - salida_clase_accuracy: 0.9162 - salidas_continuas_mae: 23.7295 - val_loss: 618.3145 - val_salida_clase_accuracy: 0.9703 - val_salidas_continuas_mae: 16.8580 - learning_rate: 5.0000e-04
# Epoch 33/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1198.7799 - salida_clase_accuracy: 0.9227 - salidas_continuas_mae: 23.5865 - val_loss: 608.5070 - val_salida_clase_accuracy: 0.9757 - val_salidas_continuas_mae: 16.9474 - learning_rate: 5.0000e-04
# Epoch 34/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1195.3898 - salida_clase_accuracy: 0.9204 - salidas_continuas_mae: 23.5617 - val_loss: 588.1496 - val_salida_clase_accuracy: 0.9751 - val_salidas_continuas_mae: 16.3312 - learning_rate: 5.0000e-04
# Epoch 35/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1199.2173 - salida_clase_accuracy: 0.9201 - salidas_continuas_mae: 23.5404 - val_loss: 581.2975 - val_salida_clase_accuracy: 0.9777 - val_salidas_continuas_mae: 16.1839 - learning_rate: 5.0000e-04
# Epoch 36/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1179.9702 - salida_clase_accuracy: 0.9202 - salidas_continuas_mae: 23.3815 - val_loss: 599.0887 - val_salida_clase_accuracy: 0.9746 - val_salidas_continuas_mae: 16.6514 - learning_rate: 5.0000e-04
# Epoch 37/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1195.5964 - salida_clase_accuracy: 0.9206 - salidas_continuas_mae: 23.4352 - val_loss: 581.5757 - val_salida_clase_accuracy: 0.9689 - val_salidas_continuas_mae: 16.2486 - learning_rate: 5.0000e-04
# Epoch 38/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1167.7892 - salida_clase_accuracy: 0.9192 - salidas_continuas_mae: 23.3068 - val_loss: 634.8796 - val_salida_clase_accuracy: 0.9767 - val_salidas_continuas_mae: 16.9132 - learning_rate: 5.0000e-04
# Epoch 39/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1172.0514 - salida_clase_accuracy: 0.9200 - salidas_continuas_mae: 23.2295 - val_loss: 579.1193 - val_salida_clase_accuracy: 0.9764 - val_salidas_continuas_mae: 16.2218 - learning_rate: 5.0000e-04
# Epoch 40/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1155.8314 - salida_clase_accuracy: 0.9200 - salidas_continuas_mae: 23.1066 - val_loss: 638.7601 - val_salida_clase_accuracy: 0.9797 - val_salidas_continuas_mae: 17.5907 - learning_rate: 5.0000e-04
# Epoch 41/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1187.6689 - salida_clase_accuracy: 0.9252 - salidas_continuas_mae: 23.2770 - val_loss: 582.8307 - val_salida_clase_accuracy: 0.9769 - val_salidas_continuas_mae: 16.1752 - learning_rate: 5.0000e-04
# Epoch 42/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1144.0532 - salida_clase_accuracy: 0.9249 - salidas_continuas_mae: 23.0565 - val_loss: 574.3453 - val_salida_clase_accuracy: 0.9753 - val_salidas_continuas_mae: 16.3077 - learning_rate: 5.0000e-04
# Epoch 43/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 1168.8350 - salida_clase_accuracy: 0.9206 - salidas_continuas_mae: 23.1387 - val_loss: 572.6334 - val_salida_clase_accuracy: 0.9820 - val_salidas_continuas_mae: 16.4808 - learning_rate: 5.0000e-04
# Epoch 44/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1135.9393 - salida_clase_accuracy: 0.9254 - salidas_continuas_mae: 22.9077 - val_loss: 591.2350 - val_salida_clase_accuracy: 0.9775 - val_salidas_continuas_mae: 16.6268 - learning_rate: 5.0000e-04
# Epoch 45/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1153.8297 - salida_clase_accuracy: 0.9287 - salidas_continuas_mae: 22.9912 - val_loss: 576.2990 - val_salida_clase_accuracy: 0.9764 - val_salidas_continuas_mae: 16.3203 - learning_rate: 5.0000e-04
# Epoch 46/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1132.3182 - salida_clase_accuracy: 0.9234 - salidas_continuas_mae: 22.8147 - val_loss: 567.5762 - val_salida_clase_accuracy: 0.9777 - val_salidas_continuas_mae: 16.1140 - learning_rate: 5.0000e-04
# Epoch 47/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1128.7305 - salida_clase_accuracy: 0.9282 - salidas_continuas_mae: 22.8817 - val_loss: 609.4213 - val_salida_clase_accuracy: 0.9802 - val_salidas_continuas_mae: 17.0887 - learning_rate: 5.0000e-04
# Epoch 48/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1138.9366 - salida_clase_accuracy: 0.9218 - salidas_continuas_mae: 22.8860 - val_loss: 559.9805 - val_salida_clase_accuracy: 0.9794 - val_salidas_continuas_mae: 15.8388 - learning_rate: 5.0000e-04
# Epoch 49/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1126.3964 - salida_clase_accuracy: 0.9289 - salidas_continuas_mae: 22.7582 - val_loss: 557.8776 - val_salida_clase_accuracy: 0.9682 - val_salidas_continuas_mae: 15.9203 - learning_rate: 5.0000e-04
# Epoch 50/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1130.4700 - salida_clase_accuracy: 0.9319 - salidas_continuas_mae: 22.7880 - val_loss: 644.3275 - val_salida_clase_accuracy: 0.9754 - val_salidas_continuas_mae: 17.9221 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 555.6017 - salida_clase_accuracy: 0.9694 - salidas_continuas_mae: 15.9727
# Fold 1: Loss=547.993408203125, MAE=15.861807823181152, Accuracy=0.9675648212432861
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Entrenando fold 2...
# Epoch 1/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 24606.7949 - salida_clase_accuracy: 0.6027 - salidas_continuas_mae: 88.3995 - val_loss: 10023.3301 - val_salida_clase_accuracy: 0.8281 - val_salidas_continuas_mae: 56.4181 - learning_rate: 5.0000e-04
# Epoch 2/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 9211.4082 - salida_clase_accuracy: 0.7678 - salidas_continuas_mae: 53.8974 - val_loss: 6998.7153 - val_salida_clase_accuracy: 0.8776 - val_salidas_continuas_mae: 46.0064 - learning_rate: 5.0000e-04
# Epoch 3/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 6600.9336 - salida_clase_accuracy: 0.8020 - salidas_continuas_mae: 45.2034 - val_loss: 5354.9688 - val_salida_clase_accuracy: 0.8964 - val_salidas_continuas_mae: 40.7265 - learning_rate: 5.0000e-04
# Epoch 4/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 5152.7788 - salida_clase_accuracy: 0.8277 - salidas_continuas_mae: 40.4063 - val_loss: 3589.1926 - val_salida_clase_accuracy: 0.9156 - val_salidas_continuas_mae: 34.4379 - learning_rate: 5.0000e-04
# Epoch 5/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 4002.4204 - salida_clase_accuracy: 0.8418 - salidas_continuas_mae: 36.9950 - val_loss: 2879.6709 - val_salida_clase_accuracy: 0.9235 - val_salidas_continuas_mae: 32.0956 - learning_rate: 5.0000e-04
# Epoch 6/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 3278.3752 - salida_clase_accuracy: 0.8549 - salidas_continuas_mae: 34.4354 - val_loss: 2191.8748 - val_salida_clase_accuracy: 0.9291 - val_salidas_continuas_mae: 28.3811 - learning_rate: 5.0000e-04
# Epoch 7/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2806.2261 - salida_clase_accuracy: 0.8615 - salidas_continuas_mae: 32.6532 - val_loss: 1813.5287 - val_salida_clase_accuracy: 0.9377 - val_salidas_continuas_mae: 26.9355 - learning_rate: 5.0000e-04
# Epoch 8/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2381.3176 - salida_clase_accuracy: 0.8546 - salidas_continuas_mae: 31.0570 - val_loss: 1526.9077 - val_salida_clase_accuracy: 0.9422 - val_salidas_continuas_mae: 25.5523 - learning_rate: 5.0000e-04
# Epoch 9/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 2115.8455 - salida_clase_accuracy: 0.8656 - salidas_continuas_mae: 29.8411 - val_loss: 1299.2985 - val_salida_clase_accuracy: 0.9291 - val_salidas_continuas_mae: 23.8794 - learning_rate: 5.0000e-04
# Epoch 10/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1967.2787 - salida_clase_accuracy: 0.8739 - salidas_continuas_mae: 29.1670 - val_loss: 1207.5833 - val_salida_clase_accuracy: 0.9484 - val_salidas_continuas_mae: 23.3655 - learning_rate: 5.0000e-04
# Epoch 11/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1807.4489 - salida_clase_accuracy: 0.8747 - salidas_continuas_mae: 28.2903 - val_loss: 1048.7997 - val_salida_clase_accuracy: 0.9283 - val_salidas_continuas_mae: 21.5666 - learning_rate: 5.0000e-04
# Epoch 12/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1716.2653 - salida_clase_accuracy: 0.8751 - salidas_continuas_mae: 27.7272 - val_loss: 958.9828 - val_salida_clase_accuracy: 0.9489 - val_salidas_continuas_mae: 20.6313 - learning_rate: 5.0000e-04
# Epoch 13/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1660.9415 - salida_clase_accuracy: 0.8779 - salidas_continuas_mae: 27.3743 - val_loss: 894.6181 - val_salida_clase_accuracy: 0.9520 - val_salidas_continuas_mae: 20.1845 - learning_rate: 5.0000e-04
# Epoch 14/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1562.1676 - salida_clase_accuracy: 0.8822 - salidas_continuas_mae: 26.6515 - val_loss: 854.1829 - val_salida_clase_accuracy: 0.9387 - val_salidas_continuas_mae: 19.9433 - learning_rate: 5.0000e-04
# Epoch 15/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1549.5144 - salida_clase_accuracy: 0.8907 - salidas_continuas_mae: 26.5299 - val_loss: 815.5627 - val_salida_clase_accuracy: 0.9540 - val_salidas_continuas_mae: 19.3277 - learning_rate: 5.0000e-04
# Epoch 16/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1481.9272 - salida_clase_accuracy: 0.8966 - salidas_continuas_mae: 26.0693 - val_loss: 859.2953 - val_salida_clase_accuracy: 0.9334 - val_salidas_continuas_mae: 19.8697 - learning_rate: 5.0000e-04
# Epoch 17/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1471.0297 - salida_clase_accuracy: 0.8952 - salidas_continuas_mae: 25.9515 - val_loss: 762.9081 - val_salida_clase_accuracy: 0.9520 - val_salidas_continuas_mae: 18.8050 - learning_rate: 5.0000e-04
# Epoch 18/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1408.1295 - salida_clase_accuracy: 0.8957 - salidas_continuas_mae: 25.5260 - val_loss: 759.0885 - val_salida_clase_accuracy: 0.9563 - val_salidas_continuas_mae: 18.9186 - learning_rate: 5.0000e-04
# Epoch 19/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1431.3754 - salida_clase_accuracy: 0.9029 - salidas_continuas_mae: 25.6097 - val_loss: 733.5290 - val_salida_clase_accuracy: 0.9465 - val_salidas_continuas_mae: 18.5161 - learning_rate: 5.0000e-04
# Epoch 20/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1399.0106 - salida_clase_accuracy: 0.9032 - salidas_continuas_mae: 25.3568 - val_loss: 736.6570 - val_salida_clase_accuracy: 0.9580 - val_salidas_continuas_mae: 18.3742 - learning_rate: 5.0000e-04
# Epoch 21/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1387.3669 - salida_clase_accuracy: 0.8996 - salidas_continuas_mae: 25.2065 - val_loss: 712.9946 - val_salida_clase_accuracy: 0.9419 - val_salidas_continuas_mae: 18.2232 - learning_rate: 5.0000e-04
# Epoch 22/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1354.0508 - salida_clase_accuracy: 0.9059 - salidas_continuas_mae: 25.0093 - val_loss: 677.8832 - val_salida_clase_accuracy: 0.9497 - val_salidas_continuas_mae: 17.7139 - learning_rate: 5.0000e-04
# Epoch 23/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1347.1621 - salida_clase_accuracy: 0.8998 - salidas_continuas_mae: 24.9083 - val_loss: 658.2638 - val_salida_clase_accuracy: 0.9374 - val_salidas_continuas_mae: 17.3418 - learning_rate: 5.0000e-04
# Epoch 24/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1322.9388 - salida_clase_accuracy: 0.9078 - salidas_continuas_mae: 24.6773 - val_loss: 672.1621 - val_salida_clase_accuracy: 0.9575 - val_salidas_continuas_mae: 17.7891 - learning_rate: 5.0000e-04
# Epoch 25/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - loss: 1304.0947 - salida_clase_accuracy: 0.9136 - salidas_continuas_mae: 24.5119 - val_loss: 681.0734 - val_salida_clase_accuracy: 0.9564 - val_salidas_continuas_mae: 17.5741 - learning_rate: 5.0000e-04
# Epoch 26/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1302.9327 - salida_clase_accuracy: 0.9124 - salidas_continuas_mae: 24.5180 - val_loss: 628.7460 - val_salida_clase_accuracy: 0.9628 - val_salidas_continuas_mae: 16.8768 - learning_rate: 5.0000e-04
# Epoch 27/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1285.7283 - salida_clase_accuracy: 0.9096 - salidas_continuas_mae: 24.2977 - val_loss: 657.8438 - val_salida_clase_accuracy: 0.9559 - val_salidas_continuas_mae: 17.5975 - learning_rate: 5.0000e-04
# Epoch 28/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1259.6547 - salida_clase_accuracy: 0.9098 - salidas_continuas_mae: 24.1010 - val_loss: 612.9742 - val_salida_clase_accuracy: 0.9611 - val_salidas_continuas_mae: 16.7569 - learning_rate: 5.0000e-04
# Epoch 29/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1262.6300 - salida_clase_accuracy: 0.9156 - salidas_continuas_mae: 24.1723 - val_loss: 611.8598 - val_salida_clase_accuracy: 0.9489 - val_salidas_continuas_mae: 16.6491 - learning_rate: 5.0000e-04
# Epoch 30/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1260.6239 - salida_clase_accuracy: 0.9084 - salidas_continuas_mae: 23.9582 - val_loss: 596.6938 - val_salida_clase_accuracy: 0.9583 - val_salidas_continuas_mae: 16.4775 - learning_rate: 5.0000e-04
# Epoch 31/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1267.6079 - salida_clase_accuracy: 0.9166 - salidas_continuas_mae: 23.9919 - val_loss: 609.6346 - val_salida_clase_accuracy: 0.9660 - val_salidas_continuas_mae: 16.8594 - learning_rate: 5.0000e-04
# Epoch 32/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1219.5588 - salida_clase_accuracy: 0.9163 - salidas_continuas_mae: 23.7466 - val_loss: 636.6455 - val_salida_clase_accuracy: 0.9571 - val_salidas_continuas_mae: 17.3715 - learning_rate: 5.0000e-04
# Epoch 33/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1258.5015 - salida_clase_accuracy: 0.9145 - salidas_continuas_mae: 23.9234 - val_loss: 608.8099 - val_salida_clase_accuracy: 0.9650 - val_salidas_continuas_mae: 16.7790 - learning_rate: 5.0000e-04
# Epoch 34/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1226.5078 - salida_clase_accuracy: 0.9158 - salidas_continuas_mae: 23.7135 - val_loss: 619.6201 - val_salida_clase_accuracy: 0.9588 - val_salidas_continuas_mae: 16.7440 - learning_rate: 5.0000e-04
# Epoch 35/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1243.5415 - salida_clase_accuracy: 0.9222 - salidas_continuas_mae: 23.7931 - val_loss: 563.7913 - val_salida_clase_accuracy: 0.9619 - val_salidas_continuas_mae: 15.7088 - learning_rate: 5.0000e-04
# Epoch 36/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1215.2515 - salida_clase_accuracy: 0.9232 - salidas_continuas_mae: 23.6166 - val_loss: 607.4075 - val_salida_clase_accuracy: 0.9658 - val_salidas_continuas_mae: 16.8542 - learning_rate: 5.0000e-04
# Epoch 37/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1200.7413 - salida_clase_accuracy: 0.9243 - salidas_continuas_mae: 23.4787 - val_loss: 584.8654 - val_salida_clase_accuracy: 0.9636 - val_salidas_continuas_mae: 16.3942 - learning_rate: 5.0000e-04
# Epoch 38/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1191.1416 - salida_clase_accuracy: 0.9226 - salidas_continuas_mae: 23.4663 - val_loss: 589.4068 - val_salida_clase_accuracy: 0.9611 - val_salidas_continuas_mae: 16.2111 - learning_rate: 5.0000e-04
# Epoch 39/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1201.2286 - salida_clase_accuracy: 0.9163 - salidas_continuas_mae: 23.5374 - val_loss: 597.2517 - val_salida_clase_accuracy: 0.9700 - val_salidas_continuas_mae: 16.7365 - learning_rate: 5.0000e-04
# Epoch 40/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1190.5846 - salida_clase_accuracy: 0.9197 - salidas_continuas_mae: 23.3485 - val_loss: 578.9059 - val_salida_clase_accuracy: 0.9646 - val_salidas_continuas_mae: 16.3542 - learning_rate: 5.0000e-04
# Epoch 41/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1171.4301 - salida_clase_accuracy: 0.9247 - salidas_continuas_mae: 23.2143 - val_loss: 585.5269 - val_salida_clase_accuracy: 0.9700 - val_salidas_continuas_mae: 16.5400 - learning_rate: 2.5000e-04
# Epoch 42/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1157.1212 - salida_clase_accuracy: 0.9271 - salidas_continuas_mae: 23.0489 - val_loss: 591.0911 - val_salida_clase_accuracy: 0.9711 - val_salidas_continuas_mae: 16.4380 - learning_rate: 2.5000e-04
# Epoch 43/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1154.8044 - salida_clase_accuracy: 0.9342 - salidas_continuas_mae: 23.0344 - val_loss: 584.1656 - val_salida_clase_accuracy: 0.9716 - val_salidas_continuas_mae: 16.3119 - learning_rate: 2.5000e-04
# Epoch 44/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 1183.0901 - salida_clase_accuracy: 0.9356 - salidas_continuas_mae: 23.2130 - val_loss: 565.0995 - val_salida_clase_accuracy: 0.9757 - val_salidas_continuas_mae: 16.0797 - learning_rate: 2.5000e-04
# Epoch 45/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 1136.5603 - salida_clase_accuracy: 0.9282 - salidas_continuas_mae: 22.8243 - val_loss: 571.4952 - val_salida_clase_accuracy: 0.9745 - val_salidas_continuas_mae: 16.1053 - learning_rate: 2.5000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 568.5467 - salida_clase_accuracy: 0.9601 - salidas_continuas_mae: 15.7908
# Fold 2: Loss=564.4303588867188, MAE=15.742795944213867, Accuracy=0.960924506187439
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Entrenando fold 3...
# Epoch 1/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 24940.1074 - salida_clase_accuracy: 0.5939 - salidas_continuas_mae: 88.4030 - val_loss: 9980.9160 - val_salida_clase_accuracy: 0.8143 - val_salidas_continuas_mae: 56.4615 - learning_rate: 5.0000e-04
# Epoch 2/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 9088.7246 - salida_clase_accuracy: 0.7566 - salidas_continuas_mae: 53.6857 - val_loss: 6659.4878 - val_salida_clase_accuracy: 0.8715 - val_salidas_continuas_mae: 45.8763 - learning_rate: 5.0000e-04
# Epoch 3/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 6418.3433 - salida_clase_accuracy: 0.7955 - salidas_continuas_mae: 45.1714 - val_loss: 4626.0513 - val_salida_clase_accuracy: 0.9037 - val_salidas_continuas_mae: 38.3102 - learning_rate: 5.0000e-04
# Epoch 4/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 4918.9531 - salida_clase_accuracy: 0.8322 - salidas_continuas_mae: 40.0763 - val_loss: 3413.9980 - val_salida_clase_accuracy: 0.9120 - val_salidas_continuas_mae: 33.9003 - learning_rate: 5.0000e-04
# Epoch 5/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 3704.7009 - salida_clase_accuracy: 0.8458 - salidas_continuas_mae: 36.2485 - val_loss: 2603.1018 - val_salida_clase_accuracy: 0.9240 - val_salidas_continuas_mae: 31.0493 - learning_rate: 5.0000e-04
# Epoch 6/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 2999.9702 - salida_clase_accuracy: 0.8444 - salidas_continuas_mae: 33.8312 - val_loss: 2006.8812 - val_salida_clase_accuracy: 0.9307 - val_salidas_continuas_mae: 27.4708 - learning_rate: 5.0000e-04
# Epoch 7/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 2551.8765 - salida_clase_accuracy: 0.8602 - salidas_continuas_mae: 31.9557 - val_loss: 1652.4694 - val_salida_clase_accuracy: 0.9192 - val_salidas_continuas_mae: 26.4420 - learning_rate: 5.0000e-04
# Epoch 8/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 2181.9802 - salida_clase_accuracy: 0.8639 - salidas_continuas_mae: 30.4562 - val_loss: 1371.6453 - val_salida_clase_accuracy: 0.9299 - val_salidas_continuas_mae: 24.3755 - learning_rate: 5.0000e-04
# Epoch 9/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1974.8729 - salida_clase_accuracy: 0.8690 - salidas_continuas_mae: 29.2907 - val_loss: 1214.8627 - val_salida_clase_accuracy: 0.9293 - val_salidas_continuas_mae: 23.4039 - learning_rate: 5.0000e-04
# Epoch 10/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1848.8618 - salida_clase_accuracy: 0.8742 - salidas_continuas_mae: 28.6906 - val_loss: 1153.0594 - val_salida_clase_accuracy: 0.9393 - val_salidas_continuas_mae: 22.6208 - learning_rate: 5.0000e-04
# Epoch 11/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1710.2292 - salida_clase_accuracy: 0.8806 - salidas_continuas_mae: 27.8358 - val_loss: 997.8337 - val_salida_clase_accuracy: 0.9427 - val_salidas_continuas_mae: 21.3460 - learning_rate: 5.0000e-04
# Epoch 12/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1663.8374 - salida_clase_accuracy: 0.8840 - salidas_continuas_mae: 27.4642 - val_loss: 963.9257 - val_salida_clase_accuracy: 0.9397 - val_salidas_continuas_mae: 21.0908 - learning_rate: 5.0000e-04
# Epoch 13/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1559.7115 - salida_clase_accuracy: 0.8850 - salidas_continuas_mae: 26.8106 - val_loss: 877.9818 - val_salida_clase_accuracy: 0.9489 - val_salidas_continuas_mae: 20.1203 - learning_rate: 5.0000e-04
# Epoch 14/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 1545.2656 - salida_clase_accuracy: 0.8831 - salidas_continuas_mae: 26.6430 - val_loss: 842.0825 - val_salida_clase_accuracy: 0.9472 - val_salidas_continuas_mae: 19.6728 - learning_rate: 5.0000e-04
# Epoch 15/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1478.5162 - salida_clase_accuracy: 0.8945 - salidas_continuas_mae: 26.1278 - val_loss: 813.5732 - val_salida_clase_accuracy: 0.9555 - val_salidas_continuas_mae: 19.5623 - learning_rate: 5.0000e-04
# Epoch 16/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1451.7195 - salida_clase_accuracy: 0.8972 - salidas_continuas_mae: 25.8765 - val_loss: 810.0433 - val_salida_clase_accuracy: 0.9550 - val_salidas_continuas_mae: 19.3322 - learning_rate: 5.0000e-04
# Epoch 17/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1440.3680 - salida_clase_accuracy: 0.8980 - salidas_continuas_mae: 25.6716 - val_loss: 737.5365 - val_salida_clase_accuracy: 0.9598 - val_salidas_continuas_mae: 18.5734 - learning_rate: 5.0000e-04
# Epoch 18/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1419.6456 - salida_clase_accuracy: 0.9004 - salidas_continuas_mae: 25.3870 - val_loss: 761.3519 - val_salida_clase_accuracy: 0.9580 - val_salidas_continuas_mae: 18.8695 - learning_rate: 5.0000e-04
# Epoch 19/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1380.5786 - salida_clase_accuracy: 0.9006 - salidas_continuas_mae: 25.2615 - val_loss: 718.9826 - val_salida_clase_accuracy: 0.9527 - val_salidas_continuas_mae: 18.2620 - learning_rate: 5.0000e-04
# Epoch 20/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1353.6874 - salida_clase_accuracy: 0.9097 - salidas_continuas_mae: 24.9978 - val_loss: 702.3997 - val_salida_clase_accuracy: 0.9523 - val_salidas_continuas_mae: 18.1476 - learning_rate: 5.0000e-04
# Epoch 21/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1333.2821 - salida_clase_accuracy: 0.9024 - salidas_continuas_mae: 24.8890 - val_loss: 705.3320 - val_salida_clase_accuracy: 0.9516 - val_salidas_continuas_mae: 18.2613 - learning_rate: 5.0000e-04
# Epoch 22/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1316.9215 - salida_clase_accuracy: 0.9082 - salidas_continuas_mae: 24.6867 - val_loss: 674.8081 - val_salida_clase_accuracy: 0.9631 - val_salidas_continuas_mae: 17.7263 - learning_rate: 5.0000e-04
# Epoch 23/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1280.5957 - salida_clase_accuracy: 0.9089 - salidas_continuas_mae: 24.3762 - val_loss: 704.1904 - val_salida_clase_accuracy: 0.9585 - val_salidas_continuas_mae: 18.2921 - learning_rate: 5.0000e-04
# Epoch 24/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1273.2139 - salida_clase_accuracy: 0.9111 - salidas_continuas_mae: 24.3987 - val_loss: 686.0185 - val_salida_clase_accuracy: 0.9539 - val_salidas_continuas_mae: 17.9854 - learning_rate: 5.0000e-04
# Epoch 25/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1268.5374 - salida_clase_accuracy: 0.9048 - salidas_continuas_mae: 24.1530 - val_loss: 663.6165 - val_salida_clase_accuracy: 0.9663 - val_salidas_continuas_mae: 17.8688 - learning_rate: 5.0000e-04
# Epoch 26/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1255.6792 - salida_clase_accuracy: 0.9112 - salidas_continuas_mae: 24.1615 - val_loss: 627.9224 - val_salida_clase_accuracy: 0.9553 - val_salidas_continuas_mae: 16.8906 - learning_rate: 5.0000e-04
# Epoch 27/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1238.6934 - salida_clase_accuracy: 0.9158 - salidas_continuas_mae: 23.9621 - val_loss: 626.9622 - val_salida_clase_accuracy: 0.9686 - val_salidas_continuas_mae: 17.1409 - learning_rate: 5.0000e-04
# Epoch 28/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1228.1685 - salida_clase_accuracy: 0.9174 - salidas_continuas_mae: 23.8428 - val_loss: 643.0142 - val_salida_clase_accuracy: 0.9673 - val_salidas_continuas_mae: 17.3328 - learning_rate: 5.0000e-04
# Epoch 29/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1216.1949 - salida_clase_accuracy: 0.9181 - salidas_continuas_mae: 23.7529 - val_loss: 636.3253 - val_salida_clase_accuracy: 0.9575 - val_salidas_continuas_mae: 17.2242 - learning_rate: 5.0000e-04
# Epoch 30/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1249.4111 - salida_clase_accuracy: 0.9151 - salidas_continuas_mae: 23.9061 - val_loss: 604.9806 - val_salida_clase_accuracy: 0.9610 - val_salidas_continuas_mae: 16.7789 - learning_rate: 5.0000e-04
# Epoch 31/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1224.0583 - salida_clase_accuracy: 0.9137 - salidas_continuas_mae: 23.8335 - val_loss: 655.5375 - val_salida_clase_accuracy: 0.9713 - val_salidas_continuas_mae: 17.7305 - learning_rate: 5.0000e-04
# Epoch 32/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1187.3567 - salida_clase_accuracy: 0.9199 - salidas_continuas_mae: 23.4873 - val_loss: 622.6049 - val_salida_clase_accuracy: 0.9660 - val_salidas_continuas_mae: 17.0555 - learning_rate: 5.0000e-04
# Epoch 33/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1205.2327 - salida_clase_accuracy: 0.9162 - salidas_continuas_mae: 23.5600 - val_loss: 611.1844 - val_salida_clase_accuracy: 0.9650 - val_salidas_continuas_mae: 16.9183 - learning_rate: 5.0000e-04
# Epoch 34/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1208.1400 - salida_clase_accuracy: 0.9105 - salidas_continuas_mae: 23.5697 - val_loss: 609.2269 - val_salida_clase_accuracy: 0.9681 - val_salidas_continuas_mae: 17.0419 - learning_rate: 5.0000e-04
# Epoch 35/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1197.0520 - salida_clase_accuracy: 0.9174 - salidas_continuas_mae: 23.4362 - val_loss: 596.6355 - val_salida_clase_accuracy: 0.9670 - val_salidas_continuas_mae: 16.6008 - learning_rate: 5.0000e-04
# Epoch 36/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1184.9253 - salida_clase_accuracy: 0.9177 - salidas_continuas_mae: 23.4017 - val_loss: 607.4993 - val_salida_clase_accuracy: 0.9709 - val_salidas_continuas_mae: 16.9189 - learning_rate: 5.0000e-04
# Epoch 37/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1177.3612 - salida_clase_accuracy: 0.9203 - salidas_continuas_mae: 23.3611 - val_loss: 622.9265 - val_salida_clase_accuracy: 0.9701 - val_salidas_continuas_mae: 17.1874 - learning_rate: 5.0000e-04
# Epoch 38/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 1163.7522 - salida_clase_accuracy: 0.9241 - salidas_continuas_mae: 23.2219 - val_loss: 583.0542 - val_salida_clase_accuracy: 0.9713 - val_salidas_continuas_mae: 16.3780 - learning_rate: 5.0000e-04
# Epoch 39/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1164.2018 - salida_clase_accuracy: 0.9259 - salidas_continuas_mae: 23.1633 - val_loss: 577.7765 - val_salida_clase_accuracy: 0.9654 - val_salidas_continuas_mae: 16.4508 - learning_rate: 5.0000e-04
# Epoch 40/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1159.4830 - salida_clase_accuracy: 0.9242 - salidas_continuas_mae: 23.0700 - val_loss: 576.7345 - val_salida_clase_accuracy: 0.9666 - val_salidas_continuas_mae: 16.1113 - learning_rate: 5.0000e-04
# Epoch 41/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1140.6365 - salida_clase_accuracy: 0.9223 - salidas_continuas_mae: 22.9484 - val_loss: 621.4995 - val_salida_clase_accuracy: 0.9713 - val_salidas_continuas_mae: 17.4732 - learning_rate: 5.0000e-04
# Epoch 42/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1155.0079 - salida_clase_accuracy: 0.9196 - salidas_continuas_mae: 23.0833 - val_loss: 572.5954 - val_salida_clase_accuracy: 0.9738 - val_salidas_continuas_mae: 16.1336 - learning_rate: 5.0000e-04
# Epoch 43/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1146.6675 - salida_clase_accuracy: 0.9238 - salidas_continuas_mae: 23.0542 - val_loss: 583.4915 - val_salida_clase_accuracy: 0.9689 - val_salidas_continuas_mae: 16.6403 - learning_rate: 5.0000e-04
# Epoch 44/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1142.9690 - salida_clase_accuracy: 0.9225 - salidas_continuas_mae: 22.9829 - val_loss: 578.6458 - val_salida_clase_accuracy: 0.9725 - val_salidas_continuas_mae: 16.6088 - learning_rate: 5.0000e-04
# Epoch 45/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1155.5665 - salida_clase_accuracy: 0.9225 - salidas_continuas_mae: 23.0437 - val_loss: 611.1180 - val_salida_clase_accuracy: 0.9697 - val_salidas_continuas_mae: 17.0271 - learning_rate: 5.0000e-04
# Epoch 46/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1144.3246 - salida_clase_accuracy: 0.9243 - salidas_continuas_mae: 22.9177 - val_loss: 568.1459 - val_salida_clase_accuracy: 0.9543 - val_salidas_continuas_mae: 16.2383 - learning_rate: 5.0000e-04
# Epoch 47/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1148.1497 - salida_clase_accuracy: 0.9218 - salidas_continuas_mae: 22.8363 - val_loss: 585.9006 - val_salida_clase_accuracy: 0.9690 - val_salidas_continuas_mae: 16.8042 - learning_rate: 5.0000e-04
# Epoch 48/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1119.7000 - salida_clase_accuracy: 0.9257 - salidas_continuas_mae: 22.7795 - val_loss: 570.0553 - val_salida_clase_accuracy: 0.9746 - val_salidas_continuas_mae: 16.2964 - learning_rate: 5.0000e-04
# Epoch 49/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1138.8059 - salida_clase_accuracy: 0.9274 - salidas_continuas_mae: 22.8270 - val_loss: 570.9185 - val_salida_clase_accuracy: 0.9740 - val_salidas_continuas_mae: 16.3648 - learning_rate: 5.0000e-04
# Epoch 50/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1100.6757 - salida_clase_accuracy: 0.9259 - salidas_continuas_mae: 22.4967 - val_loss: 543.4758 - val_salida_clase_accuracy: 0.9738 - val_salidas_continuas_mae: 15.8931 - learning_rate: 5.0000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 535.8939 - salida_clase_accuracy: 0.9750 - salidas_continuas_mae: 15.7438
# Fold 3: Loss=531.0980834960938, MAE=15.674269676208496, Accuracy=0.9758651256561279
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Entrenando fold 4...
# Epoch 1/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 24611.0117 - salida_clase_accuracy: 0.6034 - salidas_continuas_mae: 88.5649 - val_loss: 9931.8555 - val_salida_clase_accuracy: 0.8202 - val_salidas_continuas_mae: 57.0875 - learning_rate: 5.0000e-04
# Epoch 2/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 9099.6924 - salida_clase_accuracy: 0.7584 - salidas_continuas_mae: 53.7073 - val_loss: 6278.6333 - val_salida_clase_accuracy: 0.8507 - val_salidas_continuas_mae: 43.8242 - learning_rate: 5.0000e-04
# Epoch 3/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 6538.9292 - salida_clase_accuracy: 0.7915 - salidas_continuas_mae: 45.0143 - val_loss: 4746.6392 - val_salida_clase_accuracy: 0.8980 - val_salidas_continuas_mae: 38.1950 - learning_rate: 5.0000e-04
# Epoch 4/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 4824.4194 - salida_clase_accuracy: 0.8283 - salidas_continuas_mae: 39.4367 - val_loss: 3484.6543 - val_salida_clase_accuracy: 0.8814 - val_salidas_continuas_mae: 33.6339 - learning_rate: 5.0000e-04
# Epoch 5/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3804.6838 - salida_clase_accuracy: 0.8461 - salidas_continuas_mae: 36.0101 - val_loss: 2595.8760 - val_salida_clase_accuracy: 0.9058 - val_salidas_continuas_mae: 30.4366 - learning_rate: 5.0000e-04
# Epoch 6/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3071.8958 - salida_clase_accuracy: 0.8502 - salidas_continuas_mae: 33.6202 - val_loss: 2187.6624 - val_salida_clase_accuracy: 0.9205 - val_salidas_continuas_mae: 28.6704 - learning_rate: 5.0000e-04
# Epoch 7/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2546.0828 - salida_clase_accuracy: 0.8557 - salidas_continuas_mae: 31.7437 - val_loss: 1604.3933 - val_salida_clase_accuracy: 0.9197 - val_salidas_continuas_mae: 25.2847 - learning_rate: 5.0000e-04
# Epoch 8/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 2214.0920 - salida_clase_accuracy: 0.8614 - salidas_continuas_mae: 30.4268 - val_loss: 1438.3442 - val_salida_clase_accuracy: 0.9446 - val_salidas_continuas_mae: 24.7982 - learning_rate: 5.0000e-04
# Epoch 9/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1972.6626 - salida_clase_accuracy: 0.8747 - salidas_continuas_mae: 29.3163 - val_loss: 1221.4818 - val_salida_clase_accuracy: 0.9270 - val_salidas_continuas_mae: 23.0386 - learning_rate: 5.0000e-04
# Epoch 10/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1848.3015 - salida_clase_accuracy: 0.8741 - salidas_continuas_mae: 28.6281 - val_loss: 1075.3336 - val_salida_clase_accuracy: 0.9256 - val_salidas_continuas_mae: 21.9746 - learning_rate: 5.0000e-04
# Epoch 11/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1721.1315 - salida_clase_accuracy: 0.8798 - salidas_continuas_mae: 27.9006 - val_loss: 997.2974 - val_salida_clase_accuracy: 0.9405 - val_salidas_continuas_mae: 21.3160 - learning_rate: 5.0000e-04
# Epoch 12/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1620.1930 - salida_clase_accuracy: 0.8844 - salidas_continuas_mae: 27.3176 - val_loss: 904.6464 - val_salida_clase_accuracy: 0.9417 - val_salidas_continuas_mae: 20.1410 - learning_rate: 5.0000e-04
# Epoch 13/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1565.0675 - salida_clase_accuracy: 0.8850 - salidas_continuas_mae: 26.8487 - val_loss: 864.8058 - val_salida_clase_accuracy: 0.9406 - val_salidas_continuas_mae: 20.0232 - learning_rate: 5.0000e-04
# Epoch 14/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1498.2434 - salida_clase_accuracy: 0.8872 - salidas_continuas_mae: 26.4160 - val_loss: 867.1940 - val_salida_clase_accuracy: 0.9523 - val_salidas_continuas_mae: 20.2190 - learning_rate: 5.0000e-04
# Epoch 15/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1481.6171 - salida_clase_accuracy: 0.8987 - salidas_continuas_mae: 26.1058 - val_loss: 815.5705 - val_salida_clase_accuracy: 0.9464 - val_salidas_continuas_mae: 19.2447 - learning_rate: 5.0000e-04
# Epoch 16/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1459.3560 - salida_clase_accuracy: 0.8963 - salidas_continuas_mae: 25.9440 - val_loss: 753.9490 - val_salida_clase_accuracy: 0.9462 - val_salidas_continuas_mae: 18.4690 - learning_rate: 5.0000e-04
# Epoch 17/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1407.3840 - salida_clase_accuracy: 0.8978 - salidas_continuas_mae: 25.5796 - val_loss: 734.3656 - val_salida_clase_accuracy: 0.9519 - val_salidas_continuas_mae: 18.2490 - learning_rate: 5.0000e-04
# Epoch 18/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1383.9578 - salida_clase_accuracy: 0.9059 - salidas_continuas_mae: 25.3653 - val_loss: 738.0492 - val_salida_clase_accuracy: 0.9488 - val_salidas_continuas_mae: 18.5179 - learning_rate: 5.0000e-04
# Epoch 19/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1378.7051 - salida_clase_accuracy: 0.9075 - salidas_continuas_mae: 25.2077 - val_loss: 714.1110 - val_salida_clase_accuracy: 0.9531 - val_salidas_continuas_mae: 17.9886 - learning_rate: 5.0000e-04
# Epoch 20/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1336.8427 - salida_clase_accuracy: 0.9018 - salidas_continuas_mae: 24.9330 - val_loss: 674.9042 - val_salida_clase_accuracy: 0.9598 - val_salidas_continuas_mae: 17.4262 - learning_rate: 5.0000e-04
# Epoch 21/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1299.0448 - salida_clase_accuracy: 0.9111 - salidas_continuas_mae: 24.5963 - val_loss: 688.0659 - val_salida_clase_accuracy: 0.9615 - val_salidas_continuas_mae: 17.7431 - learning_rate: 5.0000e-04
# Epoch 22/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1314.3232 - salida_clase_accuracy: 0.9102 - salidas_continuas_mae: 24.6849 - val_loss: 672.1541 - val_salida_clase_accuracy: 0.9502 - val_salidas_continuas_mae: 17.6106 - learning_rate: 5.0000e-04
# Epoch 23/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1275.6638 - salida_clase_accuracy: 0.9114 - salidas_continuas_mae: 24.4953 - val_loss: 662.2513 - val_salida_clase_accuracy: 0.9508 - val_salidas_continuas_mae: 17.4096 - learning_rate: 5.0000e-04
# Epoch 24/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1271.7712 - salida_clase_accuracy: 0.9149 - salidas_continuas_mae: 24.2960 - val_loss: 650.3617 - val_salida_clase_accuracy: 0.9649 - val_salidas_continuas_mae: 17.1029 - learning_rate: 5.0000e-04
# Epoch 25/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1265.8815 - salida_clase_accuracy: 0.9164 - salidas_continuas_mae: 24.2682 - val_loss: 684.5502 - val_salida_clase_accuracy: 0.9610 - val_salidas_continuas_mae: 18.0805 - learning_rate: 5.0000e-04
# Epoch 26/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1251.9735 - salida_clase_accuracy: 0.9161 - salidas_continuas_mae: 24.0726 - val_loss: 674.1400 - val_salida_clase_accuracy: 0.9602 - val_salidas_continuas_mae: 17.7105 - learning_rate: 5.0000e-04
# Epoch 27/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1249.6235 - salida_clase_accuracy: 0.9165 - salidas_continuas_mae: 23.9888 - val_loss: 687.4230 - val_salida_clase_accuracy: 0.9612 - val_salidas_continuas_mae: 18.0439 - learning_rate: 5.0000e-04
# Epoch 28/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1204.3680 - salida_clase_accuracy: 0.9189 - salidas_continuas_mae: 23.6923 - val_loss: 652.7911 - val_salida_clase_accuracy: 0.9574 - val_salidas_continuas_mae: 17.5310 - learning_rate: 5.0000e-04
# Epoch 29/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1215.9258 - salida_clase_accuracy: 0.9147 - salidas_continuas_mae: 23.7490 - val_loss: 610.0665 - val_salida_clase_accuracy: 0.9583 - val_salidas_continuas_mae: 16.7368 - learning_rate: 5.0000e-04
# Epoch 30/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1216.9176 - salida_clase_accuracy: 0.9137 - salidas_continuas_mae: 23.8118 - val_loss: 618.4097 - val_salida_clase_accuracy: 0.9671 - val_salidas_continuas_mae: 16.6672 - learning_rate: 5.0000e-04
# Epoch 31/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1213.2662 - salida_clase_accuracy: 0.9163 - salidas_continuas_mae: 23.6018 - val_loss: 606.1681 - val_salida_clase_accuracy: 0.9693 - val_salidas_continuas_mae: 16.8284 - learning_rate: 5.0000e-04
# Epoch 32/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1194.4343 - salida_clase_accuracy: 0.9170 - salidas_continuas_mae: 23.5664 - val_loss: 603.9949 - val_salida_clase_accuracy: 0.9674 - val_salidas_continuas_mae: 16.5503 - learning_rate: 5.0000e-04
# Epoch 33/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1197.4880 - salida_clase_accuracy: 0.9214 - salidas_continuas_mae: 23.4852 - val_loss: 640.5715 - val_salida_clase_accuracy: 0.9655 - val_salidas_continuas_mae: 17.1910 - learning_rate: 5.0000e-04
# Epoch 34/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1182.7794 - salida_clase_accuracy: 0.9206 - salidas_continuas_mae: 23.3417 - val_loss: 592.5068 - val_salida_clase_accuracy: 0.9620 - val_salidas_continuas_mae: 16.5664 - learning_rate: 5.0000e-04
# Epoch 35/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1160.9005 - salida_clase_accuracy: 0.9153 - salidas_continuas_mae: 23.3368 - val_loss: 618.8021 - val_salida_clase_accuracy: 0.9622 - val_salidas_continuas_mae: 16.9193 - learning_rate: 5.0000e-04
# Epoch 36/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1163.5208 - salida_clase_accuracy: 0.9220 - salidas_continuas_mae: 23.2631 - val_loss: 562.8369 - val_salida_clase_accuracy: 0.9499 - val_salidas_continuas_mae: 15.9614 - learning_rate: 5.0000e-04
# Epoch 37/50
# ...
# Epoch 42/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1155.0746 - salida_clase_accuracy: 0.9217 - salidas_continuas_mae: 22.9979 - val_loss: 574.7283 - val_salida_clase_accuracy: 0.9732 - val_salidas_continuas_mae: 16.1805 - learning_rate: 5.0000e-04
# Epoch 43/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1139.5145 - salida_clase_accuracy: 0.9281 - salidas_continuas_mae: 23.0119 - val_loss: 657.2546 - val_salida_clase_accuracy: 0.9684 - val_salidas_continuas_mae: 17.6154 - learning_rate: 5.0000e-04
# Epoch 44/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1134.4072 - salida_clase_accuracy: 0.9340 - salidas_continuas_mae: 22.8785 - val_loss: 554.8036 - val_salida_clase_accuracy: 0.9719 - val_salidas_continuas_mae: 15.7983 - learning_rate: 2.5000e-04
# Epoch 45/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1115.6548 - salida_clase_accuracy: 0.9358 - salidas_continuas_mae: 22.6677 - val_loss: 586.5557 - val_salida_clase_accuracy: 0.9777 - val_salidas_continuas_mae: 16.6156 - learning_rate: 2.5000e-04
# Epoch 46/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1107.5215 - salida_clase_accuracy: 0.9357 - salidas_continuas_mae: 22.7044 - val_loss: 552.2106 - val_salida_clase_accuracy: 0.9711 - val_salidas_continuas_mae: 15.8254 - learning_rate: 2.5000e-04
# Epoch 47/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1100.9492 - salida_clase_accuracy: 0.9360 - salidas_continuas_mae: 22.5214 - val_loss: 564.3751 - val_salida_clase_accuracy: 0.9746 - val_salidas_continuas_mae: 16.0126 - learning_rate: 2.5000e-04
# Epoch 48/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1116.7336 - salida_clase_accuracy: 0.9416 - salidas_continuas_mae: 22.7167 - val_loss: 571.6068 - val_salida_clase_accuracy: 0.9746 - val_salidas_continuas_mae: 16.2258 - learning_rate: 2.5000e-04
# Epoch 49/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1103.9742 - salida_clase_accuracy: 0.9362 - salidas_continuas_mae: 22.5972 - val_loss: 547.6491 - val_salida_clase_accuracy: 0.9805 - val_salidas_continuas_mae: 15.6934 - learning_rate: 2.5000e-04
# Epoch 50/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1108.9546 - salida_clase_accuracy: 0.9352 - salidas_continuas_mae: 22.6736 - val_loss: 542.4513 - val_salida_clase_accuracy: 0.9701 - val_salidas_continuas_mae: 15.5508 - learning_rate: 2.5000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 535.9297 - salida_clase_accuracy: 0.9743 - salidas_continuas_mae: 15.5061
# Fold 4: Loss=527.674072265625, MAE=15.390214920043945, Accuracy=0.9738219976425171
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Entrenando fold 5...
# Epoch 1/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 24792.9863 - salida_clase_accuracy: 0.6010 - salidas_continuas_mae: 89.1686 - val_loss: 10040.8604 - val_salida_clase_accuracy: 0.8595 - val_salidas_continuas_mae: 56.9549 - learning_rate: 5.0000e-04
# Epoch 2/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 9180.5967 - salida_clase_accuracy: 0.7743 - salidas_continuas_mae: 53.7491 - val_loss: 6652.5161 - val_salida_clase_accuracy: 0.8798 - val_salidas_continuas_mae: 44.7279 - learning_rate: 5.0000e-04
# Epoch 3/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 6442.2119 - salida_clase_accuracy: 0.8110 - salidas_continuas_mae: 44.8352 - val_loss: 4597.1724 - val_salida_clase_accuracy: 0.9041 - val_salidas_continuas_mae: 37.4420 - learning_rate: 5.0000e-04
# Epoch 4/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 4855.4009 - salida_clase_accuracy: 0.8319 - salidas_continuas_mae: 39.6351 - val_loss: 3279.0122 - val_salida_clase_accuracy: 0.9069 - val_salidas_continuas_mae: 32.9016 - learning_rate: 5.0000e-04
# Epoch 5/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3940.8396 - salida_clase_accuracy: 0.8401 - salidas_continuas_mae: 36.8016 - val_loss: 2594.5391 - val_salida_clase_accuracy: 0.9231 - val_salidas_continuas_mae: 30.8952 - learning_rate: 5.0000e-04
# Epoch 6/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 3065.4670 - salida_clase_accuracy: 0.8512 - salidas_continuas_mae: 33.7414 - val_loss: 2032.3860 - val_salida_clase_accuracy: 0.9155 - val_salidas_continuas_mae: 28.0952 - learning_rate: 5.0000e-04
# Epoch 7/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2605.0547 - salida_clase_accuracy: 0.8550 - salidas_continuas_mae: 32.0112 - val_loss: 1723.1691 - val_salida_clase_accuracy: 0.9286 - val_salidas_continuas_mae: 26.7172 - learning_rate: 5.0000e-04
# Epoch 8/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2273.5151 - salida_clase_accuracy: 0.8589 - salidas_continuas_mae: 30.7133 - val_loss: 1349.1381 - val_salida_clase_accuracy: 0.9302 - val_salidas_continuas_mae: 23.6871 - learning_rate: 5.0000e-04
# Epoch 9/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 2030.1212 - salida_clase_accuracy: 0.8742 - salidas_continuas_mae: 29.4705 - val_loss: 1243.2319 - val_salida_clase_accuracy: 0.9330 - val_salidas_continuas_mae: 23.7157 - learning_rate: 5.0000e-04
# Epoch 10/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1828.8695 - salida_clase_accuracy: 0.8778 - salidas_continuas_mae: 28.4429 - val_loss: 1087.6200 - val_salida_clase_accuracy: 0.9211 - val_salidas_continuas_mae: 21.9019 - learning_rate: 5.0000e-04
# Epoch 11/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1741.7583 - salida_clase_accuracy: 0.8780 - salidas_continuas_mae: 27.8789 - val_loss: 977.6533 - val_salida_clase_accuracy: 0.9371 - val_salidas_continuas_mae: 20.9676 - learning_rate: 5.0000e-04
# Epoch 12/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1656.9495 - salida_clase_accuracy: 0.8797 - salidas_continuas_mae: 27.3415 - val_loss: 893.6796 - val_salida_clase_accuracy: 0.9443 - val_salidas_continuas_mae: 20.2757 - learning_rate: 5.0000e-04
# Epoch 13/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1584.9332 - salida_clase_accuracy: 0.8870 - salidas_continuas_mae: 26.8035 - val_loss: 872.1855 - val_salida_clase_accuracy: 0.9448 - val_salidas_continuas_mae: 20.1571 - learning_rate: 5.0000e-04
# Epoch 14/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1525.1478 - salida_clase_accuracy: 0.8905 - salidas_continuas_mae: 26.3707 - val_loss: 857.4998 - val_salida_clase_accuracy: 0.9444 - val_salidas_continuas_mae: 20.1427 - learning_rate: 5.0000e-04
# Epoch 15/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1465.0676 - salida_clase_accuracy: 0.8927 - salidas_continuas_mae: 26.0178 - val_loss: 780.2384 - val_salida_clase_accuracy: 0.9384 - val_salidas_continuas_mae: 19.0920 - learning_rate: 5.0000e-04
# Epoch 16/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1448.1838 - salida_clase_accuracy: 0.8951 - salidas_continuas_mae: 25.9404 - val_loss: 762.3099 - val_salida_clase_accuracy: 0.9499 - val_salidas_continuas_mae: 18.9674 - learning_rate: 5.0000e-04
# Epoch 17/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1420.4589 - salida_clase_accuracy: 0.8977 - salidas_continuas_mae: 25.5340 - val_loss: 757.2974 - val_salida_clase_accuracy: 0.9459 - val_salidas_continuas_mae: 19.0695 - learning_rate: 5.0000e-04
# Epoch 18/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1383.6599 - salida_clase_accuracy: 0.8960 - salidas_continuas_mae: 25.2594 - val_loss: 728.3729 - val_salida_clase_accuracy: 0.9561 - val_salidas_continuas_mae: 18.6526 - learning_rate: 5.0000e-04
# Epoch 19/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1370.5083 - salida_clase_accuracy: 0.9033 - salidas_continuas_mae: 25.2024 - val_loss: 713.3447 - val_salida_clase_accuracy: 0.9484 - val_salidas_continuas_mae: 18.4762 - learning_rate: 5.0000e-04
# Epoch 20/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1356.4421 - salida_clase_accuracy: 0.9042 - salidas_continuas_mae: 25.0369 - val_loss: 726.5881 - val_salida_clase_accuracy: 0.9547 - val_salidas_continuas_mae: 18.5803 - learning_rate: 5.0000e-04
# Epoch 21/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1375.2985 - salida_clase_accuracy: 0.9080 - salidas_continuas_mae: 25.0408 - val_loss: 726.4466 - val_salida_clase_accuracy: 0.9532 - val_salidas_continuas_mae: 18.9520 - learning_rate: 5.0000e-04
# Epoch 22/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1319.9102 - salida_clase_accuracy: 0.9044 - salidas_continuas_mae: 24.6965 - val_loss: 685.7236 - val_salida_clase_accuracy: 0.9649 - val_salidas_continuas_mae: 17.8963 - learning_rate: 5.0000e-04
# Epoch 23/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1302.8944 - salida_clase_accuracy: 0.9090 - salidas_continuas_mae: 24.5818 - val_loss: 649.9106 - val_salida_clase_accuracy: 0.9625 - val_salidas_continuas_mae: 17.1736 - learning_rate: 5.0000e-04
# Epoch 24/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1289.0199 - salida_clase_accuracy: 0.9066 - salidas_continuas_mae: 24.4843 - val_loss: 645.1781 - val_salida_clase_accuracy: 0.9631 - val_salidas_continuas_mae: 17.0757 - learning_rate: 5.0000e-04
# Epoch 25/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1281.8105 - salida_clase_accuracy: 0.9055 - salidas_continuas_mae: 24.3818 - val_loss: 625.7186 - val_salida_clase_accuracy: 0.9617 - val_salidas_continuas_mae: 17.0381 - learning_rate: 5.0000e-04
# Epoch 26/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1287.6160 - salida_clase_accuracy: 0.9141 - salidas_continuas_mae: 24.2906 - val_loss: 633.4911 - val_salida_clase_accuracy: 0.9571 - val_salidas_continuas_mae: 17.1168 - learning_rate: 5.0000e-04
# Epoch 27/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1285.9551 - salida_clase_accuracy: 0.9111 - salidas_continuas_mae: 24.2893 - val_loss: 622.1036 - val_salida_clase_accuracy: 0.9634 - val_salidas_continuas_mae: 17.1929 - learning_rate: 5.0000e-04
# Epoch 28/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1239.2169 - salida_clase_accuracy: 0.9117 - salidas_continuas_mae: 23.9925 - val_loss: 605.2263 - val_salida_clase_accuracy: 0.9620 - val_salidas_continuas_mae: 16.6015 - learning_rate: 5.0000e-04
# Epoch 29/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1248.3192 - salida_clase_accuracy: 0.9196 - salidas_continuas_mae: 24.0427 - val_loss: 590.6282 - val_salida_clase_accuracy: 0.9545 - val_salidas_continuas_mae: 16.5427 - learning_rate: 5.0000e-04
# Epoch 30/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1252.3318 - salida_clase_accuracy: 0.9156 - salidas_continuas_mae: 23.9766 - val_loss: 609.5038 - val_salida_clase_accuracy: 0.9583 - val_salidas_continuas_mae: 16.6539 - learning_rate: 5.0000e-04
# Epoch 31/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1236.3992 - salida_clase_accuracy: 0.9164 - salidas_continuas_mae: 23.9054 - val_loss: 648.7101 - val_salida_clase_accuracy: 0.9488 - val_salidas_continuas_mae: 17.6970 - learning_rate: 5.0000e-04
# Epoch 32/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1227.8092 - salida_clase_accuracy: 0.9194 - salidas_continuas_mae: 23.7349 - val_loss: 643.4224 - val_salida_clase_accuracy: 0.9610 - val_salidas_continuas_mae: 17.7277 - learning_rate: 5.0000e-04
# Epoch 33/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1232.0647 - salida_clase_accuracy: 0.9194 - salidas_continuas_mae: 23.8083 - val_loss: 595.9222 - val_salida_clase_accuracy: 0.9572 - val_salidas_continuas_mae: 16.5853 - learning_rate: 5.0000e-04
# Epoch 34/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1208.1993 - salida_clase_accuracy: 0.9202 - salidas_continuas_mae: 23.6153 - val_loss: 612.8806 - val_salida_clase_accuracy: 0.9655 - val_salidas_continuas_mae: 16.9671 - learning_rate: 5.0000e-04
# Epoch 35/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1204.6953 - salida_clase_accuracy: 0.9301 - salidas_continuas_mae: 23.5346 - val_loss: 594.0221 - val_salida_clase_accuracy: 0.9711 - val_salidas_continuas_mae: 16.6043 - learning_rate: 2.5000e-04
# Epoch 36/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1188.5519 - salida_clase_accuracy: 0.9277 - salidas_continuas_mae: 23.3684 - val_loss: 595.4071 - val_salida_clase_accuracy: 0.9692 - val_salidas_continuas_mae: 16.7333 - learning_rate: 2.5000e-04
# Epoch 37/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1203.7975 - salida_clase_accuracy: 0.9274 - salidas_continuas_mae: 23.5103 - val_loss: 602.9994 - val_salida_clase_accuracy: 0.9574 - val_salidas_continuas_mae: 16.7338 - learning_rate: 2.5000e-04
# Epoch 38/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1175.5385 - salida_clase_accuracy: 0.9290 - salidas_continuas_mae: 23.3364 - val_loss: 576.1727 - val_salida_clase_accuracy: 0.9711 - val_salidas_continuas_mae: 16.4450 - learning_rate: 2.5000e-04
# Epoch 39/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1172.8711 - salida_clase_accuracy: 0.9297 - salidas_continuas_mae: 23.2266 - val_loss: 591.4163 - val_salida_clase_accuracy: 0.9684 - val_salidas_continuas_mae: 16.5275 - learning_rate: 2.5000e-04
# Epoch 40/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1172.2089 - salida_clase_accuracy: 0.9287 - salidas_continuas_mae: 23.3160 - val_loss: 586.4233 - val_salida_clase_accuracy: 0.9641 - val_salidas_continuas_mae: 16.5843 - learning_rate: 2.5000e-04
# Epoch 41/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1143.6444 - salida_clase_accuracy: 0.9289 - salidas_continuas_mae: 23.0637 - val_loss: 573.7140 - val_salida_clase_accuracy: 0.9687 - val_salidas_continuas_mae: 16.2932 - learning_rate: 2.5000e-04
# Epoch 42/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1165.0386 - salida_clase_accuracy: 0.9339 - salidas_continuas_mae: 23.2291 - val_loss: 591.2904 - val_salida_clase_accuracy: 0.9706 - val_salidas_continuas_mae: 16.8325 - learning_rate: 2.5000e-04
# Epoch 43/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1165.4608 - salida_clase_accuracy: 0.9302 - salidas_continuas_mae: 23.0450 - val_loss: 611.4141 - val_salida_clase_accuracy: 0.9738 - val_salidas_continuas_mae: 17.0039 - learning_rate: 2.5000e-04
# Epoch 44/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1170.2047 - salida_clase_accuracy: 0.9329 - salidas_continuas_mae: 23.2284 - val_loss: 568.0469 - val_salida_clase_accuracy: 0.9721 - val_salidas_continuas_mae: 16.2660 - learning_rate: 2.5000e-04
# Epoch 45/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1163.0033 - salida_clase_accuracy: 0.9324 - salidas_continuas_mae: 23.1328 - val_loss: 576.0624 - val_salida_clase_accuracy: 0.9663 - val_salidas_continuas_mae: 16.2968 - learning_rate: 2.5000e-04
# Epoch 46/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1154.0935 - salida_clase_accuracy: 0.9317 - salidas_continuas_mae: 23.1612 - val_loss: 561.8174 - val_salida_clase_accuracy: 0.9657 - val_salidas_continuas_mae: 16.1160 - learning_rate: 2.5000e-04
# Epoch 47/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1154.9030 - salida_clase_accuracy: 0.9339 - salidas_continuas_mae: 23.0204 - val_loss: 575.9945 - val_salida_clase_accuracy: 0.9663 - val_salidas_continuas_mae: 16.3818 - learning_rate: 2.5000e-04
# Epoch 48/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1148.3027 - salida_clase_accuracy: 0.9325 - salidas_continuas_mae: 23.0153 - val_loss: 584.4678 - val_salida_clase_accuracy: 0.9725 - val_salidas_continuas_mae: 16.6973 - learning_rate: 2.5000e-04
# Epoch 49/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1161.9952 - salida_clase_accuracy: 0.9298 - salidas_continuas_mae: 23.0964 - val_loss: 536.6885 - val_salida_clase_accuracy: 0.9719 - val_salidas_continuas_mae: 15.5685 - learning_rate: 2.5000e-04
# Epoch 50/50
# 784/784 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 1146.1510 - salida_clase_accuracy: 0.9324 - salidas_continuas_mae: 23.0358 - val_loss: 564.3227 - val_salida_clase_accuracy: 0.9735 - val_salidas_continuas_mae: 16.1342 - learning_rate: 2.5000e-04
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 540.9012 - salida_clase_accuracy: 0.9767 - salidas_continuas_mae: 15.6628
# Fold 5: Loss=533.1905517578125, MAE=15.554417610168457, Accuracy=0.977014422416687
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 540.877294921875
# MAE: 15.644700199792771
# MSE: 540.3173008073084
# RMSE: 23.242880614203546
# R^2: 0.9755007652120984
# Accuracy: 0.9710381746292114
# Precisión: 0.9714976890049162
# Recall: 0.9710381815860043
# F1-Score: 0.9709227432680431
