# %%
import joblib
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, Activation, Dropout, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Cargar datos
ruta_actual = os.getcwd()
carpeta_mediapipe = os.path.dirname(ruta_actual)
ruta_csv = os.path.join(carpeta_mediapipe, 'Datos_Videos_Pose', 'pose_data.csv')
ruta_npy = os.path.join(ruta_actual, 'datos', 'classes.npy')
ruta_scaler = os.path.join(ruta_actual, 'datos', 'scaler_X.pkl')
ruta_modelo = os.path.join(ruta_actual, 'model', 'exercise_model.h5')

data = pd.read_csv(ruta_csv)

# Preparar datos
num_keypoints = 17 * 3
X = data.iloc[:, :num_keypoints].values
y_continuas = data.iloc[:, num_keypoints:(data.shape[1] - 1)].values
y_clase = data.iloc[:, -1].values

encoder = LabelEncoder()
y_clase_encoded = encoder.fit_transform(y_clase)
num_clases = len(encoder.classes_)

X_train, X_test, y_continuas_train, y_continuas_test, y_clase_train, y_clase_test = train_test_split(
    X, y_continuas, y_clase_encoded, test_size=0.2, random_state=42)

scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

X_train_cnn = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_cnn = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

# Función para crear el modelo con ajustes de hiperparámetros
def create_model(learning_rate=0.001):
    input_layer = Input(shape=(X_train_cnn.shape[1], X_train_cnn.shape[2]))
    x = Conv1D(64, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(input_layer)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Conv1D(64, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Conv1D(32, kernel_size=3, padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)
    
    x = Flatten()(x)
    
    salidas_continuas = Dense(10, activation='linear', name='salidas_continuas')(x)
    salida_clase = Dense(num_clases, activation='softmax', name='salida_clase')(x)
    
    model = Model(inputs=input_layer, outputs=[salidas_continuas, salida_clase])
    
    optimizer = Adam(learning_rate=learning_rate)
    
    model.compile(optimizer=optimizer,
                  loss={'salidas_continuas': 'mean_squared_error', 'salida_clase': 'sparse_categorical_crossentropy'},
                  metrics={'salidas_continuas': 'mae', 'salida_clase': 'accuracy'})
    
    return model

# Listas para almacenar métricas
all_loss = []
all_mae = []
all_mse = []
all_rmse = []
all_r2 = []
all_accuracy = []
all_precision = []
all_recall = []
all_f1 = []

# Matrices para almacenar la historia del entrenamiento
n_epochs = 50  # Número de épocas
all_train_loss = np.full((5, n_epochs), np.nan)  
all_val_loss = np.full((5, n_epochs), np.nan)
all_train_accuracy = np.full((5, n_epochs), np.nan)
all_val_accuracy = np.full((5, n_epochs), np.nan)

# Optimización de hiperparámetros y validación cruzada
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

fold_index = 0
for train_index, val_index in kfold.split(X_train_cnn):
    fold_index += 1
    print(f"Entrenando fold {fold_index}...")

    X_train_fold, X_val_fold = X_train_cnn[train_index], X_train_cnn[val_index]
    y_continuas_train_fold, y_continuas_val_fold = y_continuas_train[train_index], y_continuas_train[val_index]
    y_clase_train_fold, y_clase_val_fold = y_clase_train[train_index], y_clase_train[val_index]

    model = create_model(learning_rate=0.0005)  # Ajustar la tasa de aprendizaje aquí
    tensorboard_callback = TensorBoard(log_dir=os.path.join(ruta_actual, 'logs', f'fold_{fold_index}'), histogram_freq=1)
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

    history = model.fit(X_train_fold, {'salidas_continuas': y_continuas_train_fold, 'salida_clase': y_clase_train_fold},
                        validation_data=(X_val_fold, {'salidas_continuas': y_continuas_val_fold, 'salida_clase': y_clase_val_fold}),
                        epochs=n_epochs, batch_size=32, callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback])

    # Almacenar la historia del entrenamiento como matrices NumPy
    epochs_completed = len(history.history['loss'])
    all_train_loss[fold_index - 1, :epochs_completed] = history.history['loss']
    all_val_loss[fold_index - 1, :epochs_completed] = history.history['val_loss']
    all_train_accuracy[fold_index - 1, :epochs_completed] = history.history['salida_clase_accuracy']
    all_val_accuracy[fold_index - 1, :epochs_completed] = history.history['val_salida_clase_accuracy']

    # Evaluar el modelo en el conjunto de prueba
    scores = model.evaluate(X_test_cnn, {'salidas_continuas': y_continuas_test, 'salida_clase': y_clase_test})
    print(f"Fold {fold_index}: Loss={scores[0]}, MAE={scores[2]}, Accuracy={scores[1]}")

    # Calcular métricas adicionales para las salidas continuas
    y_pred_continuas = model.predict(X_test_cnn)[0]
    mae = mean_absolute_error(y_continuas_test, y_pred_continuas)
    mse = mean_squared_error(y_continuas_test, y_pred_continuas)
    rmse = np.sqrt(mse)
    r2 = 1 - mse / np.var(y_continuas_test)

    all_loss.append(scores[0])
    all_mae.append(mae)
    all_mse.append(mse)
    all_rmse.append(rmse)
    all_r2.append(r2)
    all_accuracy.append(scores[1])

    # Calcular métricas de clasificación
    y_pred_clase = np.argmax(model.predict(X_test_cnn)[1], axis=1)
    precision = precision_score(y_clase_test, y_pred_clase, average='weighted')
    recall = recall_score(y_clase_test, y_pred_clase, average='weighted')
    f1 = f1_score(y_clase_test, y_pred_clase, average='weighted')

    all_precision.append(precision)
    all_recall.append(recall)
    all_f1.append(f1)

    # Imprimir matriz de confusión
    cm = confusion_matrix(y_clase_test, y_pred_clase, labels=np.unique(y_clase_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_)
    plt.figure(figsize=(12, 8))
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title(f'Matriz de Confusión')
    plt.tight_layout()
    plt.show()
# Out:
# Entrenando fold 1...
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 26179.7480 - salida_clase_accuracy: 0.6334 - salidas_continuas_mae: 94.6476 - val_loss: 15620.8262 - val_salida_clase_accuracy: 0.9194 - val_salidas_continuas_mae: 66.2196 - learning_rate: 5.0000e-04
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 11256.9697 - salida_clase_accuracy: 0.8768 - salidas_continuas_mae: 56.7069 - val_loss: 7274.5898 - val_salida_clase_accuracy: 0.9389 - val_salidas_continuas_mae: 49.3865 - learning_rate: 5.0000e-04
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 7159.4263 - salida_clase_accuracy: 0.8956 - salidas_continuas_mae: 47.2325 - val_loss: 5365.9043 - val_salida_clase_accuracy: 0.9447 - val_salidas_continuas_mae: 43.7297 - learning_rate: 5.0000e-04
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 5214.5620 - salida_clase_accuracy: 0.9082 - salidas_continuas_mae: 40.9913 - val_loss: 4503.5981 - val_salida_clase_accuracy: 0.9680 - val_salidas_continuas_mae: 39.5657 - learning_rate: 5.0000e-04
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 4125.3848 - salida_clase_accuracy: 0.9189 - salidas_continuas_mae: 36.5467 - val_loss: 3594.5806 - val_salida_clase_accuracy: 0.9680 - val_salidas_continuas_mae: 34.2164 - learning_rate: 5.0000e-04
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 3489.8000 - salida_clase_accuracy: 0.9290 - salidas_continuas_mae: 33.8463 - val_loss: 2886.3306 - val_salida_clase_accuracy: 0.9734 - val_salidas_continuas_mae: 30.1584 - learning_rate: 5.0000e-04
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 3041.0720 - salida_clase_accuracy: 0.9352 - salidas_continuas_mae: 31.7681 - val_loss: 2572.1187 - val_salida_clase_accuracy: 0.9834 - val_salidas_continuas_mae: 28.1715 - learning_rate: 5.0000e-04
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 2717.2783 - salida_clase_accuracy: 0.9440 - salidas_continuas_mae: 30.1934 - val_loss: 2308.0854 - val_salida_clase_accuracy: 0.9821 - val_salidas_continuas_mae: 27.1177 - learning_rate: 5.0000e-04
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2500.5923 - salida_clase_accuracy: 0.9474 - salidas_continuas_mae: 29.0562 - val_loss: 2045.0447 - val_salida_clase_accuracy: 0.9786 - val_salidas_continuas_mae: 25.3030 - learning_rate: 5.0000e-04
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2307.9297 - salida_clase_accuracy: 0.9541 - salidas_continuas_mae: 28.1814 - val_loss: 1871.4581 - val_salida_clase_accuracy: 0.9872 - val_salidas_continuas_mae: 24.0849 - learning_rate: 5.0000e-04
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2156.4766 - salida_clase_accuracy: 0.9509 - salidas_continuas_mae: 27.3803 - val_loss: 1749.7341 - val_salida_clase_accuracy: 0.9875 - val_salidas_continuas_mae: 24.5316 - learning_rate: 5.0000e-04
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1977.3151 - salida_clase_accuracy: 0.9577 - salidas_continuas_mae: 26.5161 - val_loss: 1594.3530 - val_salida_clase_accuracy: 0.9885 - val_salidas_continuas_mae: 22.8565 - learning_rate: 5.0000e-04
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1847.8534 - salida_clase_accuracy: 0.9545 - salidas_continuas_mae: 25.7484 - val_loss: 1601.8928 - val_salida_clase_accuracy: 0.9869 - val_salidas_continuas_mae: 23.2307 - learning_rate: 5.0000e-04
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1741.9841 - salida_clase_accuracy: 0.9594 - salidas_continuas_mae: 25.2701 - val_loss: 1415.0845 - val_salida_clase_accuracy: 0.9920 - val_salidas_continuas_mae: 22.6241 - learning_rate: 5.0000e-04
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1676.2349 - salida_clase_accuracy: 0.9609 - salidas_continuas_mae: 24.7691 - val_loss: 1313.0919 - val_salida_clase_accuracy: 0.9907 - val_salidas_continuas_mae: 20.9914 - learning_rate: 5.0000e-04
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1616.8011 - salida_clase_accuracy: 0.9653 - salidas_continuas_mae: 24.4497 - val_loss: 1227.2369 - val_salida_clase_accuracy: 0.9898 - val_salidas_continuas_mae: 20.3776 - learning_rate: 5.0000e-04
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1527.6301 - salida_clase_accuracy: 0.9659 - salidas_continuas_mae: 24.0677 - val_loss: 1148.2480 - val_salida_clase_accuracy: 0.9910 - val_salidas_continuas_mae: 19.3206 - learning_rate: 5.0000e-04
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1516.2428 - salida_clase_accuracy: 0.9674 - salidas_continuas_mae: 23.9184 - val_loss: 1072.3411 - val_salida_clase_accuracy: 0.9901 - val_salidas_continuas_mae: 18.6639 - learning_rate: 5.0000e-04
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1419.4548 - salida_clase_accuracy: 0.9688 - salidas_continuas_mae: 23.4659 - val_loss: 1041.9591 - val_salida_clase_accuracy: 0.9926 - val_salidas_continuas_mae: 18.8712 - learning_rate: 5.0000e-04
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1345.5778 - salida_clase_accuracy: 0.9715 - salidas_continuas_mae: 23.1407 - val_loss: 994.9903 - val_salida_clase_accuracy: 0.9933 - val_salidas_continuas_mae: 18.3292 - learning_rate: 5.0000e-04
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1331.3551 - salida_clase_accuracy: 0.9701 - salidas_continuas_mae: 22.8094 - val_loss: 970.9850 - val_salida_clase_accuracy: 0.9904 - val_salidas_continuas_mae: 18.5274 - learning_rate: 5.0000e-04
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1303.6171 - salida_clase_accuracy: 0.9714 - salidas_continuas_mae: 22.7572 - val_loss: 1021.4833 - val_salida_clase_accuracy: 0.9888 - val_salidas_continuas_mae: 19.2703 - learning_rate: 5.0000e-04
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1265.9747 - salida_clase_accuracy: 0.9760 - salidas_continuas_mae: 22.3767 - val_loss: 869.0062 - val_salida_clase_accuracy: 0.9933 - val_salidas_continuas_mae: 17.2406 - learning_rate: 5.0000e-04
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1285.6982 - salida_clase_accuracy: 0.9759 - salidas_continuas_mae: 22.3854 - val_loss: 828.0562 - val_salida_clase_accuracy: 0.9946 - val_salidas_continuas_mae: 16.8561 - learning_rate: 5.0000e-04
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1180.2222 - salida_clase_accuracy: 0.9701 - salidas_continuas_mae: 21.9401 - val_loss: 801.8529 - val_salida_clase_accuracy: 0.9936 - val_salidas_continuas_mae: 16.3721 - learning_rate: 5.0000e-04
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1189.2010 - salida_clase_accuracy: 0.9769 - salidas_continuas_mae: 21.8290 - val_loss: 762.0107 - val_salida_clase_accuracy: 0.9936 - val_salidas_continuas_mae: 16.0577 - learning_rate: 5.0000e-04
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1172.2614 - salida_clase_accuracy: 0.9748 - salidas_continuas_mae: 21.5707 - val_loss: 789.0735 - val_salida_clase_accuracy: 0.9936 - val_salidas_continuas_mae: 17.1000 - learning_rate: 5.0000e-04
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1128.2151 - salida_clase_accuracy: 0.9760 - salidas_continuas_mae: 21.4704 - val_loss: 807.0946 - val_salida_clase_accuracy: 0.9933 - val_salidas_continuas_mae: 17.3332 - learning_rate: 5.0000e-04
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1147.5189 - salida_clase_accuracy: 0.9807 - salidas_continuas_mae: 21.4565 - val_loss: 720.9448 - val_salida_clase_accuracy: 0.9952 - val_salidas_continuas_mae: 15.8198 - learning_rate: 5.0000e-04
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1116.8497 - salida_clase_accuracy: 0.9739 - salidas_continuas_mae: 21.3262 - val_loss: 692.2902 - val_salida_clase_accuracy: 0.9930 - val_salidas_continuas_mae: 15.1414 - learning_rate: 5.0000e-04
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1151.4108 - salida_clase_accuracy: 0.9800 - salidas_continuas_mae: 21.4375 - val_loss: 672.3704 - val_salida_clase_accuracy: 0.9936 - val_salidas_continuas_mae: 15.1860 - learning_rate: 5.0000e-04
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1110.4720 - salida_clase_accuracy: 0.9792 - salidas_continuas_mae: 21.2646 - val_loss: 694.3802 - val_salida_clase_accuracy: 0.9946 - val_salidas_continuas_mae: 15.7855 - learning_rate: 5.0000e-04
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1066.9030 - salida_clase_accuracy: 0.9794 - salidas_continuas_mae: 21.0118 - val_loss: 657.7474 - val_salida_clase_accuracy: 0.9930 - val_salidas_continuas_mae: 14.9614 - learning_rate: 5.0000e-04
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1061.6797 - salida_clase_accuracy: 0.9816 - salidas_continuas_mae: 20.8598 - val_loss: 655.6133 - val_salida_clase_accuracy: 0.9946 - val_salidas_continuas_mae: 14.9997 - learning_rate: 5.0000e-04
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1076.8040 - salida_clase_accuracy: 0.9824 - salidas_continuas_mae: 20.8272 - val_loss: 641.6126 - val_salida_clase_accuracy: 0.9942 - val_salidas_continuas_mae: 14.6948 - learning_rate: 5.0000e-04
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1046.5426 - salida_clase_accuracy: 0.9797 - salidas_continuas_mae: 20.5826 - val_loss: 728.9636 - val_salida_clase_accuracy: 0.9952 - val_salidas_continuas_mae: 15.7695 - learning_rate: 5.0000e-04
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1047.1692 - salida_clase_accuracy: 0.9822 - salidas_continuas_mae: 20.7954 - val_loss: 677.6599 - val_salida_clase_accuracy: 0.9946 - val_salidas_continuas_mae: 15.6876 - learning_rate: 5.0000e-04
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1011.3705 - salida_clase_accuracy: 0.9819 - salidas_continuas_mae: 20.4910 - val_loss: 617.5301 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 15.0468 - learning_rate: 5.0000e-04
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1024.8914 - salida_clase_accuracy: 0.9827 - salidas_continuas_mae: 20.5449 - val_loss: 607.4837 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 14.4583 - learning_rate: 5.0000e-04
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 991.0466 - salida_clase_accuracy: 0.9820 - salidas_continuas_mae: 20.2102 - val_loss: 595.5710 - val_salida_clase_accuracy: 0.9933 - val_salidas_continuas_mae: 14.1546 - learning_rate: 5.0000e-04
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1005.7420 - salida_clase_accuracy: 0.9817 - salidas_continuas_mae: 20.1969 - val_loss: 603.4180 - val_salida_clase_accuracy: 0.9939 - val_salidas_continuas_mae: 14.7559 - learning_rate: 5.0000e-04
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1038.7285 - salida_clase_accuracy: 0.9801 - salidas_continuas_mae: 20.6096 - val_loss: 601.3376 - val_salida_clase_accuracy: 0.9949 - val_salidas_continuas_mae: 14.7259 - learning_rate: 5.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 987.1506 - salida_clase_accuracy: 0.9859 - salidas_continuas_mae: 20.2345 - val_loss: 650.5527 - val_salida_clase_accuracy: 0.9949 - val_salidas_continuas_mae: 15.8819 - learning_rate: 5.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 990.8474 - salida_clase_accuracy: 0.9816 - salidas_continuas_mae: 20.1371 - val_loss: 606.6978 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 14.7964 - learning_rate: 5.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 947.0482 - salida_clase_accuracy: 0.9803 - salidas_continuas_mae: 19.8896 - val_loss: 626.3732 - val_salida_clase_accuracy: 0.9965 - val_salidas_continuas_mae: 15.5303 - learning_rate: 5.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 965.0978 - salida_clase_accuracy: 0.9844 - salidas_continuas_mae: 19.9814 - val_loss: 575.9037 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 14.3146 - learning_rate: 2.5000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 969.9909 - salida_clase_accuracy: 0.9877 - salidas_continuas_mae: 19.9758 - val_loss: 571.3499 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 14.1079 - learning_rate: 2.5000e-04
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 960.0139 - salida_clase_accuracy: 0.9878 - salidas_continuas_mae: 19.9311 - val_loss: 542.7570 - val_salida_clase_accuracy: 0.9968 - val_salidas_continuas_mae: 13.5357 - learning_rate: 2.5000e-04
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 965.3970 - salida_clase_accuracy: 0.9875 - salidas_continuas_mae: 19.9568 - val_loss: 572.1948 - val_salida_clase_accuracy: 0.9971 - val_salidas_continuas_mae: 14.2103 - learning_rate: 2.5000e-04
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 950.3137 - salida_clase_accuracy: 0.9855 - salidas_continuas_mae: 19.8529 - val_loss: 542.6245 - val_salida_clase_accuracy: 0.9965 - val_salidas_continuas_mae: 13.6452 - learning_rate: 2.5000e-04
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 474.8095 - salida_clase_accuracy: 0.9966 - salidas_continuas_mae: 13.3458
# Fold 1: Loss=465.565673828125, MAE=13.208700180053711, Accuracy=0.9969293475151062
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Entrenando fold 2...
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - loss: 26008.4941 - salida_clase_accuracy: 0.6574 - salidas_continuas_mae: 94.5656 - val_loss: 14949.1494 - val_salida_clase_accuracy: 0.9117 - val_salidas_continuas_mae: 62.8630 - learning_rate: 5.0000e-04
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 11279.5410 - salida_clase_accuracy: 0.8802 - salidas_continuas_mae: 56.8235 - val_loss: 7361.7568 - val_salida_clase_accuracy: 0.9360 - val_salidas_continuas_mae: 49.2662 - learning_rate: 5.0000e-04
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 6792.2241 - salida_clase_accuracy: 0.9018 - salidas_continuas_mae: 46.4902 - val_loss: 5498.3530 - val_salida_clase_accuracy: 0.9463 - val_salidas_continuas_mae: 43.5601 - learning_rate: 5.0000e-04
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 5180.4683 - salida_clase_accuracy: 0.9076 - salidas_continuas_mae: 40.4504 - val_loss: 4412.5337 - val_salida_clase_accuracy: 0.9507 - val_salidas_continuas_mae: 38.7664 - learning_rate: 5.0000e-04
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 4181.1035 - salida_clase_accuracy: 0.9237 - salidas_continuas_mae: 36.3671 - val_loss: 3411.4807 - val_salida_clase_accuracy: 0.9696 - val_salidas_continuas_mae: 33.6002 - learning_rate: 5.0000e-04
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 3557.5945 - salida_clase_accuracy: 0.9319 - salidas_continuas_mae: 33.4230 - val_loss: 2892.9375 - val_salida_clase_accuracy: 0.9623 - val_salidas_continuas_mae: 30.3696 - learning_rate: 5.0000e-04
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 3056.2388 - salida_clase_accuracy: 0.9356 - salidas_continuas_mae: 31.5448 - val_loss: 2358.0972 - val_salida_clase_accuracy: 0.9680 - val_salidas_continuas_mae: 28.0945 - learning_rate: 5.0000e-04
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 2750.3577 - salida_clase_accuracy: 0.9415 - salidas_continuas_mae: 30.0599 - val_loss: 2122.4917 - val_salida_clase_accuracy: 0.9830 - val_salidas_continuas_mae: 26.8893 - learning_rate: 5.0000e-04
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 2558.0835 - salida_clase_accuracy: 0.9487 - salidas_continuas_mae: 29.2454 - val_loss: 1839.2058 - val_salida_clase_accuracy: 0.9859 - val_salidas_continuas_mae: 24.8369 - learning_rate: 5.0000e-04
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 2276.3242 - salida_clase_accuracy: 0.9544 - salidas_continuas_mae: 27.6973 - val_loss: 1650.5460 - val_salida_clase_accuracy: 0.9846 - val_salidas_continuas_mae: 23.8438 - learning_rate: 5.0000e-04
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 2059.0374 - salida_clase_accuracy: 0.9555 - salidas_continuas_mae: 26.9279 - val_loss: 1632.3530 - val_salida_clase_accuracy: 0.9843 - val_salidas_continuas_mae: 24.4043 - learning_rate: 5.0000e-04
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1998.7756 - salida_clase_accuracy: 0.9561 - salidas_continuas_mae: 26.5073 - val_loss: 1352.8484 - val_salida_clase_accuracy: 0.9866 - val_salidas_continuas_mae: 22.2968 - learning_rate: 5.0000e-04
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 1794.3425 - salida_clase_accuracy: 0.9634 - salidas_continuas_mae: 25.5058 - val_loss: 1286.6285 - val_salida_clase_accuracy: 0.9830 - val_salidas_continuas_mae: 21.9671 - learning_rate: 5.0000e-04
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 1742.9674 - salida_clase_accuracy: 0.9641 - salidas_continuas_mae: 25.2362 - val_loss: 1120.6216 - val_salida_clase_accuracy: 0.9923 - val_salidas_continuas_mae: 19.8965 - learning_rate: 5.0000e-04
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 1633.1924 - salida_clase_accuracy: 0.9603 - salidas_continuas_mae: 24.6229 - val_loss: 1107.1050 - val_salida_clase_accuracy: 0.9914 - val_salidas_continuas_mae: 19.9214 - learning_rate: 5.0000e-04
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1562.8573 - salida_clase_accuracy: 0.9635 - salidas_continuas_mae: 24.0498 - val_loss: 1004.1923 - val_salida_clase_accuracy: 0.9914 - val_salidas_continuas_mae: 19.1851 - learning_rate: 5.0000e-04
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1522.9437 - salida_clase_accuracy: 0.9666 - salidas_continuas_mae: 23.9771 - val_loss: 974.4696 - val_salida_clase_accuracy: 0.9891 - val_salidas_continuas_mae: 18.8513 - learning_rate: 5.0000e-04
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 1487.1616 - salida_clase_accuracy: 0.9657 - salidas_continuas_mae: 23.8014 - val_loss: 898.7917 - val_salida_clase_accuracy: 0.9926 - val_salidas_continuas_mae: 18.5057 - learning_rate: 5.0000e-04
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1358.2375 - salida_clase_accuracy: 0.9701 - salidas_continuas_mae: 23.1742 - val_loss: 877.1418 - val_salida_clase_accuracy: 0.9920 - val_salidas_continuas_mae: 18.2695 - learning_rate: 5.0000e-04
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1339.2917 - salida_clase_accuracy: 0.9666 - salidas_continuas_mae: 22.9565 - val_loss: 837.9247 - val_salida_clase_accuracy: 0.9901 - val_salidas_continuas_mae: 17.5694 - learning_rate: 5.0000e-04
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 1340.4584 - salida_clase_accuracy: 0.9736 - salidas_continuas_mae: 22.8631 - val_loss: 805.5712 - val_salida_clase_accuracy: 0.9926 - val_salidas_continuas_mae: 17.4584 - learning_rate: 5.0000e-04
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1292.6095 - salida_clase_accuracy: 0.9735 - salidas_continuas_mae: 22.5841 - val_loss: 801.3643 - val_salida_clase_accuracy: 0.9920 - val_salidas_continuas_mae: 17.4941 - learning_rate: 5.0000e-04
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1263.7957 - salida_clase_accuracy: 0.9721 - salidas_continuas_mae: 22.3457 - val_loss: 725.1405 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 16.2821 - learning_rate: 5.0000e-04
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 1228.9296 - salida_clase_accuracy: 0.9771 - salidas_continuas_mae: 22.1888 - val_loss: 760.7088 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 17.2121 - learning_rate: 5.0000e-04
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1210.3124 - salida_clase_accuracy: 0.9760 - salidas_continuas_mae: 21.9924 - val_loss: 727.7029 - val_salida_clase_accuracy: 0.9952 - val_salidas_continuas_mae: 16.6594 - learning_rate: 5.0000e-04
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1164.1008 - salida_clase_accuracy: 0.9748 - salidas_continuas_mae: 21.7642 - val_loss: 688.8431 - val_salida_clase_accuracy: 0.9942 - val_salidas_continuas_mae: 16.2692 - learning_rate: 5.0000e-04
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1169.2856 - salida_clase_accuracy: 0.9784 - salidas_continuas_mae: 21.7757 - val_loss: 683.2872 - val_salida_clase_accuracy: 0.9942 - val_salidas_continuas_mae: 16.3861 - learning_rate: 5.0000e-04
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1149.4784 - salida_clase_accuracy: 0.9757 - salidas_continuas_mae: 21.5822 - val_loss: 677.4275 - val_salida_clase_accuracy: 0.9910 - val_salidas_continuas_mae: 16.1171 - learning_rate: 5.0000e-04
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1112.2543 - salida_clase_accuracy: 0.9779 - salidas_continuas_mae: 21.2940 - val_loss: 653.7721 - val_salida_clase_accuracy: 0.9930 - val_salidas_continuas_mae: 15.8553 - learning_rate: 5.0000e-04
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1102.0525 - salida_clase_accuracy: 0.9793 - salidas_continuas_mae: 21.2697 - val_loss: 656.5515 - val_salida_clase_accuracy: 0.9901 - val_salidas_continuas_mae: 15.9950 - learning_rate: 5.0000e-04
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1102.8833 - salida_clase_accuracy: 0.9799 - salidas_continuas_mae: 21.2936 - val_loss: 635.7361 - val_salida_clase_accuracy: 0.9923 - val_salidas_continuas_mae: 15.8510 - learning_rate: 5.0000e-04
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1094.7932 - salida_clase_accuracy: 0.9831 - salidas_continuas_mae: 21.2132 - val_loss: 631.3538 - val_salida_clase_accuracy: 0.9930 - val_salidas_continuas_mae: 15.3513 - learning_rate: 5.0000e-04
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 1088.7510 - salida_clase_accuracy: 0.9789 - salidas_continuas_mae: 20.9766 - val_loss: 642.5649 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 15.9631 - learning_rate: 5.0000e-04
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1056.4332 - salida_clase_accuracy: 0.9814 - salidas_continuas_mae: 20.8531 - val_loss: 595.3300 - val_salida_clase_accuracy: 0.9952 - val_salidas_continuas_mae: 15.0612 - learning_rate: 5.0000e-04
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 1043.2346 - salida_clase_accuracy: 0.9813 - salidas_continuas_mae: 20.7792 - val_loss: 605.9550 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 15.0394 - learning_rate: 5.0000e-04
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 1049.6661 - salida_clase_accuracy: 0.9821 - salidas_continuas_mae: 20.6515 - val_loss: 605.1487 - val_salida_clase_accuracy: 0.9968 - val_salidas_continuas_mae: 15.2288 - learning_rate: 5.0000e-04
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 1057.1605 - salida_clase_accuracy: 0.9812 - salidas_continuas_mae: 20.7242 - val_loss: 589.0706 - val_salida_clase_accuracy: 0.9968 - val_salidas_continuas_mae: 15.1497 - learning_rate: 5.0000e-04
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1026.9805 - salida_clase_accuracy: 0.9794 - salidas_continuas_mae: 20.4670 - val_loss: 542.6754 - val_salida_clase_accuracy: 0.9920 - val_salidas_continuas_mae: 13.8339 - learning_rate: 5.0000e-04
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1030.2106 - salida_clase_accuracy: 0.9816 - salidas_continuas_mae: 20.4599 - val_loss: 565.7465 - val_salida_clase_accuracy: 0.9942 - val_salidas_continuas_mae: 14.4918 - learning_rate: 5.0000e-04
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1001.3574 - salida_clase_accuracy: 0.9832 - salidas_continuas_mae: 20.2636 - val_loss: 556.3723 - val_salida_clase_accuracy: 0.9968 - val_salidas_continuas_mae: 14.5976 - learning_rate: 5.0000e-04
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 991.8107 - salida_clase_accuracy: 0.9821 - salidas_continuas_mae: 20.1597 - val_loss: 555.4192 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 14.6987 - learning_rate: 5.0000e-04
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1011.9055 - salida_clase_accuracy: 0.9847 - salidas_continuas_mae: 20.2896 - val_loss: 537.0154 - val_salida_clase_accuracy: 0.9933 - val_salidas_continuas_mae: 14.0254 - learning_rate: 5.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 965.1304 - salida_clase_accuracy: 0.9797 - salidas_continuas_mae: 20.1362 - val_loss: 604.6791 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 15.1980 - learning_rate: 5.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 980.4788 - salida_clase_accuracy: 0.9849 - salidas_continuas_mae: 20.1244 - val_loss: 546.7048 - val_salida_clase_accuracy: 0.9949 - val_salidas_continuas_mae: 14.5929 - learning_rate: 5.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 979.7759 - salida_clase_accuracy: 0.9836 - salidas_continuas_mae: 20.1116 - val_loss: 574.6611 - val_salida_clase_accuracy: 0.9949 - val_salidas_continuas_mae: 15.0824 - learning_rate: 5.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 1000.3154 - salida_clase_accuracy: 0.9856 - salidas_continuas_mae: 20.1022 - val_loss: 562.2332 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 14.5918 - learning_rate: 5.0000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 978.1851 - salida_clase_accuracy: 0.9831 - salidas_continuas_mae: 20.0554 - val_loss: 550.3293 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 14.6978 - learning_rate: 5.0000e-04
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 945.7549 - salida_clase_accuracy: 0.9840 - salidas_continuas_mae: 19.8050 - val_loss: 521.7391 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 13.9631 - learning_rate: 2.5000e-04
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 961.9994 - salida_clase_accuracy: 0.9832 - salidas_continuas_mae: 19.8714 - val_loss: 521.2593 - val_salida_clase_accuracy: 0.9968 - val_salidas_continuas_mae: 13.9339 - learning_rate: 2.5000e-04
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 950.1255 - salida_clase_accuracy: 0.9861 - salidas_continuas_mae: 19.7754 - val_loss: 513.3834 - val_salida_clase_accuracy: 0.9968 - val_salidas_continuas_mae: 13.8758 - learning_rate: 2.5000e-04
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 479.0421 - salida_clase_accuracy: 0.9961 - salidas_continuas_mae: 13.5561
# Fold 2: Loss=472.5274353027344, MAE=13.457815170288086, Accuracy=0.9971852898597717
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Entrenando fold 3...
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - loss: 25729.0430 - salida_clase_accuracy: 0.6393 - salidas_continuas_mae: 93.8386 - val_loss: 15183.1914 - val_salida_clase_accuracy: 0.9088 - val_salidas_continuas_mae: 61.9967 - learning_rate: 5.0000e-04
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 11431.7822 - salida_clase_accuracy: 0.8639 - salidas_continuas_mae: 56.6643 - val_loss: 7402.4165 - val_salida_clase_accuracy: 0.9363 - val_salidas_continuas_mae: 49.6583 - learning_rate: 5.0000e-04
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 6906.9985 - salida_clase_accuracy: 0.8809 - salidas_continuas_mae: 46.8454 - val_loss: 5202.3066 - val_salida_clase_accuracy: 0.9459 - val_salidas_continuas_mae: 42.8111 - learning_rate: 5.0000e-04
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 5114.6245 - salida_clase_accuracy: 0.9096 - salidas_continuas_mae: 40.6011 - val_loss: 4047.2844 - val_salida_clase_accuracy: 0.9683 - val_salidas_continuas_mae: 37.4634 - learning_rate: 5.0000e-04
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 4160.4517 - salida_clase_accuracy: 0.9174 - salidas_continuas_mae: 36.8353 - val_loss: 3270.3713 - val_salida_clase_accuracy: 0.9760 - val_salidas_continuas_mae: 32.3848 - learning_rate: 5.0000e-04
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 3540.5229 - salida_clase_accuracy: 0.9303 - salidas_continuas_mae: 33.7800 - val_loss: 2842.9832 - val_salida_clase_accuracy: 0.9830 - val_salidas_continuas_mae: 30.0525 - learning_rate: 5.0000e-04
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 3096.5549 - salida_clase_accuracy: 0.9342 - salidas_continuas_mae: 31.8728 - val_loss: 2452.7937 - val_salida_clase_accuracy: 0.9808 - val_salidas_continuas_mae: 28.0704 - learning_rate: 5.0000e-04
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 2703.5581 - salida_clase_accuracy: 0.9398 - salidas_continuas_mae: 30.2994 - val_loss: 2295.3511 - val_salida_clase_accuracy: 0.9840 - val_salidas_continuas_mae: 27.4518 - learning_rate: 5.0000e-04
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2558.1562 - salida_clase_accuracy: 0.9408 - salidas_continuas_mae: 29.4154 - val_loss: 2030.4078 - val_salida_clase_accuracy: 0.9834 - val_salidas_continuas_mae: 25.5731 - learning_rate: 5.0000e-04
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 2332.9421 - salida_clase_accuracy: 0.9558 - salidas_continuas_mae: 28.4152 - val_loss: 1771.4958 - val_salida_clase_accuracy: 0.9802 - val_salidas_continuas_mae: 23.4496 - learning_rate: 5.0000e-04
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 2162.3618 - salida_clase_accuracy: 0.9535 - salidas_continuas_mae: 27.5776 - val_loss: 1642.7269 - val_salida_clase_accuracy: 0.9702 - val_salidas_continuas_mae: 23.0957 - learning_rate: 5.0000e-04
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 2113.0281 - salida_clase_accuracy: 0.9523 - salidas_continuas_mae: 27.1029 - val_loss: 1577.7563 - val_salida_clase_accuracy: 0.9827 - val_salidas_continuas_mae: 22.9186 - learning_rate: 5.0000e-04
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1905.2163 - salida_clase_accuracy: 0.9565 - salidas_continuas_mae: 26.2338 - val_loss: 1408.5721 - val_salida_clase_accuracy: 0.9856 - val_salidas_continuas_mae: 21.4896 - learning_rate: 5.0000e-04
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1820.6237 - salida_clase_accuracy: 0.9596 - salidas_continuas_mae: 25.7019 - val_loss: 1514.4180 - val_salida_clase_accuracy: 0.9856 - val_salidas_continuas_mae: 23.4460 - learning_rate: 5.0000e-04
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1707.4891 - salida_clase_accuracy: 0.9643 - salidas_continuas_mae: 25.1009 - val_loss: 1257.9855 - val_salida_clase_accuracy: 0.9827 - val_salidas_continuas_mae: 19.9033 - learning_rate: 5.0000e-04
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1704.8871 - salida_clase_accuracy: 0.9662 - salidas_continuas_mae: 24.9984 - val_loss: 1200.5862 - val_salida_clase_accuracy: 0.9872 - val_salidas_continuas_mae: 20.7975 - learning_rate: 5.0000e-04
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1540.0695 - salida_clase_accuracy: 0.9659 - salidas_continuas_mae: 24.2509 - val_loss: 1056.8657 - val_salida_clase_accuracy: 0.9907 - val_salidas_continuas_mae: 18.7353 - learning_rate: 5.0000e-04
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1521.6707 - salida_clase_accuracy: 0.9632 - salidas_continuas_mae: 24.1154 - val_loss: 1074.5342 - val_salida_clase_accuracy: 0.9923 - val_salidas_continuas_mae: 19.2726 - learning_rate: 5.0000e-04
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1482.8956 - salida_clase_accuracy: 0.9714 - salidas_continuas_mae: 23.8608 - val_loss: 1044.7474 - val_salida_clase_accuracy: 0.9888 - val_salidas_continuas_mae: 19.3439 - learning_rate: 5.0000e-04
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 1461.7069 - salida_clase_accuracy: 0.9688 - salidas_continuas_mae: 23.6247 - val_loss: 920.2104 - val_salida_clase_accuracy: 0.9891 - val_salidas_continuas_mae: 17.6391 - learning_rate: 5.0000e-04
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1402.2263 - salida_clase_accuracy: 0.9689 - salidas_continuas_mae: 23.3317 - val_loss: 901.4246 - val_salida_clase_accuracy: 0.9942 - val_salidas_continuas_mae: 17.5021 - learning_rate: 5.0000e-04
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1342.8418 - salida_clase_accuracy: 0.9750 - salidas_continuas_mae: 22.9501 - val_loss: 953.5051 - val_salida_clase_accuracy: 0.9869 - val_salidas_continuas_mae: 18.4746 - learning_rate: 5.0000e-04
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1363.5161 - salida_clase_accuracy: 0.9754 - salidas_continuas_mae: 23.0398 - val_loss: 849.3989 - val_salida_clase_accuracy: 0.9917 - val_salidas_continuas_mae: 17.6231 - learning_rate: 5.0000e-04
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1283.4882 - salida_clase_accuracy: 0.9720 - salidas_continuas_mae: 22.5604 - val_loss: 830.3528 - val_salida_clase_accuracy: 0.9926 - val_salidas_continuas_mae: 17.4604 - learning_rate: 5.0000e-04
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1230.2166 - salida_clase_accuracy: 0.9786 - salidas_continuas_mae: 22.2215 - val_loss: 755.4301 - val_salida_clase_accuracy: 0.9926 - val_salidas_continuas_mae: 16.2832 - learning_rate: 5.0000e-04
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1264.1235 - salida_clase_accuracy: 0.9771 - salidas_continuas_mae: 22.3474 - val_loss: 753.7340 - val_salida_clase_accuracy: 0.9926 - val_salidas_continuas_mae: 16.6029 - learning_rate: 5.0000e-04
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1199.0574 - salida_clase_accuracy: 0.9781 - salidas_continuas_mae: 21.9428 - val_loss: 771.0974 - val_salida_clase_accuracy: 0.9942 - val_salidas_continuas_mae: 16.6312 - learning_rate: 5.0000e-04
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1180.8383 - salida_clase_accuracy: 0.9818 - salidas_continuas_mae: 21.8775 - val_loss: 703.1049 - val_salida_clase_accuracy: 0.9933 - val_salidas_continuas_mae: 15.8216 - learning_rate: 5.0000e-04
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1200.9526 - salida_clase_accuracy: 0.9764 - salidas_continuas_mae: 21.8413 - val_loss: 657.7808 - val_salida_clase_accuracy: 0.9936 - val_salidas_continuas_mae: 15.3667 - learning_rate: 5.0000e-04
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1165.1278 - salida_clase_accuracy: 0.9774 - salidas_continuas_mae: 21.7051 - val_loss: 671.5510 - val_salida_clase_accuracy: 0.9923 - val_salidas_continuas_mae: 15.7832 - learning_rate: 5.0000e-04
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1145.7468 - salida_clase_accuracy: 0.9810 - salidas_continuas_mae: 21.4406 - val_loss: 642.6954 - val_salida_clase_accuracy: 0.9939 - val_salidas_continuas_mae: 15.2693 - learning_rate: 5.0000e-04
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1123.8025 - salida_clase_accuracy: 0.9798 - salidas_continuas_mae: 21.4748 - val_loss: 680.7234 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 16.2061 - learning_rate: 5.0000e-04
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1115.4553 - salida_clase_accuracy: 0.9798 - salidas_continuas_mae: 21.3043 - val_loss: 623.5832 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 14.9862 - learning_rate: 5.0000e-04
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1099.5602 - salida_clase_accuracy: 0.9781 - salidas_continuas_mae: 21.1285 - val_loss: 635.1664 - val_salida_clase_accuracy: 0.9930 - val_salidas_continuas_mae: 15.5096 - learning_rate: 5.0000e-04
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1102.0806 - salida_clase_accuracy: 0.9794 - salidas_continuas_mae: 21.1142 - val_loss: 640.9723 - val_salida_clase_accuracy: 0.9949 - val_salidas_continuas_mae: 15.6491 - learning_rate: 5.0000e-04
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1048.4441 - salida_clase_accuracy: 0.9820 - salidas_continuas_mae: 20.7146 - val_loss: 599.2083 - val_salida_clase_accuracy: 0.9946 - val_salidas_continuas_mae: 15.1872 - learning_rate: 5.0000e-04
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1080.8104 - salida_clase_accuracy: 0.9826 - salidas_continuas_mae: 20.9841 - val_loss: 613.8107 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 15.2321 - learning_rate: 5.0000e-04
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1044.8525 - salida_clase_accuracy: 0.9804 - salidas_continuas_mae: 20.7830 - val_loss: 585.9250 - val_salida_clase_accuracy: 0.9936 - val_salidas_continuas_mae: 14.7217 - learning_rate: 5.0000e-04
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1081.7427 - salida_clase_accuracy: 0.9814 - salidas_continuas_mae: 20.9039 - val_loss: 563.9917 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 14.2058 - learning_rate: 5.0000e-04
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1037.5715 - salida_clase_accuracy: 0.9827 - salidas_continuas_mae: 20.6416 - val_loss: 546.2409 - val_salida_clase_accuracy: 0.9949 - val_salidas_continuas_mae: 13.9585 - learning_rate: 5.0000e-04
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1052.2172 - salida_clase_accuracy: 0.9814 - salidas_continuas_mae: 20.7907 - val_loss: 561.8880 - val_salida_clase_accuracy: 0.9942 - val_salidas_continuas_mae: 14.4057 - learning_rate: 5.0000e-04
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1039.0439 - salida_clase_accuracy: 0.9810 - salidas_continuas_mae: 20.5568 - val_loss: 589.7776 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 15.1729 - learning_rate: 5.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1027.7917 - salida_clase_accuracy: 0.9805 - salidas_continuas_mae: 20.5479 - val_loss: 540.1000 - val_salida_clase_accuracy: 0.9952 - val_salidas_continuas_mae: 14.1362 - learning_rate: 5.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 992.8809 - salida_clase_accuracy: 0.9808 - salidas_continuas_mae: 20.3041 - val_loss: 584.9617 - val_salida_clase_accuracy: 0.9946 - val_salidas_continuas_mae: 15.1093 - learning_rate: 5.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 970.8371 - salida_clase_accuracy: 0.9839 - salidas_continuas_mae: 20.0890 - val_loss: 542.2418 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 14.0826 - learning_rate: 5.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 968.4797 - salida_clase_accuracy: 0.9846 - salidas_continuas_mae: 20.1053 - val_loss: 529.5577 - val_salida_clase_accuracy: 0.9952 - val_salidas_continuas_mae: 13.8905 - learning_rate: 5.0000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1015.0665 - salida_clase_accuracy: 0.9829 - salidas_continuas_mae: 20.2860 - val_loss: 524.2408 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 13.8819 - learning_rate: 5.0000e-04
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 969.1565 - salida_clase_accuracy: 0.9847 - salidas_continuas_mae: 19.9929 - val_loss: 547.9140 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 14.4652 - learning_rate: 5.0000e-04
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 994.9399 - salida_clase_accuracy: 0.9849 - salidas_continuas_mae: 20.1591 - val_loss: 536.5110 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 14.3368 - learning_rate: 5.0000e-04
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 987.3144 - salida_clase_accuracy: 0.9848 - salidas_continuas_mae: 19.8795 - val_loss: 523.0449 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 14.1174 - learning_rate: 5.0000e-04
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 491.9441 - salida_clase_accuracy: 0.9962 - salidas_continuas_mae: 13.8661
# Fold 3: Loss=483.6332092285156, MAE=13.743146896362305, Accuracy=0.9976970553398132
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Entrenando fold 4...
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - loss: 26657.2754 - salida_clase_accuracy: 0.6286 - salidas_continuas_mae: 95.0248 - val_loss: 15437.5391 - val_salida_clase_accuracy: 0.8957 - val_salidas_continuas_mae: 62.3421 - learning_rate: 5.0000e-04
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 11781.6807 - salida_clase_accuracy: 0.8759 - salidas_continuas_mae: 56.9406 - val_loss: 7084.3462 - val_salida_clase_accuracy: 0.9322 - val_salidas_continuas_mae: 48.9412 - learning_rate: 5.0000e-04
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 6936.8540 - salida_clase_accuracy: 0.8867 - salidas_continuas_mae: 46.8322 - val_loss: 4982.7021 - val_salida_clase_accuracy: 0.9546 - val_salidas_continuas_mae: 41.5968 - learning_rate: 5.0000e-04
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 5487.6636 - salida_clase_accuracy: 0.9050 - salidas_continuas_mae: 41.5517 - val_loss: 4435.8770 - val_salida_clase_accuracy: 0.9597 - val_salidas_continuas_mae: 38.2769 - learning_rate: 5.0000e-04
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 4202.8701 - salida_clase_accuracy: 0.9227 - salidas_continuas_mae: 36.8386 - val_loss: 3253.6528 - val_salida_clase_accuracy: 0.9731 - val_salidas_continuas_mae: 32.6361 - learning_rate: 5.0000e-04
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 3590.1843 - salida_clase_accuracy: 0.9340 - salidas_continuas_mae: 34.1153 - val_loss: 3068.9724 - val_salida_clase_accuracy: 0.9722 - val_salidas_continuas_mae: 31.1112 - learning_rate: 5.0000e-04
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 3117.2939 - salida_clase_accuracy: 0.9420 - salidas_continuas_mae: 31.9731 - val_loss: 2640.5925 - val_salida_clase_accuracy: 0.9798 - val_salidas_continuas_mae: 29.5479 - learning_rate: 5.0000e-04
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2781.0581 - salida_clase_accuracy: 0.9468 - salidas_continuas_mae: 30.4551 - val_loss: 2291.7598 - val_salida_clase_accuracy: 0.9872 - val_salidas_continuas_mae: 27.0672 - learning_rate: 5.0000e-04
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 2550.4043 - salida_clase_accuracy: 0.9519 - salidas_continuas_mae: 29.2575 - val_loss: 2044.0918 - val_salida_clase_accuracy: 0.9875 - val_salidas_continuas_mae: 26.0144 - learning_rate: 5.0000e-04
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2311.5896 - salida_clase_accuracy: 0.9520 - salidas_continuas_mae: 28.2179 - val_loss: 1744.0312 - val_salida_clase_accuracy: 0.9882 - val_salidas_continuas_mae: 24.1318 - learning_rate: 5.0000e-04
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2054.6172 - salida_clase_accuracy: 0.9550 - salidas_continuas_mae: 27.1379 - val_loss: 1606.1357 - val_salida_clase_accuracy: 0.9814 - val_salidas_continuas_mae: 23.4974 - learning_rate: 5.0000e-04
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1964.4485 - salida_clase_accuracy: 0.9554 - salidas_continuas_mae: 26.4054 - val_loss: 1521.8362 - val_salida_clase_accuracy: 0.9872 - val_salidas_continuas_mae: 22.9538 - learning_rate: 5.0000e-04
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1841.0519 - salida_clase_accuracy: 0.9609 - salidas_continuas_mae: 25.8892 - val_loss: 1316.7909 - val_salida_clase_accuracy: 0.9910 - val_salidas_continuas_mae: 21.2511 - learning_rate: 5.0000e-04
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1714.6339 - salida_clase_accuracy: 0.9607 - salidas_continuas_mae: 25.1237 - val_loss: 1255.3699 - val_salida_clase_accuracy: 0.9907 - val_salidas_continuas_mae: 21.2327 - learning_rate: 5.0000e-04
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1672.3317 - salida_clase_accuracy: 0.9640 - salidas_continuas_mae: 24.8942 - val_loss: 1136.2766 - val_salida_clase_accuracy: 0.9920 - val_salidas_continuas_mae: 19.6493 - learning_rate: 5.0000e-04
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1598.9663 - salida_clase_accuracy: 0.9669 - salidas_continuas_mae: 24.4507 - val_loss: 1160.0817 - val_salida_clase_accuracy: 0.9933 - val_salidas_continuas_mae: 20.5759 - learning_rate: 5.0000e-04
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1538.5812 - salida_clase_accuracy: 0.9699 - salidas_continuas_mae: 23.9155 - val_loss: 1110.1674 - val_salida_clase_accuracy: 0.9923 - val_salidas_continuas_mae: 19.8237 - learning_rate: 5.0000e-04
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1454.1239 - salida_clase_accuracy: 0.9689 - salidas_continuas_mae: 23.6205 - val_loss: 942.8660 - val_salida_clase_accuracy: 0.9901 - val_salidas_continuas_mae: 18.1025 - learning_rate: 5.0000e-04
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1394.9653 - salida_clase_accuracy: 0.9698 - salidas_continuas_mae: 23.1453 - val_loss: 906.7062 - val_salida_clase_accuracy: 0.9930 - val_salidas_continuas_mae: 17.9259 - learning_rate: 5.0000e-04
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1342.2258 - salida_clase_accuracy: 0.9684 - salidas_continuas_mae: 22.9267 - val_loss: 891.3937 - val_salida_clase_accuracy: 0.9933 - val_salidas_continuas_mae: 18.1587 - learning_rate: 5.0000e-04
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1287.6987 - salida_clase_accuracy: 0.9772 - salidas_continuas_mae: 22.6463 - val_loss: 824.2889 - val_salida_clase_accuracy: 0.9939 - val_salidas_continuas_mae: 17.4843 - learning_rate: 5.0000e-04
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1320.0023 - salida_clase_accuracy: 0.9709 - salidas_continuas_mae: 22.4901 - val_loss: 795.7720 - val_salida_clase_accuracy: 0.9946 - val_salidas_continuas_mae: 17.2224 - learning_rate: 5.0000e-04
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1268.6836 - salida_clase_accuracy: 0.9727 - salidas_continuas_mae: 22.3210 - val_loss: 806.1106 - val_salida_clase_accuracy: 0.9936 - val_salidas_continuas_mae: 16.8735 - learning_rate: 5.0000e-04
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1240.7443 - salida_clase_accuracy: 0.9769 - salidas_continuas_mae: 21.9969 - val_loss: 731.9006 - val_salida_clase_accuracy: 0.9952 - val_salidas_continuas_mae: 16.3119 - learning_rate: 5.0000e-04
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1247.8607 - salida_clase_accuracy: 0.9747 - salidas_continuas_mae: 22.1380 - val_loss: 731.6771 - val_salida_clase_accuracy: 0.9949 - val_salidas_continuas_mae: 16.5093 - learning_rate: 5.0000e-04
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1196.7776 - salida_clase_accuracy: 0.9775 - salidas_continuas_mae: 21.8834 - val_loss: 757.2458 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 16.4284 - learning_rate: 5.0000e-04
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1185.8427 - salida_clase_accuracy: 0.9806 - salidas_continuas_mae: 21.6817 - val_loss: 790.2502 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 17.6525 - learning_rate: 5.0000e-04
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1136.3579 - salida_clase_accuracy: 0.9813 - salidas_continuas_mae: 21.2999 - val_loss: 687.6034 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 15.6164 - learning_rate: 5.0000e-04
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1148.3906 - salida_clase_accuracy: 0.9736 - salidas_continuas_mae: 21.4974 - val_loss: 644.2418 - val_salida_clase_accuracy: 0.9952 - val_salidas_continuas_mae: 15.2038 - learning_rate: 5.0000e-04
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1097.9188 - salida_clase_accuracy: 0.9760 - salidas_continuas_mae: 21.0321 - val_loss: 636.5804 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 15.0097 - learning_rate: 5.0000e-04
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1117.1565 - salida_clase_accuracy: 0.9796 - salidas_continuas_mae: 21.1447 - val_loss: 641.3296 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 15.4331 - learning_rate: 5.0000e-04
# Epoch 32/50
# ...
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 976.2557 - salida_clase_accuracy: 0.9812 - salidas_continuas_mae: 20.0020 - val_loss: 602.3807 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 14.8233 - learning_rate: 5.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1008.3954 - salida_clase_accuracy: 0.9828 - salidas_continuas_mae: 20.2279 - val_loss: 546.4797 - val_salida_clase_accuracy: 0.9968 - val_salidas_continuas_mae: 14.2424 - learning_rate: 5.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1009.3922 - salida_clase_accuracy: 0.9830 - salidas_continuas_mae: 20.2075 - val_loss: 555.5524 - val_salida_clase_accuracy: 0.9965 - val_salidas_continuas_mae: 14.4933 - learning_rate: 5.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1004.8639 - salida_clase_accuracy: 0.9846 - salidas_continuas_mae: 20.1514 - val_loss: 548.0771 - val_salida_clase_accuracy: 0.9965 - val_salidas_continuas_mae: 14.1851 - learning_rate: 5.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 998.5040 - salida_clase_accuracy: 0.9877 - salidas_continuas_mae: 19.9890 - val_loss: 597.5992 - val_salida_clase_accuracy: 0.9939 - val_salidas_continuas_mae: 15.3015 - learning_rate: 5.0000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 954.0590 - salida_clase_accuracy: 0.9849 - salidas_continuas_mae: 19.9478 - val_loss: 563.3593 - val_salida_clase_accuracy: 0.9968 - val_salidas_continuas_mae: 14.4681 - learning_rate: 5.0000e-04
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 954.9662 - salida_clase_accuracy: 0.9857 - salidas_continuas_mae: 19.8045 - val_loss: 529.4655 - val_salida_clase_accuracy: 0.9965 - val_salidas_continuas_mae: 14.0695 - learning_rate: 5.0000e-04
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 971.1324 - salida_clase_accuracy: 0.9843 - salidas_continuas_mae: 19.8456 - val_loss: 555.3143 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 14.5615 - learning_rate: 5.0000e-04
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 985.7275 - salida_clase_accuracy: 0.9859 - salidas_continuas_mae: 19.9077 - val_loss: 585.0346 - val_salida_clase_accuracy: 0.9968 - val_salidas_continuas_mae: 15.0913 - learning_rate: 5.0000e-04
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 493.4303 - salida_clase_accuracy: 0.9963 - salidas_continuas_mae: 13.9019
# Fold 4: Loss=486.8677978515625, MAE=13.7841157913208, Accuracy=0.9966734647750854
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Entrenando fold 5...
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - loss: 25516.7715 - salida_clase_accuracy: 0.6289 - salidas_continuas_mae: 93.2559 - val_loss: 16892.0059 - val_salida_clase_accuracy: 0.8938 - val_salidas_continuas_mae: 66.2595 - learning_rate: 5.0000e-04
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 11439.9346 - salida_clase_accuracy: 0.8705 - salidas_continuas_mae: 56.5796 - val_loss: 8730.2451 - val_salida_clase_accuracy: 0.9229 - val_salidas_continuas_mae: 53.4675 - learning_rate: 5.0000e-04
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 6987.2017 - salida_clase_accuracy: 0.8914 - salidas_continuas_mae: 46.8652 - val_loss: 5590.1992 - val_salida_clase_accuracy: 0.9379 - val_salidas_continuas_mae: 44.3155 - learning_rate: 5.0000e-04
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 5308.4756 - salida_clase_accuracy: 0.9082 - salidas_continuas_mae: 41.0302 - val_loss: 3885.7278 - val_salida_clase_accuracy: 0.9584 - val_salidas_continuas_mae: 36.5719 - learning_rate: 5.0000e-04
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 4161.0000 - salida_clase_accuracy: 0.9147 - salidas_continuas_mae: 36.7836 - val_loss: 3168.5227 - val_salida_clase_accuracy: 0.9690 - val_salidas_continuas_mae: 32.7425 - learning_rate: 5.0000e-04
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 3499.5974 - salida_clase_accuracy: 0.9285 - salidas_continuas_mae: 33.6961 - val_loss: 2775.5488 - val_salida_clase_accuracy: 0.9789 - val_salidas_continuas_mae: 30.2154 - learning_rate: 5.0000e-04
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 3032.8411 - salida_clase_accuracy: 0.9416 - salidas_continuas_mae: 31.4111 - val_loss: 2254.1721 - val_salida_clase_accuracy: 0.9786 - val_salidas_continuas_mae: 27.1005 - learning_rate: 5.0000e-04
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2701.5054 - salida_clase_accuracy: 0.9435 - salidas_continuas_mae: 29.8431 - val_loss: 2065.8511 - val_salida_clase_accuracy: 0.9821 - val_salidas_continuas_mae: 26.2298 - learning_rate: 5.0000e-04
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2422.9695 - salida_clase_accuracy: 0.9473 - salidas_continuas_mae: 28.7041 - val_loss: 1876.7816 - val_salida_clase_accuracy: 0.9811 - val_salidas_continuas_mae: 25.7121 - learning_rate: 5.0000e-04
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 2264.1340 - salida_clase_accuracy: 0.9553 - salidas_continuas_mae: 27.7290 - val_loss: 1709.6661 - val_salida_clase_accuracy: 0.9830 - val_salidas_continuas_mae: 24.0819 - learning_rate: 5.0000e-04
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 2138.1223 - salida_clase_accuracy: 0.9579 - salidas_continuas_mae: 26.9147 - val_loss: 1444.8516 - val_salida_clase_accuracy: 0.9878 - val_salidas_continuas_mae: 22.7951 - learning_rate: 5.0000e-04
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 2029.7831 - salida_clase_accuracy: 0.9616 - salidas_continuas_mae: 26.2800 - val_loss: 1301.7179 - val_salida_clase_accuracy: 0.9894 - val_salidas_continuas_mae: 21.1782 - learning_rate: 5.0000e-04
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1788.7350 - salida_clase_accuracy: 0.9585 - salidas_continuas_mae: 25.3162 - val_loss: 1230.1027 - val_salida_clase_accuracy: 0.9850 - val_salidas_continuas_mae: 20.4916 - learning_rate: 5.0000e-04
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1709.3359 - salida_clase_accuracy: 0.9635 - salidas_continuas_mae: 24.9228 - val_loss: 1132.2897 - val_salida_clase_accuracy: 0.9901 - val_salidas_continuas_mae: 20.3996 - learning_rate: 5.0000e-04
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1637.4504 - salida_clase_accuracy: 0.9634 - salidas_continuas_mae: 24.6055 - val_loss: 1053.4586 - val_salida_clase_accuracy: 0.9894 - val_salidas_continuas_mae: 19.3412 - learning_rate: 5.0000e-04
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1542.6570 - salida_clase_accuracy: 0.9669 - salidas_continuas_mae: 23.8335 - val_loss: 950.3796 - val_salida_clase_accuracy: 0.9901 - val_salidas_continuas_mae: 18.6161 - learning_rate: 5.0000e-04
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1578.0947 - salida_clase_accuracy: 0.9677 - salidas_continuas_mae: 24.0541 - val_loss: 919.2805 - val_salida_clase_accuracy: 0.9910 - val_salidas_continuas_mae: 18.2879 - learning_rate: 5.0000e-04
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1443.0984 - salida_clase_accuracy: 0.9715 - salidas_continuas_mae: 23.3380 - val_loss: 877.3546 - val_salida_clase_accuracy: 0.9888 - val_salidas_continuas_mae: 18.3784 - learning_rate: 5.0000e-04
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1373.6597 - salida_clase_accuracy: 0.9753 - salidas_continuas_mae: 22.9109 - val_loss: 813.3062 - val_salida_clase_accuracy: 0.9923 - val_salidas_continuas_mae: 17.4539 - learning_rate: 5.0000e-04
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1386.4083 - salida_clase_accuracy: 0.9740 - salidas_continuas_mae: 22.9175 - val_loss: 787.3943 - val_salida_clase_accuracy: 0.9930 - val_salidas_continuas_mae: 17.1588 - learning_rate: 5.0000e-04
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1317.8813 - salida_clase_accuracy: 0.9733 - salidas_continuas_mae: 22.6043 - val_loss: 722.8694 - val_salida_clase_accuracy: 0.9846 - val_salidas_continuas_mae: 16.5199 - learning_rate: 5.0000e-04
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1242.6470 - salida_clase_accuracy: 0.9733 - salidas_continuas_mae: 22.3256 - val_loss: 690.5552 - val_salida_clase_accuracy: 0.9914 - val_salidas_continuas_mae: 16.1299 - learning_rate: 5.0000e-04
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1267.4688 - salida_clase_accuracy: 0.9725 - salidas_continuas_mae: 22.3728 - val_loss: 672.1773 - val_salida_clase_accuracy: 0.9939 - val_salidas_continuas_mae: 15.7310 - learning_rate: 5.0000e-04
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1221.2653 - salida_clase_accuracy: 0.9745 - salidas_continuas_mae: 22.1480 - val_loss: 679.3226 - val_salida_clase_accuracy: 0.9923 - val_salidas_continuas_mae: 15.8721 - learning_rate: 5.0000e-04
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1195.4174 - salida_clase_accuracy: 0.9781 - salidas_continuas_mae: 21.9640 - val_loss: 651.0529 - val_salida_clase_accuracy: 0.9907 - val_salidas_continuas_mae: 15.9828 - learning_rate: 5.0000e-04
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1208.9521 - salida_clase_accuracy: 0.9736 - salidas_continuas_mae: 21.8133 - val_loss: 641.1572 - val_salida_clase_accuracy: 0.9923 - val_salidas_continuas_mae: 15.7032 - learning_rate: 5.0000e-04
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1159.3621 - salida_clase_accuracy: 0.9744 - salidas_continuas_mae: 21.7201 - val_loss: 631.2328 - val_salida_clase_accuracy: 0.9933 - val_salidas_continuas_mae: 15.7108 - learning_rate: 5.0000e-04
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1164.9473 - salida_clase_accuracy: 0.9791 - salidas_continuas_mae: 21.7138 - val_loss: 620.8237 - val_salida_clase_accuracy: 0.9952 - val_salidas_continuas_mae: 15.6433 - learning_rate: 5.0000e-04
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 1146.5787 - salida_clase_accuracy: 0.9790 - salidas_continuas_mae: 21.5114 - val_loss: 596.6968 - val_salida_clase_accuracy: 0.9946 - val_salidas_continuas_mae: 15.0937 - learning_rate: 5.0000e-04
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 1115.9039 - salida_clase_accuracy: 0.9756 - salidas_continuas_mae: 21.4017 - val_loss: 689.0938 - val_salida_clase_accuracy: 0.9952 - val_salidas_continuas_mae: 16.8098 - learning_rate: 5.0000e-04
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1100.1144 - salida_clase_accuracy: 0.9826 - salidas_continuas_mae: 21.0750 - val_loss: 591.6415 - val_salida_clase_accuracy: 0.9933 - val_salidas_continuas_mae: 15.3116 - learning_rate: 5.0000e-04
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1102.9189 - salida_clase_accuracy: 0.9800 - salidas_continuas_mae: 21.1304 - val_loss: 585.9901 - val_salida_clase_accuracy: 0.9952 - val_salidas_continuas_mae: 15.3727 - learning_rate: 5.0000e-04
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1061.5074 - salida_clase_accuracy: 0.9806 - salidas_continuas_mae: 20.9048 - val_loss: 570.5347 - val_salida_clase_accuracy: 0.9958 - val_salidas_continuas_mae: 15.1267 - learning_rate: 5.0000e-04
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1064.6111 - salida_clase_accuracy: 0.9848 - salidas_continuas_mae: 20.8399 - val_loss: 543.1788 - val_salida_clase_accuracy: 0.9946 - val_salidas_continuas_mae: 14.6563 - learning_rate: 5.0000e-04
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1044.2795 - salida_clase_accuracy: 0.9802 - salidas_continuas_mae: 20.6863 - val_loss: 520.4495 - val_salida_clase_accuracy: 0.9949 - val_salidas_continuas_mae: 14.3340 - learning_rate: 5.0000e-04
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 1109.9144 - salida_clase_accuracy: 0.9792 - salidas_continuas_mae: 21.0548 - val_loss: 545.1309 - val_salida_clase_accuracy: 0.9942 - val_salidas_continuas_mae: 14.6739 - learning_rate: 5.0000e-04
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1028.8865 - salida_clase_accuracy: 0.9836 - salidas_continuas_mae: 20.4153 - val_loss: 515.2098 - val_salida_clase_accuracy: 0.9872 - val_salidas_continuas_mae: 14.1024 - learning_rate: 5.0000e-04
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1010.8564 - salida_clase_accuracy: 0.9831 - salidas_continuas_mae: 20.4232 - val_loss: 507.3811 - val_salida_clase_accuracy: 0.9942 - val_salidas_continuas_mae: 14.0735 - learning_rate: 5.0000e-04
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1014.8630 - salida_clase_accuracy: 0.9814 - salidas_continuas_mae: 20.4250 - val_loss: 533.6459 - val_salida_clase_accuracy: 0.9962 - val_salidas_continuas_mae: 14.4862 - learning_rate: 5.0000e-04
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1028.0664 - salida_clase_accuracy: 0.9809 - salidas_continuas_mae: 20.4611 - val_loss: 544.5488 - val_salida_clase_accuracy: 0.9955 - val_salidas_continuas_mae: 14.9195 - learning_rate: 5.0000e-04
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 987.1622 - salida_clase_accuracy: 0.9824 - salidas_continuas_mae: 20.2274 - val_loss: 505.8751 - val_salida_clase_accuracy: 0.9946 - val_salidas_continuas_mae: 13.8520 - learning_rate: 5.0000e-04
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1021.9337 - salida_clase_accuracy: 0.9836 - salidas_continuas_mae: 20.3857 - val_loss: 542.8997 - val_salida_clase_accuracy: 0.9978 - val_salidas_continuas_mae: 15.1102 - learning_rate: 5.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 1038.3657 - salida_clase_accuracy: 0.9838 - salidas_continuas_mae: 20.4457 - val_loss: 476.6907 - val_salida_clase_accuracy: 0.9907 - val_salidas_continuas_mae: 13.5286 - learning_rate: 5.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 999.3220 - salida_clase_accuracy: 0.9824 - salidas_continuas_mae: 20.2341 - val_loss: 525.9713 - val_salida_clase_accuracy: 0.9965 - val_salidas_continuas_mae: 14.5126 - learning_rate: 5.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 991.6349 - salida_clase_accuracy: 0.9802 - salidas_continuas_mae: 20.0885 - val_loss: 467.6156 - val_salida_clase_accuracy: 0.9968 - val_salidas_continuas_mae: 13.4271 - learning_rate: 5.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 965.5535 - salida_clase_accuracy: 0.9861 - salidas_continuas_mae: 20.0841 - val_loss: 477.2125 - val_salida_clase_accuracy: 0.9965 - val_salidas_continuas_mae: 13.5579 - learning_rate: 5.0000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 980.1183 - salida_clase_accuracy: 0.9825 - salidas_continuas_mae: 19.8730 - val_loss: 484.5941 - val_salida_clase_accuracy: 0.9930 - val_salidas_continuas_mae: 13.8925 - learning_rate: 5.0000e-04
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 977.1735 - salida_clase_accuracy: 0.9855 - salidas_continuas_mae: 20.0166 - val_loss: 496.2451 - val_salida_clase_accuracy: 0.9949 - val_salidas_continuas_mae: 13.9828 - learning_rate: 5.0000e-04
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 934.5785 - salida_clase_accuracy: 0.9852 - salidas_continuas_mae: 19.7482 - val_loss: 479.5122 - val_salida_clase_accuracy: 0.9971 - val_salidas_continuas_mae: 13.7565 - learning_rate: 5.0000e-04
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 950.4034 - salida_clase_accuracy: 0.9867 - salidas_continuas_mae: 19.8266 - val_loss: 471.7691 - val_salida_clase_accuracy: 0.9949 - val_salidas_continuas_mae: 13.8095 - learning_rate: 5.0000e-04
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 479.3490 - salida_clase_accuracy: 0.9945 - salidas_continuas_mae: 13.4075
# Fold 5: Loss=471.3294982910156, MAE=13.296043395996094, Accuracy=0.9959058165550232
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Promediar las historias del entrenamiento
mean_train_loss = np.mean(all_train_loss, axis=0)
mean_val_loss = np.mean(all_val_loss, axis=0)
mean_train_accuracy = np.mean(all_train_accuracy, axis=0)
mean_val_accuracy = np.mean(all_val_accuracy, axis=0)

# Graficar los promedios
plt.figure(figsize=(12, 6))

# Promedio de Loss
plt.subplot(1, 2, 1)
plt.plot(mean_train_loss, label='Training Loss Promedio')
plt.plot(mean_val_loss, label='Validation Loss Promedio')
plt.title('Promedio de Loss durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Promedio de Accuracy
plt.subplot(1, 2, 2)
plt.plot(mean_train_accuracy, label='Training Accuracy Promedio')
plt.plot(mean_val_accuracy, label='Validation Accuracy Promedio')
plt.title('Promedio de Accuracy durante el Entrenamiento y la Validación')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Imprimir métricas promedio de todos los folds
print("\nMétricas promedio de todos los folds:")
print(f"Loss: {np.mean(all_loss)}")
print(f"MAE: {np.mean(all_mae)}")
print(f"MSE: {np.mean(all_mse)}")
print(f"RMSE: {np.mean(all_rmse)}")
print(f"R^2: {np.mean(all_r2)}")
print(f"Accuracy: {np.mean(all_accuracy)}")
print(f"Precisión: {np.mean(all_precision)}")
print(f"Recall: {np.mean(all_recall)}")
print(f"F1-Score: {np.mean(all_f1)}")

# Guardar el modelo
model.save(ruta_modelo)
joblib.dump(scaler_X, ruta_scaler)
np.save(ruta_npy, encoder.classes_)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Métricas promedio de todos los folds:
# Loss: 475.98472290039064
# MAE: 13.497965128522605
# MSE: 475.68549305487556
# RMSE: 21.809448788982785
# R^2: 0.9749483956847651
# Accuracy: 0.99687819480896
# Precisión: 0.9968886118343567
# Recall: 0.996878198567042
# F1-Score: 0.9968792833002006
